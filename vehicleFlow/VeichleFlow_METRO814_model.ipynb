# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import os, pickle, random
from datetime import datetime

# %%
get_after_QA = lambda s: s.split("DISIT/", 1)[1]

# %%
dati = pd.read_excel('/Users/lapotinacci/thesis/metric_datasets/vehicleFlow_dataset.xlsx')
dati = dati[dati["serviceUri"] == "http://www.disit.org/km4city/resource/iot/orionUNIFI/DISIT/METRO814"].copy()
sensor_name = get_after_QA(dati["serviceUri"].iloc[0])
dati.drop(columns=["serviceUri"], inplace=True)
print(dati.shape)
# Out:
# (190, 15)

# %%
# === Creazione cartella esperimento con timestamp ISO ===
timestamp = datetime.now().strftime("%H-%M-%S")
print(f"Ora inizio esperimento: {timestamp}")
day= datetime.now().strftime("%Y-%m-%d")
print(f"Giorno inizio esperimento: {day}")
exp_dir = f"../RISULTATI/{day}/esperimento_{sensor_name}_{timestamp}"

os.makedirs(exp_dir, exist_ok=True)

print(f"Cartella esperimento creata: {exp_dir}")
# Out:
# Ora inizio esperimento: 14-43-32
# Giorno inizio esperimento: 2025-11-30
# Cartella esperimento creata: ../RISULTATI/2025-11-30/esperimento_METRO814_14-43-32

# %%
import ast

mask = ~dati['TTT'].str.contains("nan", na=True)
dtset_completo = dati[mask]

dtset_completo['TTT'] = dtset_completo['TTT'].apply(ast.literal_eval)

# %%
# Filtra le righe dove la colonna TTT ha lunghezza 24, ed elimina tutte le colonne le cui osservazioni sono indipendenti dal giorno
dtset_filtrato = dtset_completo[dtset_completo["TTT"].apply(lambda x: len(x) == 24)].sample(frac=1).reset_index(drop=True)
dtset_filtrato = dtset_filtrato[dtset_filtrato["type_of_TTT"] == "daily"]
len(dtset_filtrato)
# Out:
# 90

# %%
import numpy as np


def is_useful_series(series, zero_ratio_thr=0.85, min_nonzero_value=0.1):
    arr = np.array(series, dtype=float)
    
    # Serie troppo corta
    if len(arr) <= 1:
        return False
    
    # Troppi zeri
    zero_ratio = (arr == 0).mean()
    if zero_ratio >= zero_ratio_thr:
        return False
    
    # Valore medio trascurabile (quasi zero)
    mean_val = np.mean(arr)
    if abs(mean_val) < min_nonzero_value:
        return False
    
    # Se arriva qui, la serie ha valori significativi
    return True

# Applica filtro
mask_useful = dtset_filtrato["TTT"].apply(is_useful_series)
df_useful = dtset_filtrato[mask_useful]

# %%
def spezza_serie_in_colonne(df, colonna_stringa, prefix='col_'):
    # --- Controllo colonna ---
    if colonna_stringa not in df.columns:
        raise ValueError(f"La colonna '{colonna_stringa}' non esiste nel DataFrame")

    result_df = df.copy()

    # Estraggo la colonna contenente gli embedding
    col = result_df.pop(colonna_stringa)

    embeddings = []

    for item in col:
        # Gestione valori nulli o vuoti
        if pd.isna(item) or item == "":
            embeddings.append([])
            continue
        
        # Se l'item è già una lista o un array (non stringa), lo gestiamo direttamente
        if isinstance(item, (list, np.ndarray)):
            embeddings.append(list(item))
            continue

        vett = None
        
        # --- TENTATIVO 1: Parsing Standard Python (es. "[1, 2, 3]") ---
        try:
            parsed = ast.literal_eval(item)
            if isinstance(parsed, (list, tuple)):
                vett = list(parsed)
        except (ValueError, SyntaxError):
            # Se fallisce (es. SyntaxError per mancanza di virgole), passiamo al tentativo 2
            pass

        # --- TENTATIVO 2: Parsing per Spazi (es. "[1 2 3]" o "1 2 3") ---
        if vett is None:
            try:
                # Rimuove parentesi quadre, tonde e spazi iniziali/finali
                clean_str = item.replace('[', '').replace(']', '').replace('(', '').replace(')', '').strip()
                
                # Se la stringa è vuota dopo la pulizia (es. "[]"), è una lista vuota
                if not clean_str:
                    vett = []
                else:
                    # .split() senza argomenti gestisce spazi multipli, tab e newline automaticamente
                    vett = [float(x) for x in clean_str.split()]
            except Exception as e:
                print(f"Errore nel parsing dell'elemento '{item}': {e}")
                vett = []

        # --- Conversione finale e check ---
        # Assicuro che tutti gli elementi siano float (utile se ast.literal_eval ha trovato interi)
        try:
            if vett:
                vett = [float(x) for x in vett]
            embeddings.append(vett)
        except Exception as e:
            print(f"Errore conversione float per '{item}': {e}")
            embeddings.append([])

    # --- Uniformo dimensione dei vettori ---
    lengths = [len(v) for v in embeddings]
    if not lengths or max(lengths) == 0:
        # Se non ci sono dati validi, restituisco il df senza la colonna oppure sollevo errore
        # Qui scelgo di restituire il df originale senza la colonna parsata per evitare crash
        print("Warning: Nessun embedding valido trovato.")
        return result_df

    max_len = max(lengths)

    # Padding con NaN
    embeddings_padded = [
        v + [np.nan] * (max_len - len(v)) if len(v) < max_len else v
        for v in embeddings
    ]

    # --- Creo DataFrame delle nuove colonne ---
    colonne_embedding = pd.DataFrame(
        embeddings_padded,
        index=result_df.index,
        columns=[f"{prefix}{i}" for i in range(max_len)]
    )

    # --- Merge col DataFrame originale ---
    return pd.concat([result_df, colonne_embedding], axis=1)

# %%
for ttt in df_useful.TTT:
    plt.plot(ttt)

# %%
def summary_df(df):
    summary = pd.DataFrame({
        'dtype': df.dtypes,
        'n_missing': df.isna().sum(),
        '%_missing': (df.isna().mean() * 100).round(2),
        'n_unique': df.nunique(),
        'top_value': df.mode().iloc[0],  # moda
        'top_freq': [df[col].value_counts(dropna=True).iloc[0] if not df[col].value_counts(dropna=True).empty else None for col in df.columns],
        'min': [df[col].min() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'max': [df[col].max() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'mean': [df[col].mean() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'std': [df[col].std() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
    })
    return summary

# %%
#Nella precedente sono state eliminate le colonne con Nan, tuttavia alcuni dataset dei sensori METRO hanno dei Nan in city e surface dunque vengono rimossi nel prcedente box

categorical = [
    'is_weekend'
    ]

#consiglio, per serie cicliche usare funzioni periodiche tipo seno coseno 
df_encoded = pd.get_dummies(df_useful
                            , columns=categorical)

# %%
def save_pkl(obj, path):
    with open(path, "wb") as f:
        pickle.dump(obj, f)
    print(f"Salvato: {path}")

def load_pkl(path):
    with open(path, "rb") as f:
        return pickle.load(f)

# %%
#codifica ciclica delle features e individuazione del'ora del giorno e della settimana 

def encode_time_features(df, start_col="interval_start", end_col="interval_end"):
    df = df.copy()
    
    # Step 1: Ensure datetime columns are in the correct format first
    df[start_col] = pd.to_datetime(df[start_col], utc=True, format="mixed")
    df[end_col] = pd.to_datetime(df[end_col], utc=True, format="mixed")

    # Step 2: Extract 'month' and 'day' after conversion
    df['month'] = df[start_col].dt.month
    df['day'] = df[start_col].dt.dayofweek # Note: dayofweek is typically used for cyclical weekly patterns
    
    # Step 3: Now you can create the cyclical features
    df['month_sin'] = np.sin(2 * np.pi * df['month']/len(df['month'].unique()))
    df['month_cos'] = np.cos(2 * np.pi * df['month']/len(df['month'].unique()))
    df['day_sin'] = np.sin(2 * np.pi * df['day']/len(df['day'].unique()))
    df['day_cos'] = np.cos(2 * np.pi * df['day']/len(df['day'].unique()))


    # Ora del giorno (0-23) → ciclo giornaliero
    df["hour"] = df[start_col].dt.hour
    angle_day_start = 2 * np.pi * df["hour"] / 24
    df["start_time_sin"] = np.sin(angle_day_start)
    df["start_time_cos"] = np.cos(angle_day_start)

    df["hour_end"] = df[end_col].dt.hour
    angle_day_end = 2 * np.pi * df["hour_end"] / 24
    df["end_time_sin"] = np.sin(angle_day_end)
    df["end_time_cos"] = np.cos(angle_day_end)

    # Durata in minuti
    df["duration_minutes"] = (df[end_col] - df[start_col]).dt.total_seconds() / 60

    # Giorno della settimana (0=Mon..6=Sun) → ciclo settimanale
    dayofweek = df[start_col].dt.dayofweek
    angle_week = 2 * np.pi * dayofweek / 7
    df["dow_sin"] = np.sin(angle_week)
    df["dow_cos"] = np.cos(angle_week)

    # Giorno dell’anno (1-365) → ciclo annuale
    dayofyear = df[start_col].dt.dayofyear
    angle_year = 2 * np.pi * dayofyear / 365
    df["doy_sin"] = np.sin(angle_year)
    df["doy_cos"] = np.cos(angle_year)

    # Rimuovo colonne temporali e variabili ausiliarie
    df = df.drop(columns=[start_col, end_col, "hour", "hour_end", "day", "month"])
    return df

embedding_cols = ['highway_embeddings']

df_final = encode_time_features(df_encoded)
df_final.drop(columns=['type_of_TTT'], inplace=True)
for emb_col in embedding_cols:
    df_final = spezza_serie_in_colonne(df_final, emb_col, prefix=f'{emb_col}_')
df_final.shape

# Salvataggio DataFrame finale
df_path = os.path.join(exp_dir, f"dataframe_{sensor_name}")
os.makedirs(df_path, exist_ok=True)
save_pkl(df_final, os.path.join(df_path, f"filtered_dataframe.pkl"))
# Out:
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO814_14-43-32/dataframe_METRO814/filtered_dataframe.pkl

# %%
for ttt in df_final.TTT[10:20]:
    plt.plot(ttt)
    plt.title("Esempi di TTT ARPAT")
    plt.xlabel("Ora del Giorno")
    plt.ylabel("Valore TTT")

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

def series_to_2d_array(series, output_dim=24):
    arr = np.stack(series.apply(lambda x: np.array(x, dtype=np.float32)))
    if arr.shape[1] != output_dim:
        raise ValueError(f"Ogni elemento deve avere {output_dim} valori, trovato {arr.shape[1]}")
    return arr

 # Separazione delle feature e del target
X = df_final.drop(columns=['TTT'])
y = df_final['TTT']

X_np = X.to_numpy().astype(np.float32)
y_np = series_to_2d_array(y, output_dim=24)

# Calcolo deviazione standard per ogni serie
std_scores = np.std(y_np, axis=1)

std_scores_log = np.log1p(std_scores)  # log(1+x) per evitare problemi con valori vicini a 0

std_scores_normalized = (std_scores_log - np.min(std_scores_log)) / (np.max(std_scores_log) - np.min(std_scores_log))

# Creo bin basati sui quantili
bins = np.array([0.0, 0.4, 0.8, 1.0])
std_bins = np.digitize(std_scores_normalized, bins)

# Primo split: train (80%) vs temp (20%)
# Passo anche std_bins per poter stratificare
X_train, X_test, y_train, y_test = train_test_split(
    X_np, y_np,
    test_size=0.2,
    random_state=42,
    stratify=std_bins, 
    shuffle=True
)

print(f"Train size: {X_train.shape}, {y_train.shape}")
print(f"Test size: {X_test.shape}, {y_test.shape}")

# Debug prints
print(f"Final shapes:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

# Scaler per input
scaler_X = MinMaxScaler()
X_train = scaler_X.fit_transform(X_train)
X_test  = scaler_X.transform(X_test)

# Scaler per output (se serve normalizzare anche y)
scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(y_train)
y_test  = scaler_y.transform(y_test)

#cartella salvataggio train e test
path = os.path.join(exp_dir, "train_test_data")
os.makedirs(path, exist_ok=True)

#  === Salvataggio dataset e scaler in formato .pkl ===
save_pkl(scaler_X.inverse_transform(X_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_X.inverse_transform(X_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_test_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_test_unscaled_{sensor_name}.pkl"))

save_pkl(X_train, os.path.join(exp_dir, "X_train.pkl"))
save_pkl(y_train, os.path.join(exp_dir, "y_train.pkl"))
save_pkl(X_test, os.path.join(exp_dir, "X_test.pkl"))
save_pkl(y_test, os.path.join(exp_dir, "y_test.pkl"))

save_pkl(scaler_X, os.path.join(exp_dir, "scaler_X.pkl"))
save_pkl(scaler_y, os.path.join(exp_dir, "scaler_y.pkl"))

print("Scaler salvati.")

print("\nTutti i file sono stati salvati correttamente.")
print(f"Percorso cartella: {os.path.abspath(exp_dir)}")
# Out:
# Train size: (72, 28), (72, 24)
# Test size: (18, 28), (18, 24)
# Final shapes:
# X_train: (72, 28)
# y_train: (72, 24)
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_train_unscaled_METRO814.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_train_unscaled_METRO814.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_test_unscaled_METRO814.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_test_unscaled_METRO814.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO814_14-43-32/X_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO814_14-43-32/y_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO814_14-43-32/X_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO814_14-43-32/y_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO814_14-43-32/scaler_X.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO814_14-43-32/scaler_y.pkl
# Scaler salvati.
#
# Tutti i file sono stati salvati correttamente.
# Percorso cartella: /Users/lapotinacci/thesis/Federated_Sys/RISULTATI/2025-11-30/esperimento_METRO814_14-43-32

# %%
# === Costruisci i path ===
path_X_train = os.path.join(exp_dir, "X_train.pkl")
path_y_train = os.path.join(exp_dir, "y_train.pkl")
path_X_test  = os.path.join(exp_dir, "X_test.pkl")
path_y_test  = os.path.join(exp_dir, "y_test.pkl")

path_scaler_X = os.path.join(exp_dir, "scaler_X.pkl")
path_scaler_y = os.path.join(exp_dir, "scaler_y.pkl")

# === Ricaricamento ===
X_train = load_pkl(path_X_train)
y_train = load_pkl(path_y_train)
X_test  = load_pkl(path_X_test)
y_test  = load_pkl(path_y_test)


scaler_X = load_pkl(path_scaler_X)
scaler_y = load_pkl(path_scaler_y)

print("Shapes ricostruite:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

print("\nScaler caricati:")
print("scaler_X:", type(scaler_X))
print("scaler_y:", type(scaler_y))
# Out:
# Shapes ricostruite:
# X_train: (72, 28)
# y_train: (72, 24)
# X_test: (18, 28)
# y_test: (18, 24)
#
# Scaler caricati:
# scaler_X: <class 'sklearn.preprocessing._data.MinMaxScaler'>
# scaler_y: <class 'sklearn.preprocessing._data.MinMaxScaler'>

# %% [markdown]
# # modelli

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers # type: ignore
from tensorflow.keras.layers import Dropout # type: ignore
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
def save_prediction_plots(y_true, y_pred, output_dir, prefix="pred_plot"):
    os.makedirs(output_dir, exist_ok=True)

    n = len(y_true)
    print(f"Salvo {n} plot in: {output_dir}")

    for i in range(n):
        plt.figure(figsize=(8, 3))
        plt.plot(y_true[i], label="True")
        plt.plot(y_pred[i], label="Pred")
        plt.legend()
        plt.tight_layout()

        filename = f"{prefix}_{i+1}.png"
        path = os.path.join(output_dir, filename)

        plt.savefig(path)
        plt.close()

    print("Plot salvati correttamente.")

# %%
# Definizione modello DNN
def build_model(input_shape: tuple, output_shape: tuple):
    model = models.Sequential([
        layers.Dense(128, activation = "relu", input_shape=input_shape),
        Dropout(0.0),
        layers.Dense(output_shape, 'linear')
    ])
    model.compile(
    optimizer=optimizers.AdamW(learning_rate=0.0129, weight_decay=0.0148),
    loss= 'mse',
    metrics=['mae'],
    )
    return model

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',      # metrica da monitorare, es. val_loss o val_mae
    patience=50,             # numero di epoche senza miglioramento prima di fermare
    restore_best_weights=True,  # ripristina i pesi migliori trovati
    verbose = 1
)

# Training del modello
model = build_model((X_test.shape[1],), y_test.shape[1])
history = model.fit(
    X_train, y_train,
    epochs=1000,
    batch_size=32,
    callbacks = [early_stop],
    validation_split = 0.2,
    verbose=1
    )

'''print("y_train min/max:", y_train_np.min(), y_train_np.max())
print("y_pred min/max (scaled):", y_pred.min(), y_pred.max())
y_pred_rescaled = scaler_y.inverse_transform(y_pred)
print("y_pred_rescaled min/max:", y_pred_rescaled.min(), y_pred_rescaled.max())'''

if not os.path.exists(os.path.join(exp_dir, "model")):
    os.makedirs(os.path.join(exp_dir, "model"))
    model.save(os.path.join(exp_dir, "model", "NO2_MAREMMA_model.keras"))
# Out:
# Epoch 1/1000
# /Users/lapotinacci/thesis/Federated_Sys/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.4295 - mae: 0.5229 - val_loss: 0.1226 - val_mae: 0.2651
# Epoch 2/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1092 - mae: 0.2599 - val_loss: 0.1264 - val_mae: 0.3056
# Epoch 3/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1040 - mae: 0.2784 - val_loss: 0.0858 - val_mae: 0.2429
# Epoch 4/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0600 - mae: 0.1972 - val_loss: 0.0512 - val_mae: 0.1779
# Epoch 5/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0421 - mae: 0.1593 - val_loss: 0.0463 - val_mae: 0.1719
# Epoch 6/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0449 - mae: 0.1692 - val_loss: 0.0338 - val_mae: 0.1446
# Epoch 7/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0336 - mae: 0.1466 - val_loss: 0.0202 - val_mae: 0.1095
# Epoch 8/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0211 - mae: 0.1149 - val_loss: 0.0189 - val_mae: 0.1065
# Epoch 9/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0210 - mae: 0.1121 - val_loss: 0.0203 - val_mae: 0.1147
# Epoch 10/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0196 - mae: 0.1117 - val_loss: 0.0144 - val_mae: 0.0979
# Epoch 11/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0138 - mae: 0.0917 - val_loss: 0.0117 - val_mae: 0.0835
# Epoch 12/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0125 - mae: 0.0859 - val_loss: 0.0122 - val_mae: 0.0863
# Epoch 13/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0126 - mae: 0.0866 - val_loss: 0.0106 - val_mae: 0.0806
# Epoch 14/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0092 - mae: 0.0729 - val_loss: 0.0091 - val_mae: 0.0748
# Epoch 15/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0071 - mae: 0.0642 - val_loss: 0.0082 - val_mae: 0.0693
# Epoch 16/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0064 - mae: 0.0615 - val_loss: 0.0063 - val_mae: 0.0587
# Epoch 17/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0051 - mae: 0.0540 - val_loss: 0.0045 - val_mae: 0.0519
# Epoch 18/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0039 - mae: 0.0485 - val_loss: 0.0040 - val_mae: 0.0477
# Epoch 19/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0034 - mae: 0.0446 - val_loss: 0.0037 - val_mae: 0.0460
# Epoch 20/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0406 - val_loss: 0.0028 - val_mae: 0.0412
# Epoch 21/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0020 - mae: 0.0337 - val_loss: 0.0022 - val_mae: 0.0363
# Epoch 22/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0016 - mae: 0.0314 - val_loss: 0.0019 - val_mae: 0.0340
# Epoch 23/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0013 - mae: 0.0282 - val_loss: 0.0013 - val_mae: 0.0276
# Epoch 24/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.9507e-04 - mae: 0.0222 - val_loss: 0.0011 - val_mae: 0.0252
# Epoch 25/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.0849e-04 - mae: 0.0215 - val_loss: 9.4525e-04 - val_mae: 0.0240
# Epoch 26/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.9248e-04 - mae: 0.0210 - val_loss: 6.5236e-04 - val_mae: 0.0199
# Epoch 27/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.9720e-04 - mae: 0.0178 - val_loss: 4.6060e-04 - val_mae: 0.0169
# Epoch 28/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.3826e-04 - mae: 0.0167 - val_loss: 3.8798e-04 - val_mae: 0.0152
# Epoch 29/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 4.0244e-04 - mae: 0.0157 - val_loss: 3.2954e-04 - val_mae: 0.0142
# Epoch 30/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.1493e-04 - mae: 0.0141 - val_loss: 3.0697e-04 - val_mae: 0.0141
# Epoch 31/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.7587e-04 - mae: 0.0132 - val_loss: 2.7147e-04 - val_mae: 0.0131
# Epoch 32/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.2282e-04 - mae: 0.0117 - val_loss: 2.0745e-04 - val_mae: 0.0113
# Epoch 33/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.7262e-04 - mae: 0.0101 - val_loss: 1.7584e-04 - val_mae: 0.0102
# Epoch 34/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.6368e-04 - mae: 0.0097 - val_loss: 1.4399e-04 - val_mae: 0.0091
# Epoch 35/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.4148e-04 - mae: 0.0092 - val_loss: 1.1562e-04 - val_mae: 0.0085
# Epoch 36/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1756e-04 - mae: 0.0085 - val_loss: 1.0614e-04 - val_mae: 0.0081
# Epoch 37/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.0907e-04 - mae: 0.0080 - val_loss: 9.3032e-05 - val_mae: 0.0075
# Epoch 38/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.1288e-05 - mae: 0.0073 - val_loss: 7.8847e-05 - val_mae: 0.0069
# Epoch 39/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.2950e-05 - mae: 0.0071 - val_loss: 7.3817e-05 - val_mae: 0.0066
# Epoch 40/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.4301e-05 - mae: 0.0066 - val_loss: 6.0196e-05 - val_mae: 0.0059
# Epoch 41/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.2855e-05 - mae: 0.0061 - val_loss: 5.2080e-05 - val_mae: 0.0056
# Epoch 42/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.6971e-05 - mae: 0.0058 - val_loss: 4.5114e-05 - val_mae: 0.0052
# Epoch 43/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.9060e-05 - mae: 0.0055 - val_loss: 4.0166e-05 - val_mae: 0.0047
# Epoch 44/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.5184e-05 - mae: 0.0051 - val_loss: 3.7635e-05 - val_mae: 0.0044
# Epoch 45/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3014e-05 - mae: 0.0048 - val_loss: 3.1894e-05 - val_mae: 0.0041
# Epoch 46/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.7507e-05 - mae: 0.0046 - val_loss: 2.8487e-05 - val_mae: 0.0038
# Epoch 47/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.5266e-05 - mae: 0.0044 - val_loss: 2.6168e-05 - val_mae: 0.0036
# Epoch 48/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.2265e-05 - mae: 0.0042 - val_loss: 2.4806e-05 - val_mae: 0.0034
# Epoch 49/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.9714e-05 - mae: 0.0039 - val_loss: 2.4413e-05 - val_mae: 0.0033
# Epoch 50/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.7224e-05 - mae: 0.0036 - val_loss: 2.1149e-05 - val_mae: 0.0031
# Epoch 51/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.4926e-05 - mae: 0.0035 - val_loss: 1.8444e-05 - val_mae: 0.0029
# Epoch 52/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3728e-05 - mae: 0.0035 - val_loss: 1.6474e-05 - val_mae: 0.0029
# Epoch 53/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.1707e-05 - mae: 0.0034 - val_loss: 1.6255e-05 - val_mae: 0.0028
# Epoch 54/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.0063e-05 - mae: 0.0032 - val_loss: 1.5318e-05 - val_mae: 0.0026
# Epoch 55/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.8325e-05 - mae: 0.0030 - val_loss: 1.4187e-05 - val_mae: 0.0024
# Epoch 56/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.7305e-05 - mae: 0.0029 - val_loss: 1.3699e-05 - val_mae: 0.0024
# Epoch 57/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.6350e-05 - mae: 0.0028 - val_loss: 1.3018e-05 - val_mae: 0.0023
# Epoch 58/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.5304e-05 - mae: 0.0027 - val_loss: 1.2007e-05 - val_mae: 0.0022
# Epoch 59/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.4256e-05 - mae: 0.0026 - val_loss: 1.1110e-05 - val_mae: 0.0021
# Epoch 60/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.3482e-05 - mae: 0.0025 - val_loss: 1.0324e-05 - val_mae: 0.0021
# Epoch 61/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.3115e-05 - mae: 0.0025 - val_loss: 9.4573e-06 - val_mae: 0.0020
# Epoch 62/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2091e-05 - mae: 0.0023 - val_loss: 9.4108e-06 - val_mae: 0.0019
# Epoch 63/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1523e-05 - mae: 0.0023 - val_loss: 9.2920e-06 - val_mae: 0.0019
# Epoch 64/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.0884e-05 - mae: 0.0022 - val_loss: 8.5417e-06 - val_mae: 0.0018
# Epoch 65/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0297e-05 - mae: 0.0021 - val_loss: 7.9987e-06 - val_mae: 0.0017
# Epoch 66/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 9.7520e-06 - mae: 0.0021 - val_loss: 7.6595e-06 - val_mae: 0.0017
# Epoch 67/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 9.2441e-06 - mae: 0.0020 - val_loss: 7.3012e-06 - val_mae: 0.0017
# Epoch 68/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.7358e-06 - mae: 0.0020 - val_loss: 6.7102e-06 - val_mae: 0.0016
# Epoch 69/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 8.3233e-06 - mae: 0.0019 - val_loss: 6.4072e-06 - val_mae: 0.0016
# Epoch 70/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 7.9406e-06 - mae: 0.0019 - val_loss: 6.0601e-06 - val_mae: 0.0015
# Epoch 71/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.4851e-06 - mae: 0.0018 - val_loss: 5.7217e-06 - val_mae: 0.0014
# Epoch 72/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.2401e-06 - mae: 0.0018 - val_loss: 5.3484e-06 - val_mae: 0.0014
# Epoch 73/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.0374e-06 - mae: 0.0018 - val_loss: 5.5123e-06 - val_mae: 0.0014
# Epoch 74/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.5434e-06 - mae: 0.0017 - val_loss: 5.1163e-06 - val_mae: 0.0014
# Epoch 75/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.1889e-06 - mae: 0.0017 - val_loss: 4.6594e-06 - val_mae: 0.0013
# Epoch 76/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.9619e-06 - mae: 0.0016 - val_loss: 4.3528e-06 - val_mae: 0.0013
# Epoch 77/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.7307e-06 - mae: 0.0016 - val_loss: 4.1818e-06 - val_mae: 0.0012
# Epoch 78/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.4671e-06 - mae: 0.0016 - val_loss: 4.1634e-06 - val_mae: 0.0012
# Epoch 79/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 5.1627e-06 - mae: 0.0015 - val_loss: 4.2269e-06 - val_mae: 0.0012
# Epoch 80/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.9883e-06 - mae: 0.0015 - val_loss: 4.1247e-06 - val_mae: 0.0012
# Epoch 81/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.8326e-06 - mae: 0.0015 - val_loss: 3.9924e-06 - val_mae: 0.0012
# Epoch 82/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.6359e-06 - mae: 0.0014 - val_loss: 3.5663e-06 - val_mae: 0.0011
# Epoch 83/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3847e-06 - mae: 0.0014 - val_loss: 3.3454e-06 - val_mae: 0.0011
# Epoch 84/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.2080e-06 - mae: 0.0014 - val_loss: 3.2881e-06 - val_mae: 0.0011
# Epoch 85/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0393e-06 - mae: 0.0013 - val_loss: 3.1703e-06 - val_mae: 0.0011
# Epoch 86/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.9000e-06 - mae: 0.0013 - val_loss: 3.1226e-06 - val_mae: 0.0010
# Epoch 87/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.7434e-06 - mae: 0.0013 - val_loss: 3.1411e-06 - val_mae: 0.0010
# Epoch 88/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.5917e-06 - mae: 0.0012 - val_loss: 2.9626e-06 - val_mae: 9.9534e-04
# Epoch 89/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.4695e-06 - mae: 0.0012 - val_loss: 2.7659e-06 - val_mae: 9.6770e-04
# Epoch 90/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.3406e-06 - mae: 0.0012 - val_loss: 2.5580e-06 - val_mae: 9.4806e-04
# Epoch 91/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.2709e-06 - mae: 0.0012 - val_loss: 2.4422e-06 - val_mae: 9.2808e-04
# Epoch 92/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.1353e-06 - mae: 0.0012 - val_loss: 2.4947e-06 - val_mae: 9.2555e-04
# Epoch 93/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.0354e-06 - mae: 0.0011 - val_loss: 2.5856e-06 - val_mae: 9.2419e-04
# Epoch 94/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.9323e-06 - mae: 0.0011 - val_loss: 2.4724e-06 - val_mae: 8.9867e-04
# Epoch 95/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.8715e-06 - mae: 0.0011 - val_loss: 2.2791e-06 - val_mae: 8.6621e-04
# Epoch 96/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.7519e-06 - mae: 0.0011 - val_loss: 2.2005e-06 - val_mae: 8.6153e-04
# Epoch 97/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.6641e-06 - mae: 0.0011 - val_loss: 2.1953e-06 - val_mae: 8.5854e-04
# Epoch 98/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.5902e-06 - mae: 0.0011 - val_loss: 2.1322e-06 - val_mae: 8.3793e-04
# Epoch 99/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.5108e-06 - mae: 0.0010 - val_loss: 2.0333e-06 - val_mae: 8.2229e-04
# Epoch 100/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.4282e-06 - mae: 0.0010 - val_loss: 1.9811e-06 - val_mae: 8.1661e-04
# Epoch 101/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.3685e-06 - mae: 0.0010 - val_loss: 1.9131e-06 - val_mae: 7.9833e-04
# Epoch 102/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.2937e-06 - mae: 9.8759e-04 - val_loss: 1.9011e-06 - val_mae: 7.8161e-04
# Epoch 103/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.2323e-06 - mae: 9.6631e-04 - val_loss: 1.8428e-06 - val_mae: 7.6596e-04
# Epoch 104/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1729e-06 - mae: 9.5540e-04 - val_loss: 1.7492e-06 - val_mae: 7.6063e-04
# Epoch 105/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1463e-06 - mae: 9.5633e-04 - val_loss: 1.7350e-06 - val_mae: 7.5126e-04
# Epoch 106/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.0479e-06 - mae: 9.3099e-04 - val_loss: 1.6242e-06 - val_mae: 7.2440e-04
# Epoch 107/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.0026e-06 - mae: 9.1918e-04 - val_loss: 1.5696e-06 - val_mae: 7.1101e-04
# Epoch 108/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.9541e-06 - mae: 8.9945e-04 - val_loss: 1.5912e-06 - val_mae: 7.1055e-04
# Epoch 109/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9005e-06 - mae: 8.8707e-04 - val_loss: 1.5459e-06 - val_mae: 7.0191e-04
# Epoch 110/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.8651e-06 - mae: 8.8526e-04 - val_loss: 1.5604e-06 - val_mae: 7.0585e-04
# Epoch 111/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.8307e-06 - mae: 8.7343e-04 - val_loss: 1.5175e-06 - val_mae: 6.9426e-04
# Epoch 112/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.7561e-06 - mae: 8.5539e-04 - val_loss: 1.3769e-06 - val_mae: 6.6715e-04
# Epoch 113/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.7442e-06 - mae: 8.5318e-04 - val_loss: 1.2838e-06 - val_mae: 6.4668e-04
# Epoch 114/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.7111e-06 - mae: 8.3739e-04 - val_loss: 1.3590e-06 - val_mae: 6.5821e-04
# Epoch 115/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.6575e-06 - mae: 8.2921e-04 - val_loss: 1.3428e-06 - val_mae: 6.6058e-04
# Epoch 116/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.6073e-06 - mae: 8.2310e-04 - val_loss: 1.3754e-06 - val_mae: 6.5912e-04
# Epoch 117/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.5743e-06 - mae: 8.0287e-04 - val_loss: 1.3373e-06 - val_mae: 6.4883e-04
# Epoch 118/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.5391e-06 - mae: 7.9048e-04 - val_loss: 1.2804e-06 - val_mae: 6.3864e-04
# Epoch 119/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.4970e-06 - mae: 7.8419e-04 - val_loss: 1.1777e-06 - val_mae: 6.1817e-04
# Epoch 120/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.4795e-06 - mae: 7.7869e-04 - val_loss: 1.1384e-06 - val_mae: 6.0950e-04
# Epoch 121/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.4458e-06 - mae: 7.7052e-04 - val_loss: 1.1731e-06 - val_mae: 6.1390e-04
# Epoch 122/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3994e-06 - mae: 7.5292e-04 - val_loss: 1.2649e-06 - val_mae: 6.2557e-04
# Epoch 123/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3850e-06 - mae: 7.4663e-04 - val_loss: 1.2617e-06 - val_mae: 6.1791e-04
# Epoch 124/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.3676e-06 - mae: 7.4123e-04 - val_loss: 1.1601e-06 - val_mae: 5.9894e-04
# Epoch 125/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3261e-06 - mae: 7.2957e-04 - val_loss: 1.0858e-06 - val_mae: 5.9465e-04
# Epoch 126/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.2910e-06 - mae: 7.1998e-04 - val_loss: 1.0615e-06 - val_mae: 5.8254e-04
# Epoch 127/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.2658e-06 - mae: 7.0779e-04 - val_loss: 1.0527e-06 - val_mae: 5.6710e-04
# Epoch 128/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.2447e-06 - mae: 7.0141e-04 - val_loss: 1.0364e-06 - val_mae: 5.5678e-04
# Epoch 129/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.2329e-06 - mae: 7.0000e-04 - val_loss: 1.0361e-06 - val_mae: 5.6342e-04
# Epoch 130/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.2015e-06 - mae: 6.8563e-04 - val_loss: 1.0019e-06 - val_mae: 5.5058e-04
# Epoch 131/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1890e-06 - mae: 6.8076e-04 - val_loss: 9.0750e-07 - val_mae: 5.2659e-04
# Epoch 132/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.1614e-06 - mae: 6.7481e-04 - val_loss: 9.3203e-07 - val_mae: 5.3860e-04
# Epoch 133/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1302e-06 - mae: 6.6471e-04 - val_loss: 9.8514e-07 - val_mae: 5.4998e-04
# Epoch 134/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1083e-06 - mae: 6.5466e-04 - val_loss: 9.5823e-07 - val_mae: 5.3298e-04
# Epoch 135/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0916e-06 - mae: 6.5121e-04 - val_loss: 8.9681e-07 - val_mae: 5.2019e-04
# Epoch 136/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0649e-06 - mae: 6.4427e-04 - val_loss: 8.2078e-07 - val_mae: 5.0333e-04
# Epoch 137/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.0548e-06 - mae: 6.4012e-04 - val_loss: 8.0295e-07 - val_mae: 4.9657e-04
# Epoch 138/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.0325e-06 - mae: 6.3162e-04 - val_loss: 8.5481e-07 - val_mae: 5.0694e-04
# Epoch 139/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.0309e-06 - mae: 6.3301e-04 - val_loss: 8.7637e-07 - val_mae: 5.1255e-04
# Epoch 140/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.0290e-06 - mae: 6.3267e-04 - val_loss: 7.8064e-07 - val_mae: 4.8160e-04
# Epoch 141/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.8909e-07 - mae: 6.1329e-04 - val_loss: 7.8866e-07 - val_mae: 4.8763e-04
# Epoch 142/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 9.5148e-07 - mae: 6.0184e-04 - val_loss: 8.5925e-07 - val_mae: 5.0906e-04
# Epoch 143/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.6947e-07 - mae: 6.1079e-04 - val_loss: 8.3121e-07 - val_mae: 4.9500e-04
# Epoch 144/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.3344e-07 - mae: 5.9471e-04 - val_loss: 8.2951e-07 - val_mae: 5.0024e-04
# Epoch 145/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.0916e-07 - mae: 5.8791e-04 - val_loss: 8.1747e-07 - val_mae: 4.9362e-04
# Epoch 146/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.8944e-07 - mae: 5.7917e-04 - val_loss: 7.5779e-07 - val_mae: 4.7102e-04
# Epoch 147/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.7702e-07 - mae: 5.7387e-04 - val_loss: 7.1367e-07 - val_mae: 4.6455e-04
# Epoch 148/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.5617e-07 - mae: 5.7211e-04 - val_loss: 6.6622e-07 - val_mae: 4.5412e-04
# Epoch 149/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.4885e-07 - mae: 5.7079e-04 - val_loss: 6.7567e-07 - val_mae: 4.5353e-04
# Epoch 150/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.2998e-07 - mae: 5.7025e-04 - val_loss: 6.7838e-07 - val_mae: 4.5490e-04
# Epoch 151/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 8.2131e-07 - mae: 5.6813e-04 - val_loss: 6.7690e-07 - val_mae: 4.5275e-04
# Epoch 152/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.0900e-07 - mae: 5.5566e-04 - val_loss: 7.0904e-07 - val_mae: 4.5858e-04
# Epoch 153/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.8720e-07 - mae: 5.4392e-04 - val_loss: 6.5840e-07 - val_mae: 4.4855e-04
# Epoch 154/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.7803e-07 - mae: 5.4844e-04 - val_loss: 6.4028e-07 - val_mae: 4.4248e-04
# Epoch 155/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.6676e-07 - mae: 5.4337e-04 - val_loss: 6.5011e-07 - val_mae: 4.3979e-04
# Epoch 156/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.6876e-07 - mae: 5.4215e-04 - val_loss: 6.8640e-07 - val_mae: 4.4851e-04
# Epoch 157/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.3830e-07 - mae: 5.2582e-04 - val_loss: 6.2786e-07 - val_mae: 4.2881e-04
# Epoch 158/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.3446e-07 - mae: 5.2771e-04 - val_loss: 5.7238e-07 - val_mae: 4.1929e-04
# Epoch 159/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.1509e-07 - mae: 5.2467e-04 - val_loss: 5.8351e-07 - val_mae: 4.2163e-04
# Epoch 160/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.0782e-07 - mae: 5.2428e-04 - val_loss: 5.8674e-07 - val_mae: 4.2117e-04
# Epoch 161/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.8153e-07 - mae: 5.1395e-04 - val_loss: 6.2579e-07 - val_mae: 4.2638e-04
# Epoch 162/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 6.9160e-07 - mae: 5.0770e-04 - val_loss: 6.0697e-07 - val_mae: 4.2756e-04
# Epoch 163/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.6090e-07 - mae: 5.0104e-04 - val_loss: 6.0360e-07 - val_mae: 4.2493e-04
# Epoch 164/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.4910e-07 - mae: 4.9454e-04 - val_loss: 5.5471e-07 - val_mae: 4.0560e-04
# Epoch 165/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.3546e-07 - mae: 4.9167e-04 - val_loss: 4.9906e-07 - val_mae: 3.9239e-04
# Epoch 166/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.2290e-07 - mae: 4.9161e-04 - val_loss: 4.7350e-07 - val_mae: 3.8533e-04
# Epoch 167/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.1385e-07 - mae: 4.8727e-04 - val_loss: 4.8060e-07 - val_mae: 3.7954e-04
# Epoch 168/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.0056e-07 - mae: 4.8116e-04 - val_loss: 5.1421e-07 - val_mae: 3.9835e-04
# Epoch 169/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.9438e-07 - mae: 4.8425e-04 - val_loss: 5.3351e-07 - val_mae: 4.0207e-04
# Epoch 170/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.8248e-07 - mae: 4.7017e-04 - val_loss: 5.0416e-07 - val_mae: 3.8716e-04
# Epoch 171/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.7815e-07 - mae: 4.6510e-04 - val_loss: 4.6960e-07 - val_mae: 3.7584e-04
# Epoch 172/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.6286e-07 - mae: 4.6214e-04 - val_loss: 4.8011e-07 - val_mae: 3.8715e-04
# Epoch 173/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.5620e-07 - mae: 4.6567e-04 - val_loss: 4.7190e-07 - val_mae: 3.8715e-04
# Epoch 174/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.4754e-07 - mae: 4.6063e-04 - val_loss: 4.4780e-07 - val_mae: 3.6902e-04
# Epoch 175/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.4506e-07 - mae: 4.5140e-04 - val_loss: 4.4185e-07 - val_mae: 3.6979e-04
# Epoch 176/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.2580e-07 - mae: 4.4919e-04 - val_loss: 4.7169e-07 - val_mae: 3.7449e-04
# Epoch 177/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.2353e-07 - mae: 4.4653e-04 - val_loss: 4.8315e-07 - val_mae: 3.7933e-04
# Epoch 178/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.1608e-07 - mae: 4.4330e-04 - val_loss: 4.4311e-07 - val_mae: 3.6597e-04
# Epoch 179/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0517e-07 - mae: 4.3392e-04 - val_loss: 4.1622e-07 - val_mae: 3.5316e-04
# Epoch 180/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.0402e-07 - mae: 4.3459e-04 - val_loss: 4.0850e-07 - val_mae: 3.5041e-04
# Epoch 181/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.9567e-07 - mae: 4.3470e-04 - val_loss: 4.4354e-07 - val_mae: 3.6482e-04
# Epoch 182/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.8418e-07 - mae: 4.2845e-04 - val_loss: 4.2843e-07 - val_mae: 3.6078e-04
# Epoch 183/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.7733e-07 - mae: 4.2466e-04 - val_loss: 4.1686e-07 - val_mae: 3.5502e-04
# Epoch 184/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.7693e-07 - mae: 4.2336e-04 - val_loss: 3.7978e-07 - val_mae: 3.4150e-04
# Epoch 185/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.6333e-07 - mae: 4.2310e-04 - val_loss: 3.8362e-07 - val_mae: 3.4382e-04
# Epoch 186/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.5579e-07 - mae: 4.1875e-04 - val_loss: 3.8381e-07 - val_mae: 3.4057e-04
# Epoch 187/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.4708e-07 - mae: 4.0805e-04 - val_loss: 3.9909e-07 - val_mae: 3.4674e-04
# Epoch 188/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.4075e-07 - mae: 4.0498e-04 - val_loss: 3.7387e-07 - val_mae: 3.3494e-04
# Epoch 189/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.3530e-07 - mae: 4.0554e-04 - val_loss: 3.4660e-07 - val_mae: 3.2504e-04
# Epoch 190/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.2700e-07 - mae: 4.0318e-04 - val_loss: 3.4931e-07 - val_mae: 3.2854e-04
# Epoch 191/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.2657e-07 - mae: 4.0722e-04 - val_loss: 3.6291e-07 - val_mae: 3.3299e-04
# Epoch 192/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1394e-07 - mae: 3.9674e-04 - val_loss: 3.5023e-07 - val_mae: 3.2645e-04
# Epoch 193/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 4.0901e-07 - mae: 3.9261e-04 - val_loss: 3.3814e-07 - val_mae: 3.1777e-04
# Epoch 194/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0942e-07 - mae: 3.9527e-04 - val_loss: 3.3493e-07 - val_mae: 3.2195e-04
# Epoch 195/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9767e-07 - mae: 3.9027e-04 - val_loss: 3.1804e-07 - val_mae: 3.1211e-04
# Epoch 196/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0805e-07 - mae: 3.8894e-04 - val_loss: 3.1296e-07 - val_mae: 3.1594e-04
# Epoch 197/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.1253e-07 - mae: 4.0816e-04 - val_loss: 3.6176e-07 - val_mae: 3.3576e-04
# Epoch 198/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.8402e-07 - mae: 3.8886e-04 - val_loss: 3.3556e-07 - val_mae: 3.2873e-04
# Epoch 199/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.7882e-07 - mae: 3.8495e-04 - val_loss: 2.9308e-07 - val_mae: 3.1210e-04
# Epoch 200/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3.6916e-07 - mae: 3.9195e-04 - val_loss: 2.8352e-07 - val_mae: 3.1638e-04
# Epoch 201/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.6018e-07 - mae: 3.9151e-04 - val_loss: 2.9419e-07 - val_mae: 3.1741e-04
# Epoch 202/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.6366e-07 - mae: 3.9069e-04 - val_loss: 3.2338e-07 - val_mae: 3.3159e-04
# Epoch 203/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.5509e-07 - mae: 3.8291e-04 - val_loss: 2.7678e-07 - val_mae: 3.0046e-04
# Epoch 204/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.4019e-07 - mae: 3.7747e-04 - val_loss: 2.7563e-07 - val_mae: 3.1646e-04
# Epoch 205/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.3603e-07 - mae: 3.8327e-04 - val_loss: 2.7396e-07 - val_mae: 3.0172e-04
# Epoch 206/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.2730e-07 - mae: 3.7017e-04 - val_loss: 2.6325e-07 - val_mae: 2.9999e-04
# Epoch 207/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.4004e-07 - mae: 3.8083e-04 - val_loss: 2.4566e-07 - val_mae: 2.9738e-04
# Epoch 208/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.1701e-07 - mae: 3.7128e-04 - val_loss: 2.6652e-07 - val_mae: 3.0514e-04
# Epoch 209/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.1328e-07 - mae: 3.6719e-04 - val_loss: 2.9337e-07 - val_mae: 3.1527e-04
# Epoch 210/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.1563e-07 - mae: 3.6556e-04 - val_loss: 2.6739e-07 - val_mae: 2.9897e-04
# Epoch 211/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 3.0132e-07 - mae: 3.5620e-04 - val_loss: 2.5365e-07 - val_mae: 2.9454e-04
# Epoch 212/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.9411e-07 - mae: 3.5688e-04 - val_loss: 2.3590e-07 - val_mae: 2.8425e-04
# Epoch 213/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.9421e-07 - mae: 3.5643e-04 - val_loss: 2.4226e-07 - val_mae: 2.8458e-04
# Epoch 214/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.8574e-07 - mae: 3.4963e-04 - val_loss: 2.5238e-07 - val_mae: 2.9495e-04
# Epoch 215/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.7979e-07 - mae: 3.4581e-04 - val_loss: 2.4290e-07 - val_mae: 2.8775e-04
# Epoch 216/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.8140e-07 - mae: 3.5055e-04 - val_loss: 2.4174e-07 - val_mae: 2.8629e-04
# Epoch 217/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.6838e-07 - mae: 3.4215e-04 - val_loss: 2.1121e-07 - val_mae: 2.7481e-04
# Epoch 218/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.6700e-07 - mae: 3.4729e-04 - val_loss: 2.0589e-07 - val_mae: 2.7357e-04
# Epoch 219/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.6054e-07 - mae: 3.3988e-04 - val_loss: 2.1608e-07 - val_mae: 2.8626e-04
# Epoch 220/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.7817e-07 - mae: 3.5962e-04 - val_loss: 2.3436e-07 - val_mae: 2.8379e-04
# Epoch 221/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5473e-07 - mae: 3.3762e-04 - val_loss: 2.0553e-07 - val_mae: 2.7099e-04
# Epoch 222/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.5081e-07 - mae: 3.3343e-04 - val_loss: 1.8410e-07 - val_mae: 2.6142e-04
# Epoch 223/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.5127e-07 - mae: 3.3951e-04 - val_loss: 1.9041e-07 - val_mae: 2.6754e-04
# Epoch 224/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.4341e-07 - mae: 3.3625e-04 - val_loss: 2.1547e-07 - val_mae: 2.7818e-04
# Epoch 225/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.3838e-07 - mae: 3.2964e-04 - val_loss: 2.2241e-07 - val_mae: 2.8344e-04
# Epoch 226/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3486e-07 - mae: 3.2783e-04 - val_loss: 2.0160e-07 - val_mae: 2.7459e-04
# Epoch 227/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.3494e-07 - mae: 3.2639e-04 - val_loss: 1.7875e-07 - val_mae: 2.6132e-04
# Epoch 228/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.2582e-07 - mae: 3.2217e-04 - val_loss: 1.8538e-07 - val_mae: 2.6191e-04
# Epoch 229/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.2147e-07 - mae: 3.2143e-04 - val_loss: 1.9650e-07 - val_mae: 2.6994e-04
# Epoch 230/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1699e-07 - mae: 3.1455e-04 - val_loss: 2.0242e-07 - val_mae: 2.6923e-04
# Epoch 231/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1605e-07 - mae: 3.1229e-04 - val_loss: 1.8218e-07 - val_mae: 2.6003e-04
# Epoch 232/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3242e-07 - mae: 3.2526e-04 - val_loss: 1.6124e-07 - val_mae: 2.4906e-04
# Epoch 233/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1460e-07 - mae: 3.1411e-04 - val_loss: 1.8679e-07 - val_mae: 2.6504e-04
# Epoch 234/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.0909e-07 - mae: 3.0966e-04 - val_loss: 1.8424e-07 - val_mae: 2.5826e-04
# Epoch 235/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.0996e-07 - mae: 3.0788e-04 - val_loss: 1.8254e-07 - val_mae: 2.6201e-04
# Epoch 236/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.9957e-07 - mae: 3.0603e-04 - val_loss: 1.6859e-07 - val_mae: 2.5938e-04
# Epoch 237/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9881e-07 - mae: 3.0493e-04 - val_loss: 1.5513e-07 - val_mae: 2.3773e-04
# Epoch 238/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9947e-07 - mae: 3.0251e-04 - val_loss: 1.5831e-07 - val_mae: 2.4855e-04
# Epoch 239/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9300e-07 - mae: 3.0073e-04 - val_loss: 1.5664e-07 - val_mae: 2.4503e-04
# Epoch 240/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.8915e-07 - mae: 2.9847e-04 - val_loss: 1.6446e-07 - val_mae: 2.4981e-04
# Epoch 241/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9253e-07 - mae: 3.0206e-04 - val_loss: 1.6869e-07 - val_mae: 2.5124e-04
# Epoch 242/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.8551e-07 - mae: 2.9124e-04 - val_loss: 1.5091e-07 - val_mae: 2.4317e-04
# Epoch 243/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8036e-07 - mae: 2.8914e-04 - val_loss: 1.4845e-07 - val_mae: 2.4570e-04
# Epoch 244/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.8615e-07 - mae: 2.9877e-04 - val_loss: 1.4711e-07 - val_mae: 2.3358e-04
# Epoch 245/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.8079e-07 - mae: 2.9010e-04 - val_loss: 1.3839e-07 - val_mae: 2.2977e-04
# Epoch 246/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.7472e-07 - mae: 2.8371e-04 - val_loss: 1.5552e-07 - val_mae: 2.4908e-04
# Epoch 247/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.7357e-07 - mae: 2.8891e-04 - val_loss: 1.6211e-07 - val_mae: 2.5083e-04
# Epoch 248/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.7609e-07 - mae: 2.8536e-04 - val_loss: 1.5976e-07 - val_mae: 2.4798e-04
# Epoch 249/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.7208e-07 - mae: 2.8514e-04 - val_loss: 1.4350e-07 - val_mae: 2.3903e-04
# Epoch 250/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6707e-07 - mae: 2.8248e-04 - val_loss: 1.2966e-07 - val_mae: 2.3076e-04
# Epoch 251/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.7159e-07 - mae: 2.8796e-04 - val_loss: 1.3352e-07 - val_mae: 2.3337e-04
# Epoch 252/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.6553e-07 - mae: 2.8007e-04 - val_loss: 1.4698e-07 - val_mae: 2.4198e-04
# Epoch 253/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6373e-07 - mae: 2.8221e-04 - val_loss: 1.5328e-07 - val_mae: 2.3979e-04
# Epoch 254/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.6518e-07 - mae: 2.7799e-04 - val_loss: 1.3826e-07 - val_mae: 2.2300e-04
# Epoch 255/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6290e-07 - mae: 2.7676e-04 - val_loss: 1.2021e-07 - val_mae: 2.2181e-04
# Epoch 256/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6636e-07 - mae: 2.8026e-04 - val_loss: 1.2532e-07 - val_mae: 2.2632e-04
# Epoch 257/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5584e-07 - mae: 2.7067e-04 - val_loss: 1.2645e-07 - val_mae: 2.2168e-04
# Epoch 258/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.5395e-07 - mae: 2.6996e-04 - val_loss: 1.3385e-07 - val_mae: 2.3238e-04
# Epoch 259/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.4830e-07 - mae: 2.6527e-04 - val_loss: 1.2103e-07 - val_mae: 2.2088e-04
# Epoch 260/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.4825e-07 - mae: 2.6538e-04 - val_loss: 1.1916e-07 - val_mae: 2.2020e-04
# Epoch 261/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.4468e-07 - mae: 2.6601e-04 - val_loss: 1.2225e-07 - val_mae: 2.2335e-04
# Epoch 262/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.4285e-07 - mae: 2.6391e-04 - val_loss: 1.2227e-07 - val_mae: 2.1940e-04
# Epoch 263/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.4142e-07 - mae: 2.5753e-04 - val_loss: 1.2407e-07 - val_mae: 2.2042e-04
# Epoch 264/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.4052e-07 - mae: 2.5744e-04 - val_loss: 1.2667e-07 - val_mae: 2.2709e-04
# Epoch 265/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.3934e-07 - mae: 2.5628e-04 - val_loss: 1.2725e-07 - val_mae: 2.2018e-04
# Epoch 266/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.4449e-07 - mae: 2.5837e-04 - val_loss: 1.1473e-07 - val_mae: 2.0848e-04
# Epoch 267/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.4082e-07 - mae: 2.5276e-04 - val_loss: 1.2625e-07 - val_mae: 2.1827e-04
# Epoch 268/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3250e-07 - mae: 2.5022e-04 - val_loss: 1.1657e-07 - val_mae: 2.1064e-04
# Epoch 269/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.3724e-07 - mae: 2.5302e-04 - val_loss: 1.1599e-07 - val_mae: 2.1384e-04
# Epoch 270/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3314e-07 - mae: 2.4842e-04 - val_loss: 1.1126e-07 - val_mae: 2.1251e-04
# Epoch 271/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.2928e-07 - mae: 2.4770e-04 - val_loss: 1.1681e-07 - val_mae: 2.1512e-04
# Epoch 272/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3192e-07 - mae: 2.5034e-04 - val_loss: 1.1842e-07 - val_mae: 2.0707e-04
# Epoch 273/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3008e-07 - mae: 2.4558e-04 - val_loss: 1.0463e-07 - val_mae: 2.0500e-04
# Epoch 274/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2773e-07 - mae: 2.4512e-04 - val_loss: 1.0779e-07 - val_mae: 2.0916e-04
# Epoch 275/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.3161e-07 - mae: 2.4889e-04 - val_loss: 1.0497e-07 - val_mae: 2.0792e-04
# Epoch 276/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.2296e-07 - mae: 2.4205e-04 - val_loss: 1.0928e-07 - val_mae: 2.1282e-04
# Epoch 277/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.2138e-07 - mae: 2.3911e-04 - val_loss: 1.0742e-07 - val_mae: 2.0398e-04
# Epoch 278/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.2495e-07 - mae: 2.4065e-04 - val_loss: 1.0813e-07 - val_mae: 2.0630e-04
# Epoch 279/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.2045e-07 - mae: 2.3820e-04 - val_loss: 9.6578e-08 - val_mae: 2.0179e-04
# Epoch 280/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.1647e-07 - mae: 2.3680e-04 - val_loss: 9.6278e-08 - val_mae: 1.9721e-04
# Epoch 281/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.1867e-07 - mae: 2.3637e-04 - val_loss: 9.4731e-08 - val_mae: 1.9995e-04
# Epoch 282/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.2327e-07 - mae: 2.3961e-04 - val_loss: 1.0422e-07 - val_mae: 2.0449e-04
# Epoch 283/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.1737e-07 - mae: 2.3960e-04 - val_loss: 8.9178e-08 - val_mae: 1.8263e-04
# Epoch 284/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.1164e-07 - mae: 2.3255e-04 - val_loss: 9.9892e-08 - val_mae: 2.0166e-04
# Epoch 285/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1008e-07 - mae: 2.2717e-04 - val_loss: 1.0172e-07 - val_mae: 2.0909e-04
# Epoch 286/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1879e-07 - mae: 2.3597e-04 - val_loss: 1.0493e-07 - val_mae: 2.0476e-04
# Epoch 287/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.1078e-07 - mae: 2.3155e-04 - val_loss: 8.9628e-08 - val_mae: 1.9466e-04
# Epoch 288/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.2036e-07 - mae: 2.3844e-04 - val_loss: 8.4100e-08 - val_mae: 1.8810e-04
# Epoch 289/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1688e-07 - mae: 2.3475e-04 - val_loss: 9.4542e-08 - val_mae: 2.0581e-04
# Epoch 290/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1615e-07 - mae: 2.4503e-04 - val_loss: 9.5285e-08 - val_mae: 1.9984e-04
# Epoch 291/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0762e-07 - mae: 2.3222e-04 - val_loss: 9.3689e-08 - val_mae: 2.0200e-04
# Epoch 292/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0323e-07 - mae: 2.2429e-04 - val_loss: 9.0684e-08 - val_mae: 1.9331e-04
# Epoch 293/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0724e-07 - mae: 2.2552e-04 - val_loss: 9.1504e-08 - val_mae: 1.9738e-04
# Epoch 294/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.0854e-07 - mae: 2.3049e-04 - val_loss: 8.7693e-08 - val_mae: 1.9889e-04
# Epoch 295/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.2695e-07 - mae: 2.4667e-04 - val_loss: 8.4499e-08 - val_mae: 1.9400e-04
# Epoch 296/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1597e-07 - mae: 2.4183e-04 - val_loss: 8.9174e-08 - val_mae: 1.9893e-04
# Epoch 297/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.0677e-07 - mae: 2.3559e-04 - val_loss: 8.7726e-08 - val_mae: 1.8796e-04
# Epoch 298/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0287e-07 - mae: 2.2711e-04 - val_loss: 8.9212e-08 - val_mae: 1.9358e-04
# Epoch 299/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.8324e-08 - mae: 2.2256e-04 - val_loss: 8.4464e-08 - val_mae: 1.9908e-04
# Epoch 300/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0530e-07 - mae: 2.2403e-04 - val_loss: 9.4846e-08 - val_mae: 1.9745e-04
# Epoch 301/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0085e-07 - mae: 2.2341e-04 - val_loss: 9.4090e-08 - val_mae: 2.1056e-04
# Epoch 302/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0596e-07 - mae: 2.3152e-04 - val_loss: 9.4370e-08 - val_mae: 1.9464e-04
# Epoch 303/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.9046e-08 - mae: 2.1795e-04 - val_loss: 7.7558e-08 - val_mae: 1.8251e-04
# Epoch 304/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 9.4161e-08 - mae: 2.1188e-04 - val_loss: 7.2184e-08 - val_mae: 1.7278e-04
# Epoch 305/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.4968e-08 - mae: 2.1370e-04 - val_loss: 7.7113e-08 - val_mae: 1.7302e-04
# Epoch 306/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 8.8160e-08 - mae: 2.0593e-04 - val_loss: 7.7772e-08 - val_mae: 1.8184e-04
# Epoch 307/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.2893e-08 - mae: 2.1252e-04 - val_loss: 8.4427e-08 - val_mae: 1.8361e-04
# Epoch 308/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.5177e-08 - mae: 2.1225e-04 - val_loss: 7.4633e-08 - val_mae: 1.8209e-04
# Epoch 309/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.8560e-08 - mae: 2.1053e-04 - val_loss: 8.8203e-08 - val_mae: 1.8738e-04
# Epoch 310/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 9.0444e-08 - mae: 2.0956e-04 - val_loss: 7.9574e-08 - val_mae: 1.8616e-04
# Epoch 311/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 8.7302e-08 - mae: 2.0540e-04 - val_loss: 7.1125e-08 - val_mae: 1.6656e-04
# Epoch 312/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 8.5173e-08 - mae: 1.9873e-04 - val_loss: 6.5698e-08 - val_mae: 1.6253e-04
# Epoch 313/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.4901e-08 - mae: 2.0119e-04 - val_loss: 6.5226e-08 - val_mae: 1.5982e-04
# Epoch 314/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.1564e-08 - mae: 1.9625e-04 - val_loss: 6.8809e-08 - val_mae: 1.6576e-04
# Epoch 315/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 7.8848e-08 - mae: 1.9281e-04 - val_loss: 7.0715e-08 - val_mae: 1.6957e-04
# Epoch 316/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.2799e-08 - mae: 2.0235e-04 - val_loss: 6.7591e-08 - val_mae: 1.6780e-04
# Epoch 317/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 8.2466e-08 - mae: 2.0233e-04 - val_loss: 5.9326e-08 - val_mae: 1.5944e-04
# Epoch 318/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.4353e-08 - mae: 2.0121e-04 - val_loss: 7.0386e-08 - val_mae: 1.7236e-04
# Epoch 319/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.1321e-08 - mae: 1.9858e-04 - val_loss: 8.0137e-08 - val_mae: 1.8684e-04
# Epoch 320/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 7.8937e-08 - mae: 1.9684e-04 - val_loss: 8.3329e-08 - val_mae: 1.7696e-04
# Epoch 321/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.0485e-08 - mae: 1.9298e-04 - val_loss: 6.0737e-08 - val_mae: 1.6030e-04
# Epoch 322/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.5008e-08 - mae: 1.8979e-04 - val_loss: 5.9762e-08 - val_mae: 1.6243e-04
# Epoch 323/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.4902e-08 - mae: 1.9398e-04 - val_loss: 6.1306e-08 - val_mae: 1.5699e-04
# Epoch 324/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.3086e-08 - mae: 1.8574e-04 - val_loss: 6.6095e-08 - val_mae: 1.6150e-04
# Epoch 325/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 7.0554e-08 - mae: 1.7911e-04 - val_loss: 6.1606e-08 - val_mae: 1.5636e-04
# Epoch 326/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 7.0234e-08 - mae: 1.8089e-04 - val_loss: 5.9146e-08 - val_mae: 1.5331e-04
# Epoch 327/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 7.2535e-08 - mae: 1.8649e-04 - val_loss: 6.0773e-08 - val_mae: 1.4913e-04
# Epoch 328/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.9180e-08 - mae: 1.7675e-04 - val_loss: 5.8179e-08 - val_mae: 1.4707e-04
# Epoch 329/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.8404e-08 - mae: 1.7492e-04 - val_loss: 6.3533e-08 - val_mae: 1.6084e-04
# Epoch 330/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.7946e-08 - mae: 1.7563e-04 - val_loss: 6.2089e-08 - val_mae: 1.5761e-04
# Epoch 331/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.0920e-08 - mae: 1.8099e-04 - val_loss: 6.3046e-08 - val_mae: 1.5475e-04
# Epoch 332/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.9146e-08 - mae: 1.7804e-04 - val_loss: 5.0978e-08 - val_mae: 1.4607e-04
# Epoch 333/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.4292e-08 - mae: 1.7331e-04 - val_loss: 5.4486e-08 - val_mae: 1.4847e-04
# Epoch 334/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.3647e-08 - mae: 1.7098e-04 - val_loss: 6.1003e-08 - val_mae: 1.5264e-04
# Epoch 335/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.7019e-08 - mae: 1.7297e-04 - val_loss: 6.0100e-08 - val_mae: 1.6147e-04
# Epoch 336/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.7705e-08 - mae: 1.7942e-04 - val_loss: 5.2954e-08 - val_mae: 1.4530e-04
# Epoch 337/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.5917e-08 - mae: 1.7725e-04 - val_loss: 4.9457e-08 - val_mae: 1.4449e-04
# Epoch 338/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.6323e-08 - mae: 1.7617e-04 - val_loss: 5.1728e-08 - val_mae: 1.4406e-04
# Epoch 339/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.6095e-08 - mae: 1.7564e-04 - val_loss: 5.7026e-08 - val_mae: 1.6025e-04
# Epoch 340/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.4738e-08 - mae: 1.7605e-04 - val_loss: 5.6259e-08 - val_mae: 1.4551e-04
# Epoch 341/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.3737e-08 - mae: 1.7315e-04 - val_loss: 5.3805e-08 - val_mae: 1.5948e-04
# Epoch 342/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 6.3246e-08 - mae: 1.7802e-04 - val_loss: 4.8840e-08 - val_mae: 1.5151e-04
# Epoch 343/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.1826e-08 - mae: 1.7523e-04 - val_loss: 5.4595e-08 - val_mae: 1.5358e-04
# Epoch 344/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.2429e-08 - mae: 1.7687e-04 - val_loss: 5.3893e-08 - val_mae: 1.5109e-04
# Epoch 345/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.9144e-08 - mae: 1.6709e-04 - val_loss: 5.9348e-08 - val_mae: 1.6759e-04
# Epoch 346/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.1761e-08 - mae: 1.7362e-04 - val_loss: 5.3414e-08 - val_mae: 1.5288e-04
# Epoch 347/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.8314e-08 - mae: 1.8617e-04 - val_loss: 5.8460e-08 - val_mae: 1.5749e-04
# Epoch 348/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.0303e-08 - mae: 1.7163e-04 - val_loss: 5.0259e-08 - val_mae: 1.5183e-04
# Epoch 349/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.8746e-08 - mae: 1.6854e-04 - val_loss: 5.7048e-08 - val_mae: 1.5963e-04
# Epoch 350/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.7977e-08 - mae: 1.6894e-04 - val_loss: 5.2656e-08 - val_mae: 1.5156e-04
# Epoch 351/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.8498e-08 - mae: 1.6417e-04 - val_loss: 5.3281e-08 - val_mae: 1.4300e-04
# Epoch 352/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 5.9439e-08 - mae: 1.6391e-04 - val_loss: 4.7221e-08 - val_mae: 1.4193e-04
# Epoch 353/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.6171e-08 - mae: 1.6285e-04 - val_loss: 5.2425e-08 - val_mae: 1.5169e-04
# Epoch 354/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.5014e-08 - mae: 1.6007e-04 - val_loss: 5.6419e-08 - val_mae: 1.4878e-04
# Epoch 355/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6214e-08 - mae: 1.6017e-04 - val_loss: 5.0595e-08 - val_mae: 1.4664e-04
# Epoch 356/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.5786e-08 - mae: 1.6265e-04 - val_loss: 4.5288e-08 - val_mae: 1.3657e-04
# Epoch 357/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.5879e-08 - mae: 1.6354e-04 - val_loss: 4.7376e-08 - val_mae: 1.3859e-04
# Epoch 358/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 5.6889e-08 - mae: 1.6059e-04 - val_loss: 5.0206e-08 - val_mae: 1.4067e-04
# Epoch 359/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.7185e-08 - mae: 1.6377e-04 - val_loss: 4.9084e-08 - val_mae: 1.4866e-04
# Epoch 360/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.7733e-08 - mae: 1.6850e-04 - val_loss: 4.6008e-08 - val_mae: 1.4314e-04
# Epoch 361/1000
# ...
# Epoch 436/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.7423e-08 - mae: 1.5087e-04 - val_loss: 4.8331e-08 - val_mae: 1.6650e-04
# Epoch 437/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.3853e-08 - mae: 1.6628e-04 - val_loss: 5.0551e-08 - val_mae: 1.5685e-04
# Epoch 438/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4.8099e-08 - mae: 1.5752e-04 - val_loss: 3.9734e-08 - val_mae: 1.4595e-04
# Epoch 439/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6122e-08 - mae: 1.5464e-04 - val_loss: 4.0078e-08 - val_mae: 1.3842e-04
# Epoch 440/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.0947e-08 - mae: 1.4368e-04 - val_loss: 2.9453e-08 - val_mae: 1.1899e-04
# Epoch 441/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.8693e-08 - mae: 1.3969e-04 - val_loss: 3.3103e-08 - val_mae: 1.2354e-04
# Epoch 442/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.6015e-08 - mae: 1.3804e-04 - val_loss: 3.3582e-08 - val_mae: 1.2872e-04
# Epoch 443/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.3507e-08 - mae: 1.4769e-04 - val_loss: 3.7897e-08 - val_mae: 1.3739e-04
# Epoch 444/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.1602e-08 - mae: 1.4183e-04 - val_loss: 2.5033e-08 - val_mae: 1.1433e-04
# Epoch 445/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.1244e-08 - mae: 1.2556e-04 - val_loss: 2.7724e-08 - val_mae: 1.0384e-04
# Epoch 446/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.2598e-08 - mae: 1.2760e-04 - val_loss: 2.6844e-08 - val_mae: 1.1047e-04
# Epoch 447/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1315e-07 - mae: 1.9977e-04 - val_loss: 3.9256e-08 - val_mae: 1.5665e-04
# Epoch 448/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.2414e-08 - mae: 1.7010e-04 - val_loss: 4.1239e-08 - val_mae: 1.5696e-04
# Epoch 449/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 4.0254e-08 - mae: 1.5172e-04 - val_loss: 4.9007e-08 - val_mae: 1.6740e-04
# Epoch 450/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0545e-08 - mae: 1.4717e-04 - val_loss: 3.9602e-08 - val_mae: 1.5315e-04
# Epoch 451/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.7699e-08 - mae: 1.4379e-04 - val_loss: 3.0494e-08 - val_mae: 1.3197e-04
# Epoch 452/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.5182e-08 - mae: 1.3483e-04 - val_loss: 2.7724e-08 - val_mae: 1.2219e-04
# Epoch 453/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.6060e-08 - mae: 1.3797e-04 - val_loss: 3.2454e-08 - val_mae: 1.3444e-04
# Epoch 454/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.5988e-08 - mae: 1.3740e-04 - val_loss: 2.8621e-08 - val_mae: 1.1898e-04
# Epoch 455/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.3550e-08 - mae: 1.3199e-04 - val_loss: 3.3801e-08 - val_mae: 1.3139e-04
# Epoch 456/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.5826e-08 - mae: 1.3490e-04 - val_loss: 3.4944e-08 - val_mae: 1.3408e-04
# Epoch 457/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.9529e-08 - mae: 1.4240e-04 - val_loss: 2.4814e-08 - val_mae: 1.0756e-04
# Epoch 458/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.5255e-08 - mae: 1.3486e-04 - val_loss: 2.4685e-08 - val_mae: 1.0338e-04
# Epoch 459/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.0868e-08 - mae: 1.2142e-04 - val_loss: 2.8770e-08 - val_mae: 1.1881e-04
# Epoch 460/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.1603e-08 - mae: 1.2951e-04 - val_loss: 3.5250e-08 - val_mae: 1.3240e-04
# Epoch 461/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.4776e-08 - mae: 1.3173e-04 - val_loss: 4.1360e-08 - val_mae: 1.6149e-04
# Epoch 462/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.3653e-08 - mae: 1.5340e-04 - val_loss: 3.1505e-08 - val_mae: 1.2068e-04
# Epoch 463/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.3213e-08 - mae: 1.5003e-04 - val_loss: 2.6325e-08 - val_mae: 1.1630e-04
# Epoch 464/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.3247e-08 - mae: 1.2737e-04 - val_loss: 2.9116e-08 - val_mae: 1.1336e-04
# Epoch 465/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.6366e-08 - mae: 1.3495e-04 - val_loss: 4.5061e-08 - val_mae: 1.3928e-04
# Epoch 466/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.2857e-08 - mae: 1.3964e-04 - val_loss: 6.7527e-08 - val_mae: 1.6745e-04
# Epoch 467/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.5184e-08 - mae: 1.5370e-04 - val_loss: 4.6774e-08 - val_mae: 1.4088e-04
# Epoch 468/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.0889e-08 - mae: 1.5939e-04 - val_loss: 3.3344e-08 - val_mae: 1.3385e-04
# Epoch 469/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.6095e-08 - mae: 1.6019e-04 - val_loss: 2.8088e-08 - val_mae: 1.1201e-04
# Epoch 470/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.9453e-08 - mae: 1.4981e-04 - val_loss: 6.2512e-08 - val_mae: 1.7981e-04
# Epoch 471/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.8606e-08 - mae: 1.6829e-04 - val_loss: 7.3010e-08 - val_mae: 1.9002e-04
# Epoch 472/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.9187e-08 - mae: 1.9457e-04 - val_loss: 5.7751e-08 - val_mae: 1.5195e-04
# Epoch 473/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.6742e-08 - mae: 2.0733e-04 - val_loss: 3.3518e-08 - val_mae: 1.4076e-04
# Epoch 474/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.8920e-08 - mae: 1.7868e-04 - val_loss: 3.8351e-08 - val_mae: 1.3512e-04
# Epoch 475/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.8451e-08 - mae: 1.8244e-04 - val_loss: 5.0218e-08 - val_mae: 1.4157e-04
# Epoch 476/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.5600e-08 - mae: 1.6615e-04 - val_loss: 5.7746e-08 - val_mae: 1.4614e-04
# Epoch 477/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 6.9656e-08 - mae: 1.6679e-04 - val_loss: 4.7181e-08 - val_mae: 1.3742e-04
# Epoch 478/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.1837e-08 - mae: 1.8817e-04 - val_loss: 2.8993e-08 - val_mae: 1.2656e-04
# Epoch 479/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.8536e-08 - mae: 1.5038e-04 - val_loss: 3.7148e-08 - val_mae: 1.2939e-04
# Epoch 480/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.2339e-08 - mae: 1.3869e-04 - val_loss: 3.0505e-08 - val_mae: 1.2088e-04
# Epoch 481/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.1538e-08 - mae: 1.4725e-04 - val_loss: 5.8201e-08 - val_mae: 1.6927e-04
# Epoch 482/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.3973e-08 - mae: 1.6606e-04 - val_loss: 5.3854e-08 - val_mae: 1.7466e-04
# Epoch 483/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.3278e-08 - mae: 1.8334e-04 - val_loss: 5.1703e-08 - val_mae: 1.4330e-04
# Epoch 484/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.6752e-08 - mae: 1.7275e-04 - val_loss: 3.1595e-08 - val_mae: 1.3047e-04
# Epoch 485/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.8891e-08 - mae: 1.4686e-04 - val_loss: 3.8959e-08 - val_mae: 1.5054e-04
# Epoch 486/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.4123e-08 - mae: 1.5791e-04 - val_loss: 3.6498e-08 - val_mae: 1.3077e-04
# Epoch 487/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.0086e-08 - mae: 1.4085e-04 - val_loss: 2.9552e-08 - val_mae: 1.3110e-04
# Epoch 488/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.7811e-08 - mae: 1.4221e-04 - val_loss: 3.0347e-08 - val_mae: 1.1992e-04
# Epoch 489/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.8236e-08 - mae: 1.4198e-04 - val_loss: 2.6956e-08 - val_mae: 1.2036e-04
# Epoch 490/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2.9845e-08 - mae: 1.2141e-04 - val_loss: 2.5088e-08 - val_mae: 1.1069e-04
# Epoch 491/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.3157e-08 - mae: 1.3294e-04 - val_loss: 2.1364e-08 - val_mae: 1.0297e-04
# Epoch 492/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.7581e-08 - mae: 1.1830e-04 - val_loss: 2.3510e-08 - val_mae: 1.1179e-04
# Epoch 493/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.8517e-08 - mae: 1.2118e-04 - val_loss: 2.6161e-08 - val_mae: 1.0849e-04
# Epoch 494/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.7648e-08 - mae: 1.1571e-04 - val_loss: 1.9653e-08 - val_mae: 9.4289e-05
# Epoch 495/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.3601e-08 - mae: 1.0661e-04 - val_loss: 2.0379e-08 - val_mae: 9.8115e-05
# Epoch 496/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.5518e-08 - mae: 1.1378e-04 - val_loss: 2.7423e-08 - val_mae: 1.0721e-04
# Epoch 497/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.8045e-08 - mae: 1.1132e-04 - val_loss: 2.4203e-08 - val_mae: 1.1421e-04
# Epoch 498/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.4427e-08 - mae: 1.1048e-04 - val_loss: 2.7266e-08 - val_mae: 1.0930e-04
# Epoch 499/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.6632e-08 - mae: 1.3678e-04 - val_loss: 2.2310e-08 - val_mae: 1.0178e-04
# Epoch 500/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.6737e-08 - mae: 1.0964e-04 - val_loss: 2.7107e-08 - val_mae: 1.1559e-04
# Epoch 501/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.8550e-08 - mae: 1.1788e-04 - val_loss: 2.0943e-08 - val_mae: 9.8085e-05
# Epoch 502/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.5912e-08 - mae: 1.1442e-04 - val_loss: 1.8451e-08 - val_mae: 8.8157e-05
# Epoch 503/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.4202e-08 - mae: 1.0663e-04 - val_loss: 1.9405e-08 - val_mae: 9.3044e-05
# Epoch 504/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5543e-08 - mae: 1.1194e-04 - val_loss: 3.7227e-08 - val_mae: 1.3548e-04
# Epoch 505/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.5747e-08 - mae: 1.3465e-04 - val_loss: 4.5243e-08 - val_mae: 1.6439e-04
# Epoch 506/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.4856e-08 - mae: 1.5385e-04 - val_loss: 3.3799e-08 - val_mae: 1.2543e-04
# Epoch 507/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.4400e-08 - mae: 1.3263e-04 - val_loss: 2.4617e-08 - val_mae: 1.1297e-04
# Epoch 508/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.9166e-08 - mae: 1.2369e-04 - val_loss: 3.1440e-08 - val_mae: 1.1832e-04
# Epoch 509/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.0007e-08 - mae: 1.5888e-04 - val_loss: 4.3080e-08 - val_mae: 1.3286e-04
# Epoch 510/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.0120e-08 - mae: 1.6578e-04 - val_loss: 9.9647e-08 - val_mae: 2.3003e-04
# Epoch 511/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.9711e-08 - mae: 2.2306e-04 - val_loss: 9.9640e-08 - val_mae: 2.4028e-04
# Epoch 512/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.1074e-08 - mae: 2.2074e-04 - val_loss: 9.7155e-08 - val_mae: 2.4402e-04
# Epoch 513/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.5682e-08 - mae: 2.3484e-04 - val_loss: 1.1244e-07 - val_mae: 2.5565e-04
# Epoch 514/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.1487e-07 - mae: 2.3923e-04 - val_loss: 1.0129e-07 - val_mae: 2.2147e-04
# Epoch 515/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8849e-07 - mae: 3.2286e-04 - val_loss: 1.3723e-07 - val_mae: 2.5273e-04
# Epoch 516/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2421e-07 - mae: 3.4411e-04 - val_loss: 6.7601e-08 - val_mae: 1.7736e-04
# Epoch 517/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.9659e-07 - mae: 3.1842e-04 - val_loss: 1.5584e-07 - val_mae: 2.7066e-04
# Epoch 518/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.7457e-07 - mae: 3.7705e-04 - val_loss: 1.8068e-07 - val_mae: 2.8490e-04
# Epoch 519/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.6076e-07 - mae: 3.4846e-04 - val_loss: 1.8300e-07 - val_mae: 2.8101e-04
# Epoch 520/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.3207e-07 - mae: 3.3262e-04 - val_loss: 2.2129e-07 - val_mae: 3.5464e-04
# Epoch 521/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9771e-07 - mae: 3.2985e-04 - val_loss: 2.4027e-07 - val_mae: 3.6456e-04
# Epoch 522/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.6694e-07 - mae: 2.9010e-04 - val_loss: 1.5081e-07 - val_mae: 2.9616e-04
# Epoch 523/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0394e-07 - mae: 2.4357e-04 - val_loss: 1.1945e-07 - val_mae: 2.5210e-04
# Epoch 524/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1603e-07 - mae: 2.6293e-04 - val_loss: 1.2549e-07 - val_mae: 2.6163e-04
# Epoch 525/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0877e-07 - mae: 2.5037e-04 - val_loss: 3.4612e-08 - val_mae: 1.4511e-04
# Epoch 526/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 6.0836e-08 - mae: 1.9400e-04 - val_loss: 5.3216e-08 - val_mae: 1.6387e-04
# Epoch 527/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.1380e-08 - mae: 1.8469e-04 - val_loss: 5.2364e-08 - val_mae: 1.7896e-04
# Epoch 528/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.8684e-08 - mae: 1.7140e-04 - val_loss: 3.6508e-08 - val_mae: 1.3580e-04
# Epoch 529/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.5181e-08 - mae: 1.5520e-04 - val_loss: 3.2107e-08 - val_mae: 1.3368e-04
# Epoch 530/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.6789e-08 - mae: 1.3983e-04 - val_loss: 2.9123e-08 - val_mae: 1.2869e-04
# Epoch 531/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.8295e-08 - mae: 1.4359e-04 - val_loss: 2.7467e-08 - val_mae: 1.1754e-04
# Epoch 532/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.3731e-08 - mae: 1.3359e-04 - val_loss: 2.5837e-08 - val_mae: 1.1400e-04
# Epoch 533/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.3405e-08 - mae: 1.3429e-04 - val_loss: 4.0205e-08 - val_mae: 1.4778e-04
# Epoch 534/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.5507e-08 - mae: 1.4055e-04 - val_loss: 5.8513e-08 - val_mae: 1.7074e-04
# Epoch 535/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6.0060e-08 - mae: 1.7151e-04 - val_loss: 5.9230e-08 - val_mae: 1.7263e-04
# Epoch 536/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.0676e-08 - mae: 2.0473e-04 - val_loss: 3.7663e-08 - val_mae: 1.3688e-04
# Epoch 537/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.5248e-08 - mae: 1.6930e-04 - val_loss: 4.3838e-08 - val_mae: 1.4295e-04
# Epoch 538/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.2145e-08 - mae: 1.8626e-04 - val_loss: 6.9605e-08 - val_mae: 1.7445e-04
# Epoch 539/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.9957e-08 - mae: 1.6891e-04 - val_loss: 6.0890e-08 - val_mae: 1.7204e-04
# Epoch 540/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.3042e-08 - mae: 1.7915e-04 - val_loss: 7.9506e-08 - val_mae: 1.9841e-04
# Epoch 541/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.9237e-08 - mae: 2.0496e-04 - val_loss: 5.9734e-08 - val_mae: 1.5962e-04
# Epoch 542/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.7158e-08 - mae: 1.7256e-04 - val_loss: 9.6193e-08 - val_mae: 2.2369e-04
# Epoch 543/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.0059e-08 - mae: 2.1072e-04 - val_loss: 7.1505e-08 - val_mae: 2.0097e-04
# Epoch 544/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2542e-07 - mae: 2.4799e-04 - val_loss: 9.1466e-08 - val_mae: 2.0853e-04
# Epoch 545/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 8.6189e-08 - mae: 1.9775e-04 - val_loss: 6.1354e-08 - val_mae: 1.5860e-04
# Epoch 546/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0051e-07 - mae: 2.0596e-04 - val_loss: 3.9894e-08 - val_mae: 1.3839e-04
# Epoch 547/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.3451e-08 - mae: 1.6909e-04 - val_loss: 8.5758e-08 - val_mae: 1.8610e-04
# Epoch 548/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 9.6694e-08 - mae: 2.0822e-04 - val_loss: 6.5906e-08 - val_mae: 1.8903e-04
# Epoch 549/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.4130e-08 - mae: 1.9556e-04 - val_loss: 7.7216e-08 - val_mae: 1.9755e-04
# Epoch 550/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.5901e-08 - mae: 2.0383e-04 - val_loss: 5.1983e-08 - val_mae: 1.6252e-04
# Epoch 551/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.3321e-08 - mae: 1.8590e-04 - val_loss: 3.7558e-08 - val_mae: 1.4183e-04
# Epoch 552/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.4636e-08 - mae: 1.7294e-04 - val_loss: 4.1500e-08 - val_mae: 1.4048e-04
# Epoch 552: early stopping
# Restoring model weights from the end of the best epoch: 502.

# %%
model = tf.keras.models.load_model(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') if os.path.exists(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') else model

# %%
# Estrai losses da tutti i folds
train_losses = history.history['loss']
val_losses   = history.history['val_loss']

train_losses = train_losses
val_losses = val_losses

# Plot
plt.figure(figsize=(8,5))


# Training loss
plt.plot(train_losses, color='blue', label='Train Loss')
# Validation loss
plt.plot(val_losses, color='red', label='Validation Loss')


# Dettagli grafico
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.savefig(f'{exp_dir}/loss_plot.png')

# %%
def plot_first_n_series(y_pred, y_test, n_series=10, title="Confronto Serie Predette vs Reali"):
    """
    Plotta le prime n_series serie reali e predette per un confronto diretto.

    Args:
        y_pred (np.ndarray): Predizioni del modello (shape: num_samples x seq_len).
        y_test (np.ndarray): Serie reali (shape: num_samples x seq_len).
        n_series (int): Numero di serie da plottare.
        title (str): Titolo del grafico.
    """

    # Limitiamo a n_series per evitare problemi
    n = min(n_series, y_pred.shape[0], y_test.shape[0])

    plt.figure(figsize=(14, 8))

    for i in range(n):
        plt.plot(
            y_test[i], 
            linewidth=1.8, 
            alpha=0.5, 
            label=f"Reale {i+1}" if i == 0 else "",
            color = 'blue'
        )
        plt.plot(
            y_pred[i], 
            linewidth=1.2, 
            linestyle="--", 
            alpha=0.9, 
            label=f"Predetto {i+1}" if i == 0 else "",
            color = 'orange'
        )

    plt.title(title, fontsize=16)
    plt.xlabel("Time Step", fontsize=12)
    plt.ylabel("Valore", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

def plot_diagnosis_gradient(y_pred, y_test, save_path: str,  tolerance:float =0.05, max_samples_heatmap=50, scatter_sample_ratio=0.5, tol_auto = True):
    """
    Dashboard diagnostica con tolleranza AUTO-ADATTIVA alla scala dei dati.
    
    Args:
        tolerance (float): 
            - Se None: La tolleranza viene calcolata automaticamente come il 5% del range dei dati (Max-Min).
            - Se float: Valore assoluto (es. 0.5).
        tol_auto (bool): Se True, usa la tolleranza automatica basata sul range dei dati, altrimenti usa il valore manuale fornito 
        col parametro tolerance.
    """
    
    y_test_flat = y_test.flatten()
    y_pred_flat = y_pred.flatten()

    # ---------------------------------------------------------
    # AUTOMAZIONE TOLLERANZA
    # ---------------------------------------------------------
    if tol_auto:
        data_range = y_test_flat.max() - y_test_flat.min()
        # Impostiamo la tolleranza al 5% del range totale (regolabile)
        tolerance = data_range * tolerance 
        tol_label = f"Auto (5% Range: ±{tolerance:.2f})"
    else:
        tol_label = f"Manuale (±{tolerance})"

    fig, axes = plt.subplots(1, 2, figsize=(22, 8))

    # -----------------------------
    # 1. HEATMAP (SX)
    # -----------------------------
    errors = np.abs(y_test - y_pred)
    errors_subset = errors[:max_samples_heatmap]
    
    # Adattiamo anche la scala colori della heatmap alla tolleranza
    # Tutto ciò che è oltre 3 volte la tolleranza è "errore massimo" visivo
    sns.heatmap(errors_subset, cmap="plasma", ax=axes[0], 
                vmax=tolerance * 3,
                cbar_kws={'label': 'Errore Assoluto'})
    
    axes[0].set_title(f"Heatmap Errori (Primi {max_samples_heatmap} campioni)", fontsize=16)
    axes[0].set_xlabel("Time Step", fontsize=12)
    axes[0].set_ylabel("Indice Campione", fontsize=12)

    # -----------------------------
    # 2. SCATTER CON SFONDO GRADIENTE (DX)
    # -----------------------------
    
    # Campionamento dati
    if scatter_sample_ratio < 1.0:
        mask = np.random.rand(len(y_test_flat)) < scatter_sample_ratio
        sample_test = y_test_flat[mask]
        sample_pred = y_pred_flat[mask]
    else:
        sample_test = y_test_flat
        sample_pred = y_pred_flat

    # Calcolo limiti grafico
    min_val = min(y_test_flat.min(), y_pred_flat.min())
    max_val = max(y_test_flat.max(), y_pred_flat.max())
    padding = (max_val - min_val) * 0.05
    plot_min = min_val - padding
    plot_max = max_val + padding

    # --- SFONDO GRADIENTE ---
    grid_x, grid_y = np.meshgrid(
        np.linspace(plot_min, plot_max, 200),
        np.linspace(plot_min, plot_max, 200)
    )
    grid_z = np.abs(grid_y - grid_x)

    im = axes[1].imshow(
        grid_z, 
        extent=(plot_min, plot_max, plot_min, plot_max), 
        origin='lower', 
        cmap='RdYlGn_r', 
        alpha=0.4, 
        vmax=tolerance * 4, # Il rosso satura a 4x della tolleranza
        aspect='auto'
    )

    # --- PUNTI BLU ---
    axes[1].scatter(
        sample_test, 
        sample_pred, 
        alpha=0.6, 
        s=15, 
        color='royalblue', 
        edgecolors='white', 
        linewidth=0.3,
        label='Campioni'
    )

    axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

    # Metriche
    within_tol = np.mean(np.abs(y_test_flat - y_pred_flat) <= tolerance) * 100

    axes[1].set_title(
        f"Bontà delle previsioni con {tol_label}\nValori nel range di Tolleranza: {within_tol:.1f}%", 
        fontsize=16
    )
    axes[1].set_xlabel("Valore Reale", fontsize=12)
    axes[1].set_ylabel("Valore Predetto", fontsize=12)
    axes[1].set_xlim(plot_min, plot_max)
    axes[1].set_ylim(plot_min, plot_max)
    
    cbar = plt.colorbar(im, ax=axes[1], pad=0.02)
    cbar.set_label('Gravità Errore (Distanza da diagonale)')

    plt.tight_layout()
    plt.savefig(f'{exp_dir}/{save_path}.png')

# %%
y_pred = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred)
y_test_np = scaler_y.inverse_transform(y_test)

plot_diagnosis_gradient(y_pred, y_test_np, save_path='pred_quality', max_samples_heatmap=10, scatter_sample_ratio=0.7)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_3360/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

# %%
save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/TEST', prefix="pred_plot")
# Out:
# Salvo 18 plot in: ../RISULTATI/2025-11-30/esperimento_METRO814_14-43-32/TEST
# Plot salvati correttamente.

# %%
import json
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_and_log(y_true, y_pred, log_path="log.json"):
    # --- Metriche ---
    mae = mean_absolute_error(y_true, y_pred, multioutput="uniform_average")
    rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput="uniform_average"))

    mask = y_true != 0
    mape = float(np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100.0)

    r2 = r2_score(y_true, y_pred, multioutput="uniform_average")

    # Valore medio del test set
    v_mean = float(np.mean(y_true))

    # --- Stampa ---
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    print(f"Test MAPE: {mape:.2f}%")
    print(f"Test R2: {r2:.4f}")
    print(f"Valore medio del test set: {v_mean:.4f}")

    # --- Salvataggio log ---
    log_data = {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2,
        "test_mean_value": v_mean
    }

    with open(log_path, "w") as f:
        json.dump(log_data, f, indent=4)

    print(f"\nLog salvato in: {log_path}")
evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/evaluation_log.json")
# Impostazioni pandas per visualizzare tutti i dati
# Out:
# Test MAE: 0.0533
# Test RMSE: 0.0816
# Test MAPE: 0.00%
# Test R2: 1.0000
# Valore medio del test set: 1565.5548
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_METRO814_14-43-32/evaluation_log.json

# %% [markdown]
# # globale e federato

# %%
fed = tf.keras.models.load_model('/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Metro.keras')

model  = [fed]
model_name = ["federated"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 fed = tf.keras.models.load_model('/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Metro.keras')
#       3 model  = [fed]
#       4 model_name = ["federated"]
#
# File ~/thesis/Federated_Sys/.venv/lib/python3.12/site-packages/keras/src/saving/saving_api.py:203, in load_model(filepath, custom_objects, compile, safe_mode)
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#     202 elif str(filepath).endswith(".keras"):
# --> 203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#     208 else:
#     209     raise ValueError(
#     210         f"File format not supported: filepath={filepath}. "
#     211         "Keras 3 only supports V3 `.keras` files and "
#    (...)    220         "might have a different name)."
#     221     )
#
# ValueError: File not found: filepath=/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Metro.keras. Please ensure the file is an accessible `.keras` zip file.

# %%
checkpoint_filepath = f'{exp_dir}/model/{sensor_name}_fed_model.keras'

# 2. Crea l'istanza della callback
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False, 
    verbose=1
)

# %%
for model, name in zip(model, model_name):
    y_pred = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred)
    y_test_np = scaler_y.inverse_transform(y_test)

    print(f"--- {name} ---")
    #plot_diagnosis_gradient(y_pred, y_test_np, max_samples_heatmap=10, scatter_sample_ratio=0.7)
    evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_evaluation_log.json")
    save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}/TEST', prefix="pred_plot")

    print("\n")
    if name == 'federated':
        model.fit(X_train, y_train, epochs=1000, batch_size=32, callbacks=[model_checkpoint_callback], validation_split=0.2)
        model.load_weights(checkpoint_filepath)
        y_pred = model.predict(X_test)
        y_pred = scaler_y.inverse_transform(y_pred)
        print(f"--- {name} after local fine-tuning ---")
        plot_diagnosis_gradient(y_pred, y_test_np, save_path=f"{name}_pred_quality", max_samples_heatmap=10, scatter_sample_ratio=0.7)
        save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}_fd/TEST', prefix="pred_plot")
        evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_fd_evaluation_log.json")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# --- federated ---
# Test MAE: 102.8811
# Test RMSE: 130.5571
# Test MAPE: 6.28%
# Test R2: 0.3967
# Valore medio del test set: 1544.9532
#
# Log salvato in: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/federated_evaluation_log.json
# Salvo 18 plot in: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/federated/TEST
# Plot salvati correttamente.
#
#
# Epoch 1/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0730 - mae: 0.2262 - mse: 0.0730
# Epoch 2/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0479 - mae: 0.1760 - mse: 0.0479
# Epoch 3/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - mae: 0.1574 - mse: 0.0392
# Epoch 4/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0301 - mae: 0.1330 - mse: 0.0301
# Epoch 5/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0253 - mae: 0.1194 - mse: 0.0253
# Epoch 6/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0212 - mae: 0.1118 - mse: 0.0212
# Epoch 7/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0167 - mae: 0.1005 - mse: 0.0167
# Epoch 8/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0146 - mae: 0.0930 - mse: 0.0146
# Epoch 9/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0128 - mae: 0.0865 - mse: 0.0128
# Epoch 10/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0104 - mae: 0.0768 - mse: 0.0104
# Epoch 11/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0746 - mse: 0.0097
# Epoch 12/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0086 - mae: 0.0717 - mse: 0.0086
# Epoch 13/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - mae: 0.0634 - mse: 0.0074
# Epoch 14/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - mae: 0.0643 - mse: 0.0072
# Epoch 15/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - mae: 0.0582 - mse: 0.0059
# Epoch 16/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0068 - mae: 0.0620 - mse: 0.0068
# Epoch 17/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mae: 0.0572 - mse: 0.0057
# Epoch 18/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - mae: 0.0546 - mse: 0.0053
# Epoch 19/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049 - mae: 0.0505 - mse: 0.0049
# Epoch 20/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0063 - mae: 0.0581 - mse: 0.0063
# Epoch 21/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mae: 0.0566 - mse: 0.0057
# Epoch 22/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mae: 0.0531 - mse: 0.0053
# Epoch 23/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0486 - mse: 0.0042
# Epoch 24/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049 - mae: 0.0525 - mse: 0.0049
# Epoch 25/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0061 - mae: 0.0572 - mse: 0.0061
# Epoch 26/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - mae: 0.0480 - mse: 0.0044
# Epoch 27/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mae: 0.0510 - mse: 0.0048
# Epoch 28/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0498 - mse: 0.0046
# Epoch 29/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - mae: 0.0470 - mse: 0.0047
# Epoch 30/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0481 - mse: 0.0043
# Epoch 31/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0520 - mse: 0.0049
# Epoch 32/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - mae: 0.0531 - mse: 0.0055
# Epoch 33/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mae: 0.0504 - mse: 0.0048
# Epoch 34/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - mae: 0.0500 - mse: 0.0046
# Epoch 35/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - mae: 0.0533 - mse: 0.0055
# Epoch 36/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0444 - mse: 0.0036
# Epoch 37/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0433 - mse: 0.0036
# Epoch 38/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0513 - mse: 0.0049
# Epoch 39/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049 - mae: 0.0502 - mse: 0.0049
# Epoch 40/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040 - mae: 0.0463 - mse: 0.0040
# Epoch 41/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - mae: 0.0515 - mse: 0.0046
# Epoch 42/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0054 - mae: 0.0540 - mse: 0.0054
# Epoch 43/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mae: 0.0496 - mse: 0.0048
# Epoch 44/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mae: 0.0522 - mse: 0.0052
# Epoch 45/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042 - mae: 0.0458 - mse: 0.0042
# Epoch 46/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0480 - mse: 0.0040
# Epoch 47/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mae: 0.0509 - mse: 0.0048
# Epoch 48/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0476 - mse: 0.0043
# Epoch 49/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0501 - mse: 0.0049
# Epoch 50/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045 - mae: 0.0475 - mse: 0.0045
# Epoch 51/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0048 - mae: 0.0497 - mse: 0.0048
# Epoch 52/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0447 - mse: 0.0039
# Epoch 53/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0478 - mse: 0.0042
# Epoch 54/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0431 - mse: 0.0034
# Epoch 55/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - mae: 0.0457 - mse: 0.0044
# Epoch 56/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0483 - mse: 0.0046
# Epoch 57/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0427 - mse: 0.0033
# Epoch 58/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0443 - mse: 0.0037
# Epoch 59/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0429 - mse: 0.0034
# Epoch 60/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0425 - mse: 0.0036
# Epoch 61/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mae: 0.0499 - mse: 0.0052
# Epoch 62/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0446 - mse: 0.0040
# Epoch 63/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - mae: 0.0465 - mse: 0.0044
# Epoch 64/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0409 - mse: 0.0033
# Epoch 65/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mae: 0.0525 - mse: 0.0053
# Epoch 66/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0403 - mse: 0.0029
# Epoch 67/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mae: 0.0458 - mse: 0.0041
# Epoch 68/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mae: 0.0450 - mse: 0.0039
# Epoch 69/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0418 - mse: 0.0031
# Epoch 70/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0416 - mse: 0.0033
# Epoch 71/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0487 - mse: 0.0042
# Epoch 72/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0429 - mse: 0.0039
# Epoch 73/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0427 - mse: 0.0036
# Epoch 74/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - mae: 0.0449 - mse: 0.0038
# Epoch 75/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0441 - mse: 0.0037
# Epoch 76/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0447 - mse: 0.0036
# Epoch 77/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0443 - mse: 0.0034
# Epoch 78/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045 - mae: 0.0469 - mse: 0.0045
# Epoch 79/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mae: 0.0447 - mse: 0.0039
# Epoch 80/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0436 - mse: 0.0041
# Epoch 81/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0420 - mse: 0.0032
# Epoch 82/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0429 - mse: 0.0032
# Epoch 83/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0484 - mse: 0.0044
# Epoch 84/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0442 - mse: 0.0037
# Epoch 85/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - mae: 0.0430 - mse: 0.0038
# Epoch 86/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0436 - mse: 0.0036
# Epoch 87/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0419 - mse: 0.0032
# Epoch 88/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0433 - mse: 0.0036
# Epoch 89/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0469 - mse: 0.0040
# Epoch 90/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mae: 0.0465 - mse: 0.0041
# Epoch 91/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0421 - mse: 0.0033
# Epoch 92/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0436 - mse: 0.0034
# Epoch 93/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0025
# Epoch 94/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - mae: 0.0465 - mse: 0.0041
# Epoch 95/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mae: 0.0436 - mse: 0.0039
# Epoch 96/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0432 - mse: 0.0036
# Epoch 97/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0408 - mse: 0.0031
# Epoch 98/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0495 - mse: 0.0043
# Epoch 99/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0419 - mse: 0.0034
# Epoch 100/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0446 - mse: 0.0034
# Epoch 101/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0444 - mse: 0.0036
# Epoch 102/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0029 - mae: 0.0406 - mse: 0.0029
# Epoch 103/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - mae: 0.0412 - mse: 0.0031
# Epoch 104/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0408 - mse: 0.0031
# Epoch 105/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0400 - mse: 0.0030
# Epoch 106/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - mae: 0.0438 - mse: 0.0038
# Epoch 107/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mae: 0.0425 - mse: 0.0035
# Epoch 108/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045 - mae: 0.0494 - mse: 0.0045
# Epoch 109/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0467 - mse: 0.0043
# Epoch 110/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - mae: 0.0446 - mse: 0.0040
# Epoch 111/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0422 - mse: 0.0034
# Epoch 112/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0393 - mse: 0.0027
# Epoch 113/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0389 - mse: 0.0027
# Epoch 114/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0394 - mse: 0.0028
# Epoch 115/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0450 - mse: 0.0038
# Epoch 116/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0431 - mse: 0.0034
# Epoch 117/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0416 - mse: 0.0034
# Epoch 118/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030 - mae: 0.0399 - mse: 0.0030
# Epoch 119/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0405 - mse: 0.0030
# Epoch 120/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0400 - mse: 0.0029
# Epoch 121/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0425 - mse: 0.0033
# Epoch 122/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0378 - mse: 0.0029
# Epoch 123/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0436 - mse: 0.0036
# Epoch 124/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0406 - mse: 0.0031
# Epoch 125/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0423 - mse: 0.0033
# Epoch 126/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042 - mae: 0.0457 - mse: 0.0042
# Epoch 127/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 128/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0434 - mse: 0.0037
# Epoch 129/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0433 - mse: 0.0036
# Epoch 130/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0440 - mse: 0.0035
# Epoch 131/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0427 - mse: 0.0034
# Epoch 132/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0461 - mse: 0.0037
# Epoch 133/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0404 - mse: 0.0033
# Epoch 134/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0440 - mse: 0.0036
# Epoch 135/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0444 - mse: 0.0036
# Epoch 136/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0397 - mse: 0.0029
# Epoch 137/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0433 - mse: 0.0034
# Epoch 138/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0399 - mse: 0.0030
# Epoch 139/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0426 - mse: 0.0034
# Epoch 140/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0380 - mse: 0.0028
# Epoch 141/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0431 - mse: 0.0031
# Epoch 142/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - mae: 0.0417 - mse: 0.0032
# Epoch 143/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - mae: 0.0410 - mse: 0.0033
# Epoch 144/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - mae: 0.0471 - mse: 0.0047
# Epoch 145/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0425 - mse: 0.0033
# Epoch 146/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0443 - mse: 0.0037
# Epoch 147/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0380 - mse: 0.0028
# Epoch 148/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0447 - mse: 0.0039
# Epoch 149/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0468 - mse: 0.0041
# Epoch 150/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0415 - mse: 0.0032
# Epoch 151/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0465 - mse: 0.0040
# Epoch 152/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0382 - mse: 0.0026
# Epoch 153/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0426 - mse: 0.0037
# Epoch 154/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mae: 0.0440 - mse: 0.0038
# Epoch 155/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0387 - mse: 0.0027
# Epoch 156/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mae: 0.0429 - mse: 0.0035
# Epoch 157/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0412 - mse: 0.0031
# Epoch 158/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0435 - mse: 0.0036
# Epoch 159/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0445 - mse: 0.0041
# Epoch 160/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0461 - mse: 0.0037
# Epoch 161/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0428 - mse: 0.0037
# Epoch 162/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0416 - mse: 0.0032
# Epoch 163/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mae: 0.0393 - mse: 0.0028
# Epoch 164/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035 - mae: 0.0436 - mse: 0.0035
# Epoch 165/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0434 - mse: 0.0034
# Epoch 166/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0424 - mse: 0.0031
# Epoch 167/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0417 - mse: 0.0032
# Epoch 168/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0409 - mse: 0.0030
# Epoch 169/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0395 - mse: 0.0030
# Epoch 170/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0378 - mse: 0.0026
# Epoch 171/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - mae: 0.0399 - mse: 0.0031
# Epoch 172/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0406 - mse: 0.0032
# Epoch 173/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035 - mae: 0.0416 - mse: 0.0035
# Epoch 174/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0435 - mse: 0.0037
# Epoch 175/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0363 - mse: 0.0027
# Epoch 176/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0387 - mse: 0.0028
# Epoch 177/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0409 - mse: 0.0033
# Epoch 178/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0399 - mse: 0.0031
# Epoch 179/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0436 - mse: 0.0036
# Epoch 180/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0396 - mse: 0.0031
# Epoch 181/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0400 - mse: 0.0031
# Epoch 182/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 183/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 184/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0443 - mse: 0.0037
# Epoch 185/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0411 - mse: 0.0032
# Epoch 186/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0455 - mse: 0.0036
# Epoch 187/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0439 - mse: 0.0036
# Epoch 188/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0352 - mse: 0.0022
# Epoch 189/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mae: 0.0476 - mse: 0.0041
# Epoch 190/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - mae: 0.0506 - mse: 0.0054
# Epoch 191/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0441 - mse: 0.0037
# Epoch 192/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0376 - mse: 0.0026
# Epoch 193/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0391 - mse: 0.0027
# Epoch 194/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0418 - mse: 0.0033
# Epoch 195/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0425 - mse: 0.0035
# Epoch 196/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0377 - mse: 0.0027
# Epoch 197/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0404 - mse: 0.0030
# Epoch 198/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0380 - mse: 0.0026
# Epoch 199/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - mae: 0.0434 - mse: 0.0038
# Epoch 200/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0376 - mse: 0.0029
# Epoch 201/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0369 - mse: 0.0025
# Epoch 202/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0424 - mse: 0.0033
# Epoch 203/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - mae: 0.0381 - mse: 0.0028
# Epoch 204/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0365 - mse: 0.0029
# Epoch 205/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0347 - mse: 0.0021
# Epoch 206/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0426 - mse: 0.0034
# Epoch 207/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mae: 0.0431 - mse: 0.0039
# Epoch 208/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mae: 0.0440 - mse: 0.0035
# Epoch 209/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0358 - mse: 0.0025
# Epoch 210/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0368 - mse: 0.0026
# Epoch 211/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0382 - mse: 0.0025
# Epoch 212/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0402 - mse: 0.0032
# Epoch 213/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0415 - mse: 0.0034
# Epoch 214/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0405 - mse: 0.0031
# Epoch 215/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0347 - mse: 0.0022
# Epoch 216/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032 - mae: 0.0425 - mse: 0.0032
# Epoch 217/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 218/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mae: 0.0425 - mse: 0.0035
# Epoch 219/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 220/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0358 - mse: 0.0023
# Epoch 221/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0383 - mse: 0.0029
# Epoch 222/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043 - mae: 0.0456 - mse: 0.0043
# Epoch 223/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - mae: 0.0373 - mse: 0.0028
# Epoch 224/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - mae: 0.0415 - mse: 0.0034
# Epoch 225/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0387 - mse: 0.0030
# Epoch 226/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0347 - mse: 0.0025
# Epoch 227/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0420 - mse: 0.0033
# Epoch 228/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0410 - mse: 0.0029
# Epoch 229/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0430 - mse: 0.0033
# Epoch 230/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0378 - mse: 0.0028
# Epoch 231/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0370 - mse: 0.0025
# Epoch 232/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0389 - mse: 0.0030
# Epoch 233/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0378 - mse: 0.0031
# Epoch 234/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0431 - mse: 0.0036
# Epoch 235/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 236/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0384 - mse: 0.0030
# Epoch 237/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0398 - mse: 0.0031
# Epoch 238/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0369 - mse: 0.0024
# Epoch 239/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0412 - mse: 0.0033
# Epoch 240/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0406 - mse: 0.0031
# Epoch 241/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0388 - mse: 0.0027
# Epoch 242/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0420 - mse: 0.0032
# Epoch 243/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0385 - mse: 0.0029
# Epoch 244/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0390 - mse: 0.0029
# Epoch 245/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0426 - mse: 0.0034
# Epoch 246/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0413 - mse: 0.0033
# Epoch 247/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0358 - mse: 0.0025
# Epoch 248/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0375 - mse: 0.0024
# Epoch 249/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0401 - mse: 0.0031
# Epoch 250/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0386 - mse: 0.0028
# Epoch 251/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0417 - mse: 0.0030
# Epoch 252/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0385 - mse: 0.0026
# Epoch 253/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0391 - mse: 0.0029
# Epoch 254/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0410 - mse: 0.0030
# Epoch 255/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0432 - mse: 0.0040
# Epoch 256/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0427 - mse: 0.0032
# Epoch 257/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0371 - mse: 0.0025
# Epoch 258/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0411 - mse: 0.0031
# Epoch 259/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0404 - mse: 0.0030
# Epoch 260/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0392 - mse: 0.0027
# Epoch 261/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0464 - mse: 0.0043
# Epoch 262/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0374 - mse: 0.0026
# Epoch 263/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0400 - mse: 0.0028
# Epoch 264/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0373 - mse: 0.0025
# Epoch 265/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0406 - mse: 0.0029
# Epoch 266/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0381 - mse: 0.0027
# Epoch 267/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0404 - mse: 0.0030
# Epoch 268/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0400 - mse: 0.0029
# Epoch 269/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0374 - mse: 0.0026
# Epoch 270/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0384 - mse: 0.0029
# Epoch 271/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0439 - mse: 0.0039
# Epoch 272/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0395 - mse: 0.0030
# Epoch 273/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0397 - mse: 0.0031
# Epoch 274/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0374 - mse: 0.0026
# Epoch 275/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0382 - mse: 0.0028
# Epoch 276/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0414 - mse: 0.0035
# Epoch 277/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0413 - mse: 0.0032
# Epoch 278/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0415 - mse: 0.0031
# Epoch 279/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0371 - mse: 0.0024
# Epoch 280/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mae: 0.0327 - mse: 0.0020
# Epoch 281/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0421 - mse: 0.0034
# Epoch 282/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0398 - mse: 0.0028
# Epoch 283/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0410 - mse: 0.0032
# Epoch 284/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0449 - mse: 0.0034
# Epoch 285/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0417 - mse: 0.0036
# Epoch 286/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0411 - mse: 0.0033
# Epoch 287/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0415 - mse: 0.0036
# Epoch 288/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0395 - mse: 0.0027
# Epoch 289/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0399 - mse: 0.0031
# Epoch 290/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0448 - mse: 0.0041
# Epoch 291/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0372 - mse: 0.0026
# Epoch 292/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0347 - mse: 0.0022
# Epoch 293/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 294/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0385 - mse: 0.0031
# Epoch 295/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0371 - mse: 0.0028
# Epoch 296/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0431 - mse: 0.0033
# Epoch 297/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0351 - mse: 0.0023
# Epoch 298/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0360 - mse: 0.0025
# Epoch 299/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0397 - mse: 0.0027
# Epoch 300/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0382 - mse: 0.0027
# Epoch 301/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0347 - mse: 0.0023
# Epoch 302/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0392 - mse: 0.0031
# Epoch 303/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0391 - mse: 0.0032
# Epoch 304/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0418 - mse: 0.0034
# Epoch 305/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mae: 0.0388 - mse: 0.0026
# Epoch 306/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0430 - mse: 0.0034
# Epoch 307/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0400 - mse: 0.0034
# Epoch 308/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0375 - mse: 0.0028
# Epoch 309/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0401 - mse: 0.0028
# Epoch 310/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0411 - mse: 0.0031
# Epoch 311/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0391 - mse: 0.0030
# Epoch 312/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0414 - mse: 0.0031
# Epoch 313/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0432 - mse: 0.0037
# Epoch 314/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0370 - mse: 0.0025
# Epoch 315/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0389 - mse: 0.0027
# Epoch 316/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0455 - mse: 0.0036
# Epoch 317/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0397 - mse: 0.0031
# Epoch 318/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0419 - mse: 0.0034
# Epoch 319/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0344 - mse: 0.0022
# Epoch 320/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0390 - mse: 0.0030
# Epoch 321/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0037 - mae: 0.0457 - mse: 0.0037
# Epoch 322/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0401 - mse: 0.0031
# Epoch 323/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0350 - mse: 0.0023
# Epoch 324/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0025
# Epoch 325/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0439 - mse: 0.0037
# Epoch 326/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0368 - mse: 0.0026
# Epoch 327/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0402 - mse: 0.0030
# Epoch 328/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0352 - mse: 0.0024
# Epoch 329/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0390 - mse: 0.0025
# Epoch 330/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0405 - mse: 0.0032
# Epoch 331/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0411 - mse: 0.0031
# Epoch 332/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0385 - mse: 0.0027
# Epoch 333/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0363 - mse: 0.0023
# Epoch 334/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0383 - mse: 0.0027
# Epoch 335/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0385 - mse: 0.0029
# Epoch 336/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0410 - mse: 0.0031
# Epoch 337/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0347 - mse: 0.0024
# Epoch 338/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0431 - mse: 0.0035
# Epoch 339/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0416 - mse: 0.0033
# Epoch 340/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0384 - mse: 0.0028
# Epoch 341/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0368 - mse: 0.0026
# Epoch 342/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0390 - mse: 0.0029
# Epoch 343/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0324 - mse: 0.0019
# Epoch 344/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0374 - mse: 0.0024
# Epoch 345/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0397 - mse: 0.0034
# Epoch 346/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0368 - mse: 0.0025
# Epoch 347/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0369 - mse: 0.0025
# Epoch 348/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0377 - mse: 0.0027
# Epoch 349/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0343 - mse: 0.0022
# Epoch 350/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0411 - mse: 0.0034
# Epoch 351/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0026 - mae: 0.0382 - mse: 0.0026
# Epoch 352/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0314 - mse: 0.0017
# Epoch 353/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0396 - mse: 0.0026
# Epoch 354/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0404 - mse: 0.0032
# Epoch 355/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0025
# Epoch 356/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0365 - mse: 0.0025
# Epoch 357/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0407 - mse: 0.0031
# Epoch 358/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0433 - mse: 0.0036
# Epoch 359/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mae: 0.0337 - mse: 0.0020
# Epoch 360/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0327 - mse: 0.0021
# Epoch 361/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0358 - mse: 0.0024
# Epoch 362/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0386 - mse: 0.0029
# Epoch 363/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0412 - mse: 0.0033
# Epoch 364/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0386 - mse: 0.0028
# Epoch 365/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0386 - mse: 0.0029
# Epoch 366/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0332 - mse: 0.0022
# Epoch 367/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 368/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0360 - mse: 0.0025
# Epoch 369/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0395 - mse: 0.0030
# Epoch 370/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - mae: 0.0391 - mse: 0.0029
# Epoch 371/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0385 - mse: 0.0029
# Epoch 372/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0410 - mse: 0.0030
# Epoch 373/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0427 - mse: 0.0036
# Epoch 374/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0380 - mse: 0.0029
# Epoch 375/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0364 - mse: 0.0023
# Epoch 376/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0368 - mse: 0.0025
# Epoch 377/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mae: 0.0309 - mse: 0.0017
# Epoch 378/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0415 - mse: 0.0031
# Epoch 379/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0406 - mse: 0.0031
# Epoch 380/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0404 - mse: 0.0033
# Epoch 381/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0411 - mse: 0.0030
# Epoch 382/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0381 - mse: 0.0029
# Epoch 383/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0421 - mse: 0.0034
# Epoch 384/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0377 - mse: 0.0025
# Epoch 385/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0396 - mse: 0.0029
# Epoch 386/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0375 - mse: 0.0026
# Epoch 387/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0435 - mse: 0.0035
# Epoch 388/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0414 - mse: 0.0033
# Epoch 389/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0414 - mse: 0.0031
# Epoch 390/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0380 - mse: 0.0025
# Epoch 391/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0448 - mse: 0.0035
# Epoch 392/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0397 - mse: 0.0029
# Epoch 393/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0386 - mse: 0.0028
# Epoch 394/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0385 - mse: 0.0027
# Epoch 395/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0410 - mse: 0.0032
# Epoch 396/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - mae: 0.0410 - mse: 0.0034
# Epoch 397/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0376 - mse: 0.0028
# Epoch 398/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0373 - mse: 0.0025
# Epoch 399/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0356 - mse: 0.0024
# Epoch 400/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0390 - mse: 0.0027
# Epoch 401/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0376 - mse: 0.0026
# Epoch 402/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0370 - mse: 0.0024
# Epoch 403/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0403 - mse: 0.0033
# Epoch 404/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0350 - mse: 0.0023
# Epoch 405/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0338 - mse: 0.0022
# Epoch 406/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0352 - mse: 0.0026
# Epoch 407/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0388 - mse: 0.0029
# Epoch 408/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0408 - mse: 0.0031
# Epoch 409/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0379 - mse: 0.0028
# Epoch 410/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0385 - mse: 0.0030
# Epoch 411/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0389 - mse: 0.0027
# Epoch 412/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0408 - mse: 0.0029
# Epoch 413/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0405 - mse: 0.0032
# Epoch 414/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0375 - mse: 0.0029
# Epoch 415/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0413 - mse: 0.0030
# Epoch 416/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0382 - mse: 0.0028
# Epoch 417/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0340 - mse: 0.0021
# Epoch 418/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0379 - mse: 0.0026
# Epoch 419/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0446 - mse: 0.0040
# Epoch 420/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0352 - mse: 0.0023
# Epoch 421/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0332 - mse: 0.0022
# Epoch 422/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - mae: 0.0381 - mse: 0.0028
# Epoch 423/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mae: 0.0401 - mse: 0.0030
# Epoch 424/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0391 - mse: 0.0028
# Epoch 425/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0359 - mse: 0.0025
# Epoch 426/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0407 - mse: 0.0030
# Epoch 427/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0364 - mse: 0.0023
# Epoch 428/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0353 - mse: 0.0023
# Epoch 429/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0350 - mse: 0.0026
# Epoch 430/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mae: 0.0444 - mse: 0.0039
# Epoch 431/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0429 - mse: 0.0032
# Epoch 432/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0436 - mse: 0.0032
# Epoch 433/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0417 - mse: 0.0031
# Epoch 434/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0380 - mse: 0.0028
# Epoch 435/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0377 - mse: 0.0026
# Epoch 436/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0383 - mse: 0.0028
# Epoch 437/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0354 - mse: 0.0023
# Epoch 438/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0394 - mse: 0.0029
# Epoch 439/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0391 - mse: 0.0025
# Epoch 440/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0370 - mse: 0.0025
# Epoch 441/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0358 - mse: 0.0021
# Epoch 442/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0405 - mse: 0.0034
# Epoch 443/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0385 - mse: 0.0026
# Epoch 444/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0398 - mse: 0.0029
# Epoch 445/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032 - mae: 0.0415 - mse: 0.0032
# Epoch 446/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - mae: 0.0362 - mse: 0.0023
# Epoch 447/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0438 - mse: 0.0033
# Epoch 448/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0378 - mse: 0.0027
# Epoch 449/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0353 - mse: 0.0023
# Epoch 450/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0430 - mse: 0.0034
# Epoch 451/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0359 - mse: 0.0024
# Epoch 452/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0396 - mse: 0.0027
# Epoch 453/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0428 - mse: 0.0034
# Epoch 454/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0376 - mse: 0.0026
# Epoch 455/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0337 - mse: 0.0022
# Epoch 456/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0365 - mse: 0.0023
# Epoch 457/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0357 - mse: 0.0023
# Epoch 458/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0351 - mse: 0.0023
# Epoch 459/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0379 - mse: 0.0026
# Epoch 460/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0366 - mse: 0.0024
# Epoch 461/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0364 - mse: 0.0025
# Epoch 462/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0409 - mse: 0.0035
# Epoch 463/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0398 - mse: 0.0030
# Epoch 464/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0348 - mse: 0.0024
# Epoch 465/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0401 - mse: 0.0031
# Epoch 466/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0404 - mse: 0.0029
# Epoch 467/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0352 - mse: 0.0025
# Epoch 468/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0351 - mse: 0.0024
# Epoch 469/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0396 - mse: 0.0030
# Epoch 470/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0378 - mse: 0.0027
# Epoch 471/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0373 - mse: 0.0027
# Epoch 472/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0361 - mse: 0.0025
# Epoch 473/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0361 - mse: 0.0023
# Epoch 474/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0434 - mse: 0.0036
# Epoch 475/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0376 - mse: 0.0024
# Epoch 476/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0026 - mae: 0.0385 - mse: 0.0026
# Epoch 477/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mae: 0.0408 - mse: 0.0029
# Epoch 478/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0368 - mse: 0.0024
# Epoch 479/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0387 - mse: 0.0033
# Epoch 480/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0379 - mse: 0.0026
# Epoch 481/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0392 - mse: 0.0028
# Epoch 482/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0330 - mse: 0.0020
# Epoch 483/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0345 - mse: 0.0023
# Epoch 484/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0362 - mse: 0.0025
# Epoch 485/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0399 - mse: 0.0032
# Epoch 486/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0389 - mse: 0.0028
# Epoch 487/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0393 - mse: 0.0027
# Epoch 488/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0025
# Epoch 489/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0408 - mse: 0.0030
# Epoch 490/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0365 - mse: 0.0025
# Epoch 491/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0351 - mse: 0.0021
# Epoch 492/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0357 - mse: 0.0023
# Epoch 493/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mae: 0.0346 - mse: 0.0020
# Epoch 494/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0355 - mse: 0.0025
# Epoch 495/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0374 - mse: 0.0024
# Epoch 496/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mae: 0.0354 - mse: 0.0024
# Epoch 497/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021 - mae: 0.0340 - mse: 0.0021
# Epoch 498/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0417 - mse: 0.0031
# Epoch 499/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0415 - mse: 0.0032
# Epoch 500/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0387 - mse: 0.0028
# Epoch 501/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0389 - mse: 0.0029
# Epoch 502/1000
# ...
# Epoch 841/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mae: 0.0309 - mse: 0.0018
# Epoch 842/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 843/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0405 - mse: 0.0030
# Epoch 844/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0347 - mse: 0.0022
# Epoch 845/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0356 - mse: 0.0023
# Epoch 846/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0376 - mse: 0.0026
# Epoch 847/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 848/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0407 - mse: 0.0034
# Epoch 849/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - mae: 0.0373 - mse: 0.0027
# Epoch 850/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0389 - mse: 0.0028
# Epoch 851/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0368 - mse: 0.0023
# Epoch 852/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0358 - mse: 0.0022
# Epoch 853/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0373 - mse: 0.0027
# Epoch 854/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0320 - mse: 0.0019
# Epoch 855/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0388 - mse: 0.0024
# Epoch 856/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0375 - mse: 0.0025
# Epoch 857/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0367 - mse: 0.0026
# Epoch 858/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0365 - mse: 0.0024
# Epoch 859/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0390 - mse: 0.0027
# Epoch 860/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0410 - mse: 0.0028
# Epoch 861/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0400 - mse: 0.0030
# Epoch 862/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0323 - mse: 0.0021
# Epoch 863/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0381 - mse: 0.0028
# Epoch 864/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0379 - mse: 0.0030
# Epoch 865/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0401 - mse: 0.0032
# Epoch 866/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0404 - mse: 0.0027
# Epoch 867/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0383 - mse: 0.0026
# Epoch 868/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0394 - mse: 0.0028
# Epoch 869/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 870/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0390 - mse: 0.0029
# Epoch 871/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0409 - mse: 0.0031
# Epoch 872/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0354 - mse: 0.0028
# Epoch 873/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0028 - mae: 0.0384 - mse: 0.0028
# Epoch 874/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - mae: 0.0417 - mse: 0.0033
# Epoch 875/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0355 - mse: 0.0023
# Epoch 876/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mae: 0.0329 - mse: 0.0020
# Epoch 877/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0025
# Epoch 878/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0334 - mse: 0.0021
# Epoch 879/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0403 - mse: 0.0032
# Epoch 880/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0383 - mse: 0.0033
# Epoch 881/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0354 - mse: 0.0022
# Epoch 882/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0332 - mse: 0.0020
# Epoch 883/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0367 - mse: 0.0027
# Epoch 884/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0315 - mse: 0.0019
# Epoch 885/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0347 - mse: 0.0023
# Epoch 886/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0348 - mse: 0.0021
# Epoch 887/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0432 - mse: 0.0036
# Epoch 888/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0355 - mse: 0.0024
# Epoch 889/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0374 - mse: 0.0028
# Epoch 890/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0387 - mse: 0.0028
# Epoch 891/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0354 - mse: 0.0023
# Epoch 892/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0401 - mse: 0.0030
# Epoch 893/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 894/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0414 - mse: 0.0033
# Epoch 895/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0386 - mse: 0.0028
# Epoch 896/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0325 - mse: 0.0019
# Epoch 897/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mae: 0.0309 - mse: 0.0017
# Epoch 898/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - mae: 0.0336 - mse: 0.0021
# Epoch 899/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0350 - mse: 0.0021
# Epoch 900/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0372 - mse: 0.0026
# Epoch 901/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0361 - mse: 0.0024
# Epoch 902/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0384 - mse: 0.0029
# Epoch 903/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0368 - mse: 0.0027
# Epoch 904/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0356 - mse: 0.0026
# Epoch 905/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0350 - mse: 0.0023
# Epoch 906/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0366 - mse: 0.0023
# Epoch 907/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0351 - mse: 0.0022
# Epoch 908/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0357 - mse: 0.0027
# Epoch 909/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0359 - mse: 0.0023
# Epoch 910/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0366 - mse: 0.0023
# Epoch 911/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0439 - mse: 0.0036
# Epoch 912/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0343 - mse: 0.0021
# Epoch 913/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0367 - mse: 0.0024
# Epoch 914/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0386 - mse: 0.0031
# Epoch 915/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0340 - mse: 0.0022
# Epoch 916/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - mae: 0.0386 - mse: 0.0029
# Epoch 917/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - mae: 0.0313 - mse: 0.0018
# Epoch 918/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mae: 0.0342 - mse: 0.0022
# Epoch 919/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0349 - mse: 0.0022
# Epoch 920/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0399 - mse: 0.0032
# Epoch 921/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0388 - mse: 0.0027
# Epoch 922/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0320 - mse: 0.0018
# Epoch 923/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0368 - mse: 0.0025
# Epoch 924/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0364 - mse: 0.0023
# Epoch 925/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0306 - mse: 0.0017
# Epoch 926/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 927/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0411 - mse: 0.0031
# Epoch 928/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0360 - mse: 0.0024
# Epoch 929/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0404 - mse: 0.0034
# Epoch 930/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 931/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0387 - mse: 0.0029
# Epoch 932/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0364 - mse: 0.0026
# Epoch 933/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0344 - mse: 0.0022
# Epoch 934/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0380 - mse: 0.0026
# Epoch 935/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0025
# Epoch 936/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0336 - mse: 0.0021
# Epoch 937/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0355 - mse: 0.0024
# Epoch 938/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0380 - mse: 0.0026
# Epoch 939/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0394 - mse: 0.0029
# Epoch 940/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0364 - mse: 0.0024
# Epoch 941/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 942/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mae: 0.0345 - mse: 0.0020
# Epoch 943/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0353 - mse: 0.0022
# Epoch 944/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0427 - mse: 0.0034
# Epoch 945/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - mae: 0.0381 - mse: 0.0026
# Epoch 946/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0348 - mse: 0.0022
# Epoch 947/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0377 - mse: 0.0027
# Epoch 948/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0303 - mse: 0.0017
# Epoch 949/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0354 - mse: 0.0026
# Epoch 950/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0336 - mse: 0.0020
# Epoch 951/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0387 - mse: 0.0028
# Epoch 952/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0347 - mse: 0.0020
# Epoch 953/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0375 - mse: 0.0026
# Epoch 954/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0329 - mse: 0.0019
# Epoch 955/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0339 - mse: 0.0022
# Epoch 956/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0374 - mse: 0.0026
# Epoch 957/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0313 - mse: 0.0017
# Epoch 958/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0337 - mse: 0.0023
# Epoch 959/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0326 - mse: 0.0021
# Epoch 960/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0322 - mse: 0.0019
# Epoch 961/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0356 - mse: 0.0025
# Epoch 962/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0357 - mse: 0.0022
# Epoch 963/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0340 - mse: 0.0021
# Epoch 964/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0370 - mse: 0.0024
# Epoch 965/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 966/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - mae: 0.0399 - mse: 0.0031
# Epoch 967/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0316 - mse: 0.0020
# Epoch 968/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0391 - mse: 0.0032
# Epoch 969/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0339 - mse: 0.0025
# Epoch 970/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - mae: 0.0375 - mse: 0.0029
# Epoch 971/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 972/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0377 - mse: 0.0024
# Epoch 973/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0398 - mse: 0.0026
# Epoch 974/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0405 - mse: 0.0031
# Epoch 975/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0347 - mse: 0.0023
# Epoch 976/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0326 - mse: 0.0021
# Epoch 977/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0326 - mse: 0.0020
# Epoch 978/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0334 - mse: 0.0022
# Epoch 979/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0350 - mse: 0.0025
# Epoch 980/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0369 - mse: 0.0023
# Epoch 981/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0349 - mse: 0.0021
# Epoch 982/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0314 - mse: 0.0018
# Epoch 983/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0351 - mse: 0.0022
# Epoch 984/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0379 - mse: 0.0026
# Epoch 985/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0337 - mse: 0.0022
# Epoch 986/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0368 - mse: 0.0027
# Epoch 987/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - mae: 0.0349 - mse: 0.0021
# Epoch 988/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0381 - mse: 0.0028
# Epoch 989/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0321 - mse: 0.0018
# Epoch 990/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0374 - mse: 0.0027
# Epoch 991/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0379 - mse: 0.0029
# Epoch 992/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0369 - mse: 0.0024
# Epoch 993/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0375 - mse: 0.0024
# Epoch 994/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0359 - mse: 0.0025
# Epoch 995/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0357 - mse: 0.0022
# Epoch 996/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0334 - mse: 0.0024
# Epoch 997/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0365 - mse: 0.0026
# Epoch 998/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0403 - mse: 0.0032
# Epoch 999/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0328 - mse: 0.0020
# Epoch 1000/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0357 - mse: 0.0024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# --- federated after local fine-tuning ---
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_96887/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Salvo 18 plot in: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/federated_fd/TEST
# Plot salvati correttamente.
# Test MAE: 5.2715
# Test RMSE: 6.6995
# Test MAPE: 0.34%
# Test R2: 0.9985
# Valore medio del test set: 1544.9532
#
# Log salvato in: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/federated_fd_evaluation_log.json
