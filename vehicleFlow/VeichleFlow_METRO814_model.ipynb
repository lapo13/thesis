# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import os, pickle, random
from datetime import datetime

# %%
get_after_QA = lambda s: s.split("DISIT/", 1)[1]

# %%
dati = pd.read_excel('/Users/lapotinacci/thesis/metric_datasets/vehicleFlow_dataset.xlsx')
dati = dati[dati["serviceUri"] == "http://www.disit.org/km4city/resource/iot/orionUNIFI/DISIT/METRO814"].copy()
sensor_name = get_after_QA(dati["serviceUri"].iloc[0])
dati.drop(columns=["serviceUri"], inplace=True)
print(dati.shape)
# Out:
# (190, 15)

# %%
# === Creazione cartella esperimento con timestamp ISO ===
timestamp = datetime.now().strftime("%H-%M-%S")
print(f"Ora inizio esperimento: {timestamp}")
day= datetime.now().strftime("%Y-%m-%d")
print(f"Giorno inizio esperimento: {day}")
exp_dir = f"../RISULTATI/{day}/esperimento_{sensor_name}_{timestamp}"

os.makedirs(exp_dir, exist_ok=True)

print(f"Cartella esperimento creata: {exp_dir}")
# Out:
# Ora inizio esperimento: 16-04-27
# Giorno inizio esperimento: 2025-11-29
# Cartella esperimento creata: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27

# %%
import ast

mask = ~dati['TTT'].str.contains("nan", na=True)
dtset_completo = dati[mask]

dtset_completo['TTT'] = dtset_completo['TTT'].apply(ast.literal_eval)

# %%
# Filtra le righe dove la colonna TTT ha lunghezza 24, ed elimina tutte le colonne le cui osservazioni sono indipendenti dal giorno
dtset_filtrato = dtset_completo[dtset_completo["TTT"].apply(lambda x: len(x) == 24)].sample(frac=1).reset_index(drop=True)
dtset_filtrato = dtset_filtrato[dtset_filtrato["type_of_TTT"] == "daily"]
len(dtset_filtrato)
# Out:
# 90

# %%
import numpy as np


def is_useful_series(series, zero_ratio_thr=0.85, min_nonzero_value=0.1):
    arr = np.array(series, dtype=float)
    
    # Serie troppo corta
    if len(arr) <= 1:
        return False
    
    # Troppi zeri
    zero_ratio = (arr == 0).mean()
    if zero_ratio >= zero_ratio_thr:
        return False
    
    # Valore medio trascurabile (quasi zero)
    mean_val = np.mean(arr)
    if abs(mean_val) < min_nonzero_value:
        return False
    
    # Se arriva qui, la serie ha valori significativi
    return True

# Applica filtro
mask_useful = dtset_filtrato["TTT"].apply(is_useful_series)
df_useful = dtset_filtrato[mask_useful]

# %%
def spezza_serie_in_colonne(df, colonna_stringa, prefix='col_'):
    # --- Controllo colonna ---
    if colonna_stringa not in df.columns:
        raise ValueError(f"La colonna '{colonna_stringa}' non esiste nel DataFrame")

    result_df = df.copy()

    # Estraggo la colonna contenente gli embedding
    col = result_df.pop(colonna_stringa)

    embeddings = []

    for item in col:
        # Gestione valori nulli o vuoti
        if pd.isna(item) or item == "":
            embeddings.append([])
            continue
        
        # Se l'item è già una lista o un array (non stringa), lo gestiamo direttamente
        if isinstance(item, (list, np.ndarray)):
            embeddings.append(list(item))
            continue

        vett = None
        
        # --- TENTATIVO 1: Parsing Standard Python (es. "[1, 2, 3]") ---
        try:
            parsed = ast.literal_eval(item)
            if isinstance(parsed, (list, tuple)):
                vett = list(parsed)
        except (ValueError, SyntaxError):
            # Se fallisce (es. SyntaxError per mancanza di virgole), passiamo al tentativo 2
            pass

        # --- TENTATIVO 2: Parsing per Spazi (es. "[1 2 3]" o "1 2 3") ---
        if vett is None:
            try:
                # Rimuove parentesi quadre, tonde e spazi iniziali/finali
                clean_str = item.replace('[', '').replace(']', '').replace('(', '').replace(')', '').strip()
                
                # Se la stringa è vuota dopo la pulizia (es. "[]"), è una lista vuota
                if not clean_str:
                    vett = []
                else:
                    # .split() senza argomenti gestisce spazi multipli, tab e newline automaticamente
                    vett = [float(x) for x in clean_str.split()]
            except Exception as e:
                print(f"Errore nel parsing dell'elemento '{item}': {e}")
                vett = []

        # --- Conversione finale e check ---
        # Assicuro che tutti gli elementi siano float (utile se ast.literal_eval ha trovato interi)
        try:
            if vett:
                vett = [float(x) for x in vett]
            embeddings.append(vett)
        except Exception as e:
            print(f"Errore conversione float per '{item}': {e}")
            embeddings.append([])

    # --- Uniformo dimensione dei vettori ---
    lengths = [len(v) for v in embeddings]
    if not lengths or max(lengths) == 0:
        # Se non ci sono dati validi, restituisco il df senza la colonna oppure sollevo errore
        # Qui scelgo di restituire il df originale senza la colonna parsata per evitare crash
        print("Warning: Nessun embedding valido trovato.")
        return result_df

    max_len = max(lengths)

    # Padding con NaN
    embeddings_padded = [
        v + [np.nan] * (max_len - len(v)) if len(v) < max_len else v
        for v in embeddings
    ]

    # --- Creo DataFrame delle nuove colonne ---
    colonne_embedding = pd.DataFrame(
        embeddings_padded,
        index=result_df.index,
        columns=[f"{prefix}{i}" for i in range(max_len)]
    )

    # --- Merge col DataFrame originale ---
    return pd.concat([result_df, colonne_embedding], axis=1)

# %%
for ttt in df_useful.TTT:
    plt.plot(ttt)

# %%
def summary_df(df):
    summary = pd.DataFrame({
        'dtype': df.dtypes,
        'n_missing': df.isna().sum(),
        '%_missing': (df.isna().mean() * 100).round(2),
        'n_unique': df.nunique(),
        'top_value': df.mode().iloc[0],  # moda
        'top_freq': [df[col].value_counts(dropna=True).iloc[0] if not df[col].value_counts(dropna=True).empty else None for col in df.columns],
        'min': [df[col].min() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'max': [df[col].max() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'mean': [df[col].mean() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'std': [df[col].std() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
    })
    return summary

# %%
#Nella precedente sono state eliminate le colonne con Nan, tuttavia alcuni dataset dei sensori METRO hanno dei Nan in city e surface dunque vengono rimossi nel prcedente box

categorical = [
    'is_weekend'
    ]

#consiglio, per serie cicliche usare funzioni periodiche tipo seno coseno 
df_encoded = pd.get_dummies(df_useful
                            , columns=categorical)

# %%
def save_pkl(obj, path):
    with open(path, "wb") as f:
        pickle.dump(obj, f)
    print(f"Salvato: {path}")

def load_pkl(path):
    with open(path, "rb") as f:
        return pickle.load(f)

# %%
#codifica ciclica delle features e individuazione del'ora del giorno e della settimana 

def encode_time_features(df, start_col="interval_start", end_col="interval_end"):
    df = df.copy()
    
    # Step 1: Ensure datetime columns are in the correct format first
    df[start_col] = pd.to_datetime(df[start_col], utc=True, format="mixed")
    df[end_col] = pd.to_datetime(df[end_col], utc=True, format="mixed")

    # Step 2: Extract 'month' and 'day' after conversion
    df['month'] = df[start_col].dt.month
    df['day'] = df[start_col].dt.dayofweek # Note: dayofweek is typically used for cyclical weekly patterns
    
    # Step 3: Now you can create the cyclical features
    df['month_sin'] = np.sin(2 * np.pi * df['month']/len(df['month'].unique()))
    df['month_cos'] = np.cos(2 * np.pi * df['month']/len(df['month'].unique()))
    df['day_sin'] = np.sin(2 * np.pi * df['day']/len(df['day'].unique()))
    df['day_cos'] = np.cos(2 * np.pi * df['day']/len(df['day'].unique()))


    # Ora del giorno (0-23) → ciclo giornaliero
    df["hour"] = df[start_col].dt.hour
    angle_day_start = 2 * np.pi * df["hour"] / 24
    df["start_time_sin"] = np.sin(angle_day_start)
    df["start_time_cos"] = np.cos(angle_day_start)

    df["hour_end"] = df[end_col].dt.hour
    angle_day_end = 2 * np.pi * df["hour_end"] / 24
    df["end_time_sin"] = np.sin(angle_day_end)
    df["end_time_cos"] = np.cos(angle_day_end)

    # Durata in minuti
    df["duration_minutes"] = (df[end_col] - df[start_col]).dt.total_seconds() / 60

    # Giorno della settimana (0=Mon..6=Sun) → ciclo settimanale
    dayofweek = df[start_col].dt.dayofweek
    angle_week = 2 * np.pi * dayofweek / 7
    df["dow_sin"] = np.sin(angle_week)
    df["dow_cos"] = np.cos(angle_week)

    # Giorno dell’anno (1-365) → ciclo annuale
    dayofyear = df[start_col].dt.dayofyear
    angle_year = 2 * np.pi * dayofyear / 365
    df["doy_sin"] = np.sin(angle_year)
    df["doy_cos"] = np.cos(angle_year)

    # Rimuovo colonne temporali e variabili ausiliarie
    df = df.drop(columns=[start_col, end_col, "hour", "hour_end", "day", "month"])
    return df

embedding_cols = ['highway_embeddings']

df_final = encode_time_features(df_encoded)
df_final.drop(columns=['type_of_TTT'], inplace=True)
for emb_col in embedding_cols:
    df_final = spezza_serie_in_colonne(df_final, emb_col, prefix=f'{emb_col}_')
df_final.shape

# Salvataggio DataFrame finale
df_path = os.path.join(exp_dir, f"dataframe_{sensor_name}")
os.makedirs(df_path, exist_ok=True)
save_pkl(df_final, os.path.join(df_path, f"filtered_dataframe.pkl"))
# Out:
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/dataframe_METRO814/filtered_dataframe.pkl

# %%
for ttt in df_final.TTT[10:20]:
    plt.plot(ttt)
    plt.title("Esempi di TTT ARPAT")
    plt.xlabel("Ora del Giorno")
    plt.ylabel("Valore TTT")

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

def series_to_2d_array(series, output_dim=24):
    arr = np.stack(series.apply(lambda x: np.array(x, dtype=np.float32)))
    if arr.shape[1] != output_dim:
        raise ValueError(f"Ogni elemento deve avere {output_dim} valori, trovato {arr.shape[1]}")
    return arr

 # Separazione delle feature e del target
X = df_final.drop(columns=['TTT'])
y = df_final['TTT']

X_np = X.to_numpy().astype(np.float32)
y_np = series_to_2d_array(y, output_dim=24)

# Calcolo deviazione standard per ogni serie
std_scores = np.std(y_np, axis=1)

std_scores_log = np.log1p(std_scores)  # log(1+x) per evitare problemi con valori vicini a 0

std_scores_normalized = (std_scores_log - np.min(std_scores_log)) / (np.max(std_scores_log) - np.min(std_scores_log))

# Creo bin basati sui quantili
bins = np.array([0.0, 0.4, 0.8, 1.0])
std_bins = np.digitize(std_scores_normalized, bins)

# Primo split: train (80%) vs temp (20%)
# Passo anche std_bins per poter stratificare
X_train, X_test, y_train, y_test = train_test_split(
    X_np, y_np,
    test_size=0.2,
    random_state=42,
    stratify=std_bins, 
    shuffle=True
)

print(f"Train size: {X_train.shape}, {y_train.shape}")
print(f"Test size: {X_test.shape}, {y_test.shape}")

# Debug prints
print(f"Final shapes:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

# Scaler per input
scaler_X = MinMaxScaler()
X_train = scaler_X.fit_transform(X_train)
X_test  = scaler_X.transform(X_test)

# Scaler per output (se serve normalizzare anche y)
scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(y_train)
y_test  = scaler_y.transform(y_test)

#cartella salvataggio train e test
path = os.path.join(exp_dir, "train_test_data")
os.makedirs(path, exist_ok=True)

#  === Salvataggio dataset e scaler in formato .pkl ===
save_pkl(scaler_X.inverse_transform(X_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_X.inverse_transform(X_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_test_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_test_unscaled_{sensor_name}.pkl"))

save_pkl(X_train, os.path.join(exp_dir, "X_train.pkl"))
save_pkl(y_train, os.path.join(exp_dir, "y_train.pkl"))
save_pkl(X_test, os.path.join(exp_dir, "X_test.pkl"))
save_pkl(y_test, os.path.join(exp_dir, "y_test.pkl"))

save_pkl(scaler_X, os.path.join(exp_dir, "scaler_X.pkl"))
save_pkl(scaler_y, os.path.join(exp_dir, "scaler_y.pkl"))

print("Scaler salvati.")

print("\nTutti i file sono stati salvati correttamente.")
print(f"Percorso cartella: {os.path.abspath(exp_dir)}")
# Out:
# Train size: (72, 28), (72, 24)
# Test size: (18, 28), (18, 24)
# Final shapes:
# X_train: (72, 28)
# y_train: (72, 24)
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_train_unscaled_METRO814.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_train_unscaled_METRO814.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_test_unscaled_METRO814.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_test_unscaled_METRO814.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/X_train.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/y_train.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/X_test.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/y_test.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/scaler_X.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/scaler_y.pkl
# Scaler salvati.
#
# Tutti i file sono stati salvati correttamente.
# Percorso cartella: /Users/lapotinacci/thesis/Federated_Sys/RISULTATI/2025-11-29/esperimento_METRO814_16-04-27

# %%
# === Costruisci i path ===
path_X_train = os.path.join(exp_dir, "X_train.pkl")
path_y_train = os.path.join(exp_dir, "y_train.pkl")
path_X_test  = os.path.join(exp_dir, "X_test.pkl")
path_y_test  = os.path.join(exp_dir, "y_test.pkl")

path_scaler_X = os.path.join(exp_dir, "scaler_X.pkl")
path_scaler_y = os.path.join(exp_dir, "scaler_y.pkl")

# === Ricaricamento ===
X_train = load_pkl(path_X_train)
y_train = load_pkl(path_y_train)
X_test  = load_pkl(path_X_test)
y_test  = load_pkl(path_y_test)


scaler_X = load_pkl(path_scaler_X)
scaler_y = load_pkl(path_scaler_y)

print("Shapes ricostruite:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

print("\nScaler caricati:")
print("scaler_X:", type(scaler_X))
print("scaler_y:", type(scaler_y))
# Out:
# Shapes ricostruite:
# X_train: (72, 28)
# y_train: (72, 24)
# X_test: (18, 28)
# y_test: (18, 24)
#
# Scaler caricati:
# scaler_X: <class 'sklearn.preprocessing._data.MinMaxScaler'>
# scaler_y: <class 'sklearn.preprocessing._data.MinMaxScaler'>

# %% [markdown]
# # modelli

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers # type: ignore
from tensorflow.keras.layers import Dropout # type: ignore
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
def save_prediction_plots(y_true, y_pred, output_dir, prefix="pred_plot"):
    os.makedirs(output_dir, exist_ok=True)

    n = len(y_true)
    print(f"Salvo {n} plot in: {output_dir}")

    for i in range(n):
        plt.figure(figsize=(8, 3))
        plt.plot(y_true[i], label="True")
        plt.plot(y_pred[i], label="Pred")
        plt.legend()
        plt.tight_layout()

        filename = f"{prefix}_{i+1}.png"
        path = os.path.join(output_dir, filename)

        plt.savefig(path)
        plt.close()

    print("Plot salvati correttamente.")

# %%
# Definizione modello DNN
def build_model(input_shape: tuple, output_shape: tuple):
    model = models.Sequential([
        layers.Dense(128, activation = "relu", input_shape=input_shape),
        Dropout(0.0),
        layers.Dense(output_shape, 'linear')
    ])
    model.compile(
    optimizer=optimizers.AdamW(learning_rate=0.0129, weight_decay=0.0148),
    loss= 'mse',
    metrics=['mae'],
    )
    return model

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',      # metrica da monitorare, es. val_loss o val_mae
    patience=50,             # numero di epoche senza miglioramento prima di fermare
    restore_best_weights=True,  # ripristina i pesi migliori trovati
    verbose = 1
)

# Training del modello
model = build_model((X_test.shape[1],), y_test.shape[1])
history = model.fit(
    X_train, y_train,
    epochs=1000,
    batch_size=32,
    callbacks = [early_stop],
    validation_split = 0.2,
    verbose=1
    )

'''print("y_train min/max:", y_train_np.min(), y_train_np.max())
print("y_pred min/max (scaled):", y_pred.min(), y_pred.max())
y_pred_rescaled = scaler_y.inverse_transform(y_pred)
print("y_pred_rescaled min/max:", y_pred_rescaled.min(), y_pred_rescaled.max())'''

if not os.path.exists(os.path.join(exp_dir, "model")):
    os.makedirs(os.path.join(exp_dir, "model"))
    model.save(os.path.join(exp_dir, "model", "NO2_MAREMMA_model.keras"))
# Out:
# Epoch 1/1000
# /Users/lapotinacci/thesis/Federated_Sys/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.3141 - mae: 0.4334 - val_loss: 0.1012 - val_mae: 0.2589
# Epoch 2/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1056 - mae: 0.2684 - val_loss: 0.0877 - val_mae: 0.2522
# Epoch 3/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0783 - mae: 0.2351 - val_loss: 0.0542 - val_mae: 0.1875
# Epoch 4/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0489 - mae: 0.1742 - val_loss: 0.0438 - val_mae: 0.1587
# Epoch 5/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0446 - mae: 0.1608 - val_loss: 0.0366 - val_mae: 0.1480
# Epoch 6/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0364 - mae: 0.1475 - val_loss: 0.0253 - val_mae: 0.1237
# Epoch 7/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0248 - mae: 0.1224 - val_loss: 0.0232 - val_mae: 0.1200
# Epoch 8/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0228 - mae: 0.1188 - val_loss: 0.0207 - val_mae: 0.1148
# Epoch 9/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0191 - mae: 0.1098 - val_loss: 0.0162 - val_mae: 0.1004
# Epoch 10/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0152 - mae: 0.0964 - val_loss: 0.0150 - val_mae: 0.0945
# Epoch 11/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0144 - mae: 0.0934 - val_loss: 0.0132 - val_mae: 0.0893
# Epoch 12/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0120 - mae: 0.0851 - val_loss: 0.0110 - val_mae: 0.0829
# Epoch 13/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0098 - mae: 0.0772 - val_loss: 0.0095 - val_mae: 0.0775
# Epoch 14/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0081 - mae: 0.0707 - val_loss: 0.0069 - val_mae: 0.0664
# Epoch 15/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0060 - mae: 0.0609 - val_loss: 0.0055 - val_mae: 0.0596
# Epoch 16/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0050 - mae: 0.0567 - val_loss: 0.0045 - val_mae: 0.0546
# Epoch 17/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0043 - mae: 0.0525 - val_loss: 0.0035 - val_mae: 0.0471
# Epoch 18/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0033 - mae: 0.0456 - val_loss: 0.0030 - val_mae: 0.0437
# Epoch 19/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - mae: 0.0417 - val_loss: 0.0024 - val_mae: 0.0403
# Epoch 20/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0020 - mae: 0.0368 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 21/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0018 - mae: 0.0343 - val_loss: 0.0017 - val_mae: 0.0344
# Epoch 22/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0015 - mae: 0.0313 - val_loss: 0.0013 - val_mae: 0.0286
# Epoch 23/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0011 - mae: 0.0267 - val_loss: 0.0010 - val_mae: 0.0252
# Epoch 24/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 9.3180e-04 - mae: 0.0241 - val_loss: 8.5306e-04 - val_mae: 0.0232
# Epoch 25/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8.2380e-04 - mae: 0.0228 - val_loss: 7.4522e-04 - val_mae: 0.0216
# Epoch 26/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 7.4583e-04 - mae: 0.0218 - val_loss: 6.4156e-04 - val_mae: 0.0203
# Epoch 27/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.4795e-04 - mae: 0.0207 - val_loss: 5.4269e-04 - val_mae: 0.0181
# Epoch 28/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.4114e-04 - mae: 0.0181 - val_loss: 4.5083e-04 - val_mae: 0.0159
# Epoch 29/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.4341e-04 - mae: 0.0160 - val_loss: 3.7650e-04 - val_mae: 0.0148
# Epoch 30/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.7561e-04 - mae: 0.0151 - val_loss: 3.4535e-04 - val_mae: 0.0146
# Epoch 31/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.3844e-04 - mae: 0.0146 - val_loss: 2.9810e-04 - val_mae: 0.0137
# Epoch 32/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.8402e-04 - mae: 0.0135 - val_loss: 2.7559e-04 - val_mae: 0.0134
# Epoch 33/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.4962e-04 - mae: 0.0126 - val_loss: 2.6162e-04 - val_mae: 0.0125
# Epoch 34/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.2512e-04 - mae: 0.0116 - val_loss: 2.4856e-04 - val_mae: 0.0119
# Epoch 35/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1384e-04 - mae: 0.0113 - val_loss: 2.1769e-04 - val_mae: 0.0113
# Epoch 36/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.0194e-04 - mae: 0.0111 - val_loss: 1.9192e-04 - val_mae: 0.0104
# Epoch 37/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8219e-04 - mae: 0.0101 - val_loss: 1.8057e-04 - val_mae: 0.0097
# Epoch 38/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.5928e-04 - mae: 0.0093 - val_loss: 1.7238e-04 - val_mae: 0.0095
# Epoch 39/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.4642e-04 - mae: 0.0090 - val_loss: 1.5254e-04 - val_mae: 0.0088
# Epoch 40/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.3381e-04 - mae: 0.0085 - val_loss: 1.3459e-04 - val_mae: 0.0083
# Epoch 41/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2488e-04 - mae: 0.0082 - val_loss: 1.2459e-04 - val_mae: 0.0080
# Epoch 42/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1067e-04 - mae: 0.0077 - val_loss: 1.1239e-04 - val_mae: 0.0075
# Epoch 43/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 9.9305e-05 - mae: 0.0073 - val_loss: 1.0223e-04 - val_mae: 0.0072
# Epoch 44/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.5397e-05 - mae: 0.0073 - val_loss: 8.8902e-05 - val_mae: 0.0067
# Epoch 45/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.5587e-05 - mae: 0.0068 - val_loss: 8.2466e-05 - val_mae: 0.0063
# Epoch 46/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.7716e-05 - mae: 0.0063 - val_loss: 7.7947e-05 - val_mae: 0.0061
# Epoch 47/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.1952e-05 - mae: 0.0061 - val_loss: 7.2836e-05 - val_mae: 0.0059
# Epoch 48/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.0595e-05 - mae: 0.0060 - val_loss: 6.7862e-05 - val_mae: 0.0056
# Epoch 49/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.1742e-05 - mae: 0.0056 - val_loss: 6.7529e-05 - val_mae: 0.0055
# Epoch 50/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 6.0727e-05 - mae: 0.0054 - val_loss: 6.1421e-05 - val_mae: 0.0050
# Epoch 51/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 5.3629e-05 - mae: 0.0050 - val_loss: 5.6829e-05 - val_mae: 0.0050
# Epoch 52/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.3574e-05 - mae: 0.0052 - val_loss: 5.2489e-05 - val_mae: 0.0048
# Epoch 53/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.8268e-05 - mae: 0.0049 - val_loss: 4.7402e-05 - val_mae: 0.0045
# Epoch 54/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3751e-05 - mae: 0.0046 - val_loss: 4.5246e-05 - val_mae: 0.0045
# Epoch 55/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.0980e-05 - mae: 0.0044 - val_loss: 4.2946e-05 - val_mae: 0.0044
# Epoch 56/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.8325e-05 - mae: 0.0043 - val_loss: 4.0249e-05 - val_mae: 0.0042
# Epoch 57/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.6488e-05 - mae: 0.0041 - val_loss: 3.7160e-05 - val_mae: 0.0040
# Epoch 58/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.2899e-05 - mae: 0.0039 - val_loss: 3.5715e-05 - val_mae: 0.0038
# Epoch 59/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.1527e-05 - mae: 0.0037 - val_loss: 3.1796e-05 - val_mae: 0.0036
# Epoch 60/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.9229e-05 - mae: 0.0037 - val_loss: 3.0009e-05 - val_mae: 0.0036
# Epoch 61/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.6976e-05 - mae: 0.0035 - val_loss: 2.8850e-05 - val_mae: 0.0034
# Epoch 62/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5543e-05 - mae: 0.0033 - val_loss: 2.7406e-05 - val_mae: 0.0032
# Epoch 63/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5353e-05 - mae: 0.0033 - val_loss: 2.4667e-05 - val_mae: 0.0031
# Epoch 64/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.2154e-05 - mae: 0.0031 - val_loss: 2.3466e-05 - val_mae: 0.0030
# Epoch 65/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.0656e-05 - mae: 0.0029 - val_loss: 2.2462e-05 - val_mae: 0.0029
# Epoch 66/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.9372e-05 - mae: 0.0029 - val_loss: 1.9926e-05 - val_mae: 0.0028
# Epoch 67/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8412e-05 - mae: 0.0028 - val_loss: 1.8397e-05 - val_mae: 0.0026
# Epoch 68/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8221e-05 - mae: 0.0028 - val_loss: 1.8338e-05 - val_mae: 0.0026
# Epoch 69/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.5942e-05 - mae: 0.0026 - val_loss: 1.6933e-05 - val_mae: 0.0025
# Epoch 70/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.5190e-05 - mae: 0.0025 - val_loss: 1.5690e-05 - val_mae: 0.0024
# Epoch 71/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3799e-05 - mae: 0.0024 - val_loss: 1.4788e-05 - val_mae: 0.0024
# Epoch 72/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.2956e-05 - mae: 0.0023 - val_loss: 1.3449e-05 - val_mae: 0.0023
# Epoch 73/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.2494e-05 - mae: 0.0023 - val_loss: 1.2535e-05 - val_mae: 0.0022
# Epoch 74/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1348e-05 - mae: 0.0022 - val_loss: 1.2210e-05 - val_mae: 0.0021
# Epoch 75/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0907e-05 - mae: 0.0021 - val_loss: 1.1265e-05 - val_mae: 0.0020
# Epoch 76/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.9938e-06 - mae: 0.0021 - val_loss: 1.0792e-05 - val_mae: 0.0020
# Epoch 77/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.5573e-06 - mae: 0.0020 - val_loss: 9.9703e-06 - val_mae: 0.0019
# Epoch 78/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.8705e-06 - mae: 0.0019 - val_loss: 9.3499e-06 - val_mae: 0.0019
# Epoch 79/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 8.3747e-06 - mae: 0.0019 - val_loss: 8.6692e-06 - val_mae: 0.0018
# Epoch 80/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.9434e-06 - mae: 0.0018 - val_loss: 8.4637e-06 - val_mae: 0.0018
# Epoch 81/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.3363e-06 - mae: 0.0017 - val_loss: 7.8539e-06 - val_mae: 0.0017
# Epoch 82/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.8466e-06 - mae: 0.0017 - val_loss: 7.3408e-06 - val_mae: 0.0016
# Epoch 83/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.4113e-06 - mae: 0.0016 - val_loss: 6.9596e-06 - val_mae: 0.0016
# Epoch 84/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.0498e-06 - mae: 0.0016 - val_loss: 6.6072e-06 - val_mae: 0.0016
# Epoch 85/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.6591e-06 - mae: 0.0015 - val_loss: 6.2803e-06 - val_mae: 0.0015
# Epoch 86/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.3248e-06 - mae: 0.0015 - val_loss: 5.8714e-06 - val_mae: 0.0015
# Epoch 87/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.0232e-06 - mae: 0.0014 - val_loss: 5.4271e-06 - val_mae: 0.0014
# Epoch 88/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.6901e-06 - mae: 0.0014 - val_loss: 5.1156e-06 - val_mae: 0.0014
# Epoch 89/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.4725e-06 - mae: 0.0014 - val_loss: 4.7489e-06 - val_mae: 0.0013
# Epoch 90/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 4.2093e-06 - mae: 0.0013 - val_loss: 4.5694e-06 - val_mae: 0.0013
# Epoch 91/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.9475e-06 - mae: 0.0013 - val_loss: 4.2166e-06 - val_mae: 0.0012
# Epoch 92/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.7148e-06 - mae: 0.0012 - val_loss: 3.9461e-06 - val_mae: 0.0012
# Epoch 93/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.4547e-06 - mae: 0.0012 - val_loss: 3.7697e-06 - val_mae: 0.0012
# Epoch 94/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.3023e-06 - mae: 0.0012 - val_loss: 3.5261e-06 - val_mae: 0.0011
# Epoch 95/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.0720e-06 - mae: 0.0011 - val_loss: 3.3713e-06 - val_mae: 0.0011
# Epoch 96/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.9205e-06 - mae: 0.0011 - val_loss: 3.1625e-06 - val_mae: 0.0011
# Epoch 97/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2.7256e-06 - mae: 0.0010 - val_loss: 2.9402e-06 - val_mae: 0.0010
# Epoch 98/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.6431e-06 - mae: 0.0010 - val_loss: 2.7025e-06 - val_mae: 9.9061e-04
# Epoch 99/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.4368e-06 - mae: 0.0010 - val_loss: 2.6326e-06 - val_mae: 9.7447e-04
# Epoch 100/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.3514e-06 - mae: 9.7669e-04 - val_loss: 2.4950e-06 - val_mae: 9.4908e-04
# Epoch 101/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.2158e-06 - mae: 9.5132e-04 - val_loss: 2.3258e-06 - val_mae: 9.2476e-04
# Epoch 102/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.0651e-06 - mae: 9.1909e-04 - val_loss: 2.2193e-06 - val_mae: 8.9100e-04
# Epoch 103/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.9722e-06 - mae: 8.8550e-04 - val_loss: 2.1392e-06 - val_mae: 8.6849e-04
# Epoch 104/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.9085e-06 - mae: 8.8582e-04 - val_loss: 1.9234e-06 - val_mae: 8.3805e-04
# Epoch 105/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.7317e-06 - mae: 8.5268e-04 - val_loss: 1.8584e-06 - val_mae: 8.4338e-04
# Epoch 106/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.6468e-06 - mae: 8.3496e-04 - val_loss: 1.7341e-06 - val_mae: 7.9404e-04
# Epoch 107/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.5720e-06 - mae: 8.0605e-04 - val_loss: 1.6637e-06 - val_mae: 7.7602e-04
# Epoch 108/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5088e-06 - mae: 7.8172e-04 - val_loss: 1.5819e-06 - val_mae: 7.6091e-04
# Epoch 109/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.3954e-06 - mae: 7.6309e-04 - val_loss: 1.4552e-06 - val_mae: 7.3448e-04
# Epoch 110/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.3368e-06 - mae: 7.5637e-04 - val_loss: 1.3770e-06 - val_mae: 7.1830e-04
# Epoch 111/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2334e-06 - mae: 7.1816e-04 - val_loss: 1.3286e-06 - val_mae: 7.1203e-04
# Epoch 112/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.1651e-06 - mae: 6.9665e-04 - val_loss: 1.2639e-06 - val_mae: 6.7957e-04
# Epoch 113/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.1213e-06 - mae: 6.7887e-04 - val_loss: 1.2000e-06 - val_mae: 6.6273e-04
# Epoch 114/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0516e-06 - mae: 6.5345e-04 - val_loss: 1.1030e-06 - val_mae: 6.4382e-04
# Epoch 115/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.9636e-07 - mae: 6.5085e-04 - val_loss: 9.9069e-07 - val_mae: 6.1962e-04
# Epoch 116/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 9.6191e-07 - mae: 6.5574e-04 - val_loss: 9.4067e-07 - val_mae: 6.0831e-04
# Epoch 117/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8.8842e-07 - mae: 6.2427e-04 - val_loss: 9.2290e-07 - val_mae: 5.9307e-04
# Epoch 118/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 8.3546e-07 - mae: 5.9526e-04 - val_loss: 9.2423e-07 - val_mae: 5.9002e-04
# Epoch 119/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8.0916e-07 - mae: 5.8086e-04 - val_loss: 8.6886e-07 - val_mae: 5.7579e-04
# Epoch 120/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.7488e-07 - mae: 5.7244e-04 - val_loss: 7.7222e-07 - val_mae: 5.4348e-04
# Epoch 121/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 7.1910e-07 - mae: 5.6083e-04 - val_loss: 7.1336e-07 - val_mae: 5.2749e-04
# Epoch 122/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.8158e-07 - mae: 5.5485e-04 - val_loss: 6.9374e-07 - val_mae: 5.2256e-04
# Epoch 123/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.3918e-07 - mae: 5.2906e-04 - val_loss: 6.9815e-07 - val_mae: 5.1923e-04
# Epoch 124/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.1126e-07 - mae: 5.1071e-04 - val_loss: 6.6231e-07 - val_mae: 5.0671e-04
# Epoch 125/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.8591e-07 - mae: 5.0488e-04 - val_loss: 6.0128e-07 - val_mae: 4.7998e-04
# Epoch 126/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.5049e-07 - mae: 4.8692e-04 - val_loss: 5.6157e-07 - val_mae: 4.6571e-04
# Epoch 127/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.2197e-07 - mae: 4.8079e-04 - val_loss: 5.3521e-07 - val_mae: 4.5956e-04
# Epoch 128/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.0477e-07 - mae: 4.7258e-04 - val_loss: 5.2801e-07 - val_mae: 4.5784e-04
# Epoch 129/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.7551e-07 - mae: 4.5808e-04 - val_loss: 4.7713e-07 - val_mae: 4.3416e-04
# Epoch 130/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.5131e-07 - mae: 4.4870e-04 - val_loss: 4.5620e-07 - val_mae: 4.2297e-04
# Epoch 131/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.3403e-07 - mae: 4.3572e-04 - val_loss: 4.4548e-07 - val_mae: 4.1752e-04
# Epoch 132/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 4.1252e-07 - mae: 4.2708e-04 - val_loss: 4.1347e-07 - val_mae: 4.0758e-04
# Epoch 133/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.9224e-07 - mae: 4.2032e-04 - val_loss: 3.9876e-07 - val_mae: 4.0065e-04
# Epoch 134/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.6957e-07 - mae: 4.0651e-04 - val_loss: 3.6523e-07 - val_mae: 3.8216e-04
# Epoch 135/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.5061e-07 - mae: 3.9660e-04 - val_loss: 3.5516e-07 - val_mae: 3.7426e-04
# Epoch 136/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.3391e-07 - mae: 3.8428e-04 - val_loss: 3.4715e-07 - val_mae: 3.7260e-04
# Epoch 137/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.2440e-07 - mae: 3.7927e-04 - val_loss: 3.3314e-07 - val_mae: 3.6625e-04
# Epoch 138/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.0710e-07 - mae: 3.7076e-04 - val_loss: 3.0818e-07 - val_mae: 3.5430e-04
# Epoch 139/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.9280e-07 - mae: 3.6659e-04 - val_loss: 2.8880e-07 - val_mae: 3.4432e-04
# Epoch 140/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.8854e-07 - mae: 3.6302e-04 - val_loss: 2.7820e-07 - val_mae: 3.3543e-04
# Epoch 141/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.7254e-07 - mae: 3.5012e-04 - val_loss: 2.8338e-07 - val_mae: 3.3949e-04
# Epoch 142/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.6079e-07 - mae: 3.4456e-04 - val_loss: 2.6984e-07 - val_mae: 3.3595e-04
# Epoch 143/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.5002e-07 - mae: 3.3941e-04 - val_loss: 2.5224e-07 - val_mae: 3.2211e-04
# Epoch 144/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.3867e-07 - mae: 3.2868e-04 - val_loss: 2.4186e-07 - val_mae: 3.1204e-04
# Epoch 145/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 2.2968e-07 - mae: 3.2318e-04 - val_loss: 2.2481e-07 - val_mae: 3.0794e-04
# Epoch 146/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.1741e-07 - mae: 3.1867e-04 - val_loss: 2.2278e-07 - val_mae: 3.0913e-04
# Epoch 147/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2.1085e-07 - mae: 3.1352e-04 - val_loss: 2.1218e-07 - val_mae: 2.9850e-04
# Epoch 148/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2.0326e-07 - mae: 3.0934e-04 - val_loss: 1.9752e-07 - val_mae: 2.8936e-04
# Epoch 149/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 2.0108e-07 - mae: 3.0566e-04 - val_loss: 1.9758e-07 - val_mae: 2.8963e-04
# Epoch 150/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.8529e-07 - mae: 2.9421e-04 - val_loss: 1.8012e-07 - val_mae: 2.7901e-04
# Epoch 151/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.8175e-07 - mae: 2.9710e-04 - val_loss: 1.7166e-07 - val_mae: 2.7325e-04
# Epoch 152/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.7237e-07 - mae: 2.8629e-04 - val_loss: 1.7182e-07 - val_mae: 2.6997e-04
# Epoch 153/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.7428e-07 - mae: 2.8358e-04 - val_loss: 1.7187e-07 - val_mae: 2.7128e-04
# Epoch 154/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.6656e-07 - mae: 2.7938e-04 - val_loss: 1.5295e-07 - val_mae: 2.5969e-04
# Epoch 155/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.5840e-07 - mae: 2.7487e-04 - val_loss: 1.5189e-07 - val_mae: 2.5530e-04
# Epoch 156/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.5072e-07 - mae: 2.6860e-04 - val_loss: 1.4759e-07 - val_mae: 2.5635e-04
# Epoch 157/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.4773e-07 - mae: 2.6896e-04 - val_loss: 1.4531e-07 - val_mae: 2.5469e-04
# Epoch 158/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.3940e-07 - mae: 2.5873e-04 - val_loss: 1.3423e-07 - val_mae: 2.4327e-04
# Epoch 159/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.3368e-07 - mae: 2.5415e-04 - val_loss: 1.3199e-07 - val_mae: 2.4040e-04
# Epoch 160/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.2670e-07 - mae: 2.4418e-04 - val_loss: 1.2527e-07 - val_mae: 2.3703e-04
# Epoch 161/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.2452e-07 - mae: 2.4490e-04 - val_loss: 1.2159e-07 - val_mae: 2.3382e-04
# Epoch 162/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.1903e-07 - mae: 2.3930e-04 - val_loss: 1.2103e-07 - val_mae: 2.3181e-04
# Epoch 163/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.1315e-07 - mae: 2.3366e-04 - val_loss: 1.1295e-07 - val_mae: 2.2687e-04
# Epoch 164/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.1239e-07 - mae: 2.3435e-04 - val_loss: 1.0746e-07 - val_mae: 2.2008e-04
# Epoch 165/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.0908e-07 - mae: 2.2949e-04 - val_loss: 1.0203e-07 - val_mae: 2.1508e-04
# Epoch 166/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.0564e-07 - mae: 2.2738e-04 - val_loss: 1.0360e-07 - val_mae: 2.1732e-04
# Epoch 167/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0348e-07 - mae: 2.2623e-04 - val_loss: 1.0363e-07 - val_mae: 2.1861e-04
# Epoch 168/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.0491e-07 - mae: 2.2854e-04 - val_loss: 9.4398e-08 - val_mae: 2.0885e-04
# Epoch 169/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.7574e-08 - mae: 2.1790e-04 - val_loss: 1.0292e-07 - val_mae: 2.1288e-04
# Epoch 170/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 9.5954e-08 - mae: 2.1286e-04 - val_loss: 9.1460e-08 - val_mae: 2.0849e-04
# Epoch 171/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 9.4850e-08 - mae: 2.2032e-04 - val_loss: 8.8452e-08 - val_mae: 2.0485e-04
# Epoch 172/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.9319e-08 - mae: 2.1267e-04 - val_loss: 8.7428e-08 - val_mae: 2.0169e-04
# Epoch 173/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8.7164e-08 - mae: 2.0852e-04 - val_loss: 8.6690e-08 - val_mae: 2.0306e-04
# Epoch 174/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.0590e-08 - mae: 2.1508e-04 - val_loss: 8.0923e-08 - val_mae: 1.9468e-04
# Epoch 175/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.6568e-08 - mae: 2.0997e-04 - val_loss: 8.4712e-08 - val_mae: 1.9771e-04
# Epoch 176/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.2958e-08 - mae: 2.0465e-04 - val_loss: 8.1955e-08 - val_mae: 1.9595e-04
# Epoch 177/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 8.6686e-08 - mae: 2.0704e-04 - val_loss: 7.7466e-08 - val_mae: 1.9327e-04
# Epoch 178/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.0309e-08 - mae: 2.0490e-04 - val_loss: 7.3154e-08 - val_mae: 1.8485e-04
# Epoch 179/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 7.5145e-08 - mae: 1.9409e-04 - val_loss: 7.5747e-08 - val_mae: 1.8567e-04
# Epoch 180/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 7.5711e-08 - mae: 1.9367e-04 - val_loss: 7.2072e-08 - val_mae: 1.8514e-04
# Epoch 181/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 7.5337e-08 - mae: 1.9567e-04 - val_loss: 6.8330e-08 - val_mae: 1.7897e-04
# Epoch 182/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 7.6819e-08 - mae: 1.9364e-04 - val_loss: 7.1403e-08 - val_mae: 1.8084e-04
# Epoch 183/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 6.9533e-08 - mae: 1.8541e-04 - val_loss: 6.6506e-08 - val_mae: 1.7640e-04
# Epoch 184/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 7.3404e-08 - mae: 1.8950e-04 - val_loss: 6.8001e-08 - val_mae: 1.7537e-04
# Epoch 185/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.6389e-08 - mae: 1.7839e-04 - val_loss: 6.4233e-08 - val_mae: 1.7315e-04
# Epoch 186/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.6746e-08 - mae: 1.8528e-04 - val_loss: 6.1291e-08 - val_mae: 1.6931e-04
# Epoch 187/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6.4152e-08 - mae: 1.7692e-04 - val_loss: 6.3156e-08 - val_mae: 1.7005e-04
# Epoch 188/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 7.0896e-08 - mae: 1.8610e-04 - val_loss: 5.8855e-08 - val_mae: 1.6655e-04
# Epoch 189/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 6.9608e-08 - mae: 1.8101e-04 - val_loss: 6.0396e-08 - val_mae: 1.6700e-04
# Epoch 190/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 6.7511e-08 - mae: 1.8006e-04 - val_loss: 6.7571e-08 - val_mae: 1.7359e-04
# Epoch 191/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 6.2926e-08 - mae: 1.7577e-04 - val_loss: 6.2578e-08 - val_mae: 1.6964e-04
# Epoch 192/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.9741e-08 - mae: 1.6883e-04 - val_loss: 5.7035e-08 - val_mae: 1.6439e-04
# Epoch 193/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.3156e-08 - mae: 1.7805e-04 - val_loss: 5.4784e-08 - val_mae: 1.5900e-04
# Epoch 194/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 5.6498e-08 - mae: 1.6500e-04 - val_loss: 5.0977e-08 - val_mae: 1.5620e-04
# Epoch 195/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.5042e-08 - mae: 1.6778e-04 - val_loss: 5.5446e-08 - val_mae: 1.6147e-04
# Epoch 196/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.6437e-08 - mae: 1.6681e-04 - val_loss: 5.9540e-08 - val_mae: 1.6219e-04
# Epoch 197/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.1640e-08 - mae: 1.5513e-04 - val_loss: 5.0583e-08 - val_mae: 1.5605e-04
# Epoch 198/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.5984e-08 - mae: 1.6965e-04 - val_loss: 4.8499e-08 - val_mae: 1.5077e-04
# Epoch 199/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.1844e-08 - mae: 1.5991e-04 - val_loss: 5.1332e-08 - val_mae: 1.5233e-04
# Epoch 200/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.8378e-08 - mae: 1.5286e-04 - val_loss: 4.6153e-08 - val_mae: 1.4858e-04
# Epoch 201/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.0185e-08 - mae: 1.5868e-04 - val_loss: 4.8154e-08 - val_mae: 1.4941e-04
# Epoch 202/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.0607e-08 - mae: 1.5763e-04 - val_loss: 4.7363e-08 - val_mae: 1.4778e-04
# Epoch 203/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.6693e-08 - mae: 1.4754e-04 - val_loss: 4.2938e-08 - val_mae: 1.4124e-04
# Epoch 204/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.6465e-08 - mae: 1.5404e-04 - val_loss: 4.4201e-08 - val_mae: 1.4440e-04
# Epoch 205/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.5238e-08 - mae: 1.4947e-04 - val_loss: 4.4213e-08 - val_mae: 1.4035e-04
# Epoch 206/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 4.4148e-08 - mae: 1.4498e-04 - val_loss: 4.1869e-08 - val_mae: 1.4255e-04
# Epoch 207/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.2998e-08 - mae: 1.4878e-04 - val_loss: 4.2053e-08 - val_mae: 1.3939e-04
# Epoch 208/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.1504e-08 - mae: 1.4008e-04 - val_loss: 4.1731e-08 - val_mae: 1.3874e-04
# Epoch 209/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.2806e-08 - mae: 1.4668e-04 - val_loss: 4.0804e-08 - val_mae: 1.3925e-04
# Epoch 210/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.1442e-08 - mae: 1.4053e-04 - val_loss: 4.1503e-08 - val_mae: 1.3779e-04
# Epoch 211/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 4.2904e-08 - mae: 1.4475e-04 - val_loss: 4.3818e-08 - val_mae: 1.3990e-04
# Epoch 212/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 4.2131e-08 - mae: 1.4023e-04 - val_loss: 4.1019e-08 - val_mae: 1.3442e-04
# Epoch 213/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.7282e-08 - mae: 1.3417e-04 - val_loss: 4.2398e-08 - val_mae: 1.4142e-04
# Epoch 214/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.1203e-08 - mae: 1.4540e-04 - val_loss: 4.1536e-08 - val_mae: 1.3838e-04
# Epoch 215/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 3.8383e-08 - mae: 1.3720e-04 - val_loss: 3.5821e-08 - val_mae: 1.3094e-04
# Epoch 216/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.5782e-08 - mae: 1.3466e-04 - val_loss: 3.5008e-08 - val_mae: 1.2917e-04
# Epoch 217/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.5194e-08 - mae: 1.3307e-04 - val_loss: 3.6252e-08 - val_mae: 1.3074e-04
# Epoch 218/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.5584e-08 - mae: 1.3269e-04 - val_loss: 3.7448e-08 - val_mae: 1.3353e-04
# Epoch 219/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.6472e-08 - mae: 1.3656e-04 - val_loss: 3.5432e-08 - val_mae: 1.2661e-04
# Epoch 220/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.4582e-08 - mae: 1.2948e-04 - val_loss: 3.7247e-08 - val_mae: 1.2862e-04
# Epoch 221/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.4267e-08 - mae: 1.3000e-04 - val_loss: 3.4251e-08 - val_mae: 1.2976e-04
# Epoch 222/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.3955e-08 - mae: 1.3284e-04 - val_loss: 3.5967e-08 - val_mae: 1.2951e-04
# Epoch 223/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.5653e-08 - mae: 1.3311e-04 - val_loss: 3.4117e-08 - val_mae: 1.2707e-04
# Epoch 224/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.7446e-08 - mae: 1.3872e-04 - val_loss: 3.2437e-08 - val_mae: 1.2328e-04
# Epoch 225/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.3667e-08 - mae: 1.3053e-04 - val_loss: 3.2625e-08 - val_mae: 1.2208e-04
# Epoch 226/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 3.1126e-08 - mae: 1.2566e-04 - val_loss: 3.4061e-08 - val_mae: 1.2924e-04
# Epoch 227/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 3.3041e-08 - mae: 1.2947e-04 - val_loss: 3.6027e-08 - val_mae: 1.2912e-04
# Epoch 228/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 3.3306e-08 - mae: 1.3104e-04 - val_loss: 3.3882e-08 - val_mae: 1.2919e-04
# Epoch 229/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.3361e-08 - mae: 1.3220e-04 - val_loss: 3.2657e-08 - val_mae: 1.2411e-04
# Epoch 230/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.1978e-08 - mae: 1.2629e-04 - val_loss: 3.2445e-08 - val_mae: 1.2461e-04
# Epoch 231/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.1996e-08 - mae: 1.2825e-04 - val_loss: 3.0464e-08 - val_mae: 1.2259e-04
# Epoch 232/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 3.0485e-08 - mae: 1.2315e-04 - val_loss: 3.5495e-08 - val_mae: 1.2846e-04
# Epoch 233/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.4138e-08 - mae: 1.3225e-04 - val_loss: 3.1239e-08 - val_mae: 1.2292e-04
# Epoch 234/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.0653e-08 - mae: 1.2394e-04 - val_loss: 3.1176e-08 - val_mae: 1.1837e-04
# Epoch 235/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 3.1159e-08 - mae: 1.2544e-04 - val_loss: 3.1593e-08 - val_mae: 1.2311e-04
# Epoch 236/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.9645e-08 - mae: 1.2289e-04 - val_loss: 3.3260e-08 - val_mae: 1.2419e-04
# Epoch 237/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.1988e-08 - mae: 1.2252e-04 - val_loss: 3.2844e-08 - val_mae: 1.2490e-04
# Epoch 238/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 3.3435e-08 - mae: 1.3123e-04 - val_loss: 3.1198e-08 - val_mae: 1.2104e-04
# Epoch 239/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 3.2436e-08 - mae: 1.2393e-04 - val_loss: 3.0098e-08 - val_mae: 1.2033e-04
# Epoch 240/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 3.1007e-08 - mae: 1.2836e-04 - val_loss: 2.8201e-08 - val_mae: 1.1629e-04
# Epoch 241/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.9292e-08 - mae: 1.2233e-04 - val_loss: 3.2613e-08 - val_mae: 1.2519e-04
# Epoch 242/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.1203e-08 - mae: 1.2583e-04 - val_loss: 3.1152e-08 - val_mae: 1.2356e-04
# Epoch 243/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.1168e-08 - mae: 1.2836e-04 - val_loss: 3.0629e-08 - val_mae: 1.1928e-04
# Epoch 244/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.7838e-08 - mae: 1.1838e-04 - val_loss: 3.1645e-08 - val_mae: 1.2361e-04
# Epoch 245/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.0949e-08 - mae: 1.2729e-04 - val_loss: 2.9702e-08 - val_mae: 1.1156e-04
# Epoch 246/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.2162e-08 - mae: 1.2057e-04 - val_loss: 3.0784e-08 - val_mae: 1.1914e-04
# Epoch 247/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.7220e-08 - mae: 1.3784e-04 - val_loss: 3.2444e-08 - val_mae: 1.2514e-04
# Epoch 248/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.0215e-08 - mae: 1.2258e-04 - val_loss: 3.3667e-08 - val_mae: 1.2256e-04
# Epoch 249/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 3.5825e-08 - mae: 1.3343e-04 - val_loss: 3.3612e-08 - val_mae: 1.2868e-04
# Epoch 250/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.1839e-08 - mae: 1.2893e-04 - val_loss: 3.9365e-08 - val_mae: 1.3583e-04
# Epoch 251/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.8297e-08 - mae: 1.3904e-04 - val_loss: 3.7142e-08 - val_mae: 1.3511e-04
# Epoch 252/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.6362e-08 - mae: 1.3830e-04 - val_loss: 3.8721e-08 - val_mae: 1.3587e-04
# Epoch 253/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.4517e-08 - mae: 1.3372e-04 - val_loss: 5.1526e-08 - val_mae: 1.4869e-04
# Epoch 254/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.8080e-08 - mae: 1.5102e-04 - val_loss: 4.6052e-08 - val_mae: 1.4122e-04
# Epoch 255/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.8392e-08 - mae: 1.3600e-04 - val_loss: 4.3416e-08 - val_mae: 1.3569e-04
# Epoch 256/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.9559e-08 - mae: 1.3716e-04 - val_loss: 4.0555e-08 - val_mae: 1.3869e-04
# Epoch 257/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.5378e-08 - mae: 1.3551e-04 - val_loss: 3.2430e-08 - val_mae: 1.2413e-04
# Epoch 258/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.1825e-08 - mae: 1.2747e-04 - val_loss: 3.4391e-08 - val_mae: 1.2461e-04
# Epoch 259/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.1643e-08 - mae: 1.2527e-04 - val_loss: 3.4631e-08 - val_mae: 1.3081e-04
# Epoch 260/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.9778e-08 - mae: 1.4416e-04 - val_loss: 4.7460e-08 - val_mae: 1.4495e-04
# Epoch 261/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 4.1355e-08 - mae: 1.4348e-04 - val_loss: 3.6480e-08 - val_mae: 1.3300e-04
# Epoch 262/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.5498e-08 - mae: 1.3488e-04 - val_loss: 4.2605e-08 - val_mae: 1.3681e-04
# Epoch 263/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.7322e-08 - mae: 1.3666e-04 - val_loss: 3.9371e-08 - val_mae: 1.3460e-04
# Epoch 264/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.8617e-08 - mae: 1.3971e-04 - val_loss: 3.9111e-08 - val_mae: 1.3128e-04
# Epoch 265/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.4789e-08 - mae: 1.2996e-04 - val_loss: 3.5093e-08 - val_mae: 1.2717e-04
# Epoch 266/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.3231e-08 - mae: 1.2750e-04 - val_loss: 3.9058e-08 - val_mae: 1.3263e-04
# Epoch 267/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.4300e-08 - mae: 1.3013e-04 - val_loss: 3.1597e-08 - val_mae: 1.2367e-04
# Epoch 268/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.3379e-08 - mae: 1.3036e-04 - val_loss: 4.1726e-08 - val_mae: 1.3848e-04
# Epoch 269/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9634e-08 - mae: 1.4130e-04 - val_loss: 5.1077e-08 - val_mae: 1.5115e-04
# Epoch 270/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.7763e-08 - mae: 1.4970e-04 - val_loss: 3.8807e-08 - val_mae: 1.3212e-04
# Epoch 271/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 3.2453e-08 - mae: 1.2716e-04 - val_loss: 3.6546e-08 - val_mae: 1.3308e-04
# Epoch 272/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.8069e-08 - mae: 1.4045e-04 - val_loss: 5.1454e-08 - val_mae: 1.5105e-04
# Epoch 273/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.5188e-08 - mae: 1.4836e-04 - val_loss: 5.1757e-08 - val_mae: 1.5172e-04
# Epoch 274/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.0438e-08 - mae: 1.5867e-04 - val_loss: 6.0896e-08 - val_mae: 1.6168e-04
# Epoch 275/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.9912e-08 - mae: 1.5274e-04 - val_loss: 4.3887e-08 - val_mae: 1.4517e-04
# Epoch 276/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.2518e-08 - mae: 1.4291e-04 - val_loss: 3.7043e-08 - val_mae: 1.3433e-04
# Epoch 277/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.5161e-08 - mae: 1.3480e-04 - val_loss: 2.8615e-08 - val_mae: 1.2036e-04
# Epoch 278/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.9271e-08 - mae: 1.2395e-04 - val_loss: 2.9596e-08 - val_mae: 1.1552e-04
# Epoch 279/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.8217e-08 - mae: 1.1942e-04 - val_loss: 2.6295e-08 - val_mae: 1.1092e-04
# Epoch 280/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.5531e-08 - mae: 1.1208e-04 - val_loss: 2.7389e-08 - val_mae: 1.1372e-04
# Epoch 281/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.5493e-08 - mae: 1.1509e-04 - val_loss: 2.5950e-08 - val_mae: 1.1158e-04
# Epoch 282/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 2.6008e-08 - mae: 1.1581e-04 - val_loss: 2.5152e-08 - val_mae: 1.1038e-04
# Epoch 283/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.6201e-08 - mae: 1.1574e-04 - val_loss: 2.5889e-08 - val_mae: 1.1074e-04
# Epoch 284/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.5018e-08 - mae: 1.1544e-04 - val_loss: 2.5202e-08 - val_mae: 1.1266e-04
# Epoch 285/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.7202e-08 - mae: 1.1904e-04 - val_loss: 3.1109e-08 - val_mae: 1.1963e-04
# Epoch 286/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.8187e-08 - mae: 1.1931e-04 - val_loss: 2.8809e-08 - val_mae: 1.1760e-04
# Epoch 287/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.8321e-08 - mae: 1.1907e-04 - val_loss: 2.5521e-08 - val_mae: 1.0970e-04
# Epoch 288/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.4976e-08 - mae: 1.1460e-04 - val_loss: 2.5114e-08 - val_mae: 1.0969e-04
# Epoch 289/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.3367e-08 - mae: 1.0934e-04 - val_loss: 2.8563e-08 - val_mae: 1.1546e-04
# Epoch 290/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.5148e-08 - mae: 1.1356e-04 - val_loss: 3.1979e-08 - val_mae: 1.2312e-04
# Epoch 291/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 3.0267e-08 - mae: 1.2529e-04 - val_loss: 2.9741e-08 - val_mae: 1.1506e-04
# Epoch 292/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.7742e-08 - mae: 1.1691e-04 - val_loss: 2.7335e-08 - val_mae: 1.1374e-04
# Epoch 293/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.7605e-08 - mae: 1.1858e-04 - val_loss: 2.5006e-08 - val_mae: 1.1199e-04
# Epoch 294/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.8543e-08 - mae: 1.1956e-04 - val_loss: 2.6985e-08 - val_mae: 1.1311e-04
# Epoch 295/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.7760e-08 - mae: 1.1872e-04 - val_loss: 2.5842e-08 - val_mae: 1.1195e-04
# Epoch 296/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 2.7047e-08 - mae: 1.2036e-04 - val_loss: 2.6904e-08 - val_mae: 1.1139e-04
# Epoch 297/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.7434e-08 - mae: 1.1978e-04 - val_loss: 2.3526e-08 - val_mae: 1.0840e-04
# Epoch 298/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.2220e-08 - mae: 1.0741e-04 - val_loss: 2.7296e-08 - val_mae: 1.0990e-04
# Epoch 299/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.4648e-08 - mae: 1.1084e-04 - val_loss: 2.7771e-08 - val_mae: 1.1555e-04
# Epoch 300/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.6031e-08 - mae: 1.1535e-04 - val_loss: 2.6606e-08 - val_mae: 1.1094e-04
# Epoch 301/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.5209e-08 - mae: 1.1350e-04 - val_loss: 3.3097e-08 - val_mae: 1.2370e-04
# Epoch 302/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.0893e-08 - mae: 1.2469e-04 - val_loss: 3.6563e-08 - val_mae: 1.2698e-04
# Epoch 303/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.0015e-08 - mae: 1.2372e-04 - val_loss: 3.0397e-08 - val_mae: 1.1748e-04
# Epoch 304/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.0311e-08 - mae: 1.2146e-04 - val_loss: 3.8767e-08 - val_mae: 1.3081e-04
# Epoch 305/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.4996e-08 - mae: 1.2976e-04 - val_loss: 4.7788e-08 - val_mae: 1.4454e-04
# Epoch 306/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 4.2629e-08 - mae: 1.4450e-04 - val_loss: 4.5507e-08 - val_mae: 1.4299e-04
# Epoch 307/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.4095e-08 - mae: 1.2910e-04 - val_loss: 4.1204e-08 - val_mae: 1.3833e-04
# Epoch 308/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.5460e-08 - mae: 1.3055e-04 - val_loss: 3.5535e-08 - val_mae: 1.2693e-04
# Epoch 309/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.8889e-08 - mae: 1.2307e-04 - val_loss: 3.3932e-08 - val_mae: 1.2606e-04
# Epoch 310/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.4116e-08 - mae: 1.3043e-04 - val_loss: 2.9186e-08 - val_mae: 1.1367e-04
# Epoch 311/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.7263e-08 - mae: 1.1693e-04 - val_loss: 2.2935e-08 - val_mae: 1.0647e-04
# Epoch 312/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.2989e-08 - mae: 1.0805e-04 - val_loss: 2.3075e-08 - val_mae: 1.0642e-04
# Epoch 313/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.2593e-08 - mae: 1.0919e-04 - val_loss: 2.1714e-08 - val_mae: 1.0522e-04
# Epoch 314/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.0657e-08 - mae: 1.0434e-04 - val_loss: 2.3455e-08 - val_mae: 1.0579e-04
# Epoch 315/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.3575e-08 - mae: 1.1007e-04 - val_loss: 2.2968e-08 - val_mae: 1.0641e-04
# Epoch 316/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.5017e-08 - mae: 1.1407e-04 - val_loss: 2.4416e-08 - val_mae: 1.0935e-04
# Epoch 317/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.7107e-08 - mae: 1.1943e-04 - val_loss: 3.1198e-08 - val_mae: 1.2084e-04
# Epoch 318/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.8645e-08 - mae: 1.2180e-04 - val_loss: 2.3294e-08 - val_mae: 1.0590e-04
# Epoch 319/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.4532e-08 - mae: 1.1380e-04 - val_loss: 2.2346e-08 - val_mae: 1.0185e-04
# Epoch 320/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.4260e-08 - mae: 1.1245e-04 - val_loss: 1.9078e-08 - val_mae: 9.8863e-05
# Epoch 321/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.0941e-08 - mae: 1.0618e-04 - val_loss: 2.3373e-08 - val_mae: 1.1069e-04
# Epoch 322/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.4980e-08 - mae: 1.2070e-04 - val_loss: 6.3785e-08 - val_mae: 1.4960e-04
# Epoch 323/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.0958e-08 - mae: 1.6008e-04 - val_loss: 3.0045e-08 - val_mae: 1.3389e-04
# Epoch 324/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 2.8791e-08 - mae: 1.3170e-04 - val_loss: 2.8516e-08 - val_mae: 1.3094e-04
# Epoch 325/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.1786e-08 - mae: 1.3629e-04 - val_loss: 3.4751e-08 - val_mae: 1.3711e-04
# Epoch 326/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.3388e-08 - mae: 1.3752e-04 - val_loss: 3.0484e-08 - val_mae: 1.3134e-04
# Epoch 327/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.6063e-08 - mae: 1.2475e-04 - val_loss: 3.4454e-08 - val_mae: 1.3667e-04
# Epoch 328/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.3987e-08 - mae: 1.3502e-04 - val_loss: 2.5610e-08 - val_mae: 1.1409e-04
# Epoch 329/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.5596e-08 - mae: 1.1758e-04 - val_loss: 2.2129e-08 - val_mae: 1.1187e-04
# Epoch 330/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3041e-08 - mae: 1.1671e-04 - val_loss: 2.2848e-08 - val_mae: 1.1347e-04
# Epoch 331/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.4877e-08 - mae: 1.1750e-04 - val_loss: 2.1751e-08 - val_mae: 1.0946e-04
# Epoch 332/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.4293e-08 - mae: 1.1339e-04 - val_loss: 2.3426e-08 - val_mae: 1.1152e-04
# Epoch 333/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.6435e-08 - mae: 1.2156e-04 - val_loss: 2.7597e-08 - val_mae: 1.1262e-04
# Epoch 334/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.4392e-08 - mae: 1.1283e-04 - val_loss: 2.6869e-08 - val_mae: 1.1513e-04
# Epoch 335/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 2.5772e-08 - mae: 1.1815e-04 - val_loss: 2.9536e-08 - val_mae: 1.1598e-04
# Epoch 336/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.7607e-08 - mae: 1.2112e-04 - val_loss: 3.1315e-08 - val_mae: 1.2368e-04
# Epoch 337/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 3.0056e-08 - mae: 1.2687e-04 - val_loss: 3.1850e-08 - val_mae: 1.2039e-04
# Epoch 338/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.0955e-08 - mae: 1.2797e-04 - val_loss: 2.2734e-08 - val_mae: 1.0074e-04
# Epoch 339/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.9828e-08 - mae: 1.2244e-04 - val_loss: 2.0601e-08 - val_mae: 1.0361e-04
# Epoch 340/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.8158e-08 - mae: 1.2067e-04 - val_loss: 3.0632e-08 - val_mae: 1.2045e-04
# Epoch 341/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.5975e-08 - mae: 1.1573e-04 - val_loss: 3.1042e-08 - val_mae: 1.1773e-04
# Epoch 342/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.7501e-08 - mae: 1.1695e-04 - val_loss: 3.3522e-08 - val_mae: 1.1928e-04
# Epoch 343/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.2107e-08 - mae: 1.2639e-04 - val_loss: 2.7182e-08 - val_mae: 1.1647e-04
# Epoch 344/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.4588e-08 - mae: 1.1249e-04 - val_loss: 2.3556e-08 - val_mae: 1.0585e-04
# Epoch 345/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.0073e-08 - mae: 1.0374e-04 - val_loss: 2.4714e-08 - val_mae: 1.1266e-04
# Epoch 346/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2397e-08 - mae: 1.1126e-04 - val_loss: 2.5970e-08 - val_mae: 1.0493e-04
# Epoch 347/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.5194e-08 - mae: 1.0946e-04 - val_loss: 2.2455e-08 - val_mae: 1.0611e-04
# Epoch 348/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.2197e-08 - mae: 1.1042e-04 - val_loss: 3.1585e-08 - val_mae: 1.1908e-04
# Epoch 349/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.8316e-08 - mae: 1.1948e-04 - val_loss: 2.1415e-08 - val_mae: 1.0473e-04
# Epoch 350/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.2132e-08 - mae: 1.0849e-04 - val_loss: 2.0453e-08 - val_mae: 1.0029e-04
# Epoch 351/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 2.0132e-08 - mae: 1.0460e-04 - val_loss: 2.1680e-08 - val_mae: 1.0411e-04
# Epoch 352/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1955e-08 - mae: 1.0582e-04 - val_loss: 2.3502e-08 - val_mae: 1.0346e-04
# Epoch 353/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.1978e-08 - mae: 1.0372e-04 - val_loss: 2.0910e-08 - val_mae: 1.0071e-04
# Epoch 354/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1232e-08 - mae: 1.0622e-04 - val_loss: 2.1447e-08 - val_mae: 1.0334e-04
# Epoch 355/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.8432e-08 - mae: 1.2113e-04 - val_loss: 2.0496e-08 - val_mae: 1.0350e-04
# Epoch 356/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.2358e-08 - mae: 1.2567e-04 - val_loss: 4.7153e-08 - val_mae: 1.5290e-04
# Epoch 357/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.1215e-08 - mae: 1.4804e-04 - val_loss: 7.8532e-08 - val_mae: 1.8052e-04
# Epoch 358/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 5.1760e-08 - mae: 1.5122e-04 - val_loss: 9.2465e-08 - val_mae: 2.0009e-04
# Epoch 359/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.8995e-08 - mae: 1.7330e-04 - val_loss: 8.6460e-08 - val_mae: 1.9682e-04
# Epoch 360/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.4885e-08 - mae: 1.9380e-04 - val_loss: 7.6610e-08 - val_mae: 1.9045e-04
# Epoch 361/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.7623e-08 - mae: 2.0563e-04 - val_loss: 5.2024e-08 - val_mae: 1.5534e-04
# Epoch 362/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 8.7322e-08 - mae: 1.9630e-04 - val_loss: 3.1347e-08 - val_mae: 1.2478e-04
# Epoch 363/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.6398e-08 - mae: 1.5272e-04 - val_loss: 5.3705e-08 - val_mae: 1.4960e-04
# Epoch 364/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.5926e-08 - mae: 1.4830e-04 - val_loss: 3.7844e-08 - val_mae: 1.3852e-04
# Epoch 365/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.5088e-08 - mae: 1.6764e-04 - val_loss: 2.8391e-08 - val_mae: 1.1887e-04
# Epoch 366/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6851e-08 - mae: 1.5005e-04 - val_loss: 2.3574e-08 - val_mae: 1.1114e-04
# Epoch 367/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.1832e-08 - mae: 1.4543e-04 - val_loss: 2.4709e-08 - val_mae: 1.1186e-04
# Epoch 368/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 4.1888e-08 - mae: 1.4452e-04 - val_loss: 6.8982e-08 - val_mae: 1.7487e-04
# Epoch 369/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 5.7419e-08 - mae: 1.6617e-04 - val_loss: 4.5782e-08 - val_mae: 1.5187e-04
# Epoch 370/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.5129e-08 - mae: 1.5563e-04 - val_loss: 5.2458e-08 - val_mae: 1.5851e-04
# Epoch 370: early stopping
# Restoring model weights from the end of the best epoch: 320.

# %%
model = tf.keras.models.load_model(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') if os.path.exists(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') else model

# %%
# Estrai losses da tutti i folds
train_losses = history.history['loss']
val_losses   = history.history['val_loss']

train_losses = train_losses
val_losses = val_losses

# Plot
plt.figure(figsize=(8,5))


# Training loss
plt.plot(train_losses, color='blue', label='Train Loss')
# Validation loss
plt.plot(val_losses, color='red', label='Validation Loss')


# Dettagli grafico
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.savefig(f'{exp_dir}/loss_plot.png')

# %%
def plot_first_n_series(y_pred, y_test, n_series=10, title="Confronto Serie Predette vs Reali"):
    """
    Plotta le prime n_series serie reali e predette per un confronto diretto.

    Args:
        y_pred (np.ndarray): Predizioni del modello (shape: num_samples x seq_len).
        y_test (np.ndarray): Serie reali (shape: num_samples x seq_len).
        n_series (int): Numero di serie da plottare.
        title (str): Titolo del grafico.
    """

    # Limitiamo a n_series per evitare problemi
    n = min(n_series, y_pred.shape[0], y_test.shape[0])

    plt.figure(figsize=(14, 8))

    for i in range(n):
        plt.plot(
            y_test[i], 
            linewidth=1.8, 
            alpha=0.5, 
            label=f"Reale {i+1}" if i == 0 else "",
            color = 'blue'
        )
        plt.plot(
            y_pred[i], 
            linewidth=1.2, 
            linestyle="--", 
            alpha=0.9, 
            label=f"Predetto {i+1}" if i == 0 else "",
            color = 'orange'
        )

    plt.title(title, fontsize=16)
    plt.xlabel("Time Step", fontsize=12)
    plt.ylabel("Valore", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

def plot_diagnosis_gradient(y_pred, y_test, save_path: str,  tolerance:float =0.05, max_samples_heatmap=50, scatter_sample_ratio=0.5, tol_auto = True):
    """
    Dashboard diagnostica con tolleranza AUTO-ADATTIVA alla scala dei dati.
    
    Args:
        tolerance (float): 
            - Se None: La tolleranza viene calcolata automaticamente come il 5% del range dei dati (Max-Min).
            - Se float: Valore assoluto (es. 0.5).
        tol_auto (bool): Se True, usa la tolleranza automatica basata sul range dei dati, altrimenti usa il valore manuale fornito 
        col parametro tolerance.
    """
    
    y_test_flat = y_test.flatten()
    y_pred_flat = y_pred.flatten()

    # ---------------------------------------------------------
    # AUTOMAZIONE TOLLERANZA
    # ---------------------------------------------------------
    if tol_auto:
        data_range = y_test_flat.max() - y_test_flat.min()
        # Impostiamo la tolleranza al 5% del range totale (regolabile)
        tolerance = data_range * tolerance 
        tol_label = f"Auto (5% Range: ±{tolerance:.2f})"
    else:
        tol_label = f"Manuale (±{tolerance})"

    fig, axes = plt.subplots(1, 2, figsize=(22, 8))

    # -----------------------------
    # 1. HEATMAP (SX)
    # -----------------------------
    errors = np.abs(y_test - y_pred)
    errors_subset = errors[:max_samples_heatmap]
    
    # Adattiamo anche la scala colori della heatmap alla tolleranza
    # Tutto ciò che è oltre 3 volte la tolleranza è "errore massimo" visivo
    sns.heatmap(errors_subset, cmap="plasma", ax=axes[0], 
                vmax=tolerance * 3,
                cbar_kws={'label': 'Errore Assoluto'})
    
    axes[0].set_title(f"Heatmap Errori (Primi {max_samples_heatmap} campioni)", fontsize=16)
    axes[0].set_xlabel("Time Step", fontsize=12)
    axes[0].set_ylabel("Indice Campione", fontsize=12)

    # -----------------------------
    # 2. SCATTER CON SFONDO GRADIENTE (DX)
    # -----------------------------
    
    # Campionamento dati
    if scatter_sample_ratio < 1.0:
        mask = np.random.rand(len(y_test_flat)) < scatter_sample_ratio
        sample_test = y_test_flat[mask]
        sample_pred = y_pred_flat[mask]
    else:
        sample_test = y_test_flat
        sample_pred = y_pred_flat

    # Calcolo limiti grafico
    min_val = min(y_test_flat.min(), y_pred_flat.min())
    max_val = max(y_test_flat.max(), y_pred_flat.max())
    padding = (max_val - min_val) * 0.05
    plot_min = min_val - padding
    plot_max = max_val + padding

    # --- SFONDO GRADIENTE ---
    grid_x, grid_y = np.meshgrid(
        np.linspace(plot_min, plot_max, 200),
        np.linspace(plot_min, plot_max, 200)
    )
    grid_z = np.abs(grid_y - grid_x)

    im = axes[1].imshow(
        grid_z, 
        extent=(plot_min, plot_max, plot_min, plot_max), 
        origin='lower', 
        cmap='RdYlGn_r', 
        alpha=0.4, 
        vmax=tolerance * 4, # Il rosso satura a 4x della tolleranza
        aspect='auto'
    )

    # --- PUNTI BLU ---
    axes[1].scatter(
        sample_test, 
        sample_pred, 
        alpha=0.6, 
        s=15, 
        color='royalblue', 
        edgecolors='white', 
        linewidth=0.3,
        label='Campioni'
    )

    axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

    # Metriche
    within_tol = np.mean(np.abs(y_test_flat - y_pred_flat) <= tolerance) * 100

    axes[1].set_title(
        f"Bontà delle previsioni con {tol_label}\nValori nel range di Tolleranza: {within_tol:.1f}%", 
        fontsize=16
    )
    axes[1].set_xlabel("Valore Reale", fontsize=12)
    axes[1].set_ylabel("Valore Predetto", fontsize=12)
    axes[1].set_xlim(plot_min, plot_max)
    axes[1].set_ylim(plot_min, plot_max)
    
    cbar = plt.colorbar(im, ax=axes[1], pad=0.02)
    cbar.set_label('Gravità Errore (Distanza da diagonale)')

    plt.tight_layout()
    plt.savefig(f'{exp_dir}/{save_path}.png')

# %%
y_pred = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred)
y_test_np = scaler_y.inverse_transform(y_test)

plot_diagnosis_gradient(y_pred, y_test_np, save_path='pred_quality', max_samples_heatmap=10, scatter_sample_ratio=0.7)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_96887/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

# %%
save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/TEST', prefix="pred_plot")
# Out:
# Salvo 18 plot in: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/TEST
# Plot salvati correttamente.

# %%
import json
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_and_log(y_true, y_pred, log_path="log.json"):
    # --- Metriche ---
    mae = mean_absolute_error(y_true, y_pred, multioutput="uniform_average")
    rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput="uniform_average"))

    mask = y_true != 0
    mape = float(np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100.0)

    r2 = r2_score(y_true, y_pred, multioutput="uniform_average")

    # Valore medio del test set
    v_mean = float(np.mean(y_true))

    # --- Stampa ---
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    print(f"Test MAPE: {mape:.2f}%")
    print(f"Test R2: {r2:.4f}")
    print(f"Valore medio del test set: {v_mean:.4f}")

    # --- Salvataggio log ---
    log_data = {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2,
        "test_mean_value": v_mean
    }

    with open(log_path, "w") as f:
        json.dump(log_data, f, indent=4)

    print(f"\nLog salvato in: {log_path}")
evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/evaluation_log.json")
# Impostazioni pandas per visualizzare tutti i dati
# Out:
# Test MAE: 0.0470
# Test RMSE: 0.0751
# Test MAPE: 0.00%
# Test R2: 1.0000
# Valore medio del test set: 1544.9532
#
# Log salvato in: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/evaluation_log.json

# %% [markdown]
# # globale e federato

# %%
fed = tf.keras.models.load_model('/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Metro.keras')

model  = [fed]
model_name = ["federated"]

# %%
for model, name in zip(model, model_name):
    y_pred = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred)
    y_test_np = scaler_y.inverse_transform(y_test)

    print(f"--- {name} ---")
    #plot_diagnosis_gradient(y_pred, y_test_np, max_samples_heatmap=10, scatter_sample_ratio=0.7)
    evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_evaluation_log.json")
    save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}/TEST', prefix="pred_plot")

    print("\n")
    if name == 'federated':
        model.fit(X_train, y_train, epochs=1000, batch_size=32)
        model.save(f'{exp_dir}/model/NO2_MAREMMA_fed_model.keras')
        y_pred = model.predict(X_test)
        y_pred = scaler_y.inverse_transform(y_pred)
        print(f"--- {name} after local fine-tuning ---")
        plot_diagnosis_gradient(y_pred, y_test_np, save_path=f"{name}_pred_quality", max_samples_heatmap=10, scatter_sample_ratio=0.7)
        save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}_fd/TEST', prefix="pred_plot")
        evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_fd_evaluation_log.json")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# --- federated ---
# Test MAE: 102.8811
# Test RMSE: 130.5571
# Test MAPE: 6.28%
# Test R2: 0.3967
# Valore medio del test set: 1544.9532
#
# Log salvato in: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/federated_evaluation_log.json
# Salvo 18 plot in: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/federated/TEST
# Plot salvati correttamente.
#
#
# Epoch 1/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0730 - mae: 0.2262 - mse: 0.0730
# Epoch 2/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0479 - mae: 0.1760 - mse: 0.0479
# Epoch 3/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0392 - mae: 0.1574 - mse: 0.0392
# Epoch 4/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0301 - mae: 0.1330 - mse: 0.0301
# Epoch 5/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0253 - mae: 0.1194 - mse: 0.0253
# Epoch 6/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0212 - mae: 0.1118 - mse: 0.0212
# Epoch 7/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0167 - mae: 0.1005 - mse: 0.0167
# Epoch 8/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0146 - mae: 0.0930 - mse: 0.0146
# Epoch 9/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0128 - mae: 0.0865 - mse: 0.0128
# Epoch 10/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0104 - mae: 0.0768 - mse: 0.0104
# Epoch 11/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0746 - mse: 0.0097
# Epoch 12/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0086 - mae: 0.0717 - mse: 0.0086
# Epoch 13/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - mae: 0.0634 - mse: 0.0074
# Epoch 14/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - mae: 0.0643 - mse: 0.0072
# Epoch 15/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - mae: 0.0582 - mse: 0.0059
# Epoch 16/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0068 - mae: 0.0620 - mse: 0.0068
# Epoch 17/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mae: 0.0572 - mse: 0.0057
# Epoch 18/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - mae: 0.0546 - mse: 0.0053
# Epoch 19/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049 - mae: 0.0505 - mse: 0.0049
# Epoch 20/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0063 - mae: 0.0581 - mse: 0.0063
# Epoch 21/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mae: 0.0566 - mse: 0.0057
# Epoch 22/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mae: 0.0531 - mse: 0.0053
# Epoch 23/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0486 - mse: 0.0042
# Epoch 24/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049 - mae: 0.0525 - mse: 0.0049
# Epoch 25/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0061 - mae: 0.0572 - mse: 0.0061
# Epoch 26/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - mae: 0.0480 - mse: 0.0044
# Epoch 27/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mae: 0.0510 - mse: 0.0048
# Epoch 28/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0498 - mse: 0.0046
# Epoch 29/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - mae: 0.0470 - mse: 0.0047
# Epoch 30/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0481 - mse: 0.0043
# Epoch 31/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0520 - mse: 0.0049
# Epoch 32/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - mae: 0.0531 - mse: 0.0055
# Epoch 33/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mae: 0.0504 - mse: 0.0048
# Epoch 34/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - mae: 0.0500 - mse: 0.0046
# Epoch 35/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - mae: 0.0533 - mse: 0.0055
# Epoch 36/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0444 - mse: 0.0036
# Epoch 37/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0433 - mse: 0.0036
# Epoch 38/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0513 - mse: 0.0049
# Epoch 39/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049 - mae: 0.0502 - mse: 0.0049
# Epoch 40/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040 - mae: 0.0463 - mse: 0.0040
# Epoch 41/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - mae: 0.0515 - mse: 0.0046
# Epoch 42/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0054 - mae: 0.0540 - mse: 0.0054
# Epoch 43/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mae: 0.0496 - mse: 0.0048
# Epoch 44/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mae: 0.0522 - mse: 0.0052
# Epoch 45/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042 - mae: 0.0458 - mse: 0.0042
# Epoch 46/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0480 - mse: 0.0040
# Epoch 47/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mae: 0.0509 - mse: 0.0048
# Epoch 48/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0476 - mse: 0.0043
# Epoch 49/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0501 - mse: 0.0049
# Epoch 50/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045 - mae: 0.0475 - mse: 0.0045
# Epoch 51/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0048 - mae: 0.0497 - mse: 0.0048
# Epoch 52/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0447 - mse: 0.0039
# Epoch 53/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0478 - mse: 0.0042
# Epoch 54/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0431 - mse: 0.0034
# Epoch 55/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - mae: 0.0457 - mse: 0.0044
# Epoch 56/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0483 - mse: 0.0046
# Epoch 57/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0427 - mse: 0.0033
# Epoch 58/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0443 - mse: 0.0037
# Epoch 59/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0429 - mse: 0.0034
# Epoch 60/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0425 - mse: 0.0036
# Epoch 61/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mae: 0.0499 - mse: 0.0052
# Epoch 62/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0040 - mae: 0.0446 - mse: 0.0040
# Epoch 63/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - mae: 0.0465 - mse: 0.0044
# Epoch 64/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0409 - mse: 0.0033
# Epoch 65/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053 - mae: 0.0525 - mse: 0.0053
# Epoch 66/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0403 - mse: 0.0029
# Epoch 67/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mae: 0.0458 - mse: 0.0041
# Epoch 68/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mae: 0.0450 - mse: 0.0039
# Epoch 69/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0418 - mse: 0.0031
# Epoch 70/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0416 - mse: 0.0033
# Epoch 71/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0487 - mse: 0.0042
# Epoch 72/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0429 - mse: 0.0039
# Epoch 73/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0427 - mse: 0.0036
# Epoch 74/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - mae: 0.0449 - mse: 0.0038
# Epoch 75/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0441 - mse: 0.0037
# Epoch 76/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0447 - mse: 0.0036
# Epoch 77/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0443 - mse: 0.0034
# Epoch 78/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045 - mae: 0.0469 - mse: 0.0045
# Epoch 79/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mae: 0.0447 - mse: 0.0039
# Epoch 80/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0436 - mse: 0.0041
# Epoch 81/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0420 - mse: 0.0032
# Epoch 82/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0429 - mse: 0.0032
# Epoch 83/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0484 - mse: 0.0044
# Epoch 84/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0442 - mse: 0.0037
# Epoch 85/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - mae: 0.0430 - mse: 0.0038
# Epoch 86/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0436 - mse: 0.0036
# Epoch 87/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0419 - mse: 0.0032
# Epoch 88/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0433 - mse: 0.0036
# Epoch 89/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0469 - mse: 0.0040
# Epoch 90/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mae: 0.0465 - mse: 0.0041
# Epoch 91/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0421 - mse: 0.0033
# Epoch 92/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0436 - mse: 0.0034
# Epoch 93/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0025
# Epoch 94/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - mae: 0.0465 - mse: 0.0041
# Epoch 95/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mae: 0.0436 - mse: 0.0039
# Epoch 96/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0432 - mse: 0.0036
# Epoch 97/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0408 - mse: 0.0031
# Epoch 98/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0495 - mse: 0.0043
# Epoch 99/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0419 - mse: 0.0034
# Epoch 100/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0446 - mse: 0.0034
# Epoch 101/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0444 - mse: 0.0036
# Epoch 102/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0029 - mae: 0.0406 - mse: 0.0029
# Epoch 103/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - mae: 0.0412 - mse: 0.0031
# Epoch 104/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0408 - mse: 0.0031
# Epoch 105/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0400 - mse: 0.0030
# Epoch 106/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - mae: 0.0438 - mse: 0.0038
# Epoch 107/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mae: 0.0425 - mse: 0.0035
# Epoch 108/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045 - mae: 0.0494 - mse: 0.0045
# Epoch 109/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0467 - mse: 0.0043
# Epoch 110/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - mae: 0.0446 - mse: 0.0040
# Epoch 111/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0422 - mse: 0.0034
# Epoch 112/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0393 - mse: 0.0027
# Epoch 113/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0389 - mse: 0.0027
# Epoch 114/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0394 - mse: 0.0028
# Epoch 115/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0450 - mse: 0.0038
# Epoch 116/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0431 - mse: 0.0034
# Epoch 117/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0416 - mse: 0.0034
# Epoch 118/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030 - mae: 0.0399 - mse: 0.0030
# Epoch 119/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0405 - mse: 0.0030
# Epoch 120/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0400 - mse: 0.0029
# Epoch 121/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0425 - mse: 0.0033
# Epoch 122/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0378 - mse: 0.0029
# Epoch 123/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0436 - mse: 0.0036
# Epoch 124/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0406 - mse: 0.0031
# Epoch 125/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0423 - mse: 0.0033
# Epoch 126/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042 - mae: 0.0457 - mse: 0.0042
# Epoch 127/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 128/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0434 - mse: 0.0037
# Epoch 129/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0433 - mse: 0.0036
# Epoch 130/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0440 - mse: 0.0035
# Epoch 131/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0427 - mse: 0.0034
# Epoch 132/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0461 - mse: 0.0037
# Epoch 133/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0404 - mse: 0.0033
# Epoch 134/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0440 - mse: 0.0036
# Epoch 135/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0444 - mse: 0.0036
# Epoch 136/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0397 - mse: 0.0029
# Epoch 137/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0433 - mse: 0.0034
# Epoch 138/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0399 - mse: 0.0030
# Epoch 139/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0426 - mse: 0.0034
# Epoch 140/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0380 - mse: 0.0028
# Epoch 141/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0431 - mse: 0.0031
# Epoch 142/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - mae: 0.0417 - mse: 0.0032
# Epoch 143/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - mae: 0.0410 - mse: 0.0033
# Epoch 144/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047 - mae: 0.0471 - mse: 0.0047
# Epoch 145/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0425 - mse: 0.0033
# Epoch 146/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0443 - mse: 0.0037
# Epoch 147/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0380 - mse: 0.0028
# Epoch 148/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0447 - mse: 0.0039
# Epoch 149/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0468 - mse: 0.0041
# Epoch 150/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0415 - mse: 0.0032
# Epoch 151/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0465 - mse: 0.0040
# Epoch 152/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0382 - mse: 0.0026
# Epoch 153/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0426 - mse: 0.0037
# Epoch 154/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mae: 0.0440 - mse: 0.0038
# Epoch 155/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0387 - mse: 0.0027
# Epoch 156/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mae: 0.0429 - mse: 0.0035
# Epoch 157/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0412 - mse: 0.0031
# Epoch 158/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0435 - mse: 0.0036
# Epoch 159/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0445 - mse: 0.0041
# Epoch 160/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0461 - mse: 0.0037
# Epoch 161/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0428 - mse: 0.0037
# Epoch 162/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0416 - mse: 0.0032
# Epoch 163/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mae: 0.0393 - mse: 0.0028
# Epoch 164/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035 - mae: 0.0436 - mse: 0.0035
# Epoch 165/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0434 - mse: 0.0034
# Epoch 166/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0424 - mse: 0.0031
# Epoch 167/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0417 - mse: 0.0032
# Epoch 168/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0409 - mse: 0.0030
# Epoch 169/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0395 - mse: 0.0030
# Epoch 170/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0378 - mse: 0.0026
# Epoch 171/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - mae: 0.0399 - mse: 0.0031
# Epoch 172/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0406 - mse: 0.0032
# Epoch 173/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035 - mae: 0.0416 - mse: 0.0035
# Epoch 174/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0435 - mse: 0.0037
# Epoch 175/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0363 - mse: 0.0027
# Epoch 176/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0387 - mse: 0.0028
# Epoch 177/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0409 - mse: 0.0033
# Epoch 178/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0399 - mse: 0.0031
# Epoch 179/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0436 - mse: 0.0036
# Epoch 180/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0396 - mse: 0.0031
# Epoch 181/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0400 - mse: 0.0031
# Epoch 182/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 183/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 184/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0443 - mse: 0.0037
# Epoch 185/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0411 - mse: 0.0032
# Epoch 186/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0455 - mse: 0.0036
# Epoch 187/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0439 - mse: 0.0036
# Epoch 188/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0352 - mse: 0.0022
# Epoch 189/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mae: 0.0476 - mse: 0.0041
# Epoch 190/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - mae: 0.0506 - mse: 0.0054
# Epoch 191/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037 - mae: 0.0441 - mse: 0.0037
# Epoch 192/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0376 - mse: 0.0026
# Epoch 193/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0391 - mse: 0.0027
# Epoch 194/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0418 - mse: 0.0033
# Epoch 195/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0425 - mse: 0.0035
# Epoch 196/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0377 - mse: 0.0027
# Epoch 197/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0404 - mse: 0.0030
# Epoch 198/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0380 - mse: 0.0026
# Epoch 199/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - mae: 0.0434 - mse: 0.0038
# Epoch 200/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0376 - mse: 0.0029
# Epoch 201/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0369 - mse: 0.0025
# Epoch 202/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0424 - mse: 0.0033
# Epoch 203/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - mae: 0.0381 - mse: 0.0028
# Epoch 204/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0365 - mse: 0.0029
# Epoch 205/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0347 - mse: 0.0021
# Epoch 206/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0426 - mse: 0.0034
# Epoch 207/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mae: 0.0431 - mse: 0.0039
# Epoch 208/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mae: 0.0440 - mse: 0.0035
# Epoch 209/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0358 - mse: 0.0025
# Epoch 210/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0368 - mse: 0.0026
# Epoch 211/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0382 - mse: 0.0025
# Epoch 212/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0402 - mse: 0.0032
# Epoch 213/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0415 - mse: 0.0034
# Epoch 214/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0405 - mse: 0.0031
# Epoch 215/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0347 - mse: 0.0022
# Epoch 216/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032 - mae: 0.0425 - mse: 0.0032
# Epoch 217/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 218/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035 - mae: 0.0425 - mse: 0.0035
# Epoch 219/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 220/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0358 - mse: 0.0023
# Epoch 221/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0383 - mse: 0.0029
# Epoch 222/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043 - mae: 0.0456 - mse: 0.0043
# Epoch 223/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028 - mae: 0.0373 - mse: 0.0028
# Epoch 224/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - mae: 0.0415 - mse: 0.0034
# Epoch 225/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0387 - mse: 0.0030
# Epoch 226/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0347 - mse: 0.0025
# Epoch 227/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0420 - mse: 0.0033
# Epoch 228/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0410 - mse: 0.0029
# Epoch 229/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0430 - mse: 0.0033
# Epoch 230/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0378 - mse: 0.0028
# Epoch 231/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0370 - mse: 0.0025
# Epoch 232/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0389 - mse: 0.0030
# Epoch 233/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0378 - mse: 0.0031
# Epoch 234/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0431 - mse: 0.0036
# Epoch 235/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 236/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0384 - mse: 0.0030
# Epoch 237/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0398 - mse: 0.0031
# Epoch 238/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0369 - mse: 0.0024
# Epoch 239/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0412 - mse: 0.0033
# Epoch 240/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0406 - mse: 0.0031
# Epoch 241/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0388 - mse: 0.0027
# Epoch 242/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0420 - mse: 0.0032
# Epoch 243/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0385 - mse: 0.0029
# Epoch 244/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0390 - mse: 0.0029
# Epoch 245/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0426 - mse: 0.0034
# Epoch 246/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0413 - mse: 0.0033
# Epoch 247/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0358 - mse: 0.0025
# Epoch 248/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0375 - mse: 0.0024
# Epoch 249/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0401 - mse: 0.0031
# Epoch 250/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0386 - mse: 0.0028
# Epoch 251/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0417 - mse: 0.0030
# Epoch 252/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0385 - mse: 0.0026
# Epoch 253/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0391 - mse: 0.0029
# Epoch 254/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0410 - mse: 0.0030
# Epoch 255/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0432 - mse: 0.0040
# Epoch 256/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0427 - mse: 0.0032
# Epoch 257/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0371 - mse: 0.0025
# Epoch 258/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0411 - mse: 0.0031
# Epoch 259/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0404 - mse: 0.0030
# Epoch 260/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0392 - mse: 0.0027
# Epoch 261/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0464 - mse: 0.0043
# Epoch 262/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0374 - mse: 0.0026
# Epoch 263/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0400 - mse: 0.0028
# Epoch 264/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0373 - mse: 0.0025
# Epoch 265/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0406 - mse: 0.0029
# Epoch 266/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0381 - mse: 0.0027
# Epoch 267/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0404 - mse: 0.0030
# Epoch 268/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0400 - mse: 0.0029
# Epoch 269/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0374 - mse: 0.0026
# Epoch 270/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0384 - mse: 0.0029
# Epoch 271/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0439 - mse: 0.0039
# Epoch 272/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0395 - mse: 0.0030
# Epoch 273/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0397 - mse: 0.0031
# Epoch 274/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0374 - mse: 0.0026
# Epoch 275/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0382 - mse: 0.0028
# Epoch 276/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0414 - mse: 0.0035
# Epoch 277/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0413 - mse: 0.0032
# Epoch 278/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0415 - mse: 0.0031
# Epoch 279/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0371 - mse: 0.0024
# Epoch 280/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mae: 0.0327 - mse: 0.0020
# Epoch 281/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0421 - mse: 0.0034
# Epoch 282/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0398 - mse: 0.0028
# Epoch 283/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0410 - mse: 0.0032
# Epoch 284/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0449 - mse: 0.0034
# Epoch 285/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0417 - mse: 0.0036
# Epoch 286/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0411 - mse: 0.0033
# Epoch 287/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0415 - mse: 0.0036
# Epoch 288/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0395 - mse: 0.0027
# Epoch 289/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0399 - mse: 0.0031
# Epoch 290/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0448 - mse: 0.0041
# Epoch 291/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0372 - mse: 0.0026
# Epoch 292/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0347 - mse: 0.0022
# Epoch 293/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 294/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0385 - mse: 0.0031
# Epoch 295/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0371 - mse: 0.0028
# Epoch 296/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0431 - mse: 0.0033
# Epoch 297/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0351 - mse: 0.0023
# Epoch 298/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0360 - mse: 0.0025
# Epoch 299/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0397 - mse: 0.0027
# Epoch 300/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0382 - mse: 0.0027
# Epoch 301/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0347 - mse: 0.0023
# Epoch 302/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0392 - mse: 0.0031
# Epoch 303/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0391 - mse: 0.0032
# Epoch 304/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0418 - mse: 0.0034
# Epoch 305/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mae: 0.0388 - mse: 0.0026
# Epoch 306/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0430 - mse: 0.0034
# Epoch 307/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0400 - mse: 0.0034
# Epoch 308/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0375 - mse: 0.0028
# Epoch 309/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0401 - mse: 0.0028
# Epoch 310/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0411 - mse: 0.0031
# Epoch 311/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0391 - mse: 0.0030
# Epoch 312/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0414 - mse: 0.0031
# Epoch 313/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0432 - mse: 0.0037
# Epoch 314/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0370 - mse: 0.0025
# Epoch 315/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0389 - mse: 0.0027
# Epoch 316/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0455 - mse: 0.0036
# Epoch 317/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0397 - mse: 0.0031
# Epoch 318/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0419 - mse: 0.0034
# Epoch 319/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0344 - mse: 0.0022
# Epoch 320/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0390 - mse: 0.0030
# Epoch 321/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0037 - mae: 0.0457 - mse: 0.0037
# Epoch 322/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0401 - mse: 0.0031
# Epoch 323/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0350 - mse: 0.0023
# Epoch 324/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0025
# Epoch 325/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0439 - mse: 0.0037
# Epoch 326/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0368 - mse: 0.0026
# Epoch 327/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0402 - mse: 0.0030
# Epoch 328/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0352 - mse: 0.0024
# Epoch 329/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0390 - mse: 0.0025
# Epoch 330/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0405 - mse: 0.0032
# Epoch 331/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0411 - mse: 0.0031
# Epoch 332/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0385 - mse: 0.0027
# Epoch 333/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0363 - mse: 0.0023
# Epoch 334/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0383 - mse: 0.0027
# Epoch 335/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0385 - mse: 0.0029
# Epoch 336/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0410 - mse: 0.0031
# Epoch 337/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0347 - mse: 0.0024
# Epoch 338/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0431 - mse: 0.0035
# Epoch 339/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0416 - mse: 0.0033
# Epoch 340/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0384 - mse: 0.0028
# Epoch 341/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0368 - mse: 0.0026
# Epoch 342/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0390 - mse: 0.0029
# Epoch 343/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0324 - mse: 0.0019
# Epoch 344/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0374 - mse: 0.0024
# Epoch 345/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0397 - mse: 0.0034
# Epoch 346/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0368 - mse: 0.0025
# Epoch 347/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0369 - mse: 0.0025
# Epoch 348/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0377 - mse: 0.0027
# Epoch 349/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0343 - mse: 0.0022
# Epoch 350/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0411 - mse: 0.0034
# Epoch 351/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0026 - mae: 0.0382 - mse: 0.0026
# Epoch 352/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0314 - mse: 0.0017
# Epoch 353/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0396 - mse: 0.0026
# Epoch 354/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0404 - mse: 0.0032
# Epoch 355/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0025
# Epoch 356/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0365 - mse: 0.0025
# Epoch 357/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0407 - mse: 0.0031
# Epoch 358/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0433 - mse: 0.0036
# Epoch 359/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mae: 0.0337 - mse: 0.0020
# Epoch 360/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0327 - mse: 0.0021
# Epoch 361/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0358 - mse: 0.0024
# Epoch 362/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0386 - mse: 0.0029
# Epoch 363/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0412 - mse: 0.0033
# Epoch 364/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0386 - mse: 0.0028
# Epoch 365/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0386 - mse: 0.0029
# Epoch 366/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0332 - mse: 0.0022
# Epoch 367/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 368/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0360 - mse: 0.0025
# Epoch 369/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0395 - mse: 0.0030
# Epoch 370/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - mae: 0.0391 - mse: 0.0029
# Epoch 371/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0385 - mse: 0.0029
# Epoch 372/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0410 - mse: 0.0030
# Epoch 373/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0427 - mse: 0.0036
# Epoch 374/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0380 - mse: 0.0029
# Epoch 375/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0364 - mse: 0.0023
# Epoch 376/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0368 - mse: 0.0025
# Epoch 377/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mae: 0.0309 - mse: 0.0017
# Epoch 378/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0415 - mse: 0.0031
# Epoch 379/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0406 - mse: 0.0031
# Epoch 380/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0404 - mse: 0.0033
# Epoch 381/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0411 - mse: 0.0030
# Epoch 382/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0381 - mse: 0.0029
# Epoch 383/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0421 - mse: 0.0034
# Epoch 384/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0377 - mse: 0.0025
# Epoch 385/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0396 - mse: 0.0029
# Epoch 386/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0375 - mse: 0.0026
# Epoch 387/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0435 - mse: 0.0035
# Epoch 388/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0414 - mse: 0.0033
# Epoch 389/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0414 - mse: 0.0031
# Epoch 390/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0380 - mse: 0.0025
# Epoch 391/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0448 - mse: 0.0035
# Epoch 392/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0397 - mse: 0.0029
# Epoch 393/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0386 - mse: 0.0028
# Epoch 394/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0385 - mse: 0.0027
# Epoch 395/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0410 - mse: 0.0032
# Epoch 396/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034 - mae: 0.0410 - mse: 0.0034
# Epoch 397/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0376 - mse: 0.0028
# Epoch 398/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0373 - mse: 0.0025
# Epoch 399/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0356 - mse: 0.0024
# Epoch 400/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0390 - mse: 0.0027
# Epoch 401/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0376 - mse: 0.0026
# Epoch 402/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0370 - mse: 0.0024
# Epoch 403/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0403 - mse: 0.0033
# Epoch 404/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0350 - mse: 0.0023
# Epoch 405/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0338 - mse: 0.0022
# Epoch 406/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0352 - mse: 0.0026
# Epoch 407/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0388 - mse: 0.0029
# Epoch 408/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0408 - mse: 0.0031
# Epoch 409/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0379 - mse: 0.0028
# Epoch 410/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0385 - mse: 0.0030
# Epoch 411/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0389 - mse: 0.0027
# Epoch 412/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0408 - mse: 0.0029
# Epoch 413/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0405 - mse: 0.0032
# Epoch 414/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0375 - mse: 0.0029
# Epoch 415/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0413 - mse: 0.0030
# Epoch 416/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0382 - mse: 0.0028
# Epoch 417/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0340 - mse: 0.0021
# Epoch 418/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0379 - mse: 0.0026
# Epoch 419/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0446 - mse: 0.0040
# Epoch 420/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0352 - mse: 0.0023
# Epoch 421/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0332 - mse: 0.0022
# Epoch 422/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - mae: 0.0381 - mse: 0.0028
# Epoch 423/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mae: 0.0401 - mse: 0.0030
# Epoch 424/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0391 - mse: 0.0028
# Epoch 425/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0359 - mse: 0.0025
# Epoch 426/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0407 - mse: 0.0030
# Epoch 427/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0364 - mse: 0.0023
# Epoch 428/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0353 - mse: 0.0023
# Epoch 429/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0350 - mse: 0.0026
# Epoch 430/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mae: 0.0444 - mse: 0.0039
# Epoch 431/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0429 - mse: 0.0032
# Epoch 432/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0436 - mse: 0.0032
# Epoch 433/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0417 - mse: 0.0031
# Epoch 434/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0380 - mse: 0.0028
# Epoch 435/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0377 - mse: 0.0026
# Epoch 436/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0383 - mse: 0.0028
# Epoch 437/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0354 - mse: 0.0023
# Epoch 438/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0394 - mse: 0.0029
# Epoch 439/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0391 - mse: 0.0025
# Epoch 440/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0370 - mse: 0.0025
# Epoch 441/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0358 - mse: 0.0021
# Epoch 442/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0405 - mse: 0.0034
# Epoch 443/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0385 - mse: 0.0026
# Epoch 444/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0398 - mse: 0.0029
# Epoch 445/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032 - mae: 0.0415 - mse: 0.0032
# Epoch 446/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - mae: 0.0362 - mse: 0.0023
# Epoch 447/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0438 - mse: 0.0033
# Epoch 448/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0378 - mse: 0.0027
# Epoch 449/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0353 - mse: 0.0023
# Epoch 450/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0430 - mse: 0.0034
# Epoch 451/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0359 - mse: 0.0024
# Epoch 452/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0396 - mse: 0.0027
# Epoch 453/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0428 - mse: 0.0034
# Epoch 454/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0376 - mse: 0.0026
# Epoch 455/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0337 - mse: 0.0022
# Epoch 456/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0365 - mse: 0.0023
# Epoch 457/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0357 - mse: 0.0023
# Epoch 458/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0351 - mse: 0.0023
# Epoch 459/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0379 - mse: 0.0026
# Epoch 460/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0366 - mse: 0.0024
# Epoch 461/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0364 - mse: 0.0025
# Epoch 462/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0409 - mse: 0.0035
# Epoch 463/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0398 - mse: 0.0030
# Epoch 464/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0348 - mse: 0.0024
# Epoch 465/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0401 - mse: 0.0031
# Epoch 466/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0404 - mse: 0.0029
# Epoch 467/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0352 - mse: 0.0025
# Epoch 468/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0351 - mse: 0.0024
# Epoch 469/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0396 - mse: 0.0030
# Epoch 470/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0378 - mse: 0.0027
# Epoch 471/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0373 - mse: 0.0027
# Epoch 472/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0361 - mse: 0.0025
# Epoch 473/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0361 - mse: 0.0023
# Epoch 474/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0434 - mse: 0.0036
# Epoch 475/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0376 - mse: 0.0024
# Epoch 476/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0026 - mae: 0.0385 - mse: 0.0026
# Epoch 477/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mae: 0.0408 - mse: 0.0029
# Epoch 478/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0368 - mse: 0.0024
# Epoch 479/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033 - mae: 0.0387 - mse: 0.0033
# Epoch 480/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0379 - mse: 0.0026
# Epoch 481/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0392 - mse: 0.0028
# Epoch 482/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0330 - mse: 0.0020
# Epoch 483/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0345 - mse: 0.0023
# Epoch 484/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0362 - mse: 0.0025
# Epoch 485/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0399 - mse: 0.0032
# Epoch 486/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0389 - mse: 0.0028
# Epoch 487/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0393 - mse: 0.0027
# Epoch 488/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0025
# Epoch 489/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0408 - mse: 0.0030
# Epoch 490/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0365 - mse: 0.0025
# Epoch 491/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0351 - mse: 0.0021
# Epoch 492/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0357 - mse: 0.0023
# Epoch 493/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mae: 0.0346 - mse: 0.0020
# Epoch 494/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0355 - mse: 0.0025
# Epoch 495/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0374 - mse: 0.0024
# Epoch 496/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mae: 0.0354 - mse: 0.0024
# Epoch 497/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021 - mae: 0.0340 - mse: 0.0021
# Epoch 498/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0417 - mse: 0.0031
# Epoch 499/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0415 - mse: 0.0032
# Epoch 500/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0387 - mse: 0.0028
# Epoch 501/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0389 - mse: 0.0029
# Epoch 502/1000
# ...
# Epoch 841/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mae: 0.0309 - mse: 0.0018
# Epoch 842/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 843/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0405 - mse: 0.0030
# Epoch 844/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0347 - mse: 0.0022
# Epoch 845/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0356 - mse: 0.0023
# Epoch 846/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0376 - mse: 0.0026
# Epoch 847/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 848/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0407 - mse: 0.0034
# Epoch 849/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - mae: 0.0373 - mse: 0.0027
# Epoch 850/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0389 - mse: 0.0028
# Epoch 851/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0368 - mse: 0.0023
# Epoch 852/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0358 - mse: 0.0022
# Epoch 853/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0373 - mse: 0.0027
# Epoch 854/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0320 - mse: 0.0019
# Epoch 855/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0388 - mse: 0.0024
# Epoch 856/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0375 - mse: 0.0025
# Epoch 857/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0367 - mse: 0.0026
# Epoch 858/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0365 - mse: 0.0024
# Epoch 859/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0390 - mse: 0.0027
# Epoch 860/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0410 - mse: 0.0028
# Epoch 861/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0400 - mse: 0.0030
# Epoch 862/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0323 - mse: 0.0021
# Epoch 863/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0381 - mse: 0.0028
# Epoch 864/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030 - mae: 0.0379 - mse: 0.0030
# Epoch 865/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0401 - mse: 0.0032
# Epoch 866/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0404 - mse: 0.0027
# Epoch 867/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0383 - mse: 0.0026
# Epoch 868/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0394 - mse: 0.0028
# Epoch 869/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 870/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0390 - mse: 0.0029
# Epoch 871/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0409 - mse: 0.0031
# Epoch 872/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0354 - mse: 0.0028
# Epoch 873/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0028 - mae: 0.0384 - mse: 0.0028
# Epoch 874/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - mae: 0.0417 - mse: 0.0033
# Epoch 875/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0355 - mse: 0.0023
# Epoch 876/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mae: 0.0329 - mse: 0.0020
# Epoch 877/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0367 - mse: 0.0025
# Epoch 878/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0334 - mse: 0.0021
# Epoch 879/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0403 - mse: 0.0032
# Epoch 880/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0383 - mse: 0.0033
# Epoch 881/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0354 - mse: 0.0022
# Epoch 882/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0332 - mse: 0.0020
# Epoch 883/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0367 - mse: 0.0027
# Epoch 884/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0315 - mse: 0.0019
# Epoch 885/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0347 - mse: 0.0023
# Epoch 886/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0348 - mse: 0.0021
# Epoch 887/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0432 - mse: 0.0036
# Epoch 888/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0355 - mse: 0.0024
# Epoch 889/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0374 - mse: 0.0028
# Epoch 890/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0387 - mse: 0.0028
# Epoch 891/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0354 - mse: 0.0023
# Epoch 892/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0401 - mse: 0.0030
# Epoch 893/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 894/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0414 - mse: 0.0033
# Epoch 895/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0386 - mse: 0.0028
# Epoch 896/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0325 - mse: 0.0019
# Epoch 897/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mae: 0.0309 - mse: 0.0017
# Epoch 898/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - mae: 0.0336 - mse: 0.0021
# Epoch 899/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0350 - mse: 0.0021
# Epoch 900/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0372 - mse: 0.0026
# Epoch 901/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0361 - mse: 0.0024
# Epoch 902/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0384 - mse: 0.0029
# Epoch 903/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0368 - mse: 0.0027
# Epoch 904/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0356 - mse: 0.0026
# Epoch 905/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0350 - mse: 0.0023
# Epoch 906/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0366 - mse: 0.0023
# Epoch 907/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0351 - mse: 0.0022
# Epoch 908/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0357 - mse: 0.0027
# Epoch 909/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0359 - mse: 0.0023
# Epoch 910/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0366 - mse: 0.0023
# Epoch 911/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036 - mae: 0.0439 - mse: 0.0036
# Epoch 912/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0343 - mse: 0.0021
# Epoch 913/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024 - mae: 0.0367 - mse: 0.0024
# Epoch 914/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0386 - mse: 0.0031
# Epoch 915/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0340 - mse: 0.0022
# Epoch 916/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029 - mae: 0.0386 - mse: 0.0029
# Epoch 917/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - mae: 0.0313 - mse: 0.0018
# Epoch 918/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022 - mae: 0.0342 - mse: 0.0022
# Epoch 919/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0349 - mse: 0.0022
# Epoch 920/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0399 - mse: 0.0032
# Epoch 921/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0388 - mse: 0.0027
# Epoch 922/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0320 - mse: 0.0018
# Epoch 923/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0368 - mse: 0.0025
# Epoch 924/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0364 - mse: 0.0023
# Epoch 925/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0306 - mse: 0.0017
# Epoch 926/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 927/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0031 - mae: 0.0411 - mse: 0.0031
# Epoch 928/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0360 - mse: 0.0024
# Epoch 929/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0404 - mse: 0.0034
# Epoch 930/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 931/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0387 - mse: 0.0029
# Epoch 932/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0364 - mse: 0.0026
# Epoch 933/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0344 - mse: 0.0022
# Epoch 934/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0380 - mse: 0.0026
# Epoch 935/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0025
# Epoch 936/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0336 - mse: 0.0021
# Epoch 937/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0355 - mse: 0.0024
# Epoch 938/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0380 - mse: 0.0026
# Epoch 939/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0394 - mse: 0.0029
# Epoch 940/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0364 - mse: 0.0024
# Epoch 941/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 942/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mae: 0.0345 - mse: 0.0020
# Epoch 943/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0353 - mse: 0.0022
# Epoch 944/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0427 - mse: 0.0034
# Epoch 945/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - mae: 0.0381 - mse: 0.0026
# Epoch 946/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0348 - mse: 0.0022
# Epoch 947/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0377 - mse: 0.0027
# Epoch 948/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0303 - mse: 0.0017
# Epoch 949/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0354 - mse: 0.0026
# Epoch 950/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0336 - mse: 0.0020
# Epoch 951/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0387 - mse: 0.0028
# Epoch 952/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0347 - mse: 0.0020
# Epoch 953/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0375 - mse: 0.0026
# Epoch 954/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mae: 0.0329 - mse: 0.0019
# Epoch 955/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0339 - mse: 0.0022
# Epoch 956/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0374 - mse: 0.0026
# Epoch 957/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mae: 0.0313 - mse: 0.0017
# Epoch 958/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0337 - mse: 0.0023
# Epoch 959/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021 - mae: 0.0326 - mse: 0.0021
# Epoch 960/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - mae: 0.0322 - mse: 0.0019
# Epoch 961/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0356 - mse: 0.0025
# Epoch 962/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0357 - mse: 0.0022
# Epoch 963/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0340 - mse: 0.0021
# Epoch 964/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0370 - mse: 0.0024
# Epoch 965/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 966/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - mae: 0.0399 - mse: 0.0031
# Epoch 967/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0316 - mse: 0.0020
# Epoch 968/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mae: 0.0391 - mse: 0.0032
# Epoch 969/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0339 - mse: 0.0025
# Epoch 970/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - mae: 0.0375 - mse: 0.0029
# Epoch 971/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 972/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0377 - mse: 0.0024
# Epoch 973/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0398 - mse: 0.0026
# Epoch 974/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0405 - mse: 0.0031
# Epoch 975/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mae: 0.0347 - mse: 0.0023
# Epoch 976/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0326 - mse: 0.0021
# Epoch 977/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0326 - mse: 0.0020
# Epoch 978/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0334 - mse: 0.0022
# Epoch 979/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0350 - mse: 0.0025
# Epoch 980/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0369 - mse: 0.0023
# Epoch 981/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mae: 0.0349 - mse: 0.0021
# Epoch 982/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0314 - mse: 0.0018
# Epoch 983/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0351 - mse: 0.0022
# Epoch 984/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026 - mae: 0.0379 - mse: 0.0026
# Epoch 985/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022 - mae: 0.0337 - mse: 0.0022
# Epoch 986/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0368 - mse: 0.0027
# Epoch 987/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021 - mae: 0.0349 - mse: 0.0021
# Epoch 988/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mae: 0.0381 - mse: 0.0028
# Epoch 989/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mae: 0.0321 - mse: 0.0018
# Epoch 990/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0374 - mse: 0.0027
# Epoch 991/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mae: 0.0379 - mse: 0.0029
# Epoch 992/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0369 - mse: 0.0024
# Epoch 993/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0375 - mse: 0.0024
# Epoch 994/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0359 - mse: 0.0025
# Epoch 995/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0357 - mse: 0.0022
# Epoch 996/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0334 - mse: 0.0024
# Epoch 997/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0365 - mse: 0.0026
# Epoch 998/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0403 - mse: 0.0032
# Epoch 999/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mae: 0.0328 - mse: 0.0020
# Epoch 1000/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024 - mae: 0.0357 - mse: 0.0024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# --- federated after local fine-tuning ---
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_96887/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Salvo 18 plot in: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/federated_fd/TEST
# Plot salvati correttamente.
# Test MAE: 5.2715
# Test RMSE: 6.6995
# Test MAPE: 0.34%
# Test R2: 0.9985
# Valore medio del test set: 1544.9532
#
# Log salvato in: ../RISULTATI/2025-11-29/esperimento_METRO814_16-04-27/federated_fd_evaluation_log.json
