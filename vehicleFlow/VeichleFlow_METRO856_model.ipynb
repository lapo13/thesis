# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import os, pickle, random
from datetime import datetime

# %%
get_after_QA = lambda s: s.split("DISIT/", 1)[1]

# %%
dati = pd.read_excel('/Users/lapotinacci/thesis/metric_datasets/vehicleFlow_dataset.xlsx')
dati = dati[dati["serviceUri"] == "http://www.disit.org/km4city/resource/iot/orionUNIFI/DISIT/METRO856"].copy()
sensor_name = get_after_QA(dati["serviceUri"].iloc[0])
dati.drop(columns=["serviceUri"], inplace=True)
print(dati.shape)
# Out:
# (190, 15)

# %%
# === Creazione cartella esperimento con timestamp ISO ===
timestamp = datetime.now().strftime("%H-%M-%S")
print(f"Ora inizio esperimento: {timestamp}")
day= datetime.now().strftime("%Y-%m-%d")
print(f"Giorno inizio esperimento: {day}")
exp_dir = f"../RISULTATI/{day}/esperimento_{sensor_name}_{timestamp}"

os.makedirs(exp_dir, exist_ok=True)

print(f"Cartella esperimento creata: {exp_dir}")
# Out:
# Ora inizio esperimento: 16-04-33
# Giorno inizio esperimento: 2025-11-29
# Cartella esperimento creata: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33

# %%
import ast

mask = ~dati['TTT'].str.contains("nan", na=True)
dtset_completo = dati[mask]

dtset_completo['TTT'] = dtset_completo['TTT'].apply(ast.literal_eval)

# %%
# Filtra le righe dove la colonna TTT ha lunghezza 24, ed elimina tutte le colonne le cui osservazioni sono indipendenti dal giorno
dtset_filtrato = dtset_completo[dtset_completo["TTT"].apply(lambda x: len(x) == 24)].sample(frac=1).reset_index(drop=True)
dtset_filtrato = dtset_filtrato[dtset_filtrato["type_of_TTT"] == "daily"]
len(dtset_filtrato)
# Out:
# 90

# %%
import numpy as np


def is_useful_series(series, zero_ratio_thr=0.85, min_nonzero_value=0.1):
    arr = np.array(series, dtype=float)
    
    # Serie troppo corta
    if len(arr) <= 1:
        return False
    
    # Troppi zeri
    zero_ratio = (arr == 0).mean()
    if zero_ratio >= zero_ratio_thr:
        return False
    
    # Valore medio trascurabile (quasi zero)
    mean_val = np.mean(arr)
    if abs(mean_val) < min_nonzero_value:
        return False
    
    # Se arriva qui, la serie ha valori significativi
    return True

# Applica filtro
mask_useful = dtset_filtrato["TTT"].apply(is_useful_series)
df_useful = dtset_filtrato[mask_useful]

# %%
def spezza_serie_in_colonne(df, colonna_stringa, prefix='col_'):
    # --- Controllo colonna ---
    if colonna_stringa not in df.columns:
        raise ValueError(f"La colonna '{colonna_stringa}' non esiste nel DataFrame")

    result_df = df.copy()

    # Estraggo la colonna contenente gli embedding
    col = result_df.pop(colonna_stringa)

    embeddings = []

    for item in col:
        # Gestione valori nulli o vuoti
        if pd.isna(item) or item == "":
            embeddings.append([])
            continue
        
        # Se l'item è già una lista o un array (non stringa), lo gestiamo direttamente
        if isinstance(item, (list, np.ndarray)):
            embeddings.append(list(item))
            continue

        vett = None
        
        # --- TENTATIVO 1: Parsing Standard Python (es. "[1, 2, 3]") ---
        try:
            parsed = ast.literal_eval(item)
            if isinstance(parsed, (list, tuple)):
                vett = list(parsed)
        except (ValueError, SyntaxError):
            # Se fallisce (es. SyntaxError per mancanza di virgole), passiamo al tentativo 2
            pass

        # --- TENTATIVO 2: Parsing per Spazi (es. "[1 2 3]" o "1 2 3") ---
        if vett is None:
            try:
                # Rimuove parentesi quadre, tonde e spazi iniziali/finali
                clean_str = item.replace('[', '').replace(']', '').replace('(', '').replace(')', '').strip()
                
                # Se la stringa è vuota dopo la pulizia (es. "[]"), è una lista vuota
                if not clean_str:
                    vett = []
                else:
                    # .split() senza argomenti gestisce spazi multipli, tab e newline automaticamente
                    vett = [float(x) for x in clean_str.split()]
            except Exception as e:
                print(f"Errore nel parsing dell'elemento '{item}': {e}")
                vett = []

        # --- Conversione finale e check ---
        # Assicuro che tutti gli elementi siano float (utile se ast.literal_eval ha trovato interi)
        try:
            if vett:
                vett = [float(x) for x in vett]
            embeddings.append(vett)
        except Exception as e:
            print(f"Errore conversione float per '{item}': {e}")
            embeddings.append([])

    # --- Uniformo dimensione dei vettori ---
    lengths = [len(v) for v in embeddings]
    if not lengths or max(lengths) == 0:
        # Se non ci sono dati validi, restituisco il df senza la colonna oppure sollevo errore
        # Qui scelgo di restituire il df originale senza la colonna parsata per evitare crash
        print("Warning: Nessun embedding valido trovato.")
        return result_df

    max_len = max(lengths)

    # Padding con NaN
    embeddings_padded = [
        v + [np.nan] * (max_len - len(v)) if len(v) < max_len else v
        for v in embeddings
    ]

    # --- Creo DataFrame delle nuove colonne ---
    colonne_embedding = pd.DataFrame(
        embeddings_padded,
        index=result_df.index,
        columns=[f"{prefix}{i}" for i in range(max_len)]
    )

    # --- Merge col DataFrame originale ---
    return pd.concat([result_df, colonne_embedding], axis=1)

# %%
for ttt in df_useful.TTT:
    plt.plot(ttt)

# %%
def summary_df(df):
    summary = pd.DataFrame({
        'dtype': df.dtypes,
        'n_missing': df.isna().sum(),
        '%_missing': (df.isna().mean() * 100).round(2),
        'n_unique': df.nunique(),
        'top_value': df.mode().iloc[0],  # moda
        'top_freq': [df[col].value_counts(dropna=True).iloc[0] if not df[col].value_counts(dropna=True).empty else None for col in df.columns],
        'min': [df[col].min() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'max': [df[col].max() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'mean': [df[col].mean() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'std': [df[col].std() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
    })
    return summary

# %%
#Nella precedente sono state eliminate le colonne con Nan, tuttavia alcuni dataset dei sensori METRO hanno dei Nan in city e surface dunque vengono rimossi nel prcedente box

categorical = [
    'is_weekend'
    ]

#consiglio, per serie cicliche usare funzioni periodiche tipo seno coseno 
df_encoded = pd.get_dummies(df_useful
                            , columns=categorical)

# %%
def save_pkl(obj, path):
    with open(path, "wb") as f:
        pickle.dump(obj, f)
    print(f"Salvato: {path}")

def load_pkl(path):
    with open(path, "rb") as f:
        return pickle.load(f)

# %%
#codifica ciclica delle features e individuazione del'ora del giorno e della settimana 

def encode_time_features(df, start_col="interval_start", end_col="interval_end"):
    df = df.copy()
    
    # Step 1: Ensure datetime columns are in the correct format first
    df[start_col] = pd.to_datetime(df[start_col], utc=True, format="mixed")
    df[end_col] = pd.to_datetime(df[end_col], utc=True, format="mixed")

    # Step 2: Extract 'month' and 'day' after conversion
    df['month'] = df[start_col].dt.month
    df['day'] = df[start_col].dt.dayofweek # Note: dayofweek is typically used for cyclical weekly patterns
    
    # Step 3: Now you can create the cyclical features
    df['month_sin'] = np.sin(2 * np.pi * df['month']/len(df['month'].unique()))
    df['month_cos'] = np.cos(2 * np.pi * df['month']/len(df['month'].unique()))
    df['day_sin'] = np.sin(2 * np.pi * df['day']/len(df['day'].unique()))
    df['day_cos'] = np.cos(2 * np.pi * df['day']/len(df['day'].unique()))


    # Ora del giorno (0-23) → ciclo giornaliero
    df["hour"] = df[start_col].dt.hour
    angle_day_start = 2 * np.pi * df["hour"] / 24
    df["start_time_sin"] = np.sin(angle_day_start)
    df["start_time_cos"] = np.cos(angle_day_start)

    df["hour_end"] = df[end_col].dt.hour
    angle_day_end = 2 * np.pi * df["hour_end"] / 24
    df["end_time_sin"] = np.sin(angle_day_end)
    df["end_time_cos"] = np.cos(angle_day_end)

    # Durata in minuti
    df["duration_minutes"] = (df[end_col] - df[start_col]).dt.total_seconds() / 60

    # Giorno della settimana (0=Mon..6=Sun) → ciclo settimanale
    dayofweek = df[start_col].dt.dayofweek
    angle_week = 2 * np.pi * dayofweek / 7
    df["dow_sin"] = np.sin(angle_week)
    df["dow_cos"] = np.cos(angle_week)

    # Giorno dell’anno (1-365) → ciclo annuale
    dayofyear = df[start_col].dt.dayofyear
    angle_year = 2 * np.pi * dayofyear / 365
    df["doy_sin"] = np.sin(angle_year)
    df["doy_cos"] = np.cos(angle_year)

    # Rimuovo colonne temporali e variabili ausiliarie
    df = df.drop(columns=[start_col, end_col, "hour", "hour_end", "day", "month"])
    return df

embedding_cols = ['highway_embeddings']

df_final = encode_time_features(df_encoded)
df_final.drop(columns=['type_of_TTT'], inplace=True)
for emb_col in embedding_cols:
    df_final = spezza_serie_in_colonne(df_final, emb_col, prefix=f'{emb_col}_')
df_final.shape

# Salvataggio DataFrame finale
df_path = os.path.join(exp_dir, f"dataframe_{sensor_name}")
os.makedirs(df_path, exist_ok=True)
save_pkl(df_final, os.path.join(df_path, f"filtered_dataframe.pkl"))
# Out:
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/dataframe_METRO856/filtered_dataframe.pkl

# %%
for ttt in df_final.TTT[10:20]:
    plt.plot(ttt)
    plt.title("Esempi di TTT ARPAT")
    plt.xlabel("Ora del Giorno")
    plt.ylabel("Valore TTT")

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

def series_to_2d_array(series, output_dim=24):
    arr = np.stack(series.apply(lambda x: np.array(x, dtype=np.float32)))
    if arr.shape[1] != output_dim:
        raise ValueError(f"Ogni elemento deve avere {output_dim} valori, trovato {arr.shape[1]}")
    return arr

 # Separazione delle feature e del target
X = df_final.drop(columns=['TTT'])
y = df_final['TTT']

X_np = X.to_numpy().astype(np.float32)
y_np = series_to_2d_array(y, output_dim=24)

# Calcolo deviazione standard per ogni serie
std_scores = np.std(y_np, axis=1)

std_scores_log = np.log1p(std_scores)  # log(1+x) per evitare problemi con valori vicini a 0

std_scores_normalized = (std_scores_log - np.min(std_scores_log)) / (np.max(std_scores_log) - np.min(std_scores_log))

# Creo bin basati sui quantili
bins = np.array([0.0, 0.4, 0.8, 1.0])
std_bins = np.digitize(std_scores_normalized, bins)

# Primo split: train (80%) vs temp (20%)
# Passo anche std_bins per poter stratificare
X_train, X_test, y_train, y_test = train_test_split(
    X_np, y_np,
    test_size=0.2,
    random_state=42,
    stratify=std_bins, 
    shuffle=True
)

print(f"Train size: {X_train.shape}, {y_train.shape}")
print(f"Test size: {X_test.shape}, {y_test.shape}")

# Debug prints
print(f"Final shapes:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

# Scaler per input
scaler_X = MinMaxScaler()
X_train = scaler_X.fit_transform(X_train)
X_test  = scaler_X.transform(X_test)

# Scaler per output (se serve normalizzare anche y)
scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(y_train)
y_test  = scaler_y.transform(y_test)

#cartella salvataggio train e test
path = os.path.join(exp_dir, "train_test_data")
os.makedirs(path, exist_ok=True)

#  === Salvataggio dataset e scaler in formato .pkl ===
save_pkl(scaler_X.inverse_transform(X_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_X.inverse_transform(X_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_test_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_test_unscaled_{sensor_name}.pkl"))

save_pkl(X_train, os.path.join(exp_dir, "X_train.pkl"))
save_pkl(y_train, os.path.join(exp_dir, "y_train.pkl"))
save_pkl(X_test, os.path.join(exp_dir, "X_test.pkl"))
save_pkl(y_test, os.path.join(exp_dir, "y_test.pkl"))

save_pkl(scaler_X, os.path.join(exp_dir, "scaler_X.pkl"))
save_pkl(scaler_y, os.path.join(exp_dir, "scaler_y.pkl"))

print("Scaler salvati.")

print("\nTutti i file sono stati salvati correttamente.")
print(f"Percorso cartella: {os.path.abspath(exp_dir)}")
# Out:
# Train size: (72, 28), (72, 24)
# Test size: (18, 28), (18, 24)
# Final shapes:
# X_train: (72, 28)
# y_train: (72, 24)
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_train_unscaled_METRO856.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_train_unscaled_METRO856.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_test_unscaled_METRO856.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_test_unscaled_METRO856.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/X_train.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/y_train.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/X_test.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/y_test.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/scaler_X.pkl
# Salvato: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/scaler_y.pkl
# Scaler salvati.
#
# Tutti i file sono stati salvati correttamente.
# Percorso cartella: /Users/lapotinacci/thesis/Federated_Sys/RISULTATI/2025-11-29/esperimento_METRO856_16-04-33

# %%
# === Costruisci i path ===
path_X_train = os.path.join(exp_dir, "X_train.pkl")
path_y_train = os.path.join(exp_dir, "y_train.pkl")
path_X_test  = os.path.join(exp_dir, "X_test.pkl")
path_y_test  = os.path.join(exp_dir, "y_test.pkl")

path_scaler_X = os.path.join(exp_dir, "scaler_X.pkl")
path_scaler_y = os.path.join(exp_dir, "scaler_y.pkl")

# === Ricaricamento ===
X_train = load_pkl(path_X_train)
y_train = load_pkl(path_y_train)
X_test  = load_pkl(path_X_test)
y_test  = load_pkl(path_y_test)


scaler_X = load_pkl(path_scaler_X)
scaler_y = load_pkl(path_scaler_y)

print("Shapes ricostruite:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

print("\nScaler caricati:")
print("scaler_X:", type(scaler_X))
print("scaler_y:", type(scaler_y))
# Out:
# Shapes ricostruite:
# X_train: (72, 28)
# y_train: (72, 24)
# X_test: (18, 28)
# y_test: (18, 24)
#
# Scaler caricati:
# scaler_X: <class 'sklearn.preprocessing._data.MinMaxScaler'>
# scaler_y: <class 'sklearn.preprocessing._data.MinMaxScaler'>

# %% [markdown]
# # modelli

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers # type: ignore
from tensorflow.keras.layers import Dropout # type: ignore
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
def save_prediction_plots(y_true, y_pred, output_dir, prefix="pred_plot"):
    os.makedirs(output_dir, exist_ok=True)

    n = len(y_true)
    print(f"Salvo {n} plot in: {output_dir}")

    for i in range(n):
        plt.figure(figsize=(8, 3))
        plt.plot(y_true[i], label="True")
        plt.plot(y_pred[i], label="Pred")
        plt.legend()
        plt.tight_layout()

        filename = f"{prefix}_{i+1}.png"
        path = os.path.join(output_dir, filename)

        plt.savefig(path)
        plt.close()

    print("Plot salvati correttamente.")

# %%
# Definizione modello DNN
def build_model(input_shape: tuple, output_shape: tuple):
    model = models.Sequential([
        layers.Dense(128, activation = "relu", input_shape=input_shape),
        Dropout(0.0),
        layers.Dense(output_shape, 'linear')
    ])
    model.compile(
    optimizer=optimizers.AdamW(learning_rate=0.0365, weight_decay=0.0565),
    loss= 'mse',
    metrics=['mae'],
    )
    return model

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',      # metrica da monitorare, es. val_loss o val_mae
    patience=50,             # numero di epoche senza miglioramento prima di fermare
    restore_best_weights=True,  # ripristina i pesi migliori trovati
    verbose = 1
)

# Training del modello
model = build_model((X_test.shape[1],), y_test.shape[1])
history = model.fit(
    X_train, y_train,
    epochs=1000,
    batch_size=64,
    callbacks = [early_stop],
    validation_split = 0.2,
    verbose=1
    )

'''print("y_train min/max:", y_train_np.min(), y_train_np.max())
print("y_pred min/max (scaled):", y_pred.min(), y_pred.max())
y_pred_rescaled = scaler_y.inverse_transform(y_pred)
print("y_pred_rescaled min/max:", y_pred_rescaled.min(), y_pred_rescaled.max())'''

if not os.path.exists(os.path.join(exp_dir, "model")):
    os.makedirs(os.path.join(exp_dir, "model"))
    model.save(os.path.join(exp_dir, "model", "NO2_MAREMMA_model.keras"))
# Out:
# Epoch 1/1000
# /Users/lapotinacci/thesis/Federated_Sys/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 928ms/step - loss: 0.4089 - mae: 0.5372 - val_loss: 0.1383 - val_mae: 0.3010
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.1420 - mae: 0.3069 - val_loss: 0.0952 - val_mae: 0.2563
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0943 - mae: 0.2543 - val_loss: 0.0719 - val_mae: 0.2078
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0721 - mae: 0.2073 - val_loss: 0.0634 - val_mae: 0.1937
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0637 - mae: 0.1946 - val_loss: 0.0475 - val_mae: 0.1667
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0470 - mae: 0.1659 - val_loss: 0.0391 - val_mae: 0.1538
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0380 - mae: 0.1511 - val_loss: 0.0385 - val_mae: 0.1568
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0373 - mae: 0.1548 - val_loss: 0.0312 - val_mae: 0.1409
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0304 - mae: 0.1391 - val_loss: 0.0256 - val_mae: 0.1270
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0263 - mae: 0.1290 - val_loss: 0.0232 - val_mae: 0.1240
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0251 - mae: 0.1288 - val_loss: 0.0178 - val_mae: 0.1056
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0191 - mae: 0.1093 - val_loss: 0.0147 - val_mae: 0.0941
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0147 - mae: 0.0928 - val_loss: 0.0159 - val_mae: 0.0987
# Epoch 14/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0152 - mae: 0.0949 - val_loss: 0.0141 - val_mae: 0.0951
# Epoch 15/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0135 - mae: 0.0915 - val_loss: 0.0108 - val_mae: 0.0811
# Epoch 16/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0106 - mae: 0.0797 - val_loss: 0.0099 - val_mae: 0.0751
# Epoch 17/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0104 - mae: 0.0774 - val_loss: 0.0091 - val_mae: 0.0722
# Epoch 18/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0098 - mae: 0.0758 - val_loss: 0.0075 - val_mae: 0.0665
# Epoch 19/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0077 - mae: 0.0680 - val_loss: 0.0074 - val_mae: 0.0672
# Epoch 20/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0072 - mae: 0.0650 - val_loss: 0.0073 - val_mae: 0.0661
# Epoch 21/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0069 - mae: 0.0632 - val_loss: 0.0056 - val_mae: 0.0567
# Epoch 22/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0052 - mae: 0.0536 - val_loss: 0.0046 - val_mae: 0.0513
# Epoch 23/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0044 - mae: 0.0492 - val_loss: 0.0049 - val_mae: 0.0551
# Epoch 24/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0048 - mae: 0.0540 - val_loss: 0.0046 - val_mae: 0.0530
# Epoch 25/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0045 - mae: 0.0514 - val_loss: 0.0040 - val_mae: 0.0500
# Epoch 26/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0038 - mae: 0.0475 - val_loss: 0.0040 - val_mae: 0.0503
# Epoch 27/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0037 - mae: 0.0474 - val_loss: 0.0036 - val_mae: 0.0479
# Epoch 28/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0033 - mae: 0.0448 - val_loss: 0.0029 - val_mae: 0.0421
# Epoch 29/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0025 - mae: 0.0384 - val_loss: 0.0027 - val_mae: 0.0416
# Epoch 30/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0023 - mae: 0.0385 - val_loss: 0.0026 - val_mae: 0.0402
# Epoch 31/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0023 - mae: 0.0379 - val_loss: 0.0022 - val_mae: 0.0363
# Epoch 32/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0018 - mae: 0.0332 - val_loss: 0.0021 - val_mae: 0.0353
# Epoch 33/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0017 - mae: 0.0321 - val_loss: 0.0022 - val_mae: 0.0365
# Epoch 34/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0018 - mae: 0.0338 - val_loss: 0.0019 - val_mae: 0.0337
# Epoch 35/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0016 - mae: 0.0316 - val_loss: 0.0017 - val_mae: 0.0312
# Epoch 36/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0014 - mae: 0.0295 - val_loss: 0.0016 - val_mae: 0.0299
# Epoch 37/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0014 - mae: 0.0290 - val_loss: 0.0013 - val_mae: 0.0267
# Epoch 38/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0012 - mae: 0.0252 - val_loss: 0.0012 - val_mae: 0.0261
# Epoch 39/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0010 - mae: 0.0241 - val_loss: 0.0012 - val_mae: 0.0278
# Epoch 40/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0011 - mae: 0.0259 - val_loss: 0.0012 - val_mae: 0.0264
# Epoch 41/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 9.9186e-04 - mae: 0.0243 - val_loss: 0.0011 - val_mae: 0.0252
# Epoch 42/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 9.4178e-04 - mae: 0.0234 - val_loss: 0.0011 - val_mae: 0.0251
# Epoch 43/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 9.6489e-04 - mae: 0.0237 - val_loss: 0.0010 - val_mae: 0.0234
# Epoch 44/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 8.3902e-04 - mae: 0.0216 - val_loss: 9.8703e-04 - val_mae: 0.0233
# Epoch 45/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 7.6903e-04 - mae: 0.0205 - val_loss: 0.0010 - val_mae: 0.0235
# Epoch 46/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 7.6580e-04 - mae: 0.0203 - val_loss: 9.5955e-04 - val_mae: 0.0227
# Epoch 47/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 6.9973e-04 - mae: 0.0195 - val_loss: 9.2740e-04 - val_mae: 0.0228
# Epoch 48/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.8859e-04 - mae: 0.0199 - val_loss: 8.9508e-04 - val_mae: 0.0222
# Epoch 49/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.8243e-04 - mae: 0.0197 - val_loss: 8.1502e-04 - val_mae: 0.0205
# Epoch 50/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 6.0422e-04 - mae: 0.0178 - val_loss: 7.9927e-04 - val_mae: 0.0197
# Epoch 51/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 5.7622e-04 - mae: 0.0166 - val_loss: 7.9392e-04 - val_mae: 0.0200
# Epoch 52/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 5.6899e-04 - mae: 0.0166 - val_loss: 7.3455e-04 - val_mae: 0.0192
# Epoch 53/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 5.3077e-04 - mae: 0.0162 - val_loss: 6.9071e-04 - val_mae: 0.0187
# Epoch 54/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 5.1974e-04 - mae: 0.0163 - val_loss: 6.5512e-04 - val_mae: 0.0182
# Epoch 55/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 4.9934e-04 - mae: 0.0159 - val_loss: 6.4212e-04 - val_mae: 0.0180
# Epoch 56/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 4.7905e-04 - mae: 0.0154 - val_loss: 6.5143e-04 - val_mae: 0.0186
# Epoch 57/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 4.8035e-04 - mae: 0.0157 - val_loss: 6.2231e-04 - val_mae: 0.0177
# Epoch 58/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 4.5313e-04 - mae: 0.0149 - val_loss: 5.9138e-04 - val_mae: 0.0170
# Epoch 59/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 4.3001e-04 - mae: 0.0144 - val_loss: 5.7437e-04 - val_mae: 0.0167
# Epoch 60/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 4.1658e-04 - mae: 0.0143 - val_loss: 5.5573e-04 - val_mae: 0.0161
# Epoch 61/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.9180e-04 - mae: 0.0137 - val_loss: 5.5308e-04 - val_mae: 0.0157
# Epoch 62/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 3.8172e-04 - mae: 0.0131 - val_loss: 5.4019e-04 - val_mae: 0.0154
# Epoch 63/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.6888e-04 - mae: 0.0127 - val_loss: 5.1572e-04 - val_mae: 0.0153
# Epoch 64/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.5447e-04 - mae: 0.0127 - val_loss: 4.9287e-04 - val_mae: 0.0151
# Epoch 65/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.4724e-04 - mae: 0.0128 - val_loss: 4.6582e-04 - val_mae: 0.0147
# Epoch 66/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.3121e-04 - mae: 0.0124 - val_loss: 4.4895e-04 - val_mae: 0.0143
# Epoch 67/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.1959e-04 - mae: 0.0121 - val_loss: 4.3331e-04 - val_mae: 0.0142
# Epoch 68/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 3.0871e-04 - mae: 0.0119 - val_loss: 4.1693e-04 - val_mae: 0.0139
# Epoch 69/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.9705e-04 - mae: 0.0117 - val_loss: 4.0888e-04 - val_mae: 0.0137
# Epoch 70/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.9303e-04 - mae: 0.0115 - val_loss: 3.9614e-04 - val_mae: 0.0134
# Epoch 71/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.8307e-04 - mae: 0.0114 - val_loss: 3.8243e-04 - val_mae: 0.0131
# Epoch 72/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.7143e-04 - mae: 0.0110 - val_loss: 3.6811e-04 - val_mae: 0.0126
# Epoch 73/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.6025e-04 - mae: 0.0105 - val_loss: 3.5147e-04 - val_mae: 0.0122
# Epoch 74/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.4778e-04 - mae: 0.0102 - val_loss: 3.4072e-04 - val_mae: 0.0120
# Epoch 75/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.4104e-04 - mae: 0.0102 - val_loss: 3.2994e-04 - val_mae: 0.0118
# Epoch 76/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.3252e-04 - mae: 0.0100 - val_loss: 3.1972e-04 - val_mae: 0.0116
# Epoch 77/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.2430e-04 - mae: 0.0097 - val_loss: 3.0932e-04 - val_mae: 0.0114
# Epoch 78/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.1696e-04 - mae: 0.0094 - val_loss: 2.9864e-04 - val_mae: 0.0111
# Epoch 79/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.0836e-04 - mae: 0.0092 - val_loss: 2.8232e-04 - val_mae: 0.0109
# Epoch 80/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.0111e-04 - mae: 0.0092 - val_loss: 2.6920e-04 - val_mae: 0.0107
# Epoch 81/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 1.9538e-04 - mae: 0.0092 - val_loss: 2.5759e-04 - val_mae: 0.0103
# Epoch 82/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.8726e-04 - mae: 0.0088 - val_loss: 2.4965e-04 - val_mae: 0.0100
# Epoch 83/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.8011e-04 - mae: 0.0085 - val_loss: 2.4004e-04 - val_mae: 0.0098
# Epoch 84/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.7187e-04 - mae: 0.0083 - val_loss: 2.3208e-04 - val_mae: 0.0096
# Epoch 85/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.6669e-04 - mae: 0.0081 - val_loss: 2.2370e-04 - val_mae: 0.0094
# Epoch 86/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.6046e-04 - mae: 0.0080 - val_loss: 2.1605e-04 - val_mae: 0.0092
# Epoch 87/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.5334e-04 - mae: 0.0077 - val_loss: 2.0948e-04 - val_mae: 0.0091
# Epoch 88/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.4760e-04 - mae: 0.0075 - val_loss: 2.0012e-04 - val_mae: 0.0088
# Epoch 89/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.4069e-04 - mae: 0.0073 - val_loss: 1.9197e-04 - val_mae: 0.0086
# Epoch 90/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3553e-04 - mae: 0.0072 - val_loss: 1.8374e-04 - val_mae: 0.0083
# Epoch 91/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 1.2939e-04 - mae: 0.0069 - val_loss: 1.7595e-04 - val_mae: 0.0081
# Epoch 92/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.2323e-04 - mae: 0.0066 - val_loss: 1.6851e-04 - val_mae: 0.0079
# Epoch 93/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1813e-04 - mae: 0.0065 - val_loss: 1.6035e-04 - val_mae: 0.0078
# Epoch 94/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.1305e-04 - mae: 0.0065 - val_loss: 1.5199e-04 - val_mae: 0.0076
# Epoch 95/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.0897e-04 - mae: 0.0064 - val_loss: 1.4232e-04 - val_mae: 0.0074
# Epoch 96/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0333e-04 - mae: 0.0063 - val_loss: 1.3494e-04 - val_mae: 0.0073
# Epoch 97/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.8385e-05 - mae: 0.0062 - val_loss: 1.2972e-04 - val_mae: 0.0072
# Epoch 98/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 9.4398e-05 - mae: 0.0061 - val_loss: 1.2323e-04 - val_mae: 0.0069
# Epoch 99/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 8.9936e-05 - mae: 0.0059 - val_loss: 1.1782e-04 - val_mae: 0.0067
# Epoch 100/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.4969e-05 - mae: 0.0056 - val_loss: 1.1358e-04 - val_mae: 0.0066
# Epoch 101/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.1342e-05 - mae: 0.0055 - val_loss: 1.0817e-04 - val_mae: 0.0064
# Epoch 102/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 7.7524e-05 - mae: 0.0054 - val_loss: 1.0066e-04 - val_mae: 0.0061
# Epoch 103/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 7.2643e-05 - mae: 0.0051 - val_loss: 9.3661e-05 - val_mae: 0.0059
# Epoch 104/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.8295e-05 - mae: 0.0049 - val_loss: 8.9120e-05 - val_mae: 0.0058
# Epoch 105/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.5236e-05 - mae: 0.0049 - val_loss: 8.4841e-05 - val_mae: 0.0056
# Epoch 106/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 6.1205e-05 - mae: 0.0047 - val_loss: 8.2309e-05 - val_mae: 0.0053
# Epoch 107/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.7849e-05 - mae: 0.0044 - val_loss: 7.8221e-05 - val_mae: 0.0052
# Epoch 108/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 5.4478e-05 - mae: 0.0042 - val_loss: 7.4524e-05 - val_mae: 0.0050
# Epoch 109/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 5.1842e-05 - mae: 0.0041 - val_loss: 7.0319e-05 - val_mae: 0.0048
# Epoch 110/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 4.9146e-05 - mae: 0.0040 - val_loss: 6.5560e-05 - val_mae: 0.0047
# Epoch 111/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 4.6095e-05 - mae: 0.0039 - val_loss: 6.1825e-05 - val_mae: 0.0046
# Epoch 112/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 4.4340e-05 - mae: 0.0038 - val_loss: 5.7799e-05 - val_mae: 0.0045
# Epoch 113/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 4.1011e-05 - mae: 0.0038 - val_loss: 5.4537e-05 - val_mae: 0.0044
# Epoch 114/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 3.9033e-05 - mae: 0.0038 - val_loss: 5.0649e-05 - val_mae: 0.0043
# Epoch 115/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.6530e-05 - mae: 0.0037 - val_loss: 4.6727e-05 - val_mae: 0.0041
# Epoch 116/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 3.3878e-05 - mae: 0.0035 - val_loss: 4.3744e-05 - val_mae: 0.0039
# Epoch 117/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 3.2105e-05 - mae: 0.0034 - val_loss: 4.1211e-05 - val_mae: 0.0038
# Epoch 118/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 3.0006e-05 - mae: 0.0033 - val_loss: 3.9257e-05 - val_mae: 0.0037
# Epoch 119/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.8029e-05 - mae: 0.0032 - val_loss: 3.7424e-05 - val_mae: 0.0036
# Epoch 120/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.6431e-05 - mae: 0.0031 - val_loss: 3.5531e-05 - val_mae: 0.0036
# Epoch 121/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.5175e-05 - mae: 0.0030 - val_loss: 3.3130e-05 - val_mae: 0.0034
# Epoch 122/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.3455e-05 - mae: 0.0028 - val_loss: 3.1223e-05 - val_mae: 0.0033
# Epoch 123/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.1837e-05 - mae: 0.0028 - val_loss: 2.8983e-05 - val_mae: 0.0032
# Epoch 124/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 2.0231e-05 - mae: 0.0027 - val_loss: 2.7142e-05 - val_mae: 0.0031
# Epoch 125/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.8997e-05 - mae: 0.0026 - val_loss: 2.5668e-05 - val_mae: 0.0031
# Epoch 126/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.8018e-05 - mae: 0.0026 - val_loss: 2.3902e-05 - val_mae: 0.0029
# Epoch 127/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.6619e-05 - mae: 0.0024 - val_loss: 2.2676e-05 - val_mae: 0.0028
# Epoch 128/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.5652e-05 - mae: 0.0023 - val_loss: 2.1373e-05 - val_mae: 0.0027
# Epoch 129/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.4641e-05 - mae: 0.0022 - val_loss: 2.0704e-05 - val_mae: 0.0026
# Epoch 130/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.4058e-05 - mae: 0.0022 - val_loss: 1.9190e-05 - val_mae: 0.0026
# Epoch 131/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.3056e-05 - mae: 0.0022 - val_loss: 1.7875e-05 - val_mae: 0.0025
# Epoch 132/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.2398e-05 - mae: 0.0021 - val_loss: 1.6646e-05 - val_mae: 0.0024
# Epoch 133/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.1612e-05 - mae: 0.0021 - val_loss: 1.5811e-05 - val_mae: 0.0023
# Epoch 134/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.0965e-05 - mae: 0.0020 - val_loss: 1.4786e-05 - val_mae: 0.0022
# Epoch 135/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.0154e-05 - mae: 0.0019 - val_loss: 1.3965e-05 - val_mae: 0.0022
# Epoch 136/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.6121e-06 - mae: 0.0019 - val_loss: 1.3083e-05 - val_mae: 0.0022
# Epoch 137/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.0591e-06 - mae: 0.0018 - val_loss: 1.2213e-05 - val_mae: 0.0021
# Epoch 138/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 8.7478e-06 - mae: 0.0018 - val_loss: 1.1457e-05 - val_mae: 0.0021
# Epoch 139/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.2301e-06 - mae: 0.0018 - val_loss: 1.0809e-05 - val_mae: 0.0021
# Epoch 140/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 7.9028e-06 - mae: 0.0018 - val_loss: 1.0175e-05 - val_mae: 0.0020
# Epoch 141/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 7.4752e-06 - mae: 0.0017 - val_loss: 9.7864e-06 - val_mae: 0.0019
# Epoch 142/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 7.2011e-06 - mae: 0.0017 - val_loss: 9.3913e-06 - val_mae: 0.0019
# Epoch 143/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.8991e-06 - mae: 0.0016 - val_loss: 9.1292e-06 - val_mae: 0.0019
# Epoch 144/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.5522e-06 - mae: 0.0016 - val_loss: 8.6546e-06 - val_mae: 0.0018
# Epoch 145/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.3445e-06 - mae: 0.0016 - val_loss: 8.0971e-06 - val_mae: 0.0018
# Epoch 146/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 5.9946e-06 - mae: 0.0015 - val_loss: 7.7429e-06 - val_mae: 0.0017
# Epoch 147/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 5.6438e-06 - mae: 0.0015 - val_loss: 7.4523e-06 - val_mae: 0.0016
# Epoch 148/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 5.3422e-06 - mae: 0.0014 - val_loss: 7.1693e-06 - val_mae: 0.0016
# Epoch 149/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 5.1457e-06 - mae: 0.0014 - val_loss: 6.9823e-06 - val_mae: 0.0016
# Epoch 150/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 5.0263e-06 - mae: 0.0014 - val_loss: 7.1043e-06 - val_mae: 0.0016
# Epoch 151/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 4.9141e-06 - mae: 0.0014 - val_loss: 7.1432e-06 - val_mae: 0.0017
# Epoch 152/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.9058e-06 - mae: 0.0014 - val_loss: 7.0014e-06 - val_mae: 0.0017
# Epoch 153/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 5.0539e-06 - mae: 0.0015 - val_loss: 7.1573e-06 - val_mae: 0.0017
# Epoch 154/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.0979e-06 - mae: 0.0015 - val_loss: 6.9910e-06 - val_mae: 0.0017
# Epoch 155/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 4.9257e-06 - mae: 0.0015 - val_loss: 6.6830e-06 - val_mae: 0.0017
# Epoch 156/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 4.6449e-06 - mae: 0.0014 - val_loss: 6.4194e-06 - val_mae: 0.0016
# Epoch 157/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 4.5561e-06 - mae: 0.0014 - val_loss: 6.0717e-06 - val_mae: 0.0016
# Epoch 158/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 4.3025e-06 - mae: 0.0014 - val_loss: 5.6330e-06 - val_mae: 0.0015
# Epoch 159/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 4.1295e-06 - mae: 0.0013 - val_loss: 5.3697e-06 - val_mae: 0.0015
# Epoch 160/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 4.0000e-06 - mae: 0.0013 - val_loss: 5.3174e-06 - val_mae: 0.0015
# Epoch 161/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.8746e-06 - mae: 0.0013 - val_loss: 5.1109e-06 - val_mae: 0.0015
# Epoch 162/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 3.6548e-06 - mae: 0.0013 - val_loss: 4.9123e-06 - val_mae: 0.0014
# Epoch 163/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 3.5852e-06 - mae: 0.0012 - val_loss: 4.8185e-06 - val_mae: 0.0014
# Epoch 164/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.5314e-06 - mae: 0.0012 - val_loss: 4.6604e-06 - val_mae: 0.0014
# Epoch 165/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.4230e-06 - mae: 0.0012 - val_loss: 4.5619e-06 - val_mae: 0.0013
# Epoch 166/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 3.3939e-06 - mae: 0.0012 - val_loss: 4.3354e-06 - val_mae: 0.0013
# Epoch 167/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 3.2828e-06 - mae: 0.0012 - val_loss: 4.2724e-06 - val_mae: 0.0013
# Epoch 168/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 3.1944e-06 - mae: 0.0012 - val_loss: 4.2259e-06 - val_mae: 0.0013
# Epoch 169/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.1773e-06 - mae: 0.0011 - val_loss: 4.2504e-06 - val_mae: 0.0013
# Epoch 170/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.1315e-06 - mae: 0.0011 - val_loss: 4.2449e-06 - val_mae: 0.0013
# Epoch 171/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 3.1615e-06 - mae: 0.0012 - val_loss: 4.1408e-06 - val_mae: 0.0013
# Epoch 172/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.0279e-06 - mae: 0.0012 - val_loss: 3.9852e-06 - val_mae: 0.0013
# Epoch 173/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.9954e-06 - mae: 0.0011 - val_loss: 3.8277e-06 - val_mae: 0.0013
# Epoch 174/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.9666e-06 - mae: 0.0011 - val_loss: 4.1207e-06 - val_mae: 0.0014
# Epoch 175/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 3.1784e-06 - mae: 0.0012 - val_loss: 3.8832e-06 - val_mae: 0.0013
# Epoch 176/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.9983e-06 - mae: 0.0012 - val_loss: 3.7453e-06 - val_mae: 0.0013
# Epoch 177/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 3.0101e-06 - mae: 0.0012 - val_loss: 3.8758e-06 - val_mae: 0.0013
# Epoch 178/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 3.0289e-06 - mae: 0.0012 - val_loss: 3.8741e-06 - val_mae: 0.0013
# Epoch 179/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.8885e-06 - mae: 0.0011 - val_loss: 3.9355e-06 - val_mae: 0.0013
# Epoch 180/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.9530e-06 - mae: 0.0011 - val_loss: 3.9489e-06 - val_mae: 0.0013
# Epoch 181/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.9753e-06 - mae: 0.0011 - val_loss: 4.0333e-06 - val_mae: 0.0013
# Epoch 182/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 2.9808e-06 - mae: 0.0012 - val_loss: 4.0933e-06 - val_mae: 0.0013
# Epoch 183/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.9102e-06 - mae: 0.0011 - val_loss: 3.8642e-06 - val_mae: 0.0013
# Epoch 184/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.8728e-06 - mae: 0.0012 - val_loss: 3.8518e-06 - val_mae: 0.0013
# Epoch 185/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 3.0020e-06 - mae: 0.0012 - val_loss: 4.0197e-06 - val_mae: 0.0014
# Epoch 186/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.9147e-06 - mae: 0.0012 - val_loss: 4.1035e-06 - val_mae: 0.0014
# Epoch 187/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.9562e-06 - mae: 0.0012 - val_loss: 3.7236e-06 - val_mae: 0.0013
# Epoch 188/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.8046e-06 - mae: 0.0012 - val_loss: 3.5774e-06 - val_mae: 0.0013
# Epoch 189/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.8194e-06 - mae: 0.0012 - val_loss: 3.5343e-06 - val_mae: 0.0012
# Epoch 190/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.6269e-06 - mae: 0.0011 - val_loss: 3.7728e-06 - val_mae: 0.0013
# Epoch 191/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.6749e-06 - mae: 0.0011 - val_loss: 3.7816e-06 - val_mae: 0.0013
# Epoch 192/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.8878e-06 - mae: 0.0012 - val_loss: 3.7704e-06 - val_mae: 0.0014
# Epoch 193/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.8046e-06 - mae: 0.0012 - val_loss: 3.5824e-06 - val_mae: 0.0013
# Epoch 194/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.7170e-06 - mae: 0.0011 - val_loss: 3.3710e-06 - val_mae: 0.0012
# Epoch 195/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.7154e-06 - mae: 0.0011 - val_loss: 3.4443e-06 - val_mae: 0.0013
# Epoch 196/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.7328e-06 - mae: 0.0012 - val_loss: 3.5965e-06 - val_mae: 0.0013
# Epoch 197/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.6263e-06 - mae: 0.0011 - val_loss: 3.4855e-06 - val_mae: 0.0012
# Epoch 198/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.5114e-06 - mae: 0.0011 - val_loss: 3.3964e-06 - val_mae: 0.0012
# Epoch 199/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.6707e-06 - mae: 0.0011 - val_loss: 3.4094e-06 - val_mae: 0.0013
# Epoch 200/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.5758e-06 - mae: 0.0011 - val_loss: 3.3556e-06 - val_mae: 0.0012
# Epoch 201/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.5210e-06 - mae: 0.0011 - val_loss: 3.2682e-06 - val_mae: 0.0012
# Epoch 202/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.4664e-06 - mae: 0.0011 - val_loss: 3.1804e-06 - val_mae: 0.0012
# Epoch 203/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.5048e-06 - mae: 0.0011 - val_loss: 3.1035e-06 - val_mae: 0.0012
# Epoch 204/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.3775e-06 - mae: 0.0010 - val_loss: 3.2434e-06 - val_mae: 0.0012
# Epoch 205/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 2.3655e-06 - mae: 0.0010 - val_loss: 3.5735e-06 - val_mae: 0.0013
# Epoch 206/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 2.6156e-06 - mae: 0.0012 - val_loss: 3.1308e-06 - val_mae: 0.0012
# Epoch 207/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.4243e-06 - mae: 0.0010 - val_loss: 3.0313e-06 - val_mae: 0.0011
# Epoch 208/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.4196e-06 - mae: 0.0010 - val_loss: 3.1656e-06 - val_mae: 0.0012
# Epoch 209/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.4139e-06 - mae: 0.0011 - val_loss: 3.1955e-06 - val_mae: 0.0012
# Epoch 210/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.3895e-06 - mae: 0.0010 - val_loss: 3.1636e-06 - val_mae: 0.0012
# Epoch 211/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.4557e-06 - mae: 0.0011 - val_loss: 2.9920e-06 - val_mae: 0.0012
# Epoch 212/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.2569e-06 - mae: 0.0011 - val_loss: 2.9604e-06 - val_mae: 0.0012
# Epoch 213/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.3268e-06 - mae: 0.0011 - val_loss: 2.9304e-06 - val_mae: 0.0011
# Epoch 214/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.2888e-06 - mae: 0.0010 - val_loss: 3.1286e-06 - val_mae: 0.0012
# Epoch 215/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.3328e-06 - mae: 0.0011 - val_loss: 3.0639e-06 - val_mae: 0.0012
# Epoch 216/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 2.2395e-06 - mae: 0.0010 - val_loss: 2.7446e-06 - val_mae: 0.0011
# Epoch 217/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.1747e-06 - mae: 9.9439e-04 - val_loss: 2.7608e-06 - val_mae: 0.0012
# Epoch 218/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.2433e-06 - mae: 0.0011 - val_loss: 2.8415e-06 - val_mae: 0.0011
# Epoch 219/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.1114e-06 - mae: 9.8943e-04 - val_loss: 3.0844e-06 - val_mae: 0.0011
# Epoch 220/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.1675e-06 - mae: 9.7323e-04 - val_loss: 3.0244e-06 - val_mae: 0.0011
# Epoch 221/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.1581e-06 - mae: 9.6501e-04 - val_loss: 2.8867e-06 - val_mae: 0.0011
# Epoch 222/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.1398e-06 - mae: 0.0010 - val_loss: 2.7850e-06 - val_mae: 0.0011
# Epoch 223/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 2.2204e-06 - mae: 9.8855e-04 - val_loss: 2.8973e-06 - val_mae: 0.0012
# Epoch 224/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 2.2327e-06 - mae: 0.0011 - val_loss: 2.9554e-06 - val_mae: 0.0012
# Epoch 225/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.2926e-06 - mae: 0.0011 - val_loss: 2.6058e-06 - val_mae: 0.0011
# Epoch 226/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 2.1202e-06 - mae: 0.0010 - val_loss: 2.5711e-06 - val_mae: 0.0011
# Epoch 227/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 2.0826e-06 - mae: 0.0010 - val_loss: 2.6047e-06 - val_mae: 0.0011
# Epoch 228/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.9693e-06 - mae: 9.6167e-04 - val_loss: 2.7807e-06 - val_mae: 0.0011
# Epoch 229/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 2.0362e-06 - mae: 9.6117e-04 - val_loss: 2.8170e-06 - val_mae: 0.0011
# Epoch 230/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 2.0775e-06 - mae: 9.8582e-04 - val_loss: 2.5903e-06 - val_mae: 0.0011
# Epoch 231/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.9389e-06 - mae: 9.6046e-04 - val_loss: 2.4145e-06 - val_mae: 0.0010
# Epoch 232/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.9115e-06 - mae: 9.2495e-04 - val_loss: 2.4401e-06 - val_mae: 0.0010
# Epoch 233/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.8963e-06 - mae: 9.4982e-04 - val_loss: 2.4858e-06 - val_mae: 0.0011
# Epoch 234/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.8445e-06 - mae: 9.2589e-04 - val_loss: 2.4856e-06 - val_mae: 0.0011
# Epoch 235/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.8559e-06 - mae: 9.4020e-04 - val_loss: 2.3510e-06 - val_mae: 0.0010
# Epoch 236/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.9007e-06 - mae: 9.6687e-04 - val_loss: 2.3633e-06 - val_mae: 0.0010
# Epoch 237/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.8702e-06 - mae: 9.3009e-04 - val_loss: 2.7048e-06 - val_mae: 0.0011
# Epoch 238/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.9367e-06 - mae: 9.5755e-04 - val_loss: 2.4028e-06 - val_mae: 0.0010
# Epoch 239/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.8923e-06 - mae: 9.4798e-04 - val_loss: 2.2251e-06 - val_mae: 0.0010
# Epoch 240/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.9132e-06 - mae: 9.6268e-04 - val_loss: 2.2901e-06 - val_mae: 0.0010
# Epoch 241/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.8764e-06 - mae: 9.5128e-04 - val_loss: 2.3175e-06 - val_mae: 9.9206e-04
# Epoch 242/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.7418e-06 - mae: 8.7472e-04 - val_loss: 2.5067e-06 - val_mae: 0.0010
# Epoch 243/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.8586e-06 - mae: 9.1943e-04 - val_loss: 2.3415e-06 - val_mae: 0.0010
# Epoch 244/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.7937e-06 - mae: 9.1070e-04 - val_loss: 2.3228e-06 - val_mae: 0.0011
# Epoch 245/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.7814e-06 - mae: 9.3753e-04 - val_loss: 2.2437e-06 - val_mae: 9.9803e-04
# Epoch 246/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.7604e-06 - mae: 9.0586e-04 - val_loss: 2.3877e-06 - val_mae: 0.0010
# Epoch 247/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.7927e-06 - mae: 9.3106e-04 - val_loss: 2.3785e-06 - val_mae: 0.0010
# Epoch 248/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.7269e-06 - mae: 8.7513e-04 - val_loss: 2.1877e-06 - val_mae: 9.6470e-04
# Epoch 249/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.6972e-06 - mae: 8.6940e-04 - val_loss: 2.1158e-06 - val_mae: 9.7836e-04
# Epoch 250/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.6319e-06 - mae: 8.8327e-04 - val_loss: 2.3394e-06 - val_mae: 0.0010
# Epoch 251/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.7881e-06 - mae: 9.0890e-04 - val_loss: 2.3467e-06 - val_mae: 0.0010
# Epoch 252/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.7685e-06 - mae: 8.8633e-04 - val_loss: 2.4015e-06 - val_mae: 0.0011
# Epoch 253/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.7886e-06 - mae: 9.4588e-04 - val_loss: 2.1658e-06 - val_mae: 9.5384e-04
# Epoch 254/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.6572e-06 - mae: 8.6049e-04 - val_loss: 2.0636e-06 - val_mae: 9.4154e-04
# Epoch 255/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.6925e-06 - mae: 8.8193e-04 - val_loss: 2.0714e-06 - val_mae: 9.8476e-04
# Epoch 256/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.6771e-06 - mae: 9.1346e-04 - val_loss: 2.0094e-06 - val_mae: 9.3903e-04
# Epoch 257/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.5426e-06 - mae: 8.3749e-04 - val_loss: 2.0606e-06 - val_mae: 9.4536e-04
# Epoch 258/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.6042e-06 - mae: 8.5792e-04 - val_loss: 2.2071e-06 - val_mae: 0.0010
# Epoch 259/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.7075e-06 - mae: 9.3281e-04 - val_loss: 2.1433e-06 - val_mae: 0.0010
# Epoch 260/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.6271e-06 - mae: 8.9846e-04 - val_loss: 2.1111e-06 - val_mae: 9.6385e-04
# Epoch 261/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.7048e-06 - mae: 8.9210e-04 - val_loss: 2.1984e-06 - val_mae: 0.0010
# Epoch 262/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.8127e-06 - mae: 9.7912e-04 - val_loss: 2.1184e-06 - val_mae: 0.0010
# Epoch 263/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.6982e-06 - mae: 9.1691e-04 - val_loss: 2.1351e-06 - val_mae: 0.0010
# Epoch 264/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.6772e-06 - mae: 9.0522e-04 - val_loss: 2.4396e-06 - val_mae: 0.0011
# Epoch 265/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.9142e-06 - mae: 0.0010 - val_loss: 2.2251e-06 - val_mae: 0.0010
# Epoch 266/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.8540e-06 - mae: 9.5581e-04 - val_loss: 2.0077e-06 - val_mae: 9.6460e-04
# Epoch 267/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.5699e-06 - mae: 8.5979e-04 - val_loss: 2.1571e-06 - val_mae: 9.8741e-04
# Epoch 268/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.6352e-06 - mae: 8.9442e-04 - val_loss: 2.1293e-06 - val_mae: 9.8653e-04
# Epoch 269/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.6735e-06 - mae: 9.0820e-04 - val_loss: 2.1311e-06 - val_mae: 9.9494e-04
# Epoch 270/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.5899e-06 - mae: 8.7793e-04 - val_loss: 1.9788e-06 - val_mae: 0.0010
# Epoch 271/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.5598e-06 - mae: 9.0948e-04 - val_loss: 1.8729e-06 - val_mae: 9.3570e-04
# Epoch 272/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.5148e-06 - mae: 8.5289e-04 - val_loss: 1.8857e-06 - val_mae: 9.2862e-04
# Epoch 273/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.4062e-06 - mae: 8.1591e-04 - val_loss: 2.1505e-06 - val_mae: 9.8266e-04
# Epoch 274/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.5708e-06 - mae: 8.5999e-04 - val_loss: 2.0758e-06 - val_mae: 9.8959e-04
# Epoch 275/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.5595e-06 - mae: 8.7656e-04 - val_loss: 1.8285e-06 - val_mae: 9.1232e-04
# Epoch 276/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.4787e-06 - mae: 8.3716e-04 - val_loss: 1.8381e-06 - val_mae: 9.8004e-04
# Epoch 277/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.5860e-06 - mae: 9.2652e-04 - val_loss: 1.9968e-06 - val_mae: 9.6888e-04
# Epoch 278/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.5568e-06 - mae: 8.6950e-04 - val_loss: 2.2406e-06 - val_mae: 0.0010
# Epoch 279/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.8280e-06 - mae: 9.4603e-04 - val_loss: 2.2779e-06 - val_mae: 0.0011
# Epoch 280/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.8107e-06 - mae: 0.0010 - val_loss: 2.0239e-06 - val_mae: 0.0010
# Epoch 281/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.8803e-06 - mae: 9.9524e-04 - val_loss: 1.9663e-06 - val_mae: 9.6685e-04
# Epoch 282/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.6180e-06 - mae: 8.9038e-04 - val_loss: 2.2566e-06 - val_mae: 0.0011
# Epoch 283/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.6758e-06 - mae: 9.2105e-04 - val_loss: 2.0073e-06 - val_mae: 9.7248e-04
# Epoch 284/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.6106e-06 - mae: 9.0493e-04 - val_loss: 1.8477e-06 - val_mae: 9.6741e-04
# Epoch 285/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.5372e-06 - mae: 9.2064e-04 - val_loss: 1.8539e-06 - val_mae: 9.3971e-04
# Epoch 286/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.4687e-06 - mae: 8.5675e-04 - val_loss: 2.0437e-06 - val_mae: 9.2859e-04
# Epoch 287/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.4727e-06 - mae: 8.1501e-04 - val_loss: 1.9752e-06 - val_mae: 9.6530e-04
# Epoch 288/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.5202e-06 - mae: 8.8199e-04 - val_loss: 1.7167e-06 - val_mae: 9.0284e-04
# Epoch 289/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3981e-06 - mae: 8.1803e-04 - val_loss: 1.7276e-06 - val_mae: 9.2053e-04
# Epoch 290/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.4484e-06 - mae: 8.4955e-04 - val_loss: 1.8994e-06 - val_mae: 9.3271e-04
# Epoch 291/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.4665e-06 - mae: 8.3344e-04 - val_loss: 2.1320e-06 - val_mae: 9.7396e-04
# Epoch 292/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.5780e-06 - mae: 8.6138e-04 - val_loss: 2.0210e-06 - val_mae: 0.0010
# Epoch 293/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.5347e-06 - mae: 9.2523e-04 - val_loss: 1.7282e-06 - val_mae: 9.0172e-04
# Epoch 294/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.5330e-06 - mae: 8.6706e-04 - val_loss: 1.7654e-06 - val_mae: 9.2080e-04
# Epoch 295/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.4017e-06 - mae: 8.4384e-04 - val_loss: 1.9142e-06 - val_mae: 9.3899e-04
# Epoch 296/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.4249e-06 - mae: 8.2604e-04 - val_loss: 1.7269e-06 - val_mae: 8.6461e-04
# Epoch 297/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.3912e-06 - mae: 8.0254e-04 - val_loss: 1.8252e-06 - val_mae: 9.5986e-04
# Epoch 298/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.4871e-06 - mae: 9.0532e-04 - val_loss: 1.8115e-06 - val_mae: 9.0160e-04
# Epoch 299/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.4557e-06 - mae: 8.3869e-04 - val_loss: 1.7297e-06 - val_mae: 8.9934e-04
# Epoch 300/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.3085e-06 - mae: 8.0540e-04 - val_loss: 1.8754e-06 - val_mae: 9.4838e-04
# Epoch 301/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.4057e-06 - mae: 8.4107e-04 - val_loss: 1.6700e-06 - val_mae: 8.7417e-04
# Epoch 302/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.4243e-06 - mae: 8.4314e-04 - val_loss: 1.5810e-06 - val_mae: 8.8868e-04
# Epoch 303/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.3754e-06 - mae: 8.6381e-04 - val_loss: 1.7916e-06 - val_mae: 9.5895e-04
# Epoch 304/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.3797e-06 - mae: 8.4836e-04 - val_loss: 1.7842e-06 - val_mae: 9.1748e-04
# Epoch 305/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.4416e-06 - mae: 8.5951e-04 - val_loss: 1.9706e-06 - val_mae: 0.0010
# Epoch 306/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.5131e-06 - mae: 9.1264e-04 - val_loss: 1.6734e-06 - val_mae: 8.9080e-04
# Epoch 307/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.3358e-06 - mae: 8.1417e-04 - val_loss: 1.5226e-06 - val_mae: 8.7466e-04
# Epoch 308/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.3402e-06 - mae: 8.4098e-04 - val_loss: 1.8073e-06 - val_mae: 9.4416e-04
# Epoch 309/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3786e-06 - mae: 8.3521e-04 - val_loss: 1.6832e-06 - val_mae: 8.8755e-04
# Epoch 310/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.3478e-06 - mae: 8.2312e-04 - val_loss: 1.6178e-06 - val_mae: 8.7091e-04
# Epoch 311/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.3735e-06 - mae: 8.3770e-04 - val_loss: 1.6414e-06 - val_mae: 8.5316e-04
# Epoch 312/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.2568e-06 - mae: 7.6880e-04 - val_loss: 1.7110e-06 - val_mae: 8.6113e-04
# Epoch 313/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3080e-06 - mae: 7.8291e-04 - val_loss: 1.9644e-06 - val_mae: 9.9362e-04
# Epoch 314/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 1.5579e-06 - mae: 9.1124e-04 - val_loss: 1.7481e-06 - val_mae: 9.4089e-04
# Epoch 315/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4759e-06 - mae: 8.7517e-04 - val_loss: 1.5739e-06 - val_mae: 9.2941e-04
# Epoch 316/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.4439e-06 - mae: 8.9921e-04 - val_loss: 1.5120e-06 - val_mae: 8.6336e-04
# Epoch 317/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.2253e-06 - mae: 7.8741e-04 - val_loss: 1.8600e-06 - val_mae: 9.1385e-04
# Epoch 318/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3719e-06 - mae: 8.0956e-04 - val_loss: 1.7484e-06 - val_mae: 9.4579e-04
# Epoch 319/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.3840e-06 - mae: 8.8315e-04 - val_loss: 1.5156e-06 - val_mae: 8.4942e-04
# Epoch 320/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.2786e-06 - mae: 7.9353e-04 - val_loss: 1.7810e-06 - val_mae: 0.0010
# Epoch 321/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.3814e-06 - mae: 8.9328e-04 - val_loss: 1.6277e-06 - val_mae: 9.3214e-04
# Epoch 322/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.4246e-06 - mae: 8.9518e-04 - val_loss: 1.4504e-06 - val_mae: 8.3485e-04
# Epoch 323/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3960e-06 - mae: 8.4595e-04 - val_loss: 1.5982e-06 - val_mae: 9.3042e-04
# Epoch 324/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.3339e-06 - mae: 8.6300e-04 - val_loss: 1.6009e-06 - val_mae: 8.6645e-04
# Epoch 325/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 1.2442e-06 - mae: 7.8172e-04 - val_loss: 1.6707e-06 - val_mae: 8.7359e-04
# Epoch 326/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.2594e-06 - mae: 7.7900e-04 - val_loss: 1.7269e-06 - val_mae: 9.1876e-04
# Epoch 327/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.2970e-06 - mae: 8.2663e-04 - val_loss: 1.5713e-06 - val_mae: 8.6808e-04
# Epoch 328/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.2625e-06 - mae: 7.9964e-04 - val_loss: 1.7361e-06 - val_mae: 9.3508e-04
# Epoch 329/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.2320e-06 - mae: 7.9917e-04 - val_loss: 1.5290e-06 - val_mae: 8.6937e-04
# Epoch 330/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.1361e-06 - mae: 7.6542e-04 - val_loss: 1.4188e-06 - val_mae: 8.2627e-04
# Epoch 331/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.2767e-06 - mae: 7.9873e-04 - val_loss: 1.7654e-06 - val_mae: 9.8752e-04
# Epoch 332/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.4269e-06 - mae: 9.0021e-04 - val_loss: 1.6016e-06 - val_mae: 9.1184e-04
# Epoch 333/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.4032e-06 - mae: 8.7784e-04 - val_loss: 1.3530e-06 - val_mae: 8.5157e-04
# Epoch 334/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.1862e-06 - mae: 8.1883e-04 - val_loss: 1.5105e-06 - val_mae: 8.5664e-04
# Epoch 335/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.2035e-06 - mae: 7.5576e-04 - val_loss: 1.5568e-06 - val_mae: 8.3518e-04
# Epoch 336/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.2279e-06 - mae: 7.5936e-04 - val_loss: 1.8896e-06 - val_mae: 9.7220e-04
# Epoch 337/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.4146e-06 - mae: 8.6888e-04 - val_loss: 1.5179e-06 - val_mae: 8.4826e-04
# Epoch 338/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.3714e-06 - mae: 8.2193e-04 - val_loss: 1.5050e-06 - val_mae: 9.1362e-04
# Epoch 339/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.3029e-06 - mae: 8.5509e-04 - val_loss: 1.6327e-06 - val_mae: 9.0464e-04
# Epoch 340/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.1927e-06 - mae: 7.7374e-04 - val_loss: 1.6423e-06 - val_mae: 8.7009e-04
# Epoch 341/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.3419e-06 - mae: 8.1032e-04 - val_loss: 1.6836e-06 - val_mae: 9.9816e-04
# Epoch 342/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.4663e-06 - mae: 9.5402e-04 - val_loss: 1.6149e-06 - val_mae: 9.0382e-04
# Epoch 343/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3371e-06 - mae: 8.2556e-04 - val_loss: 1.7377e-06 - val_mae: 9.4911e-04
# Epoch 344/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.3304e-06 - mae: 8.4824e-04 - val_loss: 1.5124e-06 - val_mae: 8.6084e-04
# Epoch 345/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1128e-06 - mae: 7.4854e-04 - val_loss: 1.4237e-06 - val_mae: 8.4099e-04
# Epoch 346/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1118e-06 - mae: 7.6737e-04 - val_loss: 1.3309e-06 - val_mae: 8.2061e-04
# Epoch 347/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1310e-06 - mae: 7.7675e-04 - val_loss: 1.2527e-06 - val_mae: 7.8196e-04
# Epoch 348/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.0813e-06 - mae: 7.4307e-04 - val_loss: 1.4179e-06 - val_mae: 8.3732e-04
# Epoch 349/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.1531e-06 - mae: 7.6495e-04 - val_loss: 1.3563e-06 - val_mae: 7.8473e-04
# Epoch 350/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.0875e-06 - mae: 7.2539e-04 - val_loss: 1.4353e-06 - val_mae: 8.4323e-04
# Epoch 351/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2489e-06 - mae: 8.2434e-04 - val_loss: 1.6187e-06 - val_mae: 9.3653e-04
# Epoch 352/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2834e-06 - mae: 8.4684e-04 - val_loss: 1.4708e-06 - val_mae: 8.8940e-04
# Epoch 353/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2465e-06 - mae: 8.2439e-04 - val_loss: 1.4031e-06 - val_mae: 8.8956e-04
# Epoch 354/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.3779e-06 - mae: 9.0153e-04 - val_loss: 1.3916e-06 - val_mae: 8.2455e-04
# Epoch 355/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1265e-06 - mae: 7.4923e-04 - val_loss: 1.4071e-06 - val_mae: 7.9836e-04
# Epoch 356/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0570e-06 - mae: 7.1101e-04 - val_loss: 1.4339e-06 - val_mae: 8.5653e-04
# Epoch 357/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1350e-06 - mae: 8.0053e-04 - val_loss: 1.3908e-06 - val_mae: 8.0280e-04
# Epoch 358/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.0337e-06 - mae: 7.0016e-04 - val_loss: 1.3875e-06 - val_mae: 8.5322e-04
# Epoch 359/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.0571e-06 - mae: 7.5734e-04 - val_loss: 1.4181e-06 - val_mae: 8.5121e-04
# Epoch 360/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.2082e-06 - mae: 8.1057e-04 - val_loss: 1.9354e-06 - val_mae: 0.0010
# Epoch 361/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.4865e-06 - mae: 9.0655e-04 - val_loss: 1.5227e-06 - val_mae: 8.8301e-04
# Epoch 362/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.4860e-06 - mae: 8.9752e-04 - val_loss: 1.5989e-06 - val_mae: 9.8242e-04
# Epoch 363/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.5016e-06 - mae: 9.6982e-04 - val_loss: 1.3774e-06 - val_mae: 8.2101e-04
# Epoch 364/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1570e-06 - mae: 7.5529e-04 - val_loss: 1.3668e-06 - val_mae: 7.9913e-04
# Epoch 365/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.0897e-06 - mae: 7.3094e-04 - val_loss: 1.6151e-06 - val_mae: 9.2399e-04
# Epoch 366/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.3077e-06 - mae: 8.6770e-04 - val_loss: 1.3543e-06 - val_mae: 8.2240e-04
# Epoch 367/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.1250e-06 - mae: 7.6870e-04 - val_loss: 1.3894e-06 - val_mae: 8.7229e-04
# Epoch 368/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.1025e-06 - mae: 7.9572e-04 - val_loss: 1.5301e-06 - val_mae: 9.0008e-04
# Epoch 369/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1953e-06 - mae: 8.0304e-04 - val_loss: 1.2034e-06 - val_mae: 7.9811e-04
# Epoch 370/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.0752e-06 - mae: 7.7530e-04 - val_loss: 1.1544e-06 - val_mae: 7.7689e-04
# Epoch 371/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 9.7189e-07 - mae: 7.2602e-04 - val_loss: 1.1177e-06 - val_mae: 7.4883e-04
# Epoch 372/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.5361e-07 - mae: 7.0316e-04 - val_loss: 1.1927e-06 - val_mae: 7.7062e-04
# Epoch 373/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.7372e-07 - mae: 7.0718e-04 - val_loss: 1.3401e-06 - val_mae: 7.6913e-04
# Epoch 374/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.0414e-06 - mae: 6.9707e-04 - val_loss: 1.3515e-06 - val_mae: 8.2423e-04
# Epoch 375/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.0491e-06 - mae: 7.4427e-04 - val_loss: 1.2930e-06 - val_mae: 8.2210e-04
# Epoch 376/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1010e-06 - mae: 7.7754e-04 - val_loss: 1.3007e-06 - val_mae: 8.7201e-04
# Epoch 377/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.1112e-06 - mae: 8.1411e-04 - val_loss: 1.2383e-06 - val_mae: 8.0092e-04
# Epoch 378/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0403e-06 - mae: 7.4957e-04 - val_loss: 1.4575e-06 - val_mae: 8.8895e-04
# Epoch 379/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1935e-06 - mae: 8.3184e-04 - val_loss: 1.2752e-06 - val_mae: 7.7919e-04
# Epoch 380/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.1414e-06 - mae: 7.5504e-04 - val_loss: 1.2965e-06 - val_mae: 8.1327e-04
# Epoch 381/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.0318e-06 - mae: 7.5614e-04 - val_loss: 1.3244e-06 - val_mae: 7.9332e-04
# Epoch 382/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 9.8200e-07 - mae: 6.9978e-04 - val_loss: 1.1035e-06 - val_mae: 6.9822e-04
# Epoch 383/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.7858e-07 - mae: 6.5216e-04 - val_loss: 1.2263e-06 - val_mae: 8.2134e-04
# Epoch 384/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.0072e-06 - mae: 7.6057e-04 - val_loss: 1.2044e-06 - val_mae: 7.9056e-04
# Epoch 385/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.1037e-06 - mae: 7.7369e-04 - val_loss: 1.2540e-06 - val_mae: 8.3591e-04
# Epoch 386/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.1067e-06 - mae: 7.9856e-04 - val_loss: 1.2602e-06 - val_mae: 8.3744e-04
# Epoch 387/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.0517e-06 - mae: 7.7054e-04 - val_loss: 1.3614e-06 - val_mae: 8.3413e-04
# Epoch 388/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.0972e-06 - mae: 7.6883e-04 - val_loss: 1.3287e-06 - val_mae: 7.8371e-04
# Epoch 389/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.0382e-06 - mae: 7.2961e-04 - val_loss: 1.0929e-06 - val_mae: 7.4201e-04
# Epoch 390/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 9.2281e-07 - mae: 7.0166e-04 - val_loss: 1.1870e-06 - val_mae: 8.3391e-04
# Epoch 391/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.0513e-06 - mae: 7.9468e-04 - val_loss: 1.1723e-06 - val_mae: 7.6171e-04
# Epoch 392/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.0174e-06 - mae: 7.1588e-04 - val_loss: 1.4219e-06 - val_mae: 8.6818e-04
# Epoch 393/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.1301e-06 - mae: 7.9368e-04 - val_loss: 1.2556e-06 - val_mae: 8.0581e-04
# Epoch 394/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.1115e-06 - mae: 7.7889e-04 - val_loss: 1.2856e-06 - val_mae: 8.4755e-04
# Epoch 395/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.1550e-06 - mae: 8.2549e-04 - val_loss: 1.3123e-06 - val_mae: 8.4305e-04
# Epoch 396/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.9051e-07 - mae: 7.3860e-04 - val_loss: 1.0261e-06 - val_mae: 7.1203e-04
# Epoch 397/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 9.1515e-07 - mae: 7.0833e-04 - val_loss: 1.0563e-06 - val_mae: 7.2953e-04
# Epoch 398/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 8.9336e-07 - mae: 7.0091e-04 - val_loss: 1.1268e-06 - val_mae: 7.5429e-04
# Epoch 399/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 8.8205e-07 - mae: 6.7684e-04 - val_loss: 1.2837e-06 - val_mae: 8.5051e-04
# Epoch 400/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.0760e-06 - mae: 7.9777e-04 - val_loss: 1.3643e-06 - val_mae: 8.2940e-04
# Epoch 401/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2142e-06 - mae: 8.0085e-04 - val_loss: 2.2050e-06 - val_mae: 0.0011
# Epoch 402/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.9713e-06 - mae: 0.0010 - val_loss: 1.8635e-06 - val_mae: 0.0010
# Epoch 403/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.8382e-06 - mae: 0.0010 - val_loss: 1.9206e-06 - val_mae: 0.0010
# Epoch 404/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.0330e-06 - mae: 0.0011 - val_loss: 1.7162e-06 - val_mae: 0.0010
# Epoch 405/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.4812e-06 - mae: 9.3627e-04 - val_loss: 1.5323e-06 - val_mae: 8.8104e-04
# Epoch 406/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.2590e-06 - mae: 8.3555e-04 - val_loss: 1.2352e-06 - val_mae: 7.6878e-04
# Epoch 407/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 9.9405e-07 - mae: 7.1917e-04 - val_loss: 1.3154e-06 - val_mae: 8.5237e-04
# Epoch 408/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0539e-06 - mae: 7.7528e-04 - val_loss: 1.4272e-06 - val_mae: 8.8208e-04
# Epoch 409/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.1695e-06 - mae: 8.2213e-04 - val_loss: 1.4401e-06 - val_mae: 8.9352e-04
# Epoch 410/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.2522e-06 - mae: 8.6118e-04 - val_loss: 1.5098e-06 - val_mae: 8.9305e-04
# Epoch 411/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.3830e-06 - mae: 8.6419e-04 - val_loss: 1.4458e-06 - val_mae: 8.7971e-04
# Epoch 412/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.2112e-06 - mae: 8.2109e-04 - val_loss: 1.5191e-06 - val_mae: 9.1361e-04
# Epoch 413/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.3541e-06 - mae: 8.8747e-04 - val_loss: 1.2300e-06 - val_mae: 8.0490e-04
# Epoch 414/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.0158e-06 - mae: 7.4045e-04 - val_loss: 9.5605e-07 - val_mae: 7.2222e-04
# Epoch 415/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 8.8499e-07 - mae: 7.1384e-04 - val_loss: 9.8925e-07 - val_mae: 7.2033e-04
# Epoch 416/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 8.6539e-07 - mae: 6.9074e-04 - val_loss: 1.0266e-06 - val_mae: 7.2969e-04
# Epoch 417/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.1490e-07 - mae: 6.9728e-04 - val_loss: 1.2460e-06 - val_mae: 8.5011e-04
# Epoch 418/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.0398e-06 - mae: 7.8956e-04 - val_loss: 1.5652e-06 - val_mae: 9.6454e-04
# Epoch 419/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.4804e-06 - mae: 9.4866e-04 - val_loss: 2.3682e-06 - val_mae: 0.0012
# Epoch 420/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2.3429e-06 - mae: 0.0012 - val_loss: 2.8079e-06 - val_mae: 0.0013
# Epoch 421/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.8267e-06 - mae: 0.0013 - val_loss: 3.7252e-06 - val_mae: 0.0015
# Epoch 422/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 3.8450e-06 - mae: 0.0015 - val_loss: 3.4308e-06 - val_mae: 0.0015
# Epoch 423/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.3712e-06 - mae: 0.0015 - val_loss: 2.9754e-06 - val_mae: 0.0013
# Epoch 424/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.0866e-06 - mae: 0.0014 - val_loss: 2.0206e-06 - val_mae: 0.0011
# Epoch 425/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.8594e-06 - mae: 0.0011 - val_loss: 1.1989e-06 - val_mae: 8.0532e-04
# Epoch 426/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.0324e-06 - mae: 7.7180e-04 - val_loss: 9.9912e-07 - val_mae: 6.7506e-04
# Epoch 427/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.7470e-07 - mae: 6.4004e-04 - val_loss: 1.1493e-06 - val_mae: 7.8335e-04
# Epoch 428/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 9.1906e-07 - mae: 7.1267e-04 - val_loss: 1.1626e-06 - val_mae: 8.3346e-04
# Epoch 429/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.1004e-06 - mae: 8.3542e-04 - val_loss: 1.3171e-06 - val_mae: 8.5619e-04
# Epoch 430/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.1195e-06 - mae: 7.8915e-04 - val_loss: 1.6381e-06 - val_mae: 9.5644e-04
# Epoch 431/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.5071e-06 - mae: 9.2449e-04 - val_loss: 1.9188e-06 - val_mae: 0.0010
# Epoch 432/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.9135e-06 - mae: 0.0010 - val_loss: 3.7748e-06 - val_mae: 0.0015
# Epoch 433/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 3.7877e-06 - mae: 0.0015 - val_loss: 4.7298e-06 - val_mae: 0.0017
# Epoch 434/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 5.0626e-06 - mae: 0.0018 - val_loss: 5.8002e-06 - val_mae: 0.0018
# Epoch 435/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 5.9240e-06 - mae: 0.0019 - val_loss: 5.7753e-06 - val_mae: 0.0019
# Epoch 436/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 5.7084e-06 - mae: 0.0019 - val_loss: 6.2532e-06 - val_mae: 0.0020
# Epoch 437/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.9280e-06 - mae: 0.0021 - val_loss: 6.3853e-06 - val_mae: 0.0021
# Epoch 438/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.2285e-06 - mae: 0.0021 - val_loss: 5.3687e-06 - val_mae: 0.0019
# Epoch 439/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 5.8693e-06 - mae: 0.0020 - val_loss: 3.2512e-06 - val_mae: 0.0015
# Epoch 440/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.2442e-06 - mae: 0.0015 - val_loss: 1.6022e-06 - val_mae: 9.4441e-04
# Epoch 441/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.3978e-06 - mae: 8.9131e-04 - val_loss: 1.4234e-06 - val_mae: 9.0907e-04
# Epoch 442/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.4630e-06 - mae: 9.4903e-04 - val_loss: 2.4566e-06 - val_mae: 0.0012
# Epoch 443/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.2214e-06 - mae: 0.0012 - val_loss: 2.2748e-06 - val_mae: 0.0012
# Epoch 444/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.4706e-06 - mae: 0.0013 - val_loss: 1.9874e-06 - val_mae: 0.0011
# Epoch 445/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.7968e-06 - mae: 0.0011 - val_loss: 2.5246e-06 - val_mae: 0.0012
# Epoch 446/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 2.4983e-06 - mae: 0.0012 - val_loss: 3.5549e-06 - val_mae: 0.0015
# Epoch 447/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 3.9760e-06 - mae: 0.0016 - val_loss: 8.2345e-06 - val_mae: 0.0021
# Epoch 448/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.0524e-06 - mae: 0.0021 - val_loss: 7.6509e-06 - val_mae: 0.0022
# Epoch 449/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 8.6698e-06 - mae: 0.0023 - val_loss: 8.0829e-06 - val_mae: 0.0021
# Epoch 450/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.6744e-06 - mae: 0.0023 - val_loss: 8.7475e-06 - val_mae: 0.0024
# Epoch 451/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 8.6179e-06 - mae: 0.0023 - val_loss: 1.1713e-05 - val_mae: 0.0028
# Epoch 452/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.3356e-05 - mae: 0.0030 - val_loss: 1.6665e-05 - val_mae: 0.0034
# Epoch 453/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.7097e-05 - mae: 0.0035 - val_loss: 1.6572e-05 - val_mae: 0.0033
# Epoch 454/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.9546e-05 - mae: 0.0035 - val_loss: 1.2133e-05 - val_mae: 0.0028
# Epoch 455/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.2620e-05 - mae: 0.0029 - val_loss: 7.9380e-06 - val_mae: 0.0022
# Epoch 456/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 8.7656e-06 - mae: 0.0023 - val_loss: 7.2414e-06 - val_mae: 0.0019
# Epoch 457/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.5761e-06 - mae: 0.0020 - val_loss: 7.5088e-06 - val_mae: 0.0021
# Epoch 458/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 7.2187e-06 - mae: 0.0020 - val_loss: 4.4450e-06 - val_mae: 0.0018
# Epoch 459/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 4.8380e-06 - mae: 0.0019 - val_loss: 2.8241e-06 - val_mae: 0.0014
# Epoch 460/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.6564e-06 - mae: 0.0013 - val_loss: 1.5329e-06 - val_mae: 9.3571e-04
# Epoch 461/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.2802e-06 - mae: 8.6030e-04 - val_loss: 2.7332e-06 - val_mae: 0.0013
# Epoch 462/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 2.7138e-06 - mae: 0.0014 - val_loss: 4.2292e-06 - val_mae: 0.0018
# Epoch 463/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.2463e-06 - mae: 0.0018 - val_loss: 3.8841e-06 - val_mae: 0.0016
# Epoch 464/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 4.0606e-06 - mae: 0.0016 - val_loss: 3.2753e-06 - val_mae: 0.0014
# Epoch 464: early stopping
# Restoring model weights from the end of the best epoch: 414.

# %%
model = tf.keras.models.load_model(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') if os.path.exists(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') else model

# %%
# Estrai losses da tutti i folds
train_losses = history.history['loss'][80:]
val_losses   = history.history['val_loss'][80:]

train_losses = train_losses
val_losses = val_losses

# Plot
plt.figure(figsize=(8,5))


# Training loss
plt.plot(train_losses, color='blue', label='Train Loss')
# Validation loss
plt.plot(val_losses, color='red', label='Validation Loss')


# Dettagli grafico
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.savefig(f'{exp_dir}/loss_plot.png')

# %%
def plot_first_n_series(y_pred, y_test, n_series=10, title="Confronto Serie Predette vs Reali"):
    """
    Plotta le prime n_series serie reali e predette per un confronto diretto.

    Args:
        y_pred (np.ndarray): Predizioni del modello (shape: num_samples x seq_len).
        y_test (np.ndarray): Serie reali (shape: num_samples x seq_len).
        n_series (int): Numero di serie da plottare.
        title (str): Titolo del grafico.
    """

    # Limitiamo a n_series per evitare problemi
    n = min(n_series, y_pred.shape[0], y_test.shape[0])

    plt.figure(figsize=(14, 8))

    for i in range(n):
        plt.plot(
            y_test[i], 
            linewidth=1.8, 
            alpha=0.5, 
            label=f"Reale {i+1}" if i == 0 else "",
            color = 'blue'
        )
        plt.plot(
            y_pred[i], 
            linewidth=1.2, 
            linestyle="--", 
            alpha=0.9, 
            label=f"Predetto {i+1}" if i == 0 else "",
            color = 'orange'
        )

    plt.title(title, fontsize=16)
    plt.xlabel("Time Step", fontsize=12)
    plt.ylabel("Valore", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

def plot_diagnosis_gradient(y_pred, y_test, save_path: str,  tolerance:float =0.05, max_samples_heatmap=50, scatter_sample_ratio=0.5, tol_auto = True):
    """
    Dashboard diagnostica con tolleranza AUTO-ADATTIVA alla scala dei dati.
    
    Args:
        tolerance (float): 
            - Se None: La tolleranza viene calcolata automaticamente come il 5% del range dei dati (Max-Min).
            - Se float: Valore assoluto (es. 0.5).
        tol_auto (bool): Se True, usa la tolleranza automatica basata sul range dei dati, altrimenti usa il valore manuale fornito 
        col parametro tolerance.
    """
    
    y_test_flat = y_test.flatten()
    y_pred_flat = y_pred.flatten()

    # ---------------------------------------------------------
    # AUTOMAZIONE TOLLERANZA
    # ---------------------------------------------------------
    if tol_auto:
        data_range = y_test_flat.max() - y_test_flat.min()
        # Impostiamo la tolleranza al 5% del range totale (regolabile)
        tolerance = data_range * tolerance 
        tol_label = f"Auto (5% Range: ±{tolerance:.2f})"
    else:
        tol_label = f"Manuale (±{tolerance})"

    fig, axes = plt.subplots(1, 2, figsize=(22, 8))

    # -----------------------------
    # 1. HEATMAP (SX)
    # -----------------------------
    errors = np.abs(y_test - y_pred)
    errors_subset = errors[:max_samples_heatmap]
    
    # Adattiamo anche la scala colori della heatmap alla tolleranza
    # Tutto ciò che è oltre 3 volte la tolleranza è "errore massimo" visivo
    sns.heatmap(errors_subset, cmap="plasma", ax=axes[0], 
                vmax=tolerance * 3,
                cbar_kws={'label': 'Errore Assoluto'})
    
    axes[0].set_title(f"Heatmap Errori (Primi {max_samples_heatmap} campioni)", fontsize=16)
    axes[0].set_xlabel("Time Step", fontsize=12)
    axes[0].set_ylabel("Indice Campione", fontsize=12)

    # -----------------------------
    # 2. SCATTER CON SFONDO GRADIENTE (DX)
    # -----------------------------
    
    # Campionamento dati
    if scatter_sample_ratio < 1.0:
        mask = np.random.rand(len(y_test_flat)) < scatter_sample_ratio
        sample_test = y_test_flat[mask]
        sample_pred = y_pred_flat[mask]
    else:
        sample_test = y_test_flat
        sample_pred = y_pred_flat

    # Calcolo limiti grafico
    min_val = min(y_test_flat.min(), y_pred_flat.min())
    max_val = max(y_test_flat.max(), y_pred_flat.max())
    padding = (max_val - min_val) * 0.05
    plot_min = min_val - padding
    plot_max = max_val + padding

    # --- SFONDO GRADIENTE ---
    grid_x, grid_y = np.meshgrid(
        np.linspace(plot_min, plot_max, 200),
        np.linspace(plot_min, plot_max, 200)
    )
    grid_z = np.abs(grid_y - grid_x)

    im = axes[1].imshow(
        grid_z, 
        extent=(plot_min, plot_max, plot_min, plot_max), 
        origin='lower', 
        cmap='RdYlGn_r', 
        alpha=0.4, 
        vmax=tolerance * 4, # Il rosso satura a 4x della tolleranza
        aspect='auto'
    )

    # --- PUNTI BLU ---
    axes[1].scatter(
        sample_test, 
        sample_pred, 
        alpha=0.6, 
        s=15, 
        color='royalblue', 
        edgecolors='white', 
        linewidth=0.3,
        label='Campioni'
    )

    axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

    # Metriche
    within_tol = np.mean(np.abs(y_test_flat - y_pred_flat) <= tolerance) * 100

    axes[1].set_title(
        f"Bontà delle previsioni con {tol_label}\nValori nel range di Tolleranza: {within_tol:.1f}%", 
        fontsize=16
    )
    axes[1].set_xlabel("Valore Reale", fontsize=12)
    axes[1].set_ylabel("Valore Predetto", fontsize=12)
    axes[1].set_xlim(plot_min, plot_max)
    axes[1].set_ylim(plot_min, plot_max)
    
    cbar = plt.colorbar(im, ax=axes[1], pad=0.02)
    cbar.set_label('Gravità Errore (Distanza da diagonale)')

    plt.tight_layout()
    plt.savefig(f'{exp_dir}/{save_path}.png')

# %%
y_pred = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred)
y_test_np = scaler_y.inverse_transform(y_test)

plot_diagnosis_gradient(y_pred, y_test_np, save_path='pred_quality', max_samples_heatmap=10, scatter_sample_ratio=0.7)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_96895/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

# %%
save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/TEST', prefix="pred_plot")
# Out:
# Salvo 18 plot in: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/TEST
# Plot salvati correttamente.

# %%
import json
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_and_log(y_true, y_pred, log_path="log.json"):
    # --- Metriche ---
    mae = mean_absolute_error(y_true, y_pred, multioutput="uniform_average")
    rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput="uniform_average"))

    mask = y_true != 0
    mape = float(np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100.0)

    r2 = r2_score(y_true, y_pred, multioutput="uniform_average")

    # Valore medio del test set
    v_mean = float(np.mean(y_true))

    # --- Stampa ---
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    print(f"Test MAPE: {mape:.2f}%")
    print(f"Test R2: {r2:.4f}")
    print(f"Valore medio del test set: {v_mean:.4f}")

    # --- Salvataggio log ---
    log_data = {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2,
        "test_mean_value": v_mean
    }

    with open(log_path, "w") as f:
        json.dump(log_data, f, indent=4)

    print(f"\nLog salvato in: {log_path}")
evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/evaluation_log.json")
# Impostazioni pandas per visualizzare tutti i dati
# Out:
# Test MAE: 0.0217
# Test RMSE: 0.0359
# Test MAPE: 0.02%
# Test R2: 1.0000
# Valore medio del test set: 110.6228
#
# Log salvato in: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/evaluation_log.json

# %% [markdown]
# # globale e federato

# %%
fed = tf.keras.models.load_model('/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Metro.keras')

model  = [fed]
model_name = ["federated"]

# %%
for model, name in zip(model, model_name):
    y_pred = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred)
    y_test_np = scaler_y.inverse_transform(y_test)

    print(f"--- {name} ---")
    #plot_diagnosis_gradient(y_pred, y_test_np, max_samples_heatmap=10, scatter_sample_ratio=0.7)
    evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_evaluation_log.json")
    save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}/TEST', prefix="pred_plot")

    print("\n")
    if name == 'federated':
        model.fit(X_train, y_train, epochs=1000, batch_size=64)
        model.save(f'{exp_dir}/model/{sensor_name}_fed_model.keras')
        y_pred = model.predict(X_test)
        y_pred = scaler_y.inverse_transform(y_pred)
        print(f"--- {name} after local fine-tuning ---")
        plot_diagnosis_gradient(y_pred, y_test_np, save_path=f"{name}_pred_quality", max_samples_heatmap=10, scatter_sample_ratio=0.7)
        save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}_fd/TEST', prefix="pred_plot")
        evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_fd_evaluation_log.json")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# --- federated ---
# Test MAE: 8.6324
# Test RMSE: 12.9732
# Test MAPE: 8.63%
# Test R2: 0.0568
# Valore medio del test set: 110.6228
#
# Log salvato in: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/federated_evaluation_log.json
# Salvo 18 plot in: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/federated/TEST
# Plot salvati correttamente.
#
#
# Epoch 1/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1179 - mae: 0.2765 - mse: 0.1179
# Epoch 2/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1024 - mae: 0.2590 - mse: 0.1024
# Epoch 3/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0841 - mae: 0.2335 - mse: 0.0841
# Epoch 4/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0763 - mae: 0.2208 - mse: 0.0763
# Epoch 5/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0737 - mae: 0.2181 - mse: 0.0737
# Epoch 6/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0633 - mae: 0.1951 - mse: 0.0633
# Epoch 7/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0506 - mae: 0.1720 - mse: 0.0506
# Epoch 8/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0436 - mae: 0.1606 - mse: 0.0436
# Epoch 9/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0410 - mae: 0.1599 - mse: 0.0410
# Epoch 10/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0336 - mae: 0.1450 - mse: 0.0336
# Epoch 11/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0313 - mae: 0.1384 - mse: 0.0313
# Epoch 12/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0275 - mae: 0.1310 - mse: 0.0275
# Epoch 13/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0284 - mae: 0.1308 - mse: 0.0284
# Epoch 14/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0248 - mae: 0.1212 - mse: 0.0248
# Epoch 15/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0258 - mae: 0.1229 - mse: 0.0258
# Epoch 16/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0259 - mae: 0.1238 - mse: 0.0259
# Epoch 17/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0236 - mae: 0.1175 - mse: 0.0236
# Epoch 18/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0191 - mae: 0.1015 - mse: 0.0191
# Epoch 19/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0218 - mae: 0.1104 - mse: 0.0218
# Epoch 20/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0173 - mae: 0.0982 - mse: 0.0173
# Epoch 21/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0189 - mae: 0.1030 - mse: 0.0189
# Epoch 22/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0186 - mae: 0.1013 - mse: 0.0186
# Epoch 23/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0167 - mae: 0.0984 - mse: 0.0167
# Epoch 24/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0150 - mae: 0.0899 - mse: 0.0150
# Epoch 25/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0158 - mae: 0.0940 - mse: 0.0158
# Epoch 26/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149 - mae: 0.0937 - mse: 0.0149
# Epoch 27/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0135 - mae: 0.0864 - mse: 0.0135
# Epoch 28/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0135 - mae: 0.0878 - mse: 0.0135
# Epoch 29/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0136 - mae: 0.0877 - mse: 0.0136
# Epoch 30/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0119 - mae: 0.0820 - mse: 0.0119
# Epoch 31/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0119 - mae: 0.0813 - mse: 0.0119
# Epoch 32/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102 - mae: 0.0752 - mse: 0.0102
# Epoch 33/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0113 - mae: 0.0794 - mse: 0.0113
# Epoch 34/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0098 - mae: 0.0743 - mse: 0.0098
# Epoch 35/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0101 - mae: 0.0750 - mse: 0.0101
# Epoch 36/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0099 - mae: 0.0738 - mse: 0.0099
# Epoch 37/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - mae: 0.0702 - mse: 0.0092
# Epoch 38/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085 - mae: 0.0683 - mse: 0.0085
# Epoch 39/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0096 - mae: 0.0733 - mse: 0.0096
# Epoch 40/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0084 - mae: 0.0680 - mse: 0.0084
# Epoch 41/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - mae: 0.0677 - mse: 0.0083
# Epoch 42/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - mae: 0.0688 - mse: 0.0083
# Epoch 43/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0089 - mae: 0.0707 - mse: 0.0089
# Epoch 44/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0084 - mae: 0.0685 - mse: 0.0084
# Epoch 45/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0087 - mae: 0.0696 - mse: 0.0087
# Epoch 46/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - mae: 0.0714 - mse: 0.0092
# Epoch 47/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - mae: 0.0641 - mse: 0.0079
# Epoch 48/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0087 - mae: 0.0701 - mse: 0.0087
# Epoch 49/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0080 - mae: 0.0654 - mse: 0.0080
# Epoch 50/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - mae: 0.0717 - mse: 0.0089
# Epoch 51/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - mae: 0.0657 - mse: 0.0079
# Epoch 52/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090 - mae: 0.0722 - mse: 0.0090
# Epoch 53/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - mae: 0.0611 - mse: 0.0064
# Epoch 54/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0070 - mae: 0.0643 - mse: 0.0070
# Epoch 55/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0084 - mae: 0.0706 - mse: 0.0084
# Epoch 56/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - mae: 0.0651 - mse: 0.0076
# Epoch 57/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - mae: 0.0627 - mse: 0.0074
# Epoch 58/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - mae: 0.0634 - mse: 0.0070
# Epoch 59/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082 - mae: 0.0658 - mse: 0.0082
# Epoch 60/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - mae: 0.0707 - mse: 0.0089
# Epoch 61/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0105 - mae: 0.0745 - mse: 0.0105
# Epoch 62/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - mae: 0.0643 - mse: 0.0078
# Epoch 63/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - mae: 0.0648 - mse: 0.0069
# Epoch 64/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mae: 0.0616 - mse: 0.0065
# Epoch 65/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - mae: 0.0676 - mse: 0.0077
# Epoch 66/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0059 - mae: 0.0579 - mse: 0.0059
# Epoch 67/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - mae: 0.0618 - mse: 0.0072
# Epoch 68/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - mae: 0.0631 - mse: 0.0072
# Epoch 69/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - mae: 0.0652 - mse: 0.0086
# Epoch 70/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0057 - mae: 0.0577 - mse: 0.0057
# Epoch 71/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - mae: 0.0631 - mse: 0.0077
# Epoch 72/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0062 - mae: 0.0591 - mse: 0.0062
# Epoch 73/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0608 - mse: 0.0063
# Epoch 74/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mae: 0.0627 - mse: 0.0071
# Epoch 75/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - mae: 0.0619 - mse: 0.0074
# Epoch 76/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - mae: 0.0638 - mse: 0.0070
# Epoch 77/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - mae: 0.0584 - mse: 0.0055
# Epoch 78/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0066 - mae: 0.0602 - mse: 0.0066
# Epoch 79/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052 - mae: 0.0546 - mse: 0.0052
# Epoch 80/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - mae: 0.0613 - mse: 0.0068
# Epoch 81/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - mae: 0.0594 - mse: 0.0063
# Epoch 82/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060 - mae: 0.0565 - mse: 0.0060
# Epoch 83/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057 - mae: 0.0558 - mse: 0.0057
# Epoch 84/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066 - mae: 0.0610 - mse: 0.0066
# Epoch 85/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056 - mae: 0.0561 - mse: 0.0056
# Epoch 86/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0061 - mae: 0.0590 - mse: 0.0061
# Epoch 87/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mae: 0.0624 - mse: 0.0071
# Epoch 88/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0066 - mae: 0.0628 - mse: 0.0066
# Epoch 89/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0067 - mae: 0.0617 - mse: 0.0067
# Epoch 90/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062 - mae: 0.0592 - mse: 0.0062
# Epoch 91/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061 - mae: 0.0588 - mse: 0.0061
# Epoch 92/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0058 - mae: 0.0571 - mse: 0.0058
# Epoch 93/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069 - mae: 0.0626 - mse: 0.0069
# Epoch 94/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062 - mae: 0.0585 - mse: 0.0062
# Epoch 95/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - mae: 0.0632 - mse: 0.0071
# Epoch 96/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - mae: 0.0557 - mse: 0.0057
# Epoch 97/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0067 - mae: 0.0595 - mse: 0.0067
# Epoch 98/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0060 - mae: 0.0554 - mse: 0.0060
# Epoch 99/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0063 - mae: 0.0610 - mse: 0.0063
# Epoch 100/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - mae: 0.0563 - mse: 0.0057
# Epoch 101/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070 - mae: 0.0616 - mse: 0.0070
# Epoch 102/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0059 - mae: 0.0577 - mse: 0.0059
# Epoch 103/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070 - mae: 0.0631 - mse: 0.0070
# Epoch 104/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063 - mae: 0.0608 - mse: 0.0063
# Epoch 105/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062 - mae: 0.0588 - mse: 0.0062
# Epoch 106/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0057 - mae: 0.0560 - mse: 0.0057
# Epoch 107/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0064 - mae: 0.0605 - mse: 0.0064
# Epoch 108/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0059 - mae: 0.0578 - mse: 0.0059
# Epoch 109/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0076 - mae: 0.0626 - mse: 0.0076
# Epoch 110/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - mae: 0.0512 - mse: 0.0045
# Epoch 111/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - mae: 0.0614 - mse: 0.0075
# Epoch 112/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0065 - mae: 0.0609 - mse: 0.0065
# Epoch 113/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0055 - mae: 0.0551 - mse: 0.0055
# Epoch 114/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0050 - mae: 0.0538 - mse: 0.0050
# Epoch 115/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - mae: 0.0563 - mse: 0.0057
# Epoch 116/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - mae: 0.0592 - mse: 0.0072
# Epoch 117/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058 - mae: 0.0557 - mse: 0.0058
# Epoch 118/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060 - mae: 0.0560 - mse: 0.0060
# Epoch 119/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0044 - mae: 0.0499 - mse: 0.0044
# Epoch 120/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - mae: 0.0557 - mse: 0.0060
# Epoch 121/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - mae: 0.0550 - mse: 0.0055
# Epoch 122/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061 - mae: 0.0575 - mse: 0.0061
# Epoch 123/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0059 - mae: 0.0571 - mse: 0.0059
# Epoch 124/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0592 - mse: 0.0063
# Epoch 125/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - mae: 0.0562 - mse: 0.0055
# Epoch 126/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0051 - mae: 0.0543 - mse: 0.0051
# Epoch 127/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0051 - mae: 0.0532 - mse: 0.0051
# Epoch 128/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0064 - mae: 0.0606 - mse: 0.0064
# Epoch 129/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062 - mae: 0.0594 - mse: 0.0062
# Epoch 130/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058 - mae: 0.0563 - mse: 0.0058
# Epoch 131/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - mae: 0.0512 - mse: 0.0049
# Epoch 132/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0046 - mae: 0.0482 - mse: 0.0046
# Epoch 133/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0055 - mae: 0.0558 - mse: 0.0055
# Epoch 134/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0054 - mae: 0.0562 - mse: 0.0054
# Epoch 135/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052 - mae: 0.0539 - mse: 0.0052
# Epoch 136/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - mae: 0.0511 - mse: 0.0045
# Epoch 137/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058 - mae: 0.0556 - mse: 0.0058
# Epoch 138/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0532 - mse: 0.0051
# Epoch 139/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0521 - mse: 0.0046
# Epoch 140/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0553 - mse: 0.0055
# Epoch 141/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0059 - mae: 0.0556 - mse: 0.0059
# Epoch 142/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0059 - mae: 0.0574 - mse: 0.0059
# Epoch 143/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0063 - mae: 0.0573 - mse: 0.0063
# Epoch 144/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - mae: 0.0504 - mse: 0.0044
# Epoch 145/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0511 - mse: 0.0046
# Epoch 146/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0560 - mse: 0.0056
# Epoch 147/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0580 - mse: 0.0068
# Epoch 148/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0553 - mse: 0.0055
# Epoch 149/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mae: 0.0537 - mse: 0.0053
# Epoch 150/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0515 - mse: 0.0048
# Epoch 151/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0456 - mse: 0.0038
# Epoch 152/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0547 - mse: 0.0055
# Epoch 153/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0517 - mse: 0.0047
# Epoch 154/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0065 - mae: 0.0591 - mse: 0.0065
# Epoch 155/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mae: 0.0522 - mse: 0.0049
# Epoch 156/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0496 - mse: 0.0042
# Epoch 157/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0527 - mse: 0.0051
# Epoch 158/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mae: 0.0511 - mse: 0.0049
# Epoch 159/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0471 - mse: 0.0041
# Epoch 160/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0071 - mae: 0.0597 - mse: 0.0071
# Epoch 161/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - mae: 0.0526 - mse: 0.0050
# Epoch 162/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0524 - mse: 0.0047
# Epoch 163/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0538 - mse: 0.0052
# Epoch 164/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0494 - mse: 0.0045
# Epoch 165/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0498 - mse: 0.0046
# Epoch 166/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058 - mae: 0.0583 - mse: 0.0058
# Epoch 167/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mae: 0.0508 - mse: 0.0049
# Epoch 168/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0501 - mse: 0.0047
# Epoch 169/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0480 - mse: 0.0042
# Epoch 170/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0514 - mse: 0.0047
# Epoch 171/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0552 - mse: 0.0054
# Epoch 172/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0535 - mse: 0.0052
# Epoch 173/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - mae: 0.0569 - mse: 0.0060
# Epoch 174/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0048 - mae: 0.0503 - mse: 0.0048
# Epoch 175/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0467 - mse: 0.0040
# Epoch 176/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056 - mae: 0.0559 - mse: 0.0056
# Epoch 177/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0503 - mse: 0.0046
# Epoch 178/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0497 - mse: 0.0047
# Epoch 179/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - mae: 0.0500 - mse: 0.0046
# Epoch 180/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0458 - mse: 0.0036
# Epoch 181/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - mae: 0.0589 - mse: 0.0063
# Epoch 182/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0489 - mse: 0.0044
# Epoch 183/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0502 - mse: 0.0051
# Epoch 184/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0556 - mse: 0.0055
# Epoch 185/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0553 - mse: 0.0056
# Epoch 186/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0543 - mse: 0.0051
# Epoch 187/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0496 - mse: 0.0042
# Epoch 188/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0529 - mse: 0.0051
# Epoch 189/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066 - mae: 0.0586 - mse: 0.0066
# Epoch 190/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0568 - mse: 0.0054
# Epoch 191/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0055 - mae: 0.0524 - mse: 0.0055
# Epoch 192/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - mae: 0.0573 - mse: 0.0061
# Epoch 193/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mae: 0.0516 - mse: 0.0049
# Epoch 194/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mae: 0.0514 - mse: 0.0049
# Epoch 195/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0061 - mae: 0.0562 - mse: 0.0061
# Epoch 196/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0497 - mse: 0.0045
# Epoch 197/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0473 - mse: 0.0039
# Epoch 198/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - mae: 0.0477 - mse: 0.0039
# Epoch 199/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0500 - mse: 0.0041
# Epoch 200/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0493 - mse: 0.0041
# Epoch 201/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0499 - mse: 0.0045
# Epoch 202/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0515 - mse: 0.0048
# Epoch 203/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0520 - mse: 0.0047
# Epoch 204/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0553 - mse: 0.0056
# Epoch 205/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0499 - mse: 0.0046
# Epoch 206/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - mae: 0.0525 - mse: 0.0050
# Epoch 207/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - mae: 0.0501 - mse: 0.0044
# Epoch 208/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0487 - mse: 0.0044
# Epoch 209/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0509 - mse: 0.0048
# Epoch 210/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0500 - mse: 0.0044
# Epoch 211/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0495 - mse: 0.0042
# Epoch 212/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0450 - mse: 0.0038
# Epoch 213/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0453 - mse: 0.0039
# Epoch 214/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0445 - mse: 0.0040
# Epoch 215/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054 - mae: 0.0543 - mse: 0.0054
# Epoch 216/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0497 - mse: 0.0047
# Epoch 217/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0486 - mse: 0.0043
# Epoch 218/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0480 - mse: 0.0042
# Epoch 219/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0452 - mse: 0.0037
# Epoch 220/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0483 - mse: 0.0044
# Epoch 221/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0520 - mse: 0.0047
# Epoch 222/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0467 - mse: 0.0039
# Epoch 223/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0501 - mse: 0.0044
# Epoch 224/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - mae: 0.0513 - mse: 0.0050
# Epoch 225/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0494 - mse: 0.0044
# Epoch 226/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0479 - mse: 0.0047
# Epoch 227/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0488 - mse: 0.0047
# Epoch 228/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0050 - mae: 0.0533 - mse: 0.0050
# Epoch 229/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0052 - mae: 0.0538 - mse: 0.0052
# Epoch 230/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - mae: 0.0514 - mse: 0.0047
# Epoch 231/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - mae: 0.0516 - mse: 0.0048
# Epoch 232/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0464 - mse: 0.0039
# Epoch 233/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0464 - mse: 0.0038
# Epoch 234/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mae: 0.0511 - mse: 0.0049
# Epoch 235/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - mae: 0.0471 - mse: 0.0041
# Epoch 236/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0461 - mse: 0.0040
# Epoch 237/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0514 - mse: 0.0051
# Epoch 238/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0452 - mse: 0.0040
# Epoch 239/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0459 - mse: 0.0038
# Epoch 240/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0479 - mse: 0.0043
# Epoch 241/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0470 - mse: 0.0043
# Epoch 242/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mae: 0.0521 - mse: 0.0053
# Epoch 243/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0473 - mse: 0.0039
# Epoch 244/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0491 - mse: 0.0046
# Epoch 245/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - mae: 0.0561 - mse: 0.0057
# Epoch 246/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - mae: 0.0538 - mse: 0.0050
# Epoch 247/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0466 - mse: 0.0038
# Epoch 248/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0504 - mse: 0.0047
# Epoch 249/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0485 - mse: 0.0044
# Epoch 250/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0527 - mse: 0.0051
# Epoch 251/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0526 - mse: 0.0051
# Epoch 252/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0477 - mse: 0.0040
# Epoch 253/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - mae: 0.0544 - mse: 0.0057
# Epoch 254/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0488 - mse: 0.0042
# Epoch 255/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0456 - mse: 0.0036
# Epoch 256/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0519 - mse: 0.0048
# Epoch 257/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0464 - mse: 0.0041
# Epoch 258/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0483 - mse: 0.0043
# Epoch 259/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0447 - mse: 0.0038
# Epoch 260/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0483 - mse: 0.0045
# Epoch 261/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0504 - mse: 0.0051
# Epoch 262/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0493 - mse: 0.0046
# Epoch 263/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0480 - mse: 0.0040
# Epoch 264/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - mae: 0.0535 - mse: 0.0060
# Epoch 265/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0485 - mse: 0.0043
# Epoch 266/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - mae: 0.0481 - mse: 0.0041
# Epoch 267/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - mae: 0.0478 - mse: 0.0042
# Epoch 268/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0553 - mse: 0.0056
# Epoch 269/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057 - mae: 0.0542 - mse: 0.0057
# Epoch 270/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mae: 0.0543 - mse: 0.0053
# Epoch 271/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0483 - mse: 0.0043
# Epoch 272/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060 - mae: 0.0563 - mse: 0.0060
# Epoch 273/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0506 - mse: 0.0046
# Epoch 274/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - mae: 0.0522 - mse: 0.0050
# Epoch 275/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0493 - mse: 0.0044
# Epoch 276/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0460 - mse: 0.0039
# Epoch 277/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0472 - mse: 0.0042
# Epoch 278/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0469 - mse: 0.0041
# Epoch 279/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0530 - mse: 0.0056
# Epoch 280/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052 - mae: 0.0532 - mse: 0.0052
# Epoch 281/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0448 - mse: 0.0036
# Epoch 282/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - mae: 0.0528 - mse: 0.0053
# Epoch 283/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0425 - mse: 0.0035
# Epoch 284/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0483 - mse: 0.0042
# Epoch 285/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0044 - mae: 0.0490 - mse: 0.0044
# Epoch 286/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0043 - mae: 0.0491 - mse: 0.0043
# Epoch 287/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0045 - mae: 0.0483 - mse: 0.0045
# Epoch 288/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041 - mae: 0.0471 - mse: 0.0041
# Epoch 289/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0478 - mse: 0.0040
# Epoch 290/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0488 - mse: 0.0044
# Epoch 291/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0485 - mse: 0.0042
# Epoch 292/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0497 - mse: 0.0045
# Epoch 293/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0480 - mse: 0.0037
# Epoch 294/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0450 - mse: 0.0038
# Epoch 295/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0490 - mse: 0.0045
# Epoch 296/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0457 - mse: 0.0039
# Epoch 297/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0480 - mse: 0.0044
# Epoch 298/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mae: 0.0422 - mse: 0.0032
# Epoch 299/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0441 - mse: 0.0036
# Epoch 300/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0474 - mse: 0.0041
# Epoch 301/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0442 - mse: 0.0036
# Epoch 302/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0438 - mse: 0.0036
# Epoch 303/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0509 - mse: 0.0048
# Epoch 304/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0454 - mse: 0.0037
# Epoch 305/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0509 - mse: 0.0051
# Epoch 306/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0455 - mse: 0.0039
# Epoch 307/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - mae: 0.0517 - mse: 0.0050
# Epoch 308/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - mae: 0.0473 - mse: 0.0040
# Epoch 309/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0410 - mse: 0.0031
# Epoch 310/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0462 - mse: 0.0041
# Epoch 311/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - mae: 0.0520 - mse: 0.0050
# Epoch 312/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0503 - mse: 0.0044
# Epoch 313/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0510 - mse: 0.0044
# Epoch 314/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0475 - mse: 0.0042
# Epoch 315/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0439 - mse: 0.0037
# Epoch 316/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0488 - mse: 0.0043
# Epoch 317/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0491 - mse: 0.0047
# Epoch 318/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0040 - mae: 0.0463 - mse: 0.0040
# Epoch 319/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - mae: 0.0440 - mse: 0.0036
# Epoch 320/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0448 - mse: 0.0035
# Epoch 321/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0462 - mse: 0.0037
# Epoch 322/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0506 - mse: 0.0046
# Epoch 323/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mae: 0.0519 - mse: 0.0049
# Epoch 324/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0453 - mse: 0.0037
# Epoch 325/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mae: 0.0418 - mse: 0.0030
# Epoch 326/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0429 - mse: 0.0031
# Epoch 327/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0464 - mse: 0.0042
# Epoch 328/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mae: 0.0431 - mse: 0.0032
# Epoch 329/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0491 - mse: 0.0043
# Epoch 330/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0450 - mse: 0.0037
# Epoch 331/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0438 - mse: 0.0034
# Epoch 332/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - mae: 0.0417 - mse: 0.0032
# Epoch 333/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mae: 0.0470 - mse: 0.0038
# Epoch 334/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - mae: 0.0472 - mse: 0.0043
# Epoch 335/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0432 - mse: 0.0035
# Epoch 336/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - mae: 0.0482 - mse: 0.0041
# Epoch 337/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - mae: 0.0465 - mse: 0.0040
# Epoch 338/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0037 - mae: 0.0452 - mse: 0.0037
# Epoch 339/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - mae: 0.0504 - mse: 0.0046
# Epoch 340/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - mae: 0.0522 - mse: 0.0048
# Epoch 341/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - mae: 0.0459 - mse: 0.0039
# Epoch 342/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0443 - mse: 0.0035
# Epoch 343/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - mae: 0.0439 - mse: 0.0033
# Epoch 344/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - mae: 0.0461 - mse: 0.0040
# Epoch 345/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0438 - mse: 0.0036
# Epoch 346/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - mae: 0.0448 - mse: 0.0037
# Epoch 347/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0491 - mse: 0.0046
# Epoch 348/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - mae: 0.0456 - mse: 0.0039
# Epoch 349/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - mae: 0.0464 - mse: 0.0041
# Epoch 350/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - mae: 0.0477 - mse: 0.0041
# Epoch 351/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - mae: 0.0462 - mse: 0.0039
# Epoch 352/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - mae: 0.0433 - mse: 0.0037
# Epoch 353/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mae: 0.0388 - mse: 0.0030
# Epoch 354/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - mae: 0.0412 - mse: 0.0029
# Epoch 355/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0431 - mse: 0.0034
# Epoch 356/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - mae: 0.0496 - mse: 0.0043
# Epoch 357/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - mae: 0.0503 - mse: 0.0049
# Epoch 358/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025 - mae: 0.0375 - mse: 0.0025
# Epoch 359/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - mae: 0.0501 - mse: 0.0051
# Epoch 360/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0508 - mse: 0.0046
# Epoch 361/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - mae: 0.0488 - mse: 0.0041
# Epoch 362/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0041 - mae: 0.0472 - mse: 0.0041
# Epoch 363/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0451 - mse: 0.0035
# Epoch 364/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0430 - mse: 0.0034
# Epoch 365/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - mae: 0.0438 - mse: 0.0036
# Epoch 366/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - mae: 0.0465 - mse: 0.0041
# Epoch 367/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0442 - mse: 0.0035
# Epoch 368/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - mae: 0.0433 - mse: 0.0036
# Epoch 369/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - mae: 0.0485 - mse: 0.0042
# Epoch 370/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mae: 0.0457 - mse: 0.0038
# Epoch 371/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - mae: 0.0454 - mse: 0.0042
# Epoch 372/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0038 - mae: 0.0470 - mse: 0.0038
# Epoch 373/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0503 - mse: 0.0044
# Epoch 374/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0499 - mse: 0.0045
# Epoch 375/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0411 - mse: 0.0031
# Epoch 376/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0457 - mse: 0.0041
# Epoch 377/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mae: 0.0493 - mse: 0.0049
# Epoch 378/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0449 - mse: 0.0035
# Epoch 379/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0459 - mse: 0.0038
# Epoch 380/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - mae: 0.0462 - mse: 0.0037
# Epoch 381/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0479 - mse: 0.0042
# Epoch 382/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0441 - mse: 0.0037
# Epoch 383/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0461 - mse: 0.0041
# Epoch 384/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - mae: 0.0479 - mse: 0.0048
# Epoch 385/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0463 - mse: 0.0037
# Epoch 386/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0424 - mse: 0.0035
# Epoch 387/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0470 - mse: 0.0039
# Epoch 388/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mae: 0.0411 - mse: 0.0030
# Epoch 389/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0469 - mse: 0.0041
# Epoch 390/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0469 - mse: 0.0040
# Epoch 391/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mae: 0.0398 - mse: 0.0030
# Epoch 392/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0439 - mse: 0.0036
# Epoch 393/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0443 - mse: 0.0034
# Epoch 394/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - mae: 0.0430 - mse: 0.0037
# Epoch 395/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - mae: 0.0418 - mse: 0.0036
# Epoch 396/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0398 - mse: 0.0028
# Epoch 397/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mae: 0.0399 - mse: 0.0029
# Epoch 398/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0416 - mse: 0.0034
# Epoch 399/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0448 - mse: 0.0040
# Epoch 400/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0447 - mse: 0.0042
# Epoch 401/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0432 - mse: 0.0036
# Epoch 402/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0407 - mse: 0.0031
# Epoch 403/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mae: 0.0415 - mse: 0.0030
# Epoch 404/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0041 - mae: 0.0500 - mse: 0.0041
# Epoch 405/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0517 - mse: 0.0051
# Epoch 406/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mae: 0.0423 - mse: 0.0032
# Epoch 407/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0437 - mse: 0.0037
# Epoch 408/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0486 - mse: 0.0042
# Epoch 409/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0488 - mse: 0.0045
# Epoch 410/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0471 - mse: 0.0040
# Epoch 411/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0531 - mse: 0.0051
# Epoch 412/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0429 - mse: 0.0034
# Epoch 413/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - mae: 0.0433 - mse: 0.0033
# Epoch 414/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0503 - mse: 0.0046
# Epoch 415/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0497 - mse: 0.0045
# Epoch 416/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0495 - mse: 0.0044
# Epoch 417/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0448 - mse: 0.0037
# Epoch 418/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0457 - mse: 0.0038
# Epoch 419/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0454 - mse: 0.0038
# Epoch 420/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0500 - mse: 0.0043
# Epoch 421/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mae: 0.0523 - mse: 0.0049
# Epoch 422/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0489 - mse: 0.0046
# Epoch 423/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0513 - mse: 0.0045
# Epoch 424/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0495 - mse: 0.0046
# Epoch 425/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0477 - mse: 0.0042
# Epoch 426/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - mae: 0.0421 - mse: 0.0031
# Epoch 427/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0039 - mae: 0.0461 - mse: 0.0039
# Epoch 428/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0039 - mae: 0.0458 - mse: 0.0039
# Epoch 429/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043 - mae: 0.0491 - mse: 0.0043
# Epoch 430/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0488 - mse: 0.0045
# Epoch 431/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0454 - mse: 0.0039
# Epoch 432/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0487 - mse: 0.0047
# Epoch 433/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0473 - mse: 0.0043
# Epoch 434/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0454 - mse: 0.0045
# Epoch 435/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0462 - mse: 0.0038
# Epoch 436/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0451 - mse: 0.0040
# Epoch 437/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0427 - mse: 0.0034
# Epoch 438/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - mae: 0.0438 - mse: 0.0033
# Epoch 439/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0488 - mse: 0.0043
# Epoch 440/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mae: 0.0433 - mse: 0.0032
# Epoch 441/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0437 - mse: 0.0035
# Epoch 442/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mae: 0.0390 - mse: 0.0026
# Epoch 443/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0466 - mse: 0.0039
# Epoch 444/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - mae: 0.0488 - mse: 0.0042
# Epoch 445/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - mae: 0.0403 - mse: 0.0036
# Epoch 446/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0440 - mse: 0.0034
# Epoch 447/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0456 - mse: 0.0041
# Epoch 448/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0444 - mse: 0.0039
# Epoch 449/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0440 - mse: 0.0035
# Epoch 450/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mae: 0.0414 - mse: 0.0028
# Epoch 451/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - mae: 0.0419 - mse: 0.0033
# Epoch 452/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0443 - mse: 0.0039
# Epoch 453/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mae: 0.0418 - mse: 0.0032
# Epoch 454/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - mae: 0.0471 - mse: 0.0045
# Epoch 455/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mae: 0.0391 - mse: 0.0029
# Epoch 456/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0433 - mse: 0.0036
# Epoch 457/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0443 - mse: 0.0039
# Epoch 458/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mae: 0.0394 - mse: 0.0028
# Epoch 459/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - mae: 0.0424 - mse: 0.0033
# Epoch 460/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0420 - mse: 0.0031
# Epoch 461/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0467 - mse: 0.0041
# Epoch 462/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0469 - mse: 0.0041
# Epoch 463/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0443 - mse: 0.0039
# Epoch 464/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0438 - mse: 0.0034
# Epoch 465/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0401 - mse: 0.0031
# Epoch 466/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0432 - mse: 0.0037
# Epoch 467/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0441 - mse: 0.0039
# Epoch 468/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - mae: 0.0460 - mse: 0.0037
# Epoch 469/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0412 - mse: 0.0031
# Epoch 470/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024 - mae: 0.0370 - mse: 0.0024
# Epoch 471/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0419 - mse: 0.0034
# Epoch 472/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0444 - mse: 0.0041
# Epoch 473/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0463 - mse: 0.0038
# Epoch 474/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0391 - mse: 0.0027
# Epoch 475/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0426 - mse: 0.0034
# Epoch 476/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0423 - mse: 0.0034
# Epoch 477/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0443 - mse: 0.0035
# Epoch 478/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0459 - mse: 0.0039
# Epoch 479/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - mae: 0.0496 - mse: 0.0047
# Epoch 480/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0434 - mse: 0.0034
# Epoch 481/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0464 - mse: 0.0040
# Epoch 482/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mae: 0.0399 - mse: 0.0032
# Epoch 483/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0456 - mse: 0.0040
# Epoch 484/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0503 - mse: 0.0043
# Epoch 485/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0458 - mse: 0.0039
# Epoch 486/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0481 - mse: 0.0040
# Epoch 487/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mae: 0.0411 - mse: 0.0030
# Epoch 488/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0465 - mse: 0.0038
# Epoch 489/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - mae: 0.0508 - mse: 0.0045
# Epoch 490/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0037 - mae: 0.0455 - mse: 0.0037
# Epoch 491/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0037 - mae: 0.0464 - mse: 0.0037
# Epoch 492/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043 - mae: 0.0490 - mse: 0.0043
# Epoch 493/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0443 - mse: 0.0036
# Epoch 494/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0510 - mse: 0.0046
# Epoch 495/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0456 - mse: 0.0038
# Epoch 496/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mae: 0.0382 - mse: 0.0026
# Epoch 497/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0434 - mse: 0.0031
# Epoch 498/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0484 - mse: 0.0043
# Epoch 499/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0476 - mse: 0.0041
# Epoch 500/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0464 - mse: 0.0039
# Epoch 501/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0414 - mse: 0.0035
# Epoch 502/1000
# ...
# Epoch 841/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mae: 0.0414 - mse: 0.0030
# Epoch 842/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - mae: 0.0432 - mse: 0.0033
# Epoch 843/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - mae: 0.0448 - mse: 0.0035
# Epoch 844/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - mae: 0.0481 - mse: 0.0041
# Epoch 845/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - mae: 0.0431 - mse: 0.0032
# Epoch 846/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0450 - mse: 0.0035
# Epoch 847/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mae: 0.0421 - mse: 0.0029
# Epoch 848/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027 - mae: 0.0397 - mse: 0.0027
# Epoch 849/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - mae: 0.0434 - mse: 0.0037
# Epoch 850/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0402 - mse: 0.0028
# Epoch 851/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - mae: 0.0452 - mse: 0.0040
# Epoch 852/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0036 - mae: 0.0436 - mse: 0.0036
# Epoch 853/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0430 - mse: 0.0034
# Epoch 854/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - mae: 0.0356 - mse: 0.0023
# Epoch 855/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - mae: 0.0428 - mse: 0.0031
# Epoch 856/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0438 - mse: 0.0035
# Epoch 857/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mae: 0.0414 - mse: 0.0030
# Epoch 858/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0435 - mse: 0.0035
# Epoch 859/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0428 - mse: 0.0034
# Epoch 860/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - mae: 0.0424 - mse: 0.0032
# Epoch 861/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0412 - mse: 0.0034
# Epoch 862/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - mae: 0.0435 - mse: 0.0032
# Epoch 863/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - mae: 0.0419 - mse: 0.0031
# Epoch 864/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0035 - mae: 0.0428 - mse: 0.0035
# Epoch 865/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mae: 0.0418 - mse: 0.0030
# Epoch 866/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - mae: 0.0401 - mse: 0.0027
# Epoch 867/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025 - mae: 0.0377 - mse: 0.0025
# Epoch 868/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - mae: 0.0410 - mse: 0.0032
# Epoch 869/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - mae: 0.0409 - mse: 0.0032
# Epoch 870/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0414 - mse: 0.0031
# Epoch 871/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0436 - mse: 0.0034
# Epoch 872/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033 - mae: 0.0424 - mse: 0.0033
# Epoch 873/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - mae: 0.0392 - mse: 0.0029
# Epoch 874/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mae: 0.0463 - mse: 0.0038
# Epoch 875/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0386 - mse: 0.0025
# Epoch 876/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0048 - mae: 0.0500 - mse: 0.0048
# Epoch 877/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mae: 0.0370 - mse: 0.0026
# Epoch 878/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - mae: 0.0478 - mse: 0.0040
# Epoch 879/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - mae: 0.0448 - mse: 0.0036
# Epoch 880/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - mae: 0.0410 - mse: 0.0035
# Epoch 881/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mae: 0.0406 - mse: 0.0035
# Epoch 882/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - mae: 0.0379 - mse: 0.0026
# Epoch 883/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mae: 0.0412 - mse: 0.0029
# Epoch 884/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - mae: 0.0438 - mse: 0.0037
# Epoch 885/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - mae: 0.0396 - mse: 0.0029
# Epoch 886/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mae: 0.0424 - mse: 0.0030
# Epoch 887/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mae: 0.0399 - mse: 0.0026
# Epoch 888/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mae: 0.0425 - mse: 0.0030
# Epoch 889/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - mae: 0.0409 - mse: 0.0032
# Epoch 890/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0052 - mae: 0.0508 - mse: 0.0052
# Epoch 891/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0023 - mae: 0.0348 - mse: 0.0023
# Epoch 892/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - mae: 0.0383 - mse: 0.0026
# Epoch 893/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0434 - mse: 0.0034
# Epoch 894/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mae: 0.0388 - mse: 0.0026
# Epoch 895/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mae: 0.0420 - mse: 0.0032
# Epoch 896/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0412 - mse: 0.0031
# Epoch 897/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0452 - mse: 0.0039
# Epoch 898/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0370 - mse: 0.0025
# Epoch 899/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0032 - mae: 0.0428 - mse: 0.0032
# Epoch 900/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 901/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - mae: 0.0370 - mse: 0.0026
# Epoch 902/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0425 - mse: 0.0034
# Epoch 903/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mae: 0.0399 - mse: 0.0030
# Epoch 904/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0405 - mse: 0.0031
# Epoch 905/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mae: 0.0383 - mse: 0.0028
# Epoch 906/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0408 - mse: 0.0034
# Epoch 907/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - mae: 0.0465 - mse: 0.0040
# Epoch 908/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0382 - mse: 0.0025
# Epoch 909/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0038 - mae: 0.0443 - mse: 0.0038
# Epoch 910/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0408 - mse: 0.0035
# Epoch 911/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025 - mae: 0.0375 - mse: 0.0025
# Epoch 912/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0378 - mse: 0.0025
# Epoch 913/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0399 - mse: 0.0031
# Epoch 914/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030 - mae: 0.0414 - mse: 0.0030
# Epoch 915/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0418 - mse: 0.0031
# Epoch 916/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mae: 0.0383 - mse: 0.0026
# Epoch 917/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0034 - mae: 0.0401 - mse: 0.0034
# Epoch 918/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mae: 0.0406 - mse: 0.0029
# Epoch 919/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mae: 0.0396 - mse: 0.0029
# Epoch 920/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mae: 0.0403 - mse: 0.0029
# Epoch 921/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - mae: 0.0392 - mse: 0.0027
# Epoch 922/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0384 - mse: 0.0028
# Epoch 923/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031 - mae: 0.0420 - mse: 0.0031
# Epoch 924/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023 - mae: 0.0349 - mse: 0.0023
# Epoch 925/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035 - mae: 0.0442 - mse: 0.0035
# Epoch 926/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mae: 0.0423 - mse: 0.0030
# Epoch 927/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0383 - mse: 0.0027
# Epoch 928/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0453 - mse: 0.0041
# Epoch 929/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - mae: 0.0467 - mse: 0.0042
# Epoch 930/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0441 - mse: 0.0034
# Epoch 931/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - mae: 0.0432 - mse: 0.0036
# Epoch 932/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0438 - mse: 0.0035
# Epoch 933/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - mae: 0.0404 - mse: 0.0031
# Epoch 934/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 935/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032 - mae: 0.0414 - mse: 0.0032
# Epoch 936/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - mae: 0.0437 - mse: 0.0036
# Epoch 937/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0435 - mse: 0.0034
# Epoch 938/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0397 - mse: 0.0028
# Epoch 939/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032 - mae: 0.0425 - mse: 0.0032
# Epoch 940/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0037 - mae: 0.0439 - mse: 0.0037
# Epoch 941/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023 - mae: 0.0364 - mse: 0.0023
# Epoch 942/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - mae: 0.0416 - mse: 0.0030
# Epoch 943/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030 - mae: 0.0412 - mse: 0.0030
# Epoch 944/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - mae: 0.0407 - mse: 0.0031
# Epoch 945/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mae: 0.0401 - mse: 0.0029
# Epoch 946/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - mae: 0.0381 - mse: 0.0026
# Epoch 947/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - mae: 0.0390 - mse: 0.0030
# Epoch 948/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - mae: 0.0367 - mse: 0.0026
# Epoch 949/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0428 - mse: 0.0034
# Epoch 950/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030 - mae: 0.0379 - mse: 0.0030
# Epoch 951/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - mae: 0.0428 - mse: 0.0033
# Epoch 952/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mae: 0.0419 - mse: 0.0029
# Epoch 953/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0435 - mse: 0.0034
# Epoch 954/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0026 - mae: 0.0380 - mse: 0.0026
# Epoch 955/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - mae: 0.0403 - mse: 0.0033
# Epoch 956/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - mae: 0.0404 - mse: 0.0030
# Epoch 957/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0045 - mae: 0.0467 - mse: 0.0045
# Epoch 958/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - mae: 0.0395 - mse: 0.0032
# Epoch 959/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0044 - mae: 0.0446 - mse: 0.0044
# Epoch 960/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028 - mae: 0.0374 - mse: 0.0028
# Epoch 961/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - mae: 0.0370 - mse: 0.0026
# Epoch 962/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - mae: 0.0458 - mse: 0.0046
# Epoch 963/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0435 - mse: 0.0034
# Epoch 964/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0441 - mse: 0.0034
# Epoch 965/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - mae: 0.0445 - mse: 0.0036
# Epoch 966/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - mae: 0.0392 - mse: 0.0026
# Epoch 967/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - mae: 0.0447 - mse: 0.0042
# Epoch 968/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - mae: 0.0414 - mse: 0.0029
# Epoch 969/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0439 - mse: 0.0034
# Epoch 970/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - mae: 0.0431 - mse: 0.0033
# Epoch 971/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031 - mae: 0.0403 - mse: 0.0031
# Epoch 972/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - mae: 0.0377 - mse: 0.0026
# Epoch 973/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - mae: 0.0428 - mse: 0.0036
# Epoch 974/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - mae: 0.0398 - mse: 0.0026
# Epoch 975/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030 - mae: 0.0407 - mse: 0.0030
# Epoch 976/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - mae: 0.0371 - mse: 0.0025
# Epoch 977/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0029 - mae: 0.0380 - mse: 0.0029
# Epoch 978/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0033 - mae: 0.0397 - mse: 0.0033
# Epoch 979/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027 - mae: 0.0376 - mse: 0.0027
# Epoch 980/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023 - mae: 0.0365 - mse: 0.0023
# Epoch 981/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - mae: 0.0393 - mse: 0.0030
# Epoch 982/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028 - mae: 0.0394 - mse: 0.0028
# Epoch 983/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030 - mae: 0.0412 - mse: 0.0030
# Epoch 984/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mae: 0.0399 - mse: 0.0029
# Epoch 985/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034 - mae: 0.0419 - mse: 0.0034
# Epoch 986/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - mae: 0.0416 - mse: 0.0035
# Epoch 987/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - mae: 0.0391 - mse: 0.0032
# Epoch 988/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - mae: 0.0415 - mse: 0.0032
# Epoch 989/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025 - mae: 0.0385 - mse: 0.0025
# Epoch 990/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028 - mae: 0.0389 - mse: 0.0028
# Epoch 991/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - mae: 0.0425 - mse: 0.0033
# Epoch 992/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - mae: 0.0428 - mse: 0.0032
# Epoch 993/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0030 - mae: 0.0418 - mse: 0.0030
# Epoch 994/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0027 - mae: 0.0383 - mse: 0.0027
# Epoch 995/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mae: 0.0432 - mse: 0.0035
# Epoch 996/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0428 - mse: 0.0035
# Epoch 997/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - mae: 0.0372 - mse: 0.0026
# Epoch 998/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mae: 0.0378 - mse: 0.0029
# Epoch 999/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - mae: 0.0433 - mse: 0.0036
# Epoch 1000/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - mae: 0.0364 - mse: 0.0023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# --- federated after local fine-tuning ---
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_96895/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Salvo 18 plot in: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/federated_fd/TEST
# Plot salvati correttamente.
# Test MAE: 0.3160
# Test RMSE: 0.4800
# Test MAPE: 0.33%
# Test R2: 0.9984
# Valore medio del test set: 110.6228
#
# Log salvato in: ../RISULTATI/2025-11-29/esperimento_METRO856_16-04-33/federated_fd_evaluation_log.json
