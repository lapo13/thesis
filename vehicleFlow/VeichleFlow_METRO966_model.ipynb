# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import os, pickle, random
from datetime import datetime

# %%
get_after_QA = lambda s: s.split("DISIT/", 1)[1]

# %%
dati = pd.read_excel('/Users/lapotinacci/thesis/metric_datasets/vehicleFlow_dataset.xlsx')
dati = dati[dati["serviceUri"] == "http://www.disit.org/km4city/resource/iot/orionUNIFI/DISIT/METRO966"].copy()
sensor_name = get_after_QA(dati["serviceUri"].iloc[0])
dati.drop(columns=["serviceUri"], inplace=True)
print(dati.shape)
# Out:
# (190, 15)

# %%
# === Creazione cartella esperimento con timestamp ISO ===
timestamp = datetime.now().strftime("%H-%M-%S")
print(f"Ora inizio esperimento: {timestamp}")
day= datetime.now().strftime("%Y-%m-%d")
print(f"Giorno inizio esperimento: {day}")
exp_dir = f"../RISULTATI/{day}/esperimento_{sensor_name}_{timestamp}"

os.makedirs(exp_dir, exist_ok=True)

print(f"Cartella esperimento creata: {exp_dir}")
# Out:
# Ora inizio esperimento: 14-43-40
# Giorno inizio esperimento: 2025-11-30
# Cartella esperimento creata: ../RISULTATI/2025-11-30/esperimento_METRO966_14-43-40

# %%
import ast

mask = ~dati['TTT'].str.contains("nan", na=True)
dtset_completo = dati[mask]

dtset_completo['TTT'] = dtset_completo['TTT'].apply(ast.literal_eval)

# %%
# Filtra le righe dove la colonna TTT ha lunghezza 24, ed elimina tutte le colonne le cui osservazioni sono indipendenti dal giorno
dtset_filtrato = dtset_completo[dtset_completo["TTT"].apply(lambda x: len(x) == 24)].sample(frac=1).reset_index(drop=True)
dtset_filtrato = dtset_filtrato[dtset_filtrato["type_of_TTT"] == "daily"]
len(dtset_filtrato)
# Out:
# 130

# %%
import numpy as np


def is_useful_series(series, zero_ratio_thr=0.85, min_nonzero_value=0.1):
    arr = np.array(series, dtype=float)
    
    # Serie troppo corta
    if len(arr) <= 1:
        return False
    
    # Troppi zeri
    zero_ratio = (arr == 0).mean()
    if zero_ratio >= zero_ratio_thr:
        return False
    
    # Valore medio trascurabile (quasi zero)
    mean_val = np.mean(arr)
    if abs(mean_val) < min_nonzero_value:
        return False
    
    # Se arriva qui, la serie ha valori significativi
    return True

# Applica filtro
mask_useful = dtset_filtrato["TTT"].apply(is_useful_series)
df_useful = dtset_filtrato[mask_useful]

# %%
def spezza_serie_in_colonne(df, colonna_stringa, prefix='col_'):
    # --- Controllo colonna ---
    if colonna_stringa not in df.columns:
        raise ValueError(f"La colonna '{colonna_stringa}' non esiste nel DataFrame")

    result_df = df.copy()

    # Estraggo la colonna contenente gli embedding
    col = result_df.pop(colonna_stringa)

    embeddings = []

    for item in col:
        # Gestione valori nulli o vuoti
        if pd.isna(item) or item == "":
            embeddings.append([])
            continue
        
        # Se l'item è già una lista o un array (non stringa), lo gestiamo direttamente
        if isinstance(item, (list, np.ndarray)):
            embeddings.append(list(item))
            continue

        vett = None
        
        # --- TENTATIVO 1: Parsing Standard Python (es. "[1, 2, 3]") ---
        try:
            parsed = ast.literal_eval(item)
            if isinstance(parsed, (list, tuple)):
                vett = list(parsed)
        except (ValueError, SyntaxError):
            # Se fallisce (es. SyntaxError per mancanza di virgole), passiamo al tentativo 2
            pass

        # --- TENTATIVO 2: Parsing per Spazi (es. "[1 2 3]" o "1 2 3") ---
        if vett is None:
            try:
                # Rimuove parentesi quadre, tonde e spazi iniziali/finali
                clean_str = item.replace('[', '').replace(']', '').replace('(', '').replace(')', '').strip()
                
                # Se la stringa è vuota dopo la pulizia (es. "[]"), è una lista vuota
                if not clean_str:
                    vett = []
                else:
                    # .split() senza argomenti gestisce spazi multipli, tab e newline automaticamente
                    vett = [float(x) for x in clean_str.split()]
            except Exception as e:
                print(f"Errore nel parsing dell'elemento '{item}': {e}")
                vett = []

        # --- Conversione finale e check ---
        # Assicuro che tutti gli elementi siano float (utile se ast.literal_eval ha trovato interi)
        try:
            if vett:
                vett = [float(x) for x in vett]
            embeddings.append(vett)
        except Exception as e:
            print(f"Errore conversione float per '{item}': {e}")
            embeddings.append([])

    # --- Uniformo dimensione dei vettori ---
    lengths = [len(v) for v in embeddings]
    if not lengths or max(lengths) == 0:
        # Se non ci sono dati validi, restituisco il df senza la colonna oppure sollevo errore
        # Qui scelgo di restituire il df originale senza la colonna parsata per evitare crash
        print("Warning: Nessun embedding valido trovato.")
        return result_df

    max_len = max(lengths)

    # Padding con NaN
    embeddings_padded = [
        v + [np.nan] * (max_len - len(v)) if len(v) < max_len else v
        for v in embeddings
    ]

    # --- Creo DataFrame delle nuove colonne ---
    colonne_embedding = pd.DataFrame(
        embeddings_padded,
        index=result_df.index,
        columns=[f"{prefix}{i}" for i in range(max_len)]
    )

    # --- Merge col DataFrame originale ---
    return pd.concat([result_df, colonne_embedding], axis=1)

# %%
for ttt in df_useful.TTT:
    plt.plot(ttt)

# %%
def summary_df(df):
    summary = pd.DataFrame({
        'dtype': df.dtypes,
        'n_missing': df.isna().sum(),
        '%_missing': (df.isna().mean() * 100).round(2),
        'n_unique': df.nunique(),
        'top_value': df.mode().iloc[0],  # moda
        'top_freq': [df[col].value_counts(dropna=True).iloc[0] if not df[col].value_counts(dropna=True).empty else None for col in df.columns],
        'min': [df[col].min() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'max': [df[col].max() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'mean': [df[col].mean() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'std': [df[col].std() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
    })
    return summary

# %%
#Nella precedente sono state eliminate le colonne con Nan, tuttavia alcuni dataset dei sensori METRO hanno dei Nan in city e surface dunque vengono rimossi nel prcedente box

categorical = [
    'is_weekend'
    ]

#consiglio, per serie cicliche usare funzioni periodiche tipo seno coseno 
df_encoded = pd.get_dummies(df_useful
                            , columns=categorical)

# %%
def save_pkl(obj, path):
    with open(path, "wb") as f:
        pickle.dump(obj, f)
    print(f"Salvato: {path}")

def load_pkl(path):
    with open(path, "rb") as f:
        return pickle.load(f)

# %%
#codifica ciclica delle features e individuazione del'ora del giorno e della settimana 

def encode_time_features(df, start_col="interval_start", end_col="interval_end"):
    df = df.copy()
    
    # Step 1: Ensure datetime columns are in the correct format first
    df[start_col] = pd.to_datetime(df[start_col], utc=True, format="mixed")
    df[end_col] = pd.to_datetime(df[end_col], utc=True, format="mixed")

    # Step 2: Extract 'month' and 'day' after conversion
    df['month'] = df[start_col].dt.month
    df['day'] = df[start_col].dt.dayofweek # Note: dayofweek is typically used for cyclical weekly patterns
    
    # Step 3: Now you can create the cyclical features
    df['month_sin'] = np.sin(2 * np.pi * df['month']/len(df['month'].unique()))
    df['month_cos'] = np.cos(2 * np.pi * df['month']/len(df['month'].unique()))
    df['day_sin'] = np.sin(2 * np.pi * df['day']/len(df['day'].unique()))
    df['day_cos'] = np.cos(2 * np.pi * df['day']/len(df['day'].unique()))


    # Ora del giorno (0-23) → ciclo giornaliero
    df["hour"] = df[start_col].dt.hour
    angle_day_start = 2 * np.pi * df["hour"] / 24
    df["start_time_sin"] = np.sin(angle_day_start)
    df["start_time_cos"] = np.cos(angle_day_start)

    df["hour_end"] = df[end_col].dt.hour
    angle_day_end = 2 * np.pi * df["hour_end"] / 24
    df["end_time_sin"] = np.sin(angle_day_end)
    df["end_time_cos"] = np.cos(angle_day_end)

    # Durata in minuti
    df["duration_minutes"] = (df[end_col] - df[start_col]).dt.total_seconds() / 60

    # Giorno della settimana (0=Mon..6=Sun) → ciclo settimanale
    dayofweek = df[start_col].dt.dayofweek
    angle_week = 2 * np.pi * dayofweek / 7
    df["dow_sin"] = np.sin(angle_week)
    df["dow_cos"] = np.cos(angle_week)

    # Giorno dell’anno (1-365) → ciclo annuale
    dayofyear = df[start_col].dt.dayofyear
    angle_year = 2 * np.pi * dayofyear / 365
    df["doy_sin"] = np.sin(angle_year)
    df["doy_cos"] = np.cos(angle_year)

    # Rimuovo colonne temporali e variabili ausiliarie
    df = df.drop(columns=[start_col, end_col, "hour", "hour_end", "day", "month"])
    return df

embedding_cols = ['highway_embeddings']

df_final = encode_time_features(df_encoded)
df_final.drop(columns=['type_of_TTT'], inplace=True)
for emb_col in embedding_cols:
    df_final = spezza_serie_in_colonne(df_final, emb_col, prefix=f'{emb_col}_')
df_final.shape

# Salvataggio DataFrame finale
df_path = os.path.join(exp_dir, f"dataframe_{sensor_name}")
os.makedirs(df_path, exist_ok=True)
save_pkl(df_final, os.path.join(df_path, f"filtered_dataframe.pkl"))
# Out:
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO966_14-43-40/dataframe_METRO966/filtered_dataframe.pkl

# %%
for ttt in df_final.TTT[10:20]:
    plt.plot(ttt)
    plt.title("Esempi di TTT ARPAT")
    plt.xlabel("Ora del Giorno")
    plt.ylabel("Valore TTT")

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

def series_to_2d_array(series, output_dim=24):
    arr = np.stack(series.apply(lambda x: np.array(x, dtype=np.float32)))
    if arr.shape[1] != output_dim:
        raise ValueError(f"Ogni elemento deve avere {output_dim} valori, trovato {arr.shape[1]}")
    return arr

 # Separazione delle feature e del target
X = df_final.drop(columns=['TTT'])
y = df_final['TTT']

X_np = X.to_numpy().astype(np.float32)
y_np = series_to_2d_array(y, output_dim=24)

# Calcolo deviazione standard per ogni serie
std_scores = np.std(y_np, axis=1)

std_scores_log = np.log1p(std_scores)  # log(1+x) per evitare problemi con valori vicini a 0

std_scores_normalized = (std_scores_log - np.min(std_scores_log)) / (np.max(std_scores_log) - np.min(std_scores_log))

# Creo bin basati sui quantili
bins = np.array([0.0, 0.4, 0.8, 1.0])
std_bins = np.digitize(std_scores_normalized, bins)

# Primo split: train (80%) vs temp (20%)
# Passo anche std_bins per poter stratificare
X_train, X_test, y_train, y_test = train_test_split(
    X_np, y_np,
    test_size=0.2,
    random_state=42,
    stratify=std_bins, 
    shuffle=True
)

print(f"Train size: {X_train.shape}, {y_train.shape}")
print(f"Test size: {X_test.shape}, {y_test.shape}")

# Debug prints
print(f"Final shapes:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

# Scaler per input
scaler_X = MinMaxScaler()
X_train = scaler_X.fit_transform(X_train)
X_test  = scaler_X.transform(X_test)

# Scaler per output (se serve normalizzare anche y)
scaler_y = MinMaxScaler()
y_train = scaler_y.fit_transform(y_train)
y_test  = scaler_y.transform(y_test)

#cartella salvataggio train e test
path = os.path.join(exp_dir, "train_test_data")
os.makedirs(path, exist_ok=True)

#  === Salvataggio dataset e scaler in formato .pkl ===
save_pkl(scaler_X.inverse_transform(X_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_X.inverse_transform(X_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_test_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_test_unscaled_{sensor_name}.pkl"))

save_pkl(X_train, os.path.join(exp_dir, "X_train.pkl"))
save_pkl(y_train, os.path.join(exp_dir, "y_train.pkl"))
save_pkl(X_test, os.path.join(exp_dir, "X_test.pkl"))
save_pkl(y_test, os.path.join(exp_dir, "y_test.pkl"))

save_pkl(scaler_X, os.path.join(exp_dir, "scaler_X.pkl"))
save_pkl(scaler_y, os.path.join(exp_dir, "scaler_y.pkl"))

print("Scaler salvati.")

print("\nTutti i file sono stati salvati correttamente.")
print(f"Percorso cartella: {os.path.abspath(exp_dir)}")
# Out:
# Train size: (104, 28), (104, 24)
# Test size: (26, 28), (26, 24)
# Final shapes:
# X_train: (104, 28)
# y_train: (104, 24)
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_train_unscaled_METRO966.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_train_unscaled_METRO966.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_test_unscaled_METRO966.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_test_unscaled_METRO966.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO966_14-43-40/X_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO966_14-43-40/y_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO966_14-43-40/X_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO966_14-43-40/y_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO966_14-43-40/scaler_X.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_METRO966_14-43-40/scaler_y.pkl
# Scaler salvati.
#
# Tutti i file sono stati salvati correttamente.
# Percorso cartella: /Users/lapotinacci/thesis/Federated_Sys/RISULTATI/2025-11-30/esperimento_METRO966_14-43-40

# %%
# === Costruisci i path ===
path_X_train = os.path.join(exp_dir, "X_train.pkl")
path_y_train = os.path.join(exp_dir, "y_train.pkl")
path_X_test  = os.path.join(exp_dir, "X_test.pkl")
path_y_test  = os.path.join(exp_dir, "y_test.pkl")

path_scaler_X = os.path.join(exp_dir, "scaler_X.pkl")
path_scaler_y = os.path.join(exp_dir, "scaler_y.pkl")

# === Ricaricamento ===
X_train = load_pkl(path_X_train)
y_train = load_pkl(path_y_train)
X_test  = load_pkl(path_X_test)
y_test  = load_pkl(path_y_test)


scaler_X = load_pkl(path_scaler_X)
scaler_y = load_pkl(path_scaler_y)

print("Shapes ricostruite:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

print("\nScaler caricati:")
print("scaler_X:", type(scaler_X))
print("scaler_y:", type(scaler_y))
# Out:
# Shapes ricostruite:
# X_train: (104, 28)
# y_train: (104, 24)
# X_test: (26, 28)
# y_test: (26, 24)
#
# Scaler caricati:
# scaler_X: <class 'sklearn.preprocessing._data.MinMaxScaler'>
# scaler_y: <class 'sklearn.preprocessing._data.MinMaxScaler'>

# %% [markdown]
# # modelli

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers # type: ignore
from tensorflow.keras.layers import Dropout # type: ignore
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
def save_prediction_plots(y_true, y_pred, output_dir, prefix="pred_plot"):
    os.makedirs(output_dir, exist_ok=True)

    n = len(y_true)
    print(f"Salvo {n} plot in: {output_dir}")

    for i in range(n):
        plt.figure(figsize=(8, 3))
        plt.plot(y_true[i], label="True")
        plt.plot(y_pred[i], label="Pred")
        plt.legend()
        plt.tight_layout()

        filename = f"{prefix}_{i+1}.png"
        path = os.path.join(output_dir, filename)

        plt.savefig(path)
        plt.close()

    print("Plot salvati correttamente.")

# %%
# Definizione modello DNN
def build_model(input_shape: tuple, output_shape: tuple):
    model = models.Sequential([
        layers.Dense(64, activation = "relu", input_shape=input_shape),
        Dropout(0.0),
        layers.Dense(output_shape, 'linear')
    ])
    model.compile(
    optimizer=optimizers.AdamW(learning_rate=0.0076, weight_decay=0.0759),
    loss= 'mse',
    metrics=['mae'],
    )
    return model

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',      # metrica da monitorare, es. val_loss o val_mae
    patience=50,             # numero di epoche senza miglioramento prima di fermare
    restore_best_weights=True,  # ripristina i pesi migliori trovati
    verbose = 1
)

# Training del modello
model = build_model((X_test.shape[1],), y_test.shape[1])
history = model.fit(
    X_train, y_train,
    epochs=1000,
    batch_size=32,
    callbacks = [early_stop],
    validation_split = 0.2,
    verbose=1
    )

'''print("y_train min/max:", y_train_np.min(), y_train_np.max())
print("y_pred min/max (scaled):", y_pred.min(), y_pred.max())
y_pred_rescaled = scaler_y.inverse_transform(y_pred)
print("y_pred_rescaled min/max:", y_pred_rescaled.min(), y_pred_rescaled.max())'''

if not os.path.exists(os.path.join(exp_dir, "model")):
    os.makedirs(os.path.join(exp_dir, "model"))
    model.save(os.path.join(exp_dir, "model", "NO2_MAREMMA_model.keras"))
# Out:
# Epoch 1/1000
# /Users/lapotinacci/thesis/Federated_Sys/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.4741 - mae: 0.5771 - val_loss: 0.2002 - val_mae: 0.3501
# Epoch 2/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1674 - mae: 0.3209 - val_loss: 0.0743 - val_mae: 0.2262
# Epoch 3/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0726 - mae: 0.2232 - val_loss: 0.0730 - val_mae: 0.2240
# Epoch 4/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0710 - mae: 0.2191 - val_loss: 0.0618 - val_mae: 0.1982
# Epoch 5/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0534 - mae: 0.1836 - val_loss: 0.0472 - val_mae: 0.1644
# Epoch 6/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0399 - mae: 0.1538 - val_loss: 0.0426 - val_mae: 0.1532
# Epoch 7/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0351 - mae: 0.1416 - val_loss: 0.0372 - val_mae: 0.1410
# Epoch 8/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0309 - mae: 0.1324 - val_loss: 0.0306 - val_mae: 0.1269
# Epoch 9/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0267 - mae: 0.1239 - val_loss: 0.0236 - val_mae: 0.1128
# Epoch 10/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0222 - mae: 0.1137 - val_loss: 0.0197 - val_mae: 0.1063
# Epoch 11/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0200 - mae: 0.1101 - val_loss: 0.0182 - val_mae: 0.1030
# Epoch 12/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0190 - mae: 0.1084 - val_loss: 0.0160 - val_mae: 0.0945
# Epoch 13/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0171 - mae: 0.1008 - val_loss: 0.0141 - val_mae: 0.0855
# Epoch 14/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0159 - mae: 0.0946 - val_loss: 0.0132 - val_mae: 0.0811
# Epoch 15/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0150 - mae: 0.0911 - val_loss: 0.0122 - val_mae: 0.0786
# Epoch 16/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0141 - mae: 0.0885 - val_loss: 0.0114 - val_mae: 0.0771
# Epoch 17/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0135 - mae: 0.0871 - val_loss: 0.0106 - val_mae: 0.0736
# Epoch 18/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0129 - mae: 0.0850 - val_loss: 0.0099 - val_mae: 0.0720
# Epoch 19/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0123 - mae: 0.0832 - val_loss: 0.0095 - val_mae: 0.0702
# Epoch 20/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0119 - mae: 0.0816 - val_loss: 0.0090 - val_mae: 0.0666
# Epoch 21/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0115 - mae: 0.0794 - val_loss: 0.0086 - val_mae: 0.0646
# Epoch 22/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0112 - mae: 0.0781 - val_loss: 0.0083 - val_mae: 0.0645
# Epoch 23/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0108 - mae: 0.0769 - val_loss: 0.0080 - val_mae: 0.0630
# Epoch 24/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0105 - mae: 0.0752 - val_loss: 0.0078 - val_mae: 0.0621
# Epoch 25/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0102 - mae: 0.0740 - val_loss: 0.0075 - val_mae: 0.0611
# Epoch 26/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0099 - mae: 0.0731 - val_loss: 0.0073 - val_mae: 0.0599
# Epoch 27/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0097 - mae: 0.0715 - val_loss: 0.0071 - val_mae: 0.0588
# Epoch 28/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0094 - mae: 0.0702 - val_loss: 0.0069 - val_mae: 0.0582
# Epoch 29/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0092 - mae: 0.0698 - val_loss: 0.0067 - val_mae: 0.0577
# Epoch 30/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0090 - mae: 0.0688 - val_loss: 0.0066 - val_mae: 0.0573
# Epoch 31/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0087 - mae: 0.0677 - val_loss: 0.0066 - val_mae: 0.0571
# Epoch 32/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0084 - mae: 0.0663 - val_loss: 0.0064 - val_mae: 0.0565
# Epoch 33/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0082 - mae: 0.0652 - val_loss: 0.0063 - val_mae: 0.0560
# Epoch 34/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0080 - mae: 0.0644 - val_loss: 0.0061 - val_mae: 0.0554
# Epoch 35/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0077 - mae: 0.0632 - val_loss: 0.0060 - val_mae: 0.0547
# Epoch 36/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0075 - mae: 0.0620 - val_loss: 0.0059 - val_mae: 0.0542
# Epoch 37/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0073 - mae: 0.0612 - val_loss: 0.0058 - val_mae: 0.0540
# Epoch 38/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0071 - mae: 0.0605 - val_loss: 0.0056 - val_mae: 0.0534
# Epoch 39/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0069 - mae: 0.0592 - val_loss: 0.0055 - val_mae: 0.0529
# Epoch 40/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0067 - mae: 0.0583 - val_loss: 0.0054 - val_mae: 0.0523
# Epoch 41/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0065 - mae: 0.0575 - val_loss: 0.0054 - val_mae: 0.0516
# Epoch 42/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0064 - mae: 0.0567 - val_loss: 0.0052 - val_mae: 0.0516
# Epoch 43/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0062 - mae: 0.0560 - val_loss: 0.0051 - val_mae: 0.0507
# Epoch 44/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0060 - mae: 0.0547 - val_loss: 0.0050 - val_mae: 0.0497
# Epoch 45/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0059 - mae: 0.0542 - val_loss: 0.0049 - val_mae: 0.0495
# Epoch 46/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0057 - mae: 0.0532 - val_loss: 0.0049 - val_mae: 0.0496
# Epoch 47/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0056 - mae: 0.0520 - val_loss: 0.0047 - val_mae: 0.0479
# Epoch 48/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0054 - mae: 0.0511 - val_loss: 0.0045 - val_mae: 0.0467
# Epoch 49/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0053 - mae: 0.0502 - val_loss: 0.0044 - val_mae: 0.0456
# Epoch 50/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0052 - mae: 0.0497 - val_loss: 0.0044 - val_mae: 0.0459
# Epoch 51/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0051 - mae: 0.0497 - val_loss: 0.0042 - val_mae: 0.0449
# Epoch 52/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0050 - mae: 0.0479 - val_loss: 0.0041 - val_mae: 0.0439
# Epoch 53/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0048 - mae: 0.0475 - val_loss: 0.0040 - val_mae: 0.0435
# Epoch 54/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0047 - mae: 0.0471 - val_loss: 0.0039 - val_mae: 0.0419
# Epoch 55/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0046 - mae: 0.0453 - val_loss: 0.0037 - val_mae: 0.0406
# Epoch 56/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0045 - mae: 0.0454 - val_loss: 0.0036 - val_mae: 0.0391
# Epoch 57/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0044 - mae: 0.0440 - val_loss: 0.0035 - val_mae: 0.0386
# Epoch 58/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0043 - mae: 0.0430 - val_loss: 0.0034 - val_mae: 0.0372
# Epoch 59/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0042 - mae: 0.0423 - val_loss: 0.0033 - val_mae: 0.0368
# Epoch 60/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0041 - mae: 0.0423 - val_loss: 0.0032 - val_mae: 0.0363
# Epoch 61/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0041 - mae: 0.0417 - val_loss: 0.0032 - val_mae: 0.0357
# Epoch 62/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040 - mae: 0.0408 - val_loss: 0.0031 - val_mae: 0.0349
# Epoch 63/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0039 - mae: 0.0403 - val_loss: 0.0030 - val_mae: 0.0347
# Epoch 64/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0039 - mae: 0.0402 - val_loss: 0.0029 - val_mae: 0.0336
# Epoch 65/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038 - mae: 0.0392 - val_loss: 0.0029 - val_mae: 0.0327
# Epoch 66/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0037 - mae: 0.0388 - val_loss: 0.0028 - val_mae: 0.0319
# Epoch 67/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0037 - mae: 0.0382 - val_loss: 0.0028 - val_mae: 0.0321
# Epoch 68/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0037 - mae: 0.0389 - val_loss: 0.0028 - val_mae: 0.0314
# Epoch 69/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0036 - mae: 0.0382 - val_loss: 0.0027 - val_mae: 0.0314
# Epoch 70/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0036 - mae: 0.0370 - val_loss: 0.0027 - val_mae: 0.0310
# Epoch 71/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0035 - mae: 0.0370 - val_loss: 0.0026 - val_mae: 0.0298
# Epoch 72/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0035 - mae: 0.0366 - val_loss: 0.0026 - val_mae: 0.0297
# Epoch 73/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0035 - mae: 0.0364 - val_loss: 0.0026 - val_mae: 0.0294
# Epoch 74/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0035 - mae: 0.0361 - val_loss: 0.0026 - val_mae: 0.0294
# Epoch 75/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0034 - mae: 0.0354 - val_loss: 0.0025 - val_mae: 0.0284
# Epoch 76/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0033 - mae: 0.0345 - val_loss: 0.0025 - val_mae: 0.0285
# Epoch 77/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0034 - mae: 0.0354 - val_loss: 0.0025 - val_mae: 0.0279
# Epoch 78/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0033 - mae: 0.0350 - val_loss: 0.0025 - val_mae: 0.0278
# Epoch 79/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033 - mae: 0.0346 - val_loss: 0.0025 - val_mae: 0.0282
# Epoch 80/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0032 - mae: 0.0339 - val_loss: 0.0024 - val_mae: 0.0273
# Epoch 81/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0032 - mae: 0.0344 - val_loss: 0.0024 - val_mae: 0.0275
# Epoch 82/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0032 - mae: 0.0341 - val_loss: 0.0023 - val_mae: 0.0270
# Epoch 83/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0032 - mae: 0.0332 - val_loss: 0.0024 - val_mae: 0.0268
# Epoch 84/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0330 - val_loss: 0.0024 - val_mae: 0.0257
# Epoch 85/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0327 - val_loss: 0.0023 - val_mae: 0.0257
# Epoch 86/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0321 - val_loss: 0.0023 - val_mae: 0.0253
# Epoch 87/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0032 - mae: 0.0330 - val_loss: 0.0023 - val_mae: 0.0251
# Epoch 88/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0032 - mae: 0.0333 - val_loss: 0.0023 - val_mae: 0.0258
# Epoch 89/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0330 - val_loss: 0.0023 - val_mae: 0.0267
# Epoch 90/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - mae: 0.0331 - val_loss: 0.0024 - val_mae: 0.0282
# Epoch 91/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0338 - val_loss: 0.0022 - val_mae: 0.0258
# Epoch 92/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0030 - mae: 0.0322 - val_loss: 0.0023 - val_mae: 0.0259
# Epoch 93/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0030 - mae: 0.0318 - val_loss: 0.0023 - val_mae: 0.0251
# Epoch 94/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0030 - mae: 0.0319 - val_loss: 0.0022 - val_mae: 0.0240
# Epoch 95/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0030 - mae: 0.0314 - val_loss: 0.0022 - val_mae: 0.0251
# Epoch 96/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0030 - mae: 0.0319 - val_loss: 0.0023 - val_mae: 0.0269
# Epoch 97/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0030 - mae: 0.0317 - val_loss: 0.0022 - val_mae: 0.0248
# Epoch 98/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - mae: 0.0314 - val_loss: 0.0022 - val_mae: 0.0251
# Epoch 99/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - mae: 0.0307 - val_loss: 0.0022 - val_mae: 0.0240
# Epoch 100/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0303 - val_loss: 0.0021 - val_mae: 0.0232
# Epoch 101/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - mae: 0.0299 - val_loss: 0.0021 - val_mae: 0.0234
# Epoch 102/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028 - mae: 0.0298 - val_loss: 0.0021 - val_mae: 0.0228
# Epoch 103/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - mae: 0.0298 - val_loss: 0.0021 - val_mae: 0.0227
# Epoch 104/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0028 - mae: 0.0295 - val_loss: 0.0021 - val_mae: 0.0242
# Epoch 105/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0030 - mae: 0.0324 - val_loss: 0.0021 - val_mae: 0.0234
# Epoch 106/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028 - mae: 0.0305 - val_loss: 0.0022 - val_mae: 0.0264
# Epoch 107/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - mae: 0.0314 - val_loss: 0.0022 - val_mae: 0.0254
# Epoch 108/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029 - mae: 0.0315 - val_loss: 0.0021 - val_mae: 0.0252
# Epoch 109/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - mae: 0.0297 - val_loss: 0.0021 - val_mae: 0.0238
# Epoch 110/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028 - mae: 0.0303 - val_loss: 0.0020 - val_mae: 0.0228
# Epoch 111/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0029 - mae: 0.0310 - val_loss: 0.0020 - val_mae: 0.0229
# Epoch 112/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0027 - mae: 0.0297 - val_loss: 0.0022 - val_mae: 0.0259
# Epoch 113/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028 - mae: 0.0295 - val_loss: 0.0021 - val_mae: 0.0236
# Epoch 114/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0027 - mae: 0.0294 - val_loss: 0.0020 - val_mae: 0.0224
# Epoch 115/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0284 - val_loss: 0.0020 - val_mae: 0.0225
# Epoch 116/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0284 - val_loss: 0.0020 - val_mae: 0.0218
# Epoch 117/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027 - mae: 0.0284 - val_loss: 0.0020 - val_mae: 0.0215
# Epoch 118/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0027 - mae: 0.0281 - val_loss: 0.0020 - val_mae: 0.0218
# Epoch 119/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0027 - mae: 0.0286 - val_loss: 0.0020 - val_mae: 0.0214
# Epoch 120/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - mae: 0.0279 - val_loss: 0.0020 - val_mae: 0.0216
# Epoch 121/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - mae: 0.0284 - val_loss: 0.0019 - val_mae: 0.0212
# Epoch 122/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - mae: 0.0280 - val_loss: 0.0020 - val_mae: 0.0211
# Epoch 123/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0028 - mae: 0.0289 - val_loss: 0.0019 - val_mae: 0.0208
# Epoch 124/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - mae: 0.0276 - val_loss: 0.0019 - val_mae: 0.0207
# Epoch 125/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0026 - mae: 0.0272 - val_loss: 0.0019 - val_mae: 0.0220
# Epoch 126/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - mae: 0.0276 - val_loss: 0.0019 - val_mae: 0.0207
# Epoch 127/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0026 - mae: 0.0274 - val_loss: 0.0019 - val_mae: 0.0209
# Epoch 128/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - mae: 0.0281 - val_loss: 0.0019 - val_mae: 0.0208
# Epoch 129/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mae: 0.0272 - val_loss: 0.0019 - val_mae: 0.0217
# Epoch 130/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mae: 0.0283 - val_loss: 0.0019 - val_mae: 0.0204
# Epoch 131/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - mae: 0.0274 - val_loss: 0.0019 - val_mae: 0.0209
# Epoch 132/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0026 - mae: 0.0282 - val_loss: 0.0018 - val_mae: 0.0210
# Epoch 133/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - mae: 0.0281 - val_loss: 0.0019 - val_mae: 0.0232
# Epoch 134/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - mae: 0.0291 - val_loss: 0.0019 - val_mae: 0.0218
# Epoch 135/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - mae: 0.0309 - val_loss: 0.0019 - val_mae: 0.0216
# Epoch 136/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0026 - mae: 0.0288 - val_loss: 0.0021 - val_mae: 0.0232
# Epoch 137/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - mae: 0.0284 - val_loss: 0.0021 - val_mae: 0.0289
# Epoch 138/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030 - mae: 0.0343 - val_loss: 0.0019 - val_mae: 0.0252
# Epoch 139/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - mae: 0.0315 - val_loss: 0.0021 - val_mae: 0.0269
# Epoch 140/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - mae: 0.0317 - val_loss: 0.0021 - val_mae: 0.0282
# Epoch 141/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - mae: 0.0299 - val_loss: 0.0020 - val_mae: 0.0236
# Epoch 142/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - mae: 0.0292 - val_loss: 0.0018 - val_mae: 0.0213
# Epoch 143/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - mae: 0.0279 - val_loss: 0.0018 - val_mae: 0.0220
# Epoch 144/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0024 - mae: 0.0273 - val_loss: 0.0018 - val_mae: 0.0222
# Epoch 145/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - mae: 0.0275 - val_loss: 0.0018 - val_mae: 0.0206
# Epoch 146/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - mae: 0.0271 - val_loss: 0.0018 - val_mae: 0.0204
# Epoch 147/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - mae: 0.0271 - val_loss: 0.0018 - val_mae: 0.0220
# Epoch 148/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - mae: 0.0273 - val_loss: 0.0018 - val_mae: 0.0214
# Epoch 149/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - mae: 0.0273 - val_loss: 0.0017 - val_mae: 0.0197
# Epoch 150/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0024 - mae: 0.0268 - val_loss: 0.0017 - val_mae: 0.0197
# Epoch 151/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - mae: 0.0269 - val_loss: 0.0017 - val_mae: 0.0207
# Epoch 152/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023 - mae: 0.0260 - val_loss: 0.0017 - val_mae: 0.0199
# Epoch 153/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0258 - val_loss: 0.0017 - val_mae: 0.0195
# Epoch 154/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023 - mae: 0.0253 - val_loss: 0.0017 - val_mae: 0.0198
# Epoch 155/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0256 - val_loss: 0.0017 - val_mae: 0.0189
# Epoch 156/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0252 - val_loss: 0.0017 - val_mae: 0.0189
# Epoch 157/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0254 - val_loss: 0.0017 - val_mae: 0.0190
# Epoch 158/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0248 - val_loss: 0.0017 - val_mae: 0.0193
# Epoch 159/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0250 - val_loss: 0.0017 - val_mae: 0.0191
# Epoch 160/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0246 - val_loss: 0.0017 - val_mae: 0.0194
# Epoch 161/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0246 - val_loss: 0.0016 - val_mae: 0.0208
# Epoch 162/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - mae: 0.0293 - val_loss: 0.0016 - val_mae: 0.0205
# Epoch 163/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - mae: 0.0303 - val_loss: 0.0017 - val_mae: 0.0215
# Epoch 164/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - mae: 0.0302 - val_loss: 0.0017 - val_mae: 0.0224
# Epoch 165/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023 - mae: 0.0279 - val_loss: 0.0019 - val_mae: 0.0253
# Epoch 166/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0024 - mae: 0.0290 - val_loss: 0.0018 - val_mae: 0.0260
# Epoch 167/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - mae: 0.0295 - val_loss: 0.0017 - val_mae: 0.0220
# Epoch 168/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - mae: 0.0272 - val_loss: 0.0017 - val_mae: 0.0229
# Epoch 169/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - mae: 0.0273 - val_loss: 0.0016 - val_mae: 0.0216
# Epoch 170/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - mae: 0.0273 - val_loss: 0.0017 - val_mae: 0.0211
# Epoch 171/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024 - mae: 0.0264 - val_loss: 0.0017 - val_mae: 0.0222
# Epoch 172/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0290 - val_loss: 0.0016 - val_mae: 0.0230
# Epoch 173/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0293 - val_loss: 0.0019 - val_mae: 0.0270
# Epoch 174/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - mae: 0.0305 - val_loss: 0.0016 - val_mae: 0.0228
# Epoch 175/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0291 - val_loss: 0.0017 - val_mae: 0.0241
# Epoch 176/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - mae: 0.0267 - val_loss: 0.0019 - val_mae: 0.0250
# Epoch 177/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0023 - mae: 0.0289 - val_loss: 0.0016 - val_mae: 0.0219
# Epoch 178/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0290 - val_loss: 0.0015 - val_mae: 0.0211
# Epoch 179/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - mae: 0.0260 - val_loss: 0.0019 - val_mae: 0.0237
# Epoch 180/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - mae: 0.0260 - val_loss: 0.0017 - val_mae: 0.0263
# Epoch 181/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023 - mae: 0.0312 - val_loss: 0.0015 - val_mae: 0.0214
# Epoch 182/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - mae: 0.0275 - val_loss: 0.0017 - val_mae: 0.0245
# Epoch 183/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0021 - mae: 0.0271 - val_loss: 0.0016 - val_mae: 0.0235
# Epoch 184/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0022 - mae: 0.0269 - val_loss: 0.0015 - val_mae: 0.0197
# Epoch 185/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023 - mae: 0.0286 - val_loss: 0.0016 - val_mae: 0.0228
# Epoch 186/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - mae: 0.0275 - val_loss: 0.0016 - val_mae: 0.0213
# Epoch 187/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021 - mae: 0.0264 - val_loss: 0.0016 - val_mae: 0.0227
# Epoch 188/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - mae: 0.0270 - val_loss: 0.0015 - val_mae: 0.0208
# Epoch 189/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - mae: 0.0267 - val_loss: 0.0015 - val_mae: 0.0212
# Epoch 190/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - mae: 0.0245 - val_loss: 0.0015 - val_mae: 0.0218
# Epoch 191/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - mae: 0.0257 - val_loss: 0.0014 - val_mae: 0.0195
# Epoch 192/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - mae: 0.0245 - val_loss: 0.0014 - val_mae: 0.0188
# Epoch 193/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - mae: 0.0251 - val_loss: 0.0014 - val_mae: 0.0189
# Epoch 194/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0020 - mae: 0.0247 - val_loss: 0.0015 - val_mae: 0.0186
# Epoch 195/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0020 - mae: 0.0241 - val_loss: 0.0014 - val_mae: 0.0192
# Epoch 196/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - mae: 0.0235 - val_loss: 0.0014 - val_mae: 0.0189
# Epoch 197/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0020 - mae: 0.0258 - val_loss: 0.0014 - val_mae: 0.0196
# Epoch 198/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - mae: 0.0243 - val_loss: 0.0015 - val_mae: 0.0210
# Epoch 199/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0021 - mae: 0.0250 - val_loss: 0.0014 - val_mae: 0.0197
# Epoch 200/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - mae: 0.0277 - val_loss: 0.0014 - val_mae: 0.0216
# Epoch 201/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - mae: 0.0259 - val_loss: 0.0015 - val_mae: 0.0232
# Epoch 202/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - mae: 0.0258 - val_loss: 0.0014 - val_mae: 0.0207
# Epoch 203/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019 - mae: 0.0244 - val_loss: 0.0013 - val_mae: 0.0190
# Epoch 204/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0019 - mae: 0.0245 - val_loss: 0.0013 - val_mae: 0.0198
# Epoch 205/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018 - mae: 0.0237 - val_loss: 0.0013 - val_mae: 0.0185
# Epoch 206/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - mae: 0.0238 - val_loss: 0.0013 - val_mae: 0.0183
# Epoch 207/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - mae: 0.0231 - val_loss: 0.0013 - val_mae: 0.0199
# Epoch 208/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - mae: 0.0258 - val_loss: 0.0014 - val_mae: 0.0219
# Epoch 209/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - mae: 0.0261 - val_loss: 0.0013 - val_mae: 0.0206
# Epoch 210/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - mae: 0.0242 - val_loss: 0.0014 - val_mae: 0.0227
# Epoch 211/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - mae: 0.0249 - val_loss: 0.0012 - val_mae: 0.0184
# Epoch 212/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - mae: 0.0239 - val_loss: 0.0014 - val_mae: 0.0209
# Epoch 213/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - mae: 0.0236 - val_loss: 0.0012 - val_mae: 0.0186
# Epoch 214/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0017 - mae: 0.0228 - val_loss: 0.0013 - val_mae: 0.0179
# Epoch 215/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - mae: 0.0218 - val_loss: 0.0012 - val_mae: 0.0164
# Epoch 216/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - mae: 0.0215 - val_loss: 0.0012 - val_mae: 0.0169
# Epoch 217/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - mae: 0.0226 - val_loss: 0.0012 - val_mae: 0.0160
# Epoch 218/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - mae: 0.0208 - val_loss: 0.0012 - val_mae: 0.0171
# Epoch 219/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - mae: 0.0212 - val_loss: 0.0011 - val_mae: 0.0169
# Epoch 220/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - mae: 0.0241 - val_loss: 0.0012 - val_mae: 0.0187
# Epoch 221/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - mae: 0.0236 - val_loss: 0.0012 - val_mae: 0.0184
# Epoch 222/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - mae: 0.0224 - val_loss: 0.0011 - val_mae: 0.0178
# Epoch 223/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0016 - mae: 0.0217 - val_loss: 0.0012 - val_mae: 0.0185
# Epoch 224/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - mae: 0.0226 - val_loss: 0.0011 - val_mae: 0.0182
# Epoch 225/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - mae: 0.0235 - val_loss: 0.0011 - val_mae: 0.0166
# Epoch 226/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - mae: 0.0230 - val_loss: 0.0011 - val_mae: 0.0182
# Epoch 227/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022 - mae: 0.0287 - val_loss: 0.0012 - val_mae: 0.0207
# Epoch 228/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - mae: 0.0290 - val_loss: 0.0015 - val_mae: 0.0240
# Epoch 229/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - mae: 0.0287 - val_loss: 0.0017 - val_mae: 0.0265
# Epoch 230/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - mae: 0.0270 - val_loss: 0.0018 - val_mae: 0.0283
# Epoch 231/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0020 - mae: 0.0287 - val_loss: 0.0012 - val_mae: 0.0213
# Epoch 232/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - mae: 0.0257 - val_loss: 0.0012 - val_mae: 0.0193
# Epoch 233/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0016 - mae: 0.0235 - val_loss: 0.0011 - val_mae: 0.0188
# Epoch 234/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - mae: 0.0222 - val_loss: 0.0011 - val_mae: 0.0183
# Epoch 235/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0016 - mae: 0.0229 - val_loss: 0.0012 - val_mae: 0.0195
# Epoch 236/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - mae: 0.0212 - val_loss: 0.0013 - val_mae: 0.0238
# Epoch 237/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - mae: 0.0262 - val_loss: 0.0010 - val_mae: 0.0181
# Epoch 238/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - mae: 0.0236 - val_loss: 9.8273e-04 - val_mae: 0.0156
# Epoch 239/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - mae: 0.0215 - val_loss: 9.9509e-04 - val_mae: 0.0166
# Epoch 240/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - mae: 0.0212 - val_loss: 0.0011 - val_mae: 0.0188
# Epoch 241/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - mae: 0.0216 - val_loss: 0.0010 - val_mae: 0.0196
# Epoch 242/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - mae: 0.0245 - val_loss: 0.0010 - val_mae: 0.0165
# Epoch 243/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0017 - mae: 0.0244 - val_loss: 0.0010 - val_mae: 0.0189
# Epoch 244/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - mae: 0.0254 - val_loss: 0.0010 - val_mae: 0.0181
# Epoch 245/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - mae: 0.0216 - val_loss: 0.0012 - val_mae: 0.0207
# Epoch 246/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - mae: 0.0220 - val_loss: 9.7007e-04 - val_mae: 0.0166
# Epoch 247/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - mae: 0.0205 - val_loss: 9.9471e-04 - val_mae: 0.0149
# Epoch 248/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mae: 0.0188 - val_loss: 8.8604e-04 - val_mae: 0.0148
# Epoch 249/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - mae: 0.0227 - val_loss: 9.8344e-04 - val_mae: 0.0177
# Epoch 250/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - mae: 0.0218 - val_loss: 0.0010 - val_mae: 0.0183
# Epoch 251/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mae: 0.0211 - val_loss: 0.0011 - val_mae: 0.0209
# Epoch 252/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - mae: 0.0218 - val_loss: 0.0010 - val_mae: 0.0187
# Epoch 253/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - mae: 0.0229 - val_loss: 9.6864e-04 - val_mae: 0.0186
# Epoch 254/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - mae: 0.0232 - val_loss: 8.6990e-04 - val_mae: 0.0154
# Epoch 255/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mae: 0.0191 - val_loss: 0.0011 - val_mae: 0.0187
# Epoch 256/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - mae: 0.0200 - val_loss: 9.8578e-04 - val_mae: 0.0198
# Epoch 257/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - mae: 0.0212 - val_loss: 9.1996e-04 - val_mae: 0.0162
# Epoch 258/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mae: 0.0205 - val_loss: 9.1029e-04 - val_mae: 0.0176
# Epoch 259/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - mae: 0.0207 - val_loss: 8.3568e-04 - val_mae: 0.0145
# Epoch 260/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mae: 0.0191 - val_loss: 8.8226e-04 - val_mae: 0.0155
# Epoch 261/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mae: 0.0192 - val_loss: 8.5387e-04 - val_mae: 0.0172
# Epoch 262/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mae: 0.0191 - val_loss: 8.8315e-04 - val_mae: 0.0168
# Epoch 263/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mae: 0.0191 - val_loss: 8.9977e-04 - val_mae: 0.0175
# Epoch 264/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mae: 0.0195 - val_loss: 8.9775e-04 - val_mae: 0.0182
# Epoch 265/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mae: 0.0218 - val_loss: 9.3874e-04 - val_mae: 0.0164
# Epoch 266/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - mae: 0.0218 - val_loss: 8.7240e-04 - val_mae: 0.0172
# Epoch 267/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mae: 0.0193 - val_loss: 8.5314e-04 - val_mae: 0.0160
# Epoch 268/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0013 - mae: 0.0211 - val_loss: 8.2490e-04 - val_mae: 0.0144
# Epoch 269/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - mae: 0.0184 - val_loss: 7.4471e-04 - val_mae: 0.0130
# Epoch 270/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - mae: 0.0183 - val_loss: 7.4419e-04 - val_mae: 0.0131
# Epoch 271/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - mae: 0.0167 - val_loss: 7.8013e-04 - val_mae: 0.0138
# Epoch 272/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - mae: 0.0166 - val_loss: 7.6011e-04 - val_mae: 0.0147
# Epoch 273/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - mae: 0.0193 - val_loss: 8.2806e-04 - val_mae: 0.0155
# Epoch 274/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - mae: 0.0197 - val_loss: 8.1343e-04 - val_mae: 0.0181
# Epoch 275/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mae: 0.0208 - val_loss: 8.3270e-04 - val_mae: 0.0168
# Epoch 276/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - mae: 0.0185 - val_loss: 8.3188e-04 - val_mae: 0.0166
# Epoch 277/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - mae: 0.0185 - val_loss: 8.5369e-04 - val_mae: 0.0174
# Epoch 278/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - mae: 0.0195 - val_loss: 8.2885e-04 - val_mae: 0.0162
# Epoch 279/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - mae: 0.0250 - val_loss: 0.0010 - val_mae: 0.0223
# Epoch 280/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - mae: 0.0257 - val_loss: 8.0228e-04 - val_mae: 0.0172
# Epoch 281/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - mae: 0.0225 - val_loss: 7.9868e-04 - val_mae: 0.0176
# Epoch 282/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014 - mae: 0.0243 - val_loss: 9.3693e-04 - val_mae: 0.0203
# Epoch 283/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0014 - mae: 0.0239 - val_loss: 0.0011 - val_mae: 0.0227
# Epoch 284/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mae: 0.0244 - val_loss: 0.0011 - val_mae: 0.0230
# Epoch 285/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mae: 0.0235 - val_loss: 0.0012 - val_mae: 0.0232
# Epoch 286/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012 - mae: 0.0235 - val_loss: 8.6491e-04 - val_mae: 0.0192
# Epoch 287/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mae: 0.0228 - val_loss: 7.9168e-04 - val_mae: 0.0176
# Epoch 288/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0011 - mae: 0.0222 - val_loss: 9.1175e-04 - val_mae: 0.0200
# Epoch 289/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - mae: 0.0207 - val_loss: 7.5492e-04 - val_mae: 0.0178
# Epoch 290/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - mae: 0.0189 - val_loss: 7.2297e-04 - val_mae: 0.0139
# Epoch 291/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.7729e-04 - mae: 0.0168 - val_loss: 6.9706e-04 - val_mae: 0.0150
# Epoch 292/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2386e-04 - mae: 0.0174 - val_loss: 9.0979e-04 - val_mae: 0.0175
# Epoch 293/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0011 - mae: 0.0193 - val_loss: 7.3104e-04 - val_mae: 0.0178
# Epoch 294/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0010 - mae: 0.0183 - val_loss: 6.9775e-04 - val_mae: 0.0145
# Epoch 295/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.8200e-04 - mae: 0.0187 - val_loss: 6.7532e-04 - val_mae: 0.0139
# Epoch 296/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.4559e-04 - mae: 0.0170 - val_loss: 6.9392e-04 - val_mae: 0.0145
# Epoch 297/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0010 - mae: 0.0175 - val_loss: 6.2821e-04 - val_mae: 0.0137
# Epoch 298/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.3992e-04 - mae: 0.0176 - val_loss: 6.2025e-04 - val_mae: 0.0142
# Epoch 299/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9930e-04 - mae: 0.0174 - val_loss: 7.1709e-04 - val_mae: 0.0145
# Epoch 300/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2270e-04 - mae: 0.0166 - val_loss: 6.9230e-04 - val_mae: 0.0168
# Epoch 301/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.6548e-04 - mae: 0.0163 - val_loss: 7.2349e-04 - val_mae: 0.0155
# Epoch 302/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0010 - mae: 0.0187 - val_loss: 6.1853e-04 - val_mae: 0.0137
# Epoch 303/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.3553e-04 - mae: 0.0166 - val_loss: 5.8761e-04 - val_mae: 0.0117
# Epoch 304/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4169e-04 - mae: 0.0168 - val_loss: 6.8126e-04 - val_mae: 0.0156
# Epoch 305/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.8505e-04 - mae: 0.0167 - val_loss: 5.8278e-04 - val_mae: 0.0126
# Epoch 306/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.7973e-04 - mae: 0.0167 - val_loss: 6.3423e-04 - val_mae: 0.0125
# Epoch 307/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.7493e-04 - mae: 0.0157 - val_loss: 8.7219e-04 - val_mae: 0.0203
# Epoch 308/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mae: 0.0222 - val_loss: 8.1941e-04 - val_mae: 0.0192
# Epoch 309/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.9089e-04 - mae: 0.0199 - val_loss: 6.4701e-04 - val_mae: 0.0149
# Epoch 310/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9798e-04 - mae: 0.0174 - val_loss: 5.8824e-04 - val_mae: 0.0129
# Epoch 311/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.3357e-04 - mae: 0.0166 - val_loss: 5.7087e-04 - val_mae: 0.0139
# Epoch 312/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.8999e-04 - mae: 0.0172 - val_loss: 6.6235e-04 - val_mae: 0.0155
# Epoch 313/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.8906e-04 - mae: 0.0175 - val_loss: 6.2349e-04 - val_mae: 0.0158
# Epoch 314/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.0711e-04 - mae: 0.0166 - val_loss: 5.7840e-04 - val_mae: 0.0143
# Epoch 315/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.3829e-04 - mae: 0.0173 - val_loss: 5.4899e-04 - val_mae: 0.0132
# Epoch 316/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8092e-04 - mae: 0.0155 - val_loss: 6.2395e-04 - val_mae: 0.0142
# Epoch 317/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.2001e-04 - mae: 0.0151 - val_loss: 5.4223e-04 - val_mae: 0.0133
# Epoch 318/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.3819e-04 - mae: 0.0172 - val_loss: 5.5044e-04 - val_mae: 0.0133
# Epoch 319/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.2862e-04 - mae: 0.0165 - val_loss: 6.7742e-04 - val_mae: 0.0166
# Epoch 320/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.7534e-04 - mae: 0.0175 - val_loss: 6.3919e-04 - val_mae: 0.0163
# Epoch 321/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0617e-04 - mae: 0.0179 - val_loss: 5.2011e-04 - val_mae: 0.0125
# Epoch 322/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.1320e-04 - mae: 0.0162 - val_loss: 8.3941e-04 - val_mae: 0.0189
# Epoch 323/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4480e-04 - mae: 0.0170 - val_loss: 6.3885e-04 - val_mae: 0.0163
# Epoch 324/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2733e-04 - mae: 0.0190 - val_loss: 5.7547e-04 - val_mae: 0.0148
# Epoch 325/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.3606e-04 - mae: 0.0189 - val_loss: 5.5021e-04 - val_mae: 0.0141
# Epoch 326/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 7.5942e-04 - mae: 0.0157 - val_loss: 5.3540e-04 - val_mae: 0.0136
# Epoch 327/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7890e-04 - mae: 0.0165 - val_loss: 4.9123e-04 - val_mae: 0.0129
# Epoch 328/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8385e-04 - mae: 0.0146 - val_loss: 5.6474e-04 - val_mae: 0.0138
# Epoch 329/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0053e-04 - mae: 0.0155 - val_loss: 5.3610e-04 - val_mae: 0.0132
# Epoch 330/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.3662e-04 - mae: 0.0155 - val_loss: 5.3240e-04 - val_mae: 0.0143
# Epoch 331/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5082e-04 - mae: 0.0161 - val_loss: 5.5085e-04 - val_mae: 0.0143
# Epoch 332/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1964e-04 - mae: 0.0151 - val_loss: 4.9785e-04 - val_mae: 0.0120
# Epoch 333/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 7.1569e-04 - mae: 0.0142 - val_loss: 5.5340e-04 - val_mae: 0.0142
# Epoch 334/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1356e-04 - mae: 0.0162 - val_loss: 6.0237e-04 - val_mae: 0.0170
# Epoch 335/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6417e-04 - mae: 0.0177 - val_loss: 6.5232e-04 - val_mae: 0.0172
# Epoch 336/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0624e-04 - mae: 0.0181 - val_loss: 5.8577e-04 - val_mae: 0.0171
# Epoch 337/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6359e-04 - mae: 0.0167 - val_loss: 4.9334e-04 - val_mae: 0.0121
# Epoch 338/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9927e-04 - mae: 0.0159 - val_loss: 4.5188e-04 - val_mae: 0.0125
# Epoch 339/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7995e-04 - mae: 0.0153 - val_loss: 4.1177e-04 - val_mae: 0.0105
# Epoch 340/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6131e-04 - mae: 0.0148 - val_loss: 4.3412e-04 - val_mae: 0.0105
# Epoch 341/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6470e-04 - mae: 0.0137 - val_loss: 4.3266e-04 - val_mae: 0.0119
# Epoch 342/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3638e-04 - mae: 0.0144 - val_loss: 5.1562e-04 - val_mae: 0.0124
# Epoch 343/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8591e-04 - mae: 0.0143 - val_loss: 4.1071e-04 - val_mae: 0.0114
# Epoch 344/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7290e-04 - mae: 0.0125 - val_loss: 6.6067e-04 - val_mae: 0.0160
# Epoch 345/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0871e-04 - mae: 0.0165 - val_loss: 8.0520e-04 - val_mae: 0.0216
# Epoch 346/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3557e-04 - mae: 0.0201 - val_loss: 8.4205e-04 - val_mae: 0.0215
# Epoch 347/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.4819e-04 - mae: 0.0194 - val_loss: 6.1655e-04 - val_mae: 0.0179
# Epoch 348/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9541e-04 - mae: 0.0186 - val_loss: 5.0254e-04 - val_mae: 0.0145
# Epoch 349/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9765e-04 - mae: 0.0169 - val_loss: 4.3565e-04 - val_mae: 0.0119
# Epoch 350/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5913e-04 - mae: 0.0155 - val_loss: 4.2039e-04 - val_mae: 0.0110
# Epoch 351/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3803e-04 - mae: 0.0148 - val_loss: 4.2357e-04 - val_mae: 0.0113
# Epoch 352/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3999e-04 - mae: 0.0145 - val_loss: 4.4462e-04 - val_mae: 0.0124
# Epoch 353/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5309e-04 - mae: 0.0143 - val_loss: 4.3512e-04 - val_mae: 0.0113
# Epoch 354/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9471e-04 - mae: 0.0136 - val_loss: 3.7333e-04 - val_mae: 0.0102
# Epoch 355/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2253e-04 - mae: 0.0137 - val_loss: 3.7264e-04 - val_mae: 0.0110
# Epoch 356/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6037e-04 - mae: 0.0131 - val_loss: 4.5082e-04 - val_mae: 0.0121
# Epoch 357/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7703e-04 - mae: 0.0131 - val_loss: 4.0079e-04 - val_mae: 0.0115
# Epoch 358/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4547e-04 - mae: 0.0147 - val_loss: 3.9316e-04 - val_mae: 0.0110
# Epoch 359/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.1998e-04 - mae: 0.0145 - val_loss: 3.7874e-04 - val_mae: 0.0097
# Epoch 360/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8261e-04 - mae: 0.0134 - val_loss: 3.7394e-04 - val_mae: 0.0111
# Epoch 361/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4120e-04 - mae: 0.0133 - val_loss: 4.4508e-04 - val_mae: 0.0132
# Epoch 362/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5757e-04 - mae: 0.0133 - val_loss: 3.4336e-04 - val_mae: 0.0099
# Epoch 363/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3708e-04 - mae: 0.0124 - val_loss: 3.7563e-04 - val_mae: 0.0115
# Epoch 364/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3320e-04 - mae: 0.0127 - val_loss: 3.4718e-04 - val_mae: 0.0105
# Epoch 365/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5952e-04 - mae: 0.0129 - val_loss: 4.1222e-04 - val_mae: 0.0122
# Epoch 366/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6240e-04 - mae: 0.0131 - val_loss: 5.1817e-04 - val_mae: 0.0156
# Epoch 367/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7238e-04 - mae: 0.0171 - val_loss: 8.0811e-04 - val_mae: 0.0211
# Epoch 368/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8087e-04 - mae: 0.0191 - val_loss: 4.2626e-04 - val_mae: 0.0142
# Epoch 369/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3052e-04 - mae: 0.0164 - val_loss: 4.1789e-04 - val_mae: 0.0115
# Epoch 370/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8670e-04 - mae: 0.0150 - val_loss: 3.4490e-04 - val_mae: 0.0109
# Epoch 371/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5683e-04 - mae: 0.0150 - val_loss: 3.1909e-04 - val_mae: 0.0093
# Epoch 372/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5317e-04 - mae: 0.0129 - val_loss: 3.9977e-04 - val_mae: 0.0135
# Epoch 373/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.3955e-04 - mae: 0.0146 - val_loss: 3.6572e-04 - val_mae: 0.0124
# Epoch 374/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7541e-04 - mae: 0.0144 - val_loss: 3.1896e-04 - val_mae: 0.0099
# Epoch 375/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1060e-04 - mae: 0.0127 - val_loss: 3.3338e-04 - val_mae: 0.0097
# Epoch 376/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6915e-04 - mae: 0.0117 - val_loss: 3.5326e-04 - val_mae: 0.0105
# Epoch 377/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1350e-04 - mae: 0.0125 - val_loss: 2.8000e-04 - val_mae: 0.0079
# Epoch 378/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7218e-04 - mae: 0.0122 - val_loss: 3.8945e-04 - val_mae: 0.0130
# Epoch 379/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7349e-04 - mae: 0.0150 - val_loss: 4.8831e-04 - val_mae: 0.0153
# Epoch 380/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8854e-04 - mae: 0.0158 - val_loss: 3.7503e-04 - val_mae: 0.0123
# Epoch 381/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1356e-04 - mae: 0.0149 - val_loss: 3.7964e-04 - val_mae: 0.0109
# Epoch 382/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9413e-04 - mae: 0.0125 - val_loss: 7.8960e-04 - val_mae: 0.0170
# Epoch 383/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8367e-04 - mae: 0.0140 - val_loss: 3.1472e-04 - val_mae: 0.0104
# Epoch 384/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9490e-04 - mae: 0.0124 - val_loss: 4.4196e-04 - val_mae: 0.0127
# Epoch 385/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6617e-04 - mae: 0.0119 - val_loss: 2.8159e-04 - val_mae: 0.0090
# Epoch 386/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7538e-04 - mae: 0.0126 - val_loss: 3.2024e-04 - val_mae: 0.0101
# Epoch 387/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4684e-04 - mae: 0.0111 - val_loss: 3.1225e-04 - val_mae: 0.0096
# Epoch 388/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4703e-04 - mae: 0.0114 - val_loss: 2.9014e-04 - val_mae: 0.0097
# Epoch 389/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5368e-04 - mae: 0.0122 - val_loss: 3.1776e-04 - val_mae: 0.0107
# Epoch 390/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 4.2552e-04 - mae: 0.0111 - val_loss: 2.7830e-04 - val_mae: 0.0098
# Epoch 391/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1189e-04 - mae: 0.0111 - val_loss: 2.5757e-04 - val_mae: 0.0078
# Epoch 392/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0652e-04 - mae: 0.0102 - val_loss: 2.5899e-04 - val_mae: 0.0082
# Epoch 393/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7553e-04 - mae: 0.0095 - val_loss: 2.5523e-04 - val_mae: 0.0069
# Epoch 394/1000
# ...
# Epoch 501/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0879e-04 - mae: 0.0086 - val_loss: 1.4387e-04 - val_mae: 0.0074
# Epoch 502/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9739e-04 - mae: 0.0083 - val_loss: 1.4796e-04 - val_mae: 0.0079
# Epoch 503/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9601e-04 - mae: 0.0079 - val_loss: 1.2488e-04 - val_mae: 0.0057
# Epoch 504/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9434e-04 - mae: 0.0078 - val_loss: 1.7473e-04 - val_mae: 0.0086
# Epoch 505/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8135e-04 - mae: 0.0076 - val_loss: 1.4578e-04 - val_mae: 0.0084
# Epoch 506/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8605e-04 - mae: 0.0082 - val_loss: 2.8804e-04 - val_mae: 0.0111
# Epoch 507/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6283e-04 - mae: 0.0102 - val_loss: 1.9646e-04 - val_mae: 0.0081
# Epoch 508/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.3393e-04 - mae: 0.0114 - val_loss: 1.6197e-04 - val_mae: 0.0085
# Epoch 509/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0049e-04 - mae: 0.0115 - val_loss: 3.0022e-04 - val_mae: 0.0126
# Epoch 510/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4842e-04 - mae: 0.0126 - val_loss: 1.2838e-04 - val_mae: 0.0074
# Epoch 511/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2460e-04 - mae: 0.0095 - val_loss: 1.5193e-04 - val_mae: 0.0075
# Epoch 512/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4072e-04 - mae: 0.0096 - val_loss: 1.2676e-04 - val_mae: 0.0068
# Epoch 513/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0957e-04 - mae: 0.0090 - val_loss: 1.4830e-04 - val_mae: 0.0077
# Epoch 514/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9782e-04 - mae: 0.0083 - val_loss: 1.2360e-04 - val_mae: 0.0063
# Epoch 515/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8190e-04 - mae: 0.0077 - val_loss: 1.8364e-04 - val_mae: 0.0085
# Epoch 516/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0375e-04 - mae: 0.0080 - val_loss: 1.2279e-04 - val_mae: 0.0068
# Epoch 517/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0391e-04 - mae: 0.0083 - val_loss: 1.4027e-04 - val_mae: 0.0077
# Epoch 518/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7870e-04 - mae: 0.0080 - val_loss: 1.7526e-04 - val_mae: 0.0092
# Epoch 519/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8347e-04 - mae: 0.0083 - val_loss: 1.3139e-04 - val_mae: 0.0076
# Epoch 520/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7087e-04 - mae: 0.0081 - val_loss: 1.7560e-04 - val_mae: 0.0081
# Epoch 521/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9268e-04 - mae: 0.0084 - val_loss: 1.2199e-04 - val_mae: 0.0060
# Epoch 522/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8887e-04 - mae: 0.0084 - val_loss: 1.5713e-04 - val_mae: 0.0075
# Epoch 523/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3439e-04 - mae: 0.0091 - val_loss: 1.9328e-04 - val_mae: 0.0092
# Epoch 524/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4029e-04 - mae: 0.0099 - val_loss: 2.7476e-04 - val_mae: 0.0108
# Epoch 525/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6674e-04 - mae: 0.0107 - val_loss: 1.5000e-04 - val_mae: 0.0075
# Epoch 526/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7840e-04 - mae: 0.0096 - val_loss: 1.8660e-04 - val_mae: 0.0102
# Epoch 527/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2230e-04 - mae: 0.0126 - val_loss: 3.5040e-04 - val_mae: 0.0145
# Epoch 528/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9694e-04 - mae: 0.0124 - val_loss: 2.0708e-04 - val_mae: 0.0107
# Epoch 529/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4916e-04 - mae: 0.0117 - val_loss: 1.8747e-04 - val_mae: 0.0084
# Epoch 530/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0348e-04 - mae: 0.0119 - val_loss: 2.3699e-04 - val_mae: 0.0120
# Epoch 531/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6235e-04 - mae: 0.0119 - val_loss: 2.8463e-04 - val_mae: 0.0137
# Epoch 532/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7887e-04 - mae: 0.0118 - val_loss: 1.1653e-04 - val_mae: 0.0066
# Epoch 533/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.3770e-04 - mae: 0.0099 - val_loss: 3.0013e-04 - val_mae: 0.0129
# Epoch 534/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1678e-04 - mae: 0.0091 - val_loss: 2.0514e-04 - val_mae: 0.0102
# Epoch 535/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4703e-04 - mae: 0.0101 - val_loss: 1.2943e-04 - val_mae: 0.0070
# Epoch 536/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8548e-04 - mae: 0.0084 - val_loss: 1.3368e-04 - val_mae: 0.0076
# Epoch 537/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7441e-04 - mae: 0.0083 - val_loss: 1.2865e-04 - val_mae: 0.0069
# Epoch 538/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7670e-04 - mae: 0.0081 - val_loss: 1.0616e-04 - val_mae: 0.0061
# Epoch 539/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5858e-04 - mae: 0.0076 - val_loss: 1.0635e-04 - val_mae: 0.0063
# Epoch 540/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4631e-04 - mae: 0.0069 - val_loss: 9.9765e-05 - val_mae: 0.0060
# Epoch 541/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5080e-04 - mae: 0.0070 - val_loss: 9.3626e-05 - val_mae: 0.0052
# Epoch 542/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5405e-04 - mae: 0.0068 - val_loss: 9.1631e-05 - val_mae: 0.0052
# Epoch 543/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4801e-04 - mae: 0.0067 - val_loss: 1.0567e-04 - val_mae: 0.0061
# Epoch 544/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4340e-04 - mae: 0.0069 - val_loss: 9.6737e-05 - val_mae: 0.0053
# Epoch 545/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4839e-04 - mae: 0.0065 - val_loss: 1.3373e-04 - val_mae: 0.0070
# Epoch 546/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0544e-04 - mae: 0.0084 - val_loss: 4.3850e-04 - val_mae: 0.0167
# Epoch 547/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9817e-04 - mae: 0.0142 - val_loss: 1.6625e-04 - val_mae: 0.0094
# Epoch 548/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1670e-04 - mae: 0.0103 - val_loss: 1.4489e-04 - val_mae: 0.0084
# Epoch 549/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1249e-04 - mae: 0.0092 - val_loss: 1.9400e-04 - val_mae: 0.0104
# Epoch 550/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3355e-04 - mae: 0.0106 - val_loss: 3.1740e-04 - val_mae: 0.0140
# Epoch 551/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.8988e-04 - mae: 0.0118 - val_loss: 1.2324e-04 - val_mae: 0.0075
# Epoch 552/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3593e-04 - mae: 0.0103 - val_loss: 1.5288e-04 - val_mae: 0.0082
# Epoch 553/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9568e-04 - mae: 0.0090 - val_loss: 3.7665e-04 - val_mae: 0.0144
# Epoch 554/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9762e-04 - mae: 0.0118 - val_loss: 3.3078e-04 - val_mae: 0.0143
# Epoch 555/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0276e-04 - mae: 0.0125 - val_loss: 2.1961e-04 - val_mae: 0.0098
# Epoch 556/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6971e-04 - mae: 0.0116 - val_loss: 1.7981e-04 - val_mae: 0.0097
# Epoch 557/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3030e-04 - mae: 0.0106 - val_loss: 3.2479e-04 - val_mae: 0.0148
# Epoch 558/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6766e-04 - mae: 0.0123 - val_loss: 2.2614e-04 - val_mae: 0.0114
# Epoch 559/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3469e-04 - mae: 0.0107 - val_loss: 1.1015e-04 - val_mae: 0.0067
# Epoch 560/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8784e-04 - mae: 0.0093 - val_loss: 1.3328e-04 - val_mae: 0.0082
# Epoch 561/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8033e-04 - mae: 0.0093 - val_loss: 1.3590e-04 - val_mae: 0.0078
# Epoch 562/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6495e-04 - mae: 0.0083 - val_loss: 1.5461e-04 - val_mae: 0.0093
# Epoch 563/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8478e-04 - mae: 0.0093 - val_loss: 1.1733e-04 - val_mae: 0.0071
# Epoch 564/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8851e-04 - mae: 0.0088 - val_loss: 1.2691e-04 - val_mae: 0.0066
# Epoch 565/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5781e-04 - mae: 0.0074 - val_loss: 1.3679e-04 - val_mae: 0.0076
# Epoch 566/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9602e-04 - mae: 0.0088 - val_loss: 8.6256e-05 - val_mae: 0.0051
# Epoch 567/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.3964e-04 - mae: 0.0070 - val_loss: 8.5850e-05 - val_mae: 0.0054
# Epoch 568/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3780e-04 - mae: 0.0068 - val_loss: 1.3201e-04 - val_mae: 0.0075
# Epoch 569/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6277e-04 - mae: 0.0077 - val_loss: 1.0062e-04 - val_mae: 0.0052
# Epoch 570/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4148e-04 - mae: 0.0062 - val_loss: 1.4597e-04 - val_mae: 0.0084
# Epoch 571/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7676e-04 - mae: 0.0085 - val_loss: 1.4622e-04 - val_mae: 0.0085
# Epoch 572/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4001e-04 - mae: 0.0074 - val_loss: 1.3377e-04 - val_mae: 0.0081
# Epoch 573/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7529e-04 - mae: 0.0086 - val_loss: 1.1758e-04 - val_mae: 0.0061
# Epoch 574/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8524e-04 - mae: 0.0089 - val_loss: 1.2596e-04 - val_mae: 0.0081
# Epoch 575/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0056e-04 - mae: 0.0098 - val_loss: 1.8557e-04 - val_mae: 0.0095
# Epoch 576/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8892e-04 - mae: 0.0112 - val_loss: 8.2638e-05 - val_mae: 0.0053
# Epoch 577/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1961e-04 - mae: 0.0095 - val_loss: 2.2643e-04 - val_mae: 0.0111
# Epoch 578/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1663e-04 - mae: 0.0102 - val_loss: 1.5674e-04 - val_mae: 0.0090
# Epoch 579/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7985e-04 - mae: 0.0113 - val_loss: 2.3521e-04 - val_mae: 0.0117
# Epoch 580/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5741e-04 - mae: 0.0131 - val_loss: 4.1903e-04 - val_mae: 0.0160
# Epoch 581/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4721e-04 - mae: 0.0139 - val_loss: 4.0625e-04 - val_mae: 0.0153
# Epoch 582/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0324e-04 - mae: 0.0144 - val_loss: 2.5886e-04 - val_mae: 0.0118
# Epoch 583/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9067e-04 - mae: 0.0146 - val_loss: 4.1715e-04 - val_mae: 0.0160
# Epoch 584/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1924e-04 - mae: 0.0152 - val_loss: 1.6691e-04 - val_mae: 0.0092
# Epoch 585/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0492e-04 - mae: 0.0128 - val_loss: 2.6247e-04 - val_mae: 0.0116
# Epoch 586/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.8530e-04 - mae: 0.0118 - val_loss: 3.0125e-04 - val_mae: 0.0120
# Epoch 587/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5138e-04 - mae: 0.0123 - val_loss: 4.4576e-04 - val_mae: 0.0154
# Epoch 588/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8293e-04 - mae: 0.0136 - val_loss: 5.1764e-04 - val_mae: 0.0152
# Epoch 589/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8824e-04 - mae: 0.0169 - val_loss: 3.7773e-04 - val_mae: 0.0129
# Epoch 590/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9647e-04 - mae: 0.0147 - val_loss: 3.0441e-04 - val_mae: 0.0131
# Epoch 591/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7955e-04 - mae: 0.0135 - val_loss: 3.1455e-04 - val_mae: 0.0146
# Epoch 592/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4454e-04 - mae: 0.0166 - val_loss: 4.6061e-04 - val_mae: 0.0167
# Epoch 593/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8549e-04 - mae: 0.0177 - val_loss: 1.2165e-04 - val_mae: 0.0075
# Epoch 594/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0594e-04 - mae: 0.0131 - val_loss: 1.7791e-04 - val_mae: 0.0104
# Epoch 595/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1358e-04 - mae: 0.0154 - val_loss: 4.8517e-04 - val_mae: 0.0178
# Epoch 596/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0885e-04 - mae: 0.0170 - val_loss: 2.4249e-04 - val_mae: 0.0124
# Epoch 597/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7882e-04 - mae: 0.0141 - val_loss: 4.0589e-04 - val_mae: 0.0146
# Epoch 598/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1951e-04 - mae: 0.0166 - val_loss: 0.0011 - val_mae: 0.0267
# Epoch 599/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3136e-04 - mae: 0.0202 - val_loss: 4.0324e-04 - val_mae: 0.0148
# Epoch 600/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1938e-04 - mae: 0.0170 - val_loss: 2.4885e-04 - val_mae: 0.0117
# Epoch 601/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8354e-04 - mae: 0.0146 - val_loss: 3.0572e-04 - val_mae: 0.0130
# Epoch 602/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3842e-04 - mae: 0.0154 - val_loss: 4.2351e-04 - val_mae: 0.0153
# Epoch 603/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3922e-04 - mae: 0.0178 - val_loss: 8.9158e-04 - val_mae: 0.0238
# Epoch 604/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 5.1469e-04 - mae: 0.0180 - val_loss: 2.8269e-04 - val_mae: 0.0127
# Epoch 605/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1352e-04 - mae: 0.0163 - val_loss: 2.0509e-04 - val_mae: 0.0111
# Epoch 606/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8687e-04 - mae: 0.0148 - val_loss: 6.4252e-04 - val_mae: 0.0177
# Epoch 607/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5316e-04 - mae: 0.0175 - val_loss: 5.4099e-04 - val_mae: 0.0174
# Epoch 608/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7043e-04 - mae: 0.0178 - val_loss: 3.3518e-04 - val_mae: 0.0145
# Epoch 609/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4598e-04 - mae: 0.0145 - val_loss: 2.3832e-04 - val_mae: 0.0115
# Epoch 610/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8274e-04 - mae: 0.0123 - val_loss: 2.2544e-04 - val_mae: 0.0105
# Epoch 611/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1341e-04 - mae: 0.0103 - val_loss: 2.3092e-04 - val_mae: 0.0113
# Epoch 612/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9952e-04 - mae: 0.0101 - val_loss: 2.9006e-04 - val_mae: 0.0104
# Epoch 613/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5789e-04 - mae: 0.0109 - val_loss: 4.7132e-04 - val_mae: 0.0164
# Epoch 614/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3324e-04 - mae: 0.0147 - val_loss: 3.1897e-04 - val_mae: 0.0123
# Epoch 615/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3479e-04 - mae: 0.0128 - val_loss: 2.4397e-04 - val_mae: 0.0117
# Epoch 616/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6171e-04 - mae: 0.0109 - val_loss: 1.7665e-04 - val_mae: 0.0106
# Epoch 617/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3564e-04 - mae: 0.0109 - val_loss: 2.8629e-04 - val_mae: 0.0123
# Epoch 618/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0512e-04 - mae: 0.0127 - val_loss: 1.1734e-04 - val_mae: 0.0069
# Epoch 619/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1756e-04 - mae: 0.0097 - val_loss: 1.1874e-04 - val_mae: 0.0074
# Epoch 620/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7269e-04 - mae: 0.0091 - val_loss: 1.5799e-04 - val_mae: 0.0095
# Epoch 621/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6035e-04 - mae: 0.0087 - val_loss: 1.1523e-04 - val_mae: 0.0080
# Epoch 622/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4903e-04 - mae: 0.0079 - val_loss: 1.0292e-04 - val_mae: 0.0067
# Epoch 623/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6358e-04 - mae: 0.0083 - val_loss: 1.3222e-04 - val_mae: 0.0079
# Epoch 624/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3234e-04 - mae: 0.0073 - val_loss: 1.0312e-04 - val_mae: 0.0060
# Epoch 625/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2646e-04 - mae: 0.0069 - val_loss: 1.1634e-04 - val_mae: 0.0066
# Epoch 626/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8546e-04 - mae: 0.0088 - val_loss: 1.4635e-04 - val_mae: 0.0075
# Epoch 626: early stopping
# Restoring model weights from the end of the best epoch: 576.

# %%
model = tf.keras.models.load_model(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') if os.path.exists(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') else model

# %%
# Estrai losses da tutti i folds
train_losses = history.history['loss']
val_losses   = history.history['val_loss']

train_losses = train_losses
val_losses = val_losses

# Plot
plt.figure(figsize=(8,5))


# Training loss
plt.plot(train_losses, color='blue', label='Train Loss')
# Validation loss
plt.plot(val_losses, color='red', label='Validation Loss')


# Dettagli grafico
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.savefig(f'{exp_dir}/loss_plot.png')

# %%
def plot_first_n_series(y_pred, y_test, n_series=10, title="Confronto Serie Predette vs Reali"):
    """
    Plotta le prime n_series serie reali e predette per un confronto diretto.

    Args:
        y_pred (np.ndarray): Predizioni del modello (shape: num_samples x seq_len).
        y_test (np.ndarray): Serie reali (shape: num_samples x seq_len).
        n_series (int): Numero di serie da plottare.
        title (str): Titolo del grafico.
    """

    # Limitiamo a n_series per evitare problemi
    n = min(n_series, y_pred.shape[0], y_test.shape[0])

    plt.figure(figsize=(14, 8))

    for i in range(n):
        plt.plot(
            y_test[i], 
            linewidth=1.8, 
            alpha=0.5, 
            label=f"Reale {i+1}" if i == 0 else "",
            color = 'blue'
        )
        plt.plot(
            y_pred[i], 
            linewidth=1.2, 
            linestyle="--", 
            alpha=0.9, 
            label=f"Predetto {i+1}" if i == 0 else "",
            color = 'orange'
        )

    plt.title(title, fontsize=16)
    plt.xlabel("Time Step", fontsize=12)
    plt.ylabel("Valore", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

def plot_diagnosis_gradient(y_pred, y_test, save_path: str,  tolerance:float =0.05, max_samples_heatmap=50, scatter_sample_ratio=0.5, tol_auto = True):
    """
    Dashboard diagnostica con tolleranza AUTO-ADATTIVA alla scala dei dati.
    
    Args:
        tolerance (float): 
            - Se None: La tolleranza viene calcolata automaticamente come il 5% del range dei dati (Max-Min).
            - Se float: Valore assoluto (es. 0.5).
        tol_auto (bool): Se True, usa la tolleranza automatica basata sul range dei dati, altrimenti usa il valore manuale fornito 
        col parametro tolerance.
    """
    
    y_test_flat = y_test.flatten()
    y_pred_flat = y_pred.flatten()

    # ---------------------------------------------------------
    # AUTOMAZIONE TOLLERANZA
    # ---------------------------------------------------------
    if tol_auto:
        data_range = y_test_flat.max() - y_test_flat.min()
        # Impostiamo la tolleranza al 5% del range totale (regolabile)
        tolerance = data_range * tolerance 
        tol_label = f"Auto (5% Range: ±{tolerance:.2f})"
    else:
        tol_label = f"Manuale (±{tolerance})"

    fig, axes = plt.subplots(1, 2, figsize=(22, 8))

    # -----------------------------
    # 1. HEATMAP (SX)
    # -----------------------------
    errors = np.abs(y_test - y_pred)
    errors_subset = errors[:max_samples_heatmap]
    
    # Adattiamo anche la scala colori della heatmap alla tolleranza
    # Tutto ciò che è oltre 3 volte la tolleranza è "errore massimo" visivo
    sns.heatmap(errors_subset, cmap="plasma", ax=axes[0], 
                vmax=tolerance * 3,
                cbar_kws={'label': 'Errore Assoluto'})
    
    axes[0].set_title(f"Heatmap Errori (Primi {max_samples_heatmap} campioni)", fontsize=16)
    axes[0].set_xlabel("Time Step", fontsize=12)
    axes[0].set_ylabel("Indice Campione", fontsize=12)

    # -----------------------------
    # 2. SCATTER CON SFONDO GRADIENTE (DX)
    # -----------------------------
    
    # Campionamento dati
    if scatter_sample_ratio < 1.0:
        mask = np.random.rand(len(y_test_flat)) < scatter_sample_ratio
        sample_test = y_test_flat[mask]
        sample_pred = y_pred_flat[mask]
    else:
        sample_test = y_test_flat
        sample_pred = y_pred_flat

    # Calcolo limiti grafico
    min_val = min(y_test_flat.min(), y_pred_flat.min())
    max_val = max(y_test_flat.max(), y_pred_flat.max())
    padding = (max_val - min_val) * 0.05
    plot_min = min_val - padding
    plot_max = max_val + padding

    # --- SFONDO GRADIENTE ---
    grid_x, grid_y = np.meshgrid(
        np.linspace(plot_min, plot_max, 200),
        np.linspace(plot_min, plot_max, 200)
    )
    grid_z = np.abs(grid_y - grid_x)

    im = axes[1].imshow(
        grid_z, 
        extent=(plot_min, plot_max, plot_min, plot_max), 
        origin='lower', 
        cmap='RdYlGn_r', 
        alpha=0.4, 
        vmax=tolerance * 4, # Il rosso satura a 4x della tolleranza
        aspect='auto'
    )

    # --- PUNTI BLU ---
    axes[1].scatter(
        sample_test, 
        sample_pred, 
        alpha=0.6, 
        s=15, 
        color='royalblue', 
        edgecolors='white', 
        linewidth=0.3,
        label='Campioni'
    )

    axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

    # Metriche
    within_tol = np.mean(np.abs(y_test_flat - y_pred_flat) <= tolerance) * 100

    axes[1].set_title(
        f"Bontà delle previsioni con {tol_label}\nValori nel range di Tolleranza: {within_tol:.1f}%", 
        fontsize=16
    )
    axes[1].set_xlabel("Valore Reale", fontsize=12)
    axes[1].set_ylabel("Valore Predetto", fontsize=12)
    axes[1].set_xlim(plot_min, plot_max)
    axes[1].set_ylim(plot_min, plot_max)
    
    cbar = plt.colorbar(im, ax=axes[1], pad=0.02)
    cbar.set_label('Gravità Errore (Distanza da diagonale)')

    plt.tight_layout()
    plt.savefig(f'{exp_dir}/{save_path}.png')

# %%
y_pred = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred)
y_test_np = scaler_y.inverse_transform(y_test)

plot_diagnosis_gradient(y_pred, y_test_np, save_path='pred_quality', max_samples_heatmap=10, scatter_sample_ratio=0.7)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_3382/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

# %%
save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/TEST', prefix="pred_plot")
# Out:
# Salvo 26 plot in: ../RISULTATI/2025-11-30/esperimento_METRO966_14-43-40/TEST
# Plot salvati correttamente.

# %%
import json
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_and_log(y_true, y_pred, log_path="log.json"):
    # --- Metriche ---
    mae = mean_absolute_error(y_true, y_pred, multioutput="uniform_average")
    rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput="uniform_average"))

    mask = y_true != 0
    mape = float(np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100.0)

    r2 = r2_score(y_true, y_pred, multioutput="uniform_average")

    # Valore medio del test set
    v_mean = float(np.mean(y_true))

    # --- Stampa ---
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    print(f"Test MAPE: {mape:.2f}%")
    print(f"Test R2: {r2:.4f}")
    print(f"Valore medio del test set: {v_mean:.4f}")

    # --- Salvataggio log ---
    log_data = {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2,
        "test_mean_value": v_mean
    }

    with open(log_path, "w") as f:
        json.dump(log_data, f, indent=4)

    print(f"\nLog salvato in: {log_path}")
evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/evaluation_log.json")
# Impostazioni pandas per visualizzare tutti i dati
# Out:
# Test MAE: 0.9982
# Test RMSE: 1.6826
# Test MAPE: 1.41%
# Test R2: 0.9987
# Valore medio del test set: 136.6233
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_METRO966_14-43-40/evaluation_log.json

# %% [markdown]
# # globale e federato

# %%
fed = tf.keras.models.load_model('/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Metro.keras')

model  = [fed]
model_name = ["federated"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 fed = tf.keras.models.load_model('/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Metro.keras')
#       3 model  = [fed]
#       4 model_name = ["federated"]
#
# File ~/thesis/Federated_Sys/.venv/lib/python3.12/site-packages/keras/src/saving/saving_api.py:203, in load_model(filepath, custom_objects, compile, safe_mode)
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#     202 elif str(filepath).endswith(".keras"):
# --> 203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#     208 else:
#     209     raise ValueError(
#     210         f"File format not supported: filepath={filepath}. "
#     211         "Keras 3 only supports V3 `.keras` files and "
#    (...)    220         "might have a different name)."
#     221     )
#
# ValueError: File not found: filepath=/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Metro.keras. Please ensure the file is an accessible `.keras` zip file.

# %%
checkpoint_filepath = f'{exp_dir}/model/{sensor_name}_fed_model.keras'

# 2. Crea l'istanza della callback
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False, 
    verbose=1
)

# %%
for model, name in zip(model, model_name):
    y_pred = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred)
    y_test_np = scaler_y.inverse_transform(y_test)

    print(f"--- {name} ---")
    #plot_diagnosis_gradient(y_pred, y_test_np, max_samples_heatmap=10, scatter_sample_ratio=0.7)
    evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_evaluation_log.json")
    save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}/TEST', prefix="pred_plot")

    print("\n")
    if name == 'federated':
        model.fit(X_train, y_train, epochs=1000, batch_size=32, callbacks=[model_checkpoint_callback], validation_split=0.2)
        model.load_weights(checkpoint_filepath)
        y_pred = model.predict(X_test)
        y_pred = scaler_y.inverse_transform(y_pred)
        print(f"--- {name} after local fine-tuning ---")
        plot_diagnosis_gradient(y_pred, y_test_np, save_path=f"{name}_pred_quality", max_samples_heatmap=10, scatter_sample_ratio=0.7)
        save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}_fd/TEST', prefix="pred_plot")
        evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_fd_evaluation_log.json")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# --- federated ---
# Test MAE: 34.6291
# Test RMSE: 46.2689
# Test MAPE: 51.94%
# Test R2: 0.2502
# Valore medio del test set: 134.9622
#
# Log salvato in: ../RISULTATI/2025-11-29/esperimento_METRO966_16-04-35/federated_evaluation_log.json
# Salvo 26 plot in: ../RISULTATI/2025-11-29/esperimento_METRO966_16-04-35/federated/TEST
# Plot salvati correttamente.
#
#
# Epoch 1/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0819 - mae: 0.2335 - mse: 0.0819
# Epoch 2/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0356 - mae: 0.1508 - mse: 0.0356
# Epoch 3/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0284 - mae: 0.1311 - mse: 0.0284
# Epoch 4/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0252 - mae: 0.1223 - mse: 0.0252
# Epoch 5/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - mae: 0.0986 - mse: 0.0181
# Epoch 6/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0162 - mae: 0.0972 - mse: 0.0162
# Epoch 7/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0152 - mae: 0.0947 - mse: 0.0152
# Epoch 8/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0129 - mae: 0.0865 - mse: 0.0129
# Epoch 9/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0113 - mae: 0.0789 - mse: 0.0113
# Epoch 10/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0131 - mae: 0.0860 - mse: 0.0131
# Epoch 11/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0115 - mae: 0.0791 - mse: 0.0115
# Epoch 12/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0109 - mae: 0.0787 - mse: 0.0109
# Epoch 13/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108 - mae: 0.0769 - mse: 0.0108
# Epoch 14/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0093 - mae: 0.0727 - mse: 0.0093
# Epoch 15/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0107 - mae: 0.0764 - mse: 0.0107
# Epoch 16/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - mae: 0.0702 - mse: 0.0085
# Epoch 17/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0100 - mae: 0.0730 - mse: 0.0100
# Epoch 18/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103 - mae: 0.0760 - mse: 0.0103
# Epoch 19/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0090 - mae: 0.0701 - mse: 0.0090
# Epoch 20/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0090 - mae: 0.0710 - mse: 0.0090
# Epoch 21/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0086 - mae: 0.0697 - mse: 0.0086
# Epoch 22/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - mae: 0.0685 - mse: 0.0084
# Epoch 23/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089 - mae: 0.0707 - mse: 0.0089
# Epoch 24/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0071 - mae: 0.0626 - mse: 0.0071
# Epoch 25/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - mae: 0.0692 - mse: 0.0084
# Epoch 26/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0084 - mae: 0.0683 - mse: 0.0084
# Epoch 27/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0101 - mae: 0.0751 - mse: 0.0101
# Epoch 28/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0078 - mae: 0.0651 - mse: 0.0078
# Epoch 29/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - mae: 0.0664 - mse: 0.0081
# Epoch 30/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084 - mae: 0.0689 - mse: 0.0084
# Epoch 31/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - mae: 0.0672 - mse: 0.0084
# Epoch 32/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0077 - mae: 0.0665 - mse: 0.0077
# Epoch 33/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - mae: 0.0688 - mse: 0.0086
# Epoch 34/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - mae: 0.0646 - mse: 0.0078
# Epoch 35/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0077 - mae: 0.0651 - mse: 0.0077
# Epoch 36/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0090 - mae: 0.0691 - mse: 0.0090
# Epoch 37/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0071 - mae: 0.0631 - mse: 0.0071
# Epoch 38/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0081 - mae: 0.0649 - mse: 0.0081
# Epoch 39/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - mae: 0.0631 - mse: 0.0072
# Epoch 40/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0085 - mae: 0.0669 - mse: 0.0085
# Epoch 41/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0074 - mae: 0.0636 - mse: 0.0074
# Epoch 42/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - mae: 0.0619 - mse: 0.0072
# Epoch 43/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0077 - mae: 0.0661 - mse: 0.0077
# Epoch 44/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0086 - mae: 0.0705 - mse: 0.0086
# Epoch 45/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0071 - mae: 0.0619 - mse: 0.0071
# Epoch 46/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - mae: 0.0634 - mse: 0.0074
# Epoch 47/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - mae: 0.0633 - mse: 0.0073
# Epoch 48/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0074 - mae: 0.0648 - mse: 0.0074
# Epoch 49/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072 - mae: 0.0640 - mse: 0.0072
# Epoch 50/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - mae: 0.0618 - mse: 0.0070
# Epoch 51/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0077 - mae: 0.0643 - mse: 0.0077
# Epoch 52/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mae: 0.0619 - mse: 0.0073
# Epoch 53/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - mae: 0.0627 - mse: 0.0071
# Epoch 54/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0082 - mae: 0.0652 - mse: 0.0082
# Epoch 55/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - mae: 0.0701 - mse: 0.0086
# Epoch 56/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - mae: 0.0572 - mse: 0.0062
# Epoch 57/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - mae: 0.0603 - mse: 0.0067
# Epoch 58/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - mae: 0.0643 - mse: 0.0072
# Epoch 59/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - mae: 0.0630 - mse: 0.0072
# Epoch 60/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mae: 0.0626 - mse: 0.0073
# Epoch 61/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - mae: 0.0614 - mse: 0.0067
# Epoch 62/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mae: 0.0629 - mse: 0.0068
# Epoch 63/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0073 - mae: 0.0629 - mse: 0.0073
# Epoch 64/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mae: 0.0620 - mse: 0.0068
# Epoch 65/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - mae: 0.0630 - mse: 0.0071
# Epoch 66/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mae: 0.0610 - mse: 0.0069
# Epoch 67/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - mae: 0.0607 - mse: 0.0072
# Epoch 68/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mae: 0.0588 - mse: 0.0065
# Epoch 69/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - mae: 0.0625 - mse: 0.0072
# Epoch 70/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0078 - mae: 0.0663 - mse: 0.0078
# Epoch 71/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - mae: 0.0597 - mse: 0.0067
# Epoch 72/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mae: 0.0609 - mse: 0.0073
# Epoch 73/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0601 - mse: 0.0064
# Epoch 74/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061 - mae: 0.0576 - mse: 0.0061
# Epoch 75/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - mae: 0.0595 - mse: 0.0067
# Epoch 76/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - mae: 0.0642 - mse: 0.0075
# Epoch 77/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mae: 0.0615 - mse: 0.0070
# Epoch 78/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mae: 0.0613 - mse: 0.0068
# Epoch 79/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mae: 0.0616 - mse: 0.0068
# Epoch 80/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - mae: 0.0617 - mse: 0.0071
# Epoch 81/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066 - mae: 0.0599 - mse: 0.0066
# Epoch 82/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0075 - mae: 0.0622 - mse: 0.0075
# Epoch 83/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066 - mae: 0.0602 - mse: 0.0066
# Epoch 84/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mae: 0.0558 - mse: 0.0057
# Epoch 85/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mae: 0.0618 - mse: 0.0069
# Epoch 86/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0066 - mae: 0.0604 - mse: 0.0066
# Epoch 87/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - mae: 0.0600 - mse: 0.0071
# Epoch 88/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mae: 0.0593 - mse: 0.0065
# Epoch 89/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - mae: 0.0575 - mse: 0.0064
# Epoch 90/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - mae: 0.0606 - mse: 0.0067
# Epoch 91/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0062 - mae: 0.0587 - mse: 0.0062
# Epoch 92/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0064 - mae: 0.0579 - mse: 0.0064
# Epoch 93/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - mae: 0.0585 - mse: 0.0066
# Epoch 94/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0076 - mae: 0.0638 - mse: 0.0076
# Epoch 95/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - mae: 0.0614 - mse: 0.0066
# Epoch 96/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0063 - mae: 0.0561 - mse: 0.0063
# Epoch 97/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0582 - mse: 0.0063
# Epoch 98/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - mae: 0.0603 - mse: 0.0067
# Epoch 99/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0607 - mse: 0.0064
# Epoch 100/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mae: 0.0618 - mse: 0.0070
# Epoch 101/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mae: 0.0615 - mse: 0.0070
# Epoch 102/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mae: 0.0600 - mse: 0.0065
# Epoch 103/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - mae: 0.0590 - mse: 0.0062
# Epoch 104/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mae: 0.0555 - mse: 0.0057
# Epoch 105/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0068 - mae: 0.0610 - mse: 0.0068
# Epoch 106/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - mae: 0.0548 - mse: 0.0053
# Epoch 107/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mae: 0.0566 - mse: 0.0057
# Epoch 108/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - mae: 0.0616 - mse: 0.0072
# Epoch 109/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0587 - mse: 0.0063
# Epoch 110/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0607 - mse: 0.0064
# Epoch 111/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mae: 0.0482 - mse: 0.0045
# Epoch 112/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mae: 0.0565 - mse: 0.0057
# Epoch 113/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0070 - mae: 0.0633 - mse: 0.0070
# Epoch 114/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - mae: 0.0580 - mse: 0.0058
# Epoch 115/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0571 - mse: 0.0064
# Epoch 116/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0067 - mae: 0.0607 - mse: 0.0067
# Epoch 117/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0591 - mse: 0.0063
# Epoch 118/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - mae: 0.0560 - mse: 0.0060
# Epoch 119/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mae: 0.0628 - mse: 0.0069
# Epoch 120/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059 - mae: 0.0561 - mse: 0.0059
# Epoch 121/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - mae: 0.0565 - mse: 0.0058
# Epoch 122/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0527 - mse: 0.0051
# Epoch 123/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0060 - mae: 0.0567 - mse: 0.0060
# Epoch 124/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mae: 0.0608 - mse: 0.0069
# Epoch 125/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0585 - mse: 0.0064
# Epoch 126/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mae: 0.0555 - mse: 0.0057
# Epoch 127/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0596 - mse: 0.0063
# Epoch 128/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0062 - mae: 0.0560 - mse: 0.0062
# Epoch 129/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0072 - mae: 0.0623 - mse: 0.0072
# Epoch 130/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056 - mae: 0.0553 - mse: 0.0056
# Epoch 131/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061 - mae: 0.0582 - mse: 0.0061
# Epoch 132/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061 - mae: 0.0583 - mse: 0.0061
# Epoch 133/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0571 - mse: 0.0063
# Epoch 134/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0540 - mse: 0.0051
# Epoch 135/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0068 - mae: 0.0604 - mse: 0.0068
# Epoch 136/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mae: 0.0557 - mse: 0.0057
# Epoch 137/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056 - mae: 0.0550 - mse: 0.0056
# Epoch 138/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - mae: 0.0570 - mse: 0.0062
# Epoch 139/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - mae: 0.0530 - mse: 0.0054
# Epoch 140/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0537 - mse: 0.0051
# Epoch 141/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0071 - mae: 0.0638 - mse: 0.0071
# Epoch 142/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059 - mae: 0.0559 - mse: 0.0059
# Epoch 143/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0065 - mae: 0.0567 - mse: 0.0065
# Epoch 144/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0068 - mae: 0.0605 - mse: 0.0068
# Epoch 145/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mae: 0.0557 - mse: 0.0057
# Epoch 146/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mae: 0.0560 - mse: 0.0057
# Epoch 147/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0060 - mae: 0.0573 - mse: 0.0060
# Epoch 148/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mae: 0.0553 - mse: 0.0053
# Epoch 149/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mae: 0.0530 - mse: 0.0050
# Epoch 150/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - mae: 0.0606 - mse: 0.0070
# Epoch 151/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - mae: 0.0603 - mse: 0.0067
# Epoch 152/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mae: 0.0523 - mse: 0.0052
# Epoch 153/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0061 - mae: 0.0583 - mse: 0.0061
# Epoch 154/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0058 - mae: 0.0564 - mse: 0.0058
# Epoch 155/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mae: 0.0516 - mse: 0.0048
# Epoch 156/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0063 - mae: 0.0576 - mse: 0.0063
# Epoch 157/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0064 - mae: 0.0594 - mse: 0.0064
# Epoch 158/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - mae: 0.0552 - mse: 0.0055
# Epoch 159/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - mae: 0.0575 - mse: 0.0060
# Epoch 160/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0063 - mae: 0.0555 - mse: 0.0063
# Epoch 161/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mae: 0.0538 - mse: 0.0052
# Epoch 162/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0058 - mae: 0.0568 - mse: 0.0058
# Epoch 163/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0058 - mae: 0.0562 - mse: 0.0058
# Epoch 164/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - mae: 0.0552 - mse: 0.0058
# Epoch 165/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0062 - mae: 0.0566 - mse: 0.0062
# Epoch 166/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mae: 0.0517 - mse: 0.0049
# Epoch 167/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055 - mae: 0.0537 - mse: 0.0055
# Epoch 168/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - mae: 0.0543 - mse: 0.0055
# Epoch 169/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mae: 0.0549 - mse: 0.0053
# Epoch 170/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mae: 0.0525 - mse: 0.0052
# Epoch 171/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - mae: 0.0548 - mse: 0.0056
# Epoch 172/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - mae: 0.0536 - mse: 0.0055
# Epoch 173/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - mae: 0.0544 - mse: 0.0053
# Epoch 174/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0060 - mae: 0.0581 - mse: 0.0060
# Epoch 175/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mae: 0.0531 - mse: 0.0052
# Epoch 176/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056 - mae: 0.0574 - mse: 0.0056
# Epoch 177/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0520 - mse: 0.0050
# Epoch 178/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - mae: 0.0536 - mse: 0.0054
# Epoch 179/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - mae: 0.0543 - mse: 0.0058
# Epoch 180/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mae: 0.0521 - mse: 0.0052
# Epoch 181/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - mae: 0.0544 - mse: 0.0054
# Epoch 182/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - mae: 0.0582 - mse: 0.0060
# Epoch 183/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mae: 0.0539 - mse: 0.0052
# Epoch 184/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056 - mae: 0.0570 - mse: 0.0056
# Epoch 185/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056 - mae: 0.0551 - mse: 0.0056
# Epoch 186/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - mae: 0.0536 - mse: 0.0051
# Epoch 187/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mae: 0.0526 - mse: 0.0052
# Epoch 188/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - mae: 0.0545 - mse: 0.0055
# Epoch 189/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - mae: 0.0549 - mse: 0.0054
# Epoch 190/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mae: 0.0561 - mse: 0.0057
# Epoch 191/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0061 - mae: 0.0578 - mse: 0.0061
# Epoch 192/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0527 - mse: 0.0050
# Epoch 193/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0533 - mse: 0.0051
# Epoch 194/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0055 - mae: 0.0567 - mse: 0.0055
# Epoch 195/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0532 - mse: 0.0050
# Epoch 196/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mae: 0.0538 - mse: 0.0052
# Epoch 197/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0530 - mse: 0.0049
# Epoch 198/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059 - mae: 0.0565 - mse: 0.0059
# Epoch 199/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0538 - mse: 0.0051
# Epoch 200/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - mae: 0.0530 - mse: 0.0053
# Epoch 201/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - mae: 0.0530 - mse: 0.0053
# Epoch 202/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0055 - mae: 0.0552 - mse: 0.0055
# Epoch 203/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0513 - mse: 0.0050
# Epoch 204/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0522 - mse: 0.0050
# Epoch 205/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0059 - mae: 0.0567 - mse: 0.0059
# Epoch 206/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - mae: 0.0533 - mse: 0.0053
# Epoch 207/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mae: 0.0512 - mse: 0.0049
# Epoch 208/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - mae: 0.0531 - mse: 0.0054
# Epoch 209/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - mae: 0.0534 - mse: 0.0054
# Epoch 210/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0531 - mse: 0.0051
# Epoch 211/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0517 - mse: 0.0050
# Epoch 212/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0487 - mse: 0.0043
# Epoch 213/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mae: 0.0526 - mse: 0.0052
# Epoch 214/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0517 - mse: 0.0051
# Epoch 215/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0049 - mae: 0.0509 - mse: 0.0049
# Epoch 216/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - mae: 0.0586 - mse: 0.0060
# Epoch 217/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0527 - mse: 0.0051
# Epoch 218/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mae: 0.0522 - mse: 0.0048
# Epoch 219/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - mae: 0.0539 - mse: 0.0056
# Epoch 220/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mae: 0.0494 - mse: 0.0046
# Epoch 221/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0056 - mae: 0.0574 - mse: 0.0056
# Epoch 222/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0491 - mse: 0.0044
# Epoch 223/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mae: 0.0539 - mse: 0.0053
# Epoch 224/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mae: 0.0508 - mse: 0.0047
# Epoch 225/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - mae: 0.0552 - mse: 0.0054
# Epoch 226/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - mae: 0.0538 - mse: 0.0054
# Epoch 227/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0482 - mse: 0.0044
# Epoch 228/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0537 - mse: 0.0050
# Epoch 229/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0053 - mae: 0.0530 - mse: 0.0053
# Epoch 230/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0501 - mse: 0.0043
# Epoch 231/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0533 - mse: 0.0051
# Epoch 232/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0466 - mse: 0.0040
# Epoch 233/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - mae: 0.0488 - mse: 0.0046
# Epoch 234/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mae: 0.0535 - mse: 0.0052
# Epoch 235/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0055 - mae: 0.0552 - mse: 0.0055
# Epoch 236/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0055 - mae: 0.0548 - mse: 0.0055
# Epoch 237/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mae: 0.0517 - mse: 0.0052
# Epoch 238/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mae: 0.0545 - mse: 0.0052
# Epoch 239/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0056 - mae: 0.0555 - mse: 0.0056
# Epoch 240/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mae: 0.0511 - mse: 0.0046
# Epoch 241/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mae: 0.0515 - mse: 0.0047
# Epoch 242/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0058 - mae: 0.0591 - mse: 0.0058
# Epoch 243/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0484 - mse: 0.0044
# Epoch 244/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mae: 0.0526 - mse: 0.0048
# Epoch 245/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mae: 0.0530 - mse: 0.0052
# Epoch 246/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mae: 0.0515 - mse: 0.0045
# Epoch 247/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mae: 0.0497 - mse: 0.0047
# Epoch 248/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mae: 0.0529 - mse: 0.0053
# Epoch 249/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mae: 0.0512 - mse: 0.0048
# Epoch 250/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mae: 0.0561 - mse: 0.0057
# Epoch 251/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mae: 0.0510 - mse: 0.0047
# Epoch 252/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - mae: 0.0528 - mse: 0.0051
# Epoch 253/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0521 - mse: 0.0049
# Epoch 254/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mae: 0.0496 - mse: 0.0046
# Epoch 255/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mae: 0.0502 - mse: 0.0045
# Epoch 256/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mae: 0.0523 - mse: 0.0048
# Epoch 257/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mae: 0.0486 - mse: 0.0045
# Epoch 258/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0481 - mse: 0.0043
# Epoch 259/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0507 - mse: 0.0049
# Epoch 260/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - mae: 0.0478 - mse: 0.0040
# Epoch 261/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mae: 0.0513 - mse: 0.0048
# Epoch 262/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mae: 0.0532 - mse: 0.0052
# Epoch 263/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mae: 0.0514 - mse: 0.0049
# Epoch 264/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0054 - mae: 0.0549 - mse: 0.0054
# Epoch 265/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0518 - mse: 0.0046
# Epoch 266/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mae: 0.0530 - mse: 0.0047
# Epoch 267/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mae: 0.0492 - mse: 0.0047
# Epoch 268/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0478 - mse: 0.0044
# Epoch 269/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mae: 0.0499 - mse: 0.0047
# Epoch 270/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mae: 0.0534 - mse: 0.0050
# Epoch 271/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0457 - mse: 0.0040
# Epoch 272/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0532 - mse: 0.0050
# Epoch 273/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - mae: 0.0565 - mse: 0.0054
# Epoch 274/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mae: 0.0551 - mse: 0.0057
# Epoch 275/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mae: 0.0504 - mse: 0.0049
# Epoch 276/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0536 - mse: 0.0051
# Epoch 277/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0536 - mse: 0.0051
# Epoch 278/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mae: 0.0505 - mse: 0.0049
# Epoch 279/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mae: 0.0546 - mse: 0.0052
# Epoch 280/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mae: 0.0522 - mse: 0.0046
# Epoch 281/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0533 - mse: 0.0051
# Epoch 282/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0046 - mae: 0.0490 - mse: 0.0046
# Epoch 283/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mae: 0.0471 - mse: 0.0041
# Epoch 284/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mae: 0.0505 - mse: 0.0046
# Epoch 285/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mae: 0.0512 - mse: 0.0045
# Epoch 286/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0523 - mse: 0.0050
# Epoch 287/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - mae: 0.0463 - mse: 0.0040
# Epoch 288/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mae: 0.0470 - mse: 0.0041
# Epoch 289/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mae: 0.0535 - mse: 0.0052
# Epoch 290/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0534 - mse: 0.0050
# Epoch 291/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mae: 0.0522 - mse: 0.0049
# Epoch 292/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mae: 0.0525 - mse: 0.0049
# Epoch 293/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mae: 0.0506 - mse: 0.0050
# Epoch 294/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051 - mae: 0.0535 - mse: 0.0051
# Epoch 295/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0474 - mse: 0.0043
# Epoch 296/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mae: 0.0549 - mse: 0.0057
# Epoch 297/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mae: 0.0511 - mse: 0.0047
# Epoch 298/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - mae: 0.0526 - mse: 0.0051
# Epoch 299/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049 - mae: 0.0541 - mse: 0.0049
# Epoch 300/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mae: 0.0520 - mse: 0.0050
# Epoch 301/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0501 - mse: 0.0044
# Epoch 302/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mae: 0.0482 - mse: 0.0041
# Epoch 303/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0467 - mse: 0.0040
# Epoch 304/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0481 - mse: 0.0044
# Epoch 305/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mae: 0.0543 - mse: 0.0053
# Epoch 306/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mae: 0.0481 - mse: 0.0041
# Epoch 307/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mae: 0.0511 - mse: 0.0048
# Epoch 308/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mae: 0.0427 - mse: 0.0033
# Epoch 309/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mae: 0.0483 - mse: 0.0042
# Epoch 310/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050 - mae: 0.0496 - mse: 0.0050
# Epoch 311/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0530 - mse: 0.0049
# Epoch 312/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0500 - mse: 0.0044
# Epoch 313/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mae: 0.0517 - mse: 0.0048
# Epoch 314/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0480 - mse: 0.0042
# Epoch 315/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0458 - mse: 0.0038
# Epoch 316/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0468 - mse: 0.0042
# Epoch 317/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - mae: 0.0566 - mse: 0.0057
# Epoch 318/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mae: 0.0518 - mse: 0.0050
# Epoch 319/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mae: 0.0510 - mse: 0.0047
# Epoch 320/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0053 - mae: 0.0544 - mse: 0.0053
# Epoch 321/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0492 - mse: 0.0043
# Epoch 322/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0059 - mae: 0.0567 - mse: 0.0059
# Epoch 323/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0487 - mse: 0.0042
# Epoch 324/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041 - mae: 0.0466 - mse: 0.0041
# Epoch 325/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mae: 0.0524 - mse: 0.0052
# Epoch 326/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0496 - mse: 0.0044
# Epoch 327/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0507 - mse: 0.0046
# Epoch 328/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0461 - mse: 0.0036
# Epoch 329/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mae: 0.0496 - mse: 0.0048
# Epoch 330/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0513 - mse: 0.0049
# Epoch 331/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0453 - mse: 0.0038
# Epoch 332/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0497 - mse: 0.0043
# Epoch 333/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043 - mae: 0.0492 - mse: 0.0043
# Epoch 334/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mae: 0.0513 - mse: 0.0047
# Epoch 335/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0503 - mse: 0.0049
# Epoch 336/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0474 - mse: 0.0042
# Epoch 337/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0460 - mse: 0.0039
# Epoch 338/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0495 - mse: 0.0046
# Epoch 339/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mae: 0.0506 - mse: 0.0047
# Epoch 340/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0517 - mse: 0.0049
# Epoch 341/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0499 - mse: 0.0044
# Epoch 342/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0484 - mse: 0.0043
# Epoch 343/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mae: 0.0501 - mse: 0.0045
# Epoch 344/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mae: 0.0475 - mse: 0.0045
# Epoch 345/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0477 - mse: 0.0040
# Epoch 346/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0483 - mse: 0.0042
# Epoch 347/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0488 - mse: 0.0042
# Epoch 348/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0041 - mae: 0.0471 - mse: 0.0041
# Epoch 349/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - mae: 0.0548 - mse: 0.0054
# Epoch 350/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0476 - mse: 0.0039
# Epoch 351/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0466 - mse: 0.0042
# Epoch 352/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0473 - mse: 0.0040
# Epoch 353/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0522 - mse: 0.0046
# Epoch 354/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0465 - mse: 0.0039
# Epoch 355/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mae: 0.0501 - mse: 0.0045
# Epoch 356/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mae: 0.0498 - mse: 0.0047
# Epoch 357/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048 - mae: 0.0528 - mse: 0.0048
# Epoch 358/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0479 - mse: 0.0042
# Epoch 359/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mae: 0.0536 - mse: 0.0052
# Epoch 360/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0452 - mse: 0.0038
# Epoch 361/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0473 - mse: 0.0043
# Epoch 362/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mae: 0.0517 - mse: 0.0050
# Epoch 363/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mae: 0.0470 - mse: 0.0042
# Epoch 364/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mae: 0.0506 - mse: 0.0050
# Epoch 365/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0042 - mae: 0.0480 - mse: 0.0042
# Epoch 366/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - mae: 0.0464 - mse: 0.0041
# Epoch 367/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mae: 0.0455 - mse: 0.0041
# Epoch 368/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mae: 0.0505 - mse: 0.0047
# Epoch 369/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0499 - mse: 0.0046
# Epoch 370/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0484 - mse: 0.0043
# Epoch 371/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - mae: 0.0478 - mse: 0.0040
# Epoch 372/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mae: 0.0497 - mse: 0.0045
# Epoch 373/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0454 - mse: 0.0037
# Epoch 374/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0455 - mse: 0.0035
# Epoch 375/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mae: 0.0494 - mse: 0.0045
# Epoch 376/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - mae: 0.0459 - mse: 0.0040
# Epoch 377/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0458 - mse: 0.0038
# Epoch 378/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mae: 0.0517 - mse: 0.0047
# Epoch 379/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - mae: 0.0450 - mse: 0.0039
# Epoch 380/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0475 - mse: 0.0041
# Epoch 381/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0490 - mse: 0.0044
# Epoch 382/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0505 - mse: 0.0044
# Epoch 383/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0479 - mse: 0.0043
# Epoch 384/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0489 - mse: 0.0044
# Epoch 385/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0437 - mse: 0.0035
# Epoch 386/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0463 - mse: 0.0040
# Epoch 387/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mae: 0.0468 - mse: 0.0041
# Epoch 388/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0479 - mse: 0.0043
# Epoch 389/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - mae: 0.0442 - mse: 0.0036
# Epoch 390/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0469 - mse: 0.0039
# Epoch 391/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mae: 0.0476 - mse: 0.0045
# Epoch 392/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - mae: 0.0452 - mse: 0.0036
# Epoch 393/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - mae: 0.0461 - mse: 0.0039
# Epoch 394/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - mae: 0.0475 - mse: 0.0040
# Epoch 395/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0049 - mae: 0.0523 - mse: 0.0049
# Epoch 396/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0461 - mse: 0.0040
# Epoch 397/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0036 - mae: 0.0439 - mse: 0.0036
# Epoch 398/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0480 - mse: 0.0044
# Epoch 399/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0472 - mse: 0.0042
# Epoch 400/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0486 - mse: 0.0041
# Epoch 401/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mae: 0.0497 - mse: 0.0045
# Epoch 402/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0423 - mse: 0.0033
# Epoch 403/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0462 - mse: 0.0039
# Epoch 404/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0475 - mse: 0.0040
# Epoch 405/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0443 - mse: 0.0039
# Epoch 406/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0485 - mse: 0.0044
# Epoch 407/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mae: 0.0448 - mse: 0.0037
# Epoch 408/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0453 - mse: 0.0039
# Epoch 409/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - mae: 0.0476 - mse: 0.0040
# Epoch 410/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0469 - mse: 0.0039
# Epoch 411/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0514 - mse: 0.0044
# Epoch 412/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0486 - mse: 0.0041
# Epoch 413/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0459 - mse: 0.0040
# Epoch 414/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0463 - mse: 0.0041
# Epoch 415/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mae: 0.0526 - mse: 0.0050
# Epoch 416/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0456 - mse: 0.0039
# Epoch 417/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0504 - mse: 0.0044
# Epoch 418/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044 - mae: 0.0499 - mse: 0.0044
# Epoch 419/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0494 - mse: 0.0044
# Epoch 420/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - mae: 0.0455 - mse: 0.0040
# Epoch 421/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0471 - mse: 0.0044
# Epoch 422/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0480 - mse: 0.0043
# Epoch 423/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0469 - mse: 0.0039
# Epoch 424/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mae: 0.0428 - mse: 0.0033
# Epoch 425/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0491 - mse: 0.0044
# Epoch 426/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - mae: 0.0464 - mse: 0.0039
# Epoch 427/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0465 - mse: 0.0040
# Epoch 428/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0478 - mse: 0.0044
# Epoch 429/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0468 - mse: 0.0043
# Epoch 430/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0470 - mse: 0.0043
# Epoch 431/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033 - mae: 0.0435 - mse: 0.0033
# Epoch 432/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041 - mae: 0.0466 - mse: 0.0041
# Epoch 433/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047 - mae: 0.0502 - mse: 0.0047
# Epoch 434/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0469 - mse: 0.0043
# Epoch 435/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - mae: 0.0535 - mse: 0.0050
# Epoch 436/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mae: 0.0464 - mse: 0.0037
# Epoch 437/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mae: 0.0466 - mse: 0.0041
# Epoch 438/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - mae: 0.0524 - mse: 0.0052
# Epoch 439/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - mae: 0.0548 - mse: 0.0052
# Epoch 440/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0446 - mse: 0.0038
# Epoch 441/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - mae: 0.0467 - mse: 0.0038
# Epoch 442/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mae: 0.0504 - mse: 0.0048
# Epoch 443/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0503 - mse: 0.0043
# Epoch 444/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mae: 0.0458 - mse: 0.0042
# Epoch 445/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0464 - mse: 0.0043
# Epoch 446/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0480 - mse: 0.0044
# Epoch 447/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - mae: 0.0492 - mse: 0.0046
# Epoch 448/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mae: 0.0433 - mse: 0.0034
# Epoch 449/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0481 - mse: 0.0044
# Epoch 450/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mae: 0.0460 - mse: 0.0041
# Epoch 451/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0041 - mae: 0.0475 - mse: 0.0041
# Epoch 452/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mae: 0.0473 - mse: 0.0042
# Epoch 453/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0427 - mse: 0.0034
# Epoch 454/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - mae: 0.0481 - mse: 0.0041
# Epoch 455/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048 - mae: 0.0487 - mse: 0.0048
# Epoch 456/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0449 - mse: 0.0037
# Epoch 457/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0447 - mse: 0.0035
# Epoch 458/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mae: 0.0492 - mse: 0.0043
# Epoch 459/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mae: 0.0436 - mse: 0.0035
# Epoch 460/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041 - mae: 0.0474 - mse: 0.0041
# Epoch 461/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0473 - mse: 0.0040
# Epoch 462/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0437 - mse: 0.0037
# Epoch 463/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - mae: 0.0500 - mse: 0.0045
# Epoch 464/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0450 - mse: 0.0039
# Epoch 465/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0447 - mse: 0.0037
# Epoch 466/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mae: 0.0460 - mse: 0.0037
# Epoch 467/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mae: 0.0437 - mse: 0.0037
# Epoch 468/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0424 - mse: 0.0033
# Epoch 469/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048 - mae: 0.0514 - mse: 0.0048
# Epoch 470/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0439 - mse: 0.0036
# Epoch 471/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mae: 0.0475 - mse: 0.0042
# Epoch 472/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0467 - mse: 0.0043
# Epoch 473/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0474 - mse: 0.0042
# Epoch 474/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0040 - mae: 0.0480 - mse: 0.0040
# Epoch 475/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0042 - mae: 0.0471 - mse: 0.0042
# Epoch 476/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040 - mae: 0.0459 - mse: 0.0040
# Epoch 477/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0454 - mse: 0.0038
# Epoch 478/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0429 - mse: 0.0035
# Epoch 479/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - mae: 0.0439 - mse: 0.0036
# Epoch 480/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0453 - mse: 0.0039
# Epoch 481/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0427 - mse: 0.0034
# Epoch 482/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0434 - mse: 0.0034
# Epoch 483/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0460 - mse: 0.0039
# Epoch 484/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0462 - mse: 0.0040
# Epoch 485/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0423 - mse: 0.0034
# Epoch 486/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0466 - mse: 0.0040
# Epoch 487/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - mae: 0.0478 - mse: 0.0042
# Epoch 488/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mae: 0.0503 - mse: 0.0045
# Epoch 489/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0448 - mse: 0.0037
# Epoch 490/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - mae: 0.0455 - mse: 0.0043
# Epoch 491/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - mae: 0.0439 - mse: 0.0035
# Epoch 492/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - mae: 0.0483 - mse: 0.0045
# Epoch 493/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0432 - mse: 0.0033
# Epoch 494/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044 - mae: 0.0457 - mse: 0.0044
# Epoch 495/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0449 - mse: 0.0038
# Epoch 496/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0443 - mse: 0.0036
# Epoch 497/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0414 - mse: 0.0031
# Epoch 498/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0447 - mse: 0.0037
# Epoch 499/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0409 - mse: 0.0031
# Epoch 500/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0450 - mse: 0.0038
# Epoch 501/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0441 - mse: 0.0035
# Epoch 502/1000
# ...
# Epoch 841/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0421 - mse: 0.0032
# Epoch 842/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0454 - mse: 0.0039
# Epoch 843/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0405 - mse: 0.0028
# Epoch 844/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0399 - mse: 0.0028
# Epoch 845/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mae: 0.0419 - mse: 0.0037
# Epoch 846/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0372 - mse: 0.0027
# Epoch 847/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0414 - mse: 0.0032
# Epoch 848/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mae: 0.0389 - mse: 0.0029
# Epoch 849/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032 - mae: 0.0414 - mse: 0.0032
# Epoch 850/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mae: 0.0431 - mse: 0.0035
# Epoch 851/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0394 - mse: 0.0029
# Epoch 852/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0415 - mse: 0.0032
# Epoch 853/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0408 - mse: 0.0031
# Epoch 854/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0404 - mse: 0.0032
# Epoch 855/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0419 - mse: 0.0030
# Epoch 856/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0392 - mse: 0.0029
# Epoch 857/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0398 - mse: 0.0032
# Epoch 858/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0381 - mse: 0.0027
# Epoch 859/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0411 - mse: 0.0031
# Epoch 860/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0431 - mse: 0.0033
# Epoch 861/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0472 - mse: 0.0044
# Epoch 862/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0425 - mse: 0.0033
# Epoch 863/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - mae: 0.0431 - mse: 0.0035
# Epoch 864/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0034 - mae: 0.0430 - mse: 0.0034
# Epoch 865/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - mae: 0.0421 - mse: 0.0032
# Epoch 866/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mae: 0.0385 - mse: 0.0027
# Epoch 867/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0403 - mse: 0.0029
# Epoch 868/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mae: 0.0404 - mse: 0.0031
# Epoch 869/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0391 - mse: 0.0027
# Epoch 870/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0446 - mse: 0.0036
# Epoch 871/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0405 - mse: 0.0029
# Epoch 872/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0365 - mse: 0.0025
# Epoch 873/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0422 - mse: 0.0035
# Epoch 874/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0401 - mse: 0.0031
# Epoch 875/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - mae: 0.0459 - mse: 0.0039
# Epoch 876/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0411 - mse: 0.0035
# Epoch 877/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0422 - mse: 0.0034
# Epoch 878/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0413 - mse: 0.0030
# Epoch 879/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0402 - mse: 0.0030
# Epoch 880/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0392 - mse: 0.0029
# Epoch 881/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - mae: 0.0419 - mse: 0.0036
# Epoch 882/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0393 - mse: 0.0028
# Epoch 883/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0415 - mse: 0.0032
# Epoch 884/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0391 - mse: 0.0035
# Epoch 885/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mae: 0.0426 - mse: 0.0035
# Epoch 886/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mae: 0.0383 - mse: 0.0028
# Epoch 887/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mae: 0.0371 - mse: 0.0025
# Epoch 888/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0025
# Epoch 889/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mae: 0.0376 - mse: 0.0026
# Epoch 890/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0398 - mse: 0.0032
# Epoch 891/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mae: 0.0370 - mse: 0.0026
# Epoch 892/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0372 - mse: 0.0028
# Epoch 893/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mae: 0.0418 - mse: 0.0034
# Epoch 894/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mae: 0.0377 - mse: 0.0025
# Epoch 895/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mae: 0.0376 - mse: 0.0025
# Epoch 896/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mae: 0.0398 - mse: 0.0029
# Epoch 897/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0397 - mse: 0.0030
# Epoch 898/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0380 - mse: 0.0027
# Epoch 899/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mae: 0.0372 - mse: 0.0024
# Epoch 900/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - mae: 0.0422 - mse: 0.0038
# Epoch 901/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0397 - mse: 0.0029
# Epoch 902/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0416 - mse: 0.0030
# Epoch 903/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mae: 0.0386 - mse: 0.0028
# Epoch 904/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mae: 0.0396 - mse: 0.0029
# Epoch 905/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mae: 0.0396 - mse: 0.0029
# Epoch 906/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mae: 0.0405 - mse: 0.0034
# Epoch 907/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0398 - mse: 0.0032
# Epoch 908/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0379 - mse: 0.0027
# Epoch 909/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0030 - mae: 0.0397 - mse: 0.0030
# Epoch 910/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0408 - mse: 0.0032
# Epoch 911/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mae: 0.0375 - mse: 0.0026
# Epoch 912/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0400 - mse: 0.0029
# Epoch 913/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - mae: 0.0428 - mse: 0.0036
# Epoch 914/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0440 - mse: 0.0035
# Epoch 915/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0459 - mse: 0.0040
# Epoch 916/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mae: 0.0388 - mse: 0.0028
# Epoch 917/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mae: 0.0396 - mse: 0.0031
# Epoch 918/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mae: 0.0383 - mse: 0.0026
# Epoch 919/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mae: 0.0373 - mse: 0.0026
# Epoch 920/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026 - mae: 0.0384 - mse: 0.0026
# Epoch 921/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mae: 0.0411 - mse: 0.0035
# Epoch 922/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mae: 0.0383 - mse: 0.0028
# Epoch 923/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0384 - mse: 0.0028
# Epoch 924/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0396 - mse: 0.0028
# Epoch 925/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0413 - mse: 0.0031
# Epoch 926/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mae: 0.0386 - mse: 0.0028
# Epoch 927/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0036 - mae: 0.0431 - mse: 0.0036
# Epoch 928/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mae: 0.0397 - mse: 0.0027
# Epoch 929/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0412 - mse: 0.0033
# Epoch 930/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0363 - mse: 0.0026
# Epoch 931/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0365 - mse: 0.0024
# Epoch 932/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0376 - mse: 0.0027
# Epoch 933/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mae: 0.0385 - mse: 0.0028
# Epoch 934/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0029 - mae: 0.0397 - mse: 0.0029
# Epoch 935/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038 - mae: 0.0429 - mse: 0.0038
# Epoch 936/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0378 - mse: 0.0027
# Epoch 937/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0360 - mse: 0.0026
# Epoch 938/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mae: 0.0408 - mse: 0.0031
# Epoch 939/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mae: 0.0368 - mse: 0.0025
# Epoch 940/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mae: 0.0384 - mse: 0.0025
# Epoch 941/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0390 - mse: 0.0029
# Epoch 942/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0411 - mse: 0.0035
# Epoch 943/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0434 - mse: 0.0034
# Epoch 944/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040 - mae: 0.0450 - mse: 0.0040
# Epoch 945/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0389 - mse: 0.0027
# Epoch 946/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0393 - mse: 0.0029
# Epoch 947/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0374 - mse: 0.0027
# Epoch 948/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mae: 0.0431 - mse: 0.0033
# Epoch 949/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - mae: 0.0448 - mse: 0.0039
# Epoch 950/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0418 - mse: 0.0035
# Epoch 951/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mae: 0.0417 - mse: 0.0031
# Epoch 952/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0406 - mse: 0.0035
# Epoch 953/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0044 - mae: 0.0448 - mse: 0.0044
# Epoch 954/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0417 - mse: 0.0032
# Epoch 955/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mae: 0.0382 - mse: 0.0026
# Epoch 956/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - mae: 0.0446 - mse: 0.0039
# Epoch 957/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0023 - mae: 0.0348 - mse: 0.0023
# Epoch 958/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0028 - mae: 0.0395 - mse: 0.0028
# Epoch 959/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0382 - mse: 0.0027
# Epoch 960/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0375 - mse: 0.0027
# Epoch 961/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0396 - mse: 0.0032
# Epoch 962/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mae: 0.0386 - mse: 0.0027
# Epoch 963/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - mae: 0.0407 - mse: 0.0029
# Epoch 964/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0397 - mse: 0.0031
# Epoch 965/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - mae: 0.0420 - mse: 0.0033
# Epoch 966/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027 - mae: 0.0390 - mse: 0.0027
# Epoch 967/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0410 - mse: 0.0032
# Epoch 968/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0037 - mae: 0.0425 - mse: 0.0037
# Epoch 969/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0399 - mse: 0.0032
# Epoch 970/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0412 - mse: 0.0030
# Epoch 971/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0418 - mse: 0.0032
# Epoch 972/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mae: 0.0432 - mse: 0.0035
# Epoch 973/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0034 - mae: 0.0442 - mse: 0.0034
# Epoch 974/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0030 - mae: 0.0415 - mse: 0.0030
# Epoch 975/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mae: 0.0407 - mse: 0.0029
# Epoch 976/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mae: 0.0385 - mse: 0.0028
# Epoch 977/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mae: 0.0349 - mse: 0.0023
# Epoch 978/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mae: 0.0402 - mse: 0.0032
# Epoch 979/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - mae: 0.0417 - mse: 0.0038
# Epoch 980/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - mae: 0.0396 - mse: 0.0027
# Epoch 981/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0422 - mse: 0.0035
# Epoch 982/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0035 - mae: 0.0431 - mse: 0.0035
# Epoch 983/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025 - mae: 0.0364 - mse: 0.0025
# Epoch 984/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - mae: 0.0426 - mse: 0.0035
# Epoch 985/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mae: 0.0366 - mse: 0.0025
# Epoch 986/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - mae: 0.0385 - mse: 0.0028
# Epoch 987/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0364 - mse: 0.0026
# Epoch 988/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mae: 0.0371 - mse: 0.0027
# Epoch 989/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mae: 0.0374 - mse: 0.0026
# Epoch 990/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0396 - mse: 0.0030
# Epoch 991/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - mae: 0.0378 - mse: 0.0026
# Epoch 992/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028 - mae: 0.0390 - mse: 0.0028
# Epoch 993/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0372 - mse: 0.0027
# Epoch 994/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0031 - mae: 0.0410 - mse: 0.0031
# Epoch 995/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mae: 0.0362 - mse: 0.0024
# Epoch 996/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mae: 0.0391 - mse: 0.0027
# Epoch 997/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mae: 0.0415 - mse: 0.0033
# Epoch 998/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025 - mae: 0.0371 - mse: 0.0025
# Epoch 999/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - mae: 0.0352 - mse: 0.0022
# Epoch 1000/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030 - mae: 0.0393 - mse: 0.0030
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# --- federated after local fine-tuning ---
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_96899/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Salvo 26 plot in: ../RISULTATI/2025-11-29/esperimento_METRO966_16-04-35/federated_fd/TEST
# Plot salvati correttamente.
# Test MAE: 2.1715
# Test RMSE: 3.3115
# Test MAPE: 4.60%
# Test R2: 0.9968
# Valore medio del test set: 134.9622
#
# Log salvato in: ../RISULTATI/2025-11-29/esperimento_METRO966_16-04-35/federated_fd_evaluation_log.json
