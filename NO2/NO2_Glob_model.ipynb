# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import pickle, os
from datetime import datetime
import numpy as np

# %%
# === Creazione cartella esperimento con timestamp ISO ===
timestamp = datetime.now().strftime("%H-%M-%S")
print(f"Ora inizio esperimento: {timestamp}")
day= datetime.now().strftime("%Y-%m-%d")
print(f"Giorno inizio esperimento: {day}")
exp_dir = f"../RISULTATI/{day}/esperimento_Global_Arpat_{timestamp}"

os.makedirs(exp_dir, exist_ok=True)

print(f"Cartella esperimento creata: {exp_dir}")
# Out:
# Ora inizio esperimento: 14-36-49
# Giorno inizio esperimento: 2025-11-30
# Cartella esperimento creata: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49

# %%
def save_pkl(obj, path):
    with open(path, "wb") as f:
        pickle.dump(obj, f)
    print(f"Salvato: {path}")

def load_pkl(path):
    with open(path, "rb") as f:
        return pickle.load(f)

# %%
import os
import numpy as np

def load_and_merge_tensors(file_list, path):
    """
    Carica i file .pkl da `path` + nome in file_list, concatena globalmente
    X_train, X_test, y_train, y_test e costruisce un dizionario:
      sensor_splits = { 'SENSORE': (X_test_concat_or_None, y_test_concat_or_None), ... }

    Richiede una funzione `load_pkl(full_path)` definita altrove che ritorna un np.ndarray.
    """
    X_train_list = []
    X_test_list = []
    y_train_list = []
    y_test_list = []

    # temporanei per i test per sensore
    sensors = {}  # sensor -> {"X_test": [...], "y_test": [...]}

    for f in file_list:
        full = os.path.join(path, f)
        arr = load_pkl(full)  # deve restituire np.ndarray

        # estrai nome sensore dopo "unscaled_"
        base = os.path.basename(f)
        sensor = None
        if "unscaled_" in base:
            sensor = base.split("unscaled_")[1].replace(".pkl", "")

        if base.startswith("X_train_unscaled"):
            X_train_list.append(arr)

        elif base.startswith("X_test_unscaled"):
            X_test_list.append(arr)
            if sensor is not None:
                sensors.setdefault(sensor, {"X_test": [], "y_test": []})["X_test"].append(arr)

        elif base.startswith("y_train_unscaled"):
            y_train_list.append(arr)

        elif base.startswith("y_test_unscaled"):
            y_test_list.append(arr)
            if sensor is not None:
                sensors.setdefault(sensor, {"X_test": [], "y_test": []})["y_test"].append(arr)

    # concatenazioni globali
    X_train = np.concatenate(X_train_list, axis=0) if X_train_list else None
    X_test = np.concatenate(X_test_list, axis=0) if X_test_list else None
    y_train = np.concatenate(y_train_list, axis=0) if y_train_list else None
    y_test = np.concatenate(y_test_list, axis=0) if y_test_list else None

    # costruisci dizionario richiesta: sensor -> (X_test, y_test)
    sensor_splits = {}
    for sensor, d in sensors.items():
        Xs = np.concatenate(d["X_test"], axis=0) if d.get("X_test") else None
        ys = np.concatenate(d["y_test"], axis=0) if d.get("y_test") else None
        sensor_splits[sensor] = (Xs, ys)

    return X_train, X_test, y_train, y_test, sensor_splits

# %%
path = '/Users/lapotinacci/thesis/Federated_Sys/train_test'
files = os.listdir(path)
files.sort()
files = [f for f in files if 'METRO' not in f.upper()]
print(files)
len(files)
# Out:
# ['X_test_unscaled_AR-ACROPOLI.pkl', 'X_test_unscaled_FI-GRAMSCI.pkl', 'X_test_unscaled_FI-SETTIGNANO.pkl', 'X_test_unscaled_GR-MAREMMA.pkl', 'X_test_unscaled_LI-LAPIRA.pkl', 'X_test_unscaled_LU-VIAREGGIO.pkl', 'X_test_unscaled_PO-ROMA.pkl', 'X_train_unscaled_AR-ACROPOLI.pkl', 'X_train_unscaled_FI-GRAMSCI.pkl', 'X_train_unscaled_FI-SETTIGNANO.pkl', 'X_train_unscaled_GR-MAREMMA.pkl', 'X_train_unscaled_LI-LAPIRA.pkl', 'X_train_unscaled_LU-VIAREGGIO.pkl', 'X_train_unscaled_PO-ROMA.pkl', 'y_test_unscaled_AR-ACROPOLI.pkl', 'y_test_unscaled_FI-GRAMSCI.pkl', 'y_test_unscaled_FI-SETTIGNANO.pkl', 'y_test_unscaled_GR-MAREMMA.pkl', 'y_test_unscaled_LI-LAPIRA.pkl', 'y_test_unscaled_LU-VIAREGGIO.pkl', 'y_test_unscaled_PO-ROMA.pkl', 'y_train_unscaled_AR-ACROPOLI.pkl', 'y_train_unscaled_FI-GRAMSCI.pkl', 'y_train_unscaled_FI-SETTIGNANO.pkl', 'y_train_unscaled_GR-MAREMMA.pkl', 'y_train_unscaled_LI-LAPIRA.pkl', 'y_train_unscaled_LU-VIAREGGIO.pkl', 'y_train_unscaled_PO-ROMA.pkl']
# 28

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Primo split: train (80%) vs temp (20%)
# Passo anche std_bins per poter stratificare
X_train, X_test, y_train, y_test, splits = load_and_merge_tensors(files, path)

print(f"Train size: {X_train.shape}, {y_train.shape}")
print(f"Test size: {X_test.shape}, {y_test.shape}")

# Debug prints
print(f"Final shapes:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, shuffle=True
)

# Scaler per input
scaler_X = StandardScaler()
X_train_n = scaler_X.fit_transform(X_train)
X_val   = scaler_X.transform(X_val)
X_test  = scaler_X.transform(X_test)

# Scaler per output (se serve normalizzare anche y)
scaler_y = StandardScaler()
y_train_n = scaler_y.fit_transform(y_train)
y_val   = scaler_y.transform(y_val)
y_test  = scaler_y.transform(y_test)

#  === Salvataggio dataset e scaler in formato .pkl ===
save_pkl(X_train_n, os.path.join(exp_dir, "X_train.pkl"))
save_pkl(y_train_n, os.path.join(exp_dir, "y_train.pkl"))
save_pkl(X_val, os.path.join(exp_dir, "X_val.pkl"))
save_pkl(y_val, os.path.join(exp_dir, "y_val.pkl"))
save_pkl(X_test, os.path.join(exp_dir, "X_test.pkl"))
save_pkl(y_test, os.path.join(exp_dir, "y_test.pkl"))

save_pkl(scaler_X, os.path.join(exp_dir, "scaler_X.pkl"))
save_pkl(scaler_y, os.path.join(exp_dir, "scaler_y.pkl"))

print("Scaler salvati.")

print("\nTutti i file sono stati salvati correttamente.")
print(f"Percorso cartella: {os.path.abspath(exp_dir)}")
# Out:
# Train size: (1795, 33), (1795, 24)
# Test size: (453, 33), (453, 24)
# Final shapes:
# X_train: (1795, 33)
# y_train: (1795, 24)
# Salvato: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/X_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/y_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/X_val.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/y_val.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/X_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/y_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/scaler_X.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/scaler_y.pkl
# Scaler salvati.
#
# Tutti i file sono stati salvati correttamente.
# Percorso cartella: /Users/lapotinacci/thesis/Federated_Sys/RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, losses, metrics # type: ignore
from tensorflow.keras.layers import Dropout # type: ignore
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
def save_prediction_plots(y_true, y_pred, output_dir, prefix="pred_plot"):
    os.makedirs(output_dir, exist_ok=True)

    n = len(y_true)
    print(f"Salvo {n} plot in: {output_dir}")

    for i in range(n):
        plt.figure(figsize=(8, 3))
        plt.plot(y_true[i], label="True")
        plt.plot(y_pred[i], label="Pred")
        plt.legend()
        plt.tight_layout()

        filename = f"{prefix}_{i+1}.png"
        path = os.path.join(output_dir, filename)

        plt.savefig(path)
        plt.close()

    print("Plot salvati correttamente.")

# %%
# Definizione modello DNN
def build_model(input_shape: tuple, output_shape: tuple):
    model = models.Sequential([
        layers.Dense(128, activation = "relu", input_shape=input_shape),
        Dropout(0.3),
        layers.Dense(output_shape, 'linear')
    ])
    model.compile(
    optimizer=optimizers.AdamW(learning_rate=0.016, weight_decay=0.0206),
    loss= 'mse',
    metrics=['mae'],
    )
    return model

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',      # metrica da monitorare, es. val_loss o val_mae
    patience=50,             # numero di epoche senza miglioramento prima di fermare
    restore_best_weights=True,  # ripristina i pesi migliori trovati
    verbose = 1
)

# Training del modello
model = build_model((X_test.shape[1],), y_test.shape[1])
history = model.fit(
    X_train_n, y_train_n,
    epochs=1000,
    batch_size=256,
    callbacks = [early_stop],
    validation_data=(X_val, y_val),
    verbose=1
    )
y_pred = model.predict(X_test)

'''print("y_train min/max:", y_train_np.min(), y_train_np.max())
print("y_pred min/max (scaled):", y_pred.min(), y_pred.max())
y_pred_rescaled = scaler_y.inverse_transform(y_pred)
print("y_pred_rescaled min/max:", y_pred_rescaled.min(), y_pred_rescaled.max())'''
# Out:
# Epoch 1/1000
# /Users/lapotinacci/thesis/Federated_Sys/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.6209 - mae: 0.5626 - val_loss: 0.1591 - val_mae: 0.2879
# Epoch 2/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2369 - mae: 0.3594 - val_loss: 0.1023 - val_mae: 0.2288
# Epoch 3/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1528 - mae: 0.2839 - val_loss: 0.0788 - val_mae: 0.1953
# Epoch 4/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1152 - mae: 0.2424 - val_loss: 0.0669 - val_mae: 0.1766
# Epoch 5/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0914 - mae: 0.2143 - val_loss: 0.0549 - val_mae: 0.1546
# Epoch 6/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0816 - mae: 0.1979 - val_loss: 0.0481 - val_mae: 0.1440
# Epoch 7/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0759 - mae: 0.1886 - val_loss: 0.0477 - val_mae: 0.1463
# Epoch 8/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0700 - mae: 0.1813 - val_loss: 0.0453 - val_mae: 0.1405
# Epoch 9/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0694 - mae: 0.1797 - val_loss: 0.0471 - val_mae: 0.1421
# Epoch 10/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0682 - mae: 0.1777 - val_loss: 0.0439 - val_mae: 0.1351
# Epoch 11/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0672 - mae: 0.1762 - val_loss: 0.0441 - val_mae: 0.1364
# Epoch 12/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0654 - mae: 0.1723 - val_loss: 0.0404 - val_mae: 0.1311
# Epoch 13/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0606 - mae: 0.1672 - val_loss: 0.0431 - val_mae: 0.1353
# Epoch 14/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0562 - mae: 0.1620 - val_loss: 0.0413 - val_mae: 0.1368
# Epoch 15/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0570 - mae: 0.1635 - val_loss: 0.0401 - val_mae: 0.1296
# Epoch 16/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0578 - mae: 0.1617 - val_loss: 0.0438 - val_mae: 0.1349
# Epoch 17/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0577 - mae: 0.1619 - val_loss: 0.0377 - val_mae: 0.1244
# Epoch 18/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0553 - mae: 0.1599 - val_loss: 0.0380 - val_mae: 0.1240
# Epoch 19/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0569 - mae: 0.1596 - val_loss: 0.0423 - val_mae: 0.1298
# Epoch 20/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0545 - mae: 0.1579 - val_loss: 0.0410 - val_mae: 0.1318
# Epoch 21/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0573 - mae: 0.1615 - val_loss: 0.0391 - val_mae: 0.1313
# Epoch 22/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0517 - mae: 0.1560 - val_loss: 0.0390 - val_mae: 0.1259
# Epoch 23/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0519 - mae: 0.1543 - val_loss: 0.0356 - val_mae: 0.1219
# Epoch 24/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0530 - mae: 0.1561 - val_loss: 0.0346 - val_mae: 0.1196
# Epoch 25/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0521 - mae: 0.1550 - val_loss: 0.0382 - val_mae: 0.1244
# Epoch 26/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0566 - mae: 0.1583 - val_loss: 0.0354 - val_mae: 0.1196
# Epoch 27/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0542 - mae: 0.1574 - val_loss: 0.0354 - val_mae: 0.1230
# Epoch 28/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0511 - mae: 0.1553 - val_loss: 0.0381 - val_mae: 0.1237
# Epoch 29/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0520 - mae: 0.1545 - val_loss: 0.0364 - val_mae: 0.1229
# Epoch 30/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0504 - mae: 0.1518 - val_loss: 0.0335 - val_mae: 0.1172
# Epoch 31/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0479 - mae: 0.1485 - val_loss: 0.0333 - val_mae: 0.1165
# Epoch 32/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0464 - mae: 0.1488 - val_loss: 0.0330 - val_mae: 0.1171
# Epoch 33/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0486 - mae: 0.1495 - val_loss: 0.0348 - val_mae: 0.1227
# Epoch 34/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0511 - mae: 0.1536 - val_loss: 0.0361 - val_mae: 0.1271
# Epoch 35/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0507 - mae: 0.1516 - val_loss: 0.0354 - val_mae: 0.1181
# Epoch 36/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0544 - mae: 0.1532 - val_loss: 0.0348 - val_mae: 0.1219
# Epoch 37/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - mae: 0.1488 - val_loss: 0.0337 - val_mae: 0.1170
# Epoch 38/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0502 - mae: 0.1513 - val_loss: 0.0324 - val_mae: 0.1165
# Epoch 39/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0493 - mae: 0.1497 - val_loss: 0.0317 - val_mae: 0.1127
# Epoch 40/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0480 - mae: 0.1474 - val_loss: 0.0322 - val_mae: 0.1140
# Epoch 41/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0491 - mae: 0.1492 - val_loss: 0.0326 - val_mae: 0.1157
# Epoch 42/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0467 - mae: 0.1469 - val_loss: 0.0342 - val_mae: 0.1189
# Epoch 43/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0477 - mae: 0.1495 - val_loss: 0.0316 - val_mae: 0.1140
# Epoch 44/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0454 - mae: 0.1452 - val_loss: 0.0356 - val_mae: 0.1272
# Epoch 45/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0462 - mae: 0.1475 - val_loss: 0.0356 - val_mae: 0.1270
# Epoch 46/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0457 - mae: 0.1446 - val_loss: 0.0329 - val_mae: 0.1160
# Epoch 47/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0448 - mae: 0.1462 - val_loss: 0.0311 - val_mae: 0.1153
# Epoch 48/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0444 - mae: 0.1450 - val_loss: 0.0304 - val_mae: 0.1124
# Epoch 49/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mae: 0.1493 - val_loss: 0.0353 - val_mae: 0.1203
# Epoch 50/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0472 - mae: 0.1465 - val_loss: 0.0343 - val_mae: 0.1219
# Epoch 51/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0477 - mae: 0.1468 - val_loss: 0.0327 - val_mae: 0.1152
# Epoch 52/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0447 - mae: 0.1431 - val_loss: 0.0373 - val_mae: 0.1246
# Epoch 53/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0448 - mae: 0.1440 - val_loss: 0.0362 - val_mae: 0.1243
# Epoch 54/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0435 - mae: 0.1428 - val_loss: 0.0308 - val_mae: 0.1143
# Epoch 55/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0441 - mae: 0.1417 - val_loss: 0.0306 - val_mae: 0.1146
# Epoch 56/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0437 - mae: 0.1421 - val_loss: 0.0425 - val_mae: 0.1330
# Epoch 57/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0468 - mae: 0.1457 - val_loss: 0.0384 - val_mae: 0.1253
# Epoch 58/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0471 - mae: 0.1461 - val_loss: 0.0352 - val_mae: 0.1239
# Epoch 59/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0484 - mae: 0.1492 - val_loss: 0.0406 - val_mae: 0.1313
# Epoch 60/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0519 - mae: 0.1516 - val_loss: 0.0557 - val_mae: 0.1491
# Epoch 61/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0532 - mae: 0.1526 - val_loss: 0.0491 - val_mae: 0.1381
# Epoch 62/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0501 - mae: 0.1506 - val_loss: 0.0390 - val_mae: 0.1266
# Epoch 63/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0450 - mae: 0.1420 - val_loss: 0.0358 - val_mae: 0.1216
# Epoch 64/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0444 - mae: 0.1434 - val_loss: 0.0281 - val_mae: 0.1086
# Epoch 65/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0437 - mae: 0.1431 - val_loss: 0.0289 - val_mae: 0.1109
# Epoch 66/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0474 - mae: 0.1444 - val_loss: 0.0309 - val_mae: 0.1146
# Epoch 67/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0444 - mae: 0.1418 - val_loss: 0.0369 - val_mae: 0.1262
# Epoch 68/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0462 - mae: 0.1456 - val_loss: 0.0338 - val_mae: 0.1258
# Epoch 69/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0460 - mae: 0.1451 - val_loss: 0.0283 - val_mae: 0.1103
# Epoch 70/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0446 - mae: 0.1430 - val_loss: 0.0272 - val_mae: 0.1054
# Epoch 71/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0435 - mae: 0.1418 - val_loss: 0.0272 - val_mae: 0.1055
# Epoch 72/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0462 - mae: 0.1443 - val_loss: 0.0279 - val_mae: 0.1068
# Epoch 73/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0445 - mae: 0.1408 - val_loss: 0.0273 - val_mae: 0.1055
# Epoch 74/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0461 - mae: 0.1432 - val_loss: 0.0289 - val_mae: 0.1095
# Epoch 75/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0463 - mae: 0.1436 - val_loss: 0.0312 - val_mae: 0.1128
# Epoch 76/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0450 - mae: 0.1426 - val_loss: 0.0299 - val_mae: 0.1149
# Epoch 77/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0441 - mae: 0.1418 - val_loss: 0.0282 - val_mae: 0.1086
# Epoch 78/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0438 - mae: 0.1415 - val_loss: 0.0294 - val_mae: 0.1149
# Epoch 79/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0422 - mae: 0.1395 - val_loss: 0.0290 - val_mae: 0.1155
# Epoch 80/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0456 - mae: 0.1461 - val_loss: 0.0325 - val_mae: 0.1267
# Epoch 81/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0447 - mae: 0.1437 - val_loss: 0.0305 - val_mae: 0.1185
# Epoch 82/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0439 - mae: 0.1425 - val_loss: 0.0275 - val_mae: 0.1128
# Epoch 83/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0448 - mae: 0.1432 - val_loss: 0.0355 - val_mae: 0.1266
# Epoch 84/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0465 - mae: 0.1455 - val_loss: 0.0302 - val_mae: 0.1166
# Epoch 85/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0448 - mae: 0.1431 - val_loss: 0.0287 - val_mae: 0.1149
# Epoch 86/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0486 - mae: 0.1488 - val_loss: 0.0303 - val_mae: 0.1168
# Epoch 87/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0436 - mae: 0.1407 - val_loss: 0.0266 - val_mae: 0.1073
# Epoch 88/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0450 - mae: 0.1437 - val_loss: 0.0272 - val_mae: 0.1097
# Epoch 89/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0440 - mae: 0.1441 - val_loss: 0.0284 - val_mae: 0.1099
# Epoch 90/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0399 - mae: 0.1381 - val_loss: 0.0313 - val_mae: 0.1178
# Epoch 91/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0450 - mae: 0.1439 - val_loss: 0.0288 - val_mae: 0.1142
# Epoch 92/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0429 - mae: 0.1395 - val_loss: 0.0288 - val_mae: 0.1135
# Epoch 93/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0413 - mae: 0.1388 - val_loss: 0.0300 - val_mae: 0.1182
# Epoch 94/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0433 - mae: 0.1411 - val_loss: 0.0264 - val_mae: 0.1124
# Epoch 95/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0431 - mae: 0.1408 - val_loss: 0.0285 - val_mae: 0.1154
# Epoch 96/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0423 - mae: 0.1400 - val_loss: 0.0257 - val_mae: 0.1071
# Epoch 97/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0400 - mae: 0.1359 - val_loss: 0.0262 - val_mae: 0.1056
# Epoch 98/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0408 - mae: 0.1356 - val_loss: 0.0277 - val_mae: 0.1066
# Epoch 99/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0395 - mae: 0.1341 - val_loss: 0.0281 - val_mae: 0.1115
# Epoch 100/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0416 - mae: 0.1380 - val_loss: 0.0295 - val_mae: 0.1169
# Epoch 101/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0434 - mae: 0.1405 - val_loss: 0.0291 - val_mae: 0.1137
# Epoch 102/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0430 - mae: 0.1407 - val_loss: 0.0261 - val_mae: 0.1071
# Epoch 103/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0422 - mae: 0.1392 - val_loss: 0.0288 - val_mae: 0.1102
# Epoch 104/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0427 - mae: 0.1389 - val_loss: 0.0264 - val_mae: 0.1065
# Epoch 105/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0418 - mae: 0.1385 - val_loss: 0.0311 - val_mae: 0.1173
# Epoch 106/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0404 - mae: 0.1373 - val_loss: 0.0292 - val_mae: 0.1166
# Epoch 107/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0442 - mae: 0.1429 - val_loss: 0.0320 - val_mae: 0.1149
# Epoch 108/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0431 - mae: 0.1392 - val_loss: 0.0268 - val_mae: 0.1093
# Epoch 109/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0460 - mae: 0.1429 - val_loss: 0.0267 - val_mae: 0.1079
# Epoch 110/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0448 - mae: 0.1431 - val_loss: 0.0258 - val_mae: 0.1077
# Epoch 111/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0425 - mae: 0.1401 - val_loss: 0.0270 - val_mae: 0.1096
# Epoch 112/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0428 - mae: 0.1406 - val_loss: 0.0286 - val_mae: 0.1113
# Epoch 113/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0446 - mae: 0.1409 - val_loss: 0.0322 - val_mae: 0.1231
# Epoch 114/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0469 - mae: 0.1459 - val_loss: 0.0330 - val_mae: 0.1171
# Epoch 115/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0452 - mae: 0.1413 - val_loss: 0.0406 - val_mae: 0.1307
# Epoch 116/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0482 - mae: 0.1467 - val_loss: 0.0464 - val_mae: 0.1356
# Epoch 117/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0550 - mae: 0.1523 - val_loss: 0.0338 - val_mae: 0.1197
# Epoch 118/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0466 - mae: 0.1451 - val_loss: 0.0264 - val_mae: 0.1073
# Epoch 119/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0436 - mae: 0.1420 - val_loss: 0.0245 - val_mae: 0.1043
# Epoch 120/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0432 - mae: 0.1418 - val_loss: 0.0271 - val_mae: 0.1093
# Epoch 121/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0424 - mae: 0.1401 - val_loss: 0.0265 - val_mae: 0.1094
# Epoch 122/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0467 - mae: 0.1450 - val_loss: 0.0256 - val_mae: 0.1071
# Epoch 123/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0475 - mae: 0.1479 - val_loss: 0.0266 - val_mae: 0.1128
# Epoch 124/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0436 - mae: 0.1427 - val_loss: 0.0316 - val_mae: 0.1176
# Epoch 125/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0442 - mae: 0.1419 - val_loss: 0.0292 - val_mae: 0.1113
# Epoch 126/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0420 - mae: 0.1368 - val_loss: 0.0258 - val_mae: 0.1062
# Epoch 127/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0404 - mae: 0.1371 - val_loss: 0.0237 - val_mae: 0.1023
# Epoch 128/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0434 - mae: 0.1398 - val_loss: 0.0252 - val_mae: 0.1045
# Epoch 129/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0423 - mae: 0.1388 - val_loss: 0.0234 - val_mae: 0.1002
# Epoch 130/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0410 - mae: 0.1375 - val_loss: 0.0304 - val_mae: 0.1155
# Epoch 131/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0460 - mae: 0.1426 - val_loss: 0.0291 - val_mae: 0.1164
# Epoch 132/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0422 - mae: 0.1405 - val_loss: 0.0358 - val_mae: 0.1256
# Epoch 133/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0446 - mae: 0.1413 - val_loss: 0.0315 - val_mae: 0.1158
# Epoch 134/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0421 - mae: 0.1376 - val_loss: 0.0253 - val_mae: 0.1075
# Epoch 135/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0409 - mae: 0.1380 - val_loss: 0.0357 - val_mae: 0.1240
# Epoch 136/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0434 - mae: 0.1409 - val_loss: 0.0358 - val_mae: 0.1224
# Epoch 137/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0455 - mae: 0.1423 - val_loss: 0.0317 - val_mae: 0.1199
# Epoch 138/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0441 - mae: 0.1420 - val_loss: 0.0260 - val_mae: 0.1084
# Epoch 139/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0414 - mae: 0.1381 - val_loss: 0.0239 - val_mae: 0.1022
# Epoch 140/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0399 - mae: 0.1361 - val_loss: 0.0248 - val_mae: 0.1049
# Epoch 141/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0421 - mae: 0.1395 - val_loss: 0.0259 - val_mae: 0.1108
# Epoch 142/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0399 - mae: 0.1373 - val_loss: 0.0242 - val_mae: 0.1037
# Epoch 143/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0431 - mae: 0.1415 - val_loss: 0.0254 - val_mae: 0.1055
# Epoch 144/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0431 - mae: 0.1404 - val_loss: 0.0254 - val_mae: 0.1077
# Epoch 145/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0415 - mae: 0.1381 - val_loss: 0.0267 - val_mae: 0.1103
# Epoch 146/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0436 - mae: 0.1406 - val_loss: 0.0264 - val_mae: 0.1067
# Epoch 147/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0408 - mae: 0.1364 - val_loss: 0.0268 - val_mae: 0.1074
# Epoch 148/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0426 - mae: 0.1383 - val_loss: 0.0249 - val_mae: 0.1033
# Epoch 149/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0416 - mae: 0.1370 - val_loss: 0.0242 - val_mae: 0.1027
# Epoch 150/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0430 - mae: 0.1390 - val_loss: 0.0235 - val_mae: 0.1008
# Epoch 151/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0418 - mae: 0.1374 - val_loss: 0.0244 - val_mae: 0.1016
# Epoch 152/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0380 - mae: 0.1338 - val_loss: 0.0218 - val_mae: 0.0979
# Epoch 153/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0386 - mae: 0.1351 - val_loss: 0.0232 - val_mae: 0.1008
# Epoch 154/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0368 - mae: 0.1341 - val_loss: 0.0229 - val_mae: 0.1017
# Epoch 155/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0383 - mae: 0.1345 - val_loss: 0.0233 - val_mae: 0.1043
# Epoch 156/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0413 - mae: 0.1378 - val_loss: 0.0250 - val_mae: 0.1136
# Epoch 157/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0395 - mae: 0.1366 - val_loss: 0.0215 - val_mae: 0.1001
# Epoch 158/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0385 - mae: 0.1338 - val_loss: 0.0235 - val_mae: 0.1020
# Epoch 159/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0381 - mae: 0.1345 - val_loss: 0.0229 - val_mae: 0.1009
# Epoch 160/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0423 - mae: 0.1398 - val_loss: 0.0273 - val_mae: 0.1138
# Epoch 161/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0442 - mae: 0.1416 - val_loss: 0.0322 - val_mae: 0.1198
# Epoch 162/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0439 - mae: 0.1401 - val_loss: 0.0257 - val_mae: 0.1074
# Epoch 163/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0432 - mae: 0.1397 - val_loss: 0.0270 - val_mae: 0.1106
# Epoch 164/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0424 - mae: 0.1390 - val_loss: 0.0244 - val_mae: 0.1042
# Epoch 165/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0403 - mae: 0.1357 - val_loss: 0.0239 - val_mae: 0.1053
# Epoch 166/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0433 - mae: 0.1404 - val_loss: 0.0226 - val_mae: 0.0997
# Epoch 167/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0391 - mae: 0.1345 - val_loss: 0.0248 - val_mae: 0.1031
# Epoch 168/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0406 - mae: 0.1360 - val_loss: 0.0238 - val_mae: 0.1030
# Epoch 169/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0407 - mae: 0.1355 - val_loss: 0.0229 - val_mae: 0.0981
# Epoch 170/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0402 - mae: 0.1349 - val_loss: 0.0253 - val_mae: 0.1052
# Epoch 171/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0398 - mae: 0.1343 - val_loss: 0.0239 - val_mae: 0.1092
# Epoch 172/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0398 - mae: 0.1356 - val_loss: 0.0253 - val_mae: 0.1131
# Epoch 173/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0419 - mae: 0.1399 - val_loss: 0.0260 - val_mae: 0.1076
# Epoch 174/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0412 - mae: 0.1375 - val_loss: 0.0272 - val_mae: 0.1086
# Epoch 175/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0398 - mae: 0.1348 - val_loss: 0.0324 - val_mae: 0.1186
# Epoch 176/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0406 - mae: 0.1376 - val_loss: 0.0371 - val_mae: 0.1235
# Epoch 177/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0447 - mae: 0.1431 - val_loss: 0.0312 - val_mae: 0.1211
# Epoch 178/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0443 - mae: 0.1419 - val_loss: 0.0237 - val_mae: 0.1048
# Epoch 179/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0422 - mae: 0.1392 - val_loss: 0.0258 - val_mae: 0.1066
# Epoch 180/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0453 - mae: 0.1431 - val_loss: 0.0236 - val_mae: 0.1025
# Epoch 181/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0426 - mae: 0.1387 - val_loss: 0.0240 - val_mae: 0.1050
# Epoch 182/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0437 - mae: 0.1401 - val_loss: 0.0266 - val_mae: 0.1092
# Epoch 183/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0432 - mae: 0.1411 - val_loss: 0.0216 - val_mae: 0.0982
# Epoch 184/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0414 - mae: 0.1372 - val_loss: 0.0318 - val_mae: 0.1159
# Epoch 185/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0392 - mae: 0.1347 - val_loss: 0.0264 - val_mae: 0.1094
# Epoch 186/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0440 - mae: 0.1414 - val_loss: 0.0279 - val_mae: 0.1100
# Epoch 187/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0467 - mae: 0.1415 - val_loss: 0.0254 - val_mae: 0.1044
# Epoch 188/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0417 - mae: 0.1379 - val_loss: 0.0220 - val_mae: 0.1005
# Epoch 189/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0421 - mae: 0.1391 - val_loss: 0.0263 - val_mae: 0.1063
# Epoch 190/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0433 - mae: 0.1412 - val_loss: 0.0247 - val_mae: 0.1086
# Epoch 191/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0419 - mae: 0.1406 - val_loss: 0.0229 - val_mae: 0.1038
# Epoch 192/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0390 - mae: 0.1346 - val_loss: 0.0226 - val_mae: 0.1016
# Epoch 193/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0377 - mae: 0.1326 - val_loss: 0.0222 - val_mae: 0.0995
# Epoch 194/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0386 - mae: 0.1342 - val_loss: 0.0227 - val_mae: 0.0995
# Epoch 195/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0403 - mae: 0.1356 - val_loss: 0.0251 - val_mae: 0.1052
# Epoch 196/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0405 - mae: 0.1355 - val_loss: 0.0355 - val_mae: 0.1276
# Epoch 197/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0474 - mae: 0.1446 - val_loss: 0.0249 - val_mae: 0.1036
# Epoch 198/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0579 - mae: 0.1543 - val_loss: 0.0301 - val_mae: 0.1105
# Epoch 199/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0519 - mae: 0.1481 - val_loss: 0.0377 - val_mae: 0.1287
# Epoch 200/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0500 - mae: 0.1484 - val_loss: 0.0288 - val_mae: 0.1177
# Epoch 201/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0454 - mae: 0.1442 - val_loss: 0.0216 - val_mae: 0.0997
# Epoch 202/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0422 - mae: 0.1415 - val_loss: 0.0234 - val_mae: 0.1044
# Epoch 203/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0426 - mae: 0.1385 - val_loss: 0.0240 - val_mae: 0.1037
# Epoch 204/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0453 - mae: 0.1425 - val_loss: 0.0293 - val_mae: 0.1137
# Epoch 205/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0416 - mae: 0.1379 - val_loss: 0.0302 - val_mae: 0.1163
# Epoch 206/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0447 - mae: 0.1438 - val_loss: 0.0282 - val_mae: 0.1096
# Epoch 207/1000
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0445 - mae: 0.1433 - val_loss: 0.0217 - val_mae: 0.0993
# Epoch 207: early stopping
# Restoring model weights from the end of the best epoch: 157.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 'print("y_train min/max:", y_train_np.min(), y_train_np.max())\nprint("y_pred min/max (scaled):", y_pred.min(), y_pred.max())\ny_pred_rescaled = scaler_y.inverse_transform(y_pred)\nprint("y_pred_rescaled min/max:", y_pred_rescaled.min(), y_pred_rescaled.max())'

# %%
model = tf.keras.models.load_model(f'{exp_dir}/model/NO2_global_model.keras') if os.path.exists(f'{exp_dir}/model/NO2_global_model.keras') else model

# %%
# Estrai losses da tutti i folds
train_losses = history.history['loss']
val_losses   = history.history['val_loss']

train_losses = train_losses
val_losses = val_losses

# Plot
plt.figure(figsize=(8,5))


# Training loss
plt.plot(train_losses, color='blue', label='Train Loss')
# Validation loss
plt.plot(val_losses, color='red', label='Validation Loss')


# Dettagli grafico
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.savefig(f'{exp_dir}/loss_plot.png')

# %%
def plot_first_n_series(y_pred, y_test, n_series=10, title="Confronto Serie Predette vs Reali"):
    """
    Plotta le prime n_series serie reali e predette per un confronto diretto.

    Args:
        y_pred (np.ndarray): Predizioni del modello (shape: num_samples x seq_len).
        y_test (np.ndarray): Serie reali (shape: num_samples x seq_len).
        n_series (int): Numero di serie da plottare.
        title (str): Titolo del grafico.
    """

    # Limitiamo a n_series per evitare problemi
    n = min(n_series, y_pred.shape[0], y_test.shape[0])

    plt.figure(figsize=(14, 8))

    for i in range(n):
        plt.plot(
            y_test[i], 
            linewidth=1.8, 
            alpha=0.7, 
            label=f"Reale {i+1}" if i == 0 else "",
            color = 'blue'
        )
        plt.plot(
            y_pred[i], 
            linewidth=1.8, 
            linestyle="--", 
            alpha=0.9, 
            label=f"Predetto {i+1}" if i == 0 else "",
            color = 'red'
        )

    plt.title(title, fontsize=16)
    plt.xlabel("Time Step", fontsize=12)
    plt.ylabel("Valore", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

def plot_diagnosis_gradient(y_pred, y_test, save_path: str,  tolerance:float =0.05, max_samples_heatmap=50, scatter_sample_ratio=0.5, tol_auto = True):
    """
    Dashboard diagnostica con tolleranza AUTO-ADATTIVA alla scala dei dati.
    
    Args:
        tolerance (float): 
            - Se None: La tolleranza viene calcolata automaticamente come il 5% del range dei dati (Max-Min).
            - Se float: Valore assoluto (es. 0.5).
        tol_auto (bool): Se True, usa la tolleranza automatica basata sul range dei dati, altrimenti usa il valore manuale fornito 
        col parametro tolerance.
    """
    
    y_test_flat = y_test.flatten()
    y_pred_flat = y_pred.flatten()

    # ---------------------------------------------------------
    # AUTOMAZIONE TOLLERANZA
    # ---------------------------------------------------------
    if tol_auto:
        data_range = y_test_flat.max() - y_test_flat.min()
        # Impostiamo la tolleranza al 5% del range totale (regolabile)
        tolerance = data_range * tolerance 
        tol_label = f"Auto (5% Range: ±{tolerance:.2f})"
    else:
        tol_label = f"Manuale (±{tolerance})"

    fig, axes = plt.subplots(1, 2, figsize=(22, 8))

    # -----------------------------
    # 1. HEATMAP (SX)
    # -----------------------------
    errors = np.abs(y_test - y_pred)
    errors_subset = errors[:max_samples_heatmap]
    
    # Adattiamo anche la scala colori della heatmap alla tolleranza
    # Tutto ciò che è oltre 3 volte la tolleranza è "errore massimo" visivo
    sns.heatmap(errors_subset, cmap="plasma", ax=axes[0], 
                vmax=tolerance * 3,
                cbar_kws={'label': 'Errore Assoluto'})
    
    axes[0].set_title(f"Heatmap Errori (Primi {max_samples_heatmap} campioni)", fontsize=16)
    axes[0].set_xlabel("Time Step", fontsize=12)
    axes[0].set_ylabel("Indice Campione", fontsize=12)

    # -----------------------------
    # 2. SCATTER CON SFONDO GRADIENTE (DX)
    # -----------------------------
    
    # Campionamento dati
    if scatter_sample_ratio < 1.0:
        mask = np.random.rand(len(y_test_flat)) < scatter_sample_ratio
        sample_test = y_test_flat[mask]
        sample_pred = y_pred_flat[mask]
    else:
        sample_test = y_test_flat
        sample_pred = y_pred_flat

    # Calcolo limiti grafico
    min_val = min(y_test_flat.min(), y_pred_flat.min())
    max_val = max(y_test_flat.max(), y_pred_flat.max())
    padding = (max_val - min_val) * 0.05
    plot_min = min_val - padding
    plot_max = max_val + padding

    # --- SFONDO GRADIENTE ---
    grid_x, grid_y = np.meshgrid(
        np.linspace(plot_min, plot_max, 200),
        np.linspace(plot_min, plot_max, 200)
    )
    grid_z = np.abs(grid_y - grid_x)

    im = axes[1].imshow(
        grid_z, 
        extent=(plot_min, plot_max, plot_min, plot_max), 
        origin='lower', 
        cmap='RdYlGn_r', 
        alpha=0.4, 
        vmax=tolerance * 4, # Il rosso satura a 4x della tolleranza
        aspect='auto'
    )

    # --- PUNTI BLU ---
    axes[1].scatter(
        sample_test, 
        sample_pred, 
        alpha=0.6, 
        s=15, 
        color='royalblue', 
        edgecolors='white', 
        linewidth=0.3,
        label='Campioni'
    )

    axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

    # Metriche
    within_tol = np.mean(np.abs(y_test_flat - y_pred_flat) <= tolerance) * 100

    axes[1].set_title(
        f"Bontà delle previsioni con {tol_label}\nValori nel range di Tolleranza: {within_tol:.1f}%", 
        fontsize=16
    )
    axes[1].set_xlabel("Valore Reale", fontsize=12)
    axes[1].set_ylabel("Valore Predetto", fontsize=12)
    axes[1].set_xlim(plot_min, plot_max)
    axes[1].set_ylim(plot_min, plot_max)
    
    cbar = plt.colorbar(im, ax=axes[1], pad=0.02)
    cbar.set_label('Gravità Errore (Distanza da diagonale)')

    plt.tight_layout()
    plt.savefig(f'{exp_dir}/{save_path}.png')

# %%
y_pred = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred)
y_test_np = scaler_y.inverse_transform(y_test)

plot_diagnosis_gradient(y_pred, y_test_np,save_path='pred_quality', max_samples_heatmap=10, scatter_sample_ratio=0.7)
# Out:
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_3237/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

# %%
import json
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_and_log(y_true, y_pred, log_path="log.json"):
    # --- Metriche ---
    mae = mean_absolute_error(y_true, y_pred, multioutput="uniform_average")
    rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput="uniform_average"))

    mask = y_true != 0
    mape = float(np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100.0)

    r2 = r2_score(y_true, y_pred, multioutput="uniform_average")

    # Valore medio del test set
    v_mean = float(np.mean(y_true))

    # --- Stampa ---
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    print(f"Test MAPE: {mape:.2f}%")
    print(f"Test R2: {r2:.4f}")
    print(f"Valore medio del test set: {v_mean:.4f}")

    # --- Salvataggio log ---
    log_data = {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2,
        "test_mean_value": v_mean
    }

    with open(log_path, "w") as f:
        json.dump(log_data, f, indent=4)

    print(f"\nLog salvato in: {log_path}")
evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/evaluation_log.json")
# Impostazioni pandas per visualizzare tutti i dati
# Out:
# Test MAE: 1.3767
# Test RMSE: 1.9762
# Test MAPE: 17.83%
# Test R2: 0.9817
# Valore medio del test set: 14.5727
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/evaluation_log.json

# %%
for key in splits.keys():
    X_sens, y_sens = splits[key]
    print(f"Sensore: {key}, X_test shape: {X_sens.shape if X_sens is not None else None}, y_test shape: {y_sens.shape if y_sens is not None else None}")

    y_pred = model.predict(scaler_X.transform(X_sens))
    plot_diagnosis_gradient(
          scaler_y.inverse_transform(y_pred),
          y_sens,
          save_path=f'pred_quality_sensor_{key}',
          max_samples_heatmap=10,
          scatter_sample_ratio=0.7
     )
    evaluate_and_log(
        y_sens,
        scaler_y.inverse_transform(y_pred),
        log_path=f"{exp_dir}/evaluation_log_sensor_{key}.json"
    )
    save_prediction_plots(
        y_sens,
        scaler_y.inverse_transform(y_pred),
        output_dir=f'{exp_dir}/TEST_sensor_{key}',
        prefix=f"pred_plot_sensor_{key}"
    )
# Out:
# Sensore: AR-ACROPOLI, X_test shape: (55, 33), y_test shape: (55, 24)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_3237/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Test MAE: 1.0263
# Test RMSE: 1.2409
# Test MAPE: 20.89%
# Test R2: -0.5720
# Valore medio del test set: 5.9393
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/evaluation_log_sensor_AR-ACROPOLI.json
# Salvo 55 plot in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/TEST_sensor_AR-ACROPOLI
# Plot salvati correttamente.
# Sensore: FI-GRAMSCI, X_test shape: (92, 33), y_test shape: (92, 24)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_3237/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Test MAE: 2.2119
# Test RMSE: 2.9443
# Test MAPE: 5.90%
# Test R2: 0.8553
# Valore medio del test set: 41.6166
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/evaluation_log_sensor_FI-GRAMSCI.json
# Salvo 92 plot in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/TEST_sensor_FI-GRAMSCI
# Plot salvati correttamente.
# Sensore: FI-SETTIGNANO, X_test shape: (55, 33), y_test shape: (55, 24)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test MAE: 0.7249
# Test RMSE: 0.9372
# Test MAPE: 32.22%
# Test R2: -0.2023
# Valore medio del test set: 2.8578
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/evaluation_log_sensor_FI-SETTIGNANO.json
# Salvo 55 plot in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/TEST_sensor_FI-SETTIGNANO
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_3237/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Plot salvati correttamente.
# Sensore: GR-MAREMMA, X_test shape: (62, 33), y_test shape: (62, 24)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_3237/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Test MAE: 0.7966
# Test RMSE: 0.9186
# Test MAPE: 27.99%
# Test R2: -3.4547
# Valore medio del test set: 3.0654
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/evaluation_log_sensor_GR-MAREMMA.json
# Salvo 62 plot in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/TEST_sensor_GR-MAREMMA
# Plot salvati correttamente.
# Sensore: LI-LAPIRA, X_test shape: (55, 33), y_test shape: (55, 24)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test MAE: 1.6266
# Test RMSE: 2.3717
# Test MAPE: 13.23%
# Test R2: 0.7904
# Valore medio del test set: 13.7463
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/evaluation_log_sensor_LI-LAPIRA.json
# Salvo 55 plot in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/TEST_sensor_LI-LAPIRA
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_3237/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Plot salvati correttamente.
# Sensore: LU-VIAREGGIO, X_test shape: (74, 33), y_test shape: (74, 24)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_3237/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Test MAE: 1.2752
# Test RMSE: 1.7251
# Test MAPE: 13.59%
# Test R2: 0.4073
# Valore medio del test set: 10.5587
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/evaluation_log_sensor_LU-VIAREGGIO.json
# Salvo 74 plot in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/TEST_sensor_LU-VIAREGGIO
# Plot salvati correttamente.
# Sensore: PO-ROMA, X_test shape: (60, 33), y_test shape: (60, 24)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_3237/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Test MAE: 1.5103
# Test RMSE: 2.0685
# Test MAPE: 19.10%
# Test R2: 0.5390
# Valore medio del test set: 9.3573
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/evaluation_log_sensor_PO-ROMA.json
# Salvo 60 plot in: ../RISULTATI/2025-11-30/esperimento_Global_Arpat_14-36-49/TEST_sensor_PO-ROMA
# Plot salvati correttamente.
