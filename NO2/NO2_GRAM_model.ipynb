# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import os, pickle, random
from datetime import datetime

# %%
get_after_QA = lambda s: s.split("QA_", 1)[1]

# %%
dati = pd.read_excel('/Users/lapotinacci/thesis/metric_datasets/NO2_dataset.xlsx')
dati = dati[dati["serviceUri"] == "http://www.disit.org/km4city/resource/iot/orionUNIFI/DISIT/ARPAT_QA_FI-GRAMSCI"].copy()
sensor_name = get_after_QA(dati["serviceUri"].iloc[0])
dati.drop(columns=["serviceUri"], inplace=True)
print(dati.shape)
# Out:
# (557, 16)

# %%
# === Creazione cartella esperimento con timestamp ISO ===
timestamp = datetime.now().strftime("%H-%M-%S")
print(f"Ora inizio esperimento: {timestamp}")
day= datetime.now().strftime("%Y-%m-%d")
print(f"Giorno inizio esperimento: {day}")
exp_dir = f"../RISULTATI/{day}/esperimento_{sensor_name}_{timestamp}"

os.makedirs(exp_dir, exist_ok=True)

print(f"Cartella esperimento creata: {exp_dir}")
# Out:
# Ora inizio esperimento: 14-19-05
# Giorno inizio esperimento: 2025-11-30
# Cartella esperimento creata: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05

# %%
import ast

mask = ~dati['TTT'].str.contains("nan", na=True)
dtset_completo = dati[mask]

dtset_completo['TTT'] = dtset_completo['TTT'].apply(ast.literal_eval)

# %%
# Filtra le righe dove la colonna TTT ha lunghezza 24, ed elimina tutte le colonne le cui osservazioni sono indipendenti dal giorno
dtset_filtrato = dtset_completo[dtset_completo["TTT"].apply(lambda x: len(x) == 24)].sample(frac=1).reset_index(drop=True)
dtset_filtrato = dtset_filtrato[dtset_filtrato["type_of_TTT"] == "daily"]
len(dtset_filtrato)
# Out:
# 456

# %%
import numpy as np


def is_useful_series(series, zero_ratio_thr=0.85, min_nonzero_value=0.1):
    arr = np.array(series, dtype=float)
    
    # Serie troppo corta
    if len(arr) <= 1:
        return False
    
    # Troppi zeri
    zero_ratio = (arr == 0).mean()
    if zero_ratio >= zero_ratio_thr:
        return False
    
    # Valore medio trascurabile (quasi zero)
    mean_val = np.mean(arr)
    if abs(mean_val) < min_nonzero_value:
        return False
    
    # Se arriva qui, la serie ha valori significativi
    return True

# Applica filtro
mask_useful = dtset_filtrato["TTT"].apply(is_useful_series)
df_useful = dtset_filtrato[mask_useful]

# %%
def spezza_serie_in_colonne(df, colonna_stringa, prefix='col_'):
    # --- Controllo colonna ---
    if colonna_stringa not in df.columns:
        raise ValueError(f"La colonna '{colonna_stringa}' non esiste nel DataFrame")

    result_df = df.copy()

    # Estraggo la colonna contenente gli embedding
    col = result_df.pop(colonna_stringa)

    embeddings = []

    for item in col:
        if pd.isna(item) or item == "":
            embeddings.append([])
            continue
        
        try:
            # Parsing sicuro della stringa in lista Python
            vett = ast.literal_eval(item)

            # Se l’embedding è una numpy array o altro iterabile, lo converto in list
            if not isinstance(vett, list):
                vett = list(vett)

            # Converto tutto in float
            vett = [float(x) for x in vett]

            embeddings.append(vett)

        except Exception as e:
            print(f"Errore nel parsing dell'elemento '{item}': {e}")
            embeddings.append([])

    # --- Uniformo dimensione dei vettori ---
    lengths = [len(v) for v in embeddings]
    if not lengths:
        raise ValueError("Nessun embedding valido nella colonna")

    max_len = max(lengths)

    embeddings_padded = [
        v + [np.nan] * (max_len - len(v)) if len(v) < max_len else v
        for v in embeddings
    ]

    # --- Creo DataFrame delle nuove colonne ---
    colonne_embedding = pd.DataFrame(
        embeddings_padded,
        index=result_df.index,
        columns=[f"{prefix}{i}" for i in range(max_len)]
    )

    # --- Merge col DataFrame originale ---
    return pd.concat([result_df, colonne_embedding], axis=1)

# %%
for ttt in df_useful.TTT:
    plt.plot(ttt)

# %%
def summary_df(df):
    summary = pd.DataFrame({
        'dtype': df.dtypes,
        'n_missing': df.isna().sum(),
        '%_missing': (df.isna().mean() * 100).round(2),
        'n_unique': df.nunique(),
        'top_value': df.mode().iloc[0],  # moda
        'top_freq': [df[col].value_counts(dropna=True).iloc[0] if not df[col].value_counts(dropna=True).empty else None for col in df.columns],
        'min': [df[col].min() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'max': [df[col].max() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'mean': [df[col].mean() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'std': [df[col].std() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
    })
    return summary

# %%
#Nella precedente sono state eliminate le colonne con Nan, tuttavia alcuni dataset dei sensori METRO hanno dei Nan in city e surface dunque vengono rimossi nel prcedente box

categorical = [
    'is_weekend'
    ]

#consiglio, per serie cicliche usare funzioni periodiche tipo seno coseno 
df_encoded = pd.get_dummies(df_useful
                            , columns=categorical)

# %%
def save_pkl(obj, path):
    with open(path, "wb") as f:
        pickle.dump(obj, f)
    print(f"Salvato: {path}")

def load_pkl(path):
    with open(path, "rb") as f:
        return pickle.load(f)

# %%
#codifica ciclica delle features e individuazione del'ora del giorno e della settimana 

def encode_time_features(df, start_col="interval_start", end_col="interval_end"):
    df = df.copy()
    
    # Step 1: Ensure datetime columns are in the correct format first
    df[start_col] = pd.to_datetime(df[start_col], utc=True, format="mixed")
    df[end_col] = pd.to_datetime(df[end_col], utc=True, format="mixed")

    # Step 2: Extract 'month' and 'day' after conversion
    df['month'] = df[start_col].dt.month
    df['day'] = df[start_col].dt.dayofweek # Note: dayofweek is typically used for cyclical weekly patterns
    
    # Step 3: Now you can create the cyclical features
    df['month_sin'] = np.sin(2 * np.pi * df['month']/len(df['month'].unique()))
    df['month_cos'] = np.cos(2 * np.pi * df['month']/len(df['month'].unique()))
    df['day_sin'] = np.sin(2 * np.pi * df['day']/len(df['day'].unique()))
    df['day_cos'] = np.cos(2 * np.pi * df['day']/len(df['day'].unique()))


    # Ora del giorno (0-23) → ciclo giornaliero
    df["hour"] = df[start_col].dt.hour
    angle_day_start = 2 * np.pi * df["hour"] / 24
    df["start_time_sin"] = np.sin(angle_day_start)
    df["start_time_cos"] = np.cos(angle_day_start)

    df["hour_end"] = df[end_col].dt.hour
    angle_day_end = 2 * np.pi * df["hour_end"] / 24
    df["end_time_sin"] = np.sin(angle_day_end)
    df["end_time_cos"] = np.cos(angle_day_end)

    # Durata in minuti
    df["duration_minutes"] = (df[end_col] - df[start_col]).dt.total_seconds() / 60

    # Giorno della settimana (0=Mon..6=Sun) → ciclo settimanale
    dayofweek = df[start_col].dt.dayofweek
    angle_week = 2 * np.pi * dayofweek / 7
    df["dow_sin"] = np.sin(angle_week)
    df["dow_cos"] = np.cos(angle_week)

    # Giorno dell’anno (1-365) → ciclo annuale
    dayofyear = df[start_col].dt.dayofyear
    angle_year = 2 * np.pi * dayofyear / 365
    df["doy_sin"] = np.sin(angle_year)
    df["doy_cos"] = np.cos(angle_year)

    # Rimuovo colonne temporali e variabili ausiliarie
    df = df.drop(columns=[start_col, end_col, "hour", "hour_end", "day", "month"])
    return df

embedding_cols = ['highway_embedding', 'AreaTypeEmbeddings']

df_final = encode_time_features(df_encoded)
df_final.drop(columns=['type_of_TTT'], inplace=True)
for emb_col in embedding_cols:
    df_final = spezza_serie_in_colonne(df_final, emb_col, prefix=f'{emb_col}_')
df_final.shape

# Salvataggio DataFrame finale
df_path = os.path.join(exp_dir, f"dataframe_{sensor_name}")
os.makedirs(df_path, exist_ok=True)
save_pkl(df_final, os.path.join(df_path, f"filtered_dataframe.pkl"))
# Out:
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/dataframe_FI-GRAMSCI/filtered_dataframe.pkl

# %%
for ttt in df_final.TTT[10:20]:
    plt.plot(ttt)
    plt.title("Esempi di TTT ARPAT")
    plt.xlabel("Ora del Giorno")
    plt.ylabel("Valore TTT")

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

def series_to_2d_array(series, output_dim=24):
    arr = np.stack(series.apply(lambda x: np.array(x, dtype=np.float32)))
    if arr.shape[1] != output_dim:
        raise ValueError(f"Ogni elemento deve avere {output_dim} valori, trovato {arr.shape[1]}")
    return arr

 # Separazione delle feature e del target
X = df_final.drop(columns=['TTT'])
y = df_final['TTT']

X_np = X.to_numpy().astype(np.float32)
y_np = series_to_2d_array(y, output_dim=24)

# Calcolo deviazione standard per ogni serie
std_scores = np.std(y_np, axis=1)

std_scores_log = np.log1p(std_scores)  # log(1+x) per evitare problemi con valori vicini a 0

std_scores_normalized = (std_scores_log - np.min(std_scores_log)) / (np.max(std_scores_log) - np.min(std_scores_log))

# Creo bin basati sui quantili
bins = np.array([0.0, 0.4, 0.8, 1.0])
std_bins = np.digitize(std_scores_normalized, bins)

# Primo split: train (80%) vs temp (20%)
# Passo anche std_bins per poter stratificare
X_train, X_test, y_train, y_test = train_test_split(
    X_np, y_np,
    test_size=0.2,
    random_state=42,
    stratify=std_bins, 
    shuffle=True
)

print(f"Train size: {X_train.shape}, {y_train.shape}")
print(f"Test size: {X_test.shape}, {y_test.shape}")

# Debug prints
print(f"Final shapes:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

# Scaler per input
scaler_X = StandardScaler()
X_train = scaler_X.fit_transform(X_train)
X_test  = scaler_X.transform(X_test)

# Scaler per output (se serve normalizzare anche y)
scaler_y = StandardScaler()
y_train = scaler_y.fit_transform(y_train)
y_test  = scaler_y.transform(y_test)

#cartella salvataggio train e test
path = os.path.join(exp_dir, "train_test_data")
os.makedirs(path, exist_ok=True)

#  === Salvataggio dataset e scaler in formato .pkl ===
save_pkl(scaler_X.inverse_transform(X_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_X.inverse_transform(X_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_test_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_test_unscaled_{sensor_name}.pkl"))


save_pkl(X_train, os.path.join(exp_dir, "X_train.pkl"))
save_pkl(y_train, os.path.join(exp_dir, "y_train.pkl"))
save_pkl(X_test, os.path.join(exp_dir, "X_test.pkl"))
save_pkl(y_test, os.path.join(exp_dir, "y_test.pkl"))

save_pkl(scaler_X, os.path.join(exp_dir, "scaler_X.pkl"))
save_pkl(scaler_y, os.path.join(exp_dir, "scaler_y.pkl"))

print("Scaler salvati.")

print("\nTutti i file sono stati salvati correttamente.")
print(f"Percorso cartella: {os.path.abspath(exp_dir)}")
# Out:
# Train size: (364, 33), (364, 24)
# Test size: (92, 33), (92, 24)
# Final shapes:
# X_train: (364, 33)
# y_train: (364, 24)
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_train_unscaled_FI-GRAMSCI.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_train_unscaled_FI-GRAMSCI.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_test_unscaled_FI-GRAMSCI.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_test_unscaled_FI-GRAMSCI.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/X_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/y_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/X_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/y_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/scaler_X.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/scaler_y.pkl
# Scaler salvati.
#
# Tutti i file sono stati salvati correttamente.
# Percorso cartella: /Users/lapotinacci/thesis/Federated_Sys/RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05

# %%
# === Costruisci i path ===
path_X_train = os.path.join(exp_dir, "X_train.pkl")
path_y_train = os.path.join(exp_dir, "y_train.pkl")
path_X_test  = os.path.join(exp_dir, "X_test.pkl")
path_y_test  = os.path.join(exp_dir, "y_test.pkl")

path_scaler_X = os.path.join(exp_dir, "scaler_X.pkl")
path_scaler_y = os.path.join(exp_dir, "scaler_y.pkl")

# === Ricaricamento ===
X_train = load_pkl(path_X_train)
y_train = load_pkl(path_y_train)
X_test  = load_pkl(path_X_test)
y_test  = load_pkl(path_y_test)


scaler_X = load_pkl(path_scaler_X)
scaler_y = load_pkl(path_scaler_y)

print("Shapes ricostruite:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

print("\nScaler caricati:")
print("scaler_X:", type(scaler_X))
print("scaler_y:", type(scaler_y))
# Out:
# Shapes ricostruite:
# X_train: (364, 33)
# y_train: (364, 24)
# X_test: (92, 33)
# y_test: (92, 24)
#
# Scaler caricati:
# scaler_X: <class 'sklearn.preprocessing._data.StandardScaler'>
# scaler_y: <class 'sklearn.preprocessing._data.StandardScaler'>

# %% [markdown]
# # modelli

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers # type: ignore
from tensorflow.keras.layers import Dropout # type: ignore
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
def save_prediction_plots(y_true, y_pred, output_dir, prefix="pred_plot"):
    os.makedirs(output_dir, exist_ok=True)

    n = len(y_true)
    print(f"Salvo {n} plot in: {output_dir}")

    for i in range(n):
        plt.figure(figsize=(8, 3))
        plt.plot(y_true[i], label="True")
        plt.plot(y_pred[i], label="Pred")
        plt.legend()
        plt.tight_layout()

        filename = f"{prefix}_{i+1}.png"
        path = os.path.join(output_dir, filename)

        plt.savefig(path)
        plt.close()

    print("Plot salvati correttamente.")

# %%
# Definizione modello DNN
def build_model(input_shape: tuple, output_shape: tuple):
    model = models.Sequential([
        layers.Dense(128, activation = "relu", input_shape=input_shape),
        Dropout(0.0),
        layers.Dense(output_shape, 'linear')
    ])
    model.compile(
    optimizer=optimizers.AdamW(learning_rate=0.0057, weight_decay=0.0158),
    loss= 'mse',
    metrics=['mae'],
    )
    return model

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',      # metrica da monitorare, es. val_loss o val_mae
    patience=100,             # numero di epoche senza miglioramento prima di fermare
    restore_best_weights=True,  # ripristina i pesi migliori trovati
    verbose = 1
)

# Training del modello
model = build_model((X_test.shape[1],), y_test.shape[1])
history = model.fit(
    X_train, y_train,
    epochs=1000,
    batch_size=64,
    callbacks = [early_stop],
    validation_split = 0.2,
    verbose=1
    )

'''print("y_train min/max:", y_train_np.min(), y_train_np.max())
print("y_pred min/max (scaled):", y_pred.min(), y_pred.max())
y_pred_rescaled = scaler_y.inverse_transform(y_pred)
print("y_pred_rescaled min/max:", y_pred_rescaled.min(), y_pred_rescaled.max())'''

if not os.path.exists(os.path.join(exp_dir, "model")):
    os.makedirs(os.path.join(exp_dir, "model"))
    model.save(os.path.join(exp_dir, "model", "NO2_MAREMMA_model.keras"))
# Out:
# Epoch 1/1000
# /Users/lapotinacci/thesis/Federated_Sys/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.9669 - mae: 0.7440 - val_loss: 0.5662 - val_mae: 0.5606
# Epoch 2/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4582 - mae: 0.5082 - val_loss: 0.2991 - val_mae: 0.4102
# Epoch 3/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2886 - mae: 0.4088 - val_loss: 0.2547 - val_mae: 0.3769
# Epoch 4/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2477 - mae: 0.3755 - val_loss: 0.2097 - val_mae: 0.3408
# Epoch 5/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2004 - mae: 0.3342 - val_loss: 0.1794 - val_mae: 0.3151
# Epoch 6/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1738 - mae: 0.3119 - val_loss: 0.1607 - val_mae: 0.2949
# Epoch 7/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1547 - mae: 0.2922 - val_loss: 0.1465 - val_mae: 0.2789
# Epoch 8/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1385 - mae: 0.2756 - val_loss: 0.1333 - val_mae: 0.2638
# Epoch 9/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1273 - mae: 0.2627 - val_loss: 0.1231 - val_mae: 0.2540
# Epoch 10/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1163 - mae: 0.2511 - val_loss: 0.1153 - val_mae: 0.2453
# Epoch 11/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1076 - mae: 0.2411 - val_loss: 0.1100 - val_mae: 0.2386
# Epoch 12/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0996 - mae: 0.2306 - val_loss: 0.1020 - val_mae: 0.2286
# Epoch 13/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0925 - mae: 0.2214 - val_loss: 0.0940 - val_mae: 0.2185
# Epoch 14/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0853 - mae: 0.2125 - val_loss: 0.0894 - val_mae: 0.2130
# Epoch 15/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0799 - mae: 0.2056 - val_loss: 0.0848 - val_mae: 0.2081
# Epoch 16/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0748 - mae: 0.1988 - val_loss: 0.0798 - val_mae: 0.2017
# Epoch 17/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0699 - mae: 0.1922 - val_loss: 0.0762 - val_mae: 0.1962
# Epoch 18/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0654 - mae: 0.1857 - val_loss: 0.0729 - val_mae: 0.1921
# Epoch 19/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0620 - mae: 0.1818 - val_loss: 0.0689 - val_mae: 0.1871
# Epoch 20/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0585 - mae: 0.1759 - val_loss: 0.0666 - val_mae: 0.1832
# Epoch 21/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0551 - mae: 0.1715 - val_loss: 0.0628 - val_mae: 0.1792
# Epoch 22/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0529 - mae: 0.1673 - val_loss: 0.0605 - val_mae: 0.1769
# Epoch 23/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mae: 0.1629 - val_loss: 0.0580 - val_mae: 0.1717
# Epoch 24/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0475 - mae: 0.1596 - val_loss: 0.0550 - val_mae: 0.1684
# Epoch 25/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0450 - mae: 0.1554 - val_loss: 0.0521 - val_mae: 0.1641
# Epoch 26/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0431 - mae: 0.1525 - val_loss: 0.0504 - val_mae: 0.1612
# Epoch 27/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0407 - mae: 0.1481 - val_loss: 0.0494 - val_mae: 0.1586
# Epoch 28/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0390 - mae: 0.1448 - val_loss: 0.0460 - val_mae: 0.1529
# Epoch 29/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0374 - mae: 0.1424 - val_loss: 0.0458 - val_mae: 0.1526
# Epoch 30/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0363 - mae: 0.1400 - val_loss: 0.0442 - val_mae: 0.1507
# Epoch 31/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0347 - mae: 0.1374 - val_loss: 0.0415 - val_mae: 0.1458
# Epoch 32/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0339 - mae: 0.1357 - val_loss: 0.0412 - val_mae: 0.1464
# Epoch 33/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0328 - mae: 0.1334 - val_loss: 0.0409 - val_mae: 0.1447
# Epoch 34/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0316 - mae: 0.1313 - val_loss: 0.0381 - val_mae: 0.1409
# Epoch 35/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0302 - mae: 0.1276 - val_loss: 0.0370 - val_mae: 0.1391
# Epoch 36/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0284 - mae: 0.1238 - val_loss: 0.0363 - val_mae: 0.1373
# Epoch 37/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0272 - mae: 0.1213 - val_loss: 0.0352 - val_mae: 0.1343
# Epoch 38/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0261 - mae: 0.1191 - val_loss: 0.0349 - val_mae: 0.1344
# Epoch 39/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0259 - mae: 0.1172 - val_loss: 0.0328 - val_mae: 0.1300
# Epoch 40/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0255 - mae: 0.1173 - val_loss: 0.0332 - val_mae: 0.1328
# Epoch 41/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0246 - mae: 0.1159 - val_loss: 0.0326 - val_mae: 0.1299
# Epoch 42/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0232 - mae: 0.1120 - val_loss: 0.0319 - val_mae: 0.1303
# Epoch 43/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0231 - mae: 0.1115 - val_loss: 0.0308 - val_mae: 0.1257
# Epoch 44/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0224 - mae: 0.1096 - val_loss: 0.0300 - val_mae: 0.1258
# Epoch 45/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0215 - mae: 0.1070 - val_loss: 0.0288 - val_mae: 0.1220
# Epoch 46/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0202 - mae: 0.1037 - val_loss: 0.0287 - val_mae: 0.1215
# Epoch 47/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0196 - mae: 0.1015 - val_loss: 0.0278 - val_mae: 0.1192
# Epoch 48/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0191 - mae: 0.1003 - val_loss: 0.0273 - val_mae: 0.1183
# Epoch 49/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0190 - mae: 0.1002 - val_loss: 0.0262 - val_mae: 0.1161
# Epoch 50/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0185 - mae: 0.0984 - val_loss: 0.0267 - val_mae: 0.1172
# Epoch 51/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0181 - mae: 0.0974 - val_loss: 0.0268 - val_mae: 0.1177
# Epoch 52/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0174 - mae: 0.0966 - val_loss: 0.0262 - val_mae: 0.1176
# Epoch 53/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0171 - mae: 0.0960 - val_loss: 0.0263 - val_mae: 0.1154
# Epoch 54/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0166 - mae: 0.0934 - val_loss: 0.0260 - val_mae: 0.1164
# Epoch 55/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0167 - mae: 0.0936 - val_loss: 0.0248 - val_mae: 0.1117
# Epoch 56/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0159 - mae: 0.0910 - val_loss: 0.0246 - val_mae: 0.1113
# Epoch 57/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0155 - mae: 0.0896 - val_loss: 0.0228 - val_mae: 0.1078
# Epoch 58/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0147 - mae: 0.0870 - val_loss: 0.0229 - val_mae: 0.1074
# Epoch 59/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0143 - mae: 0.0859 - val_loss: 0.0217 - val_mae: 0.1048
# Epoch 60/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0141 - mae: 0.0855 - val_loss: 0.0218 - val_mae: 0.1045
# Epoch 61/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0137 - mae: 0.0833 - val_loss: 0.0214 - val_mae: 0.1021
# Epoch 62/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0138 - mae: 0.0839 - val_loss: 0.0212 - val_mae: 0.1027
# Epoch 63/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0129 - mae: 0.0815 - val_loss: 0.0215 - val_mae: 0.1035
# Epoch 64/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127 - mae: 0.0802 - val_loss: 0.0200 - val_mae: 0.0999
# Epoch 65/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125 - mae: 0.0800 - val_loss: 0.0207 - val_mae: 0.1013
# Epoch 66/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0123 - mae: 0.0795 - val_loss: 0.0200 - val_mae: 0.1003
# Epoch 67/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0120 - mae: 0.0781 - val_loss: 0.0191 - val_mae: 0.0961
# Epoch 68/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - mae: 0.0769 - val_loss: 0.0203 - val_mae: 0.1008
# Epoch 69/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - mae: 0.0778 - val_loss: 0.0182 - val_mae: 0.0947
# Epoch 70/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0112 - mae: 0.0750 - val_loss: 0.0191 - val_mae: 0.0982
# Epoch 71/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109 - mae: 0.0738 - val_loss: 0.0185 - val_mae: 0.0950
# Epoch 72/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0107 - mae: 0.0721 - val_loss: 0.0180 - val_mae: 0.0941
# Epoch 73/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0105 - mae: 0.0724 - val_loss: 0.0171 - val_mae: 0.0914
# Epoch 74/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - mae: 0.0731 - val_loss: 0.0177 - val_mae: 0.0941
# Epoch 75/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0108 - mae: 0.0738 - val_loss: 0.0165 - val_mae: 0.0905
# Epoch 76/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0102 - mae: 0.0719 - val_loss: 0.0173 - val_mae: 0.0933
# Epoch 77/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0099 - mae: 0.0702 - val_loss: 0.0161 - val_mae: 0.0897
# Epoch 78/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0098 - mae: 0.0699 - val_loss: 0.0175 - val_mae: 0.0926
# Epoch 79/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0096 - mae: 0.0696 - val_loss: 0.0173 - val_mae: 0.0929
# Epoch 80/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0098 - mae: 0.0706 - val_loss: 0.0162 - val_mae: 0.0893
# Epoch 81/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0098 - mae: 0.0701 - val_loss: 0.0164 - val_mae: 0.0908
# Epoch 82/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0100 - mae: 0.0717 - val_loss: 0.0171 - val_mae: 0.0941
# Epoch 83/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0104 - mae: 0.0739 - val_loss: 0.0182 - val_mae: 0.0964
# Epoch 84/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0107 - mae: 0.0753 - val_loss: 0.0189 - val_mae: 0.1004
# Epoch 85/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0105 - mae: 0.0750 - val_loss: 0.0184 - val_mae: 0.0956
# Epoch 86/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0100 - mae: 0.0725 - val_loss: 0.0173 - val_mae: 0.0926
# Epoch 87/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0099 - mae: 0.0717 - val_loss: 0.0163 - val_mae: 0.0888
# Epoch 88/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0095 - mae: 0.0699 - val_loss: 0.0150 - val_mae: 0.0868
# Epoch 89/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0087 - mae: 0.0668 - val_loss: 0.0149 - val_mae: 0.0861
# Epoch 90/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084 - mae: 0.0651 - val_loss: 0.0141 - val_mae: 0.0835
# Epoch 91/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081 - mae: 0.0639 - val_loss: 0.0143 - val_mae: 0.0833
# Epoch 92/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0080 - mae: 0.0629 - val_loss: 0.0140 - val_mae: 0.0830
# Epoch 93/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0077 - mae: 0.0619 - val_loss: 0.0134 - val_mae: 0.0807
# Epoch 94/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0078 - mae: 0.0624 - val_loss: 0.0141 - val_mae: 0.0846
# Epoch 95/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0079 - mae: 0.0625 - val_loss: 0.0133 - val_mae: 0.0802
# Epoch 96/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - mae: 0.0612 - val_loss: 0.0134 - val_mae: 0.0798
# Epoch 97/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - mae: 0.0606 - val_loss: 0.0129 - val_mae: 0.0795
# Epoch 98/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - mae: 0.0590 - val_loss: 0.0128 - val_mae: 0.0794
# Epoch 99/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0071 - mae: 0.0589 - val_loss: 0.0130 - val_mae: 0.0798
# Epoch 100/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - mae: 0.0578 - val_loss: 0.0131 - val_mae: 0.0788
# Epoch 101/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.
1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - mae: 0.0492 - val_loss: 0.0089 - val_mae: 0.0654
# Epoch 135/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - mae: 0.0498 - val_loss: 0.0096 - val_mae: 0.0685
# Epoch 136/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - mae: 0.0498 - val_loss: 0.0093 - val_mae: 0.0683
# Epoch 137/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0048 - mae: 0.0500 - val_loss: 0.0093 - val_mae: 0.0683
# Epoch 138/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0499 - val_loss: 0.0094 - val_mae: 0.0682
# Epoch 139/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - mae: 0.0506 - val_loss: 0.0101 - val_mae: 0.0722
# Epoch 140/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0522 - val_loss: 0.0102 - val_mae: 0.0714
# Epoch 141/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - mae: 0.0541 - val_loss: 0.0093 - val_mae: 0.0678
# Epoch 142/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0051 - mae: 0.0526 - val_loss: 0.0090 - val_mae: 0.0673
# Epoch 143/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0051 - mae: 0.0526 - val_loss: 0.0086 - val_mae: 0.0643
# Epoch 144/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0495 - val_loss: 0.0096 - val_mae: 0.0704
# Epoch 145/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - mae: 0.0491 - val_loss: 0.0080 - val_mae: 0.0617
# Epoch 146/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0481 - val_loss: 0.0082 - val_mae: 0.0613
# Epoch 147/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - mae: 0.0464 - val_loss: 0.0087 - val_mae: 0.0648
# Epoch 148/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - mae: 0.0451 - val_loss: 0.0085 - val_mae: 0.0628
# Epoch 149/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039 - mae: 0.0434 - val_loss: 0.0075 - val_mae: 0.0589
# Epoch 150/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0039 - mae: 0.0444 - val_loss: 0.0078 - val_mae: 0.0601
# Epoch 151/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0037 - mae: 0.0430 - val_loss: 0.0076 - val_mae: 0.0596
# Epoch 152/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mae: 0.0433 - val_loss: 0.0076 - val_mae: 0.0604
# Epoch 153/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - mae: 0.0444 - val_loss: 0.0089 - val_mae: 0.0636
# Epoch 154/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - mae: 0.0462 - val_loss: 0.0097 - val_mae: 0.0679
# Epoch 155/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0048 - mae: 0.0499 - val_loss: 0.0114 - val_mae: 0.0720
# Epoch 156/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058 - mae: 0.0529 - val_loss: 0.0120 - val_mae: 0.0750
# Epoch 157/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0056 - mae: 0.0542 - val_loss: 0.0100 - val_mae: 0.0721
# Epoch 158/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0054 - mae: 0.0547 - val_loss: 0.0082 - val_mae: 0.0629
# Epoch 159/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - mae: 0.0501 - val_loss: 0.0086 - val_mae: 0.0673
# Epoch 160/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - mae: 0.0513 - val_loss: 0.0076 - val_mae: 0.0622
# Epoch 161/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - mae: 0.0495 - val_loss: 0.0102 - val_mae: 0.0686
# Epoch 162/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - mae: 0.0506 - val_loss: 0.0070 - val_mae: 0.0587
# Epoch 163/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - mae: 0.0467 - val_loss: 0.0081 - val_mae: 0.0657
# Epoch 164/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - mae: 0.0527 - val_loss: 0.0079 - val_mae: 0.0627
# Epoch 165/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0045 - mae: 0.0489 - val_loss: 0.0103 - val_mae: 0.0697
# Epoch 166/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - mae: 0.0495 - val_loss: 0.0078 - val_mae: 0.0632
# Epoch 167/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0043 - mae: 0.0491 - val_loss: 0.0080 - val_mae: 0.0639
# Epoch 168/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.
1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.4317e-04 - mae: 0.0192 - val_loss: 0.0020 - val_mae: 0.0281
# Epoch 765/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9215e-04 - mae: 0.0186 - val_loss: 0.0019 - val_mae: 0.0276
# Epoch 766/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4644e-04 - mae: 0.0192 - val_loss: 0.0023 - val_mae: 0.0304
# Epoch 767/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0070e-04 - mae: 0.0199 - val_loss: 0.0020 - val_mae: 0.0285
# Epoch 768/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9065e-04 - mae: 0.0200 - val_loss: 0.0023 - val_mae: 0.0311
# Epoch 769/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1719e-04 - mae: 0.0206 - val_loss: 0.0021 - val_mae: 0.0286
# Epoch 770/1000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1567e-04 - mae: 0.0201 - val_loss: 0.0022 - val_mae: 0.0298
# Epoch 770: early stopping
# Restoring model weights from the end of the best epoch: 670.

# %%
model = tf.keras.models.load_model(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') if os.path.exists(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') else model

# %%
# Estrai losses da tutti i folds
train_losses = history.history['loss']
val_losses   = history.history['val_loss']

train_losses = train_losses
val_losses = val_losses

# Plot
plt.figure(figsize=(8,5))


# Training loss
plt.plot(train_losses, color='blue', label='Train Loss')
# Validation loss
plt.plot(val_losses, color='red', label='Validation Loss')


# Dettagli grafico
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.savefig(f'{exp_dir}/loss_plot.png')

# %%
def plot_first_n_series(y_pred, y_test, n_series=10, title="Confronto Serie Predette vs Reali"):
    """
    Plotta le prime n_series serie reali e predette per un confronto diretto.

    Args:
        y_pred (np.ndarray): Predizioni del modello (shape: num_samples x seq_len).
        y_test (np.ndarray): Serie reali (shape: num_samples x seq_len).
        n_series (int): Numero di serie da plottare.
        title (str): Titolo del grafico.
    """

    # Limitiamo a n_series per evitare problemi
    n = min(n_series, y_pred.shape[0], y_test.shape[0])

    plt.figure(figsize=(14, 8))

    for i in range(n):
        plt.plot(
            y_test[i], 
            linewidth=1.8, 
            alpha=0.5, 
            label=f"Reale {i+1}" if i == 0 else "",
            color = 'blue'
        )
        plt.plot(
            y_pred[i], 
            linewidth=1.2, 
            linestyle="--", 
            alpha=0.9, 
            label=f"Predetto {i+1}" if i == 0 else "",
            color = 'orange'
        )

    plt.title(title, fontsize=16)
    plt.xlabel("Time Step", fontsize=12)
    plt.ylabel("Valore", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

def plot_diagnosis_gradient(y_pred, y_test, save_path: str,  tolerance:float =0.05, max_samples_heatmap=50, scatter_sample_ratio=0.5, tol_auto = True):
    """
    Dashboard diagnostica con tolleranza AUTO-ADATTIVA alla scala dei dati.
    
    Args:
        tolerance (float): 
            - Se None: La tolleranza viene calcolata automaticamente come il 5% del range dei dati (Max-Min).
            - Se float: Valore assoluto (es. 0.5).
        tol_auto (bool): Se True, usa la tolleranza automatica basata sul range dei dati, altrimenti usa il valore manuale fornito 
        col parametro tolerance.
    """
    
    y_test_flat = y_test.flatten()
    y_pred_flat = y_pred.flatten()

    # ---------------------------------------------------------
    # AUTOMAZIONE TOLLERANZA
    # ---------------------------------------------------------
    if tol_auto:
        data_range = y_test_flat.max() - y_test_flat.min()
        # Impostiamo la tolleranza al 5% del range totale (regolabile)
        tolerance = data_range * tolerance 
        tol_label = f"Auto (5% Range: ±{tolerance:.2f})"
    else:
        tol_label = f"Manuale (±{tolerance})"

    fig, axes = plt.subplots(1, 2, figsize=(22, 8))

    # -----------------------------
    # 1. HEATMAP (SX)
    # -----------------------------
    errors = np.abs(y_test - y_pred)
    errors_subset = errors[:max_samples_heatmap]
    
    # Adattiamo anche la scala colori della heatmap alla tolleranza
    # Tutto ciò che è oltre 3 volte la tolleranza è "errore massimo" visivo
    sns.heatmap(errors_subset, cmap="plasma", ax=axes[0], 
                vmax=tolerance * 3,
                cbar_kws={'label': 'Errore Assoluto'})
    
    axes[0].set_title(f"Heatmap Errori (Primi {max_samples_heatmap} campioni)", fontsize=16)
    axes[0].set_xlabel("Time Step", fontsize=12)
    axes[0].set_ylabel("Indice Campione", fontsize=12)

    # -----------------------------
    # 2. SCATTER CON SFONDO GRADIENTE (DX)
    # -----------------------------
    
    # Campionamento dati
    if scatter_sample_ratio < 1.0:
        mask = np.random.rand(len(y_test_flat)) < scatter_sample_ratio
        sample_test = y_test_flat[mask]
        sample_pred = y_pred_flat[mask]
    else:
        sample_test = y_test_flat
        sample_pred = y_pred_flat

    # Calcolo limiti grafico
    min_val = min(y_test_flat.min(), y_pred_flat.min())
    max_val = max(y_test_flat.max(), y_pred_flat.max())
    padding = (max_val - min_val) * 0.05
    plot_min = min_val - padding
    plot_max = max_val + padding

    # --- SFONDO GRADIENTE ---
    grid_x, grid_y = np.meshgrid(
        np.linspace(plot_min, plot_max, 200),
        np.linspace(plot_min, plot_max, 200)
    )
    grid_z = np.abs(grid_y - grid_x)

    im = axes[1].imshow(
        grid_z, 
        extent=(plot_min, plot_max, plot_min, plot_max), 
        origin='lower', 
        cmap='RdYlGn_r', 
        alpha=0.4, 
        vmax=tolerance * 4, # Il rosso satura a 4x della tolleranza
        aspect='auto'
    )

    # --- PUNTI BLU ---
    axes[1].scatter(
        sample_test, 
        sample_pred, 
        alpha=0.6, 
        s=15, 
        color='royalblue', 
        edgecolors='white', 
        linewidth=0.3,
        label='Campioni'
    )

    axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

    # Metriche
    within_tol = np.mean(np.abs(y_test_flat - y_pred_flat) <= tolerance) * 100

    axes[1].set_title(
        f"Bontà delle previsioni con {tol_label}\nValori nel range di Tolleranza: {within_tol:.1f}%", 
        fontsize=16
    )
    axes[1].set_xlabel("Valore Reale", fontsize=12)
    axes[1].set_ylabel("Valore Predetto", fontsize=12)
    axes[1].set_xlim(plot_min, plot_max)
    axes[1].set_ylim(plot_min, plot_max)
    
    cbar = plt.colorbar(im, ax=axes[1], pad=0.02)
    cbar.set_label('Gravità Errore (Distanza da diagonale)')

    plt.tight_layout()
    plt.savefig(f'{exp_dir}/{save_path}.png')

# %%
y_pred = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred)
y_test_np = scaler_y.inverse_transform(y_test)

plot_diagnosis_gradient(y_pred, y_test_np, save_path='pred_quality', max_samples_heatmap=10, scatter_sample_ratio=0.7)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_1846/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

# %%
save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/TEST', prefix="pred_plot")
# Out:
# Salvo 92 plot in: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/TEST
# Plot salvati correttamente.

# %%
import json
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_and_log(y_true, y_pred, log_path="log.json"):
    # --- Metriche ---
    mae = mean_absolute_error(y_true, y_pred, multioutput="uniform_average")
    rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput="uniform_average"))

    mask = y_true != 0
    mape = float(np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100.0)

    r2 = r2_score(y_true, y_pred, multioutput="uniform_average")

    # Valore medio del test set
    v_mean = float(np.mean(y_true))

    # --- Stampa ---
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    print(f"Test MAPE: {mape:.2f}%")
    print(f"Test R2: {r2:.4f}")
    print(f"Valore medio del test set: {v_mean:.4f}")

    # --- Salvataggio log ---
    log_data = {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2,
        "test_mean_value": v_mean
    }

    with open(log_path, "w") as f:
        json.dump(log_data, f, indent=4)

    print(f"\nLog salvato in: {log_path}")
evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/evaluation_log.json")
# Impostazioni pandas per visualizzare tutti i dati
# Out:
# Test MAE: 0.2586
# Test RMSE: 0.4662
# Test MAPE: 0.69%
# Test R2: 0.9965
# Valore medio del test set: 41.6166
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/evaluation_log.json

# %% [markdown]
# # globale e federato

# %%
fed = tf.keras.models.load_model('/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Arpat.keras')

model  = [fed]
model_name = ["federated"]

# %%
checkpoint_filepath = f'{exp_dir}/model/{sensor_name}_fed_model.keras'

# 2. Crea l'istanza della callback
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False, 
    verbose=1
)

# %%
for model, name in zip(model, model_name):
    y_pred = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred)
    y_test_np = scaler_y.inverse_transform(y_test)

    print(f"--- {name} ---")
    #plot_diagnosis_gradient(y_pred, y_test_np, max_samples_heatmap=10, scatter_sample_ratio=0.7)
    evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_evaluation_log.json")
    save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}/TEST', prefix="pred_plot")

    print("\n")
    if name == 'federated':
        model.fit(X_train, y_train, epochs=1000, batch_size=64, callbacks=[model_checkpoint_callback], validation_split=0.2)
        model.load_weights(checkpoint_filepath)
        y_pred = model.predict(X_test)
        y_pred = scaler_y.inverse_transform(y_pred)
        print(f"--- {name} after local fine-tuning ---")
        plot_diagnosis_gradient(y_pred, y_test_np, save_path=f"{name}_pred_quality", max_samples_heatmap=10, scatter_sample_ratio=0.7)
        save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}_fd/TEST', prefix="pred_plot")
        evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_fd_evaluation_log.json")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# --- federated ---
# Test MAE: 3.1966
# Test RMSE: 4.0868
# Test MAPE: 8.67%
# Test R2: 0.7379
# Valore medio del test set: 41.6166
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/federated_evaluation_log.json
# Salvo 92 plot in: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/federated/TEST
# Plot salvati correttamente.
#
#
# Epoch 1/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 1s 327ms/step - loss: 0.2515 - mae: 0.4044 - mse: 0.2515
# Epoch 1: val_loss improved from None to 0.12231, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1622 - mae: 0.3087 - mse: 0.1622 - val_loss: 0.1223 - val_mae: 0.2635 - val_mse: 0.1223
# Epoch 2/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1219 - mae: 0.2608 - mse: 0.1219
# Epoch 2: val_loss improved from 0.12231 to 0.07272, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0962 - mae: 0.2328 - mse: 0.0962 - val_loss: 0.0727 - val_mae: 0.2059 - val_mse: 0.0727
# Epoch 3/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0773 - mae: 0.2094 - mse: 0.0773
# Epoch 3: val_loss improved from 0.07272 to 0.04732, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0629 - mae: 0.1918 - mse: 0.0629 - val_loss: 0.0473 - val_mae: 0.1660 - val_mse: 0.0473
# Epoch 4/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0408 - mae: 0.1588 - mse: 0.0408
# Epoch 4: val_loss improved from 0.04732 to 0.03453, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0387 - mae: 0.1514 - mse: 0.0387 - val_loss: 0.0345 - val_mae: 0.1419 - val_mse: 0.0345
# Epoch 5/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0335 - mae: 0.1409 - mse: 0.0335
# Epoch 5: val_loss improved from 0.03453 to 0.02880, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0278 - mae: 0.1279 - mse: 0.0278 - val_loss: 0.0288 - val_mae: 0.1305 - val_mse: 0.0288
# Epoch 6/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0233 - mae: 0.1176 - mse: 0.0233
# Epoch 6: val_loss improved from 0.02880 to 0.01924, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0217 - mae: 0.1116 - mse: 0.0217 - val_loss: 0.0192 - val_mae: 0.1042 - val_mse: 0.0192
# Epoch 7/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0172 - mae: 0.0989 - mse: 0.0172
# Epoch 7: val_loss improved from 0.01924 to 0.01630, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0167 - mae: 0.0977 - mse: 0.0167 - val_loss: 0.0163 - val_mae: 0.0962 - val_mse: 0.0163
# Epoch 8/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0136 - mae: 0.0897 - mse: 0.0136
# Epoch 8: val_loss improved from 0.01630 to 0.01388, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0122 - mae: 0.0839 - mse: 0.0122 - val_loss: 0.0139 - val_mae: 0.0887 - val_mse: 0.0139
# Epoch 9/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0087 - mae: 0.0712 - mse: 0.0087
# Epoch 9: val_loss improved from 0.01388 to 0.01107, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0098 - mae: 0.0744 - mse: 0.0098 - val_loss: 0.0111 - val_mae: 0.0790 - val_mse: 0.0111
# Epoch 10/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093 - mae: 0.0720 - mse: 0.0093
# Epoch 10: val_loss improved from 0.01107 to 0.00948, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - mae: 0.0662 - mse: 0.0079 - val_loss: 0.0095 - val_mae: 0.0729 - val_mse: 0.0095
# Epoch 11/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - mae: 0.0612 - mse: 0.0069
# Epoch 11: val_loss improved from 0.00948 to 0.00788, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - mae: 0.0604 - mse: 0.0067 - val_loss: 0.0079 - val_mae: 0.0643 - val_mse: 0.0079
# Epoch 12/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - mae: 0.0510 - mse: 0.0048
# Epoch 12: val_loss improved from 0.00788 to 0.00721, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0057 - mae: 0.0557 - mse: 0.0057 - val_loss: 0.0072 - val_mae: 0.0622 - val_mse: 0.0072
# Epoch 13/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - mae: 0.0519 - mse: 0.0051
# Epoch 13: val_loss improved from 0.00721 to 0.00660, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - mae: 0.0509 - mse: 0.0049 - val_loss: 0.0066 - val_mae: 0.0585 - val_mse: 0.0066
# Epoch 14/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043 - mae: 0.0475 - mse: 0.0043
# Epoch 14: val_loss improved from 0.00660 to 0.00567, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - mae: 0.0486 - mse: 0.0045 - val_loss: 0.0057 - val_mae: 0.0543 - val_mse: 0.0057
# Epoch 15/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0423 - mse: 0.0034
# Epoch 15: val_loss improved from 0.00567 to 0.00519, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - mae: 0.0458 - mse: 0.0040 - val_loss: 0.0052 - val_mae: 0.0511 - val_mse: 0.0052
# Epoch 16/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - mae: 0.0387 - mse: 0.0029
# Epoch 16: val_loss improved from 0.00519 to 0.00498, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0428 - mse: 0.0035 - val_loss: 0.0050 - val_mae: 0.0495 - val_mse: 0.0050
# Epoch 17/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - mae: 0.0389 - mse: 0.0029
# Epoch 17: val_loss improved from 0.00498 to 0.00467, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0419 - mse: 0.0034 - val_loss: 0.0047 - val_mae: 0.0486 - val_mse: 0.0047
# Epoch 18/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032 - mae: 0.0406 - mse: 0.0032
# Epoch 18: val_loss improved from 0.00467 to 0.00435, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - mae: 0.0406 - mse: 0.0032 - val_loss: 0.0043 - val_mae: 0.0465 - val_mse: 0.0043
# Epoch 19/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - mae: 0.0376 - mse: 0.0029
# Epoch 19: val_loss improved from 0.00435 to 0.00427, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - mae: 0.0380 - mse: 0.0029 - val_loss: 0.0043 - val_mae: 0.0456 - val_mse: 0.0043
# Epoch 20/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0386 - mse: 0.0028
# Epoch 20: val_loss improved from 0.00427 to 0.00382, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - mae: 0.0363 - mse: 0.0026 - val_loss: 0.0038 - val_mae: 0.0433 - val_mse: 0.0038
# Epoch 21/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - mae: 0.0349 - mse: 0.0026
# Epoch 21: val_loss improved from 0.00382 to 0.00372, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024 - mae: 0.0340 - mse: 0.0024 - val_loss: 0.0037 - val_mae: 0.0420 - val_mse: 0.0037
# Epoch 22/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022 - mae: 0.0323 - mse: 0.0022
# Epoch 22: val_loss improved from 0.00372 to 0.00361, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - mae: 0.0334 - mse: 0.0023 - val_loss: 0.0036 - val_mae: 0.0413 - val_mse: 0.0036
# Epoch 23/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022 - mae: 0.0322 - mse: 0.0022
# Epoch 23: val_loss improved from 0.00361 to 0.00335, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - mae: 0.0316 - mse: 0.0021 - val_loss: 0.0033 - val_mae: 0.0393 - val_mse: 0.0033
# Epoch 24/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - mae: 0.0310 - mse: 0.0021
# Epoch 24: val_loss improved from 0.00335 to 0.00327, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019 - mae: 0.0301 - mse: 0.0019 - val_loss: 0.0033 - val_mae: 0.0383 - val_mse: 0.0033
# Epoch 25/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0020 - mae: 0.0309 - mse: 0.0020
# Epoch 25: val_loss improved from 0.00327 to 0.00315, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mae: 0.0290 - mse: 0.0018 - val_loss: 0.0031 - val_mae: 0.0376 - val_mse: 0.0031
# Epoch 26/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - mae: 0.0276 - mse: 0.0016
# Epoch 26: val_loss improved from 0.00315 to 0.00303, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mae: 0.0285 - mse: 0.0018 - val_loss: 0.0030 - val_mae: 0.0368 - val_mse: 0.0030
# Epoch 27/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mae: 0.0279 - mse: 0.0017
# Epoch 27: val_loss improved from 0.00303 to 0.00292, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - mae: 0.0274 - mse: 0.0017 - val_loss: 0.0029 - val_mae: 0.0361 - val_mse: 0.0029
# Epoch 28/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0229 - mse: 0.0011
# Epoch 28: val_loss improved from 0.00292 to 0.00279, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016 - mae: 0.0269 - mse: 0.0016 - val_loss: 0.0028 - val_mae: 0.0350 - val_mse: 0.0028
# Epoch 29/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mae: 0.0234 - mse: 0.0012
# Epoch 29: val_loss did not improve from 0.00279
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016 - mae: 0.0265 - mse: 0.0016 - val_loss: 0.0028 - val_mae: 0.0350 - val_mse: 0.0028
# Epoch 30/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mae: 0.0277 - mse: 0.0018
# Epoch 30: val_loss improved from 0.00279 to 0.00271, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - mae: 0.0258 - mse: 0.0015 - val_loss: 0.0027 - val_mae: 0.0342 - val_mse: 0.0027
# Epoch 31/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mae: 0.0245 - mse: 0.0012
# Epoch 31: val_loss did not improve from 0.00271
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mae: 0.0254 - mse: 0.0015 - val_loss: 0.0027 - val_mae: 0.0342 - val_mse: 0.0027
# Epoch 32/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0254 - mse: 0.0013
# Epoch 32: val_loss improved from 0.00271 to 0.00255, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mae: 0.0249 - mse: 0.0014 - val_loss: 0.0026 - val_mae: 0.0332 - val_mse: 0.0026
# Epoch 33/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014 - mae: 0.0247 - mse: 0.0014
# Epoch 33: val_loss did not improve from 0.00255
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mae: 0.0241 - mse: 0.0013 - val_loss: 0.0026 - val_mae: 0.0328 - val_mse: 0.0026
# Epoch 34/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017 - mae: 0.0264 - mse: 0.0017
# Epoch 34: val_loss improved from 0.00255 to 0.00248, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - mae: 0.0236 - mse: 0.0013 - val_loss: 0.0025 - val_mae: 0.0323 - val_mse: 0.0025
# Epoch 35/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - mae: 0.0215 - mse: 0.0010
# Epoch 35: val_loss improved from 0.00248 to 0.00245, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - mae: 0.0234 - mse: 0.0013 - val_loss: 0.0024 - val_mae: 0.0318 - val_mse: 0.0024
# Epoch 36/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1495e-04 - mae: 0.0203 - mse: 9.1495e-04
# Epoch 36: val_loss improved from 0.00245 to 0.00237, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mae: 0.0229 - mse: 0.0012 - val_loss: 0.0024 - val_mae: 0.0315 - val_mse: 0.0024
# Epoch 37/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mae: 0.0220 - mse: 0.0012
# Epoch 37: val_loss did not improve from 0.00237
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0227 - mse: 0.0012 - val_loss: 0.0024 - val_mae: 0.0314 - val_mse: 0.0024
# Epoch 38/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - mae: 0.0219 - mse: 0.0010
# Epoch 38: val_loss improved from 0.00237 to 0.00228, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0222 - mse: 0.0011 - val_loss: 0.0023 - val_mae: 0.0308 - val_mse: 0.0023
# Epoch 39/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - mae: 0.0217 - mse: 0.0011
# Epoch 39: val_loss improved from 0.00228 to 0.00225, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - mae: 0.0219 - mse: 0.0011 - val_loss: 0.0023 - val_mae: 0.0305 - val_mse: 0.0023
# Epoch 40/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8123e-04 - mae: 0.0205 - mse: 9.8123e-04
# Epoch 40: val_loss improved from 0.00225 to 0.00225, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0214 - mse: 0.0011 - val_loss: 0.0022 - val_mae: 0.0303 - val_mse: 0.0022
# Epoch 41/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010 - mae: 0.0207 - mse: 0.0010
# Epoch 41: val_loss improved from 0.00225 to 0.00219, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - mae: 0.0217 - mse: 0.0011 - val_loss: 0.0022 - val_mae: 0.0302 - val_mse: 0.0022
# Epoch 42/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0010 - mae: 0.0209 - mse: 0.0010
# Epoch 42: val_loss improved from 0.00219 to 0.00219, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - mae: 0.0214 - mse: 0.0011 - val_loss: 0.0022 - val_mae: 0.0296 - val_mse: 0.0022
# Epoch 43/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - mae: 0.0224 - mse: 0.0011
# Epoch 43: val_loss improved from 0.00219 to 0.00215, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0010 - mae: 0.0211 - mse: 0.0010 - val_loss: 0.0021 - val_mae: 0.0294 - val_mse: 0.0021
# Epoch 44/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.6663e-04 - mae: 0.0200 - mse: 8.6663e-04
# Epoch 44: val_loss improved from 0.00215 to 0.00209, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8895e-04 - mae: 0.0207 - mse: 9.8895e-04 - val_loss: 0.0021 - val_mae: 0.0291 - val_mse: 0.0021
# Epoch 45/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5418e-04 - mae: 0.0167 - mse: 5.5418e-04
# Epoch 45: val_loss did not improve from 0.00209
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8298e-04 - mae: 0.0206 - mse: 9.8298e-04 - val_loss: 0.0021 - val_mae: 0.0288 - val_mse: 0.0021
# Epoch 46/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - mae: 0.0239 - mse: 0.0014
# Epoch 46: val_loss improved from 0.00209 to 0.00206, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3256e-04 - mae: 0.0202 - mse: 9.3256e-04 - val_loss: 0.0021 - val_mae: 0.0288 - val_mse: 0.0021
# Epoch 47/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8011e-04 - mae: 0.0200 - mse: 8.8011e-04
# Epoch 47: val_loss improved from 0.00206 to 0.00201, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3858e-04 - mae: 0.0202 - mse: 9.3858e-04 - val_loss: 0.0020 - val_mae: 0.0281 - val_mse: 0.0020
# Epoch 48/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0210 - mse: 0.0011
# Epoch 48: val_loss did not improve from 0.00201
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0356e-04 - mae: 0.0198 - mse: 9.0356e-04 - val_loss: 0.0021 - val_mae: 0.0281 - val_mse: 0.0021
# Epoch 49/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0214 - mse: 0.0011
# Epoch 49: val_loss improved from 0.00201 to 0.00194, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9040e-04 - mae: 0.0196 - mse: 8.9040e-04 - val_loss: 0.0019 - val_mae: 0.0274 - val_mse: 0.0019
# Epoch 50/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9088e-04 - mae: 0.0209 - mse: 9.9088e-04
# Epoch 50: val_loss did not improve from 0.00194
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6784e-04 - mae: 0.0195 - mse: 8.6784e-04 - val_loss: 0.0020 - val_mae: 0.0281 - val_mse: 0.0020
# Epoch 51/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6722e-04 - mae: 0.0200 - mse: 8.6722e-04
# Epoch 51: val_loss did not improve from 0.00194
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8593e-04 - mae: 0.0197 - mse: 8.8593e-04 - val_loss: 0.0020 - val_mae: 0.0279 - val_mse: 0.0020
# Epoch 52/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3009e-04 - mae: 0.0204 - mse: 9.3009e-04
# Epoch 52: val_loss improved from 0.00194 to 0.00189, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3680e-04 - mae: 0.0186 - mse: 8.3680e-04 - val_loss: 0.0019 - val_mae: 0.0266 - val_mse: 0.0019
# Epoch 53/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3870e-04 - mae: 0.0196 - mse: 9.3870e-04
# Epoch 53: val_loss did not improve from 0.00189
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1023e-04 - mae: 0.0187 - mse: 8.1023e-04 - val_loss: 0.0019 - val_mae: 0.0266 - val_mse: 0.0019
# Epoch 54/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5649e-04 - mae: 0.0176 - mse: 6.5649e-04
# Epoch 54: val_loss improved from 0.00189 to 0.00187, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9756e-04 - mae: 0.0186 - mse: 7.9756e-04 - val_loss: 0.0019 - val_mae: 0.0266 - val_mse: 0.0019
# Epoch 55/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9252e-04 - mae: 0.0174 - mse: 6.9252e-04
# Epoch 55: val_loss improved from 0.00187 to 0.00186, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9793e-04 - mae: 0.0184 - mse: 7.9793e-04 - val_loss: 0.0019 - val_mae: 0.0262 - val_mse: 0.0019
# Epoch 56/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010 - mae: 0.0200 - mse: 0.0010
# Epoch 56: val_loss did not improve from 0.00186
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9975e-04 - mae: 0.0185 - mse: 7.9975e-04 - val_loss: 0.0019 - val_mae: 0.0268 - val_mse: 0.0019
# Epoch 57/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8519e-04 - mae: 0.0204 - mse: 9.8519e-04
# Epoch 57: val_loss improved from 0.00186 to 0.00183, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9130e-04 - mae: 0.0187 - mse: 7.9130e-04 - val_loss: 0.0018 - val_mae: 0.0261 - val_mse: 0.0018
# Epoch 58/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2935e-04 - mae: 0.0191 - mse: 8.2935e-04
# Epoch 58: val_loss did not improve from 0.00183
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6566e-04 - mae: 0.0183 - mse: 7.6566e-04 - val_loss: 0.0019 - val_mae: 0.0267 - val_mse: 0.0019
# Epoch 59/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7886e-04 - mae: 0.0179 - mse: 6.7886e-04
# Epoch 59: val_loss did not improve from 0.00183
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9750e-04 - mae: 0.0189 - mse: 7.9750e-04 - val_loss: 0.0019 - val_mae: 0.0268 - val_mse: 0.0019
# Epoch 60/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1093e-04 - mae: 0.0183 - mse: 7.1093e-04
# Epoch 60: val_loss did not improve from 0.00183
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.0382e-04 - mae: 0.0191 - mse: 8.0382e-04 - val_loss: 0.0018 - val_mae: 0.0264 - val_mse: 0.0018
# Epoch 61/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4173e-04 - mae: 0.0188 - mse: 7.4173e-04
# Epoch 61: val_loss improved from 0.00183 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8715e-04 - mae: 0.0190 - mse: 7.8715e-04 - val_loss: 0.0018 - val_mae: 0.0267 - val_mse: 0.0018
# Epoch 62/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8296e-04 - mae: 0.0186 - mse: 6.8296e-04
# Epoch 62: val_loss did not improve from 0.00180
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7815e-04 - mae: 0.0190 - mse: 7.7815e-04 - val_loss: 0.0019 - val_mae: 0.0270 - val_mse: 0.0019
# Epoch 63/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4558e-04 - mae: 0.0169 - mse: 5.4558e-04
# Epoch 63: val_loss improved from 0.00180 to 0.00176, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5204e-04 - mae: 0.0185 - mse: 7.5204e-04 - val_loss: 0.0018 - val_mae: 0.0258 - val_mse: 0.0018
# Epoch 64/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3733e-04 - mae: 0.0162 - mse: 5.3733e-04
# Epoch 64: val_loss did not improve from 0.00176
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1461e-04 - mae: 0.0181 - mse: 7.1461e-04 - val_loss: 0.0018 - val_mae: 0.0263 - val_mse: 0.0018
# Epoch 65/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7166e-04 - mae: 0.0183 - mse: 7.7166e-04
# Epoch 65: val_loss did not improve from 0.00176
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9838e-04 - mae: 0.0176 - mse: 6.9838e-04 - val_loss: 0.0018 - val_mae: 0.0254 - val_mse: 0.0018
# Epoch 66/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1968e-04 - mae: 0.0177 - mse: 7.1968e-04
# Epoch 66: val_loss improved from 0.00176 to 0.00174, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8420e-04 - mae: 0.0174 - mse: 6.8420e-04 - val_loss: 0.0017 - val_mae: 0.0254 - val_mse: 0.0017
# Epoch 67/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8198e-04 - mae: 0.0200 - mse: 9.8198e-04
# Epoch 67: val_loss did not improve from 0.00174
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3205e-04 - mae: 0.0182 - mse: 7.3205e-04 - val_loss: 0.0018 - val_mae: 0.0255 - val_mse: 0.0018
# Epoch 68/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4969e-04 - mae: 0.0198 - mse: 8.4969e-04
# Epoch 68: val_loss improved from 0.00174 to 0.00172, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5852e-04 - mae: 0.0174 - mse: 6.5852e-04 - val_loss: 0.0017 - val_mae: 0.0246 - val_mse: 0.0017
# Epoch 69/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0392e-04 - mae: 0.0146 - mse: 5.0392e-04
# Epoch 69: val_loss improved from 0.00172 to 0.00172, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5331e-04 - mae: 0.0170 - mse: 6.5331e-04 - val_loss: 0.0017 - val_mae: 0.0246 - val_mse: 0.0017
# Epoch 70/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4596e-04 - mae: 0.0150 - mse: 4.4596e-04
# Epoch 70: val_loss improved from 0.00172 to 0.00171, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4179e-04 - mae: 0.0169 - mse: 6.4179e-04 - val_loss: 0.0017 - val_mae: 0.0251 - val_mse: 0.0017
# Epoch 71/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6512e-04 - mae: 0.0180 - mse: 7.6512e-04
# Epoch 71: val_loss did not improve from 0.00171
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5507e-04 - mae: 0.0172 - mse: 6.5507e-04 - val_loss: 0.0017 - val_mae: 0.0249 - val_mse: 0.0017
# Epoch 72/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5159e-04 - mae: 0.0188 - mse: 7.5159e-04
# Epoch 72: val_loss improved from 0.00171 to 0.00164, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6940e-04 - mae: 0.0175 - mse: 6.6940e-04 - val_loss: 0.0016 - val_mae: 0.0248 - val_mse: 0.0016
# Epoch 73/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1227e-04 - mae: 0.0180 - mse: 7.1227e-04
# Epoch 73: val_loss did not improve from 0.00164
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5315e-04 - mae: 0.0176 - mse: 6.5315e-04 - val_loss: 0.0019 - val_mae: 0.0258 - val_mse: 0.0019
# Epoch 74/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4755e-04 - mae: 0.0169 - mse: 5.4755e-04
# Epoch 74: val_loss improved from 0.00164 to 0.00156, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.2229e-04 - mae: 0.0171 - mse: 6.2229e-04 - val_loss: 0.0016 - val_mae: 0.0243 - val_mse: 0.0016
# Epoch 75/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.4269e-04 - mae: 0.0176 - mse: 6.4269e-04
# Epoch 75: val_loss did not improve from 0.00156
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1313e-04 - mae: 0.0167 - mse: 6.1313e-04 - val_loss: 0.0018 - val_mae: 0.0242 - val_mse: 0.0018
# Epoch 76/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4470e-04 - mae: 0.0165 - mse: 6.4470e-04
# Epoch 76: val_loss did not improve from 0.00156
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8185e-04 - mae: 0.0162 - mse: 5.8185e-04 - val_loss: 0.0016 - val_mae: 0.0235 - val_mse: 0.0016
# Epoch 77/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6369e-04 - mae: 0.0144 - mse: 4.6369e-04
# Epoch 77: val_loss did not improve from 0.00156
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8858e-04 - mae: 0.0162 - mse: 5.8858e-04 - val_loss: 0.0016 - val_mae: 0.0235 - val_mse: 0.0016
# Epoch 78/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2908e-04 - mae: 0.0172 - mse: 6.2908e-04
# Epoch 78: val_loss did not improve from 0.00156
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0992e-04 - mae: 0.0167 - mse: 6.0992e-04 - val_loss: 0.0016 - val_mae: 0.0243 - val_mse: 0.0016
# Epoch 79/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4230e-04 - mae: 0.0178 - mse: 6.4230e-04
# Epoch 79: val_loss did not improve from 0.00156
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8885e-04 - mae: 0.0166 - mse: 5.8885e-04 - val_loss: 0.0017 - val_mae: 0.0240 - val_mse: 0.0017
# Epoch 80/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1211e-04 - mae: 0.0153 - mse: 5.1211e-04
# Epoch 80: val_loss did not improve from 0.00156
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6833e-04 - mae: 0.0162 - mse: 5.6833e-04 - val_loss: 0.0016 - val_mae: 0.0237 - val_mse: 0.0016
# Epoch 81/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6067e-04 - mae: 0.0168 - mse: 5.6067e-04
# Epoch 81: val_loss did not improve from 0.00156
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4538e-04 - mae: 0.0158 - mse: 5.4538e-04 - val_loss: 0.0016 - val_mae: 0.0234 - val_mse: 0.0016
# Epoch 82/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9276e-04 - mae: 0.0136 - mse: 3.9276e-04
# Epoch 82: val_loss did not improve from 0.00156
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3112e-04 - mae: 0.0154 - mse: 5.3112e-04 - val_loss: 0.0016 - val_mae: 0.0232 - val_mse: 0.0016
# Epoch 83/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5636e-04 - mae: 0.0160 - mse: 5.5636e-04
# Epoch 83: val_loss did not improve from 0.00156
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2081e-04 - mae: 0.0152 - mse: 5.2081e-04 - val_loss: 0.0016 - val_mae: 0.0230 - val_mse: 0.0016
# Epoch 84/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9768e-04 - mae: 0.0162 - mse: 5.9768e-04
# Epoch 84: val_loss did not improve from 0.00156
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1129e-04 - mae: 0.0150 - mse: 5.1129e-04 - val_loss: 0.0016 - val_mae: 0.0227 - val_mse: 0.0016
# Epoch 85/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3265e-04 - mae: 0.0151 - mse: 5.3265e-04
# Epoch 85: val_loss did not improve from 0.00156
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0894e-04 - mae: 0.0149 - mse: 5.0894e-04 - val_loss: 0.0016 - val_mae: 0.0227 - val_mse: 0.0016
# Epoch 86/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7388e-04 - mae: 0.0146 - mse: 4.7388e-04
# Epoch 86: val_loss improved from 0.00156 to 0.00152, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0312e-04 - mae: 0.0148 - mse: 5.0312e-04 - val_loss: 0.0015 - val_mae: 0.0221 - val_mse: 0.0015
# Epoch 87/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3947e-04 - mae: 0.0149 - mse: 6.3947e-04
# Epoch 87: val_loss did not improve from 0.00152
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8320e-04 - mae: 0.0146 - mse: 4.8320e-04 - val_loss: 0.0016 - val_mae: 0.0220 - val_mse: 0.0016
# Epoch 88/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5162e-04 - mae: 0.0144 - mse: 4.5162e-04
# Epoch 88: val_loss did not improve from 0.00152
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8040e-04 - mae: 0.0143 - mse: 4.8040e-04 - val_loss: 0.0015 - val_mae: 0.0222 - val_mse: 0.0015
# Epoch 89/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8461e-04 - mae: 0.0133 - mse: 3.8461e-04
# Epoch 89: val_loss did not improve from 0.00152
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7514e-04 - mae: 0.0143 - mse: 4.7514e-04 - val_loss: 0.0016 - val_mae: 0.0221 - val_mse: 0.0016
# Epoch 90/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3545e-04 - mae: 0.0142 - mse: 4.3545e-04
# Epoch 90: val_loss did not improve from 0.00152
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7876e-04 - mae: 0.0144 - mse: 4.7876e-04 - val_loss: 0.0015 - val_mae: 0.0223 - val_mse: 0.0015
# Epoch 91/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7427e-04 - mae: 0.0150 - mse: 4.7427e-04
# Epoch 91: val_loss did not improve from 0.00152
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6248e-04 - mae: 0.0143 - mse: 4.6248e-04 - val_loss: 0.0016 - val_mae: 0.0220 - val_mse: 0.0016
# Epoch 92/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1374e-04 - mae: 0.0104 - mse: 2.1374e-04
# Epoch 92: val_loss improved from 0.00152 to 0.00151, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5270e-04 - mae: 0.0140 - mse: 4.5270e-04 - val_loss: 0.0015 - val_mae: 0.0214 - val_mse: 0.0015
# Epoch 93/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5140e-04 - mae: 0.0147 - mse: 5.5140e-04
# Epoch 93: val_loss did not improve from 0.00151
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6901e-04 - mae: 0.0144 - mse: 4.6901e-04 - val_loss: 0.0015 - val_mae: 0.0216 - val_mse: 0.0015
# Epoch 94/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4012e-04 - mae: 0.0130 - mse: 4.4012e-04
# Epoch 94: val_loss did not improve from 0.00151
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7440e-04 - mae: 0.0145 - mse: 4.7440e-04 - val_loss: 0.0016 - val_mae: 0.0228 - val_mse: 0.0016
# Epoch 95/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5333e-04 - mae: 0.0162 - mse: 6.5333e-04
# Epoch 95: val_loss did not improve from 0.00151
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6317e-04 - mae: 0.0144 - mse: 4.6317e-04 - val_loss: 0.0015 - val_mae: 0.0219 - val_mse: 0.0015
# Epoch 96/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2256e-04 - mae: 0.0140 - mse: 4.2256e-04
# Epoch 96: val_loss did not improve from 0.00151
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4247e-04 - mae: 0.0140 - mse: 4.4247e-04 - val_loss: 0.0016 - val_mae: 0.0219 - val_mse: 0.0016
# Epoch 97/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9389e-04 - mae: 0.0150 - mse: 4.9389e-04
# Epoch 97: val_loss did not improve from 0.00151
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2992e-04 - mae: 0.0138 - mse: 4.2992e-04 - val_loss: 0.0015 - val_mae: 0.0213 - val_mse: 0.0015
# Epoch 98/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9305e-04 - mae: 0.0132 - mse: 3.9305e-04
# Epoch 98: val_loss improved from 0.00151 to 0.00149, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1668e-04 - mae: 0.0136 - mse: 4.1668e-04 - val_loss: 0.0015 - val_mae: 0.0210 - val_mse: 0.0015
# Epoch 99/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1803e-04 - mae: 0.0122 - mse: 3.1803e-04
# Epoch 99: val_loss did not improve from 0.00149
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2099e-04 - mae: 0.0136 - mse: 4.2099e-04 - val_loss: 0.0015 - val_mae: 0.0211 - val_mse: 0.0015
# Epoch 100/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8314e-04 - mae: 0.0132 - mse: 3.8314e-04
# Epoch 100: val_loss did not improve from 0.00149
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1508e-04 - mae: 0.0134 - mse: 4.1508e-04 - val_loss: 0.0015 - val_mae: 0.0209 - val_mse: 0.0015
# Epoch 101/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4446e-04 - mae: 0.0134 - mse: 4.4446e-04
# Epoch 101: val_loss did not improve from 0.00149
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1239e-04 - mae: 0.0134 - mse: 4.1239e-04 - val_loss: 0.0015 - val_mae: 0.0208 - val_mse: 0.0015
# Epoch 102/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9770e-04 - mae: 0.0136 - mse: 4.9770e-04
# Epoch 102: val_loss did not improve from 0.00149
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1681e-04 - mae: 0.0133 - mse: 4.1681e-04 - val_loss: 0.0016 - val_mae: 0.0218 - val_mse: 0.0016
# Epoch 103/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1566e-04 - mae: 0.0139 - mse: 4.1566e-04
# Epoch 103: val_loss did not improve from 0.00149
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4509e-04 - mae: 0.0139 - mse: 4.4509e-04 - val_loss: 0.0016 - val_mae: 0.0223 - val_mse: 0.0016
# Epoch 104/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7401e-04 - mae: 0.0145 - mse: 4.7401e-04
# Epoch 104: val_loss did not improve from 0.00149
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8441e-04 - mae: 0.0150 - mse: 4.8441e-04 - val_loss: 0.0016 - val_mae: 0.0231 - val_mse: 0.0016
# Epoch 105/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3504e-04 - mae: 0.0151 - mse: 5.3504e-04
# Epoch 105: val_loss did not improve from 0.00149
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4650e-04 - mae: 0.0145 - mse: 4.4650e-04 - val_loss: 0.0015 - val_mae: 0.0214 - val_mse: 0.0015
# Epoch 106/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3691e-04 - mae: 0.0138 - mse: 4.3691e-04
# Epoch 106: val_loss improved from 0.00149 to 0.00148, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5130e-04 - mae: 0.0143 - mse: 4.5130e-04 - val_loss: 0.0015 - val_mae: 0.0217 - val_mse: 0.0015
# Epoch 107/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2960e-04 - mae: 0.0133 - mse: 3.2960e-04
# Epoch 107: val_loss did not improve from 0.00148
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2839e-04 - mae: 0.0140 - mse: 4.2839e-04 - val_loss: 0.0017 - val_mae: 0.0219 - val_mse: 0.0017
# Epoch 108/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3049e-04 - mae: 0.0144 - mse: 4.3049e-04
# Epoch 108: val_loss improved from 0.00148 to 0.00146, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3169e-04 - mae: 0.0141 - mse: 4.3169e-04 - val_loss: 0.0015 - val_mae: 0.0213 - val_mse: 0.0015
# Epoch 109/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0291e-04 - mae: 0.0143 - mse: 5.0291e-04
# Epoch 109: val_loss did not improve from 0.00146
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0990e-04 - mae: 0.0137 - mse: 4.0990e-04 - val_loss: 0.0017 - val_mae: 0.0231 - val_mse: 0.0017
# Epoch 110/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8985e-04 - mae: 0.0157 - mse: 5.8985e-04
# Epoch 110: val_loss did not improve from 0.00146
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1638e-04 - mae: 0.0136 - mse: 4.1638e-04 - val_loss: 0.0015 - val_mae: 0.0212 - val_mse: 0.0015
# Epoch 111/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8869e-04 - mae: 0.0119 - mse: 2.8869e-04
# Epoch 111: val_loss did not improve from 0.00146
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0584e-04 - mae: 0.0136 - mse: 4.0584e-04 - val_loss: 0.0015 - val_mae: 0.0216 - val_mse: 0.0015
# Epoch 112/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5959e-04 - mae: 0.0162 - mse: 6.5959e-04
# Epoch 112: val_loss did not improve from 0.00146
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0195e-04 - mae: 0.0135 - mse: 4.0195e-04 - val_loss: 0.0015 - val_mae: 0.0207 - val_mse: 0.0015
# Epoch 113/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1326e-04 - mae: 0.0120 - mse: 3.1326e-04
# Epoch 113: val_loss did not improve from 0.00146
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8121e-04 - mae: 0.0128 - mse: 3.8121e-04 - val_loss: 0.0015 - val_mae: 0.0207 - val_mse: 0.0015
# Epoch 114/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1013e-04 - mae: 0.0131 - mse: 4.1013e-04
# Epoch 114: val_loss did not improve from 0.00146
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7307e-04 - mae: 0.0126 - mse: 3.7307e-04 - val_loss: 0.0016 - val_mae: 0.0207 - val_mse: 0.0016
# Epoch 115/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1969e-04 - mae: 0.0124 - mse: 4.1969e-04
# Epoch 115: val_loss improved from 0.00146 to 0.00143, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6874e-04 - mae: 0.0126 - mse: 3.6874e-04 - val_loss: 0.0014 - val_mae: 0.0200 - val_mse: 0.0014
# Epoch 116/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5151e-04 - mae: 0.0126 - mse: 3.5151e-04
# Epoch 116: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6055e-04 - mae: 0.0126 - mse: 3.6055e-04 - val_loss: 0.0015 - val_mae: 0.0203 - val_mse: 0.0015
# Epoch 117/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5050e-04 - mae: 0.0121 - mse: 3.5050e-04
# Epoch 117: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5098e-04 - mae: 0.0123 - mse: 3.5098e-04 - val_loss: 0.0015 - val_mae: 0.0202 - val_mse: 0.0015
# Epoch 118/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4504e-04 - mae: 0.0125 - mse: 3.4504e-04
# Epoch 118: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4834e-04 - mae: 0.0121 - mse: 3.4834e-04 - val_loss: 0.0015 - val_mae: 0.0200 - val_mse: 0.0015
# Epoch 119/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5013e-04 - mae: 0.0139 - mse: 4.5013e-04
# Epoch 119: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4529e-04 - mae: 0.0122 - mse: 3.4529e-04 - val_loss: 0.0015 - val_mae: 0.0205 - val_mse: 0.0015
# Epoch 120/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1133e-04 - mae: 0.0125 - mse: 3.1133e-04
# Epoch 120: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6254e-04 - mae: 0.0125 - mse: 3.6254e-04 - val_loss: 0.0015 - val_mae: 0.0207 - val_mse: 0.0015
# Epoch 121/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4968e-04 - mae: 0.0126 - mse: 3.4968e-04
# Epoch 121: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5450e-04 - mae: 0.0126 - mse: 3.5450e-04 - val_loss: 0.0015 - val_mae: 0.0206 - val_mse: 0.0015
# Epoch 122/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5706e-04 - mae: 0.0112 - mse: 2.5706e-04
# Epoch 122: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4233e-04 - mae: 0.0122 - mse: 3.4233e-04 - val_loss: 0.0015 - val_mae: 0.0202 - val_mse: 0.0015
# Epoch 123/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3818e-04 - mae: 0.0134 - mse: 4.3818e-04
# Epoch 123: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3394e-04 - mae: 0.0122 - mse: 3.3394e-04 - val_loss: 0.0015 - val_mae: 0.0202 - val_mse: 0.0015
# Epoch 124/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1882e-04 - mae: 0.0125 - mse: 3.1882e-04
# Epoch 124: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3813e-04 - mae: 0.0122 - mse: 3.3813e-04 - val_loss: 0.0015 - val_mae: 0.0198 - val_mse: 0.0015
# Epoch 125/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6188e-04 - mae: 0.0109 - mse: 2.6188e-04
# Epoch 125: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2565e-04 - mae: 0.0117 - mse: 3.2565e-04 - val_loss: 0.0014 - val_mae: 0.0196 - val_mse: 0.0014
# Epoch 126/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2840e-04 - mae: 0.0121 - mse: 3.2840e-04
# Epoch 126: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3368e-04 - mae: 0.0119 - mse: 3.3368e-04 - val_loss: 0.0015 - val_mae: 0.0201 - val_mse: 0.0015
# Epoch 127/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5399e-04 - mae: 0.0109 - mse: 2.5399e-04
# Epoch 127: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2964e-04 - mae: 0.0120 - mse: 3.2964e-04 - val_loss: 0.0014 - val_mae: 0.0195 - val_mse: 0.0014
# Epoch 128/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2644e-04 - mae: 0.0130 - mse: 4.2644e-04
# Epoch 128: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4856e-04 - mae: 0.0123 - mse: 3.4856e-04 - val_loss: 0.0015 - val_mae: 0.0199 - val_mse: 0.0015
# Epoch 129/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0655e-04 - mae: 0.0120 - mse: 3.0655e-04
# Epoch 129: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5252e-04 - mae: 0.0126 - mse: 3.5252e-04 - val_loss: 0.0016 - val_mae: 0.0207 - val_mse: 0.0016
# Epoch 130/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9738e-04 - mae: 0.0116 - mse: 2.9738e-04
# Epoch 130: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4651e-04 - mae: 0.0126 - mse: 3.4651e-04 - val_loss: 0.0015 - val_mae: 0.0212 - val_mse: 0.0015
# Epoch 131/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4692e-04 - mae: 0.0132 - mse: 3.4692e-04
# Epoch 131: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5469e-04 - mae: 0.0127 - mse: 3.5469e-04 - val_loss: 0.0016 - val_mae: 0.0211 - val_mse: 0.0016
# Epoch 132/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 4.4475e-04 - mae: 0.0152 - mse: 4.4475e-04
# Epoch 132: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9470e-04 - mae: 0.0134 - mse: 3.9470e-04 - val_loss: 0.0015 - val_mae: 0.0198 - val_mse: 0.0015
# Epoch 133/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5378e-04 - mae: 0.0132 - mse: 4.5378e-04
# Epoch 133: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7422e-04 - mae: 0.0132 - mse: 3.7422e-04 - val_loss: 0.0016 - val_mae: 0.0212 - val_mse: 0.0016
# Epoch 134/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2191e-04 - mae: 0.0129 - mse: 3.2191e-04
# Epoch 134: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1095e-04 - mae: 0.0139 - mse: 4.1095e-04 - val_loss: 0.0015 - val_mae: 0.0213 - val_mse: 0.0015
# Epoch 135/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5882e-04 - mae: 0.0140 - mse: 3.5882e-04
# Epoch 135: val_loss did not improve from 0.00143
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8653e-04 - mae: 0.0138 - mse: 3.8653e-04 - val_loss: 0.0017 - val_mae: 0.0223 - val_mse: 0.0017
# Epoch 136/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2669e-04 - mae: 0.0165 - mse: 5.2669e-04
# Epoch 136: val_loss improved from 0.00143 to 0.00135, saving model to ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/model/FI-GRAMSCI_fed_model.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9193e-04 - mae: 0.0139 - mse: 3.9193e-04 - val_loss: 0.0013 - val_mae: 0.0201 - val_mse: 0.0013
# Epoch 137/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2653e-04 - mae: 0.0130 - mse: 3.2653e-04
# Epoch 137: val_loss did not improve from 0.00135
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7211e-04 - mae: 0.0134 - mse: 3.7211e-04 - val_loss: 0.0016 - val_mae: 0.0205 - val_mse: 0.0016
# Epoch 138/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4696e-04 - mae: 0.0131 - mse: 3.4696e-04
# Epoch 138: val_loss did not improve from 0.00135
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4177e-04 - mae: 0.0128 - mse: 3.4177e-04 - val_loss: 0.0015 - val_mae: 0.0199 - val_mse: 0.0015
# Epoch 139/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6029e-04 - mae: 0.0110 - mse: 2.6029e-04
# Epoch 139: val_loss did not improve from 0.00135
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3211e-04 - mae: 0.0123 - mse: 3.3211e-04 - val_loss: 0.0015 - val_mae: 0.0197 - val_mse: 0.0015
# Epoch 140/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3115e-04 - mae: 0.0120 - mse: 3.3115e-04
# Epoch 140: val_loss did not improve from 0.00135
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2588e-04 - mae: 0.0123 - mse: 3.2588e-04 - val_loss: 0.0015 - val_mae: 0.0196 - val_mse: 0.0015
# Epoch 141/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4549e-04 - mae: 0.0119 - mse: 3.4549e-04
# Epoch 141: val_loss did not improve from 0.00135
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2204e-04 - mae: 0.0122 - mse: 3.2204e-04 - val_loss: 0.0015 - val_mae: 0.0201 - val_mse: 0.0015
# Epoch 142/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6570e-04 - mae: 0.0132 - mse: 3.6570e-04
# ...
# Epoch 949/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9088e-04 - mae: 0.0102 - mse: 1.9088e-04
# Epoch 949: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7284e-04 - mae: 0.0099 - mse: 1.7284e-04 - val_loss: 0.0015 - val_mae: 0.0169 - val_mse: 0.0015
# Epoch 950/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5796e-04 - mae: 0.0095 - mse: 1.5796e-04
# Epoch 950: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8724e-04 - mae: 0.0102 - mse: 1.8724e-04 - val_loss: 0.0016 - val_mae: 0.0167 - val_mse: 0.0016
# Epoch 951/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6381e-04 - mae: 0.0094 - mse: 1.6381e-04
# Epoch 951: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0855e-04 - mae: 0.0108 - mse: 2.0855e-04 - val_loss: 0.0017 - val_mae: 0.0196 - val_mse: 0.0017
# Epoch 952/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3536e-04 - mae: 0.0144 - mse: 5.3536e-04
# Epoch 952: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6771e-04 - mae: 0.0136 - mse: 3.6771e-04 - val_loss: 0.0014 - val_mae: 0.0207 - val_mse: 0.0014
# Epoch 953/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8734e-04 - mae: 0.0181 - mse: 5.8734e-04
# Epoch 953: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9970e-04 - mae: 0.0148 - mse: 3.9970e-04 - val_loss: 0.0021 - val_mae: 0.0231 - val_mse: 0.0021
# Epoch 954/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8508e-04 - mae: 0.0164 - mse: 4.8508e-04
# Epoch 954: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5115e-04 - mae: 0.0154 - mse: 4.5115e-04 - val_loss: 0.0017 - val_mae: 0.0203 - val_mse: 0.0017
# Epoch 955/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5135e-04 - mae: 0.0134 - mse: 3.5135e-04
# Epoch 955: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9233e-04 - mae: 0.0145 - mse: 3.9233e-04 - val_loss: 0.0019 - val_mae: 0.0225 - val_mse: 0.0019
# Epoch 956/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 5.3199e-04 - mae: 0.0169 - mse: 5.3199e-04
# Epoch 956: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5508e-04 - mae: 0.0158 - mse: 4.5508e-04 - val_loss: 0.0017 - val_mae: 0.0230 - val_mse: 0.0017
# Epoch 957/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9523e-04 - mae: 0.0172 - mse: 4.9523e-04
# Epoch 957: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0954e-04 - mae: 0.0170 - mse: 5.0954e-04 - val_loss: 0.0015 - val_mae: 0.0223 - val_mse: 0.0015
# Epoch 958/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8448e-04 - mae: 0.0169 - mse: 4.8448e-04
# Epoch 958: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8111e-04 - mae: 0.0164 - mse: 4.8111e-04 - val_loss: 0.0020 - val_mae: 0.0252 - val_mse: 0.0020
# Epoch 959/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6938e-04 - mae: 0.0208 - mse: 8.6938e-04
# Epoch 959: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2871e-04 - mae: 0.0182 - mse: 6.2871e-04 - val_loss: 0.0014 - val_mae: 0.0221 - val_mse: 0.0014
# Epoch 960/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3783e-04 - mae: 0.0157 - mse: 4.3783e-04
# Epoch 960: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2374e-04 - mae: 0.0169 - mse: 5.2374e-04 - val_loss: 0.0016 - val_mae: 0.0227 - val_mse: 0.0016
# Epoch 961/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4250e-04 - mae: 0.0173 - mse: 5.4250e-04
# Epoch 961: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3471e-04 - mae: 0.0173 - mse: 5.3471e-04 - val_loss: 0.0019 - val_mae: 0.0234 - val_mse: 0.0019
# Epoch 962/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5675e-04 - mae: 0.0161 - mse: 4.5675e-04
# Epoch 962: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7876e-04 - mae: 0.0164 - mse: 4.7876e-04 - val_loss: 0.0021 - val_mae: 0.0238 - val_mse: 0.0021
# Epoch 963/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4698e-04 - mae: 0.0186 - mse: 6.4698e-04
# Epoch 963: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9073e-04 - mae: 0.0179 - mse: 5.9073e-04 - val_loss: 0.0017 - val_mae: 0.0259 - val_mse: 0.0017
# Epoch 964/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5491e-04 - mae: 0.0186 - mse: 7.5491e-04
# Epoch 964: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6470e-04 - mae: 0.0212 - mse: 8.6470e-04 - val_loss: 0.0018 - val_mae: 0.0262 - val_mse: 0.0018
# Epoch 965/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4985e-04 - mae: 0.0224 - mse: 8.4985e-04
# Epoch 965: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6788e-04 - mae: 0.0219 - mse: 8.6788e-04 - val_loss: 0.0025 - val_mae: 0.0270 - val_mse: 0.0025
# Epoch 966/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6062e-04 - mae: 0.0216 - mse: 9.6062e-04
# Epoch 966: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6734e-04 - mae: 0.0227 - mse: 9.6734e-04 - val_loss: 0.0030 - val_mae: 0.0356 - val_mse: 0.0030
# Epoch 967/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0269 - mse: 0.0012
# Epoch 967: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - mae: 0.0243 - mse: 0.0011 - val_loss: 0.0023 - val_mae: 0.0274 - val_mse: 0.0023
# Epoch 968/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2021e-04 - mae: 0.0222 - mse: 8.2021e-04
# Epoch 968: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mae: 0.0242 - mse: 0.0011 - val_loss: 0.0025 - val_mae: 0.0313 - val_mse: 0.0025
# Epoch 969/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0290 - mse: 0.0015
# Epoch 969: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mae: 0.0284 - mse: 0.0015 - val_loss: 0.0023 - val_mae: 0.0330 - val_mse: 0.0023
# Epoch 970/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0271 - mse: 0.0012
# Epoch 970: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - mae: 0.0269 - mse: 0.0013 - val_loss: 0.0034 - val_mae: 0.0350 - val_mse: 0.0034
# Epoch 971/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0256 - mse: 0.0012
# Epoch 971: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mae: 0.0261 - mse: 0.0012 - val_loss: 0.0023 - val_mae: 0.0310 - val_mse: 0.0023
# Epoch 972/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mae: 0.0253 - mse: 0.0010
# Epoch 972: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mae: 0.0259 - mse: 0.0012 - val_loss: 0.0021 - val_mae: 0.0284 - val_mse: 0.0021
# Epoch 973/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4929e-04 - mae: 0.0204 - mse: 7.4929e-04
# Epoch 973: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mae: 0.0241 - mse: 0.0010 - val_loss: 0.0023 - val_mae: 0.0321 - val_mse: 0.0023
# Epoch 974/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0012 - mae: 0.0272 - mse: 0.0012
# Epoch 974: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mae: 0.0245 - mse: 0.0010 - val_loss: 0.0019 - val_mae: 0.0280 - val_mse: 0.0019
# Epoch 975/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 6.4692e-04 - mae: 0.0201 - mse: 6.4692e-04
# Epoch 975: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mae: 0.0244 - mse: 0.0010 - val_loss: 0.0027 - val_mae: 0.0335 - val_mse: 0.0027
# Epoch 976/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mae: 0.0269 - mse: 0.0012
# Epoch 976: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0267 - mse: 0.0012 - val_loss: 0.0027 - val_mae: 0.0336 - val_mse: 0.0027
# Epoch 977/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - mae: 0.0287 - mse: 0.0015
# Epoch 977: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - mae: 0.0278 - mse: 0.0014 - val_loss: 0.0025 - val_mae: 0.0305 - val_mse: 0.0025
# Epoch 978/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mae: 0.0236 - mse: 0.0010
# Epoch 978: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - mae: 0.0262 - mse: 0.0012 - val_loss: 0.0020 - val_mae: 0.0307 - val_mse: 0.0020
# Epoch 979/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0011 - mae: 0.0251 - mse: 0.0011
# Epoch 979: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0269 - mse: 0.0013 - val_loss: 0.0030 - val_mae: 0.0353 - val_mse: 0.0030
# Epoch 980/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mae: 0.0264 - mse: 0.0012
# Epoch 980: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - mae: 0.0265 - mse: 0.0013 - val_loss: 0.0020 - val_mae: 0.0291 - val_mse: 0.0020
# Epoch 981/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mae: 0.0247 - mse: 0.0011
# Epoch 981: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mae: 0.0242 - mse: 0.0010 - val_loss: 0.0020 - val_mae: 0.0292 - val_mse: 0.0020
# Epoch 982/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1202e-04 - mae: 0.0217 - mse: 8.1202e-04
# Epoch 982: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3262e-04 - mae: 0.0221 - mse: 8.3262e-04 - val_loss: 0.0019 - val_mae: 0.0292 - val_mse: 0.0019
# Epoch 983/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4791e-04 - mae: 0.0223 - mse: 8.4791e-04
# Epoch 983: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8001e-04 - mae: 0.0212 - mse: 7.8001e-04 - val_loss: 0.0019 - val_mae: 0.0269 - val_mse: 0.0019
# Epoch 984/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3019e-04 - mae: 0.0211 - mse: 8.3019e-04
# Epoch 984: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1359e-04 - mae: 0.0201 - mse: 7.1359e-04 - val_loss: 0.0019 - val_mae: 0.0279 - val_mse: 0.0019
# Epoch 985/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6572e-04 - mae: 0.0214 - mse: 8.6572e-04
# Epoch 985: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3682e-04 - mae: 0.0200 - mse: 7.3682e-04 - val_loss: 0.0020 - val_mae: 0.0264 - val_mse: 0.0020
# Epoch 986/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1412e-04 - mae: 0.0204 - mse: 8.1412e-04
# Epoch 986: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8001e-04 - mae: 0.0194 - mse: 6.8001e-04 - val_loss: 0.0013 - val_mae: 0.0242 - val_mse: 0.0013
# Epoch 987/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2809e-04 - mae: 0.0189 - mse: 6.2809e-04
# Epoch 987: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1274e-04 - mae: 0.0186 - mse: 6.1274e-04 - val_loss: 0.0024 - val_mae: 0.0259 - val_mse: 0.0024
# Epoch 988/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4790e-04 - mae: 0.0197 - mse: 7.4790e-04
# Epoch 988: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3770e-04 - mae: 0.0188 - mse: 6.3770e-04 - val_loss: 0.0015 - val_mae: 0.0240 - val_mse: 0.0015
# Epoch 989/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6645e-04 - mae: 0.0178 - mse: 5.6645e-04
# Epoch 989: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2349e-04 - mae: 0.0184 - mse: 6.2349e-04 - val_loss: 0.0018 - val_mae: 0.0244 - val_mse: 0.0018
# Epoch 990/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.0289e-04 - mae: 0.0167 - mse: 5.0289e-04
# Epoch 990: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7394e-04 - mae: 0.0177 - mse: 5.7394e-04 - val_loss: 0.0017 - val_mae: 0.0229 - val_mse: 0.0017
# Epoch 991/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0091e-04 - mae: 0.0168 - mse: 5.0091e-04
# Epoch 991: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8967e-04 - mae: 0.0164 - mse: 4.8967e-04 - val_loss: 0.0014 - val_mae: 0.0202 - val_mse: 0.0014
# Epoch 992/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3492e-04 - mae: 0.0140 - mse: 3.3492e-04
# Epoch 992: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5424e-04 - mae: 0.0145 - mse: 3.5424e-04 - val_loss: 0.0013 - val_mae: 0.0198 - val_mse: 0.0013
# Epoch 993/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3326e-04 - mae: 0.0140 - mse: 3.3326e-04
# Epoch 993: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0402e-04 - mae: 0.0134 - mse: 3.0402e-04 - val_loss: 0.0015 - val_mae: 0.0191 - val_mse: 0.0015
# Epoch 994/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6969e-04 - mae: 0.0125 - mse: 2.6969e-04
# Epoch 994: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7958e-04 - mae: 0.0126 - mse: 2.7958e-04 - val_loss: 0.0011 - val_mae: 0.0178 - val_mse: 0.0011
# Epoch 995/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5917e-04 - mae: 0.0122 - mse: 2.5917e-04
# Epoch 995: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3407e-04 - mae: 0.0115 - mse: 2.3407e-04 - val_loss: 0.0015 - val_mae: 0.0179 - val_mse: 0.0015
# Epoch 996/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3185e-04 - mae: 0.0109 - mse: 2.3185e-04
# Epoch 996: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0826e-04 - mae: 0.0108 - mse: 2.0826e-04 - val_loss: 0.0012 - val_mae: 0.0179 - val_mse: 0.0012
# Epoch 997/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0555e-04 - mae: 0.0110 - mse: 2.0555e-04
# Epoch 997: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0525e-04 - mae: 0.0108 - mse: 2.0525e-04 - val_loss: 0.0013 - val_mae: 0.0170 - val_mse: 0.0013
# Epoch 998/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0239e-04 - mae: 0.0107 - mse: 2.0239e-04
# Epoch 998: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8885e-04 - mae: 0.0104 - mse: 1.8885e-04 - val_loss: 0.0012 - val_mae: 0.0171 - val_mse: 0.0012
# Epoch 999/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5261e-04 - mae: 0.0094 - mse: 1.5261e-04
# Epoch 999: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7444e-04 - mae: 0.0099 - mse: 1.7444e-04 - val_loss: 0.0013 - val_mae: 0.0165 - val_mse: 0.0013
# Epoch 1000/1000
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6954e-04 - mae: 0.0099 - mse: 1.6954e-04
# Epoch 1000: val_loss did not improve from 0.00114
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4994e-04 - mae: 0.0092 - mse: 1.4994e-04 - val_loss: 0.0013 - val_mae: 0.0164 - val_mse: 0.0013
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# --- federated after local fine-tuning ---
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_1846/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Salvo 92 plot in: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/federated_fd/TEST
# Plot salvati correttamente.
# Test MAE: 0.1573
# Test RMSE: 0.2958
# Test MAPE: 0.43%
# Test R2: 0.9988
# Valore medio del test set: 41.6166
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_FI-GRAMSCI_14-19-05/federated_fd_evaluation_log.json
