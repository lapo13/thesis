# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import os, pickle, random
from datetime import datetime

# %%
get_after_QA = lambda s: s.split("QA_", 1)[1]

# %%
dati = pd.read_excel('/Users/lapotinacci/thesis/metric_datasets/NO2_dataset.xlsx')
dati = dati[dati["serviceUri"] == "http://www.disit.org/km4city/resource/iot/orionUNIFI/DISIT/ARPAT_QA_GR-MAREMMA"].copy()
sensor_name = get_after_QA(dati["serviceUri"].iloc[0])
dati.drop(columns=["serviceUri"], inplace=True)
print(dati.shape)
# Out:
# (448, 16)

# %%
# === Creazione cartella esperimento con timestamp ISO ===
timestamp = datetime.now().strftime("%H-%M-%S")
print(f"Ora inizio esperimento: {timestamp}")
day= datetime.now().strftime("%Y-%m-%d")
print(f"Giorno inizio esperimento: {day}")
exp_dir = f"../RISULTATI/{day}/esperimento_{sensor_name}_{timestamp}"

os.makedirs(exp_dir, exist_ok=True)

print(f"Cartella esperimento creata: {exp_dir}")
# Out:
# Ora inizio esperimento: 14-19-03
# Giorno inizio esperimento: 2025-11-30
# Cartella esperimento creata: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03

# %%
import ast

mask = ~dati['TTT'].str.contains("nan", na=True)
dtset_completo = dati[mask]

dtset_completo['TTT'] = dtset_completo['TTT'].apply(ast.literal_eval)

# %%
# Filtra le righe dove la colonna TTT ha lunghezza 24, ed elimina tutte le colonne le cui osservazioni sono indipendenti dal giorno
dtset_filtrato = dtset_completo[dtset_completo["TTT"].apply(lambda x: len(x) == 24)].sample(frac=1).reset_index(drop=True)
dtset_filtrato = dtset_filtrato[dtset_filtrato["type_of_TTT"] == "daily"]
len(dtset_filtrato)
# Out:
# 310

# %%
import numpy as np


def is_useful_series(series, zero_ratio_thr=0.85, min_nonzero_value=0.1):
    arr = np.array(series, dtype=float)
    
    # Serie troppo corta
    if len(arr) <= 1:
        return False
    
    # Troppi zeri
    zero_ratio = (arr == 0).mean()
    if zero_ratio >= zero_ratio_thr:
        return False
    
    # Valore medio trascurabile (quasi zero)
    mean_val = np.mean(arr)
    if abs(mean_val) < min_nonzero_value:
        return False
    
    # Se arriva qui, la serie ha valori significativi
    return True

# Applica filtro
mask_useful = dtset_filtrato["TTT"].apply(is_useful_series)
df_useful = dtset_filtrato[mask_useful]

# %%
def spezza_serie_in_colonne(df, colonna_stringa, prefix='col_'):
    # --- Controllo colonna ---
    if colonna_stringa not in df.columns:
        raise ValueError(f"La colonna '{colonna_stringa}' non esiste nel DataFrame")

    result_df = df.copy()

    # Estraggo la colonna contenente gli embedding
    col = result_df.pop(colonna_stringa)

    embeddings = []

    for item in col:
        if pd.isna(item) or item == "":
            embeddings.append([])
            continue
        
        try:
            # Parsing sicuro della stringa in lista Python
            vett = ast.literal_eval(item)

            # Se l’embedding è una numpy array o altro iterabile, lo converto in list
            if not isinstance(vett, list):
                vett = list(vett)

            # Converto tutto in float
            vett = [float(x) for x in vett]

            embeddings.append(vett)

        except Exception as e:
            print(f"Errore nel parsing dell'elemento '{item}': {e}")
            embeddings.append([])

    # --- Uniformo dimensione dei vettori ---
    lengths = [len(v) for v in embeddings]
    if not lengths:
        raise ValueError("Nessun embedding valido nella colonna")

    max_len = max(lengths)

    embeddings_padded = [
        v + [np.nan] * (max_len - len(v)) if len(v) < max_len else v
        for v in embeddings
    ]

    # --- Creo DataFrame delle nuove colonne ---
    colonne_embedding = pd.DataFrame(
        embeddings_padded,
        index=result_df.index,
        columns=[f"{prefix}{i}" for i in range(max_len)]
    )

    # --- Merge col DataFrame originale ---
    return pd.concat([result_df, colonne_embedding], axis=1)

# %%
for ttt in df_useful.TTT:
    plt.plot(ttt)

# %%
def summary_df(df):
    summary = pd.DataFrame({
        'dtype': df.dtypes,
        'n_missing': df.isna().sum(),
        '%_missing': (df.isna().mean() * 100).round(2),
        'n_unique': df.nunique(),
        'top_value': df.mode().iloc[0],  # moda
        'top_freq': [df[col].value_counts(dropna=True).iloc[0] if not df[col].value_counts(dropna=True).empty else None for col in df.columns],
        'min': [df[col].min() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'max': [df[col].max() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'mean': [df[col].mean() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'std': [df[col].std() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
    })
    return summary

# %%
#Nella precedente sono state eliminate le colonne con Nan, tuttavia alcuni dataset dei sensori METRO hanno dei Nan in city e surface dunque vengono rimossi nel prcedente box

categorical = [
    'is_weekend'
    ]

#consiglio, per serie cicliche usare funzioni periodiche tipo seno coseno 
df_encoded = pd.get_dummies(df_useful
                            , columns=categorical)

# %%
def save_pkl(obj, path):
    with open(path, "wb") as f:
        pickle.dump(obj, f)
    print(f"Salvato: {path}")

def load_pkl(path):
    with open(path, "rb") as f:
        return pickle.load(f)

# %%
#codifica ciclica delle features e individuazione del'ora del giorno e della settimana 

def encode_time_features(df, start_col="interval_start", end_col="interval_end"):
    df = df.copy()
    
    # Step 1: Ensure datetime columns are in the correct format first
    df[start_col] = pd.to_datetime(df[start_col], utc=True, format="mixed")
    df[end_col] = pd.to_datetime(df[end_col], utc=True, format="mixed")

    # Step 2: Extract 'month' and 'day' after conversion
    df['month'] = df[start_col].dt.month
    df['day'] = df[start_col].dt.dayofweek # Note: dayofweek is typically used for cyclical weekly patterns
    
    # Step 3: Now you can create the cyclical features
    df['month_sin'] = np.sin(2 * np.pi * df['month']/len(df['month'].unique()))
    df['month_cos'] = np.cos(2 * np.pi * df['month']/len(df['month'].unique()))
    df['day_sin'] = np.sin(2 * np.pi * df['day']/len(df['day'].unique()))
    df['day_cos'] = np.cos(2 * np.pi * df['day']/len(df['day'].unique()))


    # Ora del giorno (0-23) → ciclo giornaliero
    df["hour"] = df[start_col].dt.hour
    angle_day_start = 2 * np.pi * df["hour"] / 24
    df["start_time_sin"] = np.sin(angle_day_start)
    df["start_time_cos"] = np.cos(angle_day_start)

    df["hour_end"] = df[end_col].dt.hour
    angle_day_end = 2 * np.pi * df["hour_end"] / 24
    df["end_time_sin"] = np.sin(angle_day_end)
    df["end_time_cos"] = np.cos(angle_day_end)

    # Durata in minuti
    df["duration_minutes"] = (df[end_col] - df[start_col]).dt.total_seconds() / 60

    # Giorno della settimana (0=Mon..6=Sun) → ciclo settimanale
    dayofweek = df[start_col].dt.dayofweek
    angle_week = 2 * np.pi * dayofweek / 7
    df["dow_sin"] = np.sin(angle_week)
    df["dow_cos"] = np.cos(angle_week)

    # Giorno dell’anno (1-365) → ciclo annuale
    dayofyear = df[start_col].dt.dayofyear
    angle_year = 2 * np.pi * dayofyear / 365
    df["doy_sin"] = np.sin(angle_year)
    df["doy_cos"] = np.cos(angle_year)

    # Rimuovo colonne temporali e variabili ausiliarie
    df = df.drop(columns=[start_col, end_col, "hour", "hour_end", "day", "month"])
    return df

embedding_cols = ['highway_embedding', 'AreaTypeEmbeddings']

df_final = encode_time_features(df_encoded)
df_final.drop(columns=['type_of_TTT'], inplace=True)
for emb_col in embedding_cols:
    df_final = spezza_serie_in_colonne(df_final, emb_col, prefix=f'{emb_col}_')
df_final.shape

# Salvataggio DataFrame finale
df_path = os.path.join(exp_dir, f"dataframe_{sensor_name}")
os.makedirs(df_path, exist_ok=True)
save_pkl(df_final, os.path.join(df_path, f"filtered_dataframe.pkl"))
# Out:
# Salvato: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/dataframe_GR-MAREMMA/filtered_dataframe.pkl

# %%
for ttt in df_final.TTT[10:20]:
    plt.plot(ttt)
    plt.title("Esempi di TTT ARPAT")
    plt.xlabel("Ora del Giorno")
    plt.ylabel("Valore TTT")

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

def series_to_2d_array(series, output_dim=24):
    arr = np.stack(series.apply(lambda x: np.array(x, dtype=np.float32)))
    if arr.shape[1] != output_dim:
        raise ValueError(f"Ogni elemento deve avere {output_dim} valori, trovato {arr.shape[1]}")
    return arr

 # Separazione delle feature e del target
X = df_final.drop(columns=['TTT'])
y = df_final['TTT']

X_np = X.to_numpy().astype(np.float32)
y_np = series_to_2d_array(y, output_dim=24)

# Calcolo deviazione standard per ogni serie
std_scores = np.std(y_np, axis=1)

std_scores_log = np.log1p(std_scores)  # log(1+x) per evitare problemi con valori vicini a 0

std_scores_normalized = (std_scores_log - np.min(std_scores_log)) / (np.max(std_scores_log) - np.min(std_scores_log))

# Creo bin basati sui quantili
bins = np.array([0.0, 0.4, 0.8, 1.0])
std_bins = np.digitize(std_scores_normalized, bins)

# Primo split: train (80%) vs temp (20%)
# Passo anche std_bins per poter stratificare
X_train, X_test, y_train, y_test = train_test_split(
    X_np, y_np,
    test_size=0.2,
    random_state=42,
    stratify=std_bins, 
    shuffle=True
)

print(f"Train size: {X_train.shape}, {y_train.shape}")
print(f"Test size: {X_test.shape}, {y_test.shape}")

# Debug prints
print(f"Final shapes:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

# Scaler per input
scaler_X = StandardScaler()
X_train = scaler_X.fit_transform(X_train)
X_test  = scaler_X.transform(X_test)

# Scaler per output (se serve normalizzare anche y)
scaler_y = StandardScaler()
y_train = scaler_y.fit_transform(y_train)
y_test  = scaler_y.transform(y_test)

#cartella salvataggio train e test
path = os.path.join(exp_dir, "train_test_data")
os.makedirs(path, exist_ok=True)

#  === Salvataggio dataset e scaler in formato .pkl ===
save_pkl(scaler_X.inverse_transform(X_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_X.inverse_transform(X_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_test_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_test_unscaled_{sensor_name}.pkl"))


save_pkl(X_train, os.path.join(exp_dir, "X_train.pkl"))
save_pkl(y_train, os.path.join(exp_dir, "y_train.pkl"))
save_pkl(X_test, os.path.join(exp_dir, "X_test.pkl"))
save_pkl(y_test, os.path.join(exp_dir, "y_test.pkl"))

save_pkl(scaler_X, os.path.join(exp_dir, "scaler_X.pkl"))
save_pkl(scaler_y, os.path.join(exp_dir, "scaler_y.pkl"))

print("Scaler salvati.")

print("\nTutti i file sono stati salvati correttamente.")
print(f"Percorso cartella: {os.path.abspath(exp_dir)}")
# Out:
# Train size: (248, 33), (248, 24)
# Test size: (62, 33), (62, 24)
# Final shapes:
# X_train: (248, 33)
# y_train: (248, 24)
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_train_unscaled_GR-MAREMMA.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_train_unscaled_GR-MAREMMA.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_test_unscaled_GR-MAREMMA.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_test_unscaled_GR-MAREMMA.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/X_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/y_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/X_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/y_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/scaler_X.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/scaler_y.pkl
# Scaler salvati.
#
# Tutti i file sono stati salvati correttamente.
# Percorso cartella: /Users/lapotinacci/thesis/Federated_Sys/RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03

# %%
# === Costruisci i path ===
path_X_train = os.path.join(exp_dir, "X_train.pkl")
path_y_train = os.path.join(exp_dir, "y_train.pkl")
path_X_test  = os.path.join(exp_dir, "X_test.pkl")
path_y_test  = os.path.join(exp_dir, "y_test.pkl")

path_scaler_X = os.path.join(exp_dir, "scaler_X.pkl")
path_scaler_y = os.path.join(exp_dir, "scaler_y.pkl")

# === Ricaricamento ===
X_train = load_pkl(path_X_train)
y_train = load_pkl(path_y_train)
X_test  = load_pkl(path_X_test)
y_test  = load_pkl(path_y_test)


scaler_X = load_pkl(path_scaler_X)
scaler_y = load_pkl(path_scaler_y)

print("Shapes ricostruite:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

print("\nScaler caricati:")
print("scaler_X:", type(scaler_X))
print("scaler_y:", type(scaler_y))
# Out:
# Shapes ricostruite:
# X_train: (248, 33)
# y_train: (248, 24)
# X_test: (62, 33)
# y_test: (62, 24)
#
# Scaler caricati:
# scaler_X: <class 'sklearn.preprocessing._data.StandardScaler'>
# scaler_y: <class 'sklearn.preprocessing._data.StandardScaler'>

# %% [markdown]
# # modelli

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers # type: ignore
from tensorflow.keras.layers import Dropout # type: ignore
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
def save_prediction_plots(y_true, y_pred, output_dir, prefix="pred_plot"):
    os.makedirs(output_dir, exist_ok=True)

    n = len(y_true)
    print(f"Salvo {n} plot in: {output_dir}")

    for i in range(n):
        plt.figure(figsize=(8, 3))
        plt.plot(y_true[i], label="True")
        plt.plot(y_pred[i], label="Pred")
        plt.legend()
        plt.tight_layout()

        filename = f"{prefix}_{i+1}.png"
        path = os.path.join(output_dir, filename)

        plt.savefig(path)
        plt.close()

    print("Plot salvati correttamente.")

# %%
# Definizione modello DNN
def build_model(input_shape: tuple, output_shape: tuple):
    model = models.Sequential([
        layers.Dense(128, activation = "relu", input_shape=input_shape),
        Dropout(0.0),
        layers.Dense(output_shape, 'linear')
    ])
    model.compile(
    optimizer=optimizers.AdamW(learning_rate=0.0017, weight_decay=0.0158),
    loss= 'mse',
    metrics=['mae'],
    )
    return model

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',      # metrica da monitorare, es. val_loss o val_mae
    patience=100,             # numero di epoche senza miglioramento prima di fermare
    restore_best_weights=True,  # ripristina i pesi migliori trovati
    verbose = 1
)

# Training del modello
model = build_model((X_test.shape[1],), y_test.shape[1])
history = model.fit(
    X_train, y_train,
    epochs=1000,
    batch_size=64,
    callbacks = [early_stop],
    validation_split = 0.2,
    verbose=1
    )

'''print("y_train min/max:", y_train_np.min(), y_train_np.max())
print("y_pred min/max (scaled):", y_pred.min(), y_pred.max())
y_pred_rescaled = scaler_y.inverse_transform(y_pred)
print("y_pred_rescaled min/max:", y_pred_rescaled.min(), y_pred_rescaled.max())'''

if not os.path.exists(os.path.join(exp_dir, "model")):
    os.makedirs(os.path.join(exp_dir, "model"))
    model.save(os.path.join(exp_dir, "model", "NO2_MAREMMA_model.keras"))
# Out:
# Epoch 1/1000
# /Users/lapotinacci/thesis/Federated_Sys/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss:
1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4890e-04 - mae: 0.0167 - val_loss: 0.0134 - val_mae: 0.0400
# Epoch 986/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3071e-04 - mae: 0.0167 - val_loss: 0.0137 - val_mae: 0.0397
# Epoch 987/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7728e-04 - mae: 0.0160 - val_loss: 0.0141 - val_mae: 0.0403
# Epoch 988/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7294e-04 - mae: 0.0172 - val_loss: 0.0136 - val_mae: 0.0398
# Epoch 989/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7866e-04 - mae: 0.0175 - val_loss: 0.0135 - val_mae: 0.0391
# Epoch 990/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2532e-04 - mae: 0.0151 - val_loss: 0.0140 - val_mae: 0.0403
# Epoch 991/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8417e-04 - mae: 0.0161 - val_loss: 0.0135 - val_mae: 0.0396
# Epoch 992/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5561e-04 - mae: 0.0154 - val_loss: 0.0135 - val_mae: 0.0398
# Epoch 993/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6222e-04 - mae: 0.0176 - val_loss: 0.0141 - val_mae: 0.0406
# Epoch 994/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mae: 0.0203 - val_loss: 0.0134 - val_mae: 0.0414
# Epoch 995/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.9893e-04 - mae: 0.0211 - val_loss: 0.0144 - val_mae: 0.0454
# Epoch 996/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mae: 0.0201 - val_loss: 0.0143 - val_mae: 0.0429
# Epoch 997/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0222 - val_loss: 0.0139 - val_mae: 0.0429
# Epoch 998/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6630e-04 - mae: 0.0209 - val_loss: 0.0149 - val_mae: 0.0476
# Epoch 999/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mae: 0.0269 - val_loss: 0.0152 - val_mae: 0.0483
# Epoch 1000/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mae: 0.0271 - val_loss: 0.0143 - val_mae: 0.0473
# Restoring model weights from the end of the best epoch: 974.

# %%
model = tf.keras.models.load_model(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') if os.path.exists(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') else model

# %%
# Estrai losses da tutti i folds
train_losses = history.history['loss']
val_losses   = history.history['val_loss']

train_losses = train_losses
val_losses = val_losses

# Plot
plt.figure(figsize=(8,5))


# Training loss
plt.plot(train_losses, color='blue', label='Train Loss')
# Validation loss
plt.plot(val_losses, color='red', label='Validation Loss')


# Dettagli grafico
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.savefig(f'{exp_dir}/loss_plot.png')

# %%
def plot_first_n_series(y_pred, y_test, n_series=10, title="Confronto Serie Predette vs Reali"):
    """
    Plotta le prime n_series serie reali e predette per un confronto diretto.

    Args:
        y_pred (np.ndarray): Predizioni del modello (shape: num_samples x seq_len).
        y_test (np.ndarray): Serie reali (shape: num_samples x seq_len).
        n_series (int): Numero di serie da plottare.
        title (str): Titolo del grafico.
    """

    # Limitiamo a n_series per evitare problemi
    n = min(n_series, y_pred.shape[0], y_test.shape[0])

    plt.figure(figsize=(14, 8))

    for i in range(n):
        plt.plot(
            y_test[i], 
            linewidth=1.8, 
            alpha=0.5, 
            label=f"Reale {i+1}" if i == 0 else "",
            color = 'blue'
        )
        plt.plot(
            y_pred[i], 
            linewidth=1.2, 
            linestyle="--", 
            alpha=0.9, 
            label=f"Predetto {i+1}" if i == 0 else "",
            color = 'orange'
        )

    plt.title(title, fontsize=16)
    plt.xlabel("Time Step", fontsize=12)
    plt.ylabel("Valore", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

def plot_diagnosis_gradient(y_pred, y_test, save_path: str,  tolerance:float =0.05, max_samples_heatmap=50, scatter_sample_ratio=0.5, tol_auto = True):
    """
    Dashboard diagnostica con tolleranza AUTO-ADATTIVA alla scala dei dati.
    
    Args:
        tolerance (float): 
            - Se None: La tolleranza viene calcolata automaticamente come il 5% del range dei dati (Max-Min).
            - Se float: Valore assoluto (es. 0.5).
        tol_auto (bool): Se True, usa la tolleranza automatica basata sul range dei dati, altrimenti usa il valore manuale fornito 
        col parametro tolerance.
    """
    
    y_test_flat = y_test.flatten()
    y_pred_flat = y_pred.flatten()

    # ---------------------------------------------------------
    # AUTOMAZIONE TOLLERANZA
    # ---------------------------------------------------------
    if tol_auto:
        data_range = y_test_flat.max() - y_test_flat.min()
        # Impostiamo la tolleranza al 5% del range totale (regolabile)
        tolerance = data_range * tolerance 
        tol_label = f"Auto (5% Range: ±{tolerance:.2f})"
    else:
        tol_label = f"Manuale (±{tolerance})"

    fig, axes = plt.subplots(1, 2, figsize=(22, 8))

    # -----------------------------
    # 1. HEATMAP (SX)
    # -----------------------------
    errors = np.abs(y_test - y_pred)
    errors_subset = errors[:max_samples_heatmap]
    
    # Adattiamo anche la scala colori della heatmap alla tolleranza
    # Tutto ciò che è oltre 3 volte la tolleranza è "errore massimo" visivo
    sns.heatmap(errors_subset, cmap="plasma", ax=axes[0], 
                vmax=tolerance * 3,
                cbar_kws={'label': 'Errore Assoluto'})
    
    axes[0].set_title(f"Heatmap Errori (Primi {max_samples_heatmap} campioni)", fontsize=16)
    axes[0].set_xlabel("Time Step", fontsize=12)
    axes[0].set_ylabel("Indice Campione", fontsize=12)

    # -----------------------------
    # 2. SCATTER CON SFONDO GRADIENTE (DX)
    # -----------------------------
    
    # Campionamento dati
    if scatter_sample_ratio < 1.0:
        mask = np.random.rand(len(y_test_flat)) < scatter_sample_ratio
        sample_test = y_test_flat[mask]
        sample_pred = y_pred_flat[mask]
    else:
        sample_test = y_test_flat
        sample_pred = y_pred_flat

    # Calcolo limiti grafico
    min_val = min(y_test_flat.min(), y_pred_flat.min())
    max_val = max(y_test_flat.max(), y_pred_flat.max())
    padding = (max_val - min_val) * 0.05
    plot_min = min_val - padding
    plot_max = max_val + padding

    # --- SFONDO GRADIENTE ---
    grid_x, grid_y = np.meshgrid(
        np.linspace(plot_min, plot_max, 200),
        np.linspace(plot_min, plot_max, 200)
    )
    grid_z = np.abs(grid_y - grid_x)

    im = axes[1].imshow(
        grid_z, 
        extent=(plot_min, plot_max, plot_min, plot_max), 
        origin='lower', 
        cmap='RdYlGn_r', 
        alpha=0.4, 
        vmax=tolerance * 4, # Il rosso satura a 4x della tolleranza
        aspect='auto'
    )

    # --- PUNTI BLU ---
    axes[1].scatter(
        sample_test, 
        sample_pred, 
        alpha=0.6, 
        s=15, 
        color='royalblue', 
        edgecolors='white', 
        linewidth=0.3,
        label='Campioni'
    )

    axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

    # Metriche
    within_tol = np.mean(np.abs(y_test_flat - y_pred_flat) <= tolerance) * 100

    axes[1].set_title(
        f"Bontà delle previsioni con {tol_label}\nValori nel range di Tolleranza: {within_tol:.1f}%", 
        fontsize=16
    )
    axes[1].set_xlabel("Valore Reale", fontsize=12)
    axes[1].set_ylabel("Valore Predetto", fontsize=12)
    axes[1].set_xlim(plot_min, plot_max)
    axes[1].set_ylim(plot_min, plot_max)
    
    cbar = plt.colorbar(im, ax=axes[1], pad=0.02)
    cbar.set_label('Gravità Errore (Distanza da diagonale)')

    plt.tight_layout()
    plt.savefig(f'{exp_dir}/{save_path}.png')

# %%
y_pred = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred)
y_test_np = scaler_y.inverse_transform(y_test)

plot_diagnosis_gradient(y_pred, y_test_np, save_path='pred_quality', max_samples_heatmap=10, scatter_sample_ratio=0.7)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_1841/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

# %%
save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/TEST', prefix="pred_plot")
# Out:
# Salvo 62 plot in: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/TEST
# Plot salvati correttamente.

# %%
'''epsilon = 1e-8  # piccolo valore per evitare log(0) in scala log

for i in range(len(y_test_np)):
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

    # Sostituisci i valori nulli con epsilon per il log
    y_pred_safe = np.where(y_pred[i] <= 0, epsilon, y_pred[i])
    y_test_safe = np.where(y_test_np[i] <= 0, epsilon, y_test_np[i])

    # Calcola la differenza percentuale con gestione divisione per 0
    differenza = np.divide(
        (y_pred[i] - y_test_np[i]) * 100,
        y_test_np[i],
        out=np.full_like(y_pred[i], np.nan, dtype=float),
        where=(y_test_np[i] != 0)
    )

    # Mask per escludere NaN o infiniti
    mask = ~np.isnan(differenza) & ~np.isinf(differenza)

    # Primo sottografico: Serie reale vs predetta (log scale)
    ax1.plot(y_pred_safe, label='Predetto', linewidth=2, color='blue')
    ax1.plot(y_test_safe, label='Reale', linewidth=2, color='orange')
    ax1.set_ylabel('Valore della Serie', fontsize=12)
    ax1.set_title(f'Grafico {i+1} - Serie Reale vs Predetta (scala log)', fontsize=14)
    #ax1.set_yscale('log')  # scala logaritmica
    ax1.legend(loc='best')
    ax1.grid(True, alpha=0.3, which='both')

    # Secondo sottografico: Errore percentuale (solo valori validi)
    ax2.plot(
        np.arange(len(differenza))[mask],
        differenza[mask],
        linestyle='--', color='red', linewidth=2, label='Errore %'
    )
    ax2.axhline(y=0, color='gray', linestyle='-', alpha=0.5, linewidth=1)
    ax2.set_xlabel('Ora (Time Step)', fontsize=12)
    ax2.set_ylabel('Errore %', fontsize=12)

    # Imposta ticks da 0 a 23
    ax2.set_xticks(np.arange(24))  

    # Se vuoi anche le griglie verticali su ogni ora
    ax2.grid(True, axis='x', linestyle='--', alpha=0.7)
    ax2.set_title('Errore Percentuale (filtrato)', fontsize=14)
    ax2.legend(loc='best')
    ax2.grid(True, alpha=0.3)

    # Colora l'area sotto l’errore (solo valori validi)
    ax2.fill_between(
        np.arange(len(differenza))[mask],
        differenza[mask], 0,
        alpha=0.3, color='red'
    )

    plt.tight_layout()
    plt.show()'''
# Out:
# "epsilon = 1e-8  # piccolo valore per evitare log(0) in scala log\n\nfor i in range(len(y_test_np)):\n    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), sharex=True)\n\n    # Sostituisci i valori nulli con epsilon per il log\n    y_pred_safe = np.where(y_pred[i] <= 0, epsilon, y_pred[i])\n    y_test_safe = np.where(y_test_np[i] <= 0, epsilon, y_test_np[i])\n\n    # Calcola la differenza percentuale con gestione divisione per 0\n    differenza = np.divide(\n        (y_pred[i] - y_test_np[i]) * 100,\n        y_test_np[i],\n        out=np.full_like(y_pred[i], np.nan, dtype=float),\n        where=(y_test_np[i] != 0)\n    )\n\n    # Mask per escludere NaN o infiniti\n    mask = ~np.isnan(differenza) & ~np.isinf(differenza)\n\n    # Primo sottografico: Serie reale vs predetta (log scale)\n    ax1.plot(y_pred_safe, label='Predetto', linewidth=2, color='blue')\n    ax1.plot(y_test_safe, label='Reale', linewidth=2, color='orange')\n    ax1.set_ylabel('Valore della Serie', fontsize=12)\n    ax1.set_title(f'Grafico {i+1} - Serie Reale vs Predetta (scala log)', fontsize=14)\n    #ax1.set_yscale('log')  # scala logaritmica\n    ax1.legend(loc='best')\n    ax1.grid(True, alpha=0.3, which='both')\n\n    # Secondo sottografico: Errore percentuale (solo valori validi)\n    ax2.plot(\n        np.arange(len(differenza))[mask],\n        differenza[mask],\n        linestyle='--', color='red', linewidth=2, label='Errore %'\n    )\n    ax2.axhline(y=0, color='gray', linestyle='-', alpha=0.5, linewidth=1)\n    ax2.set_xlabel('Ora (Time Step)', fontsize=12)\n    ax2.set_ylabel('Errore %', fontsize=12)\n\n    # Imposta ticks da 0 a 23\n    ax2.set_xticks(np.arange(24))  \n\n    # Se vuoi anche le griglie verticali su ogni ora\n    ax2.grid(True, axis='x', linestyle='--', alpha=0.7)\n    ax2.set_title('Errore Percentuale (filtrato)', fontsize=14)\n    ax2.legend(loc='best')\n    ax2.grid(True, alpha=0.3)\n\n    # Colora l'area sotto l’errore (solo valori validi)\n    ax2.fill_between(\n        np.arange(len(differenza))[mask],\n        differenza[mask], 0,\n        alpha=0.3, color='red'\n    )\n\n    plt.tight_layout()\n    plt.show()"

# %%
import json
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_and_log(y_true, y_pred, log_path="log.json"):
    # --- Metriche ---
    mae = mean_absolute_error(y_true, y_pred, multioutput="uniform_average")
    rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput="uniform_average"))

    mask = y_true != 0
    mape = float(np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100.0)

    r2 = r2_score(y_true, y_pred, multioutput="uniform_average")

    # Valore medio del test set
    v_mean = float(np.mean(y_true))

    # --- Stampa ---
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    print(f"Test MAPE: {mape:.2f}%")
    print(f"Test R2: {r2:.4f}")
    print(f"Valore medio del test set: {v_mean:.4f}")

    # --- Salvataggio log ---
    log_data = {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2,
        "test_mean_value": v_mean
    }

    with open(log_path, "w") as f:
        json.dump(log_data, f, indent=4)

    print(f"\nLog salvato in: {log_path}")
evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/evaluation_log.json")
# Impostazioni pandas per visualizzare tutti i dati
# Out:
# Test MAE: 0.0158
# Test RMSE: 0.0509
# Test MAPE: 0.55%
# Test R2: 0.9903
# Valore medio del test set: 3.0654
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/evaluation_log.json

# %% [markdown]
# # globale e federato

# %%
fed = tf.keras.models.load_model('/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Arpat.keras')

model  = [fed]
model_name = ["federated"]

# %%
checkpoint_filepath = f'{exp_dir}/model/{sensor_name}_fed_model.keras'

# 2. Crea l'istanza della callback
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False, 
    verbose=1
)

# %%
for model, name in zip(model, model_name):
    y_pred = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred)
    y_test_np = scaler_y.inverse_transform(y_test)

    print(f"--- {name} ---")
    #plot_diagnosis_gradient(y_pred, y_test_np, max_samples_heatmap=10, scatter_sample_ratio=0.7)
    evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_evaluation_log.json")
    save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}/TEST', prefix="pred_plot")

    print("\n")
    if name == 'federated':
        model.fit(X_train, y_train, epochs=1000, batch_size=64, callbacks=[model_checkpoint_callback], validation_split=0.2)
        model.load_weights(checkpoint_filepath)
        y_pred = model.predict(X_test)
        y_pred = scaler_y.inverse_transform(y_pred)
        print(f"--- {name} after local fine-tuning ---")
        plot_diagnosis_gradient(y_pred, y_test_np, save_path=f"{name}_pred_quality", max_samples_heatmap=10, scatter_sample_ratio=0.7)
        save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}_fd/TEST', prefix="pred_plot")
        evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_fd_evaluation_log.json")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x127f95440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x127f95440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# --- federated ---
# Test MAE: 0.2957
# Test RMSE: 0.4135
# Test MAPE: 9.72%
# Test R2: 0.3353
# Valore medio del test set: 3.0654
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/federated_evaluation_log.json
# Salvo 62 plot in: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/federated/TEST
# Plot salvati correttamente.
#
#
# Epoch 1/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 1s 476ms/step - loss: 0.6535 - mae: 0.6089 - mse: 0.6535
# Epoch 1: val_loss improved from None to 0.29223, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.5069 - mae: 0.5292 - mse: 0.5069 - val_loss: 0.2922 - val_mae: 0.4051 - val_mse: 0.2922
# Epoch 2/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2348 - mae: 0.3528 - mse: 0.2348
# Epoch 2: val_loss improved from 0.29223 to 0.24052, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2472 - mae: 0.3683 - mse: 0.2472 - val_loss: 0.2405 - val_mae: 0.3751 - val_mse: 0.2405
# Epoch 3/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1515 - mae: 0.3032 - mse: 0.1515
# Epoch 3: val_loss improved from 0.24052 to 0.17418, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1897 - mae: 0.3290 - mse: 0.1897 - val_loss: 0.1742 - val_mae: 0.3198 - val_mse: 0.1742
# Epoch 4/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1493 - mae: 0.2944 - mse: 0.1493
# Epoch 4: val_loss did not improve from 0.17418
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1550 - mae: 0.2939 - mse: 0.1550 - val_loss: 0.1828 - val_mae: 0.3207 - val_mse: 0.1828
# Epoch 5/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1464 - mae: 0.2763 - mse: 0.1464
# Epoch 5: val_loss improved from 0.17418 to 0.13831, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1246 - mae: 0.2568 - mse: 0.1246 - val_loss: 0.1383 - val_mae: 0.2784 - val_mse: 0.1383
# Epoch 6/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0917 - mae: 0.2288 - mse: 0.0917
# Epoch 6: val_loss improved from 0.13831 to 0.11023, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1095 - mae: 0.2416 - mse: 0.1095 - val_loss: 0.1102 - val_mae: 0.2483 - val_mse: 0.1102
# Epoch 7/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0803 - mae: 0.2115 - mse: 0.0803
# Epoch 7: val_loss improved from 0.11023 to 0.09761, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0869 - mae: 0.2188 - mse: 0.0869 - val_loss: 0.0976 - val_mae: 0.2339 - val_mse: 0.0976
# Epoch 8/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0646 - mae: 0.1912 - mse: 0.0646
# Epoch 8: val_loss improved from 0.09761 to 0.09357, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0677 - mae: 0.1897 - mse: 0.0677 - val_loss: 0.0936 - val_mae: 0.2272 - val_mse: 0.0936
# Epoch 9/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0562 - mae: 0.1764 - mse: 0.0562
# Epoch 9: val_loss improved from 0.09357 to 0.07963, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0551 - mae: 0.1721 - mse: 0.0551 - val_loss: 0.0796 - val_mae: 0.1995 - val_mse: 0.0796
# Epoch 10/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0515 - mae: 0.1627 - mse: 0.0515
# Epoch 10: val_loss improved from 0.07963 to 0.06407, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0471 - mae: 0.1583 - mse: 0.0471 - val_loss: 0.0641 - val_mae: 0.1743 - val_mse: 0.0641
# Epoch 11/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0432 - mae: 0.1519 - mse: 0.0432
# Epoch 11: val_loss improved from 0.06407 to 0.05438, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0404 - mae: 0.1445 - mse: 0.0404 - val_loss: 0.0544 - val_mae: 0.1583 - val_mse: 0.0544
# Epoch 12/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0352 - mae: 0.1316 - mse: 0.0352
# Epoch 12: val_loss improved from 0.05438 to 0.05271, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0332 - mae: 0.1305 - mse: 0.0332 - val_loss: 0.0527 - val_mae: 0.1501 - val_mse: 0.0527
# Epoch 13/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0314 - mae: 0.1239 - mse: 0.0314
# Epoch 13: val_loss improved from 0.05271 to 0.05094, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0286 - mae: 0.1204 - mse: 0.0286 - val_loss: 0.0509 - val_mae: 0.1445 - val_mse: 0.0509
# Epoch 14/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0274 - mae: 0.1168 - mse: 0.0274
# Epoch 14: val_loss improved from 0.05094 to 0.04121, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0267 - mae: 0.1149 - mse: 0.0267 - val_loss: 0.0412 - val_mae: 0.1281 - val_mse: 0.0412
# Epoch 15/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0208 - mae: 0.0988 - mse: 0.0208
# Epoch 15: val_loss improved from 0.04121 to 0.03822, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0226 - mae: 0.1053 - mse: 0.0226 - val_loss: 0.0382 - val_mae: 0.1208 - val_mse: 0.0382
# Epoch 16/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0201 - mae: 0.0994 - mse: 0.0201
# Epoch 16: val_loss did not improve from 0.03822
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0210 - mae: 0.1002 - mse: 0.0210 - val_loss: 0.0392 - val_mae: 0.1196 - val_mse: 0.0392
# Epoch 17/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0208 - mae: 0.0954 - mse: 0.0208
# Epoch 17: val_loss did not improve from 0.03822
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0185 - mae: 0.0932 - mse: 0.0185 - val_loss: 0.0382 - val_mae: 0.1201 - val_mse: 0.0382
# Epoch 18/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0176 - mae: 0.0922 - mse: 0.0176
# Epoch 18: val_loss improved from 0.03822 to 0.03556, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0181 - mae: 0.0931 - mse: 0.0181 - val_loss: 0.0356 - val_mae: 0.1125 - val_mse: 0.0356
# Epoch 19/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0137 - mae: 0.0815 - mse: 0.0137
# Epoch 19: val_loss improved from 0.03556 to 0.03425, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0161 - mae: 0.0866 - mse: 0.0161 - val_loss: 0.0342 - val_mae: 0.1082 - val_mse: 0.0342
# Epoch 20/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0140 - mae: 0.0823 - mse: 0.0140
# Epoch 20: val_loss did not improve from 0.03425
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0155 - mae: 0.0857 - mse: 0.0155 - val_loss: 0.0350 - val_mae: 0.1128 - val_mse: 0.0350
# Epoch 21/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0147 - mae: 0.0837 - mse: 0.0147
# Epoch 21: val_loss improved from 0.03425 to 0.03300, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0149 - mae: 0.0847 - mse: 0.0149 - val_loss: 0.0330 - val_mae: 0.1070 - val_mse: 0.0330
# Epoch 22/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0149 - mae: 0.0824 - mse: 0.0149
# Epoch 22: val_loss improved from 0.03300 to 0.03186, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0143 - mae: 0.0813 - mse: 0.0143 - val_loss: 0.0319 - val_mae: 0.1078 - val_mse: 0.0319
# Epoch 23/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0153 - mae: 0.0858 - mse: 0.0153
# Epoch 23: val_loss improved from 0.03186 to 0.02860, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0149 - mae: 0.0827 - mse: 0.0149 - val_loss: 0.0286 - val_mae: 0.1021 - val_mse: 0.0286
# Epoch 24/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0131 - mae: 0.0765 - mse: 0.0131
# Epoch 24: val_loss improved from 0.02860 to 0.02818, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0128 - mae: 0.0777 - mse: 0.0128 - val_loss: 0.0282 - val_mae: 0.0997 - val_mse: 0.0282
# Epoch 25/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0121 - mae: 0.0735 - mse: 0.0121
# Epoch 25: val_loss improved from 0.02818 to 0.02720, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0119 - mae: 0.0742 - mse: 0.0119 - val_loss: 0.0272 - val_mae: 0.0966 - val_mse: 0.0272
# Epoch 26/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0098 - mae: 0.0659 - mse: 0.0098
# Epoch 26: val_loss improved from 0.02720 to 0.02675, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0108 - mae: 0.0709 - mse: 0.0108 - val_loss: 0.0268 - val_mae: 0.0965 - val_mse: 0.0268
# Epoch 27/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0100 - mae: 0.0704 - mse: 0.0100
# Epoch 27: val_loss improved from 0.02675 to 0.02537, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0104 - mae: 0.0712 - mse: 0.0104 - val_loss: 0.0254 - val_mae: 0.0909 - val_mse: 0.0254
# Epoch 28/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0091 - mae: 0.0627 - mse: 0.0091
# Epoch 28: val_loss improved from 0.02537 to 0.02504, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0093 - mae: 0.0658 - mse: 0.0093 - val_loss: 0.0250 - val_mae: 0.0881 - val_mse: 0.0250
# Epoch 29/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0082 - mae: 0.0619 - mse: 0.0082
# Epoch 29: val_loss did not improve from 0.02504
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0089 - mae: 0.0641 - mse: 0.0089 - val_loss: 0.0257 - val_mae: 0.0879 - val_mse: 0.0257
# Epoch 30/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081 - mae: 0.0627 - mse: 0.0081
# Epoch 30: val_loss did not improve from 0.02504
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084 - mae: 0.0616 - mse: 0.0084 - val_loss: 0.0255 - val_mae: 0.0861 - val_mse: 0.0255
# Epoch 31/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0085 - mae: 0.0616 - mse: 0.0085
# Epoch 31: val_loss improved from 0.02504 to 0.02325, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0075 - mae: 0.0586 - mse: 0.0075 - val_loss: 0.0233 - val_mae: 0.0835 - val_mse: 0.0233
# Epoch 32/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0086 - mae: 0.0612 - mse: 0.0086
# Epoch 32: val_loss improved from 0.02325 to 0.02292, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0077 - mae: 0.0579 - mse: 0.0077 - val_loss: 0.0229 - val_mae: 0.0817 - val_mse: 0.0229
# Epoch 33/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - mae: 0.0585 - mse: 0.0072
# Epoch 33: val_loss did not improve from 0.02292
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0071 - mae: 0.0580 - mse: 0.0071 - val_loss: 0.0235 - val_mae: 0.0816 - val_mse: 0.0235
# Epoch 34/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062 - mae: 0.0541 - mse: 0.0062
# Epoch 34: val_loss did not improve from 0.02292
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - mae: 0.0571 - mse: 0.0073 - val_loss: 0.0249 - val_mae: 0.0823 - val_mse: 0.0249
# Epoch 35/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081 - mae: 0.0568 - mse: 0.0081
# Epoch 35: val_loss did not improve from 0.02292
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0067 - mae: 0.0549 - mse: 0.0067 - val_loss: 0.0232 - val_mae: 0.0790 - val_mse: 0.0232
# Epoch 36/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - mae: 0.0497 - mse: 0.0055
# Epoch 36: val_loss improved from 0.02292 to 0.02275, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060 - mae: 0.0522 - mse: 0.0060 - val_loss: 0.0227 - val_mae: 0.0790 - val_mse: 0.0227
# Epoch 37/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - mae: 0.0560 - mse: 0.0075
# Epoch 37: val_loss improved from 0.02275 to 0.02107, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0080 - mae: 0.0589 - mse: 0.0080 - val_loss: 0.0211 - val_mae: 0.0783 - val_mse: 0.0211
# Epoch 38/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - mae: 0.0518 - mse: 0.0059
# Epoch 38: val_loss did not improve from 0.02107
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0064 - mae: 0.0545 - mse: 0.0064 - val_loss: 0.0214 - val_mae: 0.0815 - val_mse: 0.0214
# Epoch 39/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - mae: 0.0579 - mse: 0.0076
# Epoch 39: val_loss did not improve from 0.02107
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0068 - mae: 0.0563 - mse: 0.0068 - val_loss: 0.0223 - val_mae: 0.0799 - val_mse: 0.0223
# Epoch 40/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0057 - mae: 0.0525 - mse: 0.0057
# Epoch 40: val_loss did not improve from 0.02107
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - mae: 0.0527 - mse: 0.0059 - val_loss: 0.0221 - val_mae: 0.0756 - val_mse: 0.0221
# Epoch 41/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - mae: 0.0489 - mse: 0.0053
# Epoch 41: val_loss improved from 0.02107 to 0.02067, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0052 - mae: 0.0494 - mse: 0.0052 - val_loss: 0.0207 - val_mae: 0.0745 - val_mse: 0.0207
# Epoch 42/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0050 - mae: 0.0464 - mse: 0.0050
# Epoch 42: val_loss improved from 0.02067 to 0.02025, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0051 - mae: 0.0486 - mse: 0.0051 - val_loss: 0.0202 - val_mae: 0.0708 - val_mse: 0.0202
# Epoch 43/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0056 - mae: 0.0501 - mse: 0.0056
# Epoch 43: val_loss did not improve from 0.02025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - mae: 0.0473 - mse: 0.0047 - val_loss: 0.0206 - val_mae: 0.0710 - val_mse: 0.0206
# Epoch 44/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - mae: 0.0404 - mse: 0.0038
# Epoch 44: val_loss did not improve from 0.02025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - mae: 0.0437 - mse: 0.0043 - val_loss: 0.0211 - val_mae: 0.0735 - val_mse: 0.0211
# Epoch 45/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0055 - mae: 0.0478 - mse: 0.0055
# Epoch 45: val_loss did not improve from 0.02025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - mae: 0.0466 - mse: 0.0048 - val_loss: 0.0212 - val_mae: 0.0704 - val_mse: 0.0212
# Epoch 46/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0045 - mae: 0.0447 - mse: 0.0045
# Epoch 46: val_loss did not improve from 0.02025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0045 - mae: 0.0458 - mse: 0.0045 - val_loss: 0.0207 - val_mae: 0.0714 - val_mse: 0.0207
# Epoch 47/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - mae: 0.0421 - mse: 0.0032
# Epoch 47: val_loss did not improve from 0.02025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - mae: 0.0453 - mse: 0.0044 - val_loss: 0.0205 - val_mae: 0.0692 - val_mse: 0.0205
# Epoch 48/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - mae: 0.0401 - mse: 0.0036
# Epoch 48: val_loss did not improve from 0.02025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0040 - mae: 0.0426 - mse: 0.0040 - val_loss: 0.0210 - val_mae: 0.0694 - val_mse: 0.0210
# Epoch 49/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0039 - mae: 0.0408 - mse: 0.0039
# Epoch 49: val_loss did not improve from 0.02025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0039 - mae: 0.0414 - mse: 0.0039 - val_loss: 0.0211 - val_mae: 0.0696 - val_mse: 0.0211
# Epoch 50/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0035 - mae: 0.0396 - mse: 0.0035
# Epoch 50: val_loss did not improve from 0.02025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0046 - mae: 0.0417 - mse: 0.0046 - val_loss: 0.0256 - val_mae: 0.0786 - val_mse: 0.0256
# Epoch 51/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - mae: 0.0395 - mse: 0.0038
# Epoch 51: val_loss did not improve from 0.02025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - mae: 0.0455 - mse: 0.0073 - val_loss: 0.0217 - val_mae: 0.0738 - val_mse: 0.0217
# Epoch 52/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - mae: 0.0409 - mse: 0.0042
# Epoch 52: val_loss did not improve from 0.02025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - mae: 0.0448 - mse: 0.0047 - val_loss: 0.0228 - val_mae: 0.0779 - val_mse: 0.0228
# Epoch 53/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031 - mae: 0.0390 - mse: 0.0031
# Epoch 53: val_loss did not improve from 0.02025
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - mae: 0.0438 - mse: 0.0043 - val_loss: 0.0209 - val_mae: 0.0730 - val_mse: 0.0209
# Epoch 54/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0037 - mae: 0.0428 - mse: 0.0037
# Epoch 54: val_loss improved from 0.02025 to 0.02012, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0040 - mae: 0.0447 - mse: 0.0040 - val_loss: 0.0201 - val_mae: 0.0716 - val_mse: 0.0201
# Epoch 55/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047 - mae: 0.0481 - mse: 0.0047
# Epoch 55: val_loss did not improve from 0.02012
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0412 - mse: 0.0035 - val_loss: 0.0204 - val_mae: 0.0688 - val_mse: 0.0204
# Epoch 56/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - mae: 0.0383 - mse: 0.0033
# Epoch 56: val_loss improved from 0.02012 to 0.02001, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - mae: 0.0407 - mse: 0.0035 - val_loss: 0.0200 - val_mae: 0.0665 - val_mse: 0.0200
# Epoch 57/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0033 - mae: 0.0397 - mse: 0.0033
# Epoch 57: val_loss improved from 0.02001 to 0.01857, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0383 - mse: 0.0031 - val_loss: 0.0186 - val_mae: 0.0642 - val_mse: 0.0186
# Epoch 58/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026 - mae: 0.0344 - mse: 0.0026
# Epoch 58: val_loss did not improve from 0.01857
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - mae: 0.0365 - mse: 0.0029 - val_loss: 0.0186 - val_mae: 0.0650 - val_mse: 0.0186
# Epoch 59/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022 - mae: 0.0348 - mse: 0.0022
# Epoch 59: val_loss did not improve from 0.01857
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030 - mae: 0.0382 - mse: 0.0030 - val_loss: 0.0194 - val_mae: 0.0664 - val_mse: 0.0194
# Epoch 60/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mae: 0.0405 - mse: 0.0035
# Epoch 60: val_loss did not improve from 0.01857
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0034 - mae: 0.0399 - mse: 0.0034 - val_loss: 0.0190 - val_mae: 0.0639 - val_mse: 0.0190
# Epoch 61/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - mae: 0.0403 - mse: 0.0035
# Epoch 61: val_loss did not improve from 0.01857
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0410 - mse: 0.0035 - val_loss: 0.0200 - val_mae: 0.0676 - val_mse: 0.0200
# Epoch 62/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029 - mae: 0.0370 - mse: 0.0029
# Epoch 62: val_loss did not improve from 0.01857
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - mae: 0.0405 - mse: 0.0035 - val_loss: 0.0203 - val_mae: 0.0679 - val_mse: 0.0203
# Epoch 63/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0024 - mae: 0.0357 - mse: 0.0024
# Epoch 63: val_loss did not improve from 0.01857
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030 - mae: 0.0385 - mse: 0.0030 - val_loss: 0.0214 - val_mae: 0.0680 - val_mse: 0.0214
# Epoch 64/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - mae: 0.0402 - mse: 0.0035
# Epoch 64: val_loss did not improve from 0.01857
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - mae: 0.0387 - mse: 0.0031 - val_loss: 0.0200 - val_mae: 0.0663 - val_mse: 0.0200
# Epoch 65/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024 - mae: 0.0349 - mse: 0.0024
# Epoch 65: val_loss did not improve from 0.01857
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029 - mae: 0.0377 - mse: 0.0029 - val_loss: 0.0192 - val_mae: 0.0653 - val_mse: 0.0192
# Epoch 66/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mae: 0.0412 - mse: 0.0034
# Epoch 66: val_loss improved from 0.01857 to 0.01839, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027 - mae: 0.0368 - mse: 0.0027 - val_loss: 0.0184 - val_mae: 0.0633 - val_mse: 0.0184
# Epoch 67/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0023 - mae: 0.0334 - mse: 0.0023
# Epoch 67: val_loss did not improve from 0.01839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024 - mae: 0.0340 - mse: 0.0024 - val_loss: 0.0192 - val_mae: 0.0644 - val_mse: 0.0192
# Epoch 68/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0365 - mse: 0.0028
# Epoch 68: val_loss did not improve from 0.01839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025 - mae: 0.0350 - mse: 0.0025 - val_loss: 0.0190 - val_mae: 0.0628 - val_mse: 0.0190
# Epoch 69/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023 - mae: 0.0325 - mse: 0.0023
# Epoch 69: val_loss did not improve from 0.01839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - mae: 0.0330 - mse: 0.0023 - val_loss: 0.0192 - val_mae: 0.0638 - val_mse: 0.0192
# Epoch 70/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - mae: 0.0312 - mse: 0.0022
# Epoch 70: val_loss did not improve from 0.01839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0024 - mae: 0.0330 - mse: 0.0024 - val_loss: 0.0186 - val_mae: 0.0612 - val_mse: 0.0186
# Epoch 71/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0020 - mae: 0.0334 - mse: 0.0020
# Epoch 71: val_loss did not improve from 0.01839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023 - mae: 0.0336 - mse: 0.0023 - val_loss: 0.0188 - val_mae: 0.0593 - val_mse: 0.0188
# Epoch 72/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mae: 0.0302 - mse: 0.0018
# Epoch 72: val_loss did not improve from 0.01839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - mae: 0.0303 - mse: 0.0019 - val_loss: 0.0191 - val_mae: 0.0618 - val_mse: 0.0191
# Epoch 73/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016 - mae: 0.0288 - mse: 0.0016
# Epoch 73: val_loss did not improve from 0.01839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020 - mae: 0.0315 - mse: 0.0020 - val_loss: 0.0187 - val_mae: 0.0609 - val_mse: 0.0187
# Epoch 74/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - mae: 0.0300 - mse: 0.0019
# Epoch 74: val_loss did not improve from 0.01839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mae: 0.0298 - mse: 0.0018 - val_loss: 0.0190 - val_mae: 0.0598 - val_mse: 0.0190
# Epoch 75/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020 - mae: 0.0321 - mse: 0.0020
# Epoch 75: val_loss did not improve from 0.01839
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - mae: 0.0293 - mse: 0.0017 - val_loss: 0.0184 - val_mae: 0.0580 - val_mse: 0.0184
# Epoch 76/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - mae: 0.0279 - mse: 0.0017
# Epoch 76: val_loss improved from 0.01839 to 0.01735, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - mae: 0.0277 - mse: 0.0016 - val_loss: 0.0174 - val_mae: 0.0565 - val_mse: 0.0174
# Epoch 77/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016 - mae: 0.0279 - mse: 0.0016
# Epoch 77: val_loss did not improve from 0.01735
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0268 - mse: 0.0015 - val_loss: 0.0182 - val_mae: 0.0568 - val_mse: 0.0182
# Epoch 78/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0019 - mae: 0.0293 - mse: 0.0019
# Epoch 78: val_loss did not improve from 0.01735
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016 - mae: 0.0277 - mse: 0.0016 - val_loss: 0.0185 - val_mae: 0.0569 - val_mse: 0.0185
# Epoch 79/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0268 - mse: 0.0015
# Epoch 79: val_loss did not improve from 0.01735
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0266 - mse: 0.0015 - val_loss: 0.0177 - val_mae: 0.0569 - val_mse: 0.0177
# Epoch 80/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0258 - mse: 0.0015
# Epoch 80: val_loss did not improve from 0.01735
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016 - mae: 0.0274 - mse: 0.0016 - val_loss: 0.0176 - val_mae: 0.0548 - val_mse: 0.0176
# Epoch 81/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.7864e-04 - mae: 0.0223 - mse: 9.7864e-04
# Epoch 81: val_loss did not improve from 0.01735
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - mae: 0.0257 - mse: 0.0014 - val_loss: 0.0176 - val_mae: 0.0544 - val_mse: 0.0176
# Epoch 82/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - mae: 0.0241 - mse: 0.0012
# Epoch 82: val_loss did not improve from 0.01735
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0250 - mse: 0.0013 - val_loss: 0.0176 - val_mae: 0.0541 - val_mse: 0.0176
# Epoch 83/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mae: 0.0235 - mse: 0.0011
# Epoch 83: val_loss did not improve from 0.01735
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0251 - mse: 0.0013 - val_loss: 0.0181 - val_mae: 0.0546 - val_mse: 0.0181
# Epoch 84/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0250 - mse: 0.0012
# Epoch 84: val_loss did not improve from 0.01735
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mae: 0.0254 - mse: 0.0014 - val_loss: 0.0177 - val_mae: 0.0545 - val_mse: 0.0177
# Epoch 85/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0245 - mse: 0.0012
# Epoch 85: val_loss did not improve from 0.01735
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0252 - mse: 0.0013 - val_loss: 0.0188 - val_mae: 0.0538 - val_mse: 0.0188
# Epoch 86/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0251 - mse: 0.0013
# Epoch 86: val_loss did not improve from 0.01735
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0014 - mae: 0.0255 - mse: 0.0014 - val_loss: 0.0182 - val_mae: 0.0532 - val_mse: 0.0182
# Epoch 87/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.5652e-04 - mae: 0.0218 - mse: 9.5652e-04
# Epoch 87: val_loss did not improve from 0.01735
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mae: 0.0241 - mse: 0.0012 - val_loss: 0.0175 - val_mae: 0.0533 - val_mse: 0.0175
# Epoch 88/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - mae: 0.0253 - mse: 0.0013
# Epoch 88: val_loss improved from 0.01735 to 0.01710, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - mae: 0.0251 - mse: 0.0013 - val_loss: 0.0171 - val_mae: 0.0530 - val_mse: 0.0171
# Epoch 89/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0231 - mse: 0.0011
# Epoch 89: val_loss did not improve from 0.01710
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - mae: 0.0246 - mse: 0.0013 - val_loss: 0.0178 - val_mae: 0.0530 - val_mse: 0.0178
# Epoch 90/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0014 - mae: 0.0259 - mse: 0.0014
# Epoch 90: val_loss did not improve from 0.01710
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0260 - mse: 0.0015 - val_loss: 0.0180 - val_mae: 0.0556 - val_mse: 0.0180
# Epoch 91/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mae: 0.0277 - mse: 0.0017
# Epoch 91: val_loss improved from 0.01710 to 0.01692, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - mae: 0.0263 - mse: 0.0014 - val_loss: 0.0169 - val_mae: 0.0528 - val_mse: 0.0169
# Epoch 92/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0253 - mse: 0.0013
# Epoch 92: val_loss did not improve from 0.01692
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0249 - mse: 0.0012 - val_loss: 0.0171 - val_mae: 0.0538 - val_mse: 0.0171
# Epoch 93/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - mae: 0.0276 - mse: 0.0015
# Epoch 93: val_loss did not improve from 0.01692
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0258 - mse: 0.0013 - val_loss: 0.0173 - val_mae: 0.0535 - val_mse: 0.0173
# Epoch 94/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0011 - mae: 0.0230 - mse: 0.0011
# Epoch 94: val_loss improved from 0.01692 to 0.01671, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - mae: 0.0256 - mse: 0.0013 - val_loss: 0.0167 - val_mae: 0.0521 - val_mse: 0.0167
# Epoch 95/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9400e-04 - mae: 0.0225 - mse: 9.9400e-04
# Epoch 95: val_loss did not improve from 0.01671
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - mae: 0.0270 - mse: 0.0015 - val_loss: 0.0175 - val_mae: 0.0524 - val_mse: 0.0175
# Epoch 96/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0016 - mae: 0.0277 - mse: 0.0016
# Epoch 96: val_loss did not improve from 0.01671
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0018 - mae: 0.0281 - mse: 0.0018 - val_loss: 0.0177 - val_mae: 0.0537 - val_mse: 0.0177
# Epoch 97/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013 - mae: 0.0252 - mse: 0.0013
# Epoch 97: val_loss did not improve from 0.01671
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mae: 0.0263 - mse: 0.0014 - val_loss: 0.0174 - val_mae: 0.0525 - val_mse: 0.0174
# Epoch 98/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mae: 0.0237 - mse: 0.0011
# Epoch 98: val_loss did not improve from 0.01671
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mae: 0.0262 - mse: 0.0014 - val_loss: 0.0172 - val_mae: 0.0529 - val_mse: 0.0172
# Epoch 99/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mae: 0.0267 - mse: 0.0014
# Epoch 99: val_loss did not improve from 0.01671
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mae: 0.0254 - mse: 0.0014 - val_loss: 0.0186 - val_mae: 0.0541 - val_mse: 0.0186
# Epoch 100/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016 - mae: 0.0284 - mse: 0.0016
# Epoch 100: val_loss did not improve from 0.01671
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015 - mae: 0.0266 - mse: 0.0015 - val_loss: 0.0176 - val_mae: 0.0526 - val_mse: 0.0176
# Epoch 101/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014 - mae: 0.0259 - mse: 0.0014
# Epoch 101: val_loss improved from 0.01671 to 0.01664, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - mae: 0.0234 - mse: 0.0011 - val_loss: 0.0166 - val_mae: 0.0511 - val_mse: 0.0166
# Epoch 102/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mae: 0.0226 - mse: 0.0011
# Epoch 102: val_loss did not improve from 0.01664
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0227 - mse: 0.0011 - val_loss: 0.0172 - val_mae: 0.0507 - val_mse: 0.0172
# Epoch 103/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5313e-04 - mae: 0.0217 - mse: 9.5313e-04
# Epoch 103: val_loss did not improve from 0.01664
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.6712e-04 - mae: 0.0221 - mse: 9.6712e-04 - val_loss: 0.0175 - val_mae: 0.0508 - val_mse: 0.0175
# Epoch 104/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mae: 0.0225 - mse: 0.0010
# Epoch 104: val_loss did not improve from 0.01664
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mae: 0.0218 - mse: 0.0010 - val_loss: 0.0175 - val_mae: 0.0483 - val_mse: 0.0175
# Epoch 105/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7549e-04 - mae: 0.0209 - mse: 8.7549e-04
# Epoch 105: val_loss did not improve from 0.01664
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0532e-04 - mae: 0.0210 - mse: 9.0532e-04 - val_loss: 0.0170 - val_mae: 0.0485 - val_mse: 0.0170
# Epoch 106/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0229 - mse: 0.0011
# Epoch 106: val_loss improved from 0.01664 to 0.01662, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0673e-04 - mae: 0.0210 - mse: 9.0673e-04 - val_loss: 0.0166 - val_mae: 0.0480 - val_mse: 0.0166
# Epoch 107/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.7263e-04 - mae: 0.0197 - mse: 7.7263e-04
# Epoch 107: val_loss did not improve from 0.01662
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3229e-04 - mae: 0.0201 - mse: 8.3229e-04 - val_loss: 0.0169 - val_mae: 0.0482 - val_mse: 0.0169
# Epoch 108/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7528e-04 - mae: 0.0207 - mse: 8.7528e-04
# Epoch 108: val_loss did not improve from 0.01662
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5054e-04 - mae: 0.0204 - mse: 8.5054e-04 - val_loss: 0.0170 - val_mae: 0.0479 - val_mse: 0.0170
# Epoch 109/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1453e-04 - mae: 0.0186 - mse: 7.1453e-04
# Epoch 109: val_loss did not improve from 0.01662
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7442e-04 - mae: 0.0205 - mse: 8.7442e-04 - val_loss: 0.0171 - val_mae: 0.0479 - val_mse: 0.0171
# Epoch 110/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1648e-04 - mae: 0.0186 - mse: 7.1648e-04
# Epoch 110: val_loss did not improve from 0.01662
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4470e-04 - mae: 0.0199 - mse: 8.4470e-04 - val_loss: 0.0168 - val_mae: 0.0473 - val_mse: 0.0168
# Epoch 111/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0492e-04 - mae: 0.0187 - mse: 7.0492e-04
# Epoch 111: val_loss improved from 0.01662 to 0.01618, saving model to ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/model/GR-MAREMMA_fed_model.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.3325e-04 - mae: 0.0199 - mse: 8.3325e-04 - val_loss: 0.0162 - val_mae: 0.0475 - val_mse: 0.0162
# Epoch 112/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9021e-04 - mae: 0.0209 - mse: 9.9021e-04
# Epoch 112: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7303e-04 - mae: 0.0203 - mse: 8.7303e-04 - val_loss: 0.0168 - val_mae: 0.0476 - val_mse: 0.0168
# Epoch 113/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8574e-04 - mae: 0.0218 - mse: 9.8574e-04
# Epoch 113: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.2081e-04 - mae: 0.0200 - mse: 8.2081e-04 - val_loss: 0.0170 - val_mae: 0.0474 - val_mse: 0.0170
# Epoch 114/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1209e-04 - mae: 0.0185 - mse: 7.1209e-04
# Epoch 114: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.2682e-04 - mae: 0.0207 - mse: 9.2682e-04 - val_loss: 0.0171 - val_mae: 0.0477 - val_mse: 0.0171
# Epoch 115/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.0061e-04 - mae: 0.0208 - mse: 9.0061e-04
# Epoch 115: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7949e-04 - mae: 0.0206 - mse: 8.7949e-04 - val_loss: 0.0171 - val_mae: 0.0479 - val_mse: 0.0171
# Epoch 116/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0576e-04 - mae: 0.0198 - mse: 8.0576e-04
# Epoch 116: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0570e-04 - mae: 0.0197 - mse: 8.0570e-04 - val_loss: 0.0167 - val_mae: 0.0480 - val_mse: 0.0167
# Epoch 117/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2930e-04 - mae: 0.0214 - mse: 9.2930e-04
# Epoch 117: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.4806e-04 - mae: 0.0193 - mse: 7.4806e-04 - val_loss: 0.0166 - val_mae: 0.0461 - val_mse: 0.0166
# Epoch 118/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4941e-04 - mae: 0.0190 - mse: 7.4941e-04
# Epoch 118: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.0725e-04 - mae: 0.0184 - mse: 7.0725e-04 - val_loss: 0.0168 - val_mae: 0.0461 - val_mse: 0.0168
# Epoch 119/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 7.5588e-04 - mae: 0.0189 - mse: 7.5588e-04
# Epoch 119: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0888e-04 - mae: 0.0183 - mse: 7.0888e-04 - val_loss: 0.0169 - val_mae: 0.0459 - val_mse: 0.0169
# Epoch 120/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0480e-04 - mae: 0.0179 - mse: 7.0480e-04
# Epoch 120: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8413e-04 - mae: 0.0182 - mse: 6.8413e-04 - val_loss: 0.0169 - val_mae: 0.0452 - val_mse: 0.0169
# Epoch 121/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9706e-04 - mae: 0.0179 - mse: 6.9706e-04
# Epoch 121: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3240e-04 - mae: 0.0191 - mse: 7.3240e-04 - val_loss: 0.0166 - val_mae: 0.0468 - val_mse: 0.0166
# Epoch 122/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8014e-04 - mae: 0.0185 - mse: 6.8014e-04
# Epoch 122: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3332e-04 - mae: 0.0201 - mse: 8.3332e-04 - val_loss: 0.0169 - val_mae: 0.0475 - val_mse: 0.0169
# Epoch 123/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1119e-04 - mae: 0.0200 - mse: 8.1119e-04
# Epoch 123: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6279e-04 - mae: 0.0194 - mse: 7.6279e-04 - val_loss: 0.0168 - val_mae: 0.0463 - val_mse: 0.0168
# Epoch 124/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.9209e-04 - mae: 0.0199 - mse: 7.9209e-04
# Epoch 124: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4200e-04 - mae: 0.0195 - mse: 7.4200e-04 - val_loss: 0.0165 - val_mae: 0.0449 - val_mse: 0.0165
# Epoch 125/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6355e-04 - mae: 0.0199 - mse: 7.6355e-04
# Epoch 125: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2938e-04 - mae: 0.0179 - mse: 6.2938e-04 - val_loss: 0.0168 - val_mae: 0.0460 - val_mse: 0.0168
# Epoch 126/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7593e-04 - mae: 0.0199 - mse: 7.7593e-04
# Epoch 126: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6483e-04 - mae: 0.0182 - mse: 6.6483e-04 - val_loss: 0.0169 - val_mae: 0.0453 - val_mse: 0.0169
# Epoch 127/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1022e-04 - mae: 0.0171 - mse: 6.1022e-04
# Epoch 127: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4768e-04 - mae: 0.0178 - mse: 6.4768e-04 - val_loss: 0.0167 - val_mae: 0.0449 - val_mse: 0.0167
# Epoch 128/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3937e-04 - mae: 0.0190 - mse: 7.3937e-04
# Epoch 128: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8685e-04 - mae: 0.0183 - mse: 6.8685e-04 - val_loss: 0.0169 - val_mae: 0.0464 - val_mse: 0.0169
# Epoch 129/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3487e-04 - mae: 0.0178 - mse: 6.3487e-04
# Epoch 129: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1524e-04 - mae: 0.0187 - mse: 7.1524e-04 - val_loss: 0.0170 - val_mae: 0.0464 - val_mse: 0.0170
# Epoch 130/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6721e-04 - mae: 0.0185 - mse: 6.6721e-04
# Epoch 130: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.7830e-04 - mae: 0.0187 - mse: 6.7830e-04 - val_loss: 0.0170 - val_mae: 0.0454 - val_mse: 0.0170
# Epoch 131/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6540e-04 - mae: 0.0152 - mse: 4.6540e-04
# Epoch 131: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3543e-04 - mae: 0.0177 - mse: 6.3543e-04 - val_loss: 0.0167 - val_mae: 0.0452 - val_mse: 0.0167
# Epoch 132/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8841e-04 - mae: 0.0162 - mse: 4.8841e-04
# Epoch 132: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1571e-04 - mae: 0.0189 - mse: 7.1571e-04 - val_loss: 0.0166 - val_mae: 0.0458 - val_mse: 0.0166
# Epoch 133/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9953e-04 - mae: 0.0186 - mse: 6.9953e-04
# Epoch 133: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7681e-04 - mae: 0.0181 - mse: 6.7681e-04 - val_loss: 0.0168 - val_mae: 0.0447 - val_mse: 0.0168
# Epoch 134/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0560e-04 - mae: 0.0160 - mse: 5.0560e-04
# Epoch 134: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2037e-04 - mae: 0.0174 - mse: 6.2037e-04 - val_loss: 0.0167 - val_mae: 0.0453 - val_mse: 0.0167
# Epoch 135/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6495e-04 - mae: 0.0172 - mse: 5.6495e-04
# Epoch 135: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4272e-04 - mae: 0.0179 - mse: 6.4272e-04 - val_loss: 0.0167 - val_mae: 0.0465 - val_mse: 0.0167
# Epoch 136/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9859e-04 - mae: 0.0179 - mse: 6.9859e-04
# Epoch 136: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6315e-04 - mae: 0.0180 - mse: 6.6315e-04 - val_loss: 0.0168 - val_mae: 0.0453 - val_mse: 0.0168
# Epoch 137/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9276e-04 - mae: 0.0173 - mse: 5.9276e-04
# Epoch 137: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6029e-04 - mae: 0.0180 - mse: 6.6029e-04 - val_loss: 0.0166 - val_mae: 0.0449 - val_mse: 0.0166
# Epoch 138/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.5428e-04 - mae: 0.0167 - mse: 5.5428e-04
# Epoch 138: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.1048e-04 - mae: 0.0174 - mse: 6.1048e-04 - val_loss: 0.0166 - val_mae: 0.0455 - val_mse: 0.0166
# Epoch 139/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5280e-04 - mae: 0.0171 - mse: 5.5280e-04
# Epoch 139: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8230e-04 - mae: 0.0183 - mse: 6.8230e-04 - val_loss: 0.0169 - val_mae: 0.0452 - val_mse: 0.0169
# Epoch 140/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9686e-04 - mae: 0.0163 - mse: 5.9686e-04
# Epoch 140: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6901e-04 - mae: 0.0182 - mse: 7.6901e-04 - val_loss: 0.0167 - val_mae: 0.0459 - val_mse: 0.0167
# Epoch 141/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3284e-04 - mae: 0.0183 - mse: 6.3284e-04
# Epoch 141: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 6.6239e-04 - mae: 0.0185 - mse: 6.6239e-04 - val_loss: 0.0164 - val_mae: 0.0432 - val_mse: 0.0164
# Epoch 142/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1795e-04 - mae: 0.0159 - mse: 5.1795e-04
# Epoch 142: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5375e-04 - mae: 0.0178 - mse: 6.5375e-04 - val_loss: 0.0166 - val_mae: 0.0445 - val_mse: 0.0166
# Epoch 143/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7137e-04 - mae: 0.0184 - mse: 6.7137e-04
# Epoch 143: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1500e-04 - mae: 0.0175 - mse: 6.1500e-04 - val_loss: 0.0172 - val_mae: 0.0470 - val_mse: 0.0172
# Epoch 144/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0762e-04 - mae: 0.0194 - mse: 9.0762e-04
# Epoch 144: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.1498e-04 - mae: 0.0182 - mse: 8.1498e-04 - val_loss: 0.0165 - val_mae: 0.0432 - val_mse: 0.0165
# Epoch 145/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6133e-04 - mae: 0.0170 - mse: 5.6133e-04
# Epoch 145: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8608e-04 - mae: 0.0171 - mse: 5.8608e-04 - val_loss: 0.0165 - val_mae: 0.0451 - val_mse: 0.0165
# Epoch 146/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7167e-04 - mae: 0.0169 - mse: 5.7167e-04
# Epoch 146: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2237e-04 - mae: 0.0177 - mse: 6.2237e-04 - val_loss: 0.0165 - val_mae: 0.0446 - val_mse: 0.0165
# Epoch 147/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3834e-04 - mae: 0.0161 - mse: 5.3834e-04
# Epoch 147: val_loss did not improve from 0.01618
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0703e-04 - mae: 0.0175 - mse: 6.0703e-04 - val_loss: 0.0168 - val_mae: 0.0444 - val_mse: 0.0168
# Epoch 148/1000
# ...
# Epoch 948: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9141e-04 - mae: 0.0204 - mse: 7.9141e-04 - val_loss: 0.0143 - val_mae: 0.0387 - val_mse: 0.0143
# Epoch 949/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8075e-04 - mae: 0.0200 - mse: 6.8075e-04
# Epoch 949: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5546e-04 - mae: 0.0209 - mse: 7.5546e-04 - val_loss: 0.0156 - val_mae: 0.0421 - val_mse: 0.0156
# Epoch 950/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6588e-04 - mae: 0.0221 - mse: 8.6588e-04
# Epoch 950: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7194e-04 - mae: 0.0229 - mse: 9.7194e-04 - val_loss: 0.0157 - val_mae: 0.0433 - val_mse: 0.0157
# Epoch 951/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0533e-04 - mae: 0.0200 - mse: 9.0533e-04
# Epoch 951: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7281e-04 - mae: 0.0214 - mse: 9.7281e-04 - val_loss: 0.0149 - val_mae: 0.0456 - val_mse: 0.0149
# Epoch 952/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9514e-04 - mae: 0.0224 - mse: 8.9514e-04
# Epoch 952: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8607e-04 - mae: 0.0211 - mse: 7.8607e-04 - val_loss: 0.0151 - val_mae: 0.0427 - val_mse: 0.0151
# Epoch 953/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.1837e-04 - mae: 0.0193 - mse: 6.1837e-04
# Epoch 953: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5069e-04 - mae: 0.0193 - mse: 6.5069e-04 - val_loss: 0.0154 - val_mae: 0.0408 - val_mse: 0.0154
# Epoch 954/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2234e-04 - mae: 0.0176 - mse: 5.2234e-04
# Epoch 954: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7431e-04 - mae: 0.0186 - mse: 5.7431e-04 - val_loss: 0.0146 - val_mae: 0.0370 - val_mse: 0.0146
# Epoch 955/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2551e-04 - mae: 0.0141 - mse: 3.2551e-04
# Epoch 955: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2065e-04 - mae: 0.0163 - mse: 4.2065e-04 - val_loss: 0.0154 - val_mae: 0.0398 - val_mse: 0.0154
# Epoch 956/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5740e-04 - mae: 0.0154 - mse: 4.5740e-04
# Epoch 956: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6134e-04 - mae: 0.0179 - mse: 6.6134e-04 - val_loss: 0.0149 - val_mae: 0.0415 - val_mse: 0.0149
# Epoch 957/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6550e-04 - mae: 0.0162 - mse: 4.6550e-04
# Epoch 957: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6535e-04 - mae: 0.0193 - mse: 7.6535e-04 - val_loss: 0.0153 - val_mae: 0.0421 - val_mse: 0.0153
# Epoch 958/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8134e-04 - mae: 0.0187 - mse: 6.8134e-04
# Epoch 958: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.2365e-04 - mae: 0.0200 - mse: 7.2365e-04 - val_loss: 0.0159 - val_mae: 0.0408 - val_mse: 0.0159
# Epoch 959/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2564e-04 - mae: 0.0177 - mse: 5.2564e-04
# Epoch 959: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3670e-04 - mae: 0.0196 - mse: 6.3670e-04 - val_loss: 0.0149 - val_mae: 0.0389 - val_mse: 0.0149
# Epoch 960/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5786e-04 - mae: 0.0143 - mse: 3.5786e-04
# Epoch 960: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5269e-04 - mae: 0.0180 - mse: 5.5269e-04 - val_loss: 0.0152 - val_mae: 0.0375 - val_mse: 0.0152
# Epoch 961/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7782e-04 - mae: 0.0142 - mse: 3.7782e-04
# Epoch 961: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8893e-04 - mae: 0.0180 - mse: 5.8893e-04 - val_loss: 0.0148 - val_mae: 0.0384 - val_mse: 0.0148
# Epoch 962/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2024e-04 - mae: 0.0162 - mse: 5.2024e-04
# Epoch 962: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1379e-04 - mae: 0.0180 - mse: 6.1379e-04 - val_loss: 0.0148 - val_mae: 0.0413 - val_mse: 0.0148
# Epoch 963/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5288e-04 - mae: 0.0200 - mse: 6.5288e-04
# Epoch 963: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mae: 0.0225 - mse: 0.0010 - val_loss: 0.0150 - val_mae: 0.0435 - val_mse: 0.0150
# Epoch 964/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0256 - mse: 0.0013
# Epoch 964: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mae: 0.0253 - mse: 0.0013 - val_loss: 0.0152 - val_mae: 0.0411 - val_mse: 0.0152
# Epoch 965/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3583e-04 - mae: 0.0198 - mse: 7.3583e-04
# Epoch 965: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2773e-04 - mae: 0.0218 - mse: 9.2773e-04 - val_loss: 0.0159 - val_mae: 0.0470 - val_mse: 0.0159
# Epoch 966/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0221 - mse: 0.0012
# Epoch 966: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7755e-04 - mae: 0.0210 - mse: 9.7755e-04 - val_loss: 0.0158 - val_mae: 0.0438 - val_mse: 0.0158
# Epoch 967/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.9382e-04 - mae: 0.0189 - mse: 6.9382e-04
# Epoch 967: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1892e-04 - mae: 0.0191 - mse: 7.1892e-04 - val_loss: 0.0150 - val_mae: 0.0404 - val_mse: 0.0150
# Epoch 968/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4622e-04 - mae: 0.0201 - mse: 7.4622e-04
# Epoch 968: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2726e-04 - mae: 0.0214 - mse: 9.2726e-04 - val_loss: 0.0150 - val_mae: 0.0430 - val_mse: 0.0150
# Epoch 969/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7101e-04 - mae: 0.0197 - mse: 7.7101e-04
# Epoch 969: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6116e-04 - mae: 0.0208 - mse: 7.6116e-04 - val_loss: 0.0148 - val_mae: 0.0381 - val_mse: 0.0148
# Epoch 970/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1413e-04 - mae: 0.0174 - mse: 5.1413e-04
# Epoch 970: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2717e-04 - mae: 0.0176 - mse: 5.2717e-04 - val_loss: 0.0149 - val_mae: 0.0369 - val_mse: 0.0149
# Epoch 971/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0982e-04 - mae: 0.0168 - mse: 5.0982e-04
# Epoch 971: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2274e-04 - mae: 0.0172 - mse: 5.2274e-04 - val_loss: 0.0142 - val_mae: 0.0368 - val_mse: 0.0142
# Epoch 972/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1116e-04 - mae: 0.0137 - mse: 3.1116e-04
# Epoch 972: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5662e-04 - mae: 0.0161 - mse: 4.5662e-04 - val_loss: 0.0156 - val_mae: 0.0385 - val_mse: 0.0156
# Epoch 973/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4834e-04 - mae: 0.0172 - mse: 5.4834e-04
# Epoch 973: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3818e-04 - mae: 0.0177 - mse: 7.3818e-04 - val_loss: 0.0150 - val_mae: 0.0393 - val_mse: 0.0150
# Epoch 974/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5780e-04 - mae: 0.0182 - mse: 6.5780e-04
# Epoch 974: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4840e-04 - mae: 0.0195 - mse: 7.4840e-04 - val_loss: 0.0153 - val_mae: 0.0419 - val_mse: 0.0153
# Epoch 975/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5208e-04 - mae: 0.0185 - mse: 7.5208e-04
# Epoch 975: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mae: 0.0226 - mse: 0.0011 - val_loss: 0.0157 - val_mae: 0.0402 - val_mse: 0.0157
# Epoch 976/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9211e-04 - mae: 0.0163 - mse: 4.9211e-04
# Epoch 976: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1899e-04 - mae: 0.0204 - mse: 7.1899e-04 - val_loss: 0.0152 - val_mae: 0.0408 - val_mse: 0.0152
# Epoch 977/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4896e-04 - mae: 0.0174 - mse: 5.4896e-04
# Epoch 977: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8841e-04 - mae: 0.0220 - mse: 9.8841e-04 - val_loss: 0.0146 - val_mae: 0.0415 - val_mse: 0.0146
# Epoch 978/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3672e-04 - mae: 0.0222 - mse: 9.3672e-04
# Epoch 978: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mae: 0.0270 - mse: 0.0015 - val_loss: 0.0154 - val_mae: 0.0423 - val_mse: 0.0154
# Epoch 979/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mae: 0.0222 - mse: 0.0012
# Epoch 979: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mae: 0.0266 - mse: 0.0015 - val_loss: 0.0166 - val_mae: 0.0471 - val_mse: 0.0166
# Epoch 980/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mae: 0.0258 - mse: 0.0014
# Epoch 980: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016 - mae: 0.0275 - mse: 0.0016 - val_loss: 0.0154 - val_mae: 0.0431 - val_mse: 0.0154
# Epoch 981/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0230 - mse: 0.0011
# Epoch 981: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mae: 0.0253 - mse: 0.0013 - val_loss: 0.0158 - val_mae: 0.0475 - val_mse: 0.0158
# Epoch 982/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0230 - mse: 0.0013
# Epoch 982: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mae: 0.0266 - mse: 0.0015 - val_loss: 0.0147 - val_mae: 0.0526 - val_mse: 0.0147
# Epoch 983/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mae: 0.0313 - mse: 0.0017
# Epoch 983: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mae: 0.0330 - mse: 0.0020 - val_loss: 0.0173 - val_mae: 0.0563 - val_mse: 0.0173
# Epoch 984/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022 - mae: 0.0339 - mse: 0.0022
# Epoch 984: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0397 - mse: 0.0031 - val_loss: 0.0176 - val_mae: 0.0556 - val_mse: 0.0176
# Epoch 985/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mae: 0.0310 - mse: 0.0017
# Epoch 985: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - mae: 0.0345 - mse: 0.0020 - val_loss: 0.0152 - val_mae: 0.0485 - val_mse: 0.0152
# Epoch 986/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mae: 0.0247 - mse: 0.0010
# Epoch 986: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mae: 0.0327 - mse: 0.0019 - val_loss: 0.0149 - val_mae: 0.0483 - val_mse: 0.0149
# Epoch 987/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015 - mae: 0.0275 - mse: 0.0015
# Epoch 987: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018 - mae: 0.0317 - mse: 0.0018 - val_loss: 0.0143 - val_mae: 0.0447 - val_mse: 0.0143
# Epoch 988/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0259 - mse: 0.0012
# Epoch 988: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - mae: 0.0293 - mse: 0.0015 - val_loss: 0.0144 - val_mae: 0.0452 - val_mse: 0.0144
# Epoch 989/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mae: 0.0237 - mse: 0.0010
# Epoch 989: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mae: 0.0249 - mse: 0.0011 - val_loss: 0.0157 - val_mae: 0.0485 - val_mse: 0.0157
# Epoch 990/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7593e-04 - mae: 0.0222 - mse: 8.7593e-04
# Epoch 990: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021 - mae: 0.0283 - mse: 0.0021 - val_loss: 0.0151 - val_mae: 0.0467 - val_mse: 0.0151
# Epoch 991/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0244 - mse: 0.0012
# Epoch 991: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mae: 0.0284 - mse: 0.0015 - val_loss: 0.0149 - val_mae: 0.0493 - val_mse: 0.0149
# Epoch 992/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0018 - mae: 0.0298 - mse: 0.0018
# Epoch 992: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019 - mae: 0.0302 - mse: 0.0019 - val_loss: 0.0167 - val_mae: 0.0499 - val_mse: 0.0167
# Epoch 993/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056 - mae: 0.0353 - mse: 0.0056
# Epoch 993: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0307 - mse: 0.0028 - val_loss: 0.0164 - val_mae: 0.0539 - val_mse: 0.0164
# Epoch 994/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019 - mae: 0.0313 - mse: 0.0019
# Epoch 994: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mae: 0.0299 - mse: 0.0017 - val_loss: 0.0147 - val_mae: 0.0497 - val_mse: 0.0147
# Epoch 995/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mae: 0.0289 - mse: 0.0017
# Epoch 995: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mae: 0.0285 - mse: 0.0015 - val_loss: 0.0146 - val_mae: 0.0479 - val_mse: 0.0146
# Epoch 996/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - mae: 0.0251 - mse: 0.0011
# Epoch 996: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0013 - mae: 0.0264 - mse: 0.0013 - val_loss: 0.0142 - val_mae: 0.0435 - val_mse: 0.0142
# Epoch 997/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4314e-04 - mae: 0.0222 - mse: 8.4314e-04
# Epoch 997: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012 - mae: 0.0245 - mse: 0.0012 - val_loss: 0.0145 - val_mae: 0.0470 - val_mse: 0.0145
# Epoch 998/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0258 - mse: 0.0012
# Epoch 998: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mae: 0.0255 - mse: 0.0015 - val_loss: 0.0143 - val_mae: 0.0423 - val_mse: 0.0143
# Epoch 999/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.0591e-04 - mae: 0.0222 - mse: 9.0591e-04
# Epoch 999: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2743e-04 - mae: 0.0227 - mse: 9.2743e-04 - val_loss: 0.0149 - val_mae: 0.0439 - val_mse: 0.0149
# Epoch 1000/1000
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mae: 0.0237 - mse: 0.0012
# Epoch 1000: val_loss did not improve from 0.01312
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2533e-04 - mae: 0.0212 - mse: 9.2533e-04 - val_loss: 0.0136 - val_mae: 0.0428 - val_mse: 0.0136
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# --- federated after local fine-tuning ---
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_1841/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Salvo 62 plot in: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/federated_fd/TEST
# Plot salvati correttamente.
# Test MAE: 0.0145
# Test RMSE: 0.0507
# Test MAPE: 0.51%
# Test R2: 0.9906
# Valore medio del test set: 3.0654
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_GR-MAREMMA_14-19-03/federated_fd_evaluation_log.json
