# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import os, pickle, random
from datetime import datetime

# %%
get_after_QA = lambda s: s.split("QA_", 1)[1]

# %%
dati = pd.read_excel('/Users/lapotinacci/thesis/metric_datasets/NO2_dataset.xlsx')
dati = dati[dati["serviceUri"] == "http://www.disit.org/km4city/resource/iot/orionUNIFI/DISIT/ARPAT_QA_FI-SETTIGNANO"].copy()
sensor_name = get_after_QA(dati["serviceUri"].iloc[0])
dati.drop(columns=["serviceUri"], inplace=True)
print(dati.shape)
# Out:
# (308, 16)

# %%
# === Creazione cartella esperimento con timestamp ISO ===
timestamp = datetime.now().strftime("%H-%M-%S")
print(f"Ora inizio esperimento: {timestamp}")
day= datetime.now().strftime("%Y-%m-%d")
print(f"Giorno inizio esperimento: {day}")
exp_dir = f"../RISULTATI/{day}/esperimento_{sensor_name}_{timestamp}"

os.makedirs(exp_dir, exist_ok=True)

print(f"Cartella esperimento creata: {exp_dir}")
# Out:
# Ora inizio esperimento: 14-19-14
# Giorno inizio esperimento: 2025-11-30
# Cartella esperimento creata: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14

# %%
import ast

mask = ~dati['TTT'].str.contains("nan", na=True)
dtset_completo = dati[mask]

dtset_completo['TTT'] = dtset_completo['TTT'].apply(ast.literal_eval)

# %%
# Filtra le righe dove la colonna TTT ha lunghezza 24, ed elimina tutte le colonne le cui osservazioni sono indipendenti dal giorno
dtset_filtrato = dtset_completo[dtset_completo["TTT"].apply(lambda x: len(x) == 24)].sample(frac=1).reset_index(drop=True)
dtset_filtrato = dtset_filtrato[dtset_filtrato["type_of_TTT"] == "daily"]
len(dtset_filtrato)
# Out:
# 272

# %%
import numpy as np


def is_useful_series(series, zero_ratio_thr=0.85, min_nonzero_value=0.1):
    arr = np.array(series, dtype=float)
    
    # Serie troppo corta
    if len(arr) <= 1:
        return False
    
    # Troppi zeri
    zero_ratio = (arr == 0).mean()
    if zero_ratio >= zero_ratio_thr:
        return False
    
    # Valore medio trascurabile (quasi zero)
    mean_val = np.mean(arr)
    if abs(mean_val) < min_nonzero_value:
        return False
    
    # Se arriva qui, la serie ha valori significativi
    return True

# Applica filtro
mask_useful = dtset_filtrato["TTT"].apply(is_useful_series)
df_useful = dtset_filtrato[mask_useful]

# %%
def spezza_serie_in_colonne(df, colonna_stringa, prefix='col_'):
    # --- Controllo colonna ---
    if colonna_stringa not in df.columns:
        raise ValueError(f"La colonna '{colonna_stringa}' non esiste nel DataFrame")

    result_df = df.copy()

    # Estraggo la colonna contenente gli embedding
    col = result_df.pop(colonna_stringa)

    embeddings = []

    for item in col:
        if pd.isna(item) or item == "":
            embeddings.append([])
            continue
        
        try:
            # Parsing sicuro della stringa in lista Python
            vett = ast.literal_eval(item)

            # Se l’embedding è una numpy array o altro iterabile, lo converto in list
            if not isinstance(vett, list):
                vett = list(vett)

            # Converto tutto in float
            vett = [float(x) for x in vett]

            embeddings.append(vett)

        except Exception as e:
            print(f"Errore nel parsing dell'elemento '{item}': {e}")
            embeddings.append([])

    # --- Uniformo dimensione dei vettori ---
    lengths = [len(v) for v in embeddings]
    if not lengths:
        raise ValueError("Nessun embedding valido nella colonna")

    max_len = max(lengths)

    embeddings_padded = [
        v + [np.nan] * (max_len - len(v)) if len(v) < max_len else v
        for v in embeddings
    ]

    # --- Creo DataFrame delle nuove colonne ---
    colonne_embedding = pd.DataFrame(
        embeddings_padded,
        index=result_df.index,
        columns=[f"{prefix}{i}" for i in range(max_len)]
    )

    # --- Merge col DataFrame originale ---
    return pd.concat([result_df, colonne_embedding], axis=1)

# %%
for ttt in df_useful.TTT:
    plt.plot(ttt)

# %%
def summary_df(df):
    summary = pd.DataFrame({
        'dtype': df.dtypes,
        'n_missing': df.isna().sum(),
        '%_missing': (df.isna().mean() * 100).round(2),
        'n_unique': df.nunique(),
        'top_value': df.mode().iloc[0],  # moda
        'top_freq': [df[col].value_counts(dropna=True).iloc[0] if not df[col].value_counts(dropna=True).empty else None for col in df.columns],
        'min': [df[col].min() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'max': [df[col].max() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'mean': [df[col].mean() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'std': [df[col].std() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
    })
    return summary

# %%
#Nella precedente sono state eliminate le colonne con Nan, tuttavia alcuni dataset dei sensori METRO hanno dei Nan in city e surface dunque vengono rimossi nel prcedente box

categorical = [
    'is_weekend'
    ]

#consiglio, per serie cicliche usare funzioni periodiche tipo seno coseno 
df_encoded = pd.get_dummies(df_useful
                            , columns=categorical)

# %%
def save_pkl(obj, path):
    with open(path, "wb") as f:
        pickle.dump(obj, f)
    print(f"Salvato: {path}")

def load_pkl(path):
    with open(path, "rb") as f:
        return pickle.load(f)

# %%
#codifica ciclica delle features e individuazione del'ora del giorno e della settimana 

def encode_time_features(df, start_col="interval_start", end_col="interval_end"):
    df = df.copy()
    
    # Step 1: Ensure datetime columns are in the correct format first
    df[start_col] = pd.to_datetime(df[start_col], utc=True, format="mixed")
    df[end_col] = pd.to_datetime(df[end_col], utc=True, format="mixed")

    # Step 2: Extract 'month' and 'day' after conversion
    df['month'] = df[start_col].dt.month
    df['day'] = df[start_col].dt.dayofweek # Note: dayofweek is typically used for cyclical weekly patterns
    
    # Step 3: Now you can create the cyclical features
    df['month_sin'] = np.sin(2 * np.pi * df['month']/len(df['month'].unique()))
    df['month_cos'] = np.cos(2 * np.pi * df['month']/len(df['month'].unique()))
    df['day_sin'] = np.sin(2 * np.pi * df['day']/len(df['day'].unique()))
    df['day_cos'] = np.cos(2 * np.pi * df['day']/len(df['day'].unique()))


    # Ora del giorno (0-23) → ciclo giornaliero
    df["hour"] = df[start_col].dt.hour
    angle_day_start = 2 * np.pi * df["hour"] / 24
    df["start_time_sin"] = np.sin(angle_day_start)
    df["start_time_cos"] = np.cos(angle_day_start)

    df["hour_end"] = df[end_col].dt.hour
    angle_day_end = 2 * np.pi * df["hour_end"] / 24
    df["end_time_sin"] = np.sin(angle_day_end)
    df["end_time_cos"] = np.cos(angle_day_end)

    # Durata in minuti
    df["duration_minutes"] = (df[end_col] - df[start_col]).dt.total_seconds() / 60

    # Giorno della settimana (0=Mon..6=Sun) → ciclo settimanale
    dayofweek = df[start_col].dt.dayofweek
    angle_week = 2 * np.pi * dayofweek / 7
    df["dow_sin"] = np.sin(angle_week)
    df["dow_cos"] = np.cos(angle_week)

    # Giorno dell’anno (1-365) → ciclo annuale
    dayofyear = df[start_col].dt.dayofyear
    angle_year = 2 * np.pi * dayofyear / 365
    df["doy_sin"] = np.sin(angle_year)
    df["doy_cos"] = np.cos(angle_year)

    # Rimuovo colonne temporali e variabili ausiliarie
    df = df.drop(columns=[start_col, end_col, "hour", "hour_end", "day", "month"])
    return df

embedding_cols = ['highway_embedding', 'AreaTypeEmbeddings']

df_final = encode_time_features(df_encoded)
df_final.drop(columns=['type_of_TTT'], inplace=True)
for emb_col in embedding_cols:
    df_final = spezza_serie_in_colonne(df_final, emb_col, prefix=f'{emb_col}_')
df_final.shape

# Salvataggio DataFrame finale
df_path = os.path.join(exp_dir, f"dataframe_{sensor_name}")
os.makedirs(df_path, exist_ok=True)
save_pkl(df_final, os.path.join(df_path, f"filtered_dataframe.pkl"))
# Out:
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/dataframe_FI-SETTIGNANO/filtered_dataframe.pkl

# %%
for ttt in df_final.TTT[10:20]:
    plt.plot(ttt)
    plt.title("Esempi di TTT ARPAT")
    plt.xlabel("Ora del Giorno")
    plt.ylabel("Valore TTT")

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

def series_to_2d_array(series, output_dim=24):
    arr = np.stack(series.apply(lambda x: np.array(x, dtype=np.float32)))
    if arr.shape[1] != output_dim:
        raise ValueError(f"Ogni elemento deve avere {output_dim} valori, trovato {arr.shape[1]}")
    return arr

 # Separazione delle feature e del target
X = df_final.drop(columns=['TTT'])
y = df_final['TTT']

X_np = X.to_numpy().astype(np.float32)
y_np = series_to_2d_array(y, output_dim=24)

# Calcolo deviazione standard per ogni serie
std_scores = np.std(y_np, axis=1)

std_scores_log = np.log1p(std_scores)  # log(1+x) per evitare problemi con valori vicini a 0

std_scores_normalized = (std_scores_log - np.min(std_scores_log)) / (np.max(std_scores_log) - np.min(std_scores_log))

# Creo bin basati sui quantili
bins = np.array([0.0, 0.4, 0.8, 1.0])
std_bins = np.digitize(std_scores_normalized, bins)

# Primo split: train (80%) vs temp (20%)
# Passo anche std_bins per poter stratificare
X_train, X_test, y_train, y_test = train_test_split(
    X_np, y_np,
    test_size=0.2,
    random_state=42,
    stratify=std_bins, 
    shuffle=True
)

print(f"Train size: {X_train.shape}, {y_train.shape}")
print(f"Test size: {X_test.shape}, {y_test.shape}")

# Debug prints
print(f"Final shapes:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

# Scaler per input
scaler_X = StandardScaler()
X_train = scaler_X.fit_transform(X_train)
X_test  = scaler_X.transform(X_test)

# Scaler per output (se serve normalizzare anche y)
scaler_y = StandardScaler()
y_train = scaler_y.fit_transform(y_train)
y_test  = scaler_y.transform(y_test)

#cartella salvataggio train e test
path = os.path.join(exp_dir, "train_test_data")
os.makedirs(path, exist_ok=True)

#  === Salvataggio dataset e scaler in formato .pkl ===
save_pkl(scaler_X.inverse_transform(X_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_X.inverse_transform(X_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_test_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_test_unscaled_{sensor_name}.pkl"))


save_pkl(X_train, os.path.join(exp_dir, "X_train.pkl"))
save_pkl(y_train, os.path.join(exp_dir, "y_train.pkl"))
save_pkl(X_test, os.path.join(exp_dir, "X_test.pkl"))
save_pkl(y_test, os.path.join(exp_dir, "y_test.pkl"))

save_pkl(scaler_X, os.path.join(exp_dir, "scaler_X.pkl"))
save_pkl(scaler_y, os.path.join(exp_dir, "scaler_y.pkl"))

print("Scaler salvati.")

print("\nTutti i file sono stati salvati correttamente.")
print(f"Percorso cartella: {os.path.abspath(exp_dir)}")
# Out:
# Train size: (217, 33), (217, 24)
# Test size: (55, 33), (55, 24)
# Final shapes:
# X_train: (217, 33)
# y_train: (217, 24)
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_train_unscaled_FI-SETTIGNANO.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_train_unscaled_FI-SETTIGNANO.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_test_unscaled_FI-SETTIGNANO.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_test_unscaled_FI-SETTIGNANO.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/X_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/y_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/X_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/y_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/scaler_X.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/scaler_y.pkl
# Scaler salvati.
#
# Tutti i file sono stati salvati correttamente.
# Percorso cartella: /Users/lapotinacci/thesis/Federated_Sys/RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14

# %%
# === Costruisci i path ===
path_X_train = os.path.join(exp_dir, "X_train.pkl")
path_y_train = os.path.join(exp_dir, "y_train.pkl")
path_X_test  = os.path.join(exp_dir, "X_test.pkl")
path_y_test  = os.path.join(exp_dir, "y_test.pkl")

path_scaler_X = os.path.join(exp_dir, "scaler_X.pkl")
path_scaler_y = os.path.join(exp_dir, "scaler_y.pkl")

# === Ricaricamento ===
X_train = load_pkl(path_X_train)
y_train = load_pkl(path_y_train)
X_test  = load_pkl(path_X_test)
y_test  = load_pkl(path_y_test)


scaler_X = load_pkl(path_scaler_X)
scaler_y = load_pkl(path_scaler_y)

print("Shapes ricostruite:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

print("\nScaler caricati:")
print("scaler_X:", type(scaler_X))
print("scaler_y:", type(scaler_y))
# Out:
# Shapes ricostruite:
# X_train: (217, 33)
# y_train: (217, 24)
# X_test: (55, 33)
# y_test: (55, 24)
#
# Scaler caricati:
# scaler_X: <class 'sklearn.preprocessing._data.StandardScaler'>
# scaler_y: <class 'sklearn.preprocessing._data.StandardScaler'>

# %% [markdown]
# # modelli

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers # type: ignore
from tensorflow.keras.layers import Dropout # type: ignore
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
def save_prediction_plots(y_true, y_pred, output_dir, prefix="pred_plot"):
    os.makedirs(output_dir, exist_ok=True)

    n = len(y_true)
    print(f"Salvo {n} plot in: {output_dir}")

    for i in range(n):
        plt.figure(figsize=(8, 3))
        plt.plot(y_true[i], label="True")
        plt.plot(y_pred[i], label="Pred")
        plt.legend()
        plt.tight_layout()

        filename = f"{prefix}_{i+1}.png"
        path = os.path.join(output_dir, filename)

        plt.savefig(path)
        plt.close()

    print("Plot salvati correttamente.")

# %%
# Definizione modello DNN
def build_model(input_shape: tuple, output_shape: tuple):
    model = models.Sequential([
        layers.Dense(128, activation = "relu", input_shape=input_shape),
        Dropout(0.0),
        layers.Dense(output_shape, 'linear')
    ])
    model.compile(
    optimizer=optimizers.AdamW(learning_rate=0.0025, weight_decay=0.0437),
    loss= 'mse',
    metrics=['mae'],
    )
    return model

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',      # metrica da monitorare, es. val_loss o val_mae
    patience=350,             # numero di epoche senza miglioramento prima di fermare
    restore_best_weights=True,  # ripristina i pesi migliori trovati
    verbose = 1
)

# Training del modello
model = build_model((X_test.shape[1],), y_test.shape[1])
history = model.fit(
    X_train, y_train,
    epochs=1000,
    batch_size=64,
    callbacks = [early_stop],
    validation_split = 0.2,
    verbose=1
    )

'''print("y_train min/max:", y_train_np.min(), y_train_np.max())
print("y_pred min/max (scaled):", y_pred.min(), y_pred.max())
y_pred_rescaled = scaler_y.inverse_transform(y_pred)
print("y_pred_rescaled min/max:", y_pred_rescaled.min(), y_pred_rescaled.max())'''

if not os.path.exists(os.path.join(exp_dir, "model")):
    os.makedirs(os.path.join(exp_dir, "model"))
    model.save(os.path.join(exp_dir, "model", "NO2_MAREMMA_model.keras"))
# Out:
# Epoch 1/1000
# /Users/lapotinacci/thesis/Federated_Sys/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3896e-05 - mae: 0.0028 - val_loss: 3.0826e-05 - val_mae: 0.0039
# Epoch 982/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5549e-05 - mae: 0.0029 - val_loss: 2.7658e-05 - val_mae: 0.0036
# Epoch 983/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5056e-05 - mae: 0.0029 - val_loss: 2.6849e-05 - val_mae: 0.0038
# Epoch 984/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5948e-05 - mae: 0.0029 - val_loss: 3.1617e-05 - val_mae: 0.0040
# Epoch 985/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5541e-05 - mae: 0.0030 - val_loss: 2.6808e-05 - val_mae: 0.0039
# Epoch 986/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5933e-05 - mae: 0.0030 - val_loss: 2.4376e-05 - val_mae: 0.0036
# Epoch 987/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7234e-05 - mae: 0.0031 - val_loss: 3.1602e-05 - val_mae: 0.0041
# Epoch 988/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5403e-05 - mae: 0.0029 - val_loss: 2.8017e-05 - val_mae: 0.0039
# Epoch 989/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5591e-05 - mae: 0.0030 - val_loss: 2.8131e-05 - val_mae: 0.0037
# Epoch 990/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5060e-05 - mae: 0.0029 - val_loss: 2.3393e-05 - val_mae: 0.0035
# Epoch 991/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3414e-05 - mae: 0.0027 - val_loss: 2.3177e-05 - val_mae: 0.0035
# Epoch 992/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3563e-05 - mae: 0.0028 - val_loss: 3.2767e-05 - val_mae: 0.0040
# Epoch 993/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5557e-05 - mae: 0.0030 - val_loss: 2.4689e-05 - val_mae: 0.0037
# Epoch 994/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4959e-05 - mae: 0.0029 - val_loss: 2.2028e-05 - val_mae: 0.0035
# Epoch 995/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3280e-05 - mae: 0.0028 - val_loss: 2.6375e-05 - val_mae: 0.0036
# Epoch 996/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3715e-05 - mae: 0.0028 - val_loss: 2.5765e-05 - val_mae: 0.0035
# Epoch 997/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5455e-05 - mae: 0.0029 - val_loss: 2.3817e-05 - val_mae: 0.0035
# Epoch 998/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9575e-05 - mae: 0.0031 - val_loss: 2.6245e-05 - val_mae: 0.0038
# Epoch 999/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.7833e-05 - mae: 0.0032 - val_loss: 2.9326e-05 - val_mae: 0.0039
# Epoch 1000/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8909e-05 - mae: 0.0033 - val_loss: 2.7650e-05 - val_mae: 0.0039
# Restoring model weights from the end of the best epoch: 994.

# %%
model = tf.keras.models.load_model(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') if os.path.exists(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') else model

# %%
# Estrai losses da tutti i folds
train_losses = history.history['loss']
val_losses   = history.history['val_loss']

train_losses = train_losses
val_losses = val_losses

# Plot
plt.figure(figsize=(8,5))


# Training loss
plt.plot(train_losses, color='blue', label='Train Loss')
# Validation loss
plt.plot(val_losses, color='red', label='Validation Loss')


# Dettagli grafico
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.savefig(f'{exp_dir}/loss_plot.png')

# %%
def plot_first_n_series(y_pred, y_test, n_series=10, title="Confronto Serie Predette vs Reali"):
    """
    Plotta le prime n_series serie reali e predette per un confronto diretto.

    Args:
        y_pred (np.ndarray): Predizioni del modello (shape: num_samples x seq_len).
        y_test (np.ndarray): Serie reali (shape: num_samples x seq_len).
        n_series (int): Numero di serie da plottare.
        title (str): Titolo del grafico.
    """

    # Limitiamo a n_series per evitare problemi
    n = min(n_series, y_pred.shape[0], y_test.shape[0])

    plt.figure(figsize=(14, 8))

    for i in range(n):
        plt.plot(
            y_test[i], 
            linewidth=1.8, 
            alpha=0.5, 
            label=f"Reale {i+1}" if i == 0 else "",
            color = 'blue'
        )
        plt.plot(
            y_pred[i], 
            linewidth=1.2, 
            linestyle="--", 
            alpha=0.9, 
            label=f"Predetto {i+1}" if i == 0 else "",
            color = 'orange'
        )

    plt.title(title, fontsize=16)
    plt.xlabel("Time Step", fontsize=12)
    plt.ylabel("Valore", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

def plot_diagnosis_gradient(y_pred, y_test, save_path: str,  tolerance:float =0.05, max_samples_heatmap=50, scatter_sample_ratio=0.5, tol_auto = True):
    """
    Dashboard diagnostica con tolleranza AUTO-ADATTIVA alla scala dei dati.
    
    Args:
        tolerance (float): 
            - Se None: La tolleranza viene calcolata automaticamente come il 5% del range dei dati (Max-Min).
            - Se float: Valore assoluto (es. 0.5).
        tol_auto (bool): Se True, usa la tolleranza automatica basata sul range dei dati, altrimenti usa il valore manuale fornito 
        col parametro tolerance.
    """
    
    y_test_flat = y_test.flatten()
    y_pred_flat = y_pred.flatten()

    # ---------------------------------------------------------
    # AUTOMAZIONE TOLLERANZA
    # ---------------------------------------------------------
    if tol_auto:
        data_range = y_test_flat.max() - y_test_flat.min()
        # Impostiamo la tolleranza al 5% del range totale (regolabile)
        tolerance = data_range * tolerance 
        tol_label = f"Auto (5% Range: ±{tolerance:.2f})"
    else:
        tol_label = f"Manuale (±{tolerance})"

    fig, axes = plt.subplots(1, 2, figsize=(22, 8))

    # -----------------------------
    # 1. HEATMAP (SX)
    # -----------------------------
    errors = np.abs(y_test - y_pred)
    errors_subset = errors[:max_samples_heatmap]
    
    # Adattiamo anche la scala colori della heatmap alla tolleranza
    # Tutto ciò che è oltre 3 volte la tolleranza è "errore massimo" visivo
    sns.heatmap(errors_subset, cmap="plasma", ax=axes[0], 
                vmax=tolerance * 3,
                cbar_kws={'label': 'Errore Assoluto'})
    
    axes[0].set_title(f"Heatmap Errori (Primi {max_samples_heatmap} campioni)", fontsize=16)
    axes[0].set_xlabel("Time Step", fontsize=12)
    axes[0].set_ylabel("Indice Campione", fontsize=12)

    # -----------------------------
    # 2. SCATTER CON SFONDO GRADIENTE (DX)
    # -----------------------------
    
    # Campionamento dati
    if scatter_sample_ratio < 1.0:
        mask = np.random.rand(len(y_test_flat)) < scatter_sample_ratio
        sample_test = y_test_flat[mask]
        sample_pred = y_pred_flat[mask]
    else:
        sample_test = y_test_flat
        sample_pred = y_pred_flat

    # Calcolo limiti grafico
    min_val = min(y_test_flat.min(), y_pred_flat.min())
    max_val = max(y_test_flat.max(), y_pred_flat.max())
    padding = (max_val - min_val) * 0.05
    plot_min = min_val - padding
    plot_max = max_val + padding

    # --- SFONDO GRADIENTE ---
    grid_x, grid_y = np.meshgrid(
        np.linspace(plot_min, plot_max, 200),
        np.linspace(plot_min, plot_max, 200)
    )
    grid_z = np.abs(grid_y - grid_x)

    im = axes[1].imshow(
        grid_z, 
        extent=(plot_min, plot_max, plot_min, plot_max), 
        origin='lower', 
        cmap='RdYlGn_r', 
        alpha=0.4, 
        vmax=tolerance * 4, # Il rosso satura a 4x della tolleranza
        aspect='auto'
    )

    # --- PUNTI BLU ---
    axes[1].scatter(
        sample_test, 
        sample_pred, 
        alpha=0.6, 
        s=15, 
        color='royalblue', 
        edgecolors='white', 
        linewidth=0.3,
        label='Campioni'
    )

    axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

    # Metriche
    within_tol = np.mean(np.abs(y_test_flat - y_pred_flat) <= tolerance) * 100

    axes[1].set_title(
        f"Bontà delle previsioni con {tol_label}\nValori nel range di Tolleranza: {within_tol:.1f}%", 
        fontsize=16
    )
    axes[1].set_xlabel("Valore Reale", fontsize=12)
    axes[1].set_ylabel("Valore Predetto", fontsize=12)
    axes[1].set_xlim(plot_min, plot_max)
    axes[1].set_ylim(plot_min, plot_max)
    
    cbar = plt.colorbar(im, ax=axes[1], pad=0.02)
    cbar.set_label('Gravità Errore (Distanza da diagonale)')

    plt.tight_layout()
    plt.savefig(f'{exp_dir}/{save_path}.png')

# %%
y_pred = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred)
y_test_np = scaler_y.inverse_transform(y_test)

plot_diagnosis_gradient(y_pred, y_test_np, save_path='pred_quality', max_samples_heatmap=10, scatter_sample_ratio=0.7)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_1859/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

# %%
save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/TEST', prefix="pred_plot")
# Out:
# Salvo 55 plot in: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/TEST
# Plot salvati correttamente.

# %%
import json
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_and_log(y_true, y_pred, log_path="log.json"):
    # --- Metriche ---
    mae = mean_absolute_error(y_true, y_pred, multioutput="uniform_average")
    rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput="uniform_average"))

    mask = y_true != 0
    mape = float(np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100.0)

    r2 = r2_score(y_true, y_pred, multioutput="uniform_average")

    # Valore medio del test set
    v_mean = float(np.mean(y_true))

    # --- Stampa ---
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    print(f"Test MAPE: {mape:.2f}%")
    print(f"Test R2: {r2:.4f}")
    print(f"Valore medio del test set: {v_mean:.4f}")

    # --- Salvataggio log ---
    log_data = {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2,
        "test_mean_value": v_mean
    }

    with open(log_path, "w") as f:
        json.dump(log_data, f, indent=4)

    print(f"\nLog salvato in: {log_path}")
evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/evaluation_log.json")
# Impostazioni pandas per visualizzare tutti i dati
# Out:
# Test MAE: 0.0025
# Test RMSE: 0.0037
# Test MAPE: 0.10%
# Test R2: 1.0000
# Valore medio del test set: 2.8578
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/evaluation_log.json

# %% [markdown]
# # globale e federato

# %%
fed = tf.keras.models.load_model('/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Arpat.keras')

model  = [fed]
model_name = ["federated"]

# %%
checkpoint_filepath = f'{exp_dir}/model/{sensor_name}_fed_model.keras'

# 2. Crea l'istanza della callback
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False, 
    verbose=1
)

# %%
for model, name in zip(model, model_name):
    y_pred = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred)
    y_test_np = scaler_y.inverse_transform(y_test)

    print(f"--- {name} ---")
    #plot_diagnosis_gradient(y_pred, y_test_np, max_samples_heatmap=10, scatter_sample_ratio=0.7)
    evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_evaluation_log.json")
    save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}/TEST', prefix="pred_plot")

    print("\n")
    if name == 'federated':
        model.fit(X_train, y_train, epochs=1000, batch_size=64, callbacks=[model_checkpoint_callback], validation_split=0.2)
        model.load_weights(checkpoint_filepath)
        y_pred = model.predict(X_test)
        y_pred = scaler_y.inverse_transform(y_pred)
        print(f"--- {name} after local fine-tuning ---")
        plot_diagnosis_gradient(y_pred, y_test_np, save_path=f"{name}_pred_quality", max_samples_heatmap=10, scatter_sample_ratio=0.7)
        save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}_fd/TEST', prefix="pred_plot")
        evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_fd_evaluation_log.json")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# --- federated ---
# Test MAE: 0.4450
# Test RMSE: 0.6258
# Test MAPE: 17.49%
# Test R2: 0.5354
# Valore medio del test set: 2.8578
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/federated_evaluation_log.json
# Salvo 55 plot in: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/federated/TEST
# Plot salvati correttamente.
#
#
# Epoch 1/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - loss: 0.4246 - mae: 0.4952 - mse: 0.4246
# Epoch 1: val_loss improved from None to 0.29018, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.3623 - mae: 0.4471 - mse: 0.3623 - val_loss: 0.2902 - val_mae: 0.3993 - val_mse: 0.2902
# Epoch 2/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2148 - mae: 0.3492 - mse: 0.2148
# Epoch 2: val_loss improved from 0.29018 to 0.18997, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2023 - mae: 0.3384 - mse: 0.2023 - val_loss: 0.1900 - val_mae: 0.3179 - val_mse: 0.1900
# Epoch 3/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1453 - mae: 0.2873 - mse: 0.1453
# Epoch 3: val_loss improved from 0.18997 to 0.16230, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1435 - mae: 0.2839 - mse: 0.1435 - val_loss: 0.1623 - val_mae: 0.2884 - val_mse: 0.1623
# Epoch 4/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1290 - mae: 0.2721 - mse: 0.1290
# Epoch 4: val_loss improved from 0.16230 to 0.11717, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1081 - mae: 0.2497 - mse: 0.1081 - val_loss: 0.1172 - val_mae: 0.2493 - val_mse: 0.1172
# Epoch 5/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0849 - mae: 0.2292 - mse: 0.0849
# Epoch 5: val_loss improved from 0.11717 to 0.10187, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0854 - mae: 0.2251 - mse: 0.0854 - val_loss: 0.1019 - val_mae: 0.2313 - val_mse: 0.1019
# Epoch 6/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0710 - mae: 0.2085 - mse: 0.0710
# Epoch 6: val_loss improved from 0.10187 to 0.08236, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0656 - mae: 0.1977 - mse: 0.0656 - val_loss: 0.0824 - val_mae: 0.1986 - val_mse: 0.0824
# Epoch 7/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0441 - mae: 0.1654 - mse: 0.0441
# Epoch 7: val_loss improved from 0.08236 to 0.06888, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0525 - mae: 0.1756 - mse: 0.0525 - val_loss: 0.0689 - val_mae: 0.1850 - val_mse: 0.0689
# Epoch 8/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0437 - mae: 0.1560 - mse: 0.0437
# Epoch 8: val_loss improved from 0.06888 to 0.06488, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0386 - mae: 0.1492 - mse: 0.0386 - val_loss: 0.0649 - val_mae: 0.1691 - val_mse: 0.0649
# Epoch 9/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0331 - mae: 0.1394 - mse: 0.0331
# Epoch 9: val_loss improved from 0.06488 to 0.05726, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0343 - mae: 0.1400 - mse: 0.0343 - val_loss: 0.0573 - val_mae: 0.1616 - val_mse: 0.0573
# Epoch 10/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0328 - mae: 0.1331 - mse: 0.0328
# Epoch 10: val_loss improved from 0.05726 to 0.05029, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0266 - mae: 0.1243 - mse: 0.0266 - val_loss: 0.0503 - val_mae: 0.1419 - val_mse: 0.0503
# Epoch 11/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0198 - mae: 0.1079 - mse: 0.0198
# Epoch 11: val_loss improved from 0.05029 to 0.04333, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0220 - mae: 0.1092 - mse: 0.0220 - val_loss: 0.0433 - val_mae: 0.1263 - val_mse: 0.0433
# Epoch 12/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0203 - mae: 0.1072 - mse: 0.0203
# Epoch 12: val_loss improved from 0.04333 to 0.03628, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0186 - mae: 0.0982 - mse: 0.0186 - val_loss: 0.0363 - val_mae: 0.1174 - val_mse: 0.0363
# Epoch 13/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0142 - mae: 0.0913 - mse: 0.0142
# Epoch 13: val_loss improved from 0.03628 to 0.02674, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0151 - mae: 0.0899 - mse: 0.0151 - val_loss: 0.0267 - val_mae: 0.0987 - val_mse: 0.0267
# Epoch 14/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0103 - mae: 0.0772 - mse: 0.0103
# Epoch 14: val_loss did not improve from 0.02674
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0118 - mae: 0.0790 - mse: 0.0118 - val_loss: 0.0268 - val_mae: 0.0980 - val_mse: 0.0268
# Epoch 15/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0097 - mae: 0.0740 - mse: 0.0097
# Epoch 15: val_loss improved from 0.02674 to 0.02493, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0103 - mae: 0.0727 - mse: 0.0103 - val_loss: 0.0249 - val_mae: 0.0907 - val_mse: 0.0249
# Epoch 16/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - mae: 0.0617 - mse: 0.0067
# Epoch 16: val_loss improved from 0.02493 to 0.02203, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0087 - mae: 0.0663 - mse: 0.0087 - val_loss: 0.0220 - val_mae: 0.0849 - val_mse: 0.0220
# Epoch 17/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0105 - mae: 0.0688 - mse: 0.0105
# Epoch 17: val_loss improved from 0.02203 to 0.01810, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0074 - mae: 0.0610 - mse: 0.0074 - val_loss: 0.0181 - val_mae: 0.0770 - val_mse: 0.0181
# Epoch 18/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0064 - mae: 0.0585 - mse: 0.0064
# Epoch 18: val_loss improved from 0.01810 to 0.01753, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0066 - mae: 0.0564 - mse: 0.0066 - val_loss: 0.0175 - val_mae: 0.0727 - val_mse: 0.0175
# Epoch 19/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076 - mae: 0.0558 - mse: 0.0076
# Epoch 19: val_loss improved from 0.01753 to 0.01536, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0055 - mae: 0.0512 - mse: 0.0055 - val_loss: 0.0154 - val_mae: 0.0656 - val_mse: 0.0154
# Epoch 20/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041 - mae: 0.0465 - mse: 0.0041
# Epoch 20: val_loss improved from 0.01536 to 0.01410, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0048 - mae: 0.0466 - mse: 0.0048 - val_loss: 0.0141 - val_mae: 0.0637 - val_mse: 0.0141
# Epoch 21/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036 - mae: 0.0428 - mse: 0.0036
# Epoch 21: val_loss improved from 0.01410 to 0.01263, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0043 - mae: 0.0444 - mse: 0.0043 - val_loss: 0.0126 - val_mae: 0.0588 - val_mse: 0.0126
# Epoch 22/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - mae: 0.0391 - mse: 0.0028
# Epoch 22: val_loss improved from 0.01263 to 0.01080, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0037 - mae: 0.0405 - mse: 0.0037 - val_loss: 0.0108 - val_mae: 0.0548 - val_mse: 0.0108
# Epoch 23/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - mae: 0.0428 - mse: 0.0048
# Epoch 23: val_loss improved from 0.01080 to 0.00960, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0034 - mae: 0.0390 - mse: 0.0034 - val_loss: 0.0096 - val_mae: 0.0541 - val_mse: 0.0096
# Epoch 24/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - mae: 0.0388 - mse: 0.0040
# Epoch 24: val_loss improved from 0.00960 to 0.00928, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0030 - mae: 0.0370 - mse: 0.0030 - val_loss: 0.0093 - val_mae: 0.0511 - val_mse: 0.0093
# Epoch 25/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mae: 0.0310 - mse: 0.0018
# Epoch 25: val_loss improved from 0.00928 to 0.00872, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0344 - mse: 0.0027 - val_loss: 0.0087 - val_mae: 0.0492 - val_mse: 0.0087
# Epoch 26/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019 - mae: 0.0321 - mse: 0.0019
# Epoch 26: val_loss improved from 0.00872 to 0.00859, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0026 - mae: 0.0335 - mse: 0.0026 - val_loss: 0.0086 - val_mae: 0.0479 - val_mse: 0.0086
# Epoch 27/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - mae: 0.0287 - mse: 0.0015
# Epoch 27: val_loss improved from 0.00859 to 0.00782, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0022 - mae: 0.0309 - mse: 0.0022 - val_loss: 0.0078 - val_mae: 0.0448 - val_mse: 0.0078
# Epoch 28/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031 - mae: 0.0313 - mse: 0.0031
# Epoch 28: val_loss improved from 0.00782 to 0.00688, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0021 - mae: 0.0295 - mse: 0.0021 - val_loss: 0.0069 - val_mae: 0.0421 - val_mse: 0.0069
# Epoch 29/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014 - mae: 0.0265 - mse: 0.0014
# Epoch 29: val_loss improved from 0.00688 to 0.00634, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0019 - mae: 0.0283 - mse: 0.0019 - val_loss: 0.0063 - val_mae: 0.0408 - val_mse: 0.0063
# Epoch 30/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022 - mae: 0.0268 - mse: 0.0022
# Epoch 30: val_loss improved from 0.00634 to 0.00573, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0018 - mae: 0.0273 - mse: 0.0018 - val_loss: 0.0057 - val_mae: 0.0389 - val_mse: 0.0057
# Epoch 31/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - mae: 0.0284 - mse: 0.0015
# Epoch 31: val_loss improved from 0.00573 to 0.00523, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - mae: 0.0266 - mse: 0.0016 - val_loss: 0.0052 - val_mae: 0.0373 - val_mse: 0.0052
# Epoch 32/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - mae: 0.0277 - mse: 0.0021
# Epoch 32: val_loss improved from 0.00523 to 0.00444, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - mae: 0.0265 - mse: 0.0016 - val_loss: 0.0044 - val_mae: 0.0352 - val_mse: 0.0044
# Epoch 33/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mae: 0.0241 - mse: 0.0011
# Epoch 33: val_loss improved from 0.00444 to 0.00429, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - mae: 0.0248 - mse: 0.0014 - val_loss: 0.0043 - val_mae: 0.0342 - val_mse: 0.0043
# Epoch 34/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010 - mae: 0.0217 - mse: 0.0010
# Epoch 34: val_loss improved from 0.00429 to 0.00374, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0013 - mae: 0.0237 - mse: 0.0013 - val_loss: 0.0037 - val_mae: 0.0330 - val_mse: 0.0037
# Epoch 35/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - mae: 0.0232 - mse: 0.0015
# Epoch 35: val_loss improved from 0.00374 to 0.00318, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - mae: 0.0231 - mse: 0.0012 - val_loss: 0.0032 - val_mae: 0.0323 - val_mse: 0.0032
# Epoch 36/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0010 - mae: 0.0228 - mse: 0.0010
# Epoch 36: val_loss did not improve from 0.00318
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - mae: 0.0227 - mse: 0.0012 - val_loss: 0.0035 - val_mae: 0.0317 - val_mse: 0.0035
# Epoch 37/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mae: 0.0236 - mse: 0.0011
# Epoch 37: val_loss improved from 0.00318 to 0.00301, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0010 - mae: 0.0214 - mse: 0.0010 - val_loss: 0.0030 - val_mae: 0.0300 - val_mse: 0.0030
# Epoch 38/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.5287e-04 - mae: 0.0209 - mse: 8.5287e-04
# Epoch 38: val_loss improved from 0.00301 to 0.00252, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.6845e-04 - mae: 0.0210 - mse: 9.6845e-04 - val_loss: 0.0025 - val_mae: 0.0277 - val_mse: 0.0025
# Epoch 39/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4511e-04 - mae: 0.0185 - mse: 6.4511e-04
# Epoch 39: val_loss did not improve from 0.00252
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.6700e-04 - mae: 0.0197 - mse: 8.6700e-04 - val_loss: 0.0025 - val_mae: 0.0276 - val_mse: 0.0025
# Epoch 40/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7501e-04 - mae: 0.0190 - mse: 6.7501e-04
# Epoch 40: val_loss improved from 0.00252 to 0.00222, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.5124e-04 - mae: 0.0199 - mse: 8.5124e-04 - val_loss: 0.0022 - val_mae: 0.0266 - val_mse: 0.0022
# Epoch 41/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8891e-04 - mae: 0.0195 - mse: 9.8891e-04
# Epoch 41: val_loss did not improve from 0.00222
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.6288e-04 - mae: 0.0189 - mse: 7.6288e-04 - val_loss: 0.0022 - val_mae: 0.0258 - val_mse: 0.0022
# Epoch 42/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9871e-04 - mae: 0.0197 - mse: 9.9871e-04
# Epoch 42: val_loss improved from 0.00222 to 0.00201, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.2567e-04 - mae: 0.0182 - mse: 7.2567e-04 - val_loss: 0.0020 - val_mae: 0.0247 - val_mse: 0.0020
# Epoch 43/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8357e-04 - mae: 0.0173 - mse: 7.8357e-04
# Epoch 43: val_loss improved from 0.00201 to 0.00191, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.7529e-04 - mae: 0.0177 - mse: 6.7529e-04 - val_loss: 0.0019 - val_mae: 0.0244 - val_mse: 0.0019
# Epoch 44/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1723e-04 - mae: 0.0168 - mse: 5.1723e-04
# Epoch 44: val_loss improved from 0.00191 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 6.3887e-04 - mae: 0.0171 - mse: 6.3887e-04 - val_loss: 0.0018 - val_mae: 0.0240 - val_mse: 0.0018
# Epoch 45/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.4727e-04 - mae: 0.0160 - mse: 4.4727e-04
# Epoch 45: val_loss improved from 0.00180 to 0.00162, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 6.0042e-04 - mae: 0.0167 - mse: 6.0042e-04 - val_loss: 0.0016 - val_mae: 0.0229 - val_mse: 0.0016
# Epoch 46/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1416e-04 - mae: 0.0167 - mse: 7.1416e-04
# Epoch 46: val_loss improved from 0.00162 to 0.00149, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.8754e-04 - mae: 0.0167 - mse: 5.8754e-04 - val_loss: 0.0015 - val_mae: 0.0220 - val_mse: 0.0015
# Epoch 47/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2139e-04 - mae: 0.0155 - mse: 6.2139e-04
# Epoch 47: val_loss did not improve from 0.00149
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.4085e-04 - mae: 0.0161 - mse: 5.4085e-04 - val_loss: 0.0015 - val_mae: 0.0219 - val_mse: 0.0015
# Epoch 48/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1912e-04 - mae: 0.0129 - mse: 3.1912e-04
# Epoch 48: val_loss improved from 0.00149 to 0.00137, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.0901e-04 - mae: 0.0154 - mse: 5.0901e-04 - val_loss: 0.0014 - val_mae: 0.0214 - val_mse: 0.0014
# Epoch 49/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8500e-04 - mae: 0.0146 - mse: 3.8500e-04
# Epoch 49: val_loss improved from 0.00137 to 0.00115, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 4.8206e-04 - mae: 0.0152 - mse: 4.8206e-04 - val_loss: 0.0012 - val_mae: 0.0201 - val_mse: 0.0012
# Epoch 50/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5362e-04 - mae: 0.0139 - mse: 3.5362e-04
# Epoch 50: val_loss improved from 0.00115 to 0.00106, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.6856e-04 - mae: 0.0151 - mse: 4.6856e-04 - val_loss: 0.0011 - val_mae: 0.0196 - val_mse: 0.0011
# Epoch 51/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1094e-04 - mae: 0.0150 - mse: 5.1094e-04
# Epoch 51: val_loss improved from 0.00106 to 0.00097, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.4637e-04 - mae: 0.0146 - mse: 4.4637e-04 - val_loss: 9.7255e-04 - val_mae: 0.0190 - val_mse: 9.7255e-04
# Epoch 52/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.6308e-04 - mae: 0.0158 - mse: 5.6308e-04
# Epoch 52: val_loss did not improve from 0.00097
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.2875e-04 - mae: 0.0144 - mse: 4.2875e-04 - val_loss: 0.0011 - val_mae: 0.0196 - val_mse: 0.0011
# Epoch 53/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2607e-04 - mae: 0.0133 - mse: 3.2607e-04
# Epoch 53: val_loss improved from 0.00097 to 0.00095, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.0901e-04 - mae: 0.0141 - mse: 4.0901e-04 - val_loss: 9.5155e-04 - val_mae: 0.0186 - val_mse: 9.5155e-04
# Epoch 54/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6269e-04 - mae: 0.0136 - mse: 3.6269e-04
# Epoch 54: val_loss improved from 0.00095 to 0.00091, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.8669e-04 - mae: 0.0138 - mse: 3.8669e-04 - val_loss: 9.1407e-04 - val_mae: 0.0183 - val_mse: 9.1407e-04
# Epoch 55/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.0428e-04 - mae: 0.0141 - mse: 4.0428e-04
# Epoch 55: val_loss improved from 0.00091 to 0.00083, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.6800e-04 - mae: 0.0134 - mse: 3.6800e-04 - val_loss: 8.2812e-04 - val_mae: 0.0178 - val_mse: 8.2812e-04
# Epoch 56/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0942e-04 - mae: 0.0129 - mse: 3.0942e-04
# Epoch 56: val_loss improved from 0.00083 to 0.00080, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.5029e-04 - mae: 0.0131 - mse: 3.5029e-04 - val_loss: 7.9839e-04 - val_mae: 0.0174 - val_mse: 7.9839e-04
# Epoch 57/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6182e-04 - mae: 0.0141 - mse: 4.6182e-04
# Epoch 57: val_loss improved from 0.00080 to 0.00068, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.3908e-04 - mae: 0.0129 - mse: 3.3908e-04 - val_loss: 6.8480e-04 - val_mae: 0.0169 - val_mse: 6.8480e-04
# Epoch 58/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2090e-04 - mae: 0.0136 - mse: 4.2090e-04
# Epoch 58: val_loss improved from 0.00068 to 0.00067, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3437e-04 - mae: 0.0129 - mse: 3.3437e-04 - val_loss: 6.6718e-04 - val_mae: 0.0164 - val_mse: 6.6718e-04
# Epoch 59/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5771e-04 - mae: 0.0128 - mse: 3.5771e-04
# Epoch 59: val_loss did not improve from 0.00067
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1467e-04 - mae: 0.0126 - mse: 3.1467e-04 - val_loss: 6.7171e-04 - val_mae: 0.0164 - val_mse: 6.7171e-04
# Epoch 60/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6514e-04 - mae: 0.0122 - mse: 2.6514e-04
# Epoch 60: val_loss did not improve from 0.00067
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1532e-04 - mae: 0.0126 - mse: 3.1532e-04 - val_loss: 6.7519e-04 - val_mae: 0.0164 - val_mse: 6.7519e-04
# Epoch 61/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6859e-04 - mae: 0.0126 - mse: 2.6859e-04
# Epoch 61: val_loss improved from 0.00067 to 0.00063, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.9616e-04 - mae: 0.0124 - mse: 2.9616e-04 - val_loss: 6.2934e-04 - val_mae: 0.0160 - val_mse: 6.2934e-04
# Epoch 62/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3256e-04 - mae: 0.0126 - mse: 3.3256e-04
# Epoch 62: val_loss improved from 0.00063 to 0.00054, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.0187e-04 - mae: 0.0123 - mse: 3.0187e-04 - val_loss: 5.3695e-04 - val_mae: 0.0154 - val_mse: 5.3695e-04
# Epoch 63/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4038e-04 - mae: 0.0126 - mse: 3.4038e-04
# Epoch 63: val_loss did not improve from 0.00054
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6928e-04 - mae: 0.0118 - mse: 2.6928e-04 - val_loss: 6.0537e-04 - val_mae: 0.0156 - val_mse: 6.0537e-04
# Epoch 64/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2451e-04 - mae: 0.0113 - mse: 2.2451e-04
# Epoch 64: val_loss did not improve from 0.00054
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.9244e-04 - mae: 0.0120 - mse: 2.9244e-04 - val_loss: 6.2562e-04 - val_mae: 0.0156 - val_mse: 6.2562e-04
# Epoch 65/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8828e-04 - mae: 0.0103 - mse: 1.8828e-04
# Epoch 65: val_loss improved from 0.00054 to 0.00049, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.6615e-04 - mae: 0.0117 - mse: 2.6615e-04 - val_loss: 4.9474e-04 - val_mae: 0.0151 - val_mse: 4.9474e-04
# Epoch 66/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6947e-04 - mae: 0.0115 - mse: 2.6947e-04
# Epoch 66: val_loss improved from 0.00049 to 0.00048, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6361e-04 - mae: 0.0118 - mse: 2.6361e-04 - val_loss: 4.7752e-04 - val_mae: 0.0146 - val_mse: 4.7752e-04
# Epoch 67/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7192e-04 - mae: 0.0118 - mse: 2.7192e-04
# Epoch 67: val_loss did not improve from 0.00048
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4881e-04 - mae: 0.0115 - mse: 2.4881e-04 - val_loss: 4.8323e-04 - val_mae: 0.0147 - val_mse: 4.8323e-04
# Epoch 68/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1091e-04 - mae: 0.0106 - mse: 2.1091e-04
# Epoch 68: val_loss improved from 0.00048 to 0.00047, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4263e-04 - mae: 0.0111 - mse: 2.4263e-04 - val_loss: 4.7316e-04 - val_mae: 0.0143 - val_mse: 4.7316e-04
# Epoch 69/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8234e-04 - mae: 0.0100 - mse: 1.8234e-04
# Epoch 69: val_loss improved from 0.00047 to 0.00044, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.2958e-04 - mae: 0.0109 - mse: 2.2958e-04 - val_loss: 4.4055e-04 - val_mae: 0.0138 - val_mse: 4.4055e-04
# Epoch 70/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9729e-04 - mae: 0.0102 - mse: 1.9729e-04
# Epoch 70: val_loss improved from 0.00044 to 0.00041, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.1699e-04 - mae: 0.0107 - mse: 2.1699e-04 - val_loss: 4.1320e-04 - val_mae: 0.0136 - val_mse: 4.1320e-04
# Epoch 71/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3797e-04 - mae: 0.0106 - mse: 2.3797e-04
# Epoch 71: val_loss did not improve from 0.00041
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1300e-04 - mae: 0.0105 - mse: 2.1300e-04 - val_loss: 4.2412e-04 - val_mae: 0.0138 - val_mse: 4.2412e-04
# Epoch 72/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9594e-04 - mae: 0.0105 - mse: 1.9594e-04
# Epoch 72: val_loss improved from 0.00041 to 0.00039, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.0815e-04 - mae: 0.0103 - mse: 2.0815e-04 - val_loss: 3.8819e-04 - val_mae: 0.0131 - val_mse: 3.8819e-04
# Epoch 73/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.3554e-04 - mae: 0.0106 - mse: 2.3554e-04
# Epoch 73: val_loss improved from 0.00039 to 0.00037, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0602e-04 - mae: 0.0103 - mse: 2.0602e-04 - val_loss: 3.6597e-04 - val_mae: 0.0131 - val_mse: 3.6597e-04
# Epoch 74/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2161e-04 - mae: 0.0106 - mse: 2.2161e-04
# Epoch 74: val_loss did not improve from 0.00037
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0015e-04 - mae: 0.0100 - mse: 2.0015e-04 - val_loss: 4.0893e-04 - val_mae: 0.0132 - val_mse: 4.0893e-04
# Epoch 75/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.7267e-04 - mae: 0.0098 - mse: 1.7267e-04
# Epoch 75: val_loss improved from 0.00037 to 0.00035, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.9721e-04 - mae: 0.0100 - mse: 1.9721e-04 - val_loss: 3.5131e-04 - val_mae: 0.0128 - val_mse: 3.5131e-04
# Epoch 76/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7443e-04 - mae: 0.0096 - mse: 1.7443e-04
# Epoch 76: val_loss improved from 0.00035 to 0.00035, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8844e-04 - mae: 0.0098 - mse: 1.8844e-04 - val_loss: 3.4534e-04 - val_mae: 0.0127 - val_mse: 3.4534e-04
# Epoch 77/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0511e-04 - mae: 0.0100 - mse: 2.0511e-04
# Epoch 77: val_loss improved from 0.00035 to 0.00031, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8400e-04 - mae: 0.0097 - mse: 1.8400e-04 - val_loss: 3.1301e-04 - val_mae: 0.0122 - val_mse: 3.1301e-04
# Epoch 78/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6806e-04 - mae: 0.0094 - mse: 1.6806e-04
# Epoch 78: val_loss did not improve from 0.00031
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7863e-04 - mae: 0.0096 - mse: 1.7863e-04 - val_loss: 3.2524e-04 - val_mae: 0.0122 - val_mse: 3.2524e-04
# Epoch 79/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.4242e-04 - mae: 0.0086 - mse: 1.4242e-04
# Epoch 79: val_loss did not improve from 0.00031
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.7058e-04 - mae: 0.0094 - mse: 1.7058e-04 - val_loss: 3.3165e-04 - val_mae: 0.0122 - val_mse: 3.3165e-04
# Epoch 80/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5852e-04 - mae: 0.0092 - mse: 1.5852e-04
# Epoch 80: val_loss improved from 0.00031 to 0.00031, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6713e-04 - mae: 0.0094 - mse: 1.6713e-04 - val_loss: 3.0783e-04 - val_mae: 0.0120 - val_mse: 3.0783e-04
# Epoch 81/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1481e-04 - mae: 0.0101 - mse: 2.1481e-04
# Epoch 81: val_loss improved from 0.00031 to 0.00029, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6128e-04 - mae: 0.0092 - mse: 1.6128e-04 - val_loss: 2.9466e-04 - val_mae: 0.0117 - val_mse: 2.9466e-04
# Epoch 82/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2740e-04 - mae: 0.0082 - mse: 1.2740e-04
# Epoch 82: val_loss improved from 0.00029 to 0.00028, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5647e-04 - mae: 0.0091 - mse: 1.5647e-04 - val_loss: 2.7754e-04 - val_mae: 0.0115 - val_mse: 2.7754e-04
# Epoch 83/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5815e-04 - mae: 0.0091 - mse: 1.5815e-04
# Epoch 83: val_loss did not improve from 0.00028
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.5565e-04 - mae: 0.0090 - mse: 1.5565e-04 - val_loss: 2.8537e-04 - val_mae: 0.0116 - val_mse: 2.8537e-04
# Epoch 84/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4792e-04 - mae: 0.0089 - mse: 1.4792e-04
# Epoch 84: val_loss did not improve from 0.00028
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5300e-04 - mae: 0.0089 - mse: 1.5300e-04 - val_loss: 2.8884e-04 - val_mae: 0.0114 - val_mse: 2.8884e-04
# Epoch 85/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9011e-04 - mae: 0.0095 - mse: 1.9011e-04
# Epoch 85: val_loss improved from 0.00028 to 0.00026, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5650e-04 - mae: 0.0090 - mse: 1.5650e-04 - val_loss: 2.5690e-04 - val_mae: 0.0113 - val_mse: 2.5690e-04
# Epoch 86/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5274e-04 - mae: 0.0088 - mse: 1.5274e-04
# Epoch 86: val_loss improved from 0.00026 to 0.00026, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.5049e-04 - mae: 0.0088 - mse: 1.5049e-04 - val_loss: 2.5606e-04 - val_mae: 0.0113 - val_mse: 2.5606e-04
# Epoch 87/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6456e-04 - mae: 0.0089 - mse: 1.6456e-04
# Epoch 87: val_loss improved from 0.00026 to 0.00024, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.4482e-04 - mae: 0.0087 - mse: 1.4482e-04 - val_loss: 2.4260e-04 - val_mae: 0.0110 - val_mse: 2.4260e-04
# Epoch 88/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6848e-04 - mae: 0.0093 - mse: 1.6848e-04
# Epoch 88: val_loss did not improve from 0.00024
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3873e-04 - mae: 0.0086 - mse: 1.3873e-04 - val_loss: 2.4627e-04 - val_mae: 0.0108 - val_mse: 2.4627e-04
# Epoch 89/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2506e-04 - mae: 0.0084 - mse: 1.2506e-04
# Epoch 89: val_loss did not improve from 0.00024
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3747e-04 - mae: 0.0086 - mse: 1.3747e-04 - val_loss: 2.4476e-04 - val_mae: 0.0108 - val_mse: 2.4476e-04
# Epoch 90/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1826e-04 - mae: 0.0079 - mse: 1.1826e-04
# Epoch 90: val_loss improved from 0.00024 to 0.00023, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3293e-04 - mae: 0.0083 - mse: 1.3293e-04 - val_loss: 2.3203e-04 - val_mae: 0.0109 - val_mse: 2.3203e-04
# Epoch 91/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1850e-04 - mae: 0.0078 - mse: 1.1850e-04
# Epoch 91: val_loss improved from 0.00023 to 0.00023, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3074e-04 - mae: 0.0082 - mse: 1.3074e-04 - val_loss: 2.3055e-04 - val_mae: 0.0108 - val_mse: 2.3055e-04
# Epoch 92/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3135e-04 - mae: 0.0083 - mse: 1.3135e-04
# Epoch 92: val_loss improved from 0.00023 to 0.00022, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2877e-04 - mae: 0.0082 - mse: 1.2877e-04 - val_loss: 2.2396e-04 - val_mae: 0.0104 - val_mse: 2.2396e-04
# Epoch 93/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0627e-04 - mae: 0.0076 - mse: 1.0627e-04
# Epoch 93: val_loss improved from 0.00022 to 0.00021, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2637e-04 - mae: 0.0082 - mse: 1.2637e-04 - val_loss: 2.1297e-04 - val_mae: 0.0103 - val_mse: 2.1297e-04
# Epoch 94/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1994e-04 - mae: 0.0079 - mse: 1.1994e-04
# Epoch 94: val_loss improved from 0.00021 to 0.00021, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2549e-04 - mae: 0.0082 - mse: 1.2549e-04 - val_loss: 2.0782e-04 - val_mae: 0.0103 - val_mse: 2.0782e-04
# Epoch 95/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1394e-04 - mae: 0.0078 - mse: 1.1394e-04
# Epoch 95: val_loss improved from 0.00021 to 0.00020, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2391e-04 - mae: 0.0081 - mse: 1.2391e-04 - val_loss: 2.0124e-04 - val_mae: 0.0102 - val_mse: 2.0124e-04
# Epoch 96/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0982e-04 - mae: 0.0077 - mse: 1.0982e-04
# Epoch 96: val_loss improved from 0.00020 to 0.00020, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2534e-04 - mae: 0.0082 - mse: 1.2534e-04 - val_loss: 1.9926e-04 - val_mae: 0.0101 - val_mse: 1.9926e-04
# Epoch 97/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0679e-04 - mae: 0.0076 - mse: 1.0679e-04
# Epoch 97: val_loss did not improve from 0.00020
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2782e-04 - mae: 0.0082 - mse: 1.2782e-04 - val_loss: 2.1558e-04 - val_mae: 0.0103 - val_mse: 2.1558e-04
# Epoch 98/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1915e-04 - mae: 0.0077 - mse: 1.1915e-04
# Epoch 98: val_loss did not improve from 0.00020
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3829e-04 - mae: 0.0085 - mse: 1.3829e-04 - val_loss: 2.0124e-04 - val_mae: 0.0101 - val_mse: 2.0124e-04
# Epoch 99/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0699e-04 - mae: 0.0078 - mse: 1.0699e-04
# Epoch 99: val_loss did not improve from 0.00020
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3388e-04 - mae: 0.0084 - mse: 1.3388e-04 - val_loss: 2.1343e-04 - val_mae: 0.0104 - val_mse: 2.1343e-04
# Epoch 100/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1426e-04 - mae: 0.0078 - mse: 1.1426e-04
# Epoch 100: val_loss did not improve from 0.00020
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3142e-04 - mae: 0.0084 - mse: 1.3142e-04 - val_loss: 2.0371e-04 - val_mae: 0.0103 - val_mse: 2.0371e-04
# Epoch 101/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1113e-04 - mae: 0.0080 - mse: 1.1113e-04
# Epoch 101: val_loss improved from 0.00020 to 0.00020, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2834e-04 - mae: 0.0083 - mse: 1.2834e-04 - val_loss: 1.9687e-04 - val_mae: 0.0100 - val_mse: 1.9687e-04
# Epoch 102/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8138e-05 - mae: 0.0074 - mse: 9.8138e-05
# Epoch 102: val_loss improved from 0.00020 to 0.00019, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2084e-04 - mae: 0.0081 - mse: 1.2084e-04 - val_loss: 1.8757e-04 - val_mae: 0.0099 - val_mse: 1.8757e-04
# Epoch 103/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.0251e-04 - mae: 0.0076 - mse: 1.0251e-04
# Epoch 103: val_loss did not improve from 0.00019
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0920e-04 - mae: 0.0077 - mse: 1.0920e-04 - val_loss: 1.8884e-04 - val_mae: 0.0100 - val_mse: 1.8884e-04
# Epoch 104/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2608e-04 - mae: 0.0080 - mse: 1.2608e-04
# Epoch 104: val_loss improved from 0.00019 to 0.00018, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1100e-04 - mae: 0.0078 - mse: 1.1100e-04 - val_loss: 1.7502e-04 - val_mae: 0.0095 - val_mse: 1.7502e-04
# Epoch 105/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1734e-04 - mae: 0.0078 - mse: 1.1734e-04
# Epoch 105: val_loss did not improve from 0.00018
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0768e-04 - mae: 0.0077 - mse: 1.0768e-04 - val_loss: 1.8452e-04 - val_mae: 0.0096 - val_mse: 1.8452e-04
# Epoch 106/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3459e-05 - mae: 0.0070 - mse: 9.3459e-05
# Epoch 106: val_loss improved from 0.00018 to 0.00017, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0512e-04 - mae: 0.0075 - mse: 1.0512e-04 - val_loss: 1.6970e-04 - val_mae: 0.0093 - val_mse: 1.6970e-04
# Epoch 107/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.3976e-05 - mae: 0.0065 - mse: 7.3976e-05
# Epoch 107: val_loss did not improve from 0.00017
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0410e-04 - mae: 0.0074 - mse: 1.0410e-04 - val_loss: 1.7267e-04 - val_mae: 0.0094 - val_mse: 1.7267e-04
# Epoch 108/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3013e-05 - mae: 0.0073 - mse: 9.3013e-05
# Epoch 108: val_loss improved from 0.00017 to 0.00017, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0609e-04 - mae: 0.0075 - mse: 1.0609e-04 - val_loss: 1.6548e-04 - val_mae: 0.0092 - val_mse: 1.6548e-04
# Epoch 109/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1650e-04 - mae: 0.0077 - mse: 1.1650e-04
# Epoch 109: val_loss did not improve from 0.00017
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0365e-04 - mae: 0.0075 - mse: 1.0365e-04 - val_loss: 1.7249e-04 - val_mae: 0.0093 - val_mse: 1.7249e-04
# Epoch 110/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1132e-04 - mae: 0.0077 - mse: 1.1132e-04
# Epoch 110: val_loss improved from 0.00017 to 0.00016, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0087e-04 - mae: 0.0073 - mse: 1.0087e-04 - val_loss: 1.5547e-04 - val_mae: 0.0091 - val_mse: 1.5547e-04
# Epoch 111/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7045e-05 - mae: 0.0071 - mse: 8.7045e-05
# Epoch 111: val_loss did not improve from 0.00016
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.8630e-05 - mae: 0.0073 - mse: 9.8630e-05 - val_loss: 1.6669e-04 - val_mae: 0.0092 - val_mse: 1.6669e-04
# Epoch 112/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2190e-05 - mae: 0.0070 - mse: 9.2190e-05
# Epoch 112: val_loss did not improve from 0.00016
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5617e-05 - mae: 0.0071 - mse: 9.5617e-05 - val_loss: 1.6236e-04 - val_mae: 0.0092 - val_mse: 1.6236e-04
# Epoch 113/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7315e-05 - mae: 0.0068 - mse: 8.7315e-05
# Epoch 113: val_loss improved from 0.00016 to 0.00015, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0254e-04 - mae: 0.0073 - mse: 1.0254e-04 - val_loss: 1.5455e-04 - val_mae: 0.0091 - val_mse: 1.5455e-04
# Epoch 114/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1440e-04 - mae: 0.0077 - mse: 1.1440e-04
# Epoch 114: val_loss improved from 0.00015 to 0.00015, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1314e-04 - mae: 0.0078 - mse: 1.1314e-04 - val_loss: 1.5353e-04 - val_mae: 0.0091 - val_mse: 1.5353e-04
# Epoch 115/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0369e-04 - mae: 0.0077 - mse: 1.0369e-04
# Epoch 115: val_loss did not improve from 0.00015
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1536e-04 - mae: 0.0079 - mse: 1.1536e-04 - val_loss: 1.7128e-04 - val_mae: 0.0094 - val_mse: 1.7128e-04
# Epoch 116/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8328e-05 - mae: 0.0072 - mse: 9.8328e-05
# Epoch 116: val_loss improved from 0.00015 to 0.00015, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0696e-04 - mae: 0.0077 - mse: 1.0696e-04 - val_loss: 1.5048e-04 - val_mae: 0.0091 - val_mse: 1.5048e-04
# Epoch 117/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0106e-04 - mae: 0.0074 - mse: 1.0106e-04
# Epoch 117: val_loss did not improve from 0.00015
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.8661e-05 - mae: 0.0074 - mse: 9.8661e-05 - val_loss: 1.5379e-04 - val_mae: 0.0092 - val_mse: 1.5379e-04
# Epoch 118/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5083e-05 - mae: 0.0071 - mse: 8.5083e-05
# Epoch 118: val_loss improved from 0.00015 to 0.00014, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.6345e-05 - mae: 0.0073 - mse: 9.6345e-05 - val_loss: 1.4465e-04 - val_mae: 0.0085 - val_mse: 1.4465e-04
# Epoch 119/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2459e-05 - mae: 0.0068 - mse: 8.2459e-05
# Epoch 119: val_loss did not improve from 0.00014
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0179e-04 - mae: 0.0074 - mse: 1.0179e-04 - val_loss: 1.6417e-04 - val_mae: 0.0091 - val_mse: 1.6417e-04
# Epoch 120/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9660e-05 - mae: 0.0071 - mse: 9.9660e-05
# Epoch 120: val_loss improved from 0.00014 to 0.00014, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.3958e-05 - mae: 0.0071 - mse: 9.3958e-05 - val_loss: 1.3612e-04 - val_mae: 0.0086 - val_mse: 1.3612e-04
# Epoch 121/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 9.3370e-05 - mae: 0.0072 - mse: 9.3370e-05
# Epoch 121: val_loss did not improve from 0.00014
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2719e-05 - mae: 0.0071 - mse: 9.2719e-05 - val_loss: 1.4797e-04 - val_mae: 0.0089 - val_mse: 1.4797e-04
# Epoch 122/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0112e-05 - mae: 0.0071 - mse: 9.0112e-05
# Epoch 122: val_loss did not improve from 0.00014
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2931e-05 - mae: 0.0072 - mse: 9.2931e-05 - val_loss: 1.3620e-04 - val_mae: 0.0085 - val_mse: 1.3620e-04
# Epoch 123/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0494e-05 - mae: 0.0065 - mse: 7.0494e-05
# Epoch 123: val_loss did not improve from 0.00014
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2154e-05 - mae: 0.0072 - mse: 9.2154e-05 - val_loss: 1.4359e-04 - val_mae: 0.0088 - val_mse: 1.4359e-04
# Epoch 124/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8
1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0055e-04 - mae: 0.0154 - mse: 4.0055e-04
# Epoch 959: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.6465e-04 - mae: 0.0143 - mse: 3.6465e-04 - val_loss: 2.9931e-04 - val_mae: 0.0137 - val_mse: 2.9931e-04
# Epoch 960/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1601e-04 - mae: 0.0140 - mse: 3.1601e-04
# Epoch 960: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.9911e-04 - mae: 0.0132 - mse: 2.9911e-04 - val_loss: 3.2057e-04 - val_mae: 0.0144 - val_mse: 3.2057e-04
# Epoch 961/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.6895e-04 - mae: 0.0131 - mse: 2.6895e-04
# Epoch 961: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.5186e-04 - mae: 0.0123 - mse: 2.5186e-04 - val_loss: 3.3852e-04 - val_mae: 0.0141 - val_mse: 3.3852e-04
# Epoch 962/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0229e-04 - mae: 0.0134 - mse: 3.0229e-04
# Epoch 962: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.5754e-04 - mae: 0.0127 - mse: 2.5754e-04 - val_loss: 2.9389e-04 - val_mae: 0.0132 - val_mse: 2.9389e-04
# Epoch 963/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7960e-04 - mae: 0.0130 - mse: 2.7960e-04
# Epoch 963: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.4348e-04 - mae: 0.0120 - mse: 2.4348e-04 - val_loss: 2.5708e-04 - val_mae: 0.0119 - val_mse: 2.5708e-04
# Epoch 964/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.3445e-04 - mae: 0.0113 - mse: 2.3445e-04
# Epoch 964: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0207e-04 - mae: 0.0109 - mse: 2.0207e-04 - val_loss: 1.9042e-04 - val_mae: 0.0103 - val_mse: 1.9042e-04
# Epoch 965/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2586e-04 - mae: 0.0108 - mse: 2.2586e-04
# Epoch 965: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 2.0910e-04 - mae: 0.0107 - mse: 2.0910e-04 - val_loss: 1.4016e-04 - val_mae: 0.0095 - val_mse: 1.4016e-04
# Epoch 966/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6827e-04 - mae: 0.0098 - mse: 1.6827e-04
# Epoch 966: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.0827e-04 - mae: 0.0108 - mse: 2.0827e-04 - val_loss: 1.8747e-04 - val_mae: 0.0110 - val_mse: 1.8747e-04
# Epoch 967/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9827e-04 - mae: 0.0113 - mse: 1.9827e-04
# Epoch 967: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6681e-04 - mae: 0.0101 - mse: 1.6681e-04 - val_loss: 1.5473e-04 - val_mae: 0.0094 - val_mse: 1.5473e-04
# Epoch 968/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5139e-04 - mae: 0.0094 - mse: 1.5139e-04
# Epoch 968: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4434e-04 - mae: 0.0092 - mse: 1.4434e-04 - val_loss: 1.2957e-04 - val_mae: 0.0086 - val_mse: 1.2957e-04
# Epoch 969/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3397e-04 - mae: 0.0086 - mse: 1.3397e-04
# Epoch 969: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5019e-04 - mae: 0.0092 - mse: 1.5019e-04 - val_loss: 1.1722e-04 - val_mae: 0.0085 - val_mse: 1.1722e-04
# Epoch 970/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6020e-04 - mae: 0.0098 - mse: 1.6020e-04
# Epoch 970: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9144e-04 - mae: 0.0103 - mse: 1.9144e-04 - val_loss: 1.7444e-04 - val_mae: 0.0105 - val_mse: 1.7444e-04
# Epoch 971/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6435e-04 - mae: 0.0127 - mse: 2.6435e-04
# Epoch 971: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6543e-04 - mae: 0.0096 - mse: 1.6543e-04 - val_loss: 1.2224e-04 - val_mae: 0.0088 - val_mse: 1.2224e-04
# Epoch 972/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5741e-04 - mae: 0.0099 - mse: 1.5741e-04
# Epoch 972: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1818e-04 - mae: 0.0084 - mse: 1.1818e-04 - val_loss: 1.0082e-04 - val_mae: 0.0072 - val_mse: 1.0082e-04
# Epoch 973/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.6066e-05 - mae: 0.0070 - mse: 9.6066e-05
# Epoch 973: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.4268e-05 - mae: 0.0069 - mse: 8.4268e-05 - val_loss: 1.0884e-04 - val_mae: 0.0080 - val_mse: 1.0884e-04
# Epoch 974/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0424e-05 - mae: 0.0073 - mse: 9.0424e-05
# Epoch 974: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 8.2790e-05 - mae: 0.0068 - mse: 8.2790e-05 - val_loss: 1.0893e-04 - val_mae: 0.0078 - val_mse: 1.0893e-04
# Epoch 975/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.0616e-04 - mae: 0.0078 - mse: 1.0616e-04
# Epoch 975: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.8311e-05 - mae: 0.0071 - mse: 8.8311e-05 - val_loss: 9.3570e-05 - val_mae: 0.0077 - val_mse: 9.3570e-05
# Epoch 976/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0505e-04 - mae: 0.0081 - mse: 1.0505e-04
# Epoch 976: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.7543e-05 - mae: 0.0068 - mse: 7.7543e-05 - val_loss: 8.3145e-05 - val_mae: 0.0072 - val_mse: 8.3145e-05
# Epoch 977/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.5012e-05 - mae: 0.0076 - mse: 9.5012e-05
# Epoch 977: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 6.3938e-05 - mae: 0.0060 - mse: 6.3938e-05 - val_loss: 4.7947e-05 - val_mae: 0.0055 - val_mse: 4.7947e-05
# Epoch 978/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7905e-05 - mae: 0.0058 - mse: 5.7905e-05
# Epoch 978: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3611e-05 - mae: 0.0057 - mse: 5.3611e-05 - val_loss: 3.1649e-05 - val_mae: 0.0044 - val_mse: 3.1649e-05
# Epoch 979/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1501e-05 - mae: 0.0045 - mse: 3.1501e-05
# Epoch 979: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 3.8602e-05 - mae: 0.0049 - mse: 3.8602e-05 - val_loss: 3.8539e-05 - val_mae: 0.0047 - val_mse: 3.8539e-05
# Epoch 980/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7326e-05 - mae: 0.0045 - mse: 3.7326e-05
# Epoch 980: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6034e-05 - mae: 0.0046 - mse: 3.6034e-05 - val_loss: 3.1540e-05 - val_mae: 0.0042 - val_mse: 3.1540e-05
# Epoch 981/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.2347e-05 - mae: 0.0042 - mse: 3.2347e-05
# Epoch 981: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.2611e-05 - mae: 0.0043 - mse: 3.2611e-05 - val_loss: 3.2398e-05 - val_mae: 0.0044 - val_mse: 3.2398e-05
# Epoch 982/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0106e-05 - mae: 0.0042 - mse: 3.0106e-05
# Epoch 982: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8110e-05 - mae: 0.0041 - mse: 2.8110e-05 - val_loss: 4.3865e-05 - val_mae: 0.0052 - val_mse: 4.3865e-05
# Epoch 983/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2272e-05 - mae: 0.0052 - mse: 4.2272e-05
# Epoch 983: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.5540e-05 - mae: 0.0047 - mse: 3.5540e-05 - val_loss: 5.1143e-05 - val_mae: 0.0054 - val_mse: 5.1143e-05
# Epoch 984/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4829e-05 - mae: 0.0044 - mse: 3.4829e-05
# Epoch 984: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.7651e-05 - mae: 0.0048 - mse: 3.7651e-05 - val_loss: 4.9174e-05 - val_mae: 0.0056 - val_mse: 4.9174e-05
# Epoch 985/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5237e-05 - mae: 0.0046 - mse: 3.5237e-05
# Epoch 985: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8394e-05 - mae: 0.0041 - mse: 2.8394e-05 - val_loss: 4.3703e-05 - val_mae: 0.0050 - val_mse: 4.3703e-05
# Epoch 986/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1221e-05 - mae: 0.0047 - mse: 4.1221e-05
# Epoch 986: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.0651e-05 - mae: 0.0041 - mse: 3.0651e-05 - val_loss: 6.1719e-05 - val_mae: 0.0057 - val_mse: 6.1719e-05
# Epoch 987/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0518e-05 - mae: 0.0047 - mse: 4.0518e-05
# Epoch 987: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5350e-05 - mae: 0.0045 - mse: 3.5350e-05 - val_loss: 4.4385e-05 - val_mae: 0.0053 - val_mse: 4.4385e-05
# Epoch 988/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6768e-05 - mae: 0.0054 - mse: 4.6768e-05
# Epoch 988: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5536e-05 - mae: 0.0045 - mse: 3.5536e-05 - val_loss: 4.5561e-05 - val_mae: 0.0052 - val_mse: 4.5561e-05
# Epoch 989/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.1511e-05 - mae: 0.0044 - mse: 3.1511e-05
# Epoch 989: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7153e-05 - mae: 0.0041 - mse: 2.7153e-05 - val_loss: 3.2795e-05 - val_mae: 0.0045 - val_mse: 3.2795e-05
# Epoch 990/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2456e-05 - mae: 0.0043 - mse: 3.2456e-05
# Epoch 990: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.4649e-05 - mae: 0.0038 - mse: 2.4649e-05 - val_loss: 3.5056e-05 - val_mae: 0.0043 - val_mse: 3.5056e-05
# Epoch 991/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1900e-05 - mae: 0.0042 - mse: 3.1900e-05
# Epoch 991: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2960e-05 - mae: 0.0036 - mse: 2.2960e-05 - val_loss: 2.3465e-05 - val_mae: 0.0037 - val_mse: 2.3465e-05
# Epoch 992/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3617e-05 - mae: 0.0037 - mse: 2.3617e-05
# Epoch 992: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.7996e-05 - mae: 0.0032 - mse: 1.7996e-05 - val_loss: 1.9452e-05 - val_mae: 0.0033 - val_mse: 1.9452e-05
# Epoch 993/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.7358e-05 - mae: 0.0031 - mse: 1.7358e-05
# Epoch 993: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3942e-05 - mae: 0.0029 - mse: 1.3942e-05 - val_loss: 2.0977e-05 - val_mae: 0.0034 - val_mse: 2.0977e-05
# Epoch 994/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.3473e-05 - mae: 0.0028 - mse: 1.3473e-05
# Epoch 994: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2969e-05 - mae: 0.0028 - mse: 1.2969e-05 - val_loss: 1.8183e-05 - val_mae: 0.0034 - val_mse: 1.8183e-05
# Epoch 995/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5141e-05 - mae: 0.0030 - mse: 1.5141e-05
# Epoch 995: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2113e-05 - mae: 0.0027 - mse: 1.2113e-05 - val_loss: 1.9138e-05 - val_mae: 0.0034 - val_mse: 1.9138e-05
# Epoch 996/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5185e-05 - mae: 0.0031 - mse: 1.5185e-05
# Epoch 996: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2073e-05 - mae: 0.0027 - mse: 1.2073e-05 - val_loss: 1.4905e-05 - val_mae: 0.0029 - val_mse: 1.4905e-05
# Epoch 997/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1786e-05 - mae: 0.0027 - mse: 1.1786e-05
# Epoch 997: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0252e-05 - mae: 0.0025 - mse: 1.0252e-05 - val_loss: 1.4681e-05 - val_mae: 0.0029 - val_mse: 1.4681e-05
# Epoch 998/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0824e-05 - mae: 0.0025 - mse: 1.0824e-05
# Epoch 998: val_loss improved from 0.00001 to 0.00001, saving model to ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/model/FI-SETTIGNANO_fed_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.4758e-06 - mae: 0.0023 - mse: 9.4758e-06 - val_loss: 9.9563e-06 - val_mae: 0.0024 - val_mse: 9.9563e-06
# Epoch 999/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6054e-06 - mae: 0.0021 - mse: 7.6054e-06
# Epoch 999: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.7182e-06 - mae: 0.0021 - mse: 7.7182e-06 - val_loss: 1.1494e-05 - val_mae: 0.0026 - val_mse: 1.1494e-05
# Epoch 1000/1000
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4650e-06 - mae: 0.0022 - mse: 8.4650e-06
# Epoch 1000: val_loss did not improve from 0.00001
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4682e-06 - mae: 0.0021 - mse: 7.4682e-06 - val_loss: 1.0768e-05 - val_mae: 0.0025 - val_mse: 1.0768e-05
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# --- federated after local fine-tuning ---
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_1859/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Salvo 55 plot in: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/federated_fd/TEST
# Plot salvati correttamente.
# Test MAE: 0.0020
# Test RMSE: 0.0028
# Test MAPE: 0.08%
# Test R2: 1.0000
# Valore medio del test set: 2.8578
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_FI-SETTIGNANO_14-19-14/federated_fd_evaluation_log.json
