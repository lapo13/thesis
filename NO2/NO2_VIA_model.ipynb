# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import os, pickle, random
from datetime import datetime

# %%
get_after_QA = lambda s: s.split("QA_", 1)[1]

# %%
dati = pd.read_excel('/Users/lapotinacci/thesis/metric_datasets/NO2_dataset.xlsx')
dati = dati[dati["serviceUri"] == "http://www.disit.org/km4city/resource/iot/orionUNIFI/DISIT/ARPAT_QA_LU-VIAREGGIO"].copy()
sensor_name = get_after_QA(dati["serviceUri"].iloc[0])
dati.drop(columns=["serviceUri"], inplace=True)
print(dati.shape)
# Out:
# (432, 16)

# %%
# === Creazione cartella esperimento con timestamp ISO ===
timestamp = datetime.now().strftime("%H-%M-%S")
print(f"Ora inizio esperimento: {timestamp}")
day= datetime.now().strftime("%Y-%m-%d")
print(f"Giorno inizio esperimento: {day}")
exp_dir = f"../RISULTATI/{day}/esperimento_{sensor_name}_{timestamp}"

os.makedirs(exp_dir, exist_ok=True)

print(f"Cartella esperimento creata: {exp_dir}")
# Out:
# Ora inizio esperimento: 14-19-16
# Giorno inizio esperimento: 2025-11-30
# Cartella esperimento creata: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16

# %%
import ast

mask = ~dati['TTT'].str.contains("nan", na=True)
dtset_completo = dati[mask]

dtset_completo['TTT'] = dtset_completo['TTT'].apply(ast.literal_eval)

# %%
# Filtra le righe dove la colonna TTT ha lunghezza 24, ed elimina tutte le colonne le cui osservazioni sono indipendenti dal giorno
dtset_filtrato = dtset_completo[dtset_completo["TTT"].apply(lambda x: len(x) == 24)].sample(frac=1).reset_index(drop=True)
dtset_filtrato = dtset_filtrato[dtset_filtrato["type_of_TTT"] == "daily"]
len(dtset_filtrato)
# Out:
# 370

# %%
import numpy as np


def is_useful_series(series, zero_ratio_thr=0.85, min_nonzero_value=0.1):
    arr = np.array(series, dtype=float)
    
    # Serie troppo corta
    if len(arr) <= 1:
        return False
    
    # Troppi zeri
    zero_ratio = (arr == 0).mean()
    if zero_ratio >= zero_ratio_thr:
        return False
    
    # Valore medio trascurabile (quasi zero)
    mean_val = np.mean(arr)
    if abs(mean_val) < min_nonzero_value:
        return False
    
    # Se arriva qui, la serie ha valori significativi
    return True

# Applica filtro
mask_useful = dtset_filtrato["TTT"].apply(is_useful_series)
df_useful = dtset_filtrato[mask_useful]

# %%
def spezza_serie_in_colonne(df, colonna_stringa, prefix='col_'):
    # --- Controllo colonna ---
    if colonna_stringa not in df.columns:
        raise ValueError(f"La colonna '{colonna_stringa}' non esiste nel DataFrame")

    result_df = df.copy()

    # Estraggo la colonna contenente gli embedding
    col = result_df.pop(colonna_stringa)

    embeddings = []

    for item in col:
        if pd.isna(item) or item == "":
            embeddings.append([])
            continue
        
        try:
            # Parsing sicuro della stringa in lista Python
            vett = ast.literal_eval(item)

            # Se l’embedding è una numpy array o altro iterabile, lo converto in list
            if not isinstance(vett, list):
                vett = list(vett)

            # Converto tutto in float
            vett = [float(x) for x in vett]

            embeddings.append(vett)

        except Exception as e:
            print(f"Errore nel parsing dell'elemento '{item}': {e}")
            embeddings.append([])

    # --- Uniformo dimensione dei vettori ---
    lengths = [len(v) for v in embeddings]
    if not lengths:
        raise ValueError("Nessun embedding valido nella colonna")

    max_len = max(lengths)

    embeddings_padded = [
        v + [np.nan] * (max_len - len(v)) if len(v) < max_len else v
        for v in embeddings
    ]

    # --- Creo DataFrame delle nuove colonne ---
    colonne_embedding = pd.DataFrame(
        embeddings_padded,
        index=result_df.index,
        columns=[f"{prefix}{i}" for i in range(max_len)]
    )

    # --- Merge col DataFrame originale ---
    return pd.concat([result_df, colonne_embedding], axis=1)

# %%
for ttt in df_useful.TTT:
    plt.plot(ttt)

# %%
def summary_df(df):
    summary = pd.DataFrame({
        'dtype': df.dtypes,
        'n_missing': df.isna().sum(),
        '%_missing': (df.isna().mean() * 100).round(2),
        'n_unique': df.nunique(),
        'top_value': df.mode().iloc[0],  # moda
        'top_freq': [df[col].value_counts(dropna=True).iloc[0] if not df[col].value_counts(dropna=True).empty else None for col in df.columns],
        'min': [df[col].min() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'max': [df[col].max() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'mean': [df[col].mean() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
        'std': [df[col].std() if pd.api.types.is_numeric_dtype(df[col]) else None for col in df.columns],
    })
    return summary

# %%
#Nella precedente sono state eliminate le colonne con Nan, tuttavia alcuni dataset dei sensori METRO hanno dei Nan in city e surface dunque vengono rimossi nel prcedente box

categorical = [
    'is_weekend'
    ]

#consiglio, per serie cicliche usare funzioni periodiche tipo seno coseno 
df_encoded = pd.get_dummies(df_useful
                            , columns=categorical)

# %%
def save_pkl(obj, path):
    with open(path, "wb") as f:
        pickle.dump(obj, f)
    print(f"Salvato: {path}")

def load_pkl(path):
    with open(path, "rb") as f:
        return pickle.load(f)

# %%
#codifica ciclica delle features e individuazione del'ora del giorno e della settimana 

def encode_time_features(df, start_col="interval_start", end_col="interval_end"):
    df = df.copy()
    
    # Step 1: Ensure datetime columns are in the correct format first
    df[start_col] = pd.to_datetime(df[start_col], utc=True, format="mixed")
    df[end_col] = pd.to_datetime(df[end_col], utc=True, format="mixed")

    # Step 2: Extract 'month' and 'day' after conversion
    df['month'] = df[start_col].dt.month
    df['day'] = df[start_col].dt.dayofweek # Note: dayofweek is typically used for cyclical weekly patterns
    
    # Step 3: Now you can create the cyclical features
    df['month_sin'] = np.sin(2 * np.pi * df['month']/len(df['month'].unique()))
    df['month_cos'] = np.cos(2 * np.pi * df['month']/len(df['month'].unique()))
    df['day_sin'] = np.sin(2 * np.pi * df['day']/len(df['day'].unique()))
    df['day_cos'] = np.cos(2 * np.pi * df['day']/len(df['day'].unique()))


    # Ora del giorno (0-23) → ciclo giornaliero
    df["hour"] = df[start_col].dt.hour
    angle_day_start = 2 * np.pi * df["hour"] / 24
    df["start_time_sin"] = np.sin(angle_day_start)
    df["start_time_cos"] = np.cos(angle_day_start)

    df["hour_end"] = df[end_col].dt.hour
    angle_day_end = 2 * np.pi * df["hour_end"] / 24
    df["end_time_sin"] = np.sin(angle_day_end)
    df["end_time_cos"] = np.cos(angle_day_end)

    # Durata in minuti
    df["duration_minutes"] = (df[end_col] - df[start_col]).dt.total_seconds() / 60

    # Giorno della settimana (0=Mon..6=Sun) → ciclo settimanale
    dayofweek = df[start_col].dt.dayofweek
    angle_week = 2 * np.pi * dayofweek / 7
    df["dow_sin"] = np.sin(angle_week)
    df["dow_cos"] = np.cos(angle_week)

    # Giorno dell’anno (1-365) → ciclo annuale
    dayofyear = df[start_col].dt.dayofyear
    angle_year = 2 * np.pi * dayofyear / 365
    df["doy_sin"] = np.sin(angle_year)
    df["doy_cos"] = np.cos(angle_year)

    # Rimuovo colonne temporali e variabili ausiliarie
    df = df.drop(columns=[start_col, end_col, "hour", "hour_end", "day", "month"])
    return df

embedding_cols = ['highway_embedding', 'AreaTypeEmbeddings']

df_final = encode_time_features(df_encoded)
df_final.drop(columns=['type_of_TTT'], inplace=True)
for emb_col in embedding_cols:
    df_final = spezza_serie_in_colonne(df_final, emb_col, prefix=f'{emb_col}_')
df_final.shape

# Salvataggio DataFrame finale
df_path = os.path.join(exp_dir, f"dataframe_{sensor_name}")
os.makedirs(df_path, exist_ok=True)
save_pkl(df_final, os.path.join(df_path, f"filtered_dataframe.pkl"))
# Out:
# Salvato: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/dataframe_LU-VIAREGGIO/filtered_dataframe.pkl

# %%
for ttt in df_final.TTT[10:20]:
    plt.plot(ttt)
    plt.title("Esempi di TTT ARPAT")
    plt.xlabel("Ora del Giorno")
    plt.ylabel("Valore TTT")

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

def series_to_2d_array(series, output_dim=24):
    arr = np.stack(series.apply(lambda x: np.array(x, dtype=np.float32)))
    if arr.shape[1] != output_dim:
        raise ValueError(f"Ogni elemento deve avere {output_dim} valori, trovato {arr.shape[1]}")
    return arr

 # Separazione delle feature e del target
X = df_final.drop(columns=['TTT'])
y = df_final['TTT']

X_np = X.to_numpy().astype(np.float32)
y_np = series_to_2d_array(y, output_dim=24)

# Calcolo deviazione standard per ogni serie
std_scores = np.std(y_np, axis=1)

std_scores_log = np.log1p(std_scores)  # log(1+x) per evitare problemi con valori vicini a 0

std_scores_normalized = (std_scores_log - np.min(std_scores_log)) / (np.max(std_scores_log) - np.min(std_scores_log))

# Creo bin basati sui quantili
bins = np.array([0.0, 0.4, 0.8, 1.0])
std_bins = np.digitize(std_scores_normalized, bins)

# Primo split: train (80%) vs temp (20%)
# Passo anche std_bins per poter stratificare
X_train, X_test, y_train, y_test = train_test_split(
    X_np, y_np,
    test_size=0.2,
    random_state=42,
    stratify=std_bins, 
    shuffle=True
)

print(f"Train size: {X_train.shape}, {y_train.shape}")
print(f"Test size: {X_test.shape}, {y_test.shape}")

# Debug prints
print(f"Final shapes:")
print(f"X_train: {X_train.shape}")
print(f"y_train: {y_train.shape}")

# Scaler per input
scaler_X = StandardScaler()
X_train = scaler_X.fit_transform(X_train)
X_test  = scaler_X.transform(X_test)

# Scaler per output (se serve normalizzare anche y)
scaler_y = StandardScaler()
y_train = scaler_y.fit_transform(y_train)
y_test  = scaler_y.transform(y_test)

#cartella salvataggio train e test
path = os.path.join(exp_dir, "train_test_data")
os.makedirs(path, exist_ok=True)

#  === Salvataggio dataset e scaler in formato .pkl ===
save_pkl(scaler_X.inverse_transform(X_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_train), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_train_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_X.inverse_transform(X_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"X_test_unscaled_{sensor_name}.pkl"))
save_pkl(scaler_y.inverse_transform(y_test), os.path.join('/Users/lapotinacci/thesis/Federated_Sys/train_test', f"y_test_unscaled_{sensor_name}.pkl"))


save_pkl(X_train, os.path.join(exp_dir, "X_train.pkl"))
save_pkl(y_train, os.path.join(exp_dir, "y_train.pkl"))
save_pkl(X_test, os.path.join(exp_dir, "X_test.pkl"))
save_pkl(y_test, os.path.join(exp_dir, "y_test.pkl"))

save_pkl(scaler_X, os.path.join(exp_dir, "scaler_X.pkl"))
save_pkl(scaler_y, os.path.join(exp_dir, "scaler_y.pkl"))

print("Scaler salvati.")

print("\nTutti i file sono stati salvati correttamente.")
print(f"Percorso cartella: {os.path.abspath(exp_dir)}")
# Out:
# Train size: (296, 33), (296, 24)
# Test size: (74, 33), (74, 24)
# Final shapes:
# X_train: (296, 33)
# y_train: (296, 24)
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_train_unscaled_LU-VIAREGGIO.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_train_unscaled_LU-VIAREGGIO.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/X_test_unscaled_LU-VIAREGGIO.pkl
# Salvato: /Users/lapotinacci/thesis/Federated_Sys/train_test/y_test_unscaled_LU-VIAREGGIO.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/X_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/y_train.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/X_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/y_test.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/scaler_X.pkl
# Salvato: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/scaler_y.pkl
# Scaler salvati.
#
# Tutti i file sono stati salvati correttamente.
# Percorso cartella: /Users/lapotinacci/thesis/Federated_Sys/RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16

# %%
# === Costruisci i path ===
path_X_train = os.path.join(exp_dir, "X_train.pkl")
path_y_train = os.path.join(exp_dir, "y_train.pkl")
path_X_test  = os.path.join(exp_dir, "X_test.pkl")
path_y_test  = os.path.join(exp_dir, "y_test.pkl")

path_scaler_X = os.path.join(exp_dir, "scaler_X.pkl")
path_scaler_y = os.path.join(exp_dir, "scaler_y.pkl")

# === Ricaricamento ===
X_train = load_pkl(path_X_train)
y_train = load_pkl(path_y_train)
X_test  = load_pkl(path_X_test)
y_test  = load_pkl(path_y_test)


scaler_X = load_pkl(path_scaler_X)
scaler_y = load_pkl(path_scaler_y)

print("Shapes ricostruite:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

print("\nScaler caricati:")
print("scaler_X:", type(scaler_X))
print("scaler_y:", type(scaler_y))
# Out:
# Shapes ricostruite:
# X_train: (296, 33)
# y_train: (296, 24)
# X_test: (74, 33)
# y_test: (74, 24)
#
# Scaler caricati:
# scaler_X: <class 'sklearn.preprocessing._data.StandardScaler'>
# scaler_y: <class 'sklearn.preprocessing._data.StandardScaler'>

# %% [markdown]
# # modelli

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers # type: ignore
from tensorflow.keras.layers import Dropout # type: ignore
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
def save_prediction_plots(y_true, y_pred, output_dir, prefix="pred_plot"):
    os.makedirs(output_dir, exist_ok=True)

    n = len(y_true)
    print(f"Salvo {n} plot in: {output_dir}")

    for i in range(n):
        plt.figure(figsize=(8, 3))
        plt.plot(y_true[i], label="True")
        plt.plot(y_pred[i], label="Pred")
        plt.legend()
        plt.tight_layout()

        filename = f"{prefix}_{i+1}.png"
        path = os.path.join(output_dir, filename)

        plt.savefig(path)
        plt.close()

    print("Plot salvati correttamente.")

# %%
# Definizione modello DNN
def build_model(input_shape: tuple, output_shape: tuple):
    model = models.Sequential([
        layers.Dense(128, activation = "relu", input_shape=input_shape),
        Dropout(0.0),
        layers.Dense(output_shape, 'linear')
    ])
    model.compile(
    optimizer=optimizers.AdamW(learning_rate=0.022, weight_decay=0.0185),
    loss= 'mse',
    metrics=['mae'],
    )
    return model

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',      # metrica da monitorare, es. val_loss o val_mae
    patience=100,             # numero di epoche senza miglioramento prima di fermare
    restore_best_weights=True,  # ripristina i pesi migliori trovati
    verbose = 1
)

# Training del modello
model = build_model((X_test.shape[1],), y_test.shape[1])
history = model.fit(
    X_train, y_train,
    epochs=1000,
    batch_size=256,
    callbacks = [early_stop],
    validation_split = 0.2,
    verbose=1
    )

'''print("y_train min/max:", y_train_np.min(), y_train_np.max())
print("y_pred min/max (scaled):", y_pred.min(), y_pred.max())
y_pred_rescaled = scaler_y.inverse_transform(y_pred)
print("y_pred_rescaled min/max:", y_pred_rescaled.min(), y_pred_rescaled.max())'''

if not os.path.exists(os.path.join(exp_dir, "model")):
    os.makedirs(os.path.join(exp_dir, "model"))
    model.save(os.path.join(exp_dir, "model", "NO2_MAREMMA_model.keras"))
# Out:
# Epoch 1/1000
# /Users/lapotinacci/thesis/Federated_Sys/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s
1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0732 - mae: 0.1948 - val_loss: 0.0986 - val_mae: 0.2198
# Epoch 33/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0680 - mae: 0.1859 - val_loss: 0.0951 - val_mae: 0.2142
# Epoch 34/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0633 - mae: 0.1784 - val_loss: 0.0915 - val_mae: 0.2076
# Epoch 35/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0591 - mae: 0.1716 - val_loss: 0.0868 - val_mae: 0.2008
# Epoch 36/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0556 - mae: 0.1653 - val_loss: 0.0810 - val_mae: 0.1939
# Epoch 37/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0520 - mae: 0.1595 - val_loss: 0.0765 - val_mae: 0.1887
# Epoch 38/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0484 - mae: 0.1532 - val_loss: 0.0732 - val_mae: 0.1846
# Epoch 39/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0452 - mae: 0.1479 - val_loss: 0.0689 - val_mae: 0.1780
# Epoch 40/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0419 - mae: 0.1423 - val_loss: 0.0643 - val_mae: 0.1713
# Epoch 41/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0392 - mae: 0.1370 - val_loss: 0.0600 - val_mae: 0.1652
# Epoch 42/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0366 - mae: 0.1325 - val_loss: 0.0563 - val_mae: 0.1595
# Epoch 43/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0340 - mae: 0.1271 - val_loss: 0.0537 - val_mae: 0.1548
# Epoch 44/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0318 - mae: 0.1222 - val_loss: 0.0518 - val_mae: 0.1510
# Epoch 45/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0297 - mae: 0.1176 - val_loss: 0.0494 - val_mae: 0.1478
# Epoch 46/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0278 - mae: 0.1138 - val_loss: 0.0465 - val_mae: 0.1433
# Epoch 47/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0260 - mae: 0.1100 - val_loss: 0.0439 - val_mae: 0.1394
# Epoch 48/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0245 - mae: 0.1070 - val_loss: 0.0410 - val_mae: 0.1349
# Epoch 49/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0232 - mae: 0.1034 - val_loss: 0.0376 - val_mae: 0.1289
# Epoch 50/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0218 - mae: 0.1001 - val_loss: 0.0354 - val_mae: 0.1247
# Epoch 51/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0207 - mae: 0.0978 - val_loss: 0.0339 - val_mae: 0.1219
# Epoch 52/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0195 - mae: 0.0951 - val_loss: 0.0325 - val_mae: 0.1195
# Epoch 53/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0185 - mae: 0.0923 - val_loss: 0.0311 - val_mae: 0.1167
# Epoch 54/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0177 - mae: 0.0898 - val_loss: 0.0293 - val_mae: 0.1129
# Epoch 55/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0167 - mae: 0.0877 - val_loss: 0.0278 - val_mae: 0.1105
# Epoch 56/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0159 - mae: 0.0858 - val_loss: 0.0273 - val_mae: 0.1090
# Epoch 57/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0151 - mae: 0.0834 - val_loss: 0.0259 - val_mae: 0.1061
# Epoch 58/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0145 - mae: 0.0816 - val_loss: 0.0251 - val_mae: 0.1043
# Epoch 59/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0140 - mae: 0.0801 - val_loss: 0.0240 - val_mae: 0.1039
# Epoch 60/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0140 - mae: 0.0808 - val_loss: 0.0261 - val_mae: 0.1082
# Epoch 61/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0150 - mae: 0.0840 - val_loss: 0.0247 - val_mae: 0.1075
# Epoch 62/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0163 - mae: 0.0884 - val_loss: 0.0265 - val_mae: 0.1129
# Epoch 63/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0155 - mae: 0.0889 - val_loss: 0.0213 - val_mae: 0.0981
# Epoch 64/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0123 - mae: 0.0768 - val_loss: 0.0205 - val_mae: 0.0961
# Epoch 65/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.
1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 2.1542e-04 - mae: 0.0110 - val_loss: 0.0047 - val_mae: 0.0278
# Epoch 981/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.8348e-04 - mae: 0.0123 - val_loss: 0.0042 - val_mae: 0.0276
# Epoch 982/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.3636e-04 - mae: 0.0131 - val_loss: 0.0046 - val_mae: 0.0281
# Epoch 983/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.4298e-04 - mae: 0.0128 - val_loss: 0.0044 - val_mae: 0.0267
# Epoch 984/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.4130e-04 - mae: 0.0120 - val_loss: 0.0043 - val_mae: 0.0272
# Epoch 985/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.9728e-04 - mae: 0.0126 - val_loss: 0.0048 - val_mae: 0.0291
# Epoch 986/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.0619e-04 - mae: 0.0145 - val_loss: 0.0043 - val_mae: 0.0301
# Epoch 987/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.4376e-04 - mae: 0.0165 - val_loss: 0.0051 - val_mae: 0.0321
# Epoch 988/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.6915e-04 - mae: 0.0181 - val_loss: 0.0045 - val_mae: 0.0318
# Epoch 989/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 8.3039e-04 - mae: 0.0187 - val_loss: 0.0050 - val_mae: 0.0323
# Epoch 990/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.3704e-04 - mae: 0.0187 - val_loss: 0.0046 - val_mae: 0.0309
# Epoch 991/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.4132e-04 - mae: 0.0173 - val_loss: 0.0044 - val_mae: 0.0290
# Epoch 992/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.8934e-04 - mae: 0.0145 - val_loss: 0.0045 - val_mae: 0.0266
# Epoch 993/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.3142e-04 - mae: 0.0110 - val_loss: 0.0042 - val_mae: 0.0260
# Epoch 994/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.1284e-04 - mae: 0.0106 - val_loss: 0.0046 - val_mae: 0.0273
# Epoch 995/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.8200e-04 - mae: 0.0121 - val_loss: 0.0044 - val_mae: 0.0284
# Epoch 996/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.5403e-04 - mae: 0.0135 - val_loss: 0.0046 - val_mae: 0.0282
# Epoch 997/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.7733e-04 - mae: 0.0136 - val_loss: 0.0044 - val_mae: 0.0276
# Epoch 998/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.3110e-04 - mae: 0.0126 - val_loss: 0.0043 - val_mae: 0.0262
# Epoch 999/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 2.4920e-04 - mae: 0.0112 - val_loss: 0.0044 - val_mae: 0.0258
# Epoch 1000/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.8906e-04 - mae: 0.0100 - val_loss: 0.0042 - val_mae: 0.0255
# Restoring model weights from the end of the best epoch: 976.

# %%
model = tf.keras.models.load_model(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') if os.path.exists(f'{exp_dir}/model/NO2_{sensor_name}_model.keras') else model

# %%
# Estrai losses da tutti i folds
train_losses = history.history['loss']
val_losses   = history.history['val_loss']

train_losses = train_losses
val_losses = val_losses

# Plot
plt.figure(figsize=(8,5))


# Training loss
plt.plot(train_losses, color='blue', label='Train Loss')
# Validation loss
plt.plot(val_losses, color='red', label='Validation Loss')


# Dettagli grafico
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.savefig(f'{exp_dir}/loss_plot.png')

# %%
def plot_first_n_series(y_pred, y_test, n_series=10, title="Confronto Serie Predette vs Reali"):
    """
    Plotta le prime n_series serie reali e predette per un confronto diretto.

    Args:
        y_pred (np.ndarray): Predizioni del modello (shape: num_samples x seq_len).
        y_test (np.ndarray): Serie reali (shape: num_samples x seq_len).
        n_series (int): Numero di serie da plottare.
        title (str): Titolo del grafico.
    """

    # Limitiamo a n_series per evitare problemi
    n = min(n_series, y_pred.shape[0], y_test.shape[0])

    plt.figure(figsize=(14, 8))

    for i in range(n):
        plt.plot(
            y_test[i], 
            linewidth=1.8, 
            alpha=0.5, 
            label=f"Reale {i+1}" if i == 0 else "",
            color = 'blue'
        )
        plt.plot(
            y_pred[i], 
            linewidth=1.2, 
            linestyle="--", 
            alpha=0.9, 
            label=f"Predetto {i+1}" if i == 0 else "",
            color = 'orange'
        )

    plt.title(title, fontsize=16)
    plt.xlabel("Time Step", fontsize=12)
    plt.ylabel("Valore", fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns

def plot_diagnosis_gradient(y_pred, y_test, save_path: str,  tolerance:float =0.05, max_samples_heatmap=50, scatter_sample_ratio=0.5, tol_auto = True):
    """
    Dashboard diagnostica con tolleranza AUTO-ADATTIVA alla scala dei dati.
    
    Args:
        tolerance (float): 
            - Se None: La tolleranza viene calcolata automaticamente come il 5% del range dei dati (Max-Min).
            - Se float: Valore assoluto (es. 0.5).
        tol_auto (bool): Se True, usa la tolleranza automatica basata sul range dei dati, altrimenti usa il valore manuale fornito 
        col parametro tolerance.
    """
    
    y_test_flat = y_test.flatten()
    y_pred_flat = y_pred.flatten()

    # ---------------------------------------------------------
    # AUTOMAZIONE TOLLERANZA
    # ---------------------------------------------------------
    if tol_auto:
        data_range = y_test_flat.max() - y_test_flat.min()
        # Impostiamo la tolleranza al 5% del range totale (regolabile)
        tolerance = data_range * tolerance 
        tol_label = f"Auto (5% Range: ±{tolerance:.2f})"
    else:
        tol_label = f"Manuale (±{tolerance})"

    fig, axes = plt.subplots(1, 2, figsize=(22, 8))

    # -----------------------------
    # 1. HEATMAP (SX)
    # -----------------------------
    errors = np.abs(y_test - y_pred)
    errors_subset = errors[:max_samples_heatmap]
    
    # Adattiamo anche la scala colori della heatmap alla tolleranza
    # Tutto ciò che è oltre 3 volte la tolleranza è "errore massimo" visivo
    sns.heatmap(errors_subset, cmap="plasma", ax=axes[0], 
                vmax=tolerance * 3,
                cbar_kws={'label': 'Errore Assoluto'})
    
    axes[0].set_title(f"Heatmap Errori (Primi {max_samples_heatmap} campioni)", fontsize=16)
    axes[0].set_xlabel("Time Step", fontsize=12)
    axes[0].set_ylabel("Indice Campione", fontsize=12)

    # -----------------------------
    # 2. SCATTER CON SFONDO GRADIENTE (DX)
    # -----------------------------
    
    # Campionamento dati
    if scatter_sample_ratio < 1.0:
        mask = np.random.rand(len(y_test_flat)) < scatter_sample_ratio
        sample_test = y_test_flat[mask]
        sample_pred = y_pred_flat[mask]
    else:
        sample_test = y_test_flat
        sample_pred = y_pred_flat

    # Calcolo limiti grafico
    min_val = min(y_test_flat.min(), y_pred_flat.min())
    max_val = max(y_test_flat.max(), y_pred_flat.max())
    padding = (max_val - min_val) * 0.05
    plot_min = min_val - padding
    plot_max = max_val + padding

    # --- SFONDO GRADIENTE ---
    grid_x, grid_y = np.meshgrid(
        np.linspace(plot_min, plot_max, 200),
        np.linspace(plot_min, plot_max, 200)
    )
    grid_z = np.abs(grid_y - grid_x)

    im = axes[1].imshow(
        grid_z, 
        extent=(plot_min, plot_max, plot_min, plot_max), 
        origin='lower', 
        cmap='RdYlGn_r', 
        alpha=0.4, 
        vmax=tolerance * 4, # Il rosso satura a 4x della tolleranza
        aspect='auto'
    )

    # --- PUNTI BLU ---
    axes[1].scatter(
        sample_test, 
        sample_pred, 
        alpha=0.6, 
        s=15, 
        color='royalblue', 
        edgecolors='white', 
        linewidth=0.3,
        label='Campioni'
    )

    axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

    # Metriche
    within_tol = np.mean(np.abs(y_test_flat - y_pred_flat) <= tolerance) * 100

    axes[1].set_title(
        f"Bontà delle previsioni con {tol_label}\nValori nel range di Tolleranza: {within_tol:.1f}%", 
        fontsize=16
    )
    axes[1].set_xlabel("Valore Reale", fontsize=12)
    axes[1].set_ylabel("Valore Predetto", fontsize=12)
    axes[1].set_xlim(plot_min, plot_max)
    axes[1].set_ylim(plot_min, plot_max)
    
    cbar = plt.colorbar(im, ax=axes[1], pad=0.02)
    cbar.set_label('Gravità Errore (Distanza da diagonale)')

    plt.tight_layout()
    plt.savefig(f'{exp_dir}/{save_path}.png')

# %%
y_pred = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred)
y_test_np = scaler_y.inverse_transform(y_test)

plot_diagnosis_gradient(y_pred, y_test_np, save_path='pred_quality', max_samples_heatmap=10, scatter_sample_ratio=0.7)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_1863/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')

# %%
save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/TEST', prefix="pred_plot")
# Out:
# Salvo 74 plot in: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/TEST
# Plot salvati correttamente.

# %%
import json
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_and_log(y_true, y_pred, log_path="log.json"):
    # --- Metriche ---
    mae = mean_absolute_error(y_true, y_pred, multioutput="uniform_average")
    rmse = np.sqrt(mean_squared_error(y_true, y_pred, multioutput="uniform_average"))

    mask = y_true != 0
    mape = float(np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100.0)

    r2 = r2_score(y_true, y_pred, multioutput="uniform_average")

    # Valore medio del test set
    v_mean = float(np.mean(y_true))

    # --- Stampa ---
    print(f"Test MAE: {mae:.4f}")
    print(f"Test RMSE: {rmse:.4f}")
    print(f"Test MAPE: {mape:.2f}%")
    print(f"Test R2: {r2:.4f}")
    print(f"Valore medio del test set: {v_mean:.4f}")

    # --- Salvataggio log ---
    log_data = {
        "MAE": mae,
        "RMSE": rmse,
        "MAPE": mape,
        "R2": r2,
        "test_mean_value": v_mean
    }

    with open(log_path, "w") as f:
        json.dump(log_data, f, indent=4)

    print(f"\nLog salvato in: {log_path}")
evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/evaluation_log.json")
# Impostazioni pandas per visualizzare tutti i dati
# Out:
# Test MAE: 0.0599
# Test RMSE: 0.1444
# Test MAPE: 0.60%
# Test R2: 0.9981
# Valore medio del test set: 10.5587
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/evaluation_log.json

# %% [markdown]
# # globale e federato

# %%
fed = tf.keras.models.load_model('/Users/lapotinacci/thesis/Federated_Sys/app/custom/models/fed_model_Arpat.keras')

model  = [fed]
model_name = ["federated"]

# %%
checkpoint_filepath = f'{exp_dir}/model/{sensor_name}_fed_model.keras'

# 2. Crea l'istanza della callback
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False, 
    verbose=1
)

# %%
for model, name in zip(model, model_name):
    y_pred = model.predict(X_test)
    y_pred = scaler_y.inverse_transform(y_pred)
    y_test_np = scaler_y.inverse_transform(y_test)

    print(f"--- {name} ---")
    #plot_diagnosis_gradient(y_pred, y_test_np, max_samples_heatmap=10, scatter_sample_ratio=0.7)
    evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_evaluation_log.json")
    save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}/TEST', prefix="pred_plot")

    print("\n")
    if name == 'federated':
        model.fit(X_train, y_train, epochs=1000, batch_size=256, callbacks=[model_checkpoint_callback], validation_split=0.2)
        model.load_weights(checkpoint_filepath)
        y_pred = model.predict(X_test)
        y_pred = scaler_y.inverse_transform(y_pred)
        print(f"--- {name} after local fine-tuning ---")
        plot_diagnosis_gradient(y_pred, y_test_np, save_path=f"{name}_pred_quality", max_samples_heatmap=10, scatter_sample_ratio=0.7)
        save_prediction_plots(y_test_np, y_pred, output_dir=f'{exp_dir}/{name.replace(" ", "_").lower()}_fd/TEST', prefix="pred_plot")
        evaluate_and_log(y_test_np, y_pred, log_path=f"{exp_dir}/{name.replace(' ', '_').lower()}_fd_evaluation_log.json")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# --- federated ---
# Test MAE: 1.6449
# Test RMSE: 2.4434
# Test MAPE: 16.04%
# Test R2: 0.2198
# Valore medio del test set: 10.5587
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/federated_evaluation_log.json
# Salvo 74 plot in: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/federated/TEST
# Plot salvati correttamente.
#
#
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - loss: 0.7911 - mae: 0.6580 - mse: 0.7911
# Epoch 1: val_loss improved from None to 0.59924, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 849ms/step - loss: 0.7911 - mae: 0.6580 - mse: 0.7911 - val_loss: 0.5992 - val_mae: 0.5663 - val_mse: 0.5992
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6494 - mae: 0.5994 - mse: 0.6494
# Epoch 2: val_loss improved from 0.59924 to 0.47812, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.6494 - mae: 0.5994 - mse: 0.6494 - val_loss: 0.4781 - val_mae: 0.5031 - val_mse: 0.4781
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5171 - mae: 0.5330 - mse: 0.5171
# Epoch 3: val_loss improved from 0.47812 to 0.40752, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.5171 - mae: 0.5330 - mse: 0.5171 - val_loss: 0.4075 - val_mae: 0.4655 - val_mse: 0.4075
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4334 - mae: 0.4879 - mse: 0.4334
# Epoch 4: val_loss improved from 0.40752 to 0.36551, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.4334 - mae: 0.4879 - mse: 0.4334 - val_loss: 0.3655 - val_mae: 0.4402 - val_mse: 0.3655
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3800 - mae: 0.4535 - mse: 0.3800
# Epoch 5: val_loss improved from 0.36551 to 0.33483, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3800 - mae: 0.4535 - mse: 0.3800 - val_loss: 0.3348 - val_mae: 0.4225 - val_mse: 0.3348
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3384 - mae: 0.4281 - mse: 0.3384
# Epoch 6: val_loss improved from 0.33483 to 0.31082, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.3384 - mae: 0.4281 - mse: 0.3384 - val_loss: 0.3108 - val_mae: 0.4103 - val_mse: 0.3108
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3024 - mae: 0.4068 - mse: 0.3024
# Epoch 7: val_loss improved from 0.31082 to 0.29083, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.3024 - mae: 0.4068 - mse: 0.3024 - val_loss: 0.2908 - val_mae: 0.4008 - val_mse: 0.2908
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.2721 - mae: 0.3877 - mse: 0.2721
# Epoch 8: val_loss improved from 0.29083 to 0.27453, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.2721 - mae: 0.3877 - mse: 0.2721 - val_loss: 0.2745 - val_mae: 0.3925 - val_mse: 0.2745
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2484 - mae: 0.3697 - mse: 0.2484
# Epoch 9: val_loss improved from 0.27453 to 0.25882, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.2484 - mae: 0.3697 - mse: 0.2484 - val_loss: 0.2588 - val_mae: 0.3816 - val_mse: 0.2588
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2301 - mae: 0.3563 - mse: 0.2301
# Epoch 10: val_loss improved from 0.25882 to 0.24185, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.2301 - mae: 0.3563 - mse: 0.2301 - val_loss: 0.2418 - val_mae: 0.3709 - val_mse: 0.2418
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2138 - mae: 0.3456 - mse: 0.2138
# Epoch 11: val_loss improved from 0.24185 to 0.22374, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2138 - mae: 0.3456 - mse: 0.2138 - val_loss: 0.2237 - val_mae: 0.3567 - val_mse: 0.2237
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1966 - mae: 0.3315 - mse: 0.1966
# Epoch 12: val_loss improved from 0.22374 to 0.20517, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1966 - mae: 0.3315 - mse: 0.1966 - val_loss: 0.2052 - val_mae: 0.3422 - val_mse: 0.2052
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1798 - mae: 0.3157 - mse: 0.1798
# Epoch 13: val_loss improved from 0.20517 to 0.18802, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1798 - mae: 0.3157 - mse: 0.1798 - val_loss: 0.1880 - val_mae: 0.3281 - val_mse: 0.1880
# Epoch 14/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1653 - mae: 0.3005 - mse: 0.1653
# Epoch 14: val_loss improved from 0.18802 to 0.17227, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1653 - mae: 0.3005 - mse: 0.1653 - val_loss: 0.1723 - val_mae: 0.3150 - val_mse: 0.1723
# Epoch 15/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1528 - mae: 0.2883 - mse: 0.1528
# Epoch 15: val_loss improved from 0.17227 to 0.15841, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1528 - mae: 0.2883 - mse: 0.1528 - val_loss: 0.1584 - val_mae: 0.3013 - val_mse: 0.1584
# Epoch 16/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1422 - mae: 0.2782 - mse: 0.1422
# Epoch 16: val_loss improved from 0.15841 to 0.14673, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1422 - mae: 0.2782 - mse: 0.1422 - val_loss: 0.1467 - val_mae: 0.2900 - val_mse: 0.1467
# Epoch 17/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1340 - mae: 0.2707 - mse: 0.1340
# Epoch 17: val_loss improved from 0.14673 to 0.13719, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1340 - mae: 0.2707 - mse: 0.1340 - val_loss: 0.1372 - val_mae: 0.2815 - val_mse: 0.1372
# Epoch 18/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1273 - mae: 0.2644 - mse: 0.1273
# Epoch 18: val_loss improved from 0.13719 to 0.12869, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1273 - mae: 0.2644 - mse: 0.1273 - val_loss: 0.1287 - val_mae: 0.2722 - val_mse: 0.1287
# Epoch 19/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1203 - mae: 0.2567 - mse: 0.1203
# Epoch 19: val_loss improved from 0.12869 to 0.12030, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1203 - mae: 0.2567 - mse: 0.1203 - val_loss: 0.1203 - val_mae: 0.2625 - val_mse: 0.1203
# Epoch 20/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1120 - mae: 0.2477 - mse: 0.1120
# Epoch 20: val_loss improved from 0.12030 to 0.11252, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1120 - mae: 0.2477 - mse: 0.1120 - val_loss: 0.1125 - val_mae: 0.2525 - val_mse: 0.1125
# Epoch 21/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1033 - mae: 0.2364 - mse: 0.1033
# Epoch 21: val_loss improved from 0.11252 to 0.10564, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.1033 - mae: 0.2364 - mse: 0.1033 - val_loss: 0.1056 - val_mae: 0.2434 - val_mse: 0.1056
# Epoch 22/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0952 - mae: 0.2250 - mse: 0.0952
# Epoch 22: val_loss improved from 0.10564 to 0.10006, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0952 - mae: 0.2250 - mse: 0.0952 - val_loss: 0.1001 - val_mae: 0.2355 - val_mse: 0.1001
# Epoch 23/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0885 - mae: 0.2150 - mse: 0.0885
# Epoch 23: val_loss improved from 0.10006 to 0.09616, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0885 - mae: 0.2150 - mse: 0.0885 - val_loss: 0.0962 - val_mae: 0.2307 - val_mse: 0.0962
# Epoch 24/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0834 - mae: 0.2088 - mse: 0.0834
# Epoch 24: val_loss improved from 0.09616 to 0.09331, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0834 - mae: 0.2088 - mse: 0.0834 - val_loss: 0.0933 - val_mae: 0.2290 - val_mse: 0.0933
# Epoch 25/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0791 - mae: 0.2052 - mse: 0.0791
# Epoch 25: val_loss improved from 0.09331 to 0.09055, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0791 - mae: 0.2052 - mse: 0.0791 - val_loss: 0.0906 - val_mae: 0.2276 - val_mse: 0.0906
# Epoch 26/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0748 - mae: 0.2005 - mse: 0.0748
# Epoch 26: val_loss improved from 0.09055 to 0.08740, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0748 - mae: 0.2005 - mse: 0.0748 - val_loss: 0.0874 - val_mae: 0.2242 - val_mse: 0.0874
# Epoch 27/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0703 - mae: 0.1945 - mse: 0.0703
# Epoch 27: val_loss improved from 0.08740 to 0.08396, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0703 - mae: 0.1945 - mse: 0.0703 - val_loss: 0.0840 - val_mae: 0.2190 - val_mse: 0.0840
# Epoch 28/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0657 - mae: 0.1871 - mse: 0.0657
# Epoch 28: val_loss improved from 0.08396 to 0.08030, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0657 - mae: 0.1871 - mse: 0.0657 - val_loss: 0.0803 - val_mae: 0.2127 - val_mse: 0.0803
# Epoch 29/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0616 - mae: 0.1799 - mse: 0.0616
# Epoch 29: val_loss improved from 0.08030 to 0.07653, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0616 - mae: 0.1799 - mse: 0.0616 - val_loss: 0.0765 - val_mae: 0.2065 - val_mse: 0.0765
# Epoch 30/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0580 - mae: 0.1739 - mse: 0.0580
# Epoch 30: val_loss improved from 0.07653 to 0.07271, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0580 - mae: 0.1739 - mse: 0.0580 - val_loss: 0.0727 - val_mae: 0.1998 - val_mse: 0.0727
# Epoch 31/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0548 - mae: 0.1686 - mse: 0.0548
# Epoch 31: val_loss improved from 0.07271 to 0.06888, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0548 - mae: 0.1686 - mse: 0.0548 - val_loss: 0.0689 - val_mae: 0.1930 - val_mse: 0.0689
# Epoch 32/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0517 - mae: 0.1633 - mse: 0.0517
# Epoch 32: val_loss improved from 0.06888 to 0.06530, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0517 - mae: 0.1633 - mse: 0.0517 - val_loss: 0.0653 - val_mae: 0.1870 - val_mse: 0.0653
# Epoch 33/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0487 - mae: 0.1582 - mse: 0.0487
# Epoch 33: val_loss improved from 0.06530 to 0.06210, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0487 - mae: 0.1582 - mse: 0.0487 - val_loss: 0.0621 - val_mae: 0.1818 - val_mse: 0.0621
# Epoch 34/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0458 - mae: 0.1533 - mse: 0.0458
# Epoch 34: val_loss improved from 0.06210 to 0.05935, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0458 - mae: 0.1533 - mse: 0.0458 - val_loss: 0.0594 - val_mae: 0.1776 - val_mse: 0.0594
# Epoch 35/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0431 - mae: 0.1484 - mse: 0.0431
# Epoch 35: val_loss improved from 0.05935 to 0.05677, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0431 - mae: 0.1484 - mse: 0.0431 - val_loss: 0.0568 - val_mae: 0.1737 - val_mse: 0.0568
# Epoch 36/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0406 - mae: 0.1436 - mse: 0.0406
# Epoch 36: val_loss improved from 0.05677 to 0.05446, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0406 - mae: 0.1436 - mse: 0.0406 - val_loss: 0.0545 - val_mae: 0.1695 - val_mse: 0.0545
# Epoch 37/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0384 - mae: 0.1392 - mse: 0.0384
# Epoch 37: val_loss improved from 0.05446 to 0.05242, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0384 - mae: 0.1392 - mse: 0.0384 - val_loss: 0.0524 - val_mae: 0.1654 - val_mse: 0.0524
# Epoch 38/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0364 - mae: 0.1353 - mse: 0.0364
# Epoch 38: val_loss improved from 0.05242 to 0.05034, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0364 - mae: 0.1353 - mse: 0.0364 - val_loss: 0.0503 - val_mae: 0.1616 - val_mse: 0.0503
# Epoch 39/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0345 - mae: 0.1316 - mse: 0.0345
# Epoch 39: val_loss improved from 0.05034 to 0.04798, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0345 - mae: 0.1316 - mse: 0.0345 - val_loss: 0.0480 - val_mae: 0.1569 - val_mse: 0.0480
# Epoch 40/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0326 - mae: 0.1278 - mse: 0.0326
# Epoch 40: val_loss improved from 0.04798 to 0.04550, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0326 - mae: 0.1278 - mse: 0.0326 - val_loss: 0.0455 - val_mae: 0.1520 - val_mse: 0.0455
# Epoch 41/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0307 - mae: 0.1240 - mse: 0.0307
# Epoch 41: val_loss improved from 0.04550 to 0.04304, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0307 - mae: 0.1240 - mse: 0.0307 - val_loss: 0.0430 - val_mae: 0.1472 - val_mse: 0.0430
# Epoch 42/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0291 - mae: 0.1205 - mse: 0.0291
# Epoch 42: val_loss improved from 0.04304 to 0.04074, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0291 - mae: 0.1205 - mse: 0.0291 - val_loss: 0.0407 - val_mae: 0.1430 - val_mse: 0.0407
# Epoch 43/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0276 - mae: 0.1172 - mse: 0.0276
# Epoch 43: val_loss improved from 0.04074 to 0.03884, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0276 - mae: 0.1172 - mse: 0.0276 - val_loss: 0.0388 - val_mae: 0.1393 - val_mse: 0.0388
# Epoch 44/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0263 - mae: 0.1141 - mse: 0.0263
# Epoch 44: val_loss improved from 0.03884 to 0.03722, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0263 - mae: 0.1141 - mse: 0.0263 - val_loss: 0.0372 - val_mae: 0.1362 - val_mse: 0.0372
# Epoch 45/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0249 - mae: 0.1111 - mse: 0.0249
# Epoch 45: val_loss improved from 0.03722 to 0.03588, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0249 - mae: 0.1111 - mse: 0.0249 - val_loss: 0.0359 - val_mae: 0.1337 - val_mse: 0.0359
# Epoch 46/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0237 - mae: 0.1083 - mse: 0.0237
# Epoch 46: val_loss improved from 0.03588 to 0.03470, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0237 - mae: 0.1083 - mse: 0.0237 - val_loss: 0.0347 - val_mae: 0.1311 - val_mse: 0.0347
# Epoch 47/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0226 - mae: 0.1059 - mse: 0.0226
# Epoch 47: val_loss improved from 0.03470 to 0.03354, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0226 - mae: 0.1059 - mse: 0.0226 - val_loss: 0.0335 - val_mae: 0.1284 - val_mse: 0.0335
# Epoch 48/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0216 - mae: 0.1035 - mse: 0.0216
# Epoch 48: val_loss improved from 0.03354 to 0.03233, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0216 - mae: 0.1035 - mse: 0.0216 - val_loss: 0.0323 - val_mae: 0.1256 - val_mse: 0.0323
# Epoch 49/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0206 - mae: 0.1007 - mse: 0.0206
# Epoch 49: val_loss improved from 0.03233 to 0.03116, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0206 - mae: 0.1007 - mse: 0.0206 - val_loss: 0.0312 - val_mae: 0.1230 - val_mse: 0.0312
# Epoch 50/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0197 - mae: 0.0980 - mse: 0.0197
# Epoch 50: val_loss improved from 0.03116 to 0.03009, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0197 - mae: 0.0980 - mse: 0.0197 - val_loss: 0.0301 - val_mae: 0.1204 - val_mse: 0.0301
# Epoch 51/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0188 - mae: 0.0956 - mse: 0.0188
# Epoch 51: val_loss improved from 0.03009 to 0.02913, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0188 - mae: 0.0956 - mse: 0.0188 - val_loss: 0.0291 - val_mae: 0.1181 - val_mse: 0.0291
# Epoch 52/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0180 - mae: 0.0933 - mse: 0.0180
# Epoch 52: val_loss improved from 0.02913 to 0.02823, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0180 - mae: 0.0933 - mse: 0.0180 - val_loss: 0.0282 - val_mae: 0.1161 - val_mse: 0.0282
# Epoch 53/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0173 - mae: 0.0914 - mse: 0.0173
# Epoch 53: val_loss improved from 0.02823 to 0.02726, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0173 - mae: 0.0914 - mse: 0.0173 - val_loss: 0.0273 - val_mae: 0.1139 - val_mse: 0.0273
# Epoch 54/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0167 - mae: 0.0897 - mse: 0.0167
# Epoch 54: val_loss improved from 0.02726 to 0.02617, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0167 - mae: 0.0897 - mse: 0.0167 - val_loss: 0.0262 - val_mae: 0.1113 - val_mse: 0.0262
# Epoch 55/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0160 - mae: 0.0877 - mse: 0.0160
# Epoch 55: val_loss improved from 0.02617 to 0.02506, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0160 - mae: 0.0877 - mse: 0.0160 - val_loss: 0.0251 - val_mae: 0.1085 - val_mse: 0.0251
# Epoch 56/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0153 - mae: 0.0856 - mse: 0.0153
# Epoch 56: val_loss improved from 0.02506 to 0.02401, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0153 - mae: 0.0856 - mse: 0.0153 - val_loss: 0.0240 - val_mae: 0.1060 - val_mse: 0.0240
# Epoch 57/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0147 - mae: 0.0835 - mse: 0.0147
# Epoch 57: val_loss improved from 0.02401 to 0.02306, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0147 - mae: 0.0835 - mse: 0.0147 - val_loss: 0.0231 - val_mae: 0.1039 - val_mse: 0.0231
# Epoch 58/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0141 - mae: 0.0815 - mse: 0.0141
# Epoch 58: val_loss improved from 0.02306 to 0.02222, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0141 - mae: 0.0815 - mse: 0.0141 - val_loss: 0.0222 - val_mae: 0.1021 - val_mse: 0.0222
# Epoch 59/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0136 - mae: 0.0797 - mse: 0.0136
# Epoch 59: val_loss improved from 0.02222 to 0.02151, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0136 - mae: 0.0797 - mse: 0.0136 - val_loss: 0.0215 - val_mae: 0.1005 - val_mse: 0.0215
# Epoch 60/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0131 - mae: 0.0783 - mse: 0.0131
# Epoch 60: val_loss improved from 0.02151 to 0.02082, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0131 - mae: 0.0783 - mse: 0.0131 - val_loss: 0.0208 - val_mae: 0.0988 - val_mse: 0.0208
# Epoch 61/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0126 - mae: 0.0770 - mse: 0.0126
# Epoch 61: val_loss improved from 0.02082 to 0.02008, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0126 - mae: 0.0770 - mse: 0.0126 - val_loss: 0.0201 - val_mae: 0.0967 - val_mse: 0.0201
# Epoch 62/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0122 - mae: 0.0755 - mse: 0.0122
# Epoch 62: val_loss improved from 0.02008 to 0.01925, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0122 - mae: 0.0755 - mse: 0.0122 - val_loss: 0.0193 - val_mae: 0.0945 - val_mse: 0.0193
# Epoch 63/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mae: 0.0741 - mse: 0.0118
# Epoch 63: val_loss improved from 0.01925 to 0.01842, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0118 - mae: 0.0741 - mse: 0.0118 - val_loss: 0.0184 - val_mae: 0.0923 - val_mse: 0.0184
# Epoch 64/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0114 - mae: 0.0728 - mse: 0.0114
# Epoch 64: val_loss improved from 0.01842 to 0.01770, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0114 - mae: 0.0728 - mse: 0.0114 - val_loss: 0.0177 - val_mae: 0.0903 - val_mse: 0.0177
# Epoch 65/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0110 - mae: 0.0716 - mse: 0.0110
# Epoch 65: val_loss improved from 0.01770 to 0.01712, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0110 - mae: 0.0716 - mse: 0.0110 - val_loss: 0.0171 - val_mae: 0.0886 - val_mse: 0.0171
# Epoch 66/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0107 - mae: 0.0703 - mse: 0.0107
# Epoch 66: val_loss improved from 0.01712 to 0.01666, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0107 - mae: 0.0703 - mse: 0.0107 - val_loss: 0.0167 - val_mae: 0.0872 - val_mse: 0.0167
# Epoch 67/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0103 - mae: 0.0689 - mse: 0.0103
# Epoch 67: val_loss improved from 0.01666 to 0.01625, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0103 - mae: 0.0689 - mse: 0.0103 - val_loss: 0.0163 - val_mae: 0.0860 - val_mse: 0.0163
# Epoch 68/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0100 - mae: 0.0677 - mse: 0.0100
# Epoch 68: val_loss improved from 0.01625 to 0.01584, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0100 - mae: 0.0677 - mse: 0.0100 - val_loss: 0.0158 - val_mae: 0.0849 - val_mse: 0.0158
# Epoch 69/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0097 - mae: 0.0665 - mse: 0.0097
# Epoch 69: val_loss improved from 0.01584 to 0.01540, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0097 - mae: 0.0665 - mse: 0.0097 - val_loss: 0.0154 - val_mae: 0.0836 - val_mse: 0.0154
# Epoch 70/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0095 - mae: 0.0654 - mse: 0.0095
# Epoch 70: val_loss improved from 0.01540 to 0.01497, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0095 - mae: 0.0654 - mse: 0.0095 - val_loss: 0.0150 - val_mae: 0.0823 - val_mse: 0.0150
# Epoch 71/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - mae: 0.0643 - mse: 0.0092
# Epoch 71: val_loss improved from 0.01497 to 0.01459, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0092 - mae: 0.0643 - mse: 0.0092 - val_loss: 0.0146 - val_mae: 0.0812 - val_mse: 0.0146
# Epoch 72/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0089 - mae: 0.0633 - mse: 0.0089
# Epoch 72: val_loss improved from 0.01459 to 0.01424, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0089 - mae: 0.0633 - mse: 0.0089 - val_loss: 0.0142 - val_mae: 0.0801 - val_mse: 0.0142
# Epoch 73/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087 - mae: 0.0623 - mse: 0.0087
# Epoch 73: val_loss improved from 0.01424 to 0.01393, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0087 - mae: 0.0623 - mse: 0.0087 - val_loss: 0.0139 - val_mae: 0.0792 - val_mse: 0.0139
# Epoch 74/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0085 - mae: 0.0614 - mse: 0.0085
# Epoch 74: val_loss improved from 0.01393 to 0.01364, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0085 - mae: 0.0614 - mse: 0.0085 - val_loss: 0.0136 - val_mae: 0.0783 - val_mse: 0.0136
# Epoch 75/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082 - mae: 0.0604 - mse: 0.0082
# Epoch 75: val_loss improved from 0.01364 to 0.01338, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0082 - mae: 0.0604 - mse: 0.0082 - val_loss: 0.0134 - val_mae: 0.0773 - val_mse: 0.0134
# Epoch 76/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0080 - mae: 0.0595 - mse: 0.0080
# Epoch 76: val_loss improved from 0.01338 to 0.01313, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0080 - mae: 0.0595 - mse: 0.0080 - val_loss: 0.0131 - val_mae: 0.0764 - val_mse: 0.0131
# Epoch 77/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - mae: 0.0587 - mse: 0.0078
# Epoch 77: val_loss improved from 0.01313 to 0.01288, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0078 - mae: 0.0587 - mse: 0.0078 - val_loss: 0.0129 - val_mae: 0.0754 - val_mse: 0.0129
# Epoch 78/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076 - mae: 0.0579 - mse: 0.0076
# Epoch 78: val_loss improved from 0.01288 to 0.01264, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0076 - mae: 0.0579 - mse: 0.0076 - val_loss: 0.0126 - val_mae: 0.0745 - val_mse: 0.0126
# Epoch 79/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074 - mae: 0.0572 - mse: 0.0074
# Epoch 79: val_loss improved from 0.01264 to 0.01238, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0074 - mae: 0.0572 - mse: 0.0074 - val_loss: 0.0124 - val_mae: 0.0736 - val_mse: 0.0124
# Epoch 80/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - mae: 0.0565 - mse: 0.0072
# Epoch 80: val_loss improved from 0.01238 to 0.01214, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0072 - mae: 0.0565 - mse: 0.0072 - val_loss: 0.0121 - val_mae: 0.0729 - val_mse: 0.0121
# Epoch 81/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - mae: 0.0558 - mse: 0.0071
# Epoch 81: val_loss improved from 0.01214 to 0.01188, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0071 - mae: 0.0558 - mse: 0.0071 - val_loss: 0.0119 - val_mae: 0.0721 - val_mse: 0.0119
# Epoch 82/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0069 - mae: 0.0551 - mse: 0.0069
# Epoch 82: val_loss improved from 0.01188 to 0.01161, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0069 - mae: 0.0551 - mse: 0.0069 - val_loss: 0.0116 - val_mae: 0.0713 - val_mse: 0.0116
# Epoch 83/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0067 - mae: 0.0544 - mse: 0.0067
# Epoch 83: val_loss improved from 0.01161 to 0.01135, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0067 - mae: 0.0544 - mse: 0.0067 - val_loss: 0.0113 - val_mae: 0.0704 - val_mse: 0.0113
# Epoch 84/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0066 - mae: 0.0538 - mse: 0.0066
# Epoch 84: val_loss improved from 0.01135 to 0.01110, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0066 - mae: 0.0538 - mse: 0.0066 - val_loss: 0.0111 - val_mae: 0.0696 - val_mse: 0.0111
# Epoch 85/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0064 - mae: 0.0532 - mse: 0.0064
# Epoch 85: val_loss improved from 0.01110 to 0.01088, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0064 - mae: 0.0532 - mse: 0.0064 - val_loss: 0.0109 - val_mae: 0.0689 - val_mse: 0.0109
# Epoch 86/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063 - mae: 0.0526 - mse: 0.0063
# Epoch 86: val_loss improved from 0.01088 to 0.01067, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0063 - mae: 0.0526 - mse: 0.0063 - val_loss: 0.0107 - val_mae: 0.0681 - val_mse: 0.0107
# Epoch 87/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0061 - mae: 0.0521 - mse: 0.0061
# Epoch 87: val_loss improved from 0.01067 to 0.01048, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0061 - mae: 0.0521 - mse: 0.0061 - val_loss: 0.0105 - val_mae: 0.0674 - val_mse: 0.0105
# Epoch 88/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0060 - mae: 0.0515 - mse: 0.0060
# Epoch 88: val_loss improved from 0.01048 to 0.01028, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0060 - mae: 0.0515 - mse: 0.0060 - val_loss: 0.0103 - val_mae: 0.0666 - val_mse: 0.0103
# Epoch 89/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0059 - mae: 0.0509 - mse: 0.0059
# Epoch 89: val_loss improved from 0.01028 to 0.01010, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0059 - mae: 0.0509 - mse: 0.0059 - val_loss: 0.0101 - val_mae: 0.0660 - val_mse: 0.0101
# Epoch 90/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0058 - mae: 0.0504 - mse: 0.0058
# Epoch 90: val_loss improved from 0.01010 to 0.00995, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0058 - mae: 0.0504 - mse: 0.0058 - val_loss: 0.0099 - val_mae: 0.0655 - val_mse: 0.0099
# Epoch 91/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056 - mae: 0.0499 - mse: 0.0056
# Epoch 91: val_loss improved from 0.00995 to 0.00980, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0056 - mae: 0.0499 - mse: 0.0056 - val_loss: 0.0098 - val_mae: 0.0649 - val_mse: 0.0098
# Epoch 92/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055 - mae: 0.0494 - mse: 0.0055
# Epoch 92: val_loss improved from 0.00980 to 0.00966, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0055 - mae: 0.0494 - mse: 0.0055 - val_loss: 0.0097 - val_mae: 0.0644 - val_mse: 0.0097
# Epoch 93/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0054 - mae: 0.0489 - mse: 0.0054
# Epoch 93: val_loss improved from 0.00966 to 0.00951, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0054 - mae: 0.0489 - mse: 0.0054 - val_loss: 0.0095 - val_mae: 0.0638 - val_mse: 0.0095
# Epoch 94/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - mae: 0.0484 - mse: 0.0053
# Epoch 94: val_loss improved from 0.00951 to 0.00938, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0053 - mae: 0.0484 - mse: 0.0053 - val_loss: 0.0094 - val_mae: 0.0632 - val_mse: 0.0094
# Epoch 95/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0052 - mae: 0.0479 - mse: 0.0052
# Epoch 95: val_loss improved from 0.00938 to 0.00924, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0052 - mae: 0.0479 - mse: 0.0052 - val_loss: 0.0092 - val_mae: 0.0626 - val_mse: 0.0092
# Epoch 96/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - mae: 0.0475 - mse: 0.0051
# Epoch 96: val_loss improved from 0.00924 to 0.00912, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0051 - mae: 0.0475 - mse: 0.0051 - val_loss: 0.0091 - val_mae: 0.0621 - val_mse: 0.0091
# Epoch 97/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0050 - mae: 0.0470 - mse: 0.0050
# Epoch 97: val_loss improved from 0.00912 to 0.00899, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0050 - mae: 0.0470 - mse: 0.0050 - val_loss: 0.0090 - val_mae: 0.0616 - val_mse: 0.0090
# Epoch 98/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0049 - mae: 0.0466 - mse: 0.0049
# Epoch 98: val_loss improved from 0.00899 to 0.00887, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0049 - mae: 0.0466 - mse: 0.0049 - val_loss: 0.0089 - val_mae: 0.0611 - val_mse: 0.0089
# Epoch 99/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - mae: 0.0462 - mse: 0.0048
# Epoch 99: val_loss improved from 0.00887 to 0.00876, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0048 - mae: 0.0462 - mse: 0.0048 - val_loss: 0.0088 - val_mae: 0.0606 - val_mse: 0.0088
# Epoch 100/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0048 - mae: 0.0458 - mse: 0.0048
# Epoch 100: val_loss improved from 0.00876 to 0.00866, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0048 - mae: 0.0458 - mse: 0.0048 - val_loss: 0.0087 - val_mae: 0.0602 - val_mse: 0.0087
# Epoch 101/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - mae: 0.0454 - mse: 0.0047
# Epoch 101: val_loss improved from 0.00866 to 0.00856, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0047 - mae: 0.0454 - mse: 0.0047 - val_loss: 0.0086 - val_mae: 0.0597 - val_mse: 0.0086
# Epoch 102/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0046 - mae: 0.0450 - mse: 0.0046
# Epoch 102: val_loss improved from 0.00856 to 0.00844, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0046 - mae: 0.0450 - mse: 0.0046 - val_loss: 0.0084 - val_mae: 0.0592 - val_mse: 0.0084
# Epoch 103/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0045 - mae: 0.0447 - mse: 0.0045
# Epoch 103: val_loss improved from 0.00844 to 0.00831, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0045 - mae: 0.0447 - mse: 0.0045 - val_loss: 0.0083 - val_mae: 0.0587 - val_mse: 0.0083
# Epoch 104/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0044 - mae: 0.0443 - mse: 0.0044
# Epoch 104: val_loss improved from 0.00831 to 0.00822, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0044 - mae: 0.0443 - mse: 0.0044 - val_loss: 0.0082 - val_mae: 0.0583 - val_mse: 0.0082
# Epoch 105/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0044 - mae: 0.0439 - mse: 0.0044
# Epoch 105: val_loss improved from 0.00822 to 0.00814, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0044 - mae: 0.0439 - mse: 0.0044 - val_loss: 0.0081 - val_mae: 0.0580 - val_mse: 0.0081
# Epoch 106/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - mae: 0.0436 - mse: 0.0043
# Epoch 106: val_loss improved from 0.00814 to 0.00803, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0043 - mae: 0.0436 - mse: 0.0043 - val_loss: 0.0080 - val_mae: 0.0575 - val_mse: 0.0080
# Epoch 107/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - mae: 0.0432 - mse: 0.0042
# Epoch 107: val_loss improved from 0.00803 to 0.00792, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0042 - mae: 0.0432 - mse: 0.0042 - val_loss: 0.0079 - val_mae: 0.0571 - val_mse: 0.0079
# Epoch 108/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - mae: 0.0429 - mse: 0.0042
# Epoch 108: val_loss improved from 0.00792 to 0.00782, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0042 - mae: 0.0429 - mse: 0.0042 - val_loss: 0.0078 - val_mae: 0.0567 - val_mse: 0.0078
# Epoch 109/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0041 - mae: 0.0426 - mse: 0.0041
# Epoch 109: val_loss improved from 0.00782 to 0.00772, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0041 - mae: 0.0426 - mse: 0.0041 - val_loss: 0.0077 - val_mae: 0.0564 - val_mse: 0.0077
# Epoch 110/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - mae: 0.0422 - mse: 0.0040
# Epoch 110: val_loss improved from 0.00772 to 0.00762, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0040 - mae: 0.0422 - mse: 0.0040 - val_loss: 0.0076 - val_mae: 0.0560 - val_mse: 0.0076
# Epoch 111/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - mae: 0.0419 - mse: 0.0040
# Epoch 111: val_loss improved from 0.00762 to 0.00754, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0040 - mae: 0.0419 - mse: 0.0040 - val_loss: 0.0075 - val_mae: 0.0557 - val_mse: 0.0075
# Epoch 112/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0039 - mae: 0.0416 - mse: 0.0039
# Epoch 112: val_loss improved from 0.00754 to 0.00747, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0039 - mae: 0.0416 - mse: 0.0039 - val_loss: 0.0075 - val_mae: 0.0554 - val_mse: 0.0075
# Epoch 113/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mae: 0.0413 - mse: 0.0038
# Epoch 113: val_loss improved from 0.00747 to 0.00740, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0038 - mae: 0.0413 - mse: 0.0038 - val_loss: 0.0074 - val_mae: 0.0551 - val_mse: 0.0074
# Epoch 114/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - mae: 0.0410 - mse: 0.0038
# Epoch 114: val_loss improved from 0.00740 to 0.00731, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0038 - mae: 0.0410 - mse: 0.0038 - val_loss: 0.0073 - val_mae: 0.0547 - val_mse: 0.0073
# Epoch 115/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0037 - mae: 0.0406 - mse: 0.0037
# Epoch 115: val_loss improved from 0.00731 to 0.00723, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0037 - mae: 0.0406 - mse: 0.0037 - val_loss: 0.0072 - val_mae: 0.0543 - val_mse: 0.0072
# Epoch 116/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0037 - mae: 0.0403 - mse: 0.0037
# Epoch 116: val_loss improved from 0.00723 to 0.00714, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0037 - mae: 0.0403 - mse: 0.0037 - val_loss: 0.0071 - val_mae: 0.0540 - val_mse: 0.0071
# Epoch 117/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036 - mae: 0.0401 - mse: 0.0036
# Epoch 117: val_loss improved from 0.00714 to 0.00707, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0036 - mae: 0.0401 - mse: 0.0036 - val_loss: 0.0071 - val_mae: 0.0537 - val_mse: 0.0071
# Epoch 118/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0036 - mae: 0.0398 - mse: 0.0036
# Epoch 118: val_loss improved from 0.00707 to 0.00699, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0036 - mae: 0.0398 - mse: 0.0036 - val_loss: 0.0070 - val_mae: 0.0534 - val_mse: 0.0070
# Epoch 119/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035 - mae: 0.0396 - mse: 0.0035
# Epoch 119: val_loss improved from 0.00699 to 0.00691, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0035 - mae: 0.0396 - mse: 0.0035 - val_loss: 0.0069 - val_mae: 0.0531 - val_mse: 0.0069
# Epoch 120/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - mae: 0.0393 - mse: 0.0035
# Epoch 120: val_loss improved from 0.00691 to 0.00683, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0035 - mae: 0.0393 - mse: 0.0035 - val_loss: 0.0068 - val_mae: 0.0528 - val_mse: 0.0068
# Epoch 121/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0390 - mse: 0.0034
# Epoch 121: val_loss improved from 0.00683 to 0.00677, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0034 - mae: 0.0390 - mse: 0.0034 - val_loss: 0.0068 - val_mae: 0.0525 - val_mse: 0.0068
# Epoch 122/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034 - mae: 0.0387 - mse: 0.0034
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.4095e-04 - mae: 0.0079 - mse: 1.4095e-04 - val_loss: 0.0018 - val_mae: 0.0185 - val_mse: 0.0018
# Epoch 958/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4075e-04 - mae: 0.0079 - mse: 1.4075e-04
# Epoch 958: val_loss improved from 0.00181 to 0.00181, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.4075e-04 - mae: 0.0079 - mse: 1.4075e-04 - val_loss: 0.0018 - val_mae: 0.0185 - val_mse: 0.0018
# Epoch 959/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4053e-04 - mae: 0.0078 - mse: 1.4053e-04
# Epoch 959: val_loss did not improve from 0.00181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.4053e-04 - mae: 0.0078 - mse: 1.4053e-04 - val_loss: 0.0018 - val_mae: 0.0185 - val_mse: 0.0018
# Epoch 960/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4031e-04 - mae: 0.0078 - mse: 1.4031e-04
# Epoch 960: val_loss did not improve from 0.00181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.4031e-04 - mae: 0.0078 - mse: 1.4031e-04 - val_loss: 0.0018 - val_mae: 0.0185 - val_mse: 0.0018
# Epoch 961/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.4007e-04 - mae: 0.0078 - mse: 1.4007e-04
# Epoch 961: val_loss improved from 0.00181 to 0.00181, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.4007e-04 - mae: 0.0078 - mse: 1.4007e-04 - val_loss: 0.0018 - val_mae: 0.0185 - val_mse: 0.0018
# Epoch 962/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3985e-04 - mae: 0.0078 - mse: 1.3985e-04
# Epoch 962: val_loss improved from 0.00181 to 0.00181, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3985e-04 - mae: 0.0078 - mse: 1.3985e-04 - val_loss: 0.0018 - val_mae: 0.0185 - val_mse: 0.0018
# Epoch 963/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3965e-04 - mae: 0.0078 - mse: 1.3965e-04
# Epoch 963: val_loss improved from 0.00181 to 0.00181, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.3965e-04 - mae: 0.0078 - mse: 1.3965e-04 - val_loss: 0.0018 - val_mae: 0.0185 - val_mse: 0.0018
# Epoch 964/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3945e-04 - mae: 0.0078 - mse: 1.3945e-04
# Epoch 964: val_loss improved from 0.00181 to 0.00181, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3945e-04 - mae: 0.0078 - mse: 1.3945e-04 - val_loss: 0.0018 - val_mae: 0.0185 - val_mse: 0.0018
# Epoch 965/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3922e-04 - mae: 0.0078 - mse: 1.3922e-04
# Epoch 965: val_loss improved from 0.00181 to 0.00181, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.3922e-04 - mae: 0.0078 - mse: 1.3922e-04 - val_loss: 0.0018 - val_mae: 0.0185 - val_mse: 0.0018
# Epoch 966/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3898e-04 - mae: 0.0078 - mse: 1.3898e-04
# Epoch 966: val_loss improved from 0.00181 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3898e-04 - mae: 0.0078 - mse: 1.3898e-04 - val_loss: 0.0018 - val_mae: 0.0185 - val_mse: 0.0018
# Epoch 967/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3879e-04 - mae: 0.0078 - mse: 1.3879e-04
# Epoch 967: val_loss improved from 0.00180 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.3879e-04 - mae: 0.0078 - mse: 1.3879e-04 - val_loss: 0.0018 - val_mae: 0.0185 - val_mse: 0.0018
# Epoch 968/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3857e-04 - mae: 0.0078 - mse: 1.3857e-04
# Epoch 968: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.3857e-04 - mae: 0.0078 - mse: 1.3857e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 969/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3839e-04 - mae: 0.0078 - mse: 1.3839e-04
# Epoch 969: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.3839e-04 - mae: 0.0078 - mse: 1.3839e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 970/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3815e-04 - mae: 0.0078 - mse: 1.3815e-04
# Epoch 970: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.3815e-04 - mae: 0.0078 - mse: 1.3815e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 971/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.3793e-04 - mae: 0.0078 - mse: 1.3793e-04
# Epoch 971: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.3793e-04 - mae: 0.0078 - mse: 1.3793e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 972/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3773e-04 - mae: 0.0078 - mse: 1.3773e-04
# Epoch 972: val_loss improved from 0.00180 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.3773e-04 - mae: 0.0078 - mse: 1.3773e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 973/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3749e-04 - mae: 0.0078 - mse: 1.3749e-04
# Epoch 973: val_loss improved from 0.00180 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3749e-04 - mae: 0.0078 - mse: 1.3749e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 974/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3728e-04 - mae: 0.0078 - mse: 1.3728e-04
# Epoch 974: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.3728e-04 - mae: 0.0078 - mse: 1.3728e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 975/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3707e-04 - mae: 0.0077 - mse: 1.3707e-04
# Epoch 975: val_loss improved from 0.00180 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.3707e-04 - mae: 0.0077 - mse: 1.3707e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 976/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.3685e-04 - mae: 0.0077 - mse: 1.3685e-04
# Epoch 976: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.3685e-04 - mae: 0.0077 - mse: 1.3685e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 977/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3664e-04 - mae: 0.0077 - mse: 1.3664e-04
# Epoch 977: val_loss improved from 0.00180 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.3664e-04 - mae: 0.0077 - mse: 1.3664e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 978/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3643e-04 - mae: 0.0077 - mse: 1.3643e-04
# Epoch 978: val_loss improved from 0.00180 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.3643e-04 - mae: 0.0077 - mse: 1.3643e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 979/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3620e-04 - mae: 0.0077 - mse: 1.3620e-04
# Epoch 979: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.3620e-04 - mae: 0.0077 - mse: 1.3620e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 980/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3599e-04 - mae: 0.0077 - mse: 1.3599e-04
# Epoch 980: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.3599e-04 - mae: 0.0077 - mse: 1.3599e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 981/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3579e-04 - mae: 0.0077 - mse: 1.3579e-04
# Epoch 981: val_loss improved from 0.00180 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3579e-04 - mae: 0.0077 - mse: 1.3579e-04 - val_loss: 0.0018 - val_mae: 0.0184 - val_mse: 0.0018
# Epoch 982/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3555e-04 - mae: 0.0077 - mse: 1.3555e-04
# Epoch 982: val_loss improved from 0.00180 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 1.3555e-04 - mae: 0.0077 - mse: 1.3555e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 983/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3535e-04 - mae: 0.0077 - mse: 1.3535e-04
# Epoch 983: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.3535e-04 - mae: 0.0077 - mse: 1.3535e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 984/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3514e-04 - mae: 0.0077 - mse: 1.3514e-04
# Epoch 984: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.3514e-04 - mae: 0.0077 - mse: 1.3514e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 985/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3491e-04 - mae: 0.0077 - mse: 1.3491e-04
# Epoch 985: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.3491e-04 - mae: 0.0077 - mse: 1.3491e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 986/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3470e-04 - mae: 0.0077 - mse: 1.3470e-04
# Epoch 986: val_loss improved from 0.00180 to 0.00180, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.3470e-04 - mae: 0.0077 - mse: 1.3470e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 987/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3450e-04 - mae: 0.0077 - mse: 1.3450e-04
# Epoch 987: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.3450e-04 - mae: 0.0077 - mse: 1.3450e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 988/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3429e-04 - mae: 0.0077 - mse: 1.3429e-04
# Epoch 988: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.3429e-04 - mae: 0.0077 - mse: 1.3429e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 989/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3408e-04 - mae: 0.0077 - mse: 1.3408e-04
# Epoch 989: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3408e-04 - mae: 0.0077 - mse: 1.3408e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 990/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3386e-04 - mae: 0.0077 - mse: 1.3386e-04
# Epoch 990: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.3386e-04 - mae: 0.0077 - mse: 1.3386e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 991/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3365e-04 - mae: 0.0076 - mse: 1.3365e-04
# Epoch 991: val_loss did not improve from 0.00180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.3365e-04 - mae: 0.0076 - mse: 1.3365e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 992/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3343e-04 - mae: 0.0076 - mse: 1.3343e-04
# Epoch 992: val_loss improved from 0.00180 to 0.00179, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3343e-04 - mae: 0.0076 - mse: 1.3343e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 993/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3324e-04 - mae: 0.0076 - mse: 1.3324e-04
# Epoch 993: val_loss improved from 0.00179 to 0.00179, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.3324e-04 - mae: 0.0076 - mse: 1.3324e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 994/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3305e-04 - mae: 0.0076 - mse: 1.3305e-04
# Epoch 994: val_loss did not improve from 0.00179
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3305e-04 - mae: 0.0076 - mse: 1.3305e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 995/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3283e-04 - mae: 0.0076 - mse: 1.3283e-04
# Epoch 995: val_loss did not improve from 0.00179
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.3283e-04 - mae: 0.0076 - mse: 1.3283e-04 - val_loss: 0.0018 - val_mae: 0.0183 - val_mse: 0.0018
# Epoch 996/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3259e-04 - mae: 0.0076 - mse: 1.3259e-04
# Epoch 996: val_loss improved from 0.00179 to 0.00179, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.3259e-04 - mae: 0.0076 - mse: 1.3259e-04 - val_loss: 0.0018 - val_mae: 0.0182 - val_mse: 0.0018
# Epoch 997/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3242e-04 - mae: 0.0076 - mse: 1.3242e-04
# Epoch 997: val_loss improved from 0.00179 to 0.00179, saving model to ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/model/LU-VIAREGGIO_fed_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.3242e-04 - mae: 0.0076 - mse: 1.3242e-04 - val_loss: 0.0018 - val_mae: 0.0182 - val_mse: 0.0018
# Epoch 998/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3222e-04 - mae: 0.0076 - mse: 1.3222e-04
# Epoch 998: val_loss did not improve from 0.00179
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.3222e-04 - mae: 0.0076 - mse: 1.3222e-04 - val_loss: 0.0018 - val_mae: 0.0182 - val_mse: 0.0018
# Epoch 999/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3199e-04 - mae: 0.0076 - mse: 1.3199e-04
# Epoch 999: val_loss did not improve from 0.00179
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.3199e-04 - mae: 0.0076 - mse: 1.3199e-04 - val_loss: 0.0018 - val_mae: 0.0182 - val_mse: 0.0018
# Epoch 1000/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.3182e-04 - mae: 0.0076 - mse: 1.3182e-04
# Epoch 1000: val_loss did not improve from 0.00179
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 1.3182e-04 - mae: 0.0076 - mse: 1.3182e-04 - val_loss: 0.0018 - val_mae: 0.0182 - val_mse: 0.0018
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# --- federated after local fine-tuning ---
# /var/folders/1s/vnvjtlb516n5mswtv7rf58b80000gn/T/ipykernel_1863/2011710758.py:96: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   axes[1].plot([plot_min, plot_max], [plot_min, plot_max], 'k--', alpha=0.5, label='Perfetto (y=x)', color = 'red')
# Salvo 74 plot in: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/federated_fd/TEST
# Plot salvati correttamente.
# Test MAE: 0.0443
# Test RMSE: 0.1203
# Test MAPE: 0.41%
# Test R2: 0.9985
# Valore medio del test set: 10.5587
#
# Log salvato in: ../RISULTATI/2025-11-30/esperimento_LU-VIAREGGIO_14-19-16/federated_fd_evaluation_log.json
